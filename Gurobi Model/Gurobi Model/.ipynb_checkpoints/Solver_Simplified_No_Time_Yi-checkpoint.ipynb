# %%
from gurobipy import Model, GRB, quicksum, tuplelist
import numpy as np
import pandas as pd

# %%
# The following file works as a reference table to match the names of 2 sheets
hub_list = pd.read_csv('Database/Hub list.csv')
hub_list.Ref_City = hub_list.Ref_City + "-" + hub_list.Country

# drop duplicates
hub_list.drop_duplicates(subset = "Ref_City", keep='first', inplace=True)


hub_ref = {}
for row in hub_list.index:
    hub_ref[hub_list.loc[row, "City"]] = hub_list.loc[row, "Ref_City"]

    
    
def name_transform(city_name):
    if city_name in hub_ref.keys():
        return hub_ref[city_name]
    else:
        return city_name

# %%
# Simple Version
masterfile = pd.read_excel("Database/Simple/Simple Routes.xlsx", sheet_name = 0)

# Complete Version
#masterfile = pd.read_csv("Database/inter_distances.csv")

# %%
# Import forecast for creating the country set
forecast = pd.read_csv("Database/Average_Forecast.csv")
forecast.fillna(0, inplace = True)

# Only satisfied those the current network can reach
# Otherwise the solution would be infeasible

used_c = masterfile["Origin Country"].unique().tolist() +  masterfile["Destination Country"].unique().tolist() # Not every hubs in the hub list is used
used_c = list( dict.fromkeys(used_c) )  # Remove duplicate

all_c = forecast.Origin.unique().tolist() +  forecast.Destination.unique().tolist() # Not every hubs in the hub list is used
all_c = list( dict.fromkeys(all_c) )  # Remove duplicate

for x in used_c:
    try:
        all_c.remove(x)
    except:
        continue
        
for c in all_c:
    forecast["Origin"].replace(c, np.nan, inplace = True)
    forecast["Destination"].replace(c, np.nan, inplace = True)
forecast.dropna(how = "any", inplace = True)


# Set up the threshold for the demands
minimum_demands = 0
maximum_demands = 10000000000
forecast["Target"] = forecast.apply(lambda row: row.Average if row.Average >= minimum_demands else 0, axis = 1)

forecast["Target"] = forecast.apply(lambda row: row.Target if row.Target <= maximum_demands else 0, axis = 1)


forecast = forecast[forecast["Target"] > 0]
country_set = list(zip(forecast["Origin"].to_list(), forecast["Destination"].to_list()))

origin_list = list(forecast["Origin"].unique())
dst_list =  list(forecast["Destination"].unique())

country_with_forecast = forecast.Origin.unique().tolist() +  forecast.Destination.unique().tolist()
country_with_forecast = list( dict.fromkeys(country_with_forecast))  # Remove Dup

# %%
len(forecast)
# Out:
# 212

# %% [markdown]
# # Define the Set
# ## 1. Hubs in each Country (L) & All Hubs (H)

# %%
used_hubs = masterfile.From.unique().tolist() +  masterfile.To.unique().tolist() # Not every hubs in the hub list is used
used_hubs = list( dict.fromkeys(used_hubs) )  # Remove duplicate

hub_list_used = hub_list.set_index("Ref_City")
hub_list_used = hub_list_used.loc[hub_list_used.index.isin(used_hubs), :]
hub_list_used.reset_index(inplace = True)

#hub_list_used["Country"] = hub_list_used.apply(lambda row: row["Ref_City"].split("-")[-1], axis = 1) # To fill NA in country

L = {}
for country in country_with_forecast:  # hub_list_used.Country.unique():
    hub_collect = hub_list_used[hub_list_used.loc[:, "Country"] == country]["Ref_City"].tolist()
    L[country] = hub_collect

    #for row in hub_list_used.index:

    #L[hub_list_used.loc[row, "Country"]].append(hub_list_used.loc[row, "Ref_City"])
H = hub_list_used.Ref_City.unique().tolist() # All hubs

# %% [markdown]
# ## 2. European Countries (E)

# %%
E = country_with_forecast # from the "forecast" file

# %% [markdown]
# ## 3. Truck Types (T)

# %%
truck_cap = pd.read_csv("Database/TruckVSCap.csv")
T = truck_cap["Truck Type"].tolist()
T.remove("Swap Body") # To simplify the model

# %% [markdown]
# ## Define subset for the later use

# %%
# Define tuplelist for the assign of variables

mjk = tuplelist([(m,j,k) for m, k in country_set for j in country_with_forecast if (m != j) & (j != k)])
mk = tuplelist([(m,k) for m, k in country_set])

mj_k = [(m, j) for m in origin_list for j in country_with_forecast if (m, j) not in mk if m != j]   # m connects to j exlcudes k (transit countries)
mj_k = list( dict.fromkeys(mj_k) )

#j_mk = [(m, k) for m in country_with_forecast for k in dst_list if (m not in origin_list) & (m != k)]   # m connects to j exlcudes k (transit countries)
j_mk = [(j, k)  for j in country_with_forecast for k in dst_list if (j,k) not in mk if k != j]  
#j_mk = [(j, k) for m, j, k in mjk if (j,k) not in mk]   # j excludes m (transit countries), connects to k
j_mk = list( dict.fromkeys(j_mk) )

mk_all = j_mk + mj_k + mk
mk_all = list( dict.fromkeys(mk_all) )

pq = tuplelist([(p,q) for m,k in mk for p in L[m] for q in L[k]])
piq = tuplelist([(p,i,q) for (m,j,k) in mjk for p in L[m] for i in L[j] for q in L[k]])
pq_all = tuplelist((p, q) for m,k in mk_all for p in L[m] for q in L[k])
pqt = tuplelist([(p,q,t) for p,q in pq_all for t in T])

# %% [markdown]
# # Define all the parameters
#
# ## 1. Cost:
# Transportation Cost between hub p ∈ H and hub q ∈ H using truck t ∈ T (Euro/ kg)

# %%
cost_file = pd.read_csv("Database/Costs.csv")

# %%
cost = {}
for row in cost_file.index:
    cost_key = (cost_file["From"][row], cost_file["To"][row], cost_file["Truck type"][row])
    cost[cost_key] = cost_file["Cost/kg"][row]
    
cl_distance = 500

if "Co-loading" in T:
    for p, q in pq_all:
        cost[(p, q, "Co-loading")] = max([cost[p_s, q_s, t] for p_s, q_s, t in pqt.select(p, q, "*") if t != "Co-loading"])*1.5 if cost[(p, q, "Van")] < ((0.6*cl_distance+5)/2250) else 99
        # (0.6*500+5)/2250 use distance as a filter, over 500 km, the Co-loading opportunities are less
'''
for p, q in pq:
    cost[(p, q, "Co-loading-Extra")] = cost[(p, q, "Van")]*10
'''
# Out:
# '\nfor p, q in pq:\n    cost[(p, q, "Co-loading-Extra")] = cost[(p, q, "Van")]*10\n'

# %% [markdown]
# # 2. Forecast volume: Z
# Average forecasted parcel volume from country m ∈ E to country j ∈ E

# %%
Z = {}


for row in forecast.index:
    key = (forecast["Origin"][row], forecast["Destination"][row])
    Z[key] = int(round(forecast["Target"][row])) # Can only be interger

# Some missing connection in the forecast
for conn in mk:
    if conn not in Z.keys():
        Z[conn] = 0
        print(conn)

# %% [markdown]
# ## 3. Current Freqency (F_)
# the frequency of truck t from hub to hub q in the current network.

# %%
# The following code transform the excel files to csv file in specific format
'''
freq_truck = pd.read_excel("Database/Result_Freq.xlsx", sheet_name = 0)
freq_truck.replace("Ryton Gateway", "Ryton", inplace = True)
freq_truck["From"] = freq_truck.apply(lambda row: name_transform(row["Org. GTW"]), axis = 1)
freq_truck["To"] = freq_truck.apply(lambda row: name_transform(row["Dst. GTW"]), axis = 1)
freq_truck.loc[:, :].to_csv("Database/current_network.csv")

'''
# Out:
# '\nfreq_truck = pd.read_excel("Database/Result_Freq.xlsx", sheet_name = 0)\nfreq_truck.replace("Ryton Gateway", "Ryton", inplace = True)\nfreq_truck["From"] = freq_truck.apply(lambda row: name_transform(row["Org. GTW"]), axis = 1)\nfreq_truck["To"] = freq_truck.apply(lambda row: name_transform(row["Dst. GTW"]), axis = 1)\nfreq_truck.loc[:, :].to_csv("Database/current_network.csv")\n\n'

# %%
freq_current = pd.read_csv("Database/current_network.csv")
# The following section work as a formatting part. To avoid different naming issues
freq_current.replace("trailer", "Trailer", inplace = True)
freq_current.replace("2 swap bodies", "2 Swap Bodies", inplace = True)
freq_current.replace("van", "Van", inplace = True)
freq_current.replace("1 swap body", "Swap Body", inplace = True)
freq_current.replace("SEMI TRAILER", "Swap Body", inplace = True)
freq_current.replace("Cargo 50 m3", "Swap Body", inplace = True)
freq_current.replace("Sea Container", "2 Swap Bodies", inplace = True)
freq_current.replace("Van 15 m3", "Van", inplace = True)
freq_current.replace("Van 22m3", "Van", inplace = True)
freq_current.replace("4 swap bodies", "2 Swap Bodies", inplace = True)

# %%
F_ = {}
for row in freq_current.index:
    key = (freq_current.loc[row, "From"], freq_current.loc[row, "To"], freq_current.loc[row, "Truck type"])
    value = freq_current.loc[row, "Frequency"]
    
    F_[key] = value
    
for target in pqt:
    if target not in F_.keys():
        F_[target] = 0

# %% [markdown]
# ## 4. Travel time (TT)
# Total transportation time from hub p ∈ H to q ∈ H

# %%
tt_file = pd.read_csv("Database/travel time.csv")
TT = {}
for row in tt_file.index:
    key = (tt_file.loc[row, "From"], tt_file.loc[row, "To"])
    value = tt_file.loc[row, "est_tt"]
    
    TT[key] = value

# %% [markdown]
# ## 5. Hub Open & Cut-off time
# - Op = Hub opened time for hub p ∈ H
# - COp  = Hub cut off time for hub p ∈ H

# %%
def transform_time(target):
    try: 
        return int(target.split(":")[0]) + int(target.split(":")[1])/60 
    except:
        return 0

# %%
'''
hub_info = pd.read_csv("Database/Hub Cutoff and Open Time.csv")
hub_info["Hub"] = hub_info.apply(lambda row: name_transform(row["Gateways"]), axis = 1)
hub_info["Cut-off"] = hub_info.apply(lambda row: transform_time(row["Cut-Off"]), axis = 1)
hub_info["Open"] = hub_info.apply(lambda row: transform_time(row["Hub-Opening-Time"]), axis = 1)
hub_info.to_csv("Database/hub_info.csv")
'''
# Out:
# '\nhub_info = pd.read_csv("Database/Hub Cutoff and Open Time.csv")\nhub_info["Hub"] = hub_info.apply(lambda row: name_transform(row["Gateways"]), axis = 1)\nhub_info["Cut-off"] = hub_info.apply(lambda row: transform_time(row["Cut-Off"]), axis = 1)\nhub_info["Open"] = hub_info.apply(lambda row: transform_time(row["Hub-Opening-Time"]), axis = 1)\nhub_info.to_csv("Database/hub_info.csv")\n'

# %%
hub_info = pd.read_csv("Database/hub_info.csv")
merged_hub_info = hub_list_used.merge(hub_info[["Hub", "Open", "Cut-off"]], left_on = "Ref_City", right_on = "Hub", how = "left")

merged_hub_info["Open"].fillna(merged_hub_info["Open"].mode().values[0], inplace = True)
merged_hub_info["Cut-off"].fillna(merged_hub_info["Cut-off"].mode().values[0], inplace = True)

O = {} # Open time
for row in merged_hub_info.index:
    key = merged_hub_info.loc[row, "Ref_City"]
    value = merged_hub_info.loc[row, "Open"]
    O[key] = value

CO = {} # Cut-off time
for row in merged_hub_info.index:
    key = merged_hub_info.loc[row, "Ref_City"]
    value = merged_hub_info.loc[row, "Cut-off"]
    CO[key] =  value

# %% [markdown]
# ## 6. Truck Capacity

# %%
C = {}
for row in truck_cap.index:
    C[truck_cap.loc[row, "Truck Type"]] = truck_cap.loc[row, "Capacity"]

# %% [markdown]
# # Start the model

# %%
model = Model("DHL")
# Out:
# Using license file /Users/yi/gurobi.lic
# Academic license - for non-commercial use only

# %% [markdown]
# # Define the variables
# Decision variables:
# - xpq = 1 if the transportation from hub p ∈ H to hub q ∈ H is direct, else 0
# - x’piq = 1 if the transportation from hub p ∈ H to hub q ∈ H has to go through i ∈ H, else 0
# - Xmk = 1 if the transportation from country m ∈ E to county k ∈ E is direct, else 0
# - X’mjk = 1 if the transportation from country m ∈ E  to county k ∈ E  has to go through country j ∈ E , else 0
# - Vpq = route capacity from hub p ∈ H to hub q ∈ H
# - Fpqt = recommended frequency of truck t ∈ T from hub p ∈ H to hub q ∈ H
# - Spq = start time of truck from hub p ∈ H to hub q ∈ H,
# - Npq = Night needed from hub p ∈ H to hub q ∈ H

# %%
x = model.addVars(pq , vtype=GRB.BINARY, name='xpq')  # Direct from hub to hub

x_ = model.addVars(piq, vtype = GRB.BINARY, name = 'x_piq')  # Indirect from hub to hub

X = model.addVars(mk , vtype=GRB.BINARY, name='Xmk')       # Direct from country to country

X_ = model.addVars(mjk,  vtype = GRB.BINARY, name = 'X_mjk') # Indirect from country to country

V = model.addVars(pq_all , vtype=GRB.INTEGER, lb=0 ,name='Vpq')   # Route capacity

F=model.addVars(pqt , vtype=GRB.INTEGER, lb=0, name='Fpqt') # Recommended Frequency

# S=model.addVars(pq_all , vtype=GRB.CONTINUOUS, name='Spq')         # Start time from hub p

# N=model.addVars(pq_all , vtype=GRB.INTEGER, name='Npq')         # Night Needed from hub p to hub q

CL = model.addVars(pq_all, vtype = GRB.INTEGER, lb = 0, name = "CLpq") # Co-loading (in) between p and q

# %%
attri_dict = {"hub_direct": x, "hub_indirect" : x_, "country_direct" : X, "country_indirect" : X_,
              "route_cap": V, "freq" : F, "Co-loading":CL}

# %% [markdown]
# ## Objective

# %%
("NL", "AT") in mj_k
# Out:
# False

# %%
model.update()

# Minimize the travel time for each route
model.setObjective(quicksum(x[p, q] * TT[p, q] for p, q in pq) +
                   quicksum(x_[p, i ,q] * (TT[p, i] + 9 + TT[i, q])for p, i, q in piq) # Consider the transit time in the hubs
                                                                                       # Taking 9 as an example
                   ,  GRB.MINIMIZE)

# %% [markdown]
# ## Constraints

# %%
### Constraints
## Direct or Indirect Transportation

model.addConstrs(((quicksum(X_[m,j,k] for j in E if (j != m) & (j != k)) == 
                   (1 - X[m,k])) for m, k in mk),
                 "Transportation can be direct or Indirect")


## Linking Countries and Hubs

model.addConstrs(((quicksum(x[p,q] for p in L[m] for q in L[k]) == 
                  X[m,k]) for m, k in mk), "Linking_pq")  ## We can't use E_mjk here
model.addConstrs(((quicksum(x_[p,i,q] for p in L[m] for i in L[j] for q in L[k]) ==
                 X_[m,j,k]) for m,j,k in mjk), "Linking_piq")

## Truck Capacity:

# V = monthly demand of the route
# For the countries of p, q are in mk
model.addConstrs(((V[p,q] ==  
                 quicksum(x_[p,q,i] * Z[m,j] for m, k, j in mjk.select(m, k, "*") for i in L[j]) +
                 quicksum(x_[i,p,q] * Z[j,k] for j, m, k in mjk.select("*", m, k) for i in L[j]) + 
                 x[p,q] * Z[m,k])
                 for m, k in mk for p in L[m] for q in L[k]), "Truck Capacity")

# For the countries of p are in the origin, q are not in the destination:
model.addConstrs((V[p,q] ==  
                 quicksum(x_[p,q,i] * Z[m,j] for m, k, j in mjk.select(m, k, "*") for i in L[j])
                 for m, k in mj_k for p in L[m] for q in L[k] if (m,k) not in j_mk), "Truck Capacity")
                 
# For the countries of p are not in the origin, q are in the destination:           
model.addConstrs((V[p,q] ==  
                 quicksum(x_[i,p,q] * Z[j,k] for j, m, k in mjk.select("*", m, k) for i in L[j]) 
                 for m, k in j_mk for p in L[m] for q in L[k] if (m,k) not in mj_k), "Truck Capacity")

# For the countries of p and q are not in mk, but in j_mk and mj_k in the same time
model.addConstrs((V[p,q] ==  
                 quicksum(x_[p,q,i] * Z[m,j] for m, k, j in mjk.select(m, k, "*") for i in L[j]) +
                 quicksum(x_[i,p,q] * Z[j,k] for j, m, k in mjk.select("*", m, k) for i in L[j])
                 for m, k in j_mk for p in L[m] for q in L[k] if (m,k) in mj_k), "Truck Capacity 4")


## Truck type and Frequency of trucks
# transforming the weekly frequency to monthly by multiplying 4
model.addConstrs(((V[p,q] + CL[p, q]*4 <=   # Updated
                 quicksum(F[p,q,t] * C[t] * 4 for t in T) )
                 for m, k in mk_all for q in L[k] for p in L[m]),
                 "Truck Type and Frequency"
                )

# Co-loading out constraints
# model.addConstrs((F[p,q,"Co-loading"] <= 2000 for p,q in pq_all), "Coloading out constraints") ## Removed after discussion on 6/22

# Co-loading in constraints
model.addConstrs((CL[p,q] <= 2000 for p,q in pq_all), "Coloading in constraints")
model.addConstrs((CL[p,q] <= quicksum(F[p,q,t]*C[t] for t in T)*0.3 for p, q in pq_all), "Coloading in constraints 2")


'''
BigM = 9999
model.addConstrs((S[p,q] + TT[p,q] - N[p,q] * 24  <=  
                 CO[q] + 
                 BigM * (
                     1 - (x[p, q] + 
                          quicksum(x_[p, q, i] for m, k, j in mjk.select(m, k, "*") for i in L[j]) + 
                          quicksum(x_[i, p, q] for j, m, k in mjk.select("*", m, k) for i in L[j])
                 ) ) for m,k in mk for q in L[k] for p in L[m]), "Hub Cut Off Time")


BigMM = 9000

model.addConstrs((S[p,q] + TT[p,q] - N[p,q] * 24  >=  
                 O[q] + 
                 BigMM * (
                     1 - (x[p, q] + 
                          quicksum(x_[p, q, i] for m, k, j in mjk.select(m, k, "*") for i in L[j]) + 
                          quicksum(x_[i, p, q] for j, m, k in mjk.select("*", m, k) for i in L[j])
                 ) ) for m,k in mk for q in L[k] for p in L[m]), "Hub Open Time")

'''

# Assumption: all the excessive spaces could be loaded with co-loading opportunities in the current network
# Assumption: In the new network, all the co-loading oppottunities doesn't exist


Cost_bound = 1.05
Current_full = 1


'''
# The tighten model (loose a bit)
model.addConstr((quicksum(F[p,q,t] * cost[p,q,t] * C[t] for p, q, t in pqt) *
                 quicksum(F_[p,q,t] * C[t] for p, q, t in pqt) <= 
                 (quicksum(F_[p,q,t] * cost[p,q,t] * C[t] for p, q, t in pqt) *
                 (quicksum(Z[m,k] for m, k in mk)/4 + quicksum(CL[p,q] for p,q in pq)) * Cost_bound))
                 , "Cost Constraint")
'''

current_cost = sum(F_[p,q,t] * C[t] * cost[p,q,t] for p, q, t in pqt) / sum(F_[p,q,t] * C[t] for p,q,t in pqt)

model.addConstr((quicksum(F[p,q,t] * cost[p,q,t] * C[t] for p, q, t in pqt) <= 
                 (current_cost * (quicksum(V[p,q] for p, q in pq_all) / 4 + quicksum(CL[p,q] for p,q in pq))) * Cost_bound / Current_full), "Cost Constraint")
# Out:
# <gurobi.Constr *Awaiting Model Update*>

# %% [markdown]
# ## Solver

# %%
model.update()
model.printStats()
# Out:
# Statistics for model DHL :
#   Linear constraint matrix    : 23305 Constrs, 205178 Vars, 610658 NZs
#   Variable types              : 0 Continuous, 205178 Integer (177854 Binary)
#   Matrix coefficient range    : [ 0.020041, 1.43338e+06 ]
#   Objective coefficient range : [ 2.1, 197.2 ]
#   Variable bound range        : [ 1, 1 ]
#   RHS coefficient range       : [ 1, 2000 ]

# %%
# model.reset()

timeLimit = 3600*8 # In second

model.Params.TimeLimit = timeLimit - model.getAttr(GRB.Attr.Runtime)

model.Params.Heuristics = 0.5

model.Params.MIPFocus=3

model.Params.TuneCriterion = 2

model.Params.TuneTrials = 3

model.Params.SolutionLimit = 10

oldSolutionLimit = model.Params.SolutionLimit

model.Params.Seed = 3

model.Params.TuneTimeLimit = timeLimit/3

model.tune()

# model.feasRelaxS(1, False, False, True)

model.optimize()


'''
if model.tuneResultCount > 0:

    # Load the best tuned parameters into the model
    model.getTuneResult(0)

    # Write tuned parameters to a file
    model.write('tune.prm')

    # Solve the model using the tuned parameters
    model.optimize()
    
'''
# Out:
# Changed value of parameter TimeLimit to 28800.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Changed value of parameter Heuristics to 0.5
#    Prev: 0.05  Min: 0.0  Max: 1.0  Default: 0.05
# Changed value of parameter MIPFocus to 3
#    Prev: 0  Min: 0  Max: 3  Default: 0
# Changed value of parameter TuneCriterion to 2
#    Prev: -1  Min: -1  Max: 3  Default: -1
# Parameter TuneTrials unchanged
#    Value: 3  Min: 1  Max: 2000000000  Default: 3
# Changed value of parameter SolutionLimit to 10
#    Prev: 2000000000  Min: 1  Max: 2000000000  Default: 2000000000
# Changed value of parameter Seed to 3
#    Prev: 0  Min: 0  Max: 2000000000  Default: 0
# Changed value of parameter TuneTimeLimit to 9600.0
#    Prev: -1.0  Min: -1.0  Max: inf  Default: -1.0
#
# Solving model using baseline parameter set with TimeLimit=28800s
#
# Solving with random seed #1 ...
# Optimize a model with 23305 rows, 205178 columns and 610658 nonzeros
# Model fingerprint: 0xa913f8ef
# Variable types: 0 continuous, 205178 integer (177854 binary)
# Coefficient statistics:
#   Matrix range     [2e-02, 1e+06]
#   Objective range  [2e+00, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Presolve removed 8418 rows and 8457 columns (presolve time = 5s) ...
# Presolve removed 9994 rows and 10033 columns
# Presolve time: 9.76s
# Presolved: 13311 rows, 195145 columns, 576912 nonzeros
# Variable types: 0 continuous, 195145 integer (174022 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
# Presolve removed 960 rows and 960 columns
# Presolved: 12351 rows, 194185 columns, 574992 nonzeros
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    7.3289446e+03   4.967810e+03   7.525058e+09     11s
# Concurrent spin time: 0.18s
#
# Solved with dual simplex
#
# Root relaxation: objective 6.237517e+03, 671 iterations, 1.72 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 6237.51667    0  212          - 6237.51667      -     -   13s
#      0     0 6269.47303    0  270          - 6269.47303      -     -   37s
#      0     0 6278.49852    0  272          - 6278.49852      -     -   50s
#      0     0 6329.55412    0  314          - 6329.55412      -     -   63s
#      0     0 6335.60113    0  293          - 6335.60113      -     -   76s
#      0     0 6336.97067    0  293          - 6336.97067      -     -   76s
#      0     0 6365.43826    0  238          - 6365.43826      -     -   90s
#      0     0 6369.08767    0  238          - 6369.08767      -     -  105s
#      0     0 6369.24542    0  240          - 6369.24542      -     -  105s
#      0     0 6369.26227    0  240          - 6369.26227      -     -  105s
#      0     0 6382.91606    0  294          - 6382.91606      -     -  120s
#      0     0 6383.73499    0  294          - 6383.73499      -     -  131s
#      0     0 6383.74083    0  300          - 6383.74083      -     -  132s
#      0     0 6392.06803    0  332          - 6392.06803      -     -  143s
#      0     0 6415.60568    0  244 6424.70333 6415.60568  0.14%     -  434s
#      0     0 6415.60568    0  323 6424.70333 6415.60568  0.14%     -  434s
#      0     0 6415.60568    0  309 6424.70333 6415.60568  0.14%     -  434s
#      0     0 6415.60568    0  321 6424.70333 6415.60568  0.14%     -  434s
#      0     0 6415.92936    0  359 6424.70333 6415.92936  0.14%     -  434s
#      0     0 6416.05786    0  354 6424.70333 6416.05786  0.13%     -  434s
#      0     0 6417.03040    0  280 6424.70333 6417.03040  0.12%     -  436s
# H    0     0                    6424.4000000 6417.03040  0.11%     -  436s
#      0     0 6417.11501    0  286 6424.40000 6417.11501  0.11%     -  436s
#      0     0 6418.02492    0  232 6424.40000 6418.02492  0.10%     -  442s
#      0     0 6418.02492    0  187 6424.40000 6418.02492  0.10%     -  444s
#      0     0 6418.02492    0  288 6424.40000 6418.02492  0.10%     -  445s
#      0     0 6418.02492    0  269 6424.40000 6418.02492  0.10%     -  445s
#      0     0 6418.02492    0  209 6424.40000 6418.02492  0.10%     -  445s
#      0     0 6418.02492    0  184 6424.40000 6418.02492  0.10%     -  445s
#      0     0 6418.02492    0  238 6424.40000 6418.02492  0.10%     -  445s
#      0     0 6418.02492    0  251 6424.40000 6418.02492  0.10%     -  446s
#      0     0 6418.02492    0  330 6424.40000 6418.02492  0.10%     -  446s
#      0     0 6418.02492    0  296 6424.40000 6418.02492  0.10%     -  446s
#      0     0 6418.02492    0  300 6424.40000 6418.02492  0.10%     -  446s
#      0     0 6418.15595    0  273 6424.40000 6418.15595  0.10%     -  446s
#      0     0 6418.29996    0  268 6424.40000 6418.29996  0.09%     -  446s
#      0     0 6418.37714    0  263 6424.40000 6418.37714  0.09%     -  446s
#      0     0 6418.94096    0  264 6424.40000 6418.94096  0.08%     -  448s
# H    0     0                    6424.2366667 6418.94096  0.08%     -  448s
# Cutting planes:
#   Gomory: 328
#   Cover: 1
#   MIR: 814
#   StrongCG: 24
#   Flow cover: 144
#   Zero half: 34
#   RLT: 17
#   Relax-and-lift: 1
#
# Explored 1 nodes (63624 simplex iterations) in 448.63 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 8: 6424.24 6424.4 6424.7 ... 6435.29
#
# Solution limit reached
# Best objective 6.424236666667e+03, best bound 6.418940955919e+03, gap 0.0824%
#
#
# -------------------------------------------------------------------------------
# Begin tuning (baseline mean objective 6.424540e+03)...
# -------------------------------------------------------------------------------
#
# Testing candidate parameter set 2...
#
# 	SolutionLimit 10
# 	NormAdjust 0
# 	Heuristics 0.5
# 	MIPFocus 3
#
# Solving with random seed #1 ... objective 6.423677e+03
# Solving with random seed #2 ... objective 6.423723e+03
# Solving with random seed #3 ... objective 6.424470e+03
#
# Improvement found:
#   baseline: mean objective 6.424540e+03
#   improved: mean objective 6.423957e+03
# Total elapsed tuning time 2717s (6883s remaining)
#
# -------------------------------------------------------------------------------
#
# Testing candidate parameter set 3...
#
# 	SolutionLimit 10
# 	Heuristics 0.5
# 	MIPFocus 3
# 	GomoryPasses 5
#
# Solving with random seed #1 ... objective 6.425637e+03
# Solving with random seed #2 ... objective 6.423957e+03
# Solving with random seed #3 ... objective 6.427197e+03
#
# Progress so far:
#   baseline: mean objective 6.424540e+03
#   best:     mean objective 6.423957e+03
# Total elapsed tuning time 3915s (5685s remaining)
#
# -------------------------------------------------------------------------------
#
# Testing candidate parameter set 4...
#
# 	SolutionLimit 10
# 	Heuristics 0.5
# 	MIPFocus 3
# 	VarBranch 3
#
# Solving with random seed #1 ... objective 6.424610e+03
# Solving with random seed #2 ... objective 6.424773e+03
# Solving with random seed #3 ... objective 6.424237e+03
#
# Progress so far:
#   baseline: mean objective 6.424540e+03
#   best:     mean objective 6.423957e+03
# Total elapsed tuning time 5154s (4446s remaining)
#
# -------------------------------------------------------------------------------
#
# Testing candidate parameter set 5...
#
# 	SolutionLimit 10
# 	Heuristics 0.5
# 	MIPFocus 3
# 	PrePasses 1
#
# Solving with random seed #1 ... objective 6.424237e+03
# Solving with random seed #2 ... objective 6.424957e+03
# Solving with random seed #3 ... objective 6.421977e+03
#
# Improvement found:
#   baseline: mean objective 6.424540e+03
#   improved: mean objective 6.423723e+03
# Total elapsed tuning time 6520s (3080s remaining)
#
# -------------------------------------------------------------------------------
#
# Testing candidate parameter set 6...
#
# 	SolutionLimit 10
# 	Heuristics 0.5
# 	MIPFocus 3
# 	GomoryPasses 15
#
# Solving with random seed #1 ... objective 6.421977e+03
# Solving with random seed #2 ... objective 6.424727e+03
# Solving with random seed #3 ... objective 6.424377e+03
#
# Improvement found:
#   baseline: mean objective 6.424540e+03
#   improved: mean objective 6.423693e+03
# Total elapsed tuning time 7490s (2110s remaining)
#
# -------------------------------------------------------------------------------
#
# Testing candidate parameter set 7...
#
# 	SolutionLimit 10
# 	Heuristics 0.5
# 	MIPFocus 3
# 	MIRCuts 0
#
# Solving with random seed #1 ... objective 6.421883e+03
# Solving with random seed #2 ... objective 6.421953e+03
# Solving with random seed #3 ...
#
# Tune time limit reached.
#
# -------------------------------------------------------------------------------
#
# Tested 6 parameter sets in 9600.08s
#
# Baseline parameter set: mean objective 6.424540e+03
#
# Improved parameter set 1 (mean objective 6.423693e+03):
#
# 	SolutionLimit 10
# 	Heuristics 0.5
# 	MIPFocus 3
# 	GomoryPasses 15
#
# Gurobi Optimizer version 9.0.2 build v9.0.2rc0 (mac64)
# Optimize a model with 23305 rows, 205178 columns and 610658 nonzeros
# Model fingerprint: 0xa913f8ef
# Variable types: 0 continuous, 205178 integer (177854 binary)
# Coefficient statistics:
#   Matrix range     [2e-02, 1e+06]
#   Objective range  [2e+00, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Presolve removed 8842 rows and 8881 columns (presolve time = 5s) ...
# Presolve removed 9994 rows and 10033 columns
# Presolve time: 8.43s
# Presolved: 13311 rows, 195145 columns, 576912 nonzeros
# Variable types: 0 continuous, 195145 integer (174022 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
# Presolve removed 960 rows and 960 columns
# Presolved: 12351 rows, 194185 columns, 574992 nonzeros
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    7.3289446e+03   4.967810e+03   7.525058e+09     10s
#     8895    8.6491689e+03   1.404300e+03   1.588829e+10     10s
# Concurrent spin time: 0.18s
#
# Solved with dual simplex
#
# Root relaxation: objective 6.237517e+03, 639 iterations, 1.41 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 6237.51667    0  212          - 6237.51667      -     -   11s
#      0     0 6268.49186    0  273          - 6268.49186      -     -   31s
#      0     0 6277.08308    0  279          - 6277.08308      -     -   43s
#      0     0 6330.00162    0  305          - 6330.00162      -     -   54s
#      0     0 6335.84128    0  280          - 6335.84128      -     -   65s
#      0     0 6336.28943    0  268          - 6336.28943      -     -   65s
#      0     0 6336.29035    0  277          - 6336.29035      -     -   65s
#      0     0 6364.19069    0  225          - 6364.19069      -     -   76s
#      0     0 6369.10341    0  243          - 6369.10341      -     -   87s
#      0     0 6369.69505    0  255          - 6369.69505      -     -   88s
#      0     0 6413.95216    0  233 6426.05333 6413.95216  0.19%     -  322s
#      0     0 6413.95216    0  224 6426.05333 6413.95216  0.19%     -  322s
#      0     0 6413.95216    0  250 6426.05333 6413.95216  0.19%     -  322s
#      0     0 6413.95216    0  346 6426.05333 6413.95216  0.19%     -  322s
#      0     0 6413.95216    0  285 6426.05333 6413.95216  0.19%     -  322s
#      0     0 6414.23271    0  269 6426.05333 6414.23271  0.18%     -  322s
#      0     0 6414.27154    0  270 6426.05333 6414.27154  0.18%     -  322s
#      0     0 6415.33522    0  321 6426.05333 6415.33522  0.17%     -  324s
# H    0     0                    6424.3766667 6415.33522  0.14%     -  325s
#      0     0 6415.35017    0  288 6424.37667 6415.35017  0.14%     -  325s
#      0     0 6416.59912    0  257 6424.37667 6416.59912  0.12%     -  328s
#      0     0 6416.59912    0  211 6424.37667 6416.59912  0.12%     -  330s
#      0     0 6416.59912    0  271 6424.37667 6416.59912  0.12%     -  332s
#      0     0 6416.59912    0  248 6424.37667 6416.59912  0.12%     -  332s
#      0     0 6416.59912    0  231 6424.37667 6416.59912  0.12%     -  332s
#      0     0 6416.59912    0  227 6424.37667 6416.59912  0.12%     -  332s
#      0     0 6416.59912    0  229 6424.37667 6416.59912  0.12%     -  332s
#      0     0 6416.59912    0  242 6424.37667 6416.59912  0.12%     -  333s
#      0     0 6416.59912    0  301 6424.37667 6416.59912  0.12%     -  333s
#      0     0 6416.59912    0  266 6424.37667 6416.59912  0.12%     -  333s
#      0     0 6416.59912    0  252 6424.37667 6416.59912  0.12%     -  333s
#      0     0 6416.59912    0  262 6424.37667 6416.59912  0.12%     -  333s
#      0     0 6416.61784    0  259 6424.37667 6416.61784  0.12%     -  333s
#      0     0 6416.61786    0  247 6424.37667 6416.61786  0.12%     -  333s
#      0     0 6417.42541    0  236 6424.37667 6417.42541  0.11%     -  334s
#      0     0 6417.49758    0  218 6424.37667 6417.49758  0.11%     -  335s
#      0     0 6418.08762    0  195 6424.37667 6418.08762  0.10%     -  337s
#      0     0 6418.09607    0  234 6424.37667 6418.09607  0.10%     -  338s
#      0     0 6418.68456    0  267 6424.37667 6418.68456  0.09%     -  340s
#      0     0 6418.68456    0  267 6424.37667 6418.68456  0.09%     -  343s
#
# Explored 1 nodes (50688 simplex iterations) in 345.49 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 7: 6424.38 6426.05 6426.22 ... 6432.23
#
# Solution limit reached
# Best objective 6.424376666667e+03, best bound 6.418684560030e+03, gap 0.0886%
# "\nif model.tuneResultCount > 0:\n\n    # Load the best tuned parameters into the model\n    model.getTuneResult(0)\n\n    # Write tuned parameters to a file\n    model.write('tune.prm')\n\n    # Solve the model using the tuned parameters\n    model.optimize()\n    \n"

# %%
def turn_to_df(Var, col_name = None):  # Here you could input the variable
    solution = model.getAttr('x_', Var)
    num_col = len(solution.keys()[0])
    collect = []
    for row in range(0, len(solution)):
        new_row = []
        for col in range(0, num_col):
            new_row.append(solution.keys()[row][col])
        new_row.append(solution[solution.keys()[row]])
    
        collect.append(new_row)
    return pd.DataFrame(collect, columns = col_name)

# %%
Hub_Indirect = turn_to_df(x_, ["Ori_Hub", "Transit_Hub","Dest_Hub", "Taken"])
Hub_Indirect[Hub_Indirect.Taken > 0 ]
# Out:
#                       Ori_Hub         Transit_Hub  \
# 5491                  Enns-AT          Plzen 1-CZ
# 18886              Brüssel-BE          Kolding-DK
# 19565              Brüssel-BE           Poznań-PL
# 20008              Brüssel-BE  Araba (Vitoria)-ES
# 51532   PZ 93 (Regensburg)-DE           Zagreb-HR
# 63180   PZ 93 (Regensburg)-DE           Zagreb-HR
# 84312            Barcelona-ES           Zagreb-HR
# 88107            Barcelona-ES  PZ 21 (Hamburg)-DE
# 89214            Barcelona-ES           Zagreb-HR
# 92256            Barcelona-ES     Budapest OLK-HU
# 92689            Barcelona-ES  PZ 21 (Hamburg)-DE
# 95374    Vantaa (Helsinki)-FL     Budapest OLK-HU
# 97700        Lieto (Turku)-FL          Kolding-DK
# 99978        Lieto (Turku)-FL  Araba (Vitoria)-ES
# 100696   Vantaa (Helsinki)-FL       Hagenbrunn-AT
# 101093              Slough-GB          Brüssel-BE
# 102622              Slough-GB           Zagreb-HR
# 103928              Slough-GB          Brüssel-BE
# 105914              Slough-GB          Kolding-DK
# 106108              Slough-GB          Brüssel-BE
# 106715              Slough-GB           Poznań-PL
# 107994              Slough-GB  Araba (Vitoria)-ES
# 108138              Slough-GB     Budapest OLK-HU
# 114329              Kaunas-LT           Poznań-PL
# 115815     Eindhoven-Noord-NL           Zagreb-HR
# 117121     Eindhoven-Noord-NL          Brüssel-BE
# 119107     Eindhoven-Noord-NL          Kolding-DK
# 120444     Eindhoven-Noord-NL           Poznań-PL
# 121319     Eindhoven-Noord-NL  Araba (Vitoria)-ES
# 126761              Zabrze-PL     Budapest OLK-HU
# 131201             Wrocław-PL         Krupka 1-CZ
# 134857             Wrocław-PL     PZ 77 (Lahr)-DE
# 136691              Poznań-PL  Eindhoven-Noord-NL
# 138202              Poznań-PL          Brüssel-BE
# 140533             Wrocław-PL     PZ 77 (Lahr)-DE
# 144740              Lisboa-PT  Araba (Vitoria)-ES
# 145664              Lisboa-PT  Araba (Vitoria)-ES
# 146167              Lisboa-PT  Eindhoven-Noord-NL
# 146265              Lisboa-PT  Araba (Vitoria)-ES
# 146401              Lisboa-PT  Araba (Vitoria)-ES
# 146526              Lisboa-PT           Zagreb-HR
# 146725              Lisboa-PT           Zagreb-HR
# 146812              Lisboa-PT  Araba (Vitoria)-ES
# 146979              Lisboa-PT  Araba (Vitoria)-ES
# 147418              Lisboa-PT  Eindhoven-Noord-NL
# 147595              Lisboa-PT           Zagreb-HR
# 147829              Lisboa-PT  Eindhoven-Noord-NL
# 148618               Malmö-SE         Krupka 1-CZ
# 151693               Malmö-SE     Budapest OLK-HU
# 162072               Malmö-SE  Eindhoven-Noord-NL
# 165524               Malmö-SE  Araba (Vitoria)-ES
#
#                            Dest_Hub  Taken
# 5491          PZ 93 (Regensburg)-DE    1.0
# 18886              Lieto (Turku)-FL    1.0
# 19565                     Kaunas-LT    1.0
# 20008                     Lisboa-PT    1.0
# 51532                      Sofia-BG    1.0
# 63180                      Spata-GR    1.0
# 84312                      Sofia-BG    1.0
# 88107                    Kolding-DK    1.0
# 89214                      Spata-GR    1.0
# 92256                     Oradea-RO    1.0
# 92689                      Malmö-SE    1.0
# 95374                      Sofia-BG    1.0
# 97700            PZ 21 (Hamburg)-DE    1.0
# 99978                     Lisboa-PT    1.0
# 100696                 Ljubljana-SI    1.0
# 101093                      Wals-AT    1.0
# 102622                     Sofia-BG    1.0
# 103928           PZ 47 (Krefeld)-DE    1.0
# 105914             Lieto (Turku)-FL    1.0
# 106108                     Spata-GR    1.0
# 106715                    Kaunas-LT    1.0
# 107994                    Lisboa-PT    1.0
# 108138                    Oradea-RO    1.0
# 114329                     Malmö-SE    1.0
# 115815                     Sofia-BG    1.0
# 117121           PZ 47 (Krefeld)-DE    1.0
# 119107             Lieto (Turku)-FL    1.0
# 120444                    Kaunas-LT    1.0
# 121319                    Lisboa-PT    1.0
# 126761                     Sofia-BG    1.0
# 131201  PZ 04 (Radefeld/Leipzig)-DE    1.0
# 134857                 Barcelona-ES    1.0
# 136691                    Slough-GB    1.0
# 138202                    Dublin-IE    1.0
# 140533                    Lisboa-PT    1.0
# 144740                   Brüssel-BE    1.0
# 145664              PZ 77 (Lahr)-DE    1.0
# 146167                   Kolding-DK    1.0
# 146265             Lieto (Turku)-FL    1.0
# 146401                    Slough-GB    1.0
# 146526                     Spata-GR    1.0
# 146725              Budapest OLK-HU    1.0
# 146812                    Dublin-IE    1.0
# 146979               Bettembourg-LU    1.0
# 147418                    Poznań-PL    1.0
# 147595                    Oradea-RO    1.0
# 147829                     Malmö-SE    1.0
# 148618                 Allhaming-AT    1.0
# 151693                     Sofia-BG    1.0
# 162072                    Dublin-IE    1.0
# 165524                    Lisboa-PT    1.0

# %%
Country_Direct = turn_to_df(X, ["Ori_Country", "Dest_Country", "Taken"])
Country_Indirect = turn_to_df(X_, ["Ori_Country", "Transit_Country","Dest_Country", "Taken"])

Hub_Direct = turn_to_df(x, ["Ori_Hub", "Dest_Hub", "Taken"])
Hub_Indirect = turn_to_df(x_, ["Ori_Hub", "Transit_Hub","Dest_Hub", "Taken"])

Route_Cap = turn_to_df(V, ["Ori_Hub", "Dest_Hub", "Taken"])
Freq = turn_to_df(F, ["Ori_Hub", "Dest_Hub","Truck Type", "Taken"])
#Start = turn_to_df(S, ["Ori_Hub", "Dest_Hub", "Time"])
#Night = turn_to_df(N, ["Ori_Hub", "Dest_Hub", "Nights"])
Co_load = turn_to_df(CL, ["Ori_Hub", "Dest_Hub", "Amount"])
CL_sol =  model.getAttr('x_', CL)

# %%
for key in attri_dict.keys():
    df_output = turn_to_df(attri_dict[key])
    df_output.to_csv(f"Output/{key}_output.csv")

# %%
ind = Country_Indirect.Taken.sum()
d = Country_Direct.Taken.sum()

print(f"{ind} indriect routes and {d} direct route, total: {len(Z)}" )
# Out:
# 51.0 indriect routes and 161.0 direct route, total: 212

# %%
freq_result = model.getAttr('x', F)
demand_filled = model.getAttr('x', V)
print("Cost by Route Cap.:", round(sum(freq_result[p,q,t] * C[t] * cost[p,q,t] for p, q, t in pqt) / (sum(demand_filled[p,q] for p, q in pq_all)/4), 2))
print("Cost by Capacity.:", sum(freq_result[p,q,t] * C[t] * cost[p,q,t] for p, q,t in pqt) / (sum(freq_result[p,q,t] * C[t] for p, q,t in pqt)))
print("Cost by Demands.:", sum(freq_result[p,q,t] * C[t] * cost[p,q,t] for p, q,t in pqt) / (sum(Z[m, k] for m, k in mk)/4))
print("Cost by Demands + Co-load:", sum(freq_result[p,q,t] * C[t] * cost[p,q,t] for p, q, t in pqt) / (sum(Z[m, k] for m, k in mk)/4 + sum(CL_sol[p, q] for p, q in pq_all)))
# Out:
# Cost by Route Cap.: 0.08
# Cost by Capacity.: 0.07536819135130474
# Cost by Demands.: 0.1333595231002436
# Cost by Demands + Co-load: 0.12191207579200197

# %%
sum(F_[p,q,t] * C[t] * cost[p,q,t] for p, q, t in pqt) / sum(F_[p,q,t] * C[t] for p,q,t in pqt)
# Out:
# 0.07634660619388778

# %%
Freq_result = Freq[Freq.Taken > 0]
Freq_result.groupby("Truck Type").count()
# Out:
#                Ori_Hub  Dest_Hub  Taken
# Truck Type
# 2 Swap Bodies       58        58     58
# Co-loading          27        27     27
# Van                122       122    122

# %%
Freq_result = Freq[Freq.Taken > 0]
Freq_result["agg"] = Freq_result["Ori_Hub"] + Freq_result["Dest_Hub"]
print(Freq_result.groupby("Truck Type").count()) # Truck type count per routes

Freq_result["Capacity"] = Freq_result.apply(lambda row: C[row["Truck Type"]] * row["Taken"] * 4, axis = 1)
capacity_from_freq = Freq_result.groupby(["agg"]).sum()


# Indirect Route Overview

Hub_Indirect_T = Hub_Indirect[Hub_Indirect.Taken > 0]
Hub_Indirect_T["First"] = Hub_Indirect_T["Ori_Hub"] + Hub_Indirect_T["Transit_Hub"]
Hub_Indirect_T["Second"] = Hub_Indirect_T["Transit_Hub"] + Hub_Indirect_T["Dest_Hub"]

Hub_merge = Hub_Indirect_T.merge(capacity_from_freq.loc[:, "Capacity"], left_on = "First", right_on = "agg", how = "right")
Hub_merge = Hub_merge.merge(capacity_from_freq.loc[:, "Capacity"], left_on = "Second", right_on = "agg", how = "right")

pd.options.display.max_rows = 100
Hub_merge.dropna()
# Out:
#                Ori_Hub  Dest_Hub  Taken  agg
# Truck Type
# 2 Swap Bodies       58        58     58   58
# Co-loading          27        27     27   27
# Van                122       122    122  122
# /Users/yi/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/yi/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /Users/yi/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':
# /Users/yi/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
#                   Ori_Hub         Transit_Hub                     Dest_Hub  \
# 0                 Enns-AT          Plzen 1-CZ        PZ 93 (Regensburg)-DE
# 1              Brüssel-BE          Kolding-DK             Lieto (Turku)-FL
# 2               Slough-GB          Kolding-DK             Lieto (Turku)-FL
# 3      Eindhoven-Noord-NL          Kolding-DK             Lieto (Turku)-FL
# 4              Brüssel-BE           Poznań-PL                    Kaunas-LT
# 5               Slough-GB           Poznań-PL                    Kaunas-LT
# 6      Eindhoven-Noord-NL           Poznań-PL                    Kaunas-LT
# 7              Brüssel-BE  Araba (Vitoria)-ES                    Lisboa-PT
# 8        Lieto (Turku)-FL  Araba (Vitoria)-ES                    Lisboa-PT
# 9               Slough-GB  Araba (Vitoria)-ES                    Lisboa-PT
# 10     Eindhoven-Noord-NL  Araba (Vitoria)-ES                    Lisboa-PT
# 11               Malmö-SE  Araba (Vitoria)-ES                    Lisboa-PT
# 12  PZ 93 (Regensburg)-DE           Zagreb-HR                     Sofia-BG
# 13           Barcelona-ES           Zagreb-HR                     Sofia-BG
# 14              Slough-GB           Zagreb-HR                     Sofia-BG
# 15     Eindhoven-Noord-NL           Zagreb-HR                     Sofia-BG
# 16  PZ 93 (Regensburg)-DE           Zagreb-HR                     Spata-GR
# 17           Barcelona-ES           Zagreb-HR                     Spata-GR
# 18              Lisboa-PT           Zagreb-HR                     Spata-GR
# 19           Barcelona-ES  PZ 21 (Hamburg)-DE                   Kolding-DK
# 20           Barcelona-ES  PZ 21 (Hamburg)-DE                     Malmö-SE
# 21           Barcelona-ES     Budapest OLK-HU                    Oradea-RO
# 22              Slough-GB     Budapest OLK-HU                    Oradea-RO
# 23   Vantaa (Helsinki)-FL     Budapest OLK-HU                     Sofia-BG
# 24              Zabrze-PL     Budapest OLK-HU                     Sofia-BG
# 25               Malmö-SE     Budapest OLK-HU                     Sofia-BG
# 26       Lieto (Turku)-FL          Kolding-DK           PZ 21 (Hamburg)-DE
# 27   Vantaa (Helsinki)-FL       Hagenbrunn-AT                 Ljubljana-SI
# 28              Slough-GB          Brüssel-BE                      Wals-AT
# 29              Slough-GB          Brüssel-BE           PZ 47 (Krefeld)-DE
# 30     Eindhoven-Noord-NL          Brüssel-BE           PZ 47 (Krefeld)-DE
# 31              Slough-GB          Brüssel-BE                     Spata-GR
# 32              Kaunas-LT           Poznań-PL                     Malmö-SE
# 33             Wrocław-PL         Krupka 1-CZ  PZ 04 (Radefeld/Leipzig)-DE
# 34             Wrocław-PL     PZ 77 (Lahr)-DE                 Barcelona-ES
# 35             Wrocław-PL     PZ 77 (Lahr)-DE                    Lisboa-PT
# 36              Poznań-PL  Eindhoven-Noord-NL                    Slough-GB
# 37              Poznań-PL          Brüssel-BE                    Dublin-IE
# 38              Lisboa-PT  Araba (Vitoria)-ES                   Brüssel-BE
# 39              Lisboa-PT  Araba (Vitoria)-ES              PZ 77 (Lahr)-DE
# 40              Lisboa-PT  Araba (Vitoria)-ES             Lieto (Turku)-FL
# 41              Lisboa-PT  Araba (Vitoria)-ES                    Slough-GB
# 42              Lisboa-PT  Araba (Vitoria)-ES                    Dublin-IE
# 43              Lisboa-PT  Araba (Vitoria)-ES               Bettembourg-LU
# 44              Lisboa-PT  Eindhoven-Noord-NL                   Kolding-DK
# 45              Lisboa-PT  Eindhoven-Noord-NL                    Poznań-PL
# 46              Lisboa-PT  Eindhoven-Noord-NL                     Malmö-SE
# 47              Lisboa-PT           Zagreb-HR              Budapest OLK-HU
# 48              Lisboa-PT           Zagreb-HR                    Oradea-RO
# 49               Malmö-SE         Krupka 1-CZ                 Allhaming-AT
# 50               Malmö-SE  Eindhoven-Noord-NL                    Dublin-IE
#
#     Taken                                 First  \
# 0     1.0                     Enns-ATPlzen 1-CZ
# 1     1.0                  Brüssel-BEKolding-DK
# 2     1.0                   Slough-GBKolding-DK
# 3     1.0          Eindhoven-Noord-NLKolding-DK
# 4     1.0                   Brüssel-BEPoznań-PL
# 5     1.0                    Slough-GBPoznań-PL
# 6     1.0           Eindhoven-Noord-NLPoznań-PL
# 7     1.0          Brüssel-BEAraba (Vitoria)-ES
# 8     1.0    Lieto (Turku)-FLAraba (Vitoria)-ES
# 9     1.0           Slough-GBAraba (Vitoria)-ES
# 10    1.0  Eindhoven-Noord-NLAraba (Vitoria)-ES
# 11    1.0            Malmö-SEAraba (Vitoria)-ES
# 12    1.0        PZ 93 (Regensburg)-DEZagreb-HR
# 13    1.0                 Barcelona-ESZagreb-HR
# 14    1.0                    Slough-GBZagreb-HR
# 15    1.0           Eindhoven-Noord-NLZagreb-HR
# 16    1.0        PZ 93 (Regensburg)-DEZagreb-HR
# 17    1.0                 Barcelona-ESZagreb-HR
# 18    1.0                    Lisboa-PTZagreb-HR
# 19    1.0        Barcelona-ESPZ 21 (Hamburg)-DE
# 20    1.0        Barcelona-ESPZ 21 (Hamburg)-DE
# 21    1.0           Barcelona-ESBudapest OLK-HU
# 22    1.0              Slough-GBBudapest OLK-HU
# 23    1.0   Vantaa (Helsinki)-FLBudapest OLK-HU
# 24    1.0              Zabrze-PLBudapest OLK-HU
# 25    1.0               Malmö-SEBudapest OLK-HU
# 26    1.0            Lieto (Turku)-FLKolding-DK
# 27    1.0     Vantaa (Helsinki)-FLHagenbrunn-AT
# 28    1.0                   Slough-GBBrüssel-BE
# 29    1.0                   Slough-GBBrüssel-BE
# 30    1.0          Eindhoven-Noord-NLBrüssel-BE
# 31    1.0                   Slough-GBBrüssel-BE
# 32    1.0                    Kaunas-LTPoznań-PL
# 33    1.0                 Wrocław-PLKrupka 1-CZ
# 34    1.0             Wrocław-PLPZ 77 (Lahr)-DE
# 35    1.0             Wrocław-PLPZ 77 (Lahr)-DE
# 36    1.0           Poznań-PLEindhoven-Noord-NL
# 37    1.0                   Poznań-PLBrüssel-BE
# 38    1.0           Lisboa-PTAraba (Vitoria)-ES
# 39    1.0           Lisboa-PTAraba (Vitoria)-ES
# 40    1.0           Lisboa-PTAraba (Vitoria)-ES
# 41    1.0           Lisboa-PTAraba (Vitoria)-ES
# 42    1.0           Lisboa-PTAraba (Vitoria)-ES
# 43    1.0           Lisboa-PTAraba (Vitoria)-ES
# 44    1.0           Lisboa-PTEindhoven-Noord-NL
# 45    1.0           Lisboa-PTEindhoven-Noord-NL
# 46    1.0           Lisboa-PTEindhoven-Noord-NL
# 47    1.0                    Lisboa-PTZagreb-HR
# 48    1.0                    Lisboa-PTZagreb-HR
# 49    1.0                   Malmö-SEKrupka 1-CZ
# 50    1.0            Malmö-SEEindhoven-Noord-NL
#
#                                     Second  Capacity_x  Capacity_y
# 0          Plzen 1-CZPZ 93 (Regensburg)-DE    938672.0   1139816.0
# 1               Kolding-DKLieto (Turku)-FL      9000.0      9000.0
# 2               Kolding-DKLieto (Turku)-FL      9000.0      9000.0
# 3               Kolding-DKLieto (Turku)-FL      9000.0      9000.0
# 4                       Poznań-PLKaunas-LT      9000.0      9000.0
# 5                       Poznań-PLKaunas-LT      9000.0      9000.0
# 6                       Poznań-PLKaunas-LT      9000.0      9000.0
# 7              Araba (Vitoria)-ESLisboa-PT      9000.0     33524.0
# 8              Araba (Vitoria)-ESLisboa-PT      9000.0     33524.0
# 9              Araba (Vitoria)-ESLisboa-PT     67048.0     33524.0
# 10             Araba (Vitoria)-ESLisboa-PT     67048.0     33524.0
# 11             Araba (Vitoria)-ESLisboa-PT      9000.0     33524.0
# 12                       Zagreb-HRSofia-BG     33524.0     33524.0
# 13                       Zagreb-HRSofia-BG      9000.0     33524.0
# 14                       Zagreb-HRSofia-BG      9000.0     33524.0
# 15                       Zagreb-HRSofia-BG      9000.0     33524.0
# 16                       Zagreb-HRSpata-GR     33524.0      9000.0
# 17                       Zagreb-HRSpata-GR      9000.0      9000.0
# 18                       Zagreb-HRSpata-GR      9000.0      9000.0
# 19            PZ 21 (Hamburg)-DEKolding-DK      9000.0      1788.0
# 20              PZ 21 (Hamburg)-DEMalmö-SE      9000.0     35884.0
# 21                Budapest OLK-HUOradea-RO      9000.0      1460.0
# 22                Budapest OLK-HUOradea-RO      9000.0      1460.0
# 23                 Budapest OLK-HUSofia-BG      9000.0      9000.0
# 24                 Budapest OLK-HUSofia-BG     33524.0      9000.0
# 25                 Budapest OLK-HUSofia-BG      9000.0      9000.0
# 26            Kolding-DKPZ 21 (Hamburg)-DE     33524.0     33524.0
# 27               Hagenbrunn-ATLjubljana-SI      9000.0       196.0
# 28                       Brüssel-BEWals-AT    502860.0     33524.0
# 29            Brüssel-BEPZ 47 (Krefeld)-DE    502860.0   1998588.0
# 30            Brüssel-BEPZ 47 (Krefeld)-DE   1435008.0   1998588.0
# 31                      Brüssel-BESpata-GR    502860.0      9000.0
# 32                       Poznań-PLMalmö-SE        16.0      9000.0
# 33  Krupka 1-CZPZ 04 (Radefeld/Leipzig)-DE    780052.0    785504.0
# 34             PZ 77 (Lahr)-DEBarcelona-ES     67048.0     42524.0
# 35                PZ 77 (Lahr)-DELisboa-PT     67048.0     33524.0
# 36             Eindhoven-Noord-NLSlough-GB    100572.0    109572.0
# 37                     Brüssel-BEDublin-IE     33524.0     33524.0
# 38            Araba (Vitoria)-ESBrüssel-BE     33524.0      9000.0
# 39       Araba (Vitoria)-ESPZ 77 (Lahr)-DE     33524.0     33524.0
# 40      Araba (Vitoria)-ESLieto (Turku)-FL     33524.0      9000.0
# 41             Araba (Vitoria)-ESSlough-GB     33524.0     33524.0
# 42             Araba (Vitoria)-ESDublin-IE     33524.0      9000.0
# 43        Araba (Vitoria)-ESBettembourg-LU     33524.0      9000.0
# 44            Eindhoven-Noord-NLKolding-DK      9000.0      9000.0
# 45             Eindhoven-Noord-NLPoznań-PL      9000.0      9000.0
# 46              Eindhoven-Noord-NLMalmö-SE      9000.0      9000.0
# 47                Zagreb-HRBudapest OLK-HU      9000.0        96.0
# 48                      Zagreb-HROradea-RO      9000.0      9000.0
# 49                 Krupka 1-CZAllhaming-AT     67048.0     67048.0
# 50             Eindhoven-Noord-NLDublin-IE      9000.0     33524.0

# %%
Z["NL", "GB"]
# Out:
# 35554

# %% [markdown]
# ## Checking if some routes exist

# %%
("FR","ES") in mk_all
# Out:
# True

# %%
'''
solution = model.getAttr('x_', X_)
print(solution[("HU", "AT","BE")])

solution_dir = model.getAttr('x_', X)
solution_dir[("AT","BE")]
'''
# Out:
# '\nsolution = model.getAttr(\'x_\', X_)\nprint(solution[("HU", "AT","BE")])\n\nsolution_dir = model.getAttr(\'x_\', X)\nsolution_dir[("AT","BE")]\n'

# %%
Freq["Ori_C"] = Freq.apply(lambda row: row.Ori_Hub.rsplit("-")[-1], axis = 1)
Freq["Dest_C"] = Freq.apply(lambda row: row.Dest_Hub.rsplit("-")[-1], axis = 1)
Freq[Freq.Taken > 0]
# Out:
#                   Ori_Hub               Dest_Hub     Truck Type  Taken Ori_C  \
# 1027        Hagenbrunn-AT           Ljubljana-SI     Co-loading   49.0    AT
# 2192   Araba (Vitoria)-ES              Lisboa-PT  2 Swap Bodies    1.0    ES
# 2354      Budapest OLK-HU               Sofia-BG            Van    1.0    HU
# 2531      Budapest OLK-HU              Oradea-RO     Co-loading  365.0    HU
# 2639            Kaunas-LT              Poznań-PL     Co-loading    4.0    LT
# ...                   ...                    ...            ...    ...   ...
# 18086        Ljubljana-SI  PZ 93 (Regensburg)-DE            Van    1.0    SI
# 18122        Ljubljana-SI     Eindhoven-Noord-NL            Van    1.0    SI
# 18138        Ljubljana-SI              Zabrze-PL            Van    1.0    SI
# 18156  Zilina- Strecno-SK             Ostrava-CZ  2 Swap Bodies    6.0    SK
# 18158  Zilina- Strecno-SK             Ostrava-CZ            Van    1.0    SK
#
#       Dest_C
# 1027      SI
# 2192      PT
# 2354      BG
# 2531      RO
# 2639      PL
# ...      ...
# 18086     DE
# 18122     NL
# 18138     PL
# 18156     CZ
# 18158     CZ
#
# [207 rows x 6 columns]

# %%
Freq.loc[(Freq["Ori_C"] == "BE") & (Freq["Dest_C"] == "DE"), :]
# Out:
#          Ori_Hub                     Dest_Hub     Truck Type  Taken Ori_C  \
# 7496  Brüssel-BE            PZ 67 (Speyer)-DE  2 Swap Bodies   -0.0    BE
# 7497  Brüssel-BE            PZ 67 (Speyer)-DE        Trailer   -0.0    BE
# 7498  Brüssel-BE            PZ 67 (Speyer)-DE            Van   -0.0    BE
# 7499  Brüssel-BE            PZ 67 (Speyer)-DE     Co-loading    0.0    BE
# 7500  Brüssel-BE              PZ 50 (Köln)-DE  2 Swap Bodies   -0.0    BE
# 7501  Brüssel-BE              PZ 50 (Köln)-DE        Trailer   -0.0    BE
# 7502  Brüssel-BE              PZ 50 (Köln)-DE            Van   -0.0    BE
# 7503  Brüssel-BE              PZ 50 (Köln)-DE     Co-loading   -0.0    BE
# 7504  Brüssel-BE  PZ 04 (Radefeld/Leipzig)-DE  2 Swap Bodies   -0.0    BE
# 7505  Brüssel-BE  PZ 04 (Radefeld/Leipzig)-DE        Trailer   -0.0    BE
# 7506  Brüssel-BE  PZ 04 (Radefeld/Leipzig)-DE            Van   -0.0    BE
# 7507  Brüssel-BE  PZ 04 (Radefeld/Leipzig)-DE     Co-loading   -0.0    BE
# 7508  Brüssel-BE   PZ 90 (Feucht/Nürnberg)-DE  2 Swap Bodies   -0.0    BE
# 7509  Brüssel-BE   PZ 90 (Feucht/Nürnberg)-DE        Trailer   -0.0    BE
# 7510  Brüssel-BE   PZ 90 (Feucht/Nürnberg)-DE            Van   -0.0    BE
# 7511  Brüssel-BE   PZ 90 (Feucht/Nürnberg)-DE     Co-loading   -0.0    BE
# 7512  Brüssel-BE              PZ 77 (Lahr)-DE  2 Swap Bodies   -0.0    BE
# 7513  Brüssel-BE              PZ 77 (Lahr)-DE        Trailer   -0.0    BE
# 7514  Brüssel-BE              PZ 77 (Lahr)-DE            Van   -0.0    BE
# 7515  Brüssel-BE              PZ 77 (Lahr)-DE     Co-loading   -0.0    BE
# 7516  Brüssel-BE        PZ 93 (Regensburg)-DE  2 Swap Bodies   -0.0    BE
# 7517  Brüssel-BE        PZ 93 (Regensburg)-DE        Trailer   -0.0    BE
# 7518  Brüssel-BE        PZ 93 (Regensburg)-DE            Van   -0.0    BE
# 7519  Brüssel-BE        PZ 93 (Regensburg)-DE     Co-loading   -0.0    BE
# 7520  Brüssel-BE           PZ 21 (Hamburg)-DE  2 Swap Bodies   -0.0    BE
# 7521  Brüssel-BE           PZ 21 (Hamburg)-DE        Trailer   -0.0    BE
# 7522  Brüssel-BE           PZ 21 (Hamburg)-DE            Van   -0.0    BE
# 7523  Brüssel-BE           PZ 21 (Hamburg)-DE     Co-loading   -0.0    BE
# 7524  Brüssel-BE           PZ 46 (Dorsten)-DE  2 Swap Bodies    0.0    BE
# 7525  Brüssel-BE           PZ 46 (Dorsten)-DE        Trailer   -0.0    BE
# 7526  Brüssel-BE           PZ 46 (Dorsten)-DE            Van   -0.0    BE
# 7527  Brüssel-BE           PZ 46 (Dorsten)-DE     Co-loading   -0.0    BE
# 7528  Brüssel-BE             PZ 58 (Hagen)-DE  2 Swap Bodies   -0.0    BE
# 7529  Brüssel-BE             PZ 58 (Hagen)-DE        Trailer   -0.0    BE
# 7530  Brüssel-BE             PZ 58 (Hagen)-DE            Van   -0.0    BE
# 7531  Brüssel-BE             PZ 58 (Hagen)-DE     Co-loading   -0.0    BE
# 7532  Brüssel-BE           PZ 08 (Neumark)-DE  2 Swap Bodies   -0.0    BE
# 7533  Brüssel-BE           PZ 08 (Neumark)-DE        Trailer   -0.0    BE
# 7534  Brüssel-BE           PZ 08 (Neumark)-DE            Van   -0.0    BE
# 7535  Brüssel-BE           PZ 08 (Neumark)-DE     Co-loading   -0.0    BE
# 7536  Brüssel-BE           PZ 47 (Krefeld)-DE  2 Swap Bodies   59.0    BE
# 7537  Brüssel-BE           PZ 47 (Krefeld)-DE        Trailer   -0.0    BE
# 7538  Brüssel-BE           PZ 47 (Krefeld)-DE            Van    2.0    BE
# 7539  Brüssel-BE           PZ 47 (Krefeld)-DE     Co-loading  668.0    BE
# 7540  Brüssel-BE        PZ 15 (Rüdersdorf)-DE  2 Swap Bodies   -0.0    BE
# 7541  Brüssel-BE        PZ 15 (Rüdersdorf)-DE        Trailer   -0.0    BE
# 7542  Brüssel-BE        PZ 15 (Rüdersdorf)-DE            Van   -0.0    BE
# 7543  Brüssel-BE        PZ 15 (Rüdersdorf)-DE     Co-loading   -0.0    BE
# 7544  Brüssel-BE        PZ 24 (Neumünster)-DE  2 Swap Bodies   -0.0    BE
# 7545  Brüssel-BE        PZ 24 (Neumünster)-DE        Trailer   -0.0    BE
# 7546  Brüssel-BE        PZ 24 (Neumünster)-DE            Van   -0.0    BE
# 7547  Brüssel-BE        PZ 24 (Neumünster)-DE     Co-loading   -0.0    BE
# 7548  Brüssel-BE   PZ 44 (Bochum) [im Bau]-DE  2 Swap Bodies   -0.0    BE
# 7549  Brüssel-BE   PZ 44 (Bochum) [im Bau]-DE        Trailer   -0.0    BE
# 7550  Brüssel-BE   PZ 44 (Bochum) [im Bau]-DE            Van   -0.0    BE
# 7551  Brüssel-BE   PZ 44 (Bochum) [im Bau]-DE     Co-loading   -0.0    BE
#
#      Dest_C
# 7496     DE
# 7497     DE
# 7498     DE
# 7499     DE
# 7500     DE
# 7501     DE
# 7502     DE
# 7503     DE
# 7504     DE
# 7505     DE
# 7506     DE
# 7507     DE
# 7508     DE
# 7509     DE
# 7510     DE
# 7511     DE
# 7512     DE
# 7513     DE
# 7514     DE
# 7515     DE
# 7516     DE
# 7517     DE
# 7518     DE
# 7519     DE
# 7520     DE
# 7521     DE
# 7522     DE
# 7523     DE
# 7524     DE
# 7525     DE
# 7526     DE
# 7527     DE
# 7528     DE
# 7529     DE
# 7530     DE
# 7531     DE
# 7532     DE
# 7533     DE
# 7534     DE
# 7535     DE
# 7536     DE
# 7537     DE
# 7538     DE
# 7539     DE
# 7540     DE
# 7541     DE
# 7542     DE
# 7543     DE
# 7544     DE
# 7545     DE
# 7546     DE
# 7547     DE
# 7548     DE
# 7549     DE
# 7550     DE
# 7551     DE

# %% [markdown]
# # Check the relationship between Route Capacity and Demands

# %%
Route_Cap["Ori_C"] = Route_Cap.apply(lambda row: row.Ori_Hub.rsplit("-")[-1], axis = 1)
Route_Cap["Dest_C"] = Route_Cap.apply(lambda row: row.Dest_Hub.rsplit("-")[-1], axis = 1)
Route_Cap["Demands"] = Route_Cap.apply(lambda row: Z[row.Ori_C, row.Dest_C] if (row.Ori_C, row.Dest_C) in Z.keys() else 0, axis = 1)

# %%
# Route_Cap.loc[(Route_Cap["Ori_C"] == "DE") & (Route_Cap["Dest_C"] == "FL"), :]
Route_Cap[Route_Cap.Taken > 0]
# Out:
#                  Ori_Hub               Dest_Hub     Taken Ori_C Dest_C  \
# 256        Hagenbrunn-AT           Ljubljana-SI     196.0    AT     SI
# 548   Araba (Vitoria)-ES              Lisboa-PT   15843.0    ES     PT
# 588      Budapest OLK-HU               Sofia-BG    8580.0    HU     BG
# 632      Budapest OLK-HU              Oradea-RO    1457.0    HU     RO
# 659            Kaunas-LT              Poznań-PL      14.0    LT     PL
# ...                  ...                    ...       ...   ...    ...
# 4515        Ljubljana-SI             Brüssel-BE      27.0    SI     BE
# 4521        Ljubljana-SI  PZ 93 (Regensburg)-DE    3203.0    SI     DE
# 4530        Ljubljana-SI     Eindhoven-Noord-NL     220.0    SI     NL
# 4534        Ljubljana-SI              Zabrze-PL      30.0    SI     PL
# 4539  Zilina- Strecno-SK             Ostrava-CZ  201434.0    SK     CZ
#
#       Demands
# 256         0
# 548         0
# 588         0
# 632         0
# 659         0
# ...       ...
# 4515       27
# 4521     3203
# 4530      220
# 4534       30
# 4539   201434
#
# [182 rows x 6 columns]

# %%
Route_Cap.loc[(Route_Cap["Ori_C"] == "BE") & (Route_Cap["Dest_C"] == "NL"), :]
# Out:
#         Ori_Hub            Dest_Hub  Taken Ori_C Dest_C  Demands
# 330  Brüssel-BE  Eindhoven-Noord-NL    0.0    BE     NL        0
# 331  Brüssel-BE       Zaltbommel-NL    0.0    BE     NL        0

# %%
Z["BE", "AT"]
# Out:
# 5943

# %%
("NL", "AT") in mk_all
# Out:
# True
