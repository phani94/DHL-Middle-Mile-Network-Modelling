# %%
from gurobipy import Model, GRB, quicksum, tuplelist
import numpy as np
import pandas as pd

# %%
# The following file works as a reference table to match the names of 2 sheets
hub_list = pd.read_csv('Database/Hub list.csv')
hub_list.Ref_City = hub_list.Ref_City + "-" + hub_list.Country

# drop duplicates
hub_list.drop_duplicates(subset = "Ref_City", keep='first', inplace=True)


hub_ref = {}
for row in hub_list.index:
    hub_ref[hub_list.loc[row, "City"]] = hub_list.loc[row, "Ref_City"]

    
    
def name_transform(city_name):
    if city_name in hub_ref.keys():
        return hub_ref[city_name]
    else:
        return city_name

# %%
# Simple Version
masterfile = pd.read_excel("Database/Simple/Simple Routes.xlsx", sheet_name = 0)

# Complete Version
#masterfile = pd.read_csv("Database/inter_distances.csv")

# %%
# Import forecast for creating the country set
forecast = pd.read_csv("Database/Average_Forecast.csv")
forecast.fillna(0, inplace = True)

# Only satisfied those the current network can reach
# Otherwise the solution would be infeasible

used_c = masterfile["Origin Country"].unique().tolist() +  masterfile["Destination Country"].unique().tolist() # Not every hubs in the hub list is used
used_c = list( dict.fromkeys(used_c) )  # Remove duplicate

all_c = forecast.Origin.unique().tolist() +  forecast.Destination.unique().tolist() # Not every hubs in the hub list is used
all_c = list( dict.fromkeys(all_c) )  # Remove duplicate

for x in used_c:
    try:
        all_c.remove(x)
    except:
        continue
        
for c in all_c:
    forecast["Origin"].replace(c, np.nan, inplace = True)
    forecast["Destination"].replace(c, np.nan, inplace = True)
forecast.dropna(how = "any", inplace = True)


# Set up the threshold for the demands
minimum_demands = 0
maximum_demands = 10000000000
forecast["Target"] = forecast.apply(lambda row: row.Average if row.Average >= minimum_demands else 0, axis = 1)

forecast["Target"] = forecast.apply(lambda row: row.Target if row.Target <= maximum_demands else 0, axis = 1)


forecast = forecast[forecast["Target"] > 0]
country_set = list(zip(forecast["Origin"].to_list(), forecast["Destination"].to_list()))

origin_list = list(forecast["Origin"].unique())
dst_list =  list(forecast["Destination"].unique())

country_with_forecast = forecast.Origin.unique().tolist() +  forecast.Destination.unique().tolist()
country_with_forecast = list( dict.fromkeys(country_with_forecast))  # Remove Dup

# %%
len(forecast)
# Out:
# 212

# %% [markdown]
# # Define the Set
# ## 1. Hubs in each Country (L) & All Hubs (H)

# %%
used_hubs = masterfile.From.unique().tolist() +  masterfile.To.unique().tolist() # Not every hubs in the hub list is used
used_hubs = list( dict.fromkeys(used_hubs) )  # Remove duplicate

hub_list_used = hub_list.set_index("Ref_City")
hub_list_used = hub_list_used.loc[hub_list_used.index.isin(used_hubs), :]
hub_list_used.reset_index(inplace = True)

#hub_list_used["Country"] = hub_list_used.apply(lambda row: row["Ref_City"].split("-")[-1], axis = 1) # To fill NA in country

L = {}
for country in country_with_forecast:  # hub_list_used.Country.unique():
    hub_collect = hub_list_used[hub_list_used.loc[:, "Country"] == country]["Ref_City"].tolist()
    L[country] = hub_collect

    #for row in hub_list_used.index:

    #L[hub_list_used.loc[row, "Country"]].append(hub_list_used.loc[row, "Ref_City"])
H = hub_list_used.Ref_City.unique().tolist() # All hubs

# %% [markdown]
# ## 2. European Countries (E)

# %%
E = country_with_forecast # from the "forecast" file

# %% [markdown]
# ## 3. Truck Types (T)

# %%
truck_cap = pd.read_csv("Database/TruckVSCap.csv")
T = truck_cap["Truck Type"].tolist()
#T.remove("Swap Body") # To simplify the model

# %% [markdown]
# ## Define subset for the later use

# %%
# Define tuplelist for the assign of variables

mjk = tuplelist([(m,j,k) for m, k in country_set for j in country_with_forecast if (m != j) & (j != k)])
mk = tuplelist([(m,k) for m, k in country_set])

mj_k = [(m, j) for m in origin_list for j in country_with_forecast if (m, j) not in mk if m != j]   # m connects to j exlcudes k (transit countries)
mj_k = list( dict.fromkeys(mj_k) )

#j_mk = [(m, k) for m in country_with_forecast for k in dst_list if (m not in origin_list) & (m != k)]   # m connects to j exlcudes k (transit countries)
j_mk = [(j, k)  for j in country_with_forecast for k in dst_list if (j,k) not in mk if k != j]  
#j_mk = [(j, k) for m, j, k in mjk if (j,k) not in mk]   # j excludes m (transit countries), connects to k
j_mk = list( dict.fromkeys(j_mk) )

mk_all = j_mk + mj_k + mk
mk_all = list( dict.fromkeys(mk_all) )

pq = tuplelist([(p,q) for m,k in mk for p in L[m] for q in L[k]])
piq = tuplelist([(p,i,q) for (m,j,k) in mjk for p in L[m] for i in L[j] for q in L[k]])
pq_all = tuplelist((p, q) for m,k in mk_all for p in L[m] for q in L[k])
pqt = tuplelist([(p,q,t) for p,q in pq_all for t in T])

# %% [markdown]
# # Define all the parameters
#
# ## 1. Cost:
# Transportation Cost between hub p ∈ H and hub q ∈ H using truck t ∈ T (Euro/ kg)

# %%
cost_file = pd.read_csv("Database/Costs.csv")

# %%
cost = {}
for row in cost_file.index:
    cost_key = (cost_file["From"][row], cost_file["To"][row], cost_file["Truck type"][row])
    cost[cost_key] = cost_file["Cost/kg"][row]
'''    
cl_distance = 500

if "Co-loading" in T:
    for p, q in pq_all:
        cost[(p, q, "Co-loading")] = max([cost[p_s, q_s, t] for p_s, q_s, t in pqt.select(p, q, "*") if t != "Co-loading"])*1.5 if cost[(p, q, "Van")] < ((0.6*cl_distance+5)/2250) else 99
        # (0.6*500+5)/2250 use distance as a filter, over 500 km, the Co-loading opportunities are less

for p, q in pq:
    cost[(p, q, "Co-loading-Extra")] = cost[(p, q, "Van")]*10
'''
# Out:
# '    \ncl_distance = 500\n\nif "Co-loading" in T:\n    for p, q in pq_all:\n        cost[(p, q, "Co-loading")] = max([cost[p_s, q_s, t] for p_s, q_s, t in pqt.select(p, q, "*") if t != "Co-loading"])*1.5 if cost[(p, q, "Van")] < ((0.6*cl_distance+5)/2250) else 99\n        # (0.6*500+5)/2250 use distance as a filter, over 500 km, the Co-loading opportunities are less\n\nfor p, q in pq:\n    cost[(p, q, "Co-loading-Extra")] = cost[(p, q, "Van")]*10\n'

# %%
cl_file = pd.read_excel("Database/Co Loading Hubs.xlsx", sheet_name = "List hub")

cl_od = tuple(zip(cl_file["Origin"].to_list(), cl_file["Destination"].to_list()))


#cl={}

#cl=tuple(zip(cl_od))

    
if "Co-loading" in T:
    for p, q in pq_all:
        #for cl_od in cl:
        cost[(p, q, "Co-loading")] = max([cost[p_s, q_s, t] for p_s, q_s, t in pqt.select(p, q, "*") if t != "Co-loading"])*0.7 if (p,q) in cl_od else 99
        #print(cost[(p, q, "Co-loading")])

# %% [markdown]
# # 2. Forecast volume: Z
# Average forecasted parcel volume from country m ∈ E to country j ∈ E

# %%
Z = {}


for row in forecast.index:
    key = (forecast["Origin"][row], forecast["Destination"][row])
    Z[key] = int(round(forecast["Target"][row])) # Can only be interger

# Some missing connection in the forecast
for conn in mk:
    if conn not in Z.keys():
        Z[conn] = 0
        print(conn)

# %% [markdown]
# ## 3. Current Freqency (F_)
# the frequency of truck t from hub to hub q in the current network.

# %%
# The following code transform the excel files to csv file in specific format
'''
freq_truck = pd.read_excel("Database/Result_Freq.xlsx", sheet_name = 0)
freq_truck.replace("Ryton Gateway", "Ryton", inplace = True)
freq_truck["From"] = freq_truck.apply(lambda row: name_transform(row["Org. GTW"]), axis = 1)
freq_truck["To"] = freq_truck.apply(lambda row: name_transform(row["Dst. GTW"]), axis = 1)
freq_truck.loc[:, :].to_csv("Database/current_network.csv")

'''
# Out:
# '\nfreq_truck = pd.read_excel("Database/Result_Freq.xlsx", sheet_name = 0)\nfreq_truck.replace("Ryton Gateway", "Ryton", inplace = True)\nfreq_truck["From"] = freq_truck.apply(lambda row: name_transform(row["Org. GTW"]), axis = 1)\nfreq_truck["To"] = freq_truck.apply(lambda row: name_transform(row["Dst. GTW"]), axis = 1)\nfreq_truck.loc[:, :].to_csv("Database/current_network.csv")\n\n'

# %%
freq_current = pd.read_csv("Database/current_network.csv")
# The following section work as a formatting part. To avoid different naming issues
freq_current.replace("trailer", "Trailer", inplace = True)
freq_current.replace("2 swap bodies", "2 Swap Bodies", inplace = True)
freq_current.replace("van", "Van", inplace = True)
freq_current.replace("1 swap body", "Swap Body", inplace = True)
freq_current.replace("SEMI TRAILER", "Swap Body", inplace = True)
freq_current.replace("Cargo 50 m3", "Swap Body", inplace = True)
freq_current.replace("Sea Container", "2 Swap Bodies", inplace = True)
freq_current.replace("Van 15 m3", "Van", inplace = True)
freq_current.replace("Van 22m3", "Van", inplace = True)
freq_current.replace("4 swap bodies", "2 Swap Bodies", inplace = True)

# %%
F_ = {}
for row in freq_current.index:
    key = (freq_current.loc[row, "From"], freq_current.loc[row, "To"], freq_current.loc[row, "Truck type"])
    value = freq_current.loc[row, "Frequency"]
    
    F_[key] = value
    
for target in pqt:
    if target not in F_.keys():
        F_[target] = 0

# %% [markdown]
# ## 4. Travel time (TT)
# Total transportation time from hub p ∈ H to q ∈ H

# %%
tt_file = pd.read_csv("Database/travel time.csv")
TT = {}
for row in tt_file.index:
    key = (tt_file.loc[row, "From"], tt_file.loc[row, "To"])
    value = tt_file.loc[row, "est_tt"]
    
    TT[key] = value

# %% [markdown]
# ## 5. Hub Open & Cut-off time
# - Op = Hub opened time for hub p ∈ H
# - COp  = Hub cut off time for hub p ∈ H

# %%
def transform_time(target):
    try: 
        return int(target.split(":")[0]) + int(target.split(":")[1])/60 
    except:
        return 0

# %%
'''
hub_info = pd.read_csv("Database/Hub Cutoff and Open Time.csv")
hub_info["Hub"] = hub_info.apply(lambda row: name_transform(row["Gateways"]), axis = 1)
hub_info["Cut-off"] = hub_info.apply(lambda row: transform_time(row["Cut-Off"]), axis = 1)
hub_info["Open"] = hub_info.apply(lambda row: transform_time(row["Hub-Opening-Time"]), axis = 1)
hub_info.to_csv("Database/hub_info.csv")
'''
# Out:
# '\nhub_info = pd.read_csv("Database/Hub Cutoff and Open Time.csv")\nhub_info["Hub"] = hub_info.apply(lambda row: name_transform(row["Gateways"]), axis = 1)\nhub_info["Cut-off"] = hub_info.apply(lambda row: transform_time(row["Cut-Off"]), axis = 1)\nhub_info["Open"] = hub_info.apply(lambda row: transform_time(row["Hub-Opening-Time"]), axis = 1)\nhub_info.to_csv("Database/hub_info.csv")\n'

# %%
hub_info = pd.read_csv("Database/hub_info.csv")
merged_hub_info = hub_list_used.merge(hub_info[["Hub", "Open", "Cut-off"]], left_on = "Ref_City", right_on = "Hub", how = "left")

merged_hub_info["Open"].fillna(merged_hub_info["Open"].mode().values[0], inplace = True)
merged_hub_info["Cut-off"].fillna(merged_hub_info["Cut-off"].mode().values[0], inplace = True)

O = {} # Open time
for row in merged_hub_info.index:
    key = merged_hub_info.loc[row, "Ref_City"]
    value = merged_hub_info.loc[row, "Open"]
    O[key] = value

CO = {} # Cut-off time
for row in merged_hub_info.index:
    key = merged_hub_info.loc[row, "Ref_City"]
    value = merged_hub_info.loc[row, "Cut-off"]
    CO[key] =  value

# %% [markdown]
# ## 6. Truck Capacity

# %%
C = {}
for row in truck_cap.index:
    C[truck_cap.loc[row, "Truck Type"]] = truck_cap.loc[row, "Capacity"]

# %% [markdown]
# # Start the model

# %%
model = Model("DHL")
# Out:
# Academic license - for non-commercial use only

# %% [markdown]
# # Define the variables
# Decision variables:
# - xpq = 1 if the transportation from hub p ∈ H to hub q ∈ H is direct, else 0
# - x’piq = 1 if the transportation from hub p ∈ H to hub q ∈ H has to go through i ∈ H, else 0
# - Xmk = 1 if the transportation from country m ∈ E to county k ∈ E is direct, else 0
# - X’mjk = 1 if the transportation from country m ∈ E  to county k ∈ E  has to go through country j ∈ E , else 0
# - Vpq = route capacity from hub p ∈ H to hub q ∈ H
# - Fpqt = recommended frequency of truck t ∈ T from hub p ∈ H to hub q ∈ H
# - Spq = start time of truck from hub p ∈ H to hub q ∈ H,
# - Npq = Night needed from hub p ∈ H to hub q ∈ H

# %%
x = model.addVars(pq , vtype=GRB.BINARY, name='xpq')  # Direct from hub to hub

x_ = model.addVars(piq, vtype = GRB.BINARY, name = 'x_piq')  # Indirect from hub to hub

X = model.addVars(mk , vtype=GRB.BINARY, name='Xmk')       # Direct from country to country

X_ = model.addVars(mjk,  vtype = GRB.BINARY, name = 'X_mjk') # Indirect from country to country

V = model.addVars(pq_all , vtype=GRB.INTEGER, lb=0 ,name='Vpq')   # Route capacity

F=model.addVars(pqt , vtype=GRB.INTEGER, lb=0, name='Fpqt') # Recommended Frequency

# S=model.addVars(pq_all , vtype=GRB.CONTINUOUS, name='Spq')         # Start time from hub p

# N=model.addVars(pq_all , vtype=GRB.INTEGER, name='Npq')         # Night Needed from hub p to hub q

CL = model.addVars(pq_all, vtype = GRB.INTEGER, lb = 0, name = "CLpq") # Co-loading (in) between p and q

# %%
attri_dict = {"hub_direct": x, "hub_indirect" : x_, "country_direct" : X, "country_indirect" : X_,
              "route_cap": V, "freq" : F, "Co-loading":CL}

# %% [markdown]
# ## Objective

# %%
("NL", "AT") in mj_k
# Out:
# False

# %%
model.update()

# Minimize the travel time for each route
model.setObjective(quicksum(x[p, q] * TT[p, q] for p, q in pq) +
                   quicksum(x_[p, i ,q] * (TT[p, i] + 9 + TT[i, q])for p, i, q in piq) # Consider the transit time in the hubs
                                                                                       # Taking 9 as an example
                   ,  GRB.MINIMIZE)

# %% [markdown]
# ## Constraints

# %%
### Constraints
## Direct or Indirect Transportation

model.addConstrs(((quicksum(X_[m,j,k] for j in E if (j != m) & (j != k)) == 
                   (1 - X[m,k])) for m, k in mk),
                 "Transportation can be direct or Indirect")


## Linking Countries and Hubs

model.addConstrs(((quicksum(x[p,q] for p in L[m] for q in L[k]) == 
                  X[m,k]) for m, k in mk), "Linking_pq")  ## We can't use E_mjk here
model.addConstrs(((quicksum(x_[p,i,q] for p in L[m] for i in L[j] for q in L[k]) ==
                 X_[m,j,k]) for m,j,k in mjk), "Linking_piq")

## Truck Capacity:

# V = monthly demand of the route
# For the countries of p, q are in mk
model.addConstrs(((V[p,q] ==  
                 quicksum(x_[p,q,i] * Z[m,j] for m, k, j in mjk.select(m, k, "*") for i in L[j]) +
                 quicksum(x_[i,p,q] * Z[j,k] for j, m, k in mjk.select("*", m, k) for i in L[j]) + 
                 x[p,q] * Z[m,k])
                 for m, k in mk for p in L[m] for q in L[k]), "Truck Capacity")

# For the countries of p are in the origin, q are not in the destination:
model.addConstrs((V[p,q] ==  
                 quicksum(x_[p,q,i] * Z[m,j] for m, k, j in mjk.select(m, k, "*") for i in L[j])
                 for m, k in mj_k for p in L[m] for q in L[k] if (m,k) not in j_mk), "Truck Capacity")
                 
# For the countries of p are not in the origin, q are in the destination:           
model.addConstrs((V[p,q] ==  
                 quicksum(x_[i,p,q] * Z[j,k] for j, m, k in mjk.select("*", m, k) for i in L[j]) 
                 for m, k in j_mk for p in L[m] for q in L[k] if (m,k) not in mj_k), "Truck Capacity")

# For the countries of p and q are not in mk, but in j_mk and mj_k in the same time
model.addConstrs((V[p,q] ==  
                 quicksum(x_[p,q,i] * Z[m,j] for m, k, j in mjk.select(m, k, "*") for i in L[j]) +
                 quicksum(x_[i,p,q] * Z[j,k] for j, m, k in mjk.select("*", m, k) for i in L[j])
                 for m, k in j_mk for p in L[m] for q in L[k] if (m,k) in mj_k), "Truck Capacity 4")


## Truck type and Frequency of trucks
# transforming the weekly frequency to monthly by multiplying 4
model.addConstrs(((V[p,q] + CL[p, q]*4 <=   # Updated
                 quicksum(F[p,q,t] * C[t] * 4 for t in T) )
                 for m, k in mk_all for q in L[k] for p in L[m]),
                 "Truck Type and Frequency"
                )

# Co-loading out constraints
# model.addConstrs((F[p,q,"Co-loading"] <= 2000 for p,q in pq_all), "Coloading out constraints") ## Removed after discussion on 6/22

# Co-loading in constraints
#model.addConstrs((CL[p,q] <= 2000 for p,q in pq_all), "Coloading in constraints")
#model.addConstrs((CL[p,q] <= quicksum(F[p,q,t]*C[t] for t in T)*0.3 for p, q in pq_all), "Coloading in constraints 2")

model.addConstrs((CL[p,q] <= 2000 for p,q in pq_all), "Coloading in constraints")
model.addConstrs((CL[p,q] <= V[p, q]*0.3 for p, q in pq_all), "Coloading in constraints 2")

'''
BigM = 9999
model.addConstrs((S[p,q] + TT[p,q] - N[p,q] * 24  <=  
                 CO[q] + 
                 BigM * (
                     1 - (x[p, q] + 
                          quicksum(x_[p, q, i] for m, k, j in mjk.select(m, k, "*") for i in L[j]) + 
                          quicksum(x_[i, p, q] for j, m, k in mjk.select("*", m, k) for i in L[j])
                 ) ) for m,k in mk for q in L[k] for p in L[m]), "Hub Cut Off Time")


BigMM = 9000

model.addConstrs((S[p,q] + TT[p,q] - N[p,q] * 24  >=  
                 O[q] + 
                 BigMM * (
                     1 - (x[p, q] + 
                          quicksum(x_[p, q, i] for m, k, j in mjk.select(m, k, "*") for i in L[j]) + 
                          quicksum(x_[i, p, q] for j, m, k in mjk.select("*", m, k) for i in L[j])
                 ) ) for m,k in mk for q in L[k] for p in L[m]), "Hub Open Time")

'''

# Assumption: all the excessive spaces could be loaded with co-loading opportunities in the current network
# Assumption: In the new network, all the co-loading oppottunities doesn't exist


Cost_bound = 1.05
Current_full = 1


'''
# The tighten model (loose a bit)
model.addConstr((quicksum(F[p,q,t] * cost[p,q,t] * C[t] for p, q, t in pqt) *
                 quicksum(F_[p,q,t] * C[t] for p, q, t in pqt) <= 
                 (quicksum(F_[p,q,t] * cost[p,q,t] * C[t] for p, q, t in pqt) *
                 (quicksum(Z[m,k] for m, k in mk)/4 + quicksum(CL[p,q] for p,q in pq)) * Cost_bound))
                 , "Cost Constraint")
'''

current_cost = sum(F_[p,q,t] * C[t] * cost[p,q,t] for p, q, t in pqt) / sum(F_[p,q,t] * C[t] for p,q,t in pqt)

model.addConstr((quicksum(F[p,q,t] * cost[p,q,t] * C[t] for p, q, t in pqt) <= 
                 (current_cost * (quicksum(V[p,q] for p, q in pq_all) / 4 + quicksum(CL[p,q] for p,q in pq))) * Cost_bound / Current_full), "Cost Constraint")

#V[p,q] for p, q in pq_all
# Out:
# <gurobi.Constr *Awaiting Model Update*>

# %% [markdown]
# ## Solver

# %%
model.update()
model.printStats()
# Out:
# Statistics for model DHL :
#   Linear constraint matrix    : 23305 Constrs, 209732 Vars, 606104 NZs
#   Variable types              : 0 Continuous, 209732 Integer (177854 Binary)
#   Matrix coefficient range    : [ 0.0196094, 1.43338e+06 ]
#   Objective coefficient range : [ 2.1, 197.2 ]
#   Variable bound range        : [ 1, 1 ]
#   RHS coefficient range       : [ 1, 2000 ]

# %%
# model.reset()

timeLimit = 3600*3 # In second

model.Params.TimeLimit = timeLimit - model.getAttr(GRB.Attr.Runtime)

model.Params.Heuristics = 0.5

model.Params.MIPFocus=3

model.Params.TuneCriterion = 2

model.Params.TuneTrials = 3

model.Params.SolutionLimit = 10

oldSolutionLimit = model.Params.SolutionLimit

model.Params.Seed = 3

model.Params.TuneTimeLimit = timeLimit/3

model.tune()

# model.feasRelaxS(1, False, False, True)

model.optimize()


'''
if model.tuneResultCount > 0:

    # Load the best tuned parameters into the model
    model.getTuneResult(0)

    # Write tuned parameters to a file
    model.write('tune.prm')

    # Solve the model using the tuned parameters
    model.optimize()
    
'''
# Out:
# Changed value of parameter TimeLimit to 10800.0
#    Prev: 1e+100  Min: 0.0  Max: 1e+100  Default: 1e+100
# Changed value of parameter Heuristics to 0.5
#    Prev: 0.05  Min: 0.0  Max: 1.0  Default: 0.05
# Changed value of parameter MIPFocus to 3
#    Prev: 0  Min: 0  Max: 3  Default: 0
# Changed value of parameter TuneCriterion to 2
#    Prev: -1  Min: -1  Max: 3  Default: -1
# Parameter TuneTrials unchanged
#    Value: 3  Min: 1  Max: 2000000000  Default: 3
# Changed value of parameter SolutionLimit to 10
#    Prev: 2000000000  Min: 1  Max: 2000000000  Default: 2000000000
# Changed value of parameter Seed to 3
#    Prev: 0  Min: 0  Max: 2000000000  Default: 0
# Changed value of parameter TuneTimeLimit to 3600.0
#    Prev: -1.0  Min: -1.0  Max: 1e+100  Default: -1.0
#
# Solving model using baseline parameter set with TimeLimit=10800s
#
# Solving with random seed #1 ...
# Optimize a model with 23305 rows, 209732 columns and 606104 nonzeros
# Variable types: 0 continuous, 209732 integer (177854 binary)
# Coefficient statistics:
#   Matrix range     [2e-02, 1e+06]
#   Objective range  [2e+00, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Presolve removed 9610 rows and 14199 columns (presolve time = 5s) ...
# Presolve removed 9994 rows and 14583 columns
# Presolve time: 6.49s
# Presolved: 13311 rows, 195149 columns, 570860 nonzeros
# Variable types: 0 continuous, 195149 integer (174022 binary)
# Presolve removed 999 rows and 999 columns
# Presolved: 12312 rows, 194150 columns, 568823 nonzeros
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    6.2375167e+03   4.967388e+03   0.000000e+00      8s
#      592    6.2375167e+03   0.000000e+00   0.000000e+00      9s
#      592    6.2375167e+03   0.000000e+00   0.000000e+00      9s
#
# Root relaxation: objective 6.237517e+03, 592 iterations, 1.07 seconds
# Total elapsed time = 10.15s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 6237.51667    0  210          - 6237.51667      -     -   10s
#      0     0 6261.78157    0  550          - 6261.78157      -     -   42s
#      0     0 6271.80019    0  581          - 6271.80019      -     -   50s
#      0     0 6272.20642    0  596          - 6272.20642      -     -   50s
#      0     0 6272.21199    0  596          - 6272.21199      -     -   50s
#      0     0 6316.41588    0  465          - 6316.41588      -     -   80s
#      0     0 6325.95450    0  419          - 6325.95450      -     -   86s
#      0     0 6326.46647    0  412          - 6326.46647      -     -   86s
#      0     0 6354.21116    0  415          - 6354.21116      -     -  118s
#      0     0 6354.87110    0  407          - 6354.87110      -     -  122s
#      0     0 6354.87114    0  407          - 6354.87114      -     -  122s
#      0     0 6368.28350    0  407          - 6368.28350      -     -  150s
#      0     0 6368.48827    0  403          - 6368.48827      -     -  153s
#      0     0 6368.51398    0  392          - 6368.51398      -     -  153s
#      0     0 6374.87790    0  391          - 6374.87790      -     -  181s
#      0     0 6374.92559    0  366          - 6374.92559      -     -  184s
#      0     0 6379.18747    0  330          - 6379.18747      -     -  210s
#      0     0 6379.26407    0  341          - 6379.26407      -     -  214s
#      0     0 6382.20281    0  258          - 6382.20281      -     -  241s
#      0     0 6382.25082    0  247          - 6382.25082      -     -  244s
#      0     0 6382.86254    0  335          - 6382.86254      -     -  275s
#      0     0 6382.86254    0  335          - 6382.86254      -     -  353s
# H    0     0                    6412.6600000 6382.86254  0.46%     -  374s
# H    0     0                    6408.5333333 6382.86254  0.40%     -  382s
#      0     0 6382.86254    0  186 6408.53333 6382.86254  0.40%     -  410s
# H    0     0                    6405.9000000 6382.86254  0.36%     -  411s
#      0     0 6382.86254    0  461 6405.90000 6382.86254  0.36%     -  424s
#      0     0 6382.86254    0  334 6405.90000 6382.86254  0.36%     -  427s
#      0     0 6382.86254    0  301 6405.90000 6382.86254  0.36%     -  428s
#      0     0 6382.86254    0  308 6405.90000 6382.86254  0.36%     -  428s
#      0     0 6384.56482    0  250 6405.90000 6384.56482  0.33%     -  429s
#      0     0 6387.49238    0  259 6405.90000 6387.49238  0.29%     -  429s
#      0     0 6387.93302    0  282 6405.90000 6387.93302  0.28%     -  429s
#      0     0 6388.00718    0  267 6405.90000 6388.00718  0.28%     -  430s
#      0     0 6388.00907    0  268 6405.90000 6388.00907  0.28%     -  430s
#      0     0 6392.74389    0  284 6405.90000 6392.74389  0.21%     -  459s
#      0     0 6392.74389    0  193 6405.90000 6392.74389  0.21%     -  464s
#      0     0 6392.74389    0  391 6405.90000 6392.74389  0.21%     -  471s
#      0     0 6392.74389    0  281 6405.90000 6392.74389  0.21%     -  472s
#      0     0 6392.74389    0  258 6405.90000 6392.74389  0.21%     -  472s
#      0     0 6392.74389    0  248 6405.90000 6392.74389  0.21%     -  472s
#      0     0 6392.74389    0  257 6405.90000 6392.74389  0.21%     -  472s
#      0     0 6392.88243    0  312 6405.90000 6392.88243  0.20%     -  472s
#      0     0 6393.15796    0  334 6405.90000 6393.15796  0.20%     -  472s
#      0     0 6393.28189    0  336 6405.90000 6393.28189  0.20%     -  472s
#      0     0 6393.38541    0  336 6405.90000 6393.38541  0.20%     -  472s
#      0     0 6394.09636    0  230 6405.90000 6394.09636  0.18%     -  501s
# H    0     0                    6405.3400000 6394.09636  0.18%     -  501s
#      0     0 6394.19102    0  234 6405.34000 6394.19102  0.17%     -  502s
#      0     0 6394.19102    0  234 6405.34000 6394.19102  0.17%     -  502s
#      0     0 6395.31544    0  207 6405.34000 6395.31544  0.16%     -  531s
#      0     0 6395.31544    0  181 6405.34000 6395.31544  0.16%     -  534s
#      0     0 6395.31544    0  434 6405.34000 6395.31544  0.16%     -  540s
#      0     0 6395.31544    0  248 6405.34000 6395.31544  0.16%     -  541s
#      0     0 6395.31544    0  210 6405.34000 6395.31544  0.16%     -  541s
#      0     0 6395.31544    0  210 6405.34000 6395.31544  0.16%     -  541s
#      0     0 6395.31544    0  206 6405.34000 6395.31544  0.16%     -  541s
#      0     0 6395.31544    0  249 6405.34000 6395.31544  0.16%     -  541s
#      0     0 6395.31544    0  223 6405.34000 6395.31544  0.16%     -  541s
#      0     0 6395.34797    0  206 6405.34000 6395.34797  0.16%     -  541s
#      0     0 6395.38559    0  208 6405.34000 6395.38559  0.16%     -  541s
#      0     0 6396.38033    0  241 6405.34000 6396.38033  0.14%     -  560s
#      0     0 6396.61079    0  223 6405.34000 6396.61079  0.14%     -  561s
#      0     0 6396.61316    0  219 6405.34000 6396.61316  0.14%     -  561s
# H    0     0                    6405.1066667 6396.61316  0.13%     -  574s
# H    0     0                    6404.5933333 6396.61316  0.12%     -  574s
#      0     0 6397.40987    0  247 6404.59333 6397.40987  0.11%     -  603s
# H    0     0                    6403.9400000 6397.40987  0.10%     -  604s
#      0     0 6397.41283    0  237 6403.94000 6397.41283  0.10%     -  604s
#      0     0 6397.88329    0  258 6403.94000 6397.88329  0.09%     -  628s
#      0     0 6397.88329    0  280 6403.94000 6397.88329  0.09%     -  630s
#      0     0 6397.88329    0  323 6403.94000 6397.88329  0.09%     -  634s
#      0     0 6397.88329    0  239 6403.94000 6397.88329  0.09%     -  635s
#      0     0 6397.88329    0  188 6403.94000 6397.88329  0.09%     -  635s
#      0     0 6397.88329    0  218 6403.94000 6397.88329  0.09%     -  635s
#      0     0 6397.88329    0  184 6403.94000 6397.88329  0.09%     -  635s
#      0     0 6397.88329    0  183 6403.94000 6397.88329  0.09%     -  635s
#      0     0 6397.88329    0  202 6403.94000 6397.88329  0.09%     -  635s
#      0     0 6397.88329    0  180 6403.94000 6397.88329  0.09%     -  635s
#      0     0 6397.88329    0  195 6403.94000 6397.88329  0.09%     -  635s
#      0     0 6397.91975    0  234 6403.94000 6397.91975  0.09%     -  635s
#      0     0 6398.08325    0  233 6403.94000 6398.08325  0.09%     -  635s
#      0     0 6398.08803    0  252 6403.94000 6398.08803  0.09%     -  635s
#      0     0 6398.76172    0  232 6403.94000 6398.76172  0.08%     -  650s
#      0     0 6398.81997    0  266 6403.94000 6398.81997  0.08%     -  650s
#      0     0 6399.25658    0  186 6403.94000 6399.25658  0.07%     -  672s
#      0     0 6399.25848    0  191 6403.94000 6399.25848  0.07%     -  672s
#      0     0 6399.63317    0  212 6403.94000 6399.63317  0.07%     -  701s
# H    0     0                    6403.6366667 6399.63317  0.06%     -  702s
#      0     0 6399.63317    0  212 6403.63667 6399.63317  0.06%     -  709s
#      0     0 6399.63317    0  218 6403.63667 6399.63317  0.06%     -  710s
# H    0     0                    6403.5666667 6399.63317  0.06%     -  713s
#      0     0 6399.63317    0  262 6403.56667 6399.63317  0.06%     -  713s
#
# Cutting planes:
#   Gomory: 221
#   Cover: 2
#   Implied bound: 14
#   Clique: 3
#   MIR: 287
#   StrongCG: 34
#   Flow cover: 92
#   Zero half: 16
#
# Explored 1 nodes (65221 simplex iterations) in 713.65 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 6403.57 6403.64 6403.94 ... 6412.66
#
# Solution limit reached
# Best objective 6.403566666667e+03, best bound 6.399633333333e+03, gap 0.0614%
#
# -------------------------------------------------------------------------------
#
# Solving with random seed #2 ...
# Optimize a model with 23305 rows, 209732 columns and 606104 nonzeros
# Variable types: 0 continuous, 209732 integer (177854 binary)
# Coefficient statistics:
#   Matrix range     [2e-02, 1e+06]
#   Objective range  [2e+00, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Presolve removed 9802 rows and 14391 columns (presolve time = 5s) ...
# Presolve removed 9994 rows and 14583 columns
# Presolve time: 6.05s
# Presolved: 13311 rows, 195149 columns, 570860 nonzeros
# Variable types: 0 continuous, 195149 integer (174022 binary)
# Presolve removed 999 rows and 999 columns
# Presolved: 12312 rows, 194150 columns, 568823 nonzeros
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    6.2375167e+03   4.967388e+03   0.000000e+00      8s
#      593    6.2375167e+03   0.000000e+00   0.000000e+00      8s
#      593    6.2375167e+03   0.000000e+00   0.000000e+00      9s
#
# Root relaxation: objective 6.237517e+03, 593 iterations, 1.11 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 6237.51667    0  209          - 6237.51667      -     -    9s
#      0     0 6261.22958    0  543          - 6261.22958      -     -   37s
#      0     0 6271.01699    0  530          - 6271.01699      -     -   41s
#      0     0 6271.02797    0  532          - 6271.02797      -     -   41s
#      0     0 6271.03302    0  532          - 6271.03302      -     -   41s
#      0     0 6317.29636    0  484          - 6317.29636      -     -   68s
#      0     0 6322.88515    0  446          - 6322.88515      -     -   73s
#      0     0 6323.27443    0  439          - 6323.27443      -     -   73s
#      0     0 6350.45533    0  433          - 6350.45533      -     -   99s
#      0     0 6350.90527    0  400          - 6350.90527      -     -  103s
#      0     0 6363.10038    0  381          - 6363.10038      -     -  127s
#      0     0 6363.27738    0  358          - 6363.27738      -     -  131s
#      0     0 6363.28699    0  366          - 6363.28699      -     -  131s
#      0     0 6374.34554    0  366          - 6374.34554      -     -  156s
#      0     0 6374.38854    0  331          - 6374.38854      -     -  159s
#      0     0 6377.45059    0  322          - 6377.45059      -     -  185s
#      0     0 6377.46485    0  320          - 6377.46485      -     -  188s
#      0     0 6379.09135    0  330          - 6379.09135      -     -  214s
#      0     0 6379.14362    0  314          - 6379.14362      -     -  218s
#      0     0 6380.24981    0  354          - 6380.24981      -     -  245s
#      0     0 6380.28578    0  326          - 6380.28578      -     -  247s
#      0     0 6380.87765    0  308          - 6380.87765      -     -  275s
#      0     0 6380.96912    0  341          - 6380.96912      -     -  277s
#      0     0 6381.51349    0  307          - 6381.51349      -     -  311s
#      0     0 6381.51349    0  307          - 6381.51349      -     -  400s
#      0     2 6381.51349    0  307          - 6381.51349      -     - 1607s
#      7    12 6381.54392    3  295          - 6381.53131      -  80.7 1610s
#     27    29 6381.62178    8  296          - 6381.54502      -  35.2 1615s
#     41    40 6381.64610   11  269          - 6381.54502      -  30.9 1620s
#     59    63 6381.67012   14  264          - 6381.54502      -  25.4 1629s
#     70    68 6381.64891   15  268          - 6381.54502      -  27.8 1641s
#     96    98 6381.72931   20  251          - 6381.54502      -  26.3 1661s
#    137   139 6381.89372   31  235          - 6381.54502      -  28.5 1688s
#    236   240 6382.24915   54  215          - 6381.54502      -  25.2 1709s
#    307   306 6383.19278   71  213          - 6381.54502      -  30.6 1734s
#    343   341 6383.40509   77  214          - 6381.54502      -  34.1 1760s
#    416   419 6383.66807   93  222          - 6381.54502      -  39.4 1789s
#    498   499 6384.94492  116  213          - 6381.54502      -  44.4 1819s
#    569   571 6384.95032  135  204          - 6381.54502      -  47.2 1848s
#    628   630 6384.95265  153  208          - 6381.54502      -  52.8 1880s
#    688   687 6384.95560  163  200          - 6381.54502      -  60.3 1914s
#    748   750 6384.95744  174  180          - 6381.54502      -  68.1 1960s
#    811   809 6384.95878  193  180          - 6381.54502      -  80.4 2003s
#    870   872 6384.96187  210  185          - 6381.54502      -  88.9 2041s
#    995   996 6385.04034  256  170          - 6381.54502      -  94.2 2080s
#   1100  1101 6385.24050  274  178          - 6381.54502      -   104 2121s
#   1262  1267 6385.26235  290  176          - 6381.54502      -   106 2168s
#   1318  1316 6385.43269  292  182          - 6381.54502      -   119 2216s
#   1485  1489 6385.44187  339  179          - 6381.54502      -   116 2265s
#   1583  1580 6385.45852  375  174          - 6381.54502      -   120 2313s
#   1717  1718 6385.46422  409  188          - 6381.54502      -   119 2362s
#   1834  1838 6385.47227  446  174          - 6381.54502      -   122 2415s
#   1961  1960 6385.47995  474  179          - 6381.54502      -   125 2473s
#   2094  2094 6385.49118  525  175          - 6381.54502      -   128 2538s
#   2390  2392 6385.51274  566  175          - 6381.54502      -   122 2597s
#   2614  2615 6385.87091  611  174          - 6381.54502      -   121 2660s
#   2838  2841 6385.88946  653  167          - 6381.54502      -   119 2720s
#   3037  3034 6385.90187  706  191          - 6381.54502      -   120 2788s
#   3374  3374 6385.93266  807  168          - 6381.54502      -   112 2858s
#   3770  3769 6386.60065  913  191          - 6381.54502      -   105 2886s
#
# Cutting planes:
#   Gomory: 279
#   Cover: 3
#   Implied bound: 49
#   Clique: 1
#   MIR: 981
#   StrongCG: 19
#   Flow cover: 256
#   GUB cover: 2
#   Zero half: 27
#
# Explored 3946 nodes (427509 simplex iterations) in 2886.52 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 0
#
# Time limit reached
# Best objective -, best bound 6.381546666667e+03, gap -
#
# -------------------------------------------------------------------------------
#
#
#
# Tune time limit reached.
#
# -------------------------------------------------------------------------------
#
# Tested 0 parameter sets in 3600.26s
# Unable to improve on baseline parameter set.
#
# Optimize a model with 23305 rows, 209732 columns and 606104 nonzeros
# Variable types: 0 continuous, 209732 integer (177854 binary)
# Coefficient statistics:
#   Matrix range     [2e-02, 1e+06]
#   Objective range  [2e+00, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Presolve removed 9802 rows and 14391 columns (presolve time = 5s) ...
# Presolve removed 9994 rows and 14583 columns
# Presolve time: 5.96s
# Presolved: 13311 rows, 195149 columns, 570860 nonzeros
# Variable types: 0 continuous, 195149 integer (174022 binary)
# Presolve removed 999 rows and 999 columns
# Presolved: 12312 rows, 194150 columns, 568823 nonzeros
#
#
# Root simplex log...
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    6.2375167e+03   4.967388e+03   0.000000e+00      8s
#      614    6.2375167e+03   0.000000e+00   0.000000e+00      8s
#      614    6.2375167e+03   0.000000e+00   0.000000e+00      9s
#
# Root relaxation: objective 6.237517e+03, 614 iterations, 1.05 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 6237.51667    0  212          - 6237.51667      -     -    9s
#      0     0 6266.78193    0  572          - 6266.78193      -     -   36s
#      0     0 6275.89939    0  592          - 6275.89939      -     -   42s
#      0     0 6276.00423    0  589          - 6276.00423      -     -   42s
#      0     0 6276.01629    0  590          - 6276.01629      -     -   42s
#      0     0 6324.39748    0  510          - 6324.39748      -     -   69s
#      0     0 6333.13685    0  432          - 6333.13685      -     -   74s
#      0     0 6333.54552    0  423          - 6333.54552      -     -   74s
#      0     0 6356.08173    0  382          - 6356.08173      -     -   97s
#      0     0 6357.51354    0  354          - 6357.51354      -     -  101s
#      0     0 6371.27516    0  401          - 6371.27516      -     -  127s
#      0     0 6371.63229    0  416          - 6371.63229      -     -  130s
#      0     0 6371.66809    0  430          - 6371.66809      -     -  130s
#      0     0 6378.50969    0  353          - 6378.50969      -     -  156s
#      0     0 6378.61745    0  324          - 6378.61745      -     -  159s
#      0     0 6382.81224    0  359          - 6382.81224      -     -  184s
#      0     0 6382.98975    0  329          - 6382.98975      -     -  188s
#      0     0 6383.13592    0  335          - 6383.13592      -     -  188s
#      0     0 6384.38064    0  305          - 6384.38064      -     -  214s
#      0     0 6384.48578    0  316          - 6384.48578      -     -  217s
#      0     0 6384.49042    0  301          - 6384.49042      -     -  217s
#      0     0 6385.02028    0  335          - 6385.02028      -     -  245s
#      0     0 6385.26881    0  326          - 6385.26881      -     -  248s
#      0     0 6385.28057    0  315          - 6385.28057      -     -  248s
#      0     0 6385.88058    0  315          - 6385.88058      -     -  276s
#      0     0 6386.00824    0  316          - 6386.00824      -     -  279s
#      0     0 6386.38277    0  284          - 6386.38277      -     -  308s
#      0     0 6386.38277    0  284          - 6386.38277      -     -  344s
# H    0     0                    6410.7700000 6386.38277  0.38%     -  358s
# H    0     0                    6408.1566667 6386.38277  0.34%     -  361s
#      0     0 6386.38277    0  193 6408.15667 6386.38277  0.34%     -  379s
# H    0     0                    6405.5233333 6386.38277  0.30%     -  380s
#      0     0 6386.38277    0  457 6405.52333 6386.38277  0.30%     -  388s
#      0     0 6386.38277    0  330 6405.52333 6386.38277  0.30%     -  390s
#      0     0 6386.38277    0  318 6405.52333 6386.38277  0.30%     -  391s
#      0     0 6386.38277    0  301 6405.52333 6386.38277  0.30%     -  391s
#      0     0 6386.38277    0  289 6405.52333 6386.38277  0.30%     -  391s
#      0     0 6388.12351    0  231 6405.52333 6388.12351  0.27%     -  392s
#      0     0 6388.82945    0  279 6405.52333 6388.82945  0.26%     -  392s
#      0     0 6389.46490    0  322 6405.52333 6389.46490  0.25%     -  392s
#      0     0 6389.60161    0  269 6405.52333 6389.60161  0.25%     -  392s
#      0     0 6389.61581    0  262 6405.52333 6389.61581  0.25%     -  393s
#      0     0 6389.62922    0  256 6405.52333 6389.62922  0.25%     -  393s
#      0     0 6391.91347    0  283 6405.52333 6391.91347  0.21%     -  427s
#      0     0 6391.91347    0  183 6405.52333 6391.91347  0.21%     -  431s
#      0     0 6391.91347    0  413 6405.52333 6391.91347  0.21%     -  437s
#      0     0 6391.91347    0  334 6405.52333 6391.91347  0.21%     -  438s
#      0     0 6391.91347    0  260 6405.52333 6391.91347  0.21%     -  438s
#      0     0 6391.91347    0  217 6405.52333 6391.91347  0.21%     -  438s
#      0     0 6391.91347    0  224 6405.52333 6391.91347  0.21%     -  438s
#      0     0 6391.91347    0  262 6405.52333 6391.91347  0.21%     -  438s
#      0     0 6391.97914    0  271 6405.52333 6391.97914  0.21%     -  438s
#      0     0 6392.20636    0  281 6405.52333 6392.20636  0.21%     -  439s
#      0     0 6392.35672    0  276 6405.52333 6392.35672  0.21%     -  439s
# H    0     0                    6405.4766667 6392.35672  0.20%     -  461s
#      0     0 6394.75406    0  243 6405.47667 6394.75406  0.17%     -  476s
#      0     0 6394.80622    0  220 6405.47667 6394.80622  0.17%     -  476s
# H    0     0                    6405.3600000 6394.80622  0.16%     -  491s
# H    0     0                    6404.6133333 6394.80622  0.15%     -  491s
#      0     0 6396.02980    0  263 6404.61333 6396.02980  0.13%     -  512s
#      0     0 6396.02980    0  283 6404.61333 6396.02980  0.13%     -  514s
#      0     0 6396.02980    0  337 6404.61333 6396.02980  0.13%     -  518s
#      0     0 6396.02980    0  242 6404.61333 6396.02980  0.13%     -  518s
#      0     0 6396.02980    0  201 6404.61333 6396.02980  0.13%     -  518s
#      0     0 6396.02980    0  159 6404.61333 6396.02980  0.13%     -  519s
#      0     0 6396.02980    0  197 6404.61333 6396.02980  0.13%     -  519s
#      0     0 6396.02980    0  232 6404.61333 6396.02980  0.13%     -  519s
#      0     0 6396.39717    0  249 6404.61333 6396.39717  0.13%     -  519s
#      0     0 6396.64495    0  245 6404.61333 6396.64495  0.12%     -  519s
#      0     0 6396.69284    0  233 6404.61333 6396.69284  0.12%     -  519s
# H    0     0                    6404.4733333 6396.69284  0.12%     -  523s
#      0     0 6397.33395    0  260 6404.47333 6397.33395  0.11%     -  545s
# H    0     0                    6404.0333333 6397.33395  0.10%     -  546s
#      0     0 6397.40382    0  237 6404.03333 6397.40382  0.10%     -  546s
# H    0     0                    6403.9866667 6397.40382  0.10%     -  556s
#
# Cutting planes:
#   Gomory: 312
#   Cover: 26
#   Implied bound: 19
#   Clique: 2
#   MIR: 681
#   StrongCG: 41
#   Flow cover: 214
#   GUB cover: 5
#   Zero half: 16
#
# Explored 1 nodes (56346 simplex iterations) in 556.71 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 6403.99 6404.03 6404.47 ... 6410.77
#
# Solution limit reached
# Best objective 6.403986666667e+03, best bound 6.397403824805e+03, gap 0.1028%
# "\nif model.tuneResultCount > 0:\n\n    # Load the best tuned parameters into the model\n    model.getTuneResult(0)\n\n    # Write tuned parameters to a file\n    model.write('tune.prm')\n\n    # Solve the model using the tuned parameters\n    model.optimize()\n    \n"

# %%
def turn_to_df(Var, col_name = None):  # Here you could input the variable
    solution = model.getAttr('x_', Var)
    num_col = len(solution.keys()[0])
    collect = []
    for row in range(0, len(solution)):
        new_row = []
        for col in range(0, num_col):
            new_row.append(solution.keys()[row][col])
        new_row.append(solution[solution.keys()[row]])
    
        collect.append(new_row)
    return pd.DataFrame(collect, columns = col_name)

# %%
Hub_Indirect = turn_to_df(x_, ["Ori_Hub", "Transit_Hub","Dest_Hub", "Taken"])
Hub_Indirect[Hub_Indirect.Taken > 0 ]
# Out:
#                       Ori_Hub         Transit_Hub  \
# 249                 Kaunas-LT           Poznań-PL
# 524                 Lisboa-PT           Zagreb-HR
# 593                Brüssel-BE           Zagreb-HR
# 1322                Lisboa-PT           Zagreb-HR
# 1421                Lisboa-PT    Hall in Tirol-AT
# 1546                Lisboa-PT     PZ 50 (Köln)-DE
# 1972             Barcelona-ES           Zagreb-HR
# 1993                Lisboa-PT        Ljubljana-SI
# 2112               Brüssel-BE           Poznań-PL
# 5011                 Malmö-SE     Budapest OLK-HU
# 5189                Lisboa-PT        Ljubljana-SI
# 9303     Vantaa (Helsinki)-FL     Budapest OLK-HU
# 10771   PZ 93 (Regensburg)-DE           Zagreb-HR
# 11033            Barcelona-ES           Zagreb-HR
# 11064               Lisboa-PT          Brüssel-BE
# 11521    Vantaa (Helsinki)-FL       Hagenbrunn-AT
# 18338            Barcelona-ES        Ljubljana-SI
# 22515              Brüssel-BE  Araba (Vitoria)-ES
# 22782               Lisboa-PT          Brüssel-BE
# 22861               Lisboa-PT  Araba (Vitoria)-ES
# 24611               Lisboa-PT  Araba (Vitoria)-ES
# 25845      Eindhoven-Noord-NL           Zagreb-HR
# 27962               Slough-GB           Poznań-PL
# 28005        Lieto (Turku)-FL  Araba (Vitoria)-ES
# 30841              Brüssel-BE          Kolding-DK
# 31955               Slough-GB           Zagreb-HR
# 33655                Malmö-SE  Eindhoven-Noord-NL
# 36515                Malmö-SE  Eindhoven-Noord-NL
# 37734               Slough-GB     Budapest OLK-HU
# 43304      Eindhoven-Noord-NL          Kolding-DK
# 45463               Slough-GB          Brüssel-BE
# 48123               Lisboa-PT  Araba (Vitoria)-ES
# 55840               Slough-GB          Kolding-DK
# 55878               Slough-GB  Araba (Vitoria)-ES
# 73012               Poznań-PL          Brüssel-BE
# 74525               Lisboa-PT  Araba (Vitoria)-ES
# 77361               Poznań-PL  Eindhoven-Noord-NL
# 106918             Wrocław-PL     PZ 77 (Lahr)-DE
# 121567              Poznań-PL  Eindhoven-Noord-NL
# 156518              Slough-GB  Eindhoven-Noord-NL
# 158190             Wrocław-PL         Krupka 1-CZ
# 163163                Enns-AT          Plzen 1-CZ
# 168502     Eindhoven-Noord-NL          Brüssel-BE
#
#                            Dest_Hub  Taken
# 249                        Malmö-SE    1.0
# 524                        Sofia-BG    1.0
# 593                        Sofia-BG    1.0
# 1322                       Spata-GR    1.0
# 1421           Ivanka pri Dunaji-SK    1.0
# 1546                 Helsingborg-SE    1.0
# 1972                       Spata-GR    1.0
# 1993                      Oradea-RO    1.0
# 2112                      Kaunas-LT    1.0
# 5011                       Sofia-BG    1.0
# 5189                Budapest OLK-HU    1.0
# 9303                       Sofia-BG    1.0
# 10771                      Spata-GR    1.0
# 11033                      Sofia-BG    1.0
# 11064                     Poznań-PL    1.0
# 11521                  Ljubljana-SI    1.0
# 18338                     Oradea-RO    1.0
# 22515                     Lisboa-PT    1.0
# 22782                    Kolding-DK    1.0
# 22861              Lieto (Turku)-FL    1.0
# 24611            Eindhoven-Noord-NL    1.0
# 25845                      Sofia-BG    1.0
# 27962                     Kaunas-LT    1.0
# 28005                     Lisboa-PT    1.0
# 30841              Lieto (Turku)-FL    1.0
# 31955                      Sofia-BG    1.0
# 33655                     Lisboa-PT    1.0
# 36515                     Dublin-IE    1.0
# 37734                     Oradea-RO    1.0
# 43304              Lieto (Turku)-FL    1.0
# 45463                      Spata-GR    1.0
# 48123                     Dublin-IE    1.0
# 55840              Lieto (Turku)-FL    1.0
# 55878                     Lisboa-PT    1.0
# 73012                     Dublin-IE    1.0
# 74525                     Slough-GB    1.0
# 77361                     Lisboa-PT    1.0
# 106918                 Barcelona-ES    1.0
# 121567                    Slough-GB    1.0
# 156518           PZ 47 (Krefeld)-DE    1.0
# 158190  PZ 04 (Radefeld/Leipzig)-DE    1.0
# 163163        PZ 93 (Regensburg)-DE    1.0
# 168502           PZ 47 (Krefeld)-DE    1.0

# %%
Country_Direct = turn_to_df(X, ["Ori_Country", "Dest_Country", "Taken"])
Country_Indirect = turn_to_df(X_, ["Ori_Country", "Transit_Country","Dest_Country", "Taken"])

Hub_Direct = turn_to_df(x, ["Ori_Hub", "Dest_Hub", "Taken"])
Hub_Indirect = turn_to_df(x_, ["Ori_Hub", "Transit_Hub","Dest_Hub", "Taken"])

Route_Cap = turn_to_df(V, ["Ori_Hub", "Dest_Hub", "Taken"])
Freq = turn_to_df(F, ["Ori_Hub", "Dest_Hub","Truck Type", "Taken"])
#Start = turn_to_df(S, ["Ori_Hub", "Dest_Hub", "Time"])
#Night = turn_to_df(N, ["Ori_Hub", "Dest_Hub", "Nights"])
Co_load = turn_to_df(CL, ["Ori_Hub", "Dest_Hub", "Amount"])
CL_sol =  model.getAttr('x_', CL)

# %%
for key in attri_dict.keys():
    df_output = turn_to_df(attri_dict[key])
    df_output.to_csv(f"Output/{key}_output.csv")

# %%
ind = Country_Indirect.Taken.sum()
d = Country_Direct.Taken.sum()

print(f"{ind} indirect routes and {d} direct route, total: {len(Z)}" )
# Out:
# 43.0 indirect routes and 169.0 direct route, total: 212

# %%
freq_result = model.getAttr('x', F)
demand_filled = model.getAttr('x', V)
print("Cost by Route Cap.:", round(sum(freq_result[p,q,t] * C[t] * cost[p,q,t] for p, q, t in pqt) / (sum(demand_filled[p,q] for p, q in pq_all)/4), 2))
print("Cost by Capacity.:", sum(freq_result[p,q,t] * C[t] * cost[p,q,t] for p, q,t in pqt) / (sum(freq_result[p,q,t] * C[t] for p, q,t in pqt)))
print("Cost by Demands.:", sum(freq_result[p,q,t] * C[t] * cost[p,q,t] for p, q,t in pqt) / (sum(Z[m, k] for m, k in mk)/4))
print("Cost by Demands + Co-load:", sum(freq_result[p,q,t] * C[t] * cost[p,q,t] for p, q, t in pqt) / (sum(Z[m, k] for m, k in mk)/4 + sum(CL_sol[p, q] for p, q in pq_all)))
# Out:
# Cost by Route Cap.: 0.08
# Cost by Capacity.: 0.0732101483535837
# Cost by Demands.: 0.1279041759480959
# Cost by Demands + Co-load: 0.1182089040068324

# %%
sum(F_[p,q,t] * C[t] * cost[p,q,t] for p, q, t in pqt) / sum(F_[p,q,t] * C[t] for p,q,t in pqt)
# Out:
# 0.07470231825180568

# %%
Freq_result = Freq[Freq.Taken > 0]
Freq_result.groupby("Truck Type").count()
# Out:
#                Ori_Hub  Dest_Hub  Taken
# Truck Type
# 2 Swap Bodies       32        32     32
# Co-loading          12        12     12
# Swap Body           42        42     42
# Van                123       123    123

# %%
Freq_result = Freq[Freq.Taken > 0]
Freq_result["agg"] = Freq_result["Ori_Hub"] + Freq_result["Dest_Hub"]
print(Freq_result.groupby("Truck Type").count()) # Truck type count per routes

Freq_result["Capacity"] = Freq_result.apply(lambda row: C[row["Truck Type"]] * row["Taken"] * 4, axis = 1)
capacity_from_freq = Freq_result.groupby(["agg"]).sum()


# Indirect Route Overview

Hub_Indirect_T = Hub_Indirect[Hub_Indirect.Taken > 0]
Hub_Indirect_T["First"] = Hub_Indirect_T["Ori_Hub"] + Hub_Indirect_T["Transit_Hub"]
Hub_Indirect_T["Second"] = Hub_Indirect_T["Transit_Hub"] + Hub_Indirect_T["Dest_Hub"]

Hub_merge = Hub_Indirect_T.merge(capacity_from_freq.loc[:, "Capacity"], left_on = "First", right_on = "agg", how = "right")
Hub_merge = Hub_merge.merge(capacity_from_freq.loc[:, "Capacity"], left_on = "Second", right_on = "agg", how = "right")

pd.options.display.max_rows = 100
Hub_merge.dropna()
# Out:
# C:\Users\MAHITA\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\MAHITA\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
#                Ori_Hub  Dest_Hub  Taken  agg
# Truck Type
# 2 Swap Bodies       32        32     32   32
# Co-loading          12        12     12   12
# Swap Body           42        42     42   42
# Van                123       123    123  123
# C:\Users\MAHITA\Anaconda3\lib\site-packages\ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
# C:\Users\MAHITA\Anaconda3\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]
#                   Ori_Hub         Transit_Hub                     Dest_Hub  \
# 0               Kaunas-LT           Poznań-PL                     Malmö-SE
# 1               Lisboa-PT           Zagreb-HR                     Sofia-BG
# 2              Brüssel-BE           Zagreb-HR                     Sofia-BG
# 3            Barcelona-ES           Zagreb-HR                     Sofia-BG
# 4      Eindhoven-Noord-NL           Zagreb-HR                     Sofia-BG
# 5               Slough-GB           Zagreb-HR                     Sofia-BG
# 6               Lisboa-PT           Zagreb-HR                     Spata-GR
# 7            Barcelona-ES           Zagreb-HR                     Spata-GR
# 8   PZ 93 (Regensburg)-DE           Zagreb-HR                     Spata-GR
# 9               Lisboa-PT    Hall in Tirol-AT         Ivanka pri Dunaji-SK
# 10              Lisboa-PT     PZ 50 (Köln)-DE               Helsingborg-SE
# 11              Lisboa-PT        Ljubljana-SI                    Oradea-RO
# 12           Barcelona-ES        Ljubljana-SI                    Oradea-RO
# 13              Lisboa-PT        Ljubljana-SI              Budapest OLK-HU
# 14             Brüssel-BE           Poznań-PL                    Kaunas-LT
# 15              Slough-GB           Poznań-PL                    Kaunas-LT
# 16               Malmö-SE     Budapest OLK-HU                     Sofia-BG
# 17   Vantaa (Helsinki)-FL     Budapest OLK-HU                     Sofia-BG
# 18              Lisboa-PT          Brüssel-BE                    Poznań-PL
# 19              Lisboa-PT          Brüssel-BE                   Kolding-DK
# 20   Vantaa (Helsinki)-FL       Hagenbrunn-AT                 Ljubljana-SI
# 21             Brüssel-BE  Araba (Vitoria)-ES                    Lisboa-PT
# 22       Lieto (Turku)-FL  Araba (Vitoria)-ES                    Lisboa-PT
# 23              Slough-GB  Araba (Vitoria)-ES                    Lisboa-PT
# 24              Lisboa-PT  Araba (Vitoria)-ES             Lieto (Turku)-FL
# 25              Lisboa-PT  Araba (Vitoria)-ES           Eindhoven-Noord-NL
# 26              Lisboa-PT  Araba (Vitoria)-ES                    Dublin-IE
# 27              Lisboa-PT  Araba (Vitoria)-ES                    Slough-GB
# 28             Brüssel-BE          Kolding-DK             Lieto (Turku)-FL
# 29     Eindhoven-Noord-NL          Kolding-DK             Lieto (Turku)-FL
# 30              Slough-GB          Kolding-DK             Lieto (Turku)-FL
# 31               Malmö-SE  Eindhoven-Noord-NL                    Lisboa-PT
# 32              Poznań-PL  Eindhoven-Noord-NL                    Lisboa-PT
# 33               Malmö-SE  Eindhoven-Noord-NL                    Dublin-IE
# 34              Slough-GB     Budapest OLK-HU                    Oradea-RO
# 35              Slough-GB          Brüssel-BE                     Spata-GR
# 36              Poznań-PL          Brüssel-BE                    Dublin-IE
# 37              Poznań-PL  Eindhoven-Noord-NL                    Slough-GB
# 38             Wrocław-PL     PZ 77 (Lahr)-DE                 Barcelona-ES
# 39              Slough-GB  Eindhoven-Noord-NL           PZ 47 (Krefeld)-DE
# 40             Wrocław-PL         Krupka 1-CZ  PZ 04 (Radefeld/Leipzig)-DE
# 41                Enns-AT          Plzen 1-CZ        PZ 93 (Regensburg)-DE
# 42     Eindhoven-Noord-NL          Brüssel-BE           PZ 47 (Krefeld)-DE
#
#     Taken                                First  \
# 0     1.0                   Kaunas-LTPoznań-PL
# 1     1.0                   Lisboa-PTZagreb-HR
# 2     1.0                  Brüssel-BEZagreb-HR
# 3     1.0                Barcelona-ESZagreb-HR
# 4     1.0          Eindhoven-Noord-NLZagreb-HR
# 5     1.0                   Slough-GBZagreb-HR
# 6     1.0                   Lisboa-PTZagreb-HR
# 7     1.0                Barcelona-ESZagreb-HR
# 8     1.0       PZ 93 (Regensburg)-DEZagreb-HR
# 9     1.0            Lisboa-PTHall in Tirol-AT
# 10    1.0             Lisboa-PTPZ 50 (Köln)-DE
# 11    1.0                Lisboa-PTLjubljana-SI
# 12    1.0             Barcelona-ESLjubljana-SI
# 13    1.0                Lisboa-PTLjubljana-SI
# 14    1.0                  Brüssel-BEPoznań-PL
# 15    1.0                   Slough-GBPoznań-PL
# 16    1.0              Malmö-SEBudapest OLK-HU
# 17    1.0  Vantaa (Helsinki)-FLBudapest OLK-HU
# 18    1.0                  Lisboa-PTBrüssel-BE
# 19    1.0                  Lisboa-PTBrüssel-BE
# 20    1.0    Vantaa (Helsinki)-FLHagenbrunn-AT
# 21    1.0         Brüssel-BEAraba (Vitoria)-ES
# 22    1.0   Lieto (Turku)-FLAraba (Vitoria)-ES
# 23    1.0          Slough-GBAraba (Vitoria)-ES
# 24    1.0          Lisboa-PTAraba (Vitoria)-ES
# 25    1.0          Lisboa-PTAraba (Vitoria)-ES
# 26    1.0          Lisboa-PTAraba (Vitoria)-ES
# 27    1.0          Lisboa-PTAraba (Vitoria)-ES
# 28    1.0                 Brüssel-BEKolding-DK
# 29    1.0         Eindhoven-Noord-NLKolding-DK
# 30    1.0                  Slough-GBKolding-DK
# 31    1.0           Malmö-SEEindhoven-Noord-NL
# 32    1.0          Poznań-PLEindhoven-Noord-NL
# 33    1.0           Malmö-SEEindhoven-Noord-NL
# 34    1.0             Slough-GBBudapest OLK-HU
# 35    1.0                  Slough-GBBrüssel-BE
# 36    1.0                  Poznań-PLBrüssel-BE
# 37    1.0          Poznań-PLEindhoven-Noord-NL
# 38    1.0            Wrocław-PLPZ 77 (Lahr)-DE
# 39    1.0          Slough-GBEindhoven-Noord-NL
# 40    1.0                Wrocław-PLKrupka 1-CZ
# 41    1.0                    Enns-ATPlzen 1-CZ
# 42    1.0         Eindhoven-Noord-NLBrüssel-BE
#
#                                     Second  Capacity_x  Capacity_y
# 0                        Poznań-PLMalmö-SE      9000.0     16764.0
# 1                        Zagreb-HRSofia-BG      9000.0      9000.0
# 2                        Zagreb-HRSofia-BG      9000.0      9000.0
# 3                        Zagreb-HRSofia-BG      9000.0      9000.0
# 4                        Zagreb-HRSofia-BG      9000.0      9000.0
# 5                        Zagreb-HRSofia-BG      9000.0      9000.0
# 6                        Zagreb-HRSpata-GR      9000.0      9000.0
# 7                        Zagreb-HRSpata-GR      9000.0      9000.0
# 8                        Zagreb-HRSpata-GR      9000.0      9000.0
# 9     Hall in Tirol-ATIvanka pri Dunaji-SK      9000.0      9000.0
# 10           PZ 50 (Köln)-DEHelsingborg-SE       160.0       160.0
# 11                   Ljubljana-SIOradea-RO      9000.0      9000.0
# 12                   Ljubljana-SIOradea-RO      9000.0      9000.0
# 13             Ljubljana-SIBudapest OLK-HU      9000.0      9000.0
# 14                      Poznań-PLKaunas-LT      9000.0      9000.0
# 15                      Poznań-PLKaunas-LT      9000.0      9000.0
# 16                 Budapest OLK-HUSofia-BG      9000.0      9000.0
# 17                 Budapest OLK-HUSofia-BG      9000.0      9000.0
# 18                     Brüssel-BEPoznań-PL      9000.0      9000.0
# 19                    Brüssel-BEKolding-DK      9000.0      9000.0
# 20               Hagenbrunn-ATLjubljana-SI      9000.0      9000.0
# 21             Araba (Vitoria)-ESLisboa-PT      9000.0      9000.0
# 22             Araba (Vitoria)-ESLisboa-PT      9000.0      9000.0
# 23             Araba (Vitoria)-ESLisboa-PT     50288.0      9000.0
# 24      Araba (Vitoria)-ESLieto (Turku)-FL     16764.0      9000.0
# 25    Araba (Vitoria)-ESEindhoven-Noord-NL     16764.0      9000.0
# 26             Araba (Vitoria)-ESDublin-IE     16764.0      9000.0
# 27             Araba (Vitoria)-ESSlough-GB     16764.0     33524.0
# 28              Kolding-DKLieto (Turku)-FL      9000.0      9000.0
# 29              Kolding-DKLieto (Turku)-FL      9000.0      9000.0
# 30              Kolding-DKLieto (Turku)-FL      9000.0      9000.0
# 31             Eindhoven-Noord-NLLisboa-PT     16764.0     33524.0
# 32             Eindhoven-Noord-NLLisboa-PT    117336.0     33524.0
# 33             Eindhoven-Noord-NLDublin-IE     16764.0     33524.0
# 34                Budapest OLK-HUOradea-RO      9000.0      9000.0
# 35                      Brüssel-BESpata-GR     16764.0      9000.0
# 36                     Brüssel-BEDublin-IE     33524.0     16764.0
# 37             Eindhoven-Noord-NLSlough-GB    117336.0    109572.0
# 38             PZ 77 (Lahr)-DEBarcelona-ES     42524.0     50288.0
# 39    Eindhoven-Noord-NLPZ 47 (Krefeld)-DE    536384.0    486156.0
# 40  Krupka 1-CZPZ 04 (Radefeld/Leipzig)-DE    787816.0    787908.0
# 41         Plzen 1-CZPZ 93 (Regensburg)-DE    938784.0   1139952.0
# 42            Brüssel-BEPZ 47 (Krefeld)-DE   1433940.0   1525524.0

# %%
Z["NL", "GB"]
# Out:
# 35554

# %% [markdown]
# ## Checking if some routes exist

# %%
("FR","ES") in mk_all
# Out:
# True

# %%
'''
solution = model.getAttr('x_', X_)
print(solution[("HU", "AT","BE")])

solution_dir = model.getAttr('x_', X)
solution_dir[("AT","BE")]
'''
# Out:
# '\nsolution = model.getAttr(\'x_\', X_)\nprint(solution[("HU", "AT","BE")])\n\nsolution_dir = model.getAttr(\'x_\', X)\nsolution_dir[("AT","BE")]\n'

# %%
Freq["Ori_C"] = Freq.apply(lambda row: row.Ori_Hub.rsplit("-")[-1], axis = 1)
Freq["Dest_C"] = Freq.apply(lambda row: row.Dest_Hub.rsplit("-")[-1], axis = 1)
Freq[Freq.Taken > 0]
# Out:
#                            Ori_Hub                     Dest_Hub  \
# 38                       Kaunas-LT                    Poznań-PL
# 531                      Lisboa-PT           Araba (Vitoria)-ES
# 633                   Ljubljana-SI                    Oradea-RO
# 648                   Ljubljana-SI              Budapest OLK-HU
# 758             Araba (Vitoria)-ES                    Lisboa-PT
# 1763               Budapest OLK-HU                     Sofia-BG
# 1803               Budapest OLK-HU                    Oradea-RO
# 2533                 Hagenbrunn-AT                 Ljubljana-SI
# 2823              Hall in Tirol-AT         Ivanka pri Dunaji-SK
# 3671            Eindhoven-Noord-NL                   Brüssel-BE
# 3673            Eindhoven-Noord-NL                   Brüssel-BE
# 5208                    Kolding-DK             Lieto (Turku)-FL
# 5568                     Zagreb-HR                     Sofia-BG
# 5623                     Zagreb-HR                     Spata-GR
# 7653                      Sofia-BG         Vantaa (Helsinki)-FL
# 7668                      Sofia-BG                    Lisboa-PT
# 7673                     Lisboa-PT                 Ljubljana-SI
# 7678                  Ljubljana-SI                   Brüssel-BE
# 7693                  Ljubljana-SI                    Zabrze-PL
# 7713                      Sofia-BG                    Kaunas-LT
# 7783                    Brüssel-BE                 Ljubljana-SI
# 7789                      Sofia-BG                Hub Wien I-AT
# 7848                    Ostrava-CZ                    Kaunas-LT
# 7883                    Brüssel-BE                     Spata-GR
# 7888                  Barcelona-ES                   Kolding-DK
# 7903                  Barcelona-ES                    Kaunas-LT
# 7933                    Ostrava-CZ         Vantaa (Helsinki)-FL
# 7998                    Brüssel-BE                    Zagreb-HR
# 8093         PZ 15 (Rüdersdorf)-DE                    Kaunas-LT
# 8108                     Lisboa-PT               Bettembourg-LU
# 8144            PZ 21 (Hamburg)-DE                      Oslo-NO
# 8288            PZ 47 (Krefeld)-DE                    Dublin-IE
# 8323                     Lisboa-PT                    Zagreb-HR
# 8348            Araba (Vitoria)-ES             Lieto (Turku)-FL
# 8363                    Brüssel-BE         Ivanka pri Dunaji-SK
# 8368               Budapest OLK-HU               Bettembourg-LU
# 8388                      Sofia-BG                 Barcelona-ES
# 8418                     Lisboa-PT                   Plzen 1-CZ
# 8583                    Brüssel-BE                   Plzen 1-CZ
# 8633         PZ 93 (Regensburg)-DE                    Zagreb-HR
# 8748                   Krupka 1-CZ                     Malmö-SE
# 8878                  Barcelona-ES               Bettembourg-LU
# 8893                  Ljubljana-SI           Eindhoven-Noord-NL
# 8923                      Malmö-SE                    Oradea-RO
# 8998                       Wals-AT           Eindhoven-Noord-NL
# 9038                    Brüssel-BE              Budapest OLK-HU
# 9048              Lieto (Turku)-FL               Bettembourg-LU
# 9069                  Barcelona-ES               Helsingborg-SE
# 9168                      Malmö-SE                 Ljubljana-SI
# 9173                  Barcelona-ES              Budapest OLK-HU
# ...                            ...                          ...
# 15488  PZ 04 (Radefeld/Leipzig)-DE                  Krupka 1-CZ
# 15976                     Malmö-SE                   Kolding-DK
# 15980           Eindhoven-Noord-NL                    Slough-GB
# 15983           Eindhoven-Noord-NL                    Slough-GB
# 16039              PZ 50 (Köln)-DE               Helsingborg-SE
# 16170           PZ 21 (Hamburg)-DE                     Malmö-SE
# 16174           PZ 21 (Hamburg)-DE                     Malmö-SE
# 16450                Hagenbrunn-AT                    Zabrze-PL
# 16451                Hagenbrunn-AT                    Zabrze-PL
# 16780           Eindhoven-Noord-NL           Araba (Vitoria)-ES
# 16783           Eindhoven-Noord-NL           Araba (Vitoria)-ES
# 16851           PZ 47 (Krefeld)-DE                   Brüssel-BE
# 16870                   Brüssel-BE                    Slough-GB
# 16871                   Brüssel-BE                    Slough-GB
# 16890                    Slough-GB           Araba (Vitoria)-ES
# 16891                    Slough-GB           Araba (Vitoria)-ES
# 17220                     Malmö-SE           PZ 21 (Hamburg)-DE
# 17221                     Malmö-SE           PZ 21 (Hamburg)-DE
# 17270     Stockholm - Västberga-SE             Lieto (Turku)-FL
# 17310           Eindhoven-Noord-NL            Combs la ville-FR
# 17320                    Slough-GB           Eindhoven-Noord-NL
# 17375           Eindhoven-Noord-NL                      Wals-AT
# 17491                   Ostrava-CZ                    Zabrze-PL
# 17493                   Ostrava-CZ                    Zabrze-PL
# 17945                     Malmö-SE                      Wals-AT
# 18361        PZ 15 (Rüdersdorf)-DE                    Poznań-PL
# 18496                   Brüssel-BE           PZ 47 (Krefeld)-DE
# 18826        PZ 93 (Regensburg)-DE                      Wals-AT
# 19285                  Göteborg-SE                      Oslo-NO
# 19330                 Barcelona-ES              PZ 77 (Lahr)-DE
# 19525              PZ 50 (Köln)-DE            Combs la ville-FR
# 19611                    Zabrze-PL           Zilina- Strecno-SK
# 19750           PZ 47 (Krefeld)-DE                    Slough-GB
# 19751           PZ 47 (Krefeld)-DE                    Slough-GB
# 19795             Lieto (Turku)-FL     Stockholm - Västberga-SE
# 19796             Lieto (Turku)-FL     Stockholm - Västberga-SE
# 19926                    Zabrze-PL                   Ostrava-CZ
# 20010                   Wrocław-PL                  Krupka 1-CZ
# 20011                   Wrocław-PL                  Krupka 1-CZ
# 20201                Hagenbrunn-AT                      Brno-CZ
# 20296                      Enns-AT                   Plzen 1-CZ
# 20671                  Krupka 1-CZ  PZ 04 (Radefeld/Leipzig)-DE
# 20756                   Plzen 1-CZ        PZ 93 (Regensburg)-DE
# 21086           Zilina- Strecno-SK                   Ostrava-CZ
# 21088           Zilina- Strecno-SK                   Ostrava-CZ
# 21261           PZ 47 (Krefeld)-DE           Eindhoven-Noord-NL
# 21263           PZ 47 (Krefeld)-DE           Eindhoven-Noord-NL
# 21740                   Wrocław-PL              PZ 77 (Lahr)-DE
# 21743                   Wrocław-PL              PZ 77 (Lahr)-DE
# 22681           Eindhoven-Noord-NL           PZ 47 (Krefeld)-DE
#
#           Truck Type  Taken Ori_C Dest_C
# 38               Van    1.0    LT     PL
# 531        Swap Body    1.0    PT     ES
# 633              Van    1.0    SI     RO
# 648              Van    1.0    SI     HU
# 758              Van    1.0    ES     PT
# 1763             Van    1.0    HU     BG
# 1803             Van    1.0    HU     RO
# 2533             Van    1.0    AT     SI
# 2823             Van    1.0    AT     SK
# 3671       Swap Body   85.0    NL     BE
# 3673             Van    1.0    NL     BE
# 5208             Van    1.0    DK     FL
# 5568             Van    1.0    HR     BG
# 5623             Van    1.0    HR     GR
# 7653             Van    1.0    BG     FL
# 7668             Van    1.0    BG     PT
# 7673             Van    1.0    PT     SI
# 7678             Van    1.0    SI     BE
# 7693             Van    1.0    SI     PL
# 7713             Van    1.0    BG     LT
# 7783             Van    1.0    BE     SI
# 7789      Co-loading    1.0    BG     AT
# 7848             Van    1.0    CZ     LT
# 7883             Van    1.0    BE     GR
# 7888             Van    1.0    ES     DK
# 7903             Van    1.0    ES     LT
# 7933             Van    1.0    CZ     FL
# 7998             Van    1.0    BE     HR
# 8093             Van    1.0    DE     LT
# 8108             Van    1.0    PT     LU
# 8144      Co-loading    1.0    DE     NO
# 8288             Van    1.0    DE     IE
# 8323             Van    1.0    PT     HR
# 8348             Van    1.0    ES     FL
# 8363             Van    1.0    BE     SK
# 8368             Van    1.0    HU     LU
# 8388             Van    1.0    BG     ES
# 8418             Van    1.0    PT     CZ
# 8583             Van    1.0    BE     CZ
# 8633             Van    1.0    DE     HR
# 8748             Van    1.0    CZ     SE
# 8878             Van    1.0    ES     LU
# 8893             Van    1.0    SI     NL
# 8923             Van    1.0    SE     RO
# 8998             Van    1.0    AT     NL
# 9038             Van    1.0    BE     HU
# 9048             Van    1.0    FL     LU
# 9069      Co-loading    2.0    ES     SE
# 9168             Van    1.0    SE     SI
# 9173             Van    1.0    ES     HU
# ...              ...    ...   ...    ...
# 15488            Van    1.0    DE     CZ
# 15976      Swap Body    3.0    SE     DK
# 15980  2 Swap Bodies    3.0    NL     GB
# 15983            Van    1.0    NL     GB
# 16039     Co-loading    1.0    DE     SE
# 16170  2 Swap Bodies    1.0    DE     SE
# 16174     Co-loading   13.0    DE     SE
# 16450  2 Swap Bodies    1.0    AT     PL
# 16451      Swap Body    1.0    AT     PL
# 16780  2 Swap Bodies    1.0    NL     ES
# 16783            Van    1.0    NL     ES
# 16851      Swap Body    3.0    DE     BE
# 16870  2 Swap Bodies    1.0    BE     GB
# 16871      Swap Body    1.0    BE     GB
# 16890  2 Swap Bodies    1.0    GB     ES
# 16891      Swap Body    1.0    GB     ES
# 17220  2 Swap Bodies    1.0    SE     DE
# 17221      Swap Body    1.0    SE     DE
# 17270  2 Swap Bodies    2.0    SE     FL
# 17310  2 Swap Bodies    2.0    NL     FR
# 17320  2 Swap Bodies   16.0    GB     NL
# 17375  2 Swap Bodies    2.0    NL     AT
# 17491      Swap Body    4.0    CZ     PL
# 17493            Van    1.0    CZ     PL
# 17945  2 Swap Bodies    2.0    SE     AT
# 18361      Swap Body    5.0    DE     PL
# 18496      Swap Body   91.0    BE     DE
# 18826      Swap Body    6.0    DE     AT
# 19285  2 Swap Bodies    3.0    SE     NO
# 19330  2 Swap Bodies    3.0    ES     DE
# 19525  2 Swap Bodies    3.0    DE     FR
# 19611      Swap Body    6.0    PL     SK
# 19750  2 Swap Bodies    3.0    DE     GB
# 19751      Swap Body    1.0    DE     GB
# 19795  2 Swap Bodies    3.0    FL     SE
# 19796      Swap Body    1.0    FL     SE
# 19926      Swap Body    8.0    PL     CZ
# 20010  2 Swap Bodies   23.0    PL     CZ
# 20011      Swap Body    1.0    PL     CZ
# 20201      Swap Body    9.0    AT     CZ
# 20296      Swap Body   56.0    AT     CZ
# 20671      Swap Body   47.0    CZ     DE
# 20756      Swap Body   68.0    CZ     DE
# 21086      Swap Body   12.0    SK     CZ
# 21088            Van    1.0    SK     CZ
# 21261      Swap Body   17.0    DE     NL
# 21263            Van    1.0    DE     NL
# 21740  2 Swap Bodies    1.0    PL     DE
# 21743            Van    1.0    PL     DE
# 22681      Swap Body   29.0    NL     DE
#
# [209 rows x 6 columns]

# %%
Freq.loc[(Freq["Ori_C"] == "BE") & (Freq["Dest_C"] == "DE"), :]
# Out:
#           Ori_Hub                     Dest_Hub     Truck Type  Taken Ori_C  \
# 18445  Brüssel-BE            PZ 67 (Speyer)-DE  2 Swap Bodies   -0.0    BE
# 18446  Brüssel-BE            PZ 67 (Speyer)-DE      Swap Body   -0.0    BE
# 18447  Brüssel-BE            PZ 67 (Speyer)-DE        Trailer   -0.0    BE
# 18448  Brüssel-BE            PZ 67 (Speyer)-DE            Van   -0.0    BE
# 18449  Brüssel-BE            PZ 67 (Speyer)-DE     Co-loading   -0.0    BE
# 18450  Brüssel-BE              PZ 50 (Köln)-DE  2 Swap Bodies    0.0    BE
# 18451  Brüssel-BE              PZ 50 (Köln)-DE      Swap Body    0.0    BE
# 18452  Brüssel-BE              PZ 50 (Köln)-DE        Trailer   -0.0    BE
# 18453  Brüssel-BE              PZ 50 (Köln)-DE            Van    0.0    BE
# 18454  Brüssel-BE              PZ 50 (Köln)-DE     Co-loading   -0.0    BE
# 18455  Brüssel-BE  PZ 04 (Radefeld/Leipzig)-DE  2 Swap Bodies   -0.0    BE
# 18456  Brüssel-BE  PZ 04 (Radefeld/Leipzig)-DE      Swap Body   -0.0    BE
# 18457  Brüssel-BE  PZ 04 (Radefeld/Leipzig)-DE        Trailer   -0.0    BE
# 18458  Brüssel-BE  PZ 04 (Radefeld/Leipzig)-DE            Van   -0.0    BE
# 18459  Brüssel-BE  PZ 04 (Radefeld/Leipzig)-DE     Co-loading   -0.0    BE
# 18460  Brüssel-BE   PZ 90 (Feucht/Nürnberg)-DE  2 Swap Bodies   -0.0    BE
# 18461  Brüssel-BE   PZ 90 (Feucht/Nürnberg)-DE      Swap Body   -0.0    BE
# 18462  Brüssel-BE   PZ 90 (Feucht/Nürnberg)-DE        Trailer   -0.0    BE
# 18463  Brüssel-BE   PZ 90 (Feucht/Nürnberg)-DE            Van   -0.0    BE
# 18464  Brüssel-BE   PZ 90 (Feucht/Nürnberg)-DE     Co-loading   -0.0    BE
# 18465  Brüssel-BE              PZ 77 (Lahr)-DE  2 Swap Bodies   -0.0    BE
# 18466  Brüssel-BE              PZ 77 (Lahr)-DE      Swap Body   -0.0    BE
# 18467  Brüssel-BE              PZ 77 (Lahr)-DE        Trailer   -0.0    BE
# 18468  Brüssel-BE              PZ 77 (Lahr)-DE            Van   -0.0    BE
# 18469  Brüssel-BE              PZ 77 (Lahr)-DE     Co-loading   -0.0    BE
# 18470  Brüssel-BE        PZ 93 (Regensburg)-DE  2 Swap Bodies   -0.0    BE
# 18471  Brüssel-BE        PZ 93 (Regensburg)-DE      Swap Body   -0.0    BE
# 18472  Brüssel-BE        PZ 93 (Regensburg)-DE        Trailer   -0.0    BE
# 18473  Brüssel-BE        PZ 93 (Regensburg)-DE            Van   -0.0    BE
# 18474  Brüssel-BE        PZ 93 (Regensburg)-DE     Co-loading   -0.0    BE
# 18475  Brüssel-BE           PZ 21 (Hamburg)-DE  2 Swap Bodies   -0.0    BE
# 18476  Brüssel-BE           PZ 21 (Hamburg)-DE      Swap Body   -0.0    BE
# 18477  Brüssel-BE           PZ 21 (Hamburg)-DE        Trailer   -0.0    BE
# 18478  Brüssel-BE           PZ 21 (Hamburg)-DE            Van   -0.0    BE
# 18479  Brüssel-BE           PZ 21 (Hamburg)-DE     Co-loading   -0.0    BE
# 18480  Brüssel-BE           PZ 46 (Dorsten)-DE  2 Swap Bodies   -0.0    BE
# 18481  Brüssel-BE           PZ 46 (Dorsten)-DE      Swap Body   -0.0    BE
# 18482  Brüssel-BE           PZ 46 (Dorsten)-DE        Trailer   -0.0    BE
# 18483  Brüssel-BE           PZ 46 (Dorsten)-DE            Van   -0.0    BE
# 18484  Brüssel-BE           PZ 46 (Dorsten)-DE     Co-loading   -0.0    BE
# 18485  Brüssel-BE             PZ 58 (Hagen)-DE  2 Swap Bodies    0.0    BE
# 18486  Brüssel-BE             PZ 58 (Hagen)-DE      Swap Body    0.0    BE
# 18487  Brüssel-BE             PZ 58 (Hagen)-DE        Trailer   -0.0    BE
# 18488  Brüssel-BE             PZ 58 (Hagen)-DE            Van    0.0    BE
# 18489  Brüssel-BE             PZ 58 (Hagen)-DE     Co-loading   -0.0    BE
# 18490  Brüssel-BE           PZ 08 (Neumark)-DE  2 Swap Bodies   -0.0    BE
# 18491  Brüssel-BE           PZ 08 (Neumark)-DE      Swap Body   -0.0    BE
# 18492  Brüssel-BE           PZ 08 (Neumark)-DE        Trailer   -0.0    BE
# 18493  Brüssel-BE           PZ 08 (Neumark)-DE            Van   -0.0    BE
# 18494  Brüssel-BE           PZ 08 (Neumark)-DE     Co-loading   -0.0    BE
# 18495  Brüssel-BE           PZ 47 (Krefeld)-DE  2 Swap Bodies    0.0    BE
# 18496  Brüssel-BE           PZ 47 (Krefeld)-DE      Swap Body   91.0    BE
# 18497  Brüssel-BE           PZ 47 (Krefeld)-DE        Trailer   -0.0    BE
# 18498  Brüssel-BE           PZ 47 (Krefeld)-DE            Van    0.0    BE
# 18499  Brüssel-BE           PZ 47 (Krefeld)-DE     Co-loading   -0.0    BE
# 18500  Brüssel-BE        PZ 15 (Rüdersdorf)-DE  2 Swap Bodies   -0.0    BE
# 18501  Brüssel-BE        PZ 15 (Rüdersdorf)-DE      Swap Body   -0.0    BE
# 18502  Brüssel-BE        PZ 15 (Rüdersdorf)-DE        Trailer   -0.0    BE
# 18503  Brüssel-BE        PZ 15 (Rüdersdorf)-DE            Van   -0.0    BE
# 18504  Brüssel-BE        PZ 15 (Rüdersdorf)-DE     Co-loading   -0.0    BE
# 18505  Brüssel-BE        PZ 24 (Neumünster)-DE  2 Swap Bodies   -0.0    BE
# 18506  Brüssel-BE        PZ 24 (Neumünster)-DE      Swap Body   -0.0    BE
# 18507  Brüssel-BE        PZ 24 (Neumünster)-DE        Trailer   -0.0    BE
# 18508  Brüssel-BE        PZ 24 (Neumünster)-DE            Van   -0.0    BE
# 18509  Brüssel-BE        PZ 24 (Neumünster)-DE     Co-loading   -0.0    BE
# 18510  Brüssel-BE   PZ 44 (Bochum) [im Bau]-DE  2 Swap Bodies   -0.0    BE
# 18511  Brüssel-BE   PZ 44 (Bochum) [im Bau]-DE      Swap Body   -0.0    BE
# 18512  Brüssel-BE   PZ 44 (Bochum) [im Bau]-DE        Trailer   -0.0    BE
# 18513  Brüssel-BE   PZ 44 (Bochum) [im Bau]-DE            Van   -0.0    BE
# 18514  Brüssel-BE   PZ 44 (Bochum) [im Bau]-DE     Co-loading   -0.0    BE
#
#       Dest_C
# 18445     DE
# 18446     DE
# 18447     DE
# 18448     DE
# 18449     DE
# 18450     DE
# 18451     DE
# 18452     DE
# 18453     DE
# 18454     DE
# 18455     DE
# 18456     DE
# 18457     DE
# 18458     DE
# 18459     DE
# 18460     DE
# 18461     DE
# 18462     DE
# 18463     DE
# 18464     DE
# 18465     DE
# 18466     DE
# 18467     DE
# 18468     DE
# 18469     DE
# 18470     DE
# 18471     DE
# 18472     DE
# 18473     DE
# 18474     DE
# 18475     DE
# 18476     DE
# 18477     DE
# 18478     DE
# 18479     DE
# 18480     DE
# 18481     DE
# 18482     DE
# 18483     DE
# 18484     DE
# 18485     DE
# 18486     DE
# 18487     DE
# 18488     DE
# 18489     DE
# 18490     DE
# 18491     DE
# 18492     DE
# 18493     DE
# 18494     DE
# 18495     DE
# 18496     DE
# 18497     DE
# 18498     DE
# 18499     DE
# 18500     DE
# 18501     DE
# 18502     DE
# 18503     DE
# 18504     DE
# 18505     DE
# 18506     DE
# 18507     DE
# 18508     DE
# 18509     DE
# 18510     DE
# 18511     DE
# 18512     DE
# 18513     DE
# 18514     DE

# %% [markdown]
# # Check the relationship between Route Capacity and Demands

# %%
Route_Cap["Ori_C"] = Route_Cap.apply(lambda row: row.Ori_Hub.rsplit("-")[-1], axis = 1)
Route_Cap["Dest_C"] = Route_Cap.apply(lambda row: row.Dest_Hub.rsplit("-")[-1], axis = 1)
Route_Cap["Demands"] = Route_Cap.apply(lambda row: Z[row.Ori_C, row.Dest_C] if (row.Ori_C, row.Dest_C) in Z.keys() else 0, axis = 1)

# %%
# Route_Cap.loc[(Route_Cap["Ori_C"] == "DE") & (Route_Cap["Dest_C"] == "FL"), :]
Route_Cap[Route_Cap.Taken > 0]
# Out:
#                           Ori_Hub                     Dest_Hub      Taken  \
# 7                       Kaunas-LT                    Poznań-PL       14.0
# 106                     Lisboa-PT           Araba (Vitoria)-ES    13864.0
# 126                  Ljubljana-SI                    Oradea-RO      340.0
# 129                  Ljubljana-SI              Budapest OLK-HU       94.0
# 151            Araba (Vitoria)-ES                    Lisboa-PT     4713.0
# 352               Budapest OLK-HU                     Sofia-BG      259.0
# 360               Budapest OLK-HU                    Oradea-RO     1173.0
# 506                 Hagenbrunn-AT                 Ljubljana-SI      196.0
# 564              Hall in Tirol-AT         Ivanka pri Dunaji-SK       37.0
# 734            Eindhoven-Noord-NL                   Brüssel-BE  1433385.0
# 1041                   Kolding-DK             Lieto (Turku)-FL     5816.0
# 1113                    Zagreb-HR                     Sofia-BG     1381.0
# 1124                    Zagreb-HR                     Spata-GR      273.0
# 1530                     Sofia-BG         Vantaa (Helsinki)-FL       17.0
# 1533                     Sofia-BG                    Lisboa-PT       22.0
# 1534                    Lisboa-PT                 Ljubljana-SI      176.0
# 1535                 Ljubljana-SI                   Brüssel-BE       27.0
# 1538                 Ljubljana-SI                    Zabrze-PL       30.0
# 1542                     Sofia-BG                    Kaunas-LT       31.0
# 1556                   Brüssel-BE                 Ljubljana-SI       61.0
# 1557                     Sofia-BG                Hub Wien I-AT       61.0
# 1569                   Ostrava-CZ                    Kaunas-LT       64.0
# 1576                   Brüssel-BE                     Spata-GR     2008.0
# 1577                 Barcelona-ES                   Kolding-DK       75.0
# 1580                 Barcelona-ES                    Kaunas-LT       76.0
# 1586                   Ostrava-CZ         Vantaa (Helsinki)-FL       83.0
# 1599                   Brüssel-BE                    Zagreb-HR      105.0
# 1618        PZ 15 (Rüdersdorf)-DE                    Kaunas-LT       99.0
# 1621                    Lisboa-PT               Bettembourg-LU      107.0
# 1628           PZ 21 (Hamburg)-DE                      Oslo-NO      124.0
# 1657           PZ 47 (Krefeld)-DE                    Dublin-IE      134.0
# 1664                    Lisboa-PT                    Zagreb-HR      191.0
# 1669           Araba (Vitoria)-ES             Lieto (Turku)-FL      522.0
# 1672                   Brüssel-BE         Ivanka pri Dunaji-SK      143.0
# 1673              Budapest OLK-HU               Bettembourg-LU      157.0
# 1677                     Sofia-BG                 Barcelona-ES      175.0
# 1683                    Lisboa-PT                   Plzen 1-CZ      178.0
# 1716                   Brüssel-BE                   Plzen 1-CZ      199.0
# 1726        PZ 93 (Regensburg)-DE                    Zagreb-HR      389.0
# 1749                  Krupka 1-CZ                     Malmö-SE      211.0
# 1775                 Barcelona-ES               Bettembourg-LU      219.0
# 1778                 Ljubljana-SI           Eindhoven-Noord-NL      220.0
# 1784                     Malmö-SE                    Oradea-RO      256.0
# 1799                      Wals-AT           Eindhoven-Noord-NL      268.0
# 1807                   Brüssel-BE              Budapest OLK-HU      270.0
# 1809             Lieto (Turku)-FL               Bettembourg-LU      276.0
# 1813                 Barcelona-ES               Helsingborg-SE      282.0
# 1833                     Malmö-SE                 Ljubljana-SI      299.0
# 1834                 Barcelona-ES              Budapest OLK-HU      301.0
# 1849                     Malmö-SE         Ivanka pri Dunaji-SK      324.0
# ...                           ...                          ...        ...
# 2735                    Lisboa-PT              PZ 77 (Lahr)-DE    10770.0
# 2748             Suwałki (Ełk)-PL         Vantaa (Helsinki)-FL    11173.0
# 2760                    Poznań-PL                   Brüssel-BE    23501.0
# 2772                    Slough-GB                      Wals-AT    16210.0
# 2798        PZ 93 (Regensburg)-DE                 Ljubljana-SI    22360.0
# 2817        PZ 93 (Regensburg)-DE              Budapest OLK-HU    22426.0
# 2838                      Brno-CZ                Hagenbrunn-AT    22601.0
# 2934        PZ 93 (Regensburg)-DE         Ivanka pri Dunaji-SK    22870.0
# 2957             Lieto (Turku)-FL           PZ 21 (Hamburg)-DE    25037.0
# 2980           Eindhoven-Noord-NL                    Dublin-IE    26445.0
# 2985                    Poznań-PL           Eindhoven-Noord-NL   109915.0
# 2995                      Brno-CZ              Budapest OLK-HU    28440.0
# 3036                    Zabrze-PL                Hagenbrunn-AT    28959.0
# 3077                    Slough-GB            Combs la ville-FR    33992.0
# 3097  PZ 04 (Radefeld/Leipzig)-DE                  Krupka 1-CZ    34848.0
# 3195                     Malmö-SE                   Kolding-DK    35084.0
# 3196           Eindhoven-Noord-NL                    Slough-GB   103167.0
# 3207              PZ 50 (Köln)-DE               Helsingborg-SE       54.0
# 3234           PZ 21 (Hamburg)-DE                     Malmö-SE    35601.0
# 3290                Hagenbrunn-AT                    Zabrze-PL    37699.0
# 3356           Eindhoven-Noord-NL           Araba (Vitoria)-ES    38417.0
# 3370           PZ 47 (Krefeld)-DE                   Brüssel-BE    38721.0
# 3374                   Brüssel-BE                    Slough-GB    39911.0
# 3378                    Slough-GB           Araba (Vitoria)-ES    45765.0
# 3444                     Malmö-SE           PZ 21 (Hamburg)-DE    48234.0
# 3454     Stockholm - Västberga-SE             Lieto (Turku)-FL    50491.0
# 3462           Eindhoven-Noord-NL            Combs la ville-FR    50960.0
# 3464                    Slough-GB           Eindhoven-Noord-NL   532122.0
# 3475           Eindhoven-Noord-NL                      Wals-AT    61227.0
# 3498                   Ostrava-CZ                    Zabrze-PL    61940.0
# 3589                     Malmö-SE                      Wals-AT    63353.0
# 3672        PZ 15 (Rüdersdorf)-DE                    Poznań-PL    75854.0
# 3699                   Brüssel-BE           PZ 47 (Krefeld)-DE  1518705.0
# 3765        PZ 93 (Regensburg)-DE                      Wals-AT    89665.0
# 3857                  Göteborg-SE                      Oslo-NO    92346.0
# 3866                 Barcelona-ES              PZ 77 (Lahr)-DE    94403.0
# 3905              PZ 50 (Köln)-DE            Combs la ville-FR    96813.0
# 3922                    Zabrze-PL           Zilina- Strecno-SK    98453.0
# 3950           PZ 47 (Krefeld)-DE                    Slough-GB   100659.0
# 3959             Lieto (Turku)-FL     Stockholm - Västberga-SE   116234.0
# 3985                    Zabrze-PL                   Ostrava-CZ   128337.0
# 4002                   Wrocław-PL                  Krupka 1-CZ   777502.0
# 4040                Hagenbrunn-AT                      Brno-CZ   146713.0
# 4059                      Enns-AT                   Plzen 1-CZ   932495.0
# 4134                  Krupka 1-CZ  PZ 04 (Radefeld/Leipzig)-DE   777502.0
# 4151                   Plzen 1-CZ        PZ 93 (Regensburg)-DE  1131598.0
# 4217           Zilina- Strecno-SK                   Ostrava-CZ   201434.0
# 4252           PZ 47 (Krefeld)-DE           Eindhoven-Noord-NL   280731.0
# 4348                   Wrocław-PL              PZ 77 (Lahr)-DE    37736.0
# 4536           Eindhoven-Noord-NL           PZ 47 (Krefeld)-DE   471880.0
#
#      Ori_C Dest_C  Demands
# 7       LT     PL        0
# 106     PT     ES        0
# 126     SI     RO        0
# 129     SI     HU        0
# 151     ES     PT        0
# 352     HU     BG        0
# 360     HU     RO        0
# 506     AT     SI        0
# 564     AT     SK        0
# 734     NL     BE        0
# 1041    DK     FL        0
# 1113    HR     BG        0
# 1124    HR     GR        0
# 1530    BG     FL       17
# 1533    BG     PT       22
# 1534    PT     SI       26
# 1535    SI     BE       27
# 1538    SI     PL       30
# 1542    BG     LT       31
# 1556    BE     SI       61
# 1557    BG     AT       61
# 1569    CZ     LT       64
# 1576    BE     GR       71
# 1577    ES     DK       75
# 1580    ES     LT       76
# 1586    CZ     FL       83
# 1599    BE     HR       83
# 1618    DE     LT       99
# 1621    PT     LU      107
# 1628    DE     NO      124
# 1657    DE     IE      134
# 1664    PT     HR      134
# 1669    ES     FL      138
# 1672    BE     SK      143
# 1673    HU     LU      157
# 1677    BG     ES      175
# 1683    PT     CZ      178
# 1716    BE     CZ      199
# 1726    DE     HR      209
# 1749    CZ     SE      211
# 1775    ES     LU      219
# 1778    SI     NL      220
# 1784    SE     RO      256
# 1799    AT     NL      268
# 1807    BE     HU      270
# 1809    FL     LU      276
# 1813    ES     SE      282
# 1833    SE     SI      299
# 1834    ES     HU      301
# 1849    SE     SK      324
# ...    ...    ...      ...
# 2735    PT     DE    10770
# 2748    PL     FL    11173
# 2760    PL     BE    12766
# 2772    GB     AT    16210
# 2798    DE     SI    22360
# 2817    DE     HU    22426
# 2838    CZ     AT    22601
# 2934    DE     SK    22870
# 2957    FL     DE    25037
# 2980    NL     IE    25330
# 2985    PL     NL    25913
# 2995    CZ     HU    28440
# 3036    PL     AT    28959
# 3077    GB     FR    33992
# 3097    DE     CZ    34848
# 3195    SE     DK    35084
# 3196    NL     GB    35554
# 3207    DE     SE    35601
# 3234    DE     SE    35601
# 3290    AT     PL    37699
# 3356    NL     ES    38417
# 3370    DE     BE    38721
# 3374    BE     GB    39911
# 3378    GB     ES    41968
# 3444    SE     DE    48234
# 3454    SE     FL    50491
# 3462    NL     FR    50960
# 3464    GB     NL    60242
# 3475    NL     AT    61227
# 3498    CZ     PL    61940
# 3589    SE     AT    63353
# 3672    DE     PL    75854
# 3699    BE     DE    85320
# 3765    DE     AT    89665
# 3857    SE     NO    92346
# 3866    ES     DE    94403
# 3905    DE     FR    96813
# 3922    PL     SK    98453
# 3950    DE     GB   100659
# 3959    FL     SE   116234
# 3985    PL     CZ   128337
# 4002    PL     CZ   128337
# 4040    AT     CZ   146713
# 4059    AT     CZ   146713
# 4134    CZ     DE   199103
# 4151    CZ     DE   199103
# 4217    SK     CZ   201434
# 4252    DE     NL   280731
# 4348    PL     DE   777502
# 4536    NL     DE  1433385
#
# [190 rows x 6 columns]

# %%
Route_Cap.loc[(Route_Cap["Ori_C"] == "BE") & (Route_Cap["Dest_C"] == "NL"), :]
# Out:
#         Ori_Hub            Dest_Hub  Taken Ori_C Dest_C  Demands
# 111  Brüssel-BE  Eindhoven-Noord-NL   -0.0    BE     NL        0
# 112  Brüssel-BE       Zaltbommel-NL   -0.0    BE     NL        0

# %%
Z["BE", "AT"]
# Out:
# 5943

# %%
("NL", "AT") in mk_all
# Out:
# True

# %%
ind_hubs = model.getAttr('x', x_)
d_hubs = model.getAttr('x', x)

capacity_from_freq_by_hub = Freq_result.groupby(["Ori_Hub", "Dest_Hub"]).sum()
capacity_from_freq_by_hub.reset_index(inplace = True)
capacity_from_freq_by_hub.loc[:, "Clustering"] = 0

for row in capacity_from_freq_by_hub.index:
    ori = capacity_from_freq_by_hub.loc[row, "Ori_Hub"]
    dest = capacity_from_freq_by_hub.loc[row, "Dest_Hub"]
    
    try:
        ind_1 = sum(ind_hubs[p, q, i] for p, q, i in piq.select(ori, dest, "*"))
    except:
        ind_1 = 0
        
    try:
        ind_2 = sum(ind_hubs[i, p, q] for i, p, q in piq.select("*", ori, dest))
    except:
        ind_2 = 0
        
    try:
        d_1 = d_hubs[ori, dest]
        
    except:
        d_1 = 0
    
        
    capacity_from_freq_by_hub.loc[row, "Clustering"] = ind_1 + ind_2 + d_1
    
capacity_from_freq_by_hub
# Out:
#                       Ori_Hub               Dest_Hub  Taken   Capacity  \
# 0          Araba (Vitoria)-ES             Brüssel-BE    1.0     9000.0
# 1          Araba (Vitoria)-ES              Dublin-IE    1.0     9000.0
# 2          Araba (Vitoria)-ES     Eindhoven-Noord-NL    1.0     9000.0
# 3          Araba (Vitoria)-ES       Lieto (Turku)-FL    1.0     9000.0
# 4          Araba (Vitoria)-ES              Lisboa-PT    1.0     9000.0
# 5          Araba (Vitoria)-ES              Slough-GB    1.0    33524.0
# 6                Barcelona-ES         Bettembourg-LU    1.0     9000.0
# 7                Barcelona-ES        Budapest OLK-HU    1.0     9000.0
# 8                Barcelona-ES       Hall in Tirol-AT    1.0     9000.0
# 9                Barcelona-ES         Helsingborg-SE    2.0      320.0
# 10               Barcelona-ES   Ivanka pri Dunaji-SK    1.0     9000.0
# 11               Barcelona-ES              Kaunas-LT    1.0     9000.0
# 12               Barcelona-ES             Kolding-DK    1.0     9000.0
# 13               Barcelona-ES           Ljubljana-SI    1.0     9000.0
# 14               Barcelona-ES        PZ 77 (Lahr)-DE    3.0   100572.0
# 15               Barcelona-ES             Plzen 1-CZ    1.0     9000.0
# 16               Barcelona-ES             Wrocław-PL    1.0     9000.0
# 17               Barcelona-ES              Zagreb-HR    1.0     9000.0
# 18                    Brno-CZ        Budapest OLK-HU    1.0    33524.0
# 19                    Brno-CZ          Hagenbrunn-AT    2.0    33528.0
# 20                 Brüssel-BE     Araba (Vitoria)-ES    1.0     9000.0
# 21                 Brüssel-BE        Budapest OLK-HU    1.0     9000.0
# 22                 Brüssel-BE      Combs la ville-FR    1.0     9000.0
# 23                 Brüssel-BE              Dublin-IE    1.0    16764.0
# 24                 Brüssel-BE   Ivanka pri Dunaji-SK    1.0     9000.0
# 25                 Brüssel-BE             Kolding-DK    1.0     9000.0
# 26                 Brüssel-BE           Ljubljana-SI    1.0     9000.0
# 27                 Brüssel-BE               Malmö-SE    1.0     9000.0
# 28                 Brüssel-BE     PZ 47 (Krefeld)-DE   91.0  1525524.0
# 29                 Brüssel-BE             Plzen 1-CZ    1.0     9000.0
# 30                 Brüssel-BE              Poznań-PL    1.0     9000.0
# 31                 Brüssel-BE              Slough-GB    2.0    50288.0
# 32                 Brüssel-BE               Spata-GR    1.0     9000.0
# 33                 Brüssel-BE                Wals-AT    1.0     9000.0
# 34                 Brüssel-BE              Zagreb-HR    1.0     9000.0
# 35            Budapest OLK-HU         Bettembourg-LU    1.0     9000.0
# 36            Budapest OLK-HU                Brno-CZ    1.0     9000.0
# 37            Budapest OLK-HU             Brüssel-BE    1.0     9000.0
# 38            Budapest OLK-HU     Eindhoven-Noord-NL    1.0     9000.0
# 39            Budapest OLK-HU   Ivanka pri Dunaji-SK    1.0     9000.0
# 40            Budapest OLK-HU             Liesing-AT    1.0     9000.0
# 41            Budapest OLK-HU           Ljubljana-SI    1.0     9000.0
# 42            Budapest OLK-HU              Oradea-RO    1.0     9000.0
# 43            Budapest OLK-HU  PZ 93 (Regensburg)-DE    1.0    16764.0
# 44            Budapest OLK-HU               Sofia-BG    1.0     9000.0
# 45            Budapest OLK-HU              Zabrze-PL    1.0     9000.0
# 46         Eindhoven-Noord-NL     Araba (Vitoria)-ES    2.0    42524.0
# 47         Eindhoven-Noord-NL             Brüssel-BE   86.0  1433940.0
# 48         Eindhoven-Noord-NL        Budapest OLK-HU    1.0     9000.0
# 49         Eindhoven-Noord-NL      Combs la ville-FR    2.0    67048.0
# ..                        ...                    ...    ...        ...
# 140                Plzen 1-CZ  PZ 93 (Regensburg)-DE   68.0  1139952.0
# 141                 Poznań-PL             Brüssel-BE    1.0    33524.0
# 142                 Poznań-PL     Eindhoven-Noord-NL    4.0   117336.0
# 143                 Poznań-PL              Kaunas-LT    1.0     9000.0
# 144                 Poznań-PL             Kolding-DK    1.0     9000.0
# 145                 Poznań-PL               Malmö-SE    1.0    16764.0
# 146                 Slough-GB     Araba (Vitoria)-ES    2.0    50288.0
# 147                 Slough-GB         Bettembourg-LU    1.0     9000.0
# 148                 Slough-GB             Brüssel-BE    1.0    16764.0
# 149                 Slough-GB        Budapest OLK-HU    1.0     9000.0
# 150                 Slough-GB      Combs la ville-FR    2.0    42524.0
# 151                 Slough-GB     Eindhoven-Noord-NL   16.0   536384.0
# 152                 Slough-GB   Ivanka pri Dunaji-SK    1.0     9000.0
# 153                 Slough-GB             Kolding-DK    1.0     9000.0
# 154                 Slough-GB           Ljubljana-SI    1.0     9000.0
# 155                 Slough-GB             Plzen 1-CZ    1.0     9000.0
# 156                 Slough-GB              Poznań-PL    1.0     9000.0
# 157                 Slough-GB                Wals-AT    1.0    16764.0
# 158                 Slough-GB              Zagreb-HR    1.0     9000.0
# 159                  Sofia-BG           Barcelona-ES    1.0     9000.0
# 160                  Sofia-BG          Hub Wien I-AT    1.0      160.0
# 161                  Sofia-BG              Kaunas-LT    1.0     9000.0
# 162                  Sofia-BG              Lisboa-PT    1.0     9000.0
# 163                  Sofia-BG  PZ 93 (Regensburg)-DE    1.0     9000.0
# 164                  Sofia-BG   Vantaa (Helsinki)-FL    1.0     9000.0
# 165  Stockholm - Västberga-SE       Lieto (Turku)-FL    2.0    67048.0
# 166          Suwałki (Ełk)-PL              Kaunas-LT    1.0    16764.0
# 167          Suwałki (Ełk)-PL   Vantaa (Helsinki)-FL    1.0    16764.0
# 168      Vantaa (Helsinki)-FL        Budapest OLK-HU    1.0     9000.0
# 169      Vantaa (Helsinki)-FL          Hagenbrunn-AT    1.0     9000.0
# 170      Vantaa (Helsinki)-FL             Ostrava-CZ    1.0     9000.0
# 171      Vantaa (Helsinki)-FL       Suwałki (Ełk)-PL    1.0     9000.0
# 172      Vantaa (Helsinki)-FL     Zilina- Strecno-SK    1.0     9000.0
# 173                   Wals-AT     Eindhoven-Noord-NL    1.0     9000.0
# 174                Wrocław-PL         Bettembourg-LU    1.0     9000.0
# 175                Wrocław-PL            Krupka 1-CZ   24.0   787816.0
# 176                Wrocław-PL        PZ 77 (Lahr)-DE    2.0    42524.0
# 177                 Zabrze-PL        Budapest OLK-HU    1.0    16764.0
# 178                 Zabrze-PL          Hagenbrunn-AT    1.0    33524.0
# 179                 Zabrze-PL           Ljubljana-SI    1.0     9000.0
# 180                 Zabrze-PL              Oradea-RO    1.0    16764.0
# 181                 Zabrze-PL             Ostrava-CZ    8.0   134112.0
# 182                 Zabrze-PL               Sofia-BG    1.0    16764.0
# 183                 Zabrze-PL              Zagreb-HR    1.0     9000.0
# 184                 Zabrze-PL     Zilina- Strecno-SK    6.0   100584.0
# 185                 Zagreb-HR               Sofia-BG    1.0     9000.0
# 186                 Zagreb-HR               Spata-GR    1.0     9000.0
# 187             Zaltbommel-NL               Malmö-SE   17.0     2720.0
# 188             Zaltbommel-NL              Poznań-PL   19.0     3040.0
# 189        Zilina- Strecno-SK             Ostrava-CZ   13.0   210168.0
#
#      Clustering
# 0           1.0
# 1           2.0
# 2           2.0
# 3           2.0
# 4           3.0
# 5           2.0
# 6           1.0
# 7           1.0
# 8           1.0
# 9           1.0
# 10          1.0
# 11          1.0
# 12          1.0
# 13          2.0
# 14          1.0
# 15          1.0
# 16          1.0
# 17          3.0
# 18          1.0
# 19          1.0
# 20          2.0
# 21          1.0
# 22          1.0
# 23          2.0
# 24          1.0
# 25          3.0
# 26          1.0
# 27          1.0
# 28          2.0
# 29          1.0
# 30          3.0
# 31          1.0
# 32          2.0
# 33          1.0
# 34          2.0
# 35          1.0
# 36          1.0
# 37          1.0
# 38          1.0
# 39          1.0
# 40          1.0
# 41          1.0
# 42          1.0
# 43          1.0
# 44          2.0
# 45          1.0
# 46          1.0
# 47          1.0
# 48          1.0
# 49          1.0
# ..          ...
# 140         2.0
# 141         2.0
# 142         3.0
# 143         2.0
# 144         1.0
# 145         2.0
# 146         2.0
# 147         1.0
# 148         2.0
# 149         2.0
# 150         1.0
# 151         2.0
# 152         1.0
# 153         2.0
# 154         1.0
# 155         1.0
# 156         2.0
# 157         1.0
# 158         2.0
# 159         1.0
# 160         1.0
# 161         1.0
# 162         1.0
# 163         1.0
# 164         1.0
# 165         1.0
# 166         1.0
# 167         1.0
# 168         2.0
# 169         2.0
# 170         1.0
# 171         1.0
# 172         1.0
# 173         1.0
# 174         1.0
# 175         1.0
# 176         1.0
# 177         1.0
# 178         1.0
# 179         1.0
# 180         1.0
# 181         1.0
# 182         1.0
# 183         1.0
# 184         1.0
# 185         5.0
# 186         3.0
# 187         1.0
# 188         1.0
# 189         1.0
#
# [190 rows x 5 columns]
