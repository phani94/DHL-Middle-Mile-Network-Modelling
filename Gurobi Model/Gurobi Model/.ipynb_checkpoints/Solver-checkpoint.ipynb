# %%
from gurobipy import Model, GRB, quicksum, tuplelist
import numpy as np
import pandas as pd

# %%
# The following file works as a reference table to match the names of 2 sheets
hub_list = pd.read_csv('Database/Hub list.csv')
hub_list.Ref_City = hub_list.Ref_City + "-" + hub_list.Country
hub_ref = {}
for row in hub_list.index:
    hub_ref[hub_list.loc[row, "City"]] = hub_list.loc[row, "Ref_City"]


def name_transform(city_name):
    if city_name in hub_ref.keys():
        #print(city_name, " : ", hub_ref[city_name])
        return hub_ref[city_name]
    else:
        print(city_name, " not Found")
        return city_name

# %%
# Simple Version
masterfile = pd.read_excel("Database/Simple/Simple Routes.xlsx", sheet_name = 0)

# Complete Version
#masterfile = pd.read_csv("Database/inter_distances.csv")

# %%
model = Model("DHL")
# Out:
# Academic license - for non-commercial use only

# %% [markdown]
# # Define the Set
# ## 1. Hubs in each Country (L) & All Hubs (H)

# %%
used_hubs = masterfile.From.unique().tolist() +  masterfile.To.unique().tolist() # Not every hubs in the hub list is used
used_hubs = list( dict.fromkeys(used_hubs) )  # Remove duplicate

hub_list_used = [x for x in hub_list if x in used_hubs]

hub_list_used = hub_list.set_index("Ref_City")
hub_list_used = hub_list_used.loc[hub_list_used.index.isin(used_hubs), :]
hub_list_used.reset_index(inplace = True)

hub_list_used["Country"] = hub_list_used.apply(lambda row: row["Ref_City"].split("-")[-1], axis = 1) # To fill NA in country

L = {}
for country in hub_list_used.Country.unique():
    hub_collect = hub_list_used[hub_list_used.loc[:, "Country"] == country]["Ref_City"].tolist()
    L[country] = hub_collect
print(L)
#for row in hub_list_used.index:

    #L[hub_list_used.loc[row, "Country"]].append(hub_list_used.loc[row, "Ref_City"])
H = hub_list_used.Ref_City.unique().tolist() # All hubs

# %% [markdown]
# ## 2. European Countries (E)

# %%
E = hub_list_used.Country.unique().tolist() # from the "Hub list.csv" file

# %% [markdown]
# ## 3. Truck Types (T)

# %%
truck_cap = pd.read_excel("Database/TruckVSCap.xlsx", sheet_name = 0)
T = truck_cap["Truck Type"].tolist()

# %% [markdown]
# ## Define subset for the later use

# %%
# Define tuplelist for the assign of variables

mjk = tuplelist([(m,j,k) for m in E for j in E for k in E if (m != j) & (j != k) & (k != m)])
mk = tuplelist([(m,k) for m in E for k in E if m != k])
pq = tuplelist([(p,q) for m,k in mk for p in L[m] for q in L[k]])
piq = tuplelist([(p,i,q) for (m,j,k) in mjk for p in L[m] for i in L[j] for q in L[k]])
pqt = [(p,q,t) for p,q in pq for t in T]

# %% [markdown]
# # Define all the parameters
#
# ## 1. Cost:
# Transportation Cost between hub p ∈ H and hub q ∈ H using truck t ∈ T (Euro/ kg)

# %%
cost_file = pd.read_csv("Database/Costs.csv")

# %%
cost = {}
for row in cost_file.index:
    cost_key = (cost_file["From"][row], cost_file["To"][row], cost_file["Truck type"][row])
    cost[cost_key] = cost_file["Cost/kg"][row]

# %% [markdown]
# # 2. Forecast volume: Z
# Average forecasted parcel volume from country m ∈ E to country j ∈ E

# %%
forecast = pd.read_csv("Database/Average_Forecast.csv")
forecast.fillna(0, inplace = True)

# %%
# Only satisfied those the current network can reach
# Otherwise the solution would be infeasible

used_c = masterfile["Origin Country"].unique().tolist() +  masterfile["Destination Country"].unique().tolist() # Not every hubs in the hub list is used
used_c = list( dict.fromkeys(used_c) )  # Remove duplicate

all_c = forecast.Origin.unique().tolist() +  forecast.Destination.unique().tolist() # Not every hubs in the hub list is used
all_c = list( dict.fromkeys(all_c) )  # Remove duplicate

for x in used_c:
    try:
        all_c.remove(x)
    except:
        print(x)
        
for c in all_c:
    forecast["Origin"].replace(c, np.nan, inplace = True)
    forecast["Destination"].replace(c, np.nan, inplace = True)
    
forecast.dropna(how = "any")
# Out:
# FL
#      Unnamed: 0 Origin Destination        Average
# 0             0     AT          CZ  146713.092429
# 1             1     AT          DE  932495.290988
# 2             2     AT          NL     268.218824
# 3             3     AT          PL   37699.067077
# 4             4     BE          AT    5943.200000
# ..          ...    ...         ...            ...
# 254         254     SK          PL       0.000000
# 255         255     SK          PT       0.000000
# 256         256     SK          RO       0.000000
# 257         257     SK          SE       0.000000
# 258         258     SK          SI       0.000000
#
# [205 rows x 4 columns]

# %%
Z = {}


for row in forecast.index:
    key = (forecast["Origin"][row], forecast["Destination"][row])
    Z[key] = int(round(forecast["Average"][row])) # Can only be interger

# Some missing connection in the forecast
for conn in mk:
    if conn not in Z.keys():
        Z[conn] = 0
        print(conn)
# Out:
# ('AT', 'BE')
# ('AT', 'BG')
# ('AT', 'DK')
# ('AT', 'ES')
# ('AT', 'FR')
# ('AT', 'GB')
# ('AT', 'GR')
# ('AT', 'HR')
# ('AT', 'HU')
# ('AT', 'IE')
# ('AT', 'LT')
# ('AT', 'LU')
# ('AT', 'NO')
# ('AT', 'PT')
# ('AT', 'RO')
# ('AT', 'SE')
# ('AT', 'SI')
# ('AT', 'SK')
# ('BE', 'LU')
# ('BE', 'NL')
# ('BE', 'NO')
# ('BE', 'RO')
# ('BG', 'BE')
# ('BG', 'CZ')
# ('BG', 'DK')
# ('BG', 'FR')
# ('BG', 'GB')
# ('BG', 'GR')
# ('BG', 'HR')
# ('BG', 'HU')
# ('BG', 'IE')
# ('BG', 'LU')
# ('BG', 'NL')
# ('BG', 'NO')
# ('BG', 'PL')
# ('BG', 'RO')
# ('BG', 'SE')
# ('BG', 'SI')
# ('BG', 'SK')
# ('CZ', 'BE')
# ('CZ', 'BG')
# ('CZ', 'DK')
# ('CZ', 'FR')
# ('CZ', 'GB')
# ('CZ', 'GR')
# ('CZ', 'HR')
# ('CZ', 'LU')
# ('CZ', 'NL')
# ('CZ', 'NO')
# ('CZ', 'RO')
# ('CZ', 'SI')
# ('CZ', 'SK')
# ('DE', 'RO')
# ('DK', 'AT')
# ('DK', 'BE')
# ('DK', 'BG')
# ('DK', 'CZ')
# ('DK', 'DE')
# ('DK', 'ES')
# ('DK', 'FR')
# ('DK', 'GB')
# ('DK', 'GR')
# ('DK', 'HR')
# ('DK', 'HU')
# ('DK', 'IE')
# ('DK', 'LT')
# ('DK', 'LU')
# ('DK', 'NL')
# ('DK', 'NO')
# ('DK', 'PL')
# ('DK', 'PT')
# ('DK', 'RO')
# ('DK', 'SE')
# ('DK', 'SI')
# ('DK', 'SK')
# ('ES', 'FR')
# ('ES', 'NO')
# ('ES', 'PT')
# ('FR', 'AT')
# ('FR', 'BE')
# ('FR', 'BG')
# ('FR', 'CZ')
# ('FR', 'DE')
# ('FR', 'DK')
# ('FR', 'ES')
# ('FR', 'GB')
# ('FR', 'GR')
# ('FR', 'HR')
# ('FR', 'HU')
# ('FR', 'IE')
# ('FR', 'LT')
# ('FR', 'LU')
# ('FR', 'NL')
# ('FR', 'NO')
# ('FR', 'PL')
# ('FR', 'PT')
# ('FR', 'RO')
# ('FR', 'SE')
# ('FR', 'SI')
# ('FR', 'SK')
# ('GB', 'IE')
# ('GB', 'NO')
# ('GB', 'SE')
# ('GR', 'AT')
# ('GR', 'BE')
# ('GR', 'BG')
# ('GR', 'CZ')
# ('GR', 'DE')
# ('GR', 'DK')
# ('GR', 'ES')
# ('GR', 'FR')
# ('GR', 'GB')
# ('GR', 'HR')
# ('GR', 'HU')
# ('GR', 'IE')
# ('GR', 'LT')
# ('GR', 'LU')
# ('GR', 'NL')
# ('GR', 'NO')
# ('GR', 'PL')
# ('GR', 'PT')
# ('GR', 'RO')
# ('GR', 'SE')
# ('GR', 'SI')
# ('GR', 'SK')
# ('HR', 'AT')
# ('HR', 'BE')
# ('HR', 'BG')
# ('HR', 'CZ')
# ('HR', 'DE')
# ('HR', 'DK')
# ('HR', 'ES')
# ('HR', 'FR')
# ('HR', 'GB')
# ('HR', 'GR')
# ('HR', 'HU')
# ('HR', 'IE')
# ('HR', 'LT')
# ('HR', 'LU')
# ('HR', 'NL')
# ('HR', 'NO')
# ('HR', 'PL')
# ('HR', 'PT')
# ('HR', 'RO')
# ('HR', 'SE')
# ('HR', 'SI')
# ('HR', 'SK')
# ('HU', 'BG')
# ('HU', 'DK')
# ('HU', 'ES')
# ('HU', 'FR')
# ('HU', 'GB')
# ('HU', 'GR')
# ('HU', 'HR')
# ('HU', 'IE')
# ('HU', 'LT')
# ('HU', 'NO')
# ('HU', 'PT')
# ('HU', 'RO')
# ('HU', 'SE')
# ('IE', 'AT')
# ('IE', 'BE')
# ('IE', 'BG')
# ('IE', 'CZ')
# ('IE', 'DE')
# ('IE', 'DK')
# ('IE', 'ES')
# ('IE', 'FR')
# ('IE', 'GB')
# ('IE', 'GR')
# ('IE', 'HR')
# ('IE', 'HU')
# ('IE', 'LT')
# ('IE', 'LU')
# ('IE', 'NL')
# ('IE', 'NO')
# ('IE', 'PL')
# ('IE', 'PT')
# ('IE', 'RO')
# ('IE', 'SE')
# ('IE', 'SI')
# ('IE', 'SK')
# ('LT', 'AT')
# ('LT', 'BE')
# ('LT', 'BG')
# ('LT', 'CZ')
# ('LT', 'DE')
# ('LT', 'DK')
# ('LT', 'ES')
# ('LT', 'FR')
# ('LT', 'GB')
# ('LT', 'GR')
# ('LT', 'HR')
# ('LT', 'HU')
# ('LT', 'IE')
# ('LT', 'LU')
# ('LT', 'NL')
# ('LT', 'NO')
# ('LT', 'PL')
# ('LT', 'PT')
# ('LT', 'RO')
# ('LT', 'SI')
# ('LT', 'SK')
# ('LU', 'AT')
# ('LU', 'BE')
# ('LU', 'BG')
# ('LU', 'CZ')
# ('LU', 'DE')
# ('LU', 'DK')
# ('LU', 'ES')
# ('LU', 'FR')
# ('LU', 'GB')
# ('LU', 'GR')
# ('LU', 'HR')
# ('LU', 'HU')
# ('LU', 'IE')
# ('LU', 'LT')
# ('LU', 'NL')
# ('LU', 'NO')
# ('LU', 'PL')
# ('LU', 'PT')
# ('LU', 'RO')
# ('LU', 'SE')
# ('LU', 'SI')
# ('LU', 'SK')
# ('NL', 'BE')
# ('NL', 'NO')
# ('NO', 'AT')
# ('NO', 'BE')
# ('NO', 'BG')
# ('NO', 'CZ')
# ('NO', 'DE')
# ('NO', 'DK')
# ('NO', 'ES')
# ('NO', 'FR')
# ('NO', 'GB')
# ('NO', 'GR')
# ('NO', 'HR')
# ('NO', 'HU')
# ('NO', 'IE')
# ('NO', 'LT')
# ('NO', 'LU')
# ('NO', 'NL')
# ('NO', 'PL')
# ('NO', 'PT')
# ('NO', 'RO')
# ('NO', 'SE')
# ('NO', 'SI')
# ('NO', 'SK')
# ('PL', 'FR')
# ('PL', 'GR')
# ('PL', 'NO')
# ('PT', 'ES')
# ('PT', 'FR')
# ('PT', 'NO')
# ('RO', 'AT')
# ('RO', 'BE')
# ('RO', 'BG')
# ('RO', 'CZ')
# ('RO', 'DE')
# ('RO', 'DK')
# ('RO', 'ES')
# ('RO', 'FR')
# ('RO', 'GB')
# ('RO', 'GR')
# ('RO', 'HR')
# ('RO', 'HU')
# ('RO', 'IE')
# ('RO', 'LT')
# ('RO', 'LU')
# ('RO', 'NL')
# ('RO', 'NO')
# ('RO', 'PL')
# ('RO', 'PT')
# ('RO', 'SE')
# ('RO', 'SI')
# ('RO', 'SK')
# ('SE', 'GR')
# ('SE', 'LT')
# ('SI', 'BG')
# ('SI', 'CZ')
# ('SI', 'DK')
# ('SI', 'ES')
# ('SI', 'FR')
# ('SI', 'GB')
# ('SI', 'GR')
# ('SI', 'HR')
# ('SI', 'HU')
# ('SI', 'IE')
# ('SI', 'LT')
# ('SI', 'LU')
# ('SI', 'NO')
# ('SI', 'PT')
# ('SI', 'RO')
# ('SI', 'SE')
# ('SI', 'SK')
# ('SK', 'DK')
# ('SK', 'FR')
# ('SK', 'GB')
# ('SK', 'GR')
# ('SK', 'NO')

# %% [markdown]
# ## 3. Current Freqency (F_)
# the frequency of truck t from hub to hub q in the current network.

# %%
# The following code transform the excel files to csv file in specific format
'''
freq_truck = pd.read_excel("Database/Result_Freq.xlsx", sheet_name = 0)
freq_truck.replace("Ryton Gateway", "Ryton", inplace = True)
freq_truck["From"] = freq_truck.apply(lambda row: name_transform(row["Org. GTW"]), axis = 1)
freq_truck["To"] = freq_truck.apply(lambda row: name_transform(row["Dst. GTW"]), axis = 1)
freq_truck.loc[:, :].to_csv("Database/current_network.csv")

'''
# Out:
# '\nfreq_truck = pd.read_excel("Database/Result_Freq.xlsx", sheet_name = 0)\nfreq_truck.replace("Ryton Gateway", "Ryton", inplace = True)\nfreq_truck["From"] = freq_truck.apply(lambda row: name_transform(row["Org. GTW"]), axis = 1)\nfreq_truck["To"] = freq_truck.apply(lambda row: name_transform(row["Dst. GTW"]), axis = 1)\nfreq_truck.loc[:, :].to_csv("Database/current_network.csv")\n\n'

# %%
freq_current = pd.read_csv("Database/current_network.csv")
print(freq_current["Truck type"].unique())
print(truck_cap)
# The following section work as a formatting part. To avoid different naming issues
freq_current.replace("trailer", "Trailer", inplace = True)
freq_current.replace("2 swap bodies", "2 Swap Bodies", inplace = True)
freq_current.replace("van", "Van", inplace = True)
freq_current.replace("1 swap body", "Swap Body", inplace = True)
freq_current.replace("SEMI TRAILER", "Swap Body", inplace = True)
freq_current.replace("Van 15 m3", "Van", inplace = True)
freq_current.replace("Van 22m3", "Van", inplace = True)
freq_current.replace("4 swap bodies", "2 Swap Bodies", inplace = True)
# Out:
# ['Trailer' '2 swap bodies' 'SEMI TRAILER' '1 swap body' 'van' 'trailer'
#  'Van' 'Sea Container' 'Cargo 50 m3' 'Van 22m3' '4 swap bodies'
#  'Van 15 m3']
#       Truck Type  Capacity
# 0  2 Swap Bodies      8381
# 1      Swap Body      4191
# 2        Trailer      7650
# 3            Van      2250

# %%
F_ = {}
for row in freq_current.index:
    key = (freq_current.loc[row, "From"], freq_current.loc[row, "To"], freq_current.loc[row, "Truck type"])
    value = freq_current.loc[row, "Frequency"]
    
    F_[key] = value
    
for target in pqt:
    if target not in F_.keys():
        F_[target] = 0
        print(target)
# Out:
# ('Hub Wien I-AT', 'Brüssel-BE', '2 Swap Bodies')
# ('Hub Wien I-AT', 'Brüssel-BE', 'Swap Body')
# ('Hub Wien I-AT', 'Brüssel-BE', 'Trailer')
# ('Hub Wien I-AT', 'Brüssel-BE', 'Van')
# ('Hub Graz-AT', 'Brüssel-BE', '2 Swap Bodies')
# ('Hub Graz-AT', 'Brüssel-BE', 'Swap Body')
# ('Hub Graz-AT', 'Brüssel-BE', 'Trailer')
# ('Hub Graz-AT', 'Brüssel-BE', 'Van')
# ('Hub Wien I-AT', 'Sofia-BG', '2 Swap Bodies')
# ('Hub Wien I-AT', 'Sofia-BG', 'Swap Body')
# ('Hub Wien I-AT', 'Sofia-BG', 'Trailer')
# ('Hub Wien I-AT', 'Sofia-BG', 'Van')
# ('Hub Graz-AT', 'Sofia-BG', '2 Swap Bodies')
# ('Hub Graz-AT', 'Sofia-BG', 'Swap Body')
# ('Hub Graz-AT', 'Sofia-BG', 'Trailer')
# ('Hub Graz-AT', 'Sofia-BG', 'Van')
# ('Hub Wien I-AT', 'Brno-CZ', '2 Swap Bodies')
# ('Hub Wien I-AT', 'Brno-CZ', 'Swap Body')
# ('Hub Wien I-AT', 'Brno-CZ', 'Trailer')
# ('Hub Wien I-AT', 'Brno-CZ', 'Van')
# ('Hub Wien I-AT', 'Ostrava-CZ', '2 Swap Bodies')
# ('Hub Wien I-AT', 'Ostrava-CZ', 'Swap Body')
# ('Hub Wien I-AT', 'Ostrava-CZ', 'Trailer')
# ('Hub Wien I-AT', 'Ostrava-CZ', 'Van')
# ('Hub Wien I-AT', 'Krupka 1-CZ', '2 Swap Bodies')
# ('Hub Wien I-AT', 'Krupka 1-CZ', 'Swap Body')
# ('Hub Wien I-AT', 'Krupka 1-CZ', 'Trailer')
# ('Hub Wien I-AT', 'Krupka 1-CZ', 'Van')
# ('Hub Wien I-AT', 'Plzen 1-CZ', '2 Swap Bodies')
# ('Hub Wien I-AT', 'Plzen 1-CZ', 'Swap Body')
# ('Hub Wien I-AT', 'Plzen 1-CZ', 'Trailer')
# ('Hub Wien I-AT', 'Plzen 1-CZ', 'Van')
# ('Hub Wien I-AT', 'Hradec Kralove - Brezhrad-CZ', '2 Swap Bodies')
# ('Hub Wien I-AT', 'Hradec Kralove - Brezhrad-CZ', 'Swap Body')
# ('Hub Wien I-AT', 'Hradec Kralove - Brezhrad-CZ', 'Trailer')
# ('Hub Wien I-AT', 'Hradec Kralove - Brezhrad-CZ', 'Van')
# ('Hub Graz-AT', 'Brno-CZ', '2 Swap Bodies')
# ('Hub Graz-AT', 'Brno-CZ', 'Swap Body')
# ('Hub Graz-AT', 'Brno-CZ', 'Trailer')
# ('Hub Graz-AT', 'Brno-CZ', 'Van')
# ('Hub Graz-AT', 'Ostrava-CZ', '2 Swap Bodies')
# ('Hub Graz-AT', 'Ostrava-CZ', 'Swap Body')
# ('Hub Graz-AT', 'Ostrava-CZ', 'Trailer')
# ('Hub Graz-AT', 'Ostrava-CZ', 'Van')
# ('Hub Graz-AT', 'Krupka 1-CZ', '2 Swap Bodies')
# ('Hub Graz-AT', 'Krupka 1-CZ', 'Swap Body')
# ('Hub Graz-AT', 'Krupka 1-CZ', 'Trailer')
# ('Hub Graz-AT', 'Krupka 1-CZ', 'Van')
# ('Hub Graz-AT', 'Plzen 1-CZ', '2 Swap Bodies')
# ('Hub Graz-AT', 'Plzen 1-CZ', 'Swap Body')
# ('Hub Graz-AT', 'Plzen 1-CZ', 'Trailer')
# ('Hub Graz-AT', 'Plzen 1-CZ', 'Van')
# ('Hub Graz-AT', 'Hradec Kralove - Brezhrad-CZ', '2 Swap Bodies')
# ('Hub Graz-AT', 'Hradec Kralove - Brezhrad-CZ', 'Swap Body')
# ('Hub Graz-AT', 'Hradec Kralove - Brezhrad-CZ', 'Trailer')
# ('Hub Graz-AT', 'Hradec Kralove - Brezhrad-CZ', 'Van')
# ('Hub Wien I-AT', 'PZ 67 (Speyer)-DE', '2 Swap Bodies')
# ('Hub Wien I-AT', 'PZ 67 (Speyer)-DE', 'Swap Body')
# ('Hub Wien I-AT', 'PZ 67 (Speyer)-DE', 'Trailer')
# ('Hub Wien I-AT', 'PZ 67 (Speyer)-DE', 'Van')
# ('Hub Wien I-AT', 'PZ 50 (Köln)-DE', '2 Swap Bodies')
# ('Hub Wien I-AT', 'PZ 50 (Köln)-DE', 'Swap Body')
# ('Hub Wien I-AT', 'PZ 50 (Köln)-DE', 'Trailer')
# ('Hub Wien I-AT', 'PZ 50 (Köln)-DE', 'Van')
# ('Hub Wien I-AT', 'PZ 04 (Radefeld/Leipzig)-DE', '2 Swap Bodies')
# ('Hub Wien I-AT', 'PZ 04 (Radefeld/Leipzig)-DE', 'Swap Body')
# ('Hub Wien I-AT', 'PZ 04 (Radefeld/Leipzig)-DE', 'Trailer')
# ('Hub Wien I-AT', 'PZ 04 (Radefeld/Leipzig)-DE', 'Van')
# ('Hub Wien I-AT', 'PZ 90 (Feucht/Nürnberg)-DE', '2 Swap Bodies')
# ('Hub Wien I-AT', 'PZ 90 (Feucht/Nürnberg)-DE', 'Swap Body')
# ('Hub Wien I-AT', 'PZ 90 (Feucht/Nürnberg)-DE', 'Trailer')
# ('Hub Wien I-AT', 'PZ 90 (Feucht/Nürnberg)-DE', 'Van')
# ('Hub Wien I-AT', 'PZ 77 (Lahr)-DE', '2 Swap Bodies')
# ('Hub Wien I-AT', 'PZ 77 (Lahr)-DE', 'Swap Body')
# ('Hub Wien I-AT', 'PZ 77 (Lahr)-DE', 'Trailer')
# ('Hub Wien I-AT', 'PZ 77 (Lahr)-DE', 'Van')
# ('Hub Wien I-AT', 'PZ 93 (Regensburg)-DE', 'Swap Body')
# ('Hub Wien I-AT', 'PZ 93 (Regensburg)-DE', 'Trailer')
# ('Hub Wien I-AT', 'PZ 93 (Regensburg)-DE', 'Van')
# ('Hub Wien I-AT', 'PZ 21 (Hamburg)-DE', '2 Swap Bodies')
# ('Hub Wien I-AT', 'PZ 21 (Hamburg)-DE', 'Swap Body')
# ('Hub Wien I-AT', 'PZ 21 (Hamburg)-DE', 'Trailer')
# ('Hub Wien I-AT', 'PZ 21 (Hamburg)-DE', 'Van')
# ('Hub Wien I-AT', 'PZ 46 (Dorsten)-DE', '2 Swap Bodies')
# ('Hub Wien I-AT', 'PZ 46 (Dorsten)-DE', 'Swap Body')
# ('Hub Wien I-AT', 'PZ 46 (Dorsten)-DE', 'Trailer')
# ('Hub Wien I-AT', 'PZ 46 (Dorsten)-DE', 'Van')
# ('Hub Wien I-AT', 'PZ 58 (Hagen)-DE', '2 Swap Bodies')
# ('Hub Wien I-AT', 'PZ 58 (Hagen)-DE', 'Swap Body')
# ('Hub Wien I-AT', 'PZ 58 (Hagen)-DE', 'Trailer')
# ('Hub Wien I-AT', 'PZ 58 (Hagen)-DE', 'Van')
# ('Hub Wien I-AT', 'PZ 08 (Neumark)-DE', '2 Swap Bodies')
# ('Hub Wien I-AT', 'PZ 08 (Neumark)-DE', 'Swap Body')
# ('Hub Wien I-AT', 'PZ 08 (Neumark)-DE', 'Trailer')
# ('Hub Wien I-AT', 'PZ 08 (Neumark)-DE', 'Van')
# ('Hub Wien I-AT', 'PZ 47 (Krefeld)-DE', '2 Swap Bodies')
# ('Hub Wien I-AT', 'PZ 47 (Krefeld)-DE', 'Swap Body')
# ('Hub Wien I-AT', 'PZ 47 (Krefeld)-DE', 'Trailer')
# ('Hub Wien I-AT', 'PZ 47 (Krefeld)-DE', 'Van')
# ('Hub Wien I-AT', 'PZ 15 (Rüdersdorf)-DE', '2 Swap Bodies')
# ('Hub Wien I-AT', 'PZ 15 (Rüdersdorf)-DE', 'Swap Body')
# ('Hub Wien I-AT', 'PZ 15 (Rüdersdorf)-DE', 'Trailer')
# ('Hub Wien I-AT', 'PZ 15 (Rüdersdorf)-DE', 'Van')
# ('Hub Graz-AT', 'PZ 67 (Speyer)-DE', '2 Swap Bodies')
# ('Hub Graz-AT', 'PZ 67 (Speyer)-DE', 'Swap Body')
# ('Hub Graz-AT', 'PZ 67 (Speyer)-DE', 'Trailer')
# ('Hub Graz-AT', 'PZ 67 (Speyer)-DE', 'Van')
# ('Hub Graz-AT', 'PZ 50 (Köln)-DE', '2 Swap Bodies')
# ('Hub Graz-AT', 'PZ 50 (Köln)-DE', 'Swap Body')
# ('Hub Graz-AT', 'PZ 50 (Köln)-DE', 'Trailer')
# ('Hub Graz-AT', 'PZ 50 (Köln)-DE', 'Van')
# ('Hub Graz-AT', 'PZ 04 (Radefeld/Leipzig)-DE', '2 Swap Bodies')
# ('Hub Graz-AT', 'PZ 04 (Radefeld/Leipzig)-DE', 'Swap Body')
# ('Hub Graz-AT', 'PZ 04 (Radefeld/Leipzig)-DE', 'Trailer')
# ('Hub Graz-AT', 'PZ 04 (Radefeld/Leipzig)-DE', 'Van')
# ('Hub Graz-AT', 'PZ 90 (Feucht/Nürnberg)-DE', '2 Swap Bodies')
# ('Hub Graz-AT', 'PZ 90 (Feucht/Nürnberg)-DE', 'Swap Body')
# ('Hub Graz-AT', 'PZ 90 (Feucht/Nürnberg)-DE', 'Trailer')
# ('Hub Graz-AT', 'PZ 90 (Feucht/Nürnberg)-DE', 'Van')
# ('Hub Graz-AT', 'PZ 77 (Lahr)-DE', '2 Swap Bodies')
# ('Hub Graz-AT', 'PZ 77 (Lahr)-DE', 'Swap Body')
# ('Hub Graz-AT', 'PZ 77 (Lahr)-DE', 'Trailer')
# ('Hub Graz-AT', 'PZ 77 (Lahr)-DE', 'Van')
# ('Hub Graz-AT', 'PZ 93 (Regensburg)-DE', '2 Swap Bodies')
# ('Hub Graz-AT', 'PZ 93 (Regensburg)-DE', 'Swap Body')
# ('Hub Graz-AT', 'PZ 93 (Regensburg)-DE', 'Trailer')
# ('Hub Graz-AT', 'PZ 93 (Regensburg)-DE', 'Van')
# ('Hub Graz-AT', 'PZ 21 (Hamburg)-DE', '2 Swap Bodies')
# ('Hub Graz-AT', 'PZ 21 (Hamburg)-DE', 'Swap Body')
# ('Hub Graz-AT', 'PZ 21 (Hamburg)-DE', 'Trailer')
# ('Hub Graz-AT', 'PZ 21 (Hamburg)-DE', 'Van')
# ('Hub Graz-AT', 'PZ 46 (Dorsten)-DE', '2 Swap Bodies')
# ('Hub Graz-AT', 'PZ 46 (Dorsten)-DE', 'Swap Body')
# ('Hub Graz-AT', 'PZ 46 (Dorsten)-DE', 'Trailer')
# ('Hub Graz-AT', 'PZ 46 (Dorsten)-DE', 'Van')
# ('Hub Graz-AT', 'PZ 58 (Hagen)-DE', '2 Swap Bodies')
# ('Hub Graz-AT', 'PZ 58 (Hagen)-DE', 'Swap Body')
# ('Hub Graz-AT', 'PZ 58 (Hagen)-DE', 'Trailer')
# ('Hub Graz-AT', 'PZ 58 (Hagen)-DE', 'Van')
# ('Hub Graz-AT', 'PZ 08 (Neumark)-DE', '2 Swap Bodies')
# ('Hub Graz-AT', 'PZ 08 (Neumark)-DE', 'Swap Body')
# ('Hub Graz-AT', 'PZ 08 (Neumark)-DE', 'Trailer')
# ('Hub Graz-AT', 'PZ 08 (Neumark)-DE', 'Van')
# ('Hub Graz-AT', 'PZ 47 (Krefeld)-DE', '2 Swap Bodies')
# ('Hub Graz-AT', 'PZ 47 (Krefeld)-DE', 'Swap Body')
# ('Hub Graz-AT', 'PZ 47 (Krefeld)-DE', 'Trailer')
# ('Hub Graz-AT', 'PZ 47 (Krefeld)-DE', 'Van')
# ('Hub Graz-AT', 'PZ 15 (Rüdersdorf)-DE', '2 Swap Bodies')
# ('Hub Graz-AT', 'PZ 15 (Rüdersdorf)-DE', 'Swap Body')
# ('Hub Graz-AT', 'PZ 15 (Rüdersdorf)-DE', 'Trailer')
# ('Hub Graz-AT', 'PZ 15 (Rüdersdorf)-DE', 'Van')
# ('Hub Wien I-AT', 'Kolding-DK', '2 Swap Bodies')
# ('Hub Wien I-AT', 'Kolding-DK', 'Swap Body')
# ('Hub Wien I-AT', 'Kolding-DK', 'Trailer')
# ('Hub Wien I-AT', 'Kolding-DK', 'Van')
# ('Hub Graz-AT', 'Kolding-DK', '2 Swap Bodies')
# ('Hub Graz-AT', 'Kolding-DK', 'Swap Body')
# ('Hub Graz-AT', 'Kolding-DK', 'Trailer')
# ('Hub Graz-AT', 'Kolding-DK', 'Van')
# ('Hub Wien I-AT', 'Barcelona-ES', '2 Swap Bodies')
# ('Hub Wien I-AT', 'Barcelona-ES', 'Swap Body')
# ('Hub Wien I-AT', 'Barcelona-ES', 'Trailer')
# ('Hub Wien I-AT', 'Barcelona-ES', 'Van')
# ('Hub Wien I-AT', 'Madrid-ES', '2 Swap Bodies')
# ('Hub Wien I-AT', 'Madrid-ES', 'Swap Body')
# ('Hub Wien I-AT', 'Madrid-ES', 'Trailer')
# ('Hub Wien I-AT', 'Madrid-ES', 'Van')
# ('Hub Wien I-AT', 'Araba (Vitoria)-ES', '2 Swap Bodies')
# ('Hub Wien I-AT', 'Araba (Vitoria)-ES', 'Swap Body')
# ('Hub Wien I-AT', 'Araba (Vitoria)-ES', 'Trailer')
# ('Hub Wien I-AT', 'Araba (Vitoria)-ES', 'Van')
# ('Hub Graz-AT', 'Barcelona-ES', '2 Swap Bodies')
# ('Hub Graz-AT', 'Barcelona-ES', 'Swap Body')
# ('Hub Graz-AT', 'Barcelona-ES', 'Trailer')
# ('Hub Graz-AT', 'Barcelona-ES', 'Van')
# ('Hub Graz-AT', 'Madrid-ES', '2 Swap Bodies')
# ('Hub Graz-AT', 'Madrid-ES', 'Swap Body')
# ('Hub Graz-AT', 'Madrid-ES', 'Trailer')
# ('Hub Graz-AT', 'Madrid-ES', 'Van')
# ('Hub Graz-AT', 'Araba (Vitoria)-ES', '2 Swap Bodies')
# ('Hub Graz-AT', 'Araba (Vitoria)-ES', 'Swap Body')
# ('Hub Graz-AT', 'Araba (Vitoria)-ES', 'Trailer')
# ('Hub Graz-AT', 'Araba (Vitoria)-ES', 'Van')
# ('Hub Wien I-AT', 'Combs la ville-FR', '2 Swap Bodies')
# ('Hub Wien I-AT', 'Combs la ville-FR', 'Swap Body')
# ('Hub Wien I-AT', 'Combs la ville-FR', 'Trailer')
# ('Hub Wien I-AT', 'Combs la ville-FR', 'Van')
# ('Hub Graz-AT', 'Combs la ville-FR', '2 Swap Bodies')
# ('Hub Graz-AT', 'Combs la ville-FR', 'Swap Body')
# ('Hub Graz-AT', 'Combs la ville-FR', 'Trailer')
# ('Hub Graz-AT', 'Combs la ville-FR', 'Van')
# ('Hub Wien I-AT', 'Slough-GB', '2 Swap Bodies')
# ('Hub Wien I-AT', 'Slough-GB', 'Swap Body')
# ('Hub Wien I-AT', 'Slough-GB', 'Trailer')
# ('Hub Wien I-AT', 'Slough-GB', 'Van')
# ('Hub Wien I-AT', 'Ryton Gateway-GB', '2 Swap Bodies')
# ('Hub Wien I-AT', 'Ryton Gateway-GB', 'Swap Body')
# ('Hub Wien I-AT', 'Ryton Gateway-GB', 'Trailer')
# ('Hub Wien I-AT', 'Ryton Gateway-GB', 'Van')
# ('Hub Graz-AT', 'Slough-GB', '2 Swap Bodies')
# ('Hub Graz-AT', 'Slough-GB', 'Swap Body')
# ('Hub Graz-AT', 'Slough-GB', 'Trailer')
# ('Hub Graz-AT', 'Slough-GB', 'Van')
# ('Hub Graz-AT', 'Ryton Gateway-GB', '2 Swap Bodies')
# ('Hub Graz-AT', 'Ryton Gateway-GB', 'Swap Body')
# ('Hub Graz-AT', 'Ryton Gateway-GB', 'Trailer')
# ('Hub Graz-AT', 'Ryton Gateway-GB', 'Van')
# ('Hub Wien I-AT', 'Spata-GR', '2 Swap Bodies')
# ('Hub Wien I-AT', 'Spata-GR', 'Swap Body')
# ('Hub Wien I-AT', 'Spata-GR', 'Trailer')
# ('Hub Wien I-AT', 'Spata-GR', 'Van')
# ('Hub Graz-AT', 'Spata-GR', '2 Swap Bodies')
# ('Hub Graz-AT', 'Spata-GR', 'Swap Body')
# ('Hub Graz-AT', 'Spata-GR', 'Trailer')
# ('Hub Graz-AT', 'Spata-GR', 'Van')
# ('Hub Wien I-AT', 'Zagreb-HR', '2 Swap Bodies')
# ('Hub Wien I-AT', 'Zagreb-HR', 'Swap Body')
# ('Hub Wien I-AT', 'Zagreb-HR', 'Trailer')
# ('Hub Wien I-AT', 'Zagreb-HR', 'Van')
# ('Hub Graz-AT', 'Zagreb-HR', '2 Swap Bodies')
# ('Hub Graz-AT', 'Zagreb-HR', 'Swap Body')
# ('Hub Graz-AT', 'Zagreb-HR', 'Trailer')
# ('Hub Graz-AT', 'Zagreb-HR', 'Van')
# ('Hub Wien I-AT', 'Budapest OLK-HU', '2 Swap Bodies')
# ('Hub Wien I-AT', 'Budapest OLK-HU', 'Swap Body')
# ('Hub Wien I-AT', 'Budapest OLK-HU', 'Trailer')
# ('Hub Wien I-AT', 'Budapest OLK-HU', 'Van')
# ('Hub Wien I-AT', 'Budapest NPKK (OE)-HU', '2 Swap Bodies')
# ('Hub Wien I-AT', 'Budapest NPKK (OE)-HU', 'Swap Body')
# ('Hub Wien I-AT', 'Budapest NPKK (OE)-HU', 'Trailer')
# ('Hub Wien I-AT', 'Budapest NPKK (OE)-HU', 'Van')
# ('Hub Graz-AT', 'Budapest OLK-HU', '2 Swap Bodies')
# ('Hub Graz-AT', 'Budapest OLK-HU', 'Swap Body')
# ('Hub Graz-AT', 'Budapest OLK-HU', 'Trailer')
# ('Hub Graz-AT', 'Budapest OLK-HU', 'Van')
# ('Hub Graz-AT', 'Budapest NPKK (OE)-HU', '2 Swap Bodies')
# ('Hub Graz-AT', 'Budapest NPKK (OE)-HU', 'Swap Body')
# ('Hub Graz-AT', 'Budapest NPKK (OE)-HU', 'Trailer')
# ('Hub Graz-AT', 'Budapest NPKK (OE)-HU', 'Van')
# ('Hub Wien I-AT', 'Portlaoise-IE', '2 Swap Bodies')
# ('Hub Wien I-AT', 'Portlaoise-IE', 'Swap Body')
# ('Hub Wien I-AT', 'Portlaoise-IE', 'Trailer')
# ('Hub Wien I-AT', 'Portlaoise-IE', 'Van')
# ('Hub Graz-AT', 'Portlaoise-IE', '2 Swap Bodies')
# ('Hub Graz-AT', 'Portlaoise-IE', 'Swap Body')
# ('Hub Graz-AT', 'Portlaoise-IE', 'Trailer')
# ('Hub Graz-AT', 'Portlaoise-IE', 'Van')
# ('Hub Wien I-AT', 'Kaunas-LT', '2 Swap Bodies')
# ('Hub Wien I-AT', 'Kaunas-LT', 'Swap Body')
# ('Hub Wien I-AT', 'Kaunas-LT', 'Trailer')
# ('Hub Wien I-AT', 'Kaunas-LT', 'Van')
# ('Hub Graz-AT', 'Kaunas-LT', '2 Swap Bodies')
# ('Hub Graz-AT', 'Kaunas-LT', 'Swap Body')
# ('Hub Graz-AT', 'Kaunas-LT', 'Trailer')
# ('Hub Graz-AT', 'Kaunas-LT', 'Van')
# ('Hub Wien I-AT', 'Bettembourg-LU', '2 Swap Bodies')
# ('Hub Wien I-AT', 'Bettembourg-LU', 'Swap Body')
# ('Hub Wien I-AT', 'Bettembourg-LU', 'Trailer')
# ('Hub Wien I-AT', 'Bettembourg-LU', 'Van')
# ('Hub Graz-AT', 'Bettembourg-LU', '2 Swap Bodies')
# ('Hub Graz-AT', 'Bettembourg-LU', 'Swap Body')
# ('Hub Graz-AT', 'Bettembourg-LU', 'Trailer')
# ('Hub Graz-AT', 'Bettembourg-LU', 'Van')
# ('Hub Wien I-AT', 'Eindhoven-Noord-NL', '2 Swap Bodies')
# ('Hub Wien I-AT', 'Eindhoven-Noord-NL', 'Swap Body')
# ('Hub Wien I-AT', 'Eindhoven-Noord-NL', 'Trailer')
# ('Hub Wien I-AT', 'Eindhoven-Noord-NL', 'Van')
# ('Hub Wien I-AT', 'Utrecht-West + Centrum-NL', '2 Swap Bodies')
# ('Hub Wien I-AT', 'Utrecht-West + Centrum-NL', 'Swap Body')
# ('Hub Wien I-AT', 'Utrecht-West + Centrum-NL', 'Trailer')
# ('Hub Wien I-AT', 'Utrecht-West + Centrum-NL', 'Van')
# ('Hub Wien I-AT', 'Zaltbommel-NL', '2 Swap Bodies')
# ('Hub Wien I-AT', 'Zaltbommel-NL', 'Swap Body')
# ('Hub Wien I-AT', 'Zaltbommel-NL', 'Trailer')
# ('Hub Wien I-AT', 'Zaltbommel-NL', 'Van')
# ('Hub Graz-AT', 'Eindhoven-Noord-NL', '2 Swap Bodies')
# ('Hub Graz-AT', 'Eindhoven-Noord-NL', 'Swap Body')
# ('Hub Graz-AT', 'Eindhoven-Noord-NL', 'Trailer')
# ('Hub Graz-AT', 'Eindhoven-Noord-NL', 'Van')
# ('Hub Graz-AT', 'Utrecht-West + Centrum-NL', '2 Swap Bodies')
# ('Hub Graz-AT', 'Utrecht-West + Centrum-NL', 'Swap Body')
# ('Hub Graz-AT', 'Utrecht-West + Centrum-NL', 'Trailer')
# ('Hub Graz-AT', 'Utrecht-West + Centrum-NL', 'Van')
# ('Hub Graz-AT', 'Zaltbommel-NL', '2 Swap Bodies')
# ('Hub Graz-AT', 'Zaltbommel-NL', 'Swap Body')
# ('Hub Graz-AT', 'Zaltbommel-NL', 'Trailer')
# ('Hub Graz-AT', 'Zaltbommel-NL', 'Van')
# ('Hub Wien I-AT', 'Oslo-NO', '2 Swap Bodies')
# ('Hub Wien I-AT', 'Oslo-NO', 'Swap Body')
# ('Hub Wien I-AT', 'Oslo-NO', 'Trailer')
# ('Hub Wien I-AT', 'Oslo-NO', 'Van')
# ('Hub Graz-AT', 'Oslo-NO', '2 Swap Bodies')
# ('Hub Graz-AT', 'Oslo-NO', 'Swap Body')
# ('Hub Graz-AT', 'Oslo-NO', 'Trailer')
# ('Hub Graz-AT', 'Oslo-NO', 'Van')
# ('Hub Wien I-AT', 'Suwałki (Ełk)-PL', '2 Swap Bodies')
# ('Hub Wien I-AT', 'Suwałki (Ełk)-PL', 'Swap Body')
# ('Hub Wien I-AT', 'Suwałki (Ełk)-PL', 'Trailer')
# ('Hub Wien I-AT', 'Suwałki (Ełk)-PL', 'Van')
# ('Hub Wien I-AT', 'Poznań-PL', '2 Swap Bodies')
# ('Hub Wien I-AT', 'Poznań-PL', 'Swap Body')
# ('Hub Wien I-AT', 'Poznań-PL', 'Trailer')
# ('Hub Wien I-AT', 'Poznań-PL', 'Van')
# ('Hub Wien I-AT', 'Zabrze-PL', '2 Swap Bodies')
# ('Hub Wien I-AT', 'Zabrze-PL', 'Swap Body')
# ('Hub Wien I-AT', 'Zabrze-PL', 'Trailer')
# ('Hub Wien I-AT', 'Zabrze-PL', 'Van')
# ('Hub Wien I-AT', 'Koninko-PL', '2 Swap Bodies')
# ('Hub Wien I-AT', 'Koninko-PL', 'Swap Body')
# ('Hub Wien I-AT', 'Koninko-PL', 'Trailer')
# ('Hub Wien I-AT', 'Koninko-PL', 'Van')
# ('Hub Wien I-AT', 'Wrocław-PL', '2 Swap Bodies')
# ('Hub Wien I-AT', 'Wrocław-PL', 'Swap Body')
# ('Hub Wien I-AT', 'Wrocław-PL', 'Trailer')
# ('Hub Wien I-AT', 'Wrocław-PL', 'Van')
# ('Hub Wien I-AT', 'Bydgoszcz (Solec Kujawski)-PL', '2 Swap Bodies')
# ('Hub Wien I-AT', 'Bydgoszcz (Solec Kujawski)-PL', 'Swap Body')
# ('Hub Wien I-AT', 'Bydgoszcz (Solec Kujawski)-PL', 'Trailer')
# ('Hub Wien I-AT', 'Bydgoszcz (Solec Kujawski)-PL', 'Van')
# ('Hub Graz-AT', 'Suwałki (Ełk)-PL', '2 Swap Bodies')
# ('Hub Graz-AT', 'Suwałki (Ełk)-PL', 'Swap Body')
# ('Hub Graz-AT', 'Suwałki (Ełk)-PL', 'Trailer')
# ('Hub Graz-AT', 'Suwałki (Ełk)-PL', 'Van')
# ('Hub Graz-AT', 'Poznań-PL', '2 Swap Bodies')
# ('Hub Graz-AT', 'Poznań-PL', 'Swap Body')
# ('Hub Graz-AT', 'Poznań-PL', 'Trailer')
# ('Hub Graz-AT', 'Poznań-PL', 'Van')
# ('Hub Graz-AT', 'Zabrze-PL', '2 Swap Bodies')
# ('Hub Graz-AT', 'Zabrze-PL', 'Swap Body')
# ('Hub Graz-AT', 'Zabrze-PL', 'Trailer')
# ('Hub Graz-AT', 'Zabrze-PL', 'Van')
# ('Hub Graz-AT', 'Koninko-PL', '2 Swap Bodies')
# ('Hub Graz-AT', 'Koninko-PL', 'Swap Body')
# ('Hub Graz-AT', 'Koninko-PL', 'Trailer')
# ('Hub Graz-AT', 'Koninko-PL', 'Van')
# ('Hub Graz-AT', 'Wrocław-PL', '2 Swap Bodies')
# ('Hub Graz-AT', 'Wrocław-PL', 'Swap Body')
# ('Hub Graz-AT', 'Wrocław-PL', 'Trailer')
# ('Hub Graz-AT', 'Wrocław-PL', 'Van')
# ('Hub Graz-AT', 'Bydgoszcz (Solec Kujawski)-PL', '2 Swap Bodies')
# ('Hub Graz-AT', 'Bydgoszcz (Solec Kujawski)-PL', 'Swap Body')
# ('Hub Graz-AT', 'Bydgoszcz (Solec Kujawski)-PL', 'Trailer')
# ('Hub Graz-AT', 'Bydgoszcz (Solec Kujawski)-PL', 'Van')
# ('Hub Wien I-AT', 'Lisboa-PT', '2 Swap Bodies')
# ('Hub Wien I-AT', 'Lisboa-PT', 'Swap Body')
# ('Hub Wien I-AT', 'Lisboa-PT', 'Trailer')
# ('Hub Wien I-AT', 'Lisboa-PT', 'Van')
# ('Hub Graz-AT', 'Lisboa-PT', '2 Swap Bodies')
# ('Hub Graz-AT', 'Lisboa-PT', 'Swap Body')
# ('Hub Graz-AT', 'Lisboa-PT', 'Trailer')
# ('Hub Graz-AT', 'Lisboa-PT', 'Van')
# ('Hub Wien I-AT', 'Oradea-RO', '2 Swap Bodies')
# ('Hub Wien I-AT', 'Oradea-RO', 'Swap Body')
# ('Hub Wien I-AT', 'Oradea-RO', 'Trailer')
# ('Hub Wien I-AT', 'Oradea-RO', 'Van')
# ('Hub Graz-AT', 'Oradea-RO', '2 Swap Bodies')
# ('Hub Graz-AT', 'Oradea-RO', 'Swap Body')
# ('Hub Graz-AT', 'Oradea-RO', 'Trailer')
# ('Hub Graz-AT', 'Oradea-RO', 'Van')
# ('Hub Wien I-AT', 'Stockholm - Västberga-SE', '2 Swap Bodies')
# ('Hub Wien I-AT', 'Stockholm - Västberga-SE', 'Swap Body')
# ('Hub Wien I-AT', 'Stockholm - Västberga-SE', 'Trailer')
# ('Hub Wien I-AT', 'Stockholm - Västberga-SE', 'Van')
# ('Hub Wien I-AT', 'Helsingborg-SE', '2 Swap Bodies')
# ('Hub Wien I-AT', 'Helsingborg-SE', 'Swap Body')
# ('Hub Wien I-AT', 'Helsingborg-SE', 'Trailer')
# ('Hub Wien I-AT', 'Helsingborg-SE', 'Van')
# ('Hub Wien I-AT', 'Arlöv-SE', '2 Swap Bodies')
# ('Hub Wien I-AT', 'Arlöv-SE', 'Swap Body')
# ('Hub Wien I-AT', 'Arlöv-SE', 'Trailer')
# ('Hub Wien I-AT', 'Arlöv-SE', 'Van')
# ('Hub Wien I-AT', 'Malmö-SE', '2 Swap Bodies')
# ('Hub Wien I-AT', 'Malmö-SE', 'Swap Body')
# ('Hub Wien I-AT', 'Malmö-SE', 'Trailer')
# ('Hub Wien I-AT', 'Malmö-SE', 'Van')
# ('Hub Graz-AT', 'Stockholm - Västberga-SE', '2 Swap Bodies')
# ('Hub Graz-AT', 'Stockholm - Västberga-SE', 'Swap Body')
# ('Hub Graz-AT', 'Stockholm - Västberga-SE', 'Trailer')
# ('Hub Graz-AT', 'Stockholm - Västberga-SE', 'Van')
# ('Hub Graz-AT', 'Helsingborg-SE', '2 Swap Bodies')
# ('Hub Graz-AT', 'Helsingborg-SE', 'Swap Body')
# ('Hub Graz-AT', 'Helsingborg-SE', 'Trailer')
# ('Hub Graz-AT', 'Helsingborg-SE', 'Van')
# ('Hub Graz-AT', 'Arlöv-SE', '2 Swap Bodies')
# ('Hub Graz-AT', 'Arlöv-SE', 'Swap Body')
# ('Hub Graz-AT', 'Arlöv-SE', 'Trailer')
# ('Hub Graz-AT', 'Arlöv-SE', 'Van')
# ('Hub Graz-AT', 'Malmö-SE', '2 Swap Bodies')
# ('Hub Graz-AT', 'Malmö-SE', 'Swap Body')
# ('Hub Graz-AT', 'Malmö-SE', 'Trailer')
# ('Hub Graz-AT', 'Malmö-SE', 'Van')
# ('Hub Wien I-AT', 'Ljubljana-SI', '2 Swap Bodies')
# ('Hub Wien I-AT', 'Ljubljana-SI', 'Swap Body')
# ('Hub Wien I-AT', 'Ljubljana-SI', 'Trailer')
# ('Hub Wien I-AT', 'Ljubljana-SI', 'Van')
# ('Hub Graz-AT', 'Ljubljana-SI', '2 Swap Bodies')
# ('Hub Graz-AT', 'Ljubljana-SI', 'Swap Body')
# ('Hub Graz-AT', 'Ljubljana-SI', 'Trailer')
# ('Hub Graz-AT', 'Ljubljana-SI', 'Van')
# ('Hub Wien I-AT', 'Bratislava - Raca-SK', '2 Swap Bodies')
# ('Hub Wien I-AT', 'Bratislava - Raca-SK', 'Swap Body')
# ('Hub Wien I-AT', 'Bratislava - Raca-SK', 'Trailer')
# ('Hub Wien I-AT', 'Bratislava - Raca-SK', 'Van')
# ('Hub Wien I-AT', 'Bratislava - Petrzalka-SK', '2 Swap Bodies')
# ('Hub Wien I-AT', 'Bratislava - Petrzalka-SK', 'Swap Body')
# ('Hub Wien I-AT', 'Bratislava - Petrzalka-SK', 'Trailer')
# ('Hub Wien I-AT', 'Bratislava - Petrzalka-SK', 'Van')
# ('Hub Wien I-AT', 'Zilina- Strecno-SK', '2 Swap Bodies')
# ('Hub Wien I-AT', 'Zilina- Strecno-SK', 'Swap Body')
# ('Hub Wien I-AT', 'Zilina- Strecno-SK', 'Trailer')
# ('Hub Wien I-AT', 'Zilina- Strecno-SK', 'Van')
# ('Hub Graz-AT', 'Bratislava - Raca-SK', '2 Swap Bodies')
# ('Hub Graz-AT', 'Bratislava - Raca-SK', 'Swap Body')
# ('Hub Graz-AT', 'Bratislava - Raca-SK', 'Trailer')
# ('Hub Graz-AT', 'Bratislava - Raca-SK', 'Van')
# ('Hub Graz-AT', 'Bratislava - Petrzalka-SK', '2 Swap Bodies')
# ('Hub Graz-AT', 'Bratislava - Petrzalka-SK', 'Swap Body')
# ('Hub Graz-AT', 'Bratislava - Petrzalka-SK', 'Trailer')
# ('Hub Graz-AT', 'Bratislava - Petrzalka-SK', 'Van')
# ('Hub Graz-AT', 'Zilina- Strecno-SK', '2 Swap Bodies')
# ('Hub Graz-AT', 'Zilina- Strecno-SK', 'Swap Body')
# ('Hub Graz-AT', 'Zilina- Strecno-SK', 'Trailer')
# ('Hub Graz-AT', 'Zilina- Strecno-SK', 'Van')
# ('Brüssel-BE', 'Hub Wien I-AT', '2 Swap Bodies')
# ('Brüssel-BE', 'Hub Wien I-AT', 'Swap Body')
# ('Brüssel-BE', 'Hub Wien I-AT', 'Trailer')
# ('Brüssel-BE', 'Hub Wien I-AT', 'Van')
# ('Brüssel-BE', 'Hub Graz-AT', '2 Swap Bodies')
# ('Brüssel-BE', 'Hub Graz-AT', 'Swap Body')
# ('Brüssel-BE', 'Hub Graz-AT', 'Trailer')
# ('Brüssel-BE', 'Hub Graz-AT', 'Van')
# ('Brüssel-BE', 'Sofia-BG', '2 Swap Bodies')
# ('Brüssel-BE', 'Sofia-BG', 'Swap Body')
# ('Brüssel-BE', 'Sofia-BG', 'Trailer')
# ('Brüssel-BE', 'Sofia-BG', 'Van')
# ('Brüssel-BE', 'Brno-CZ', '2 Swap Bodies')
# ('Brüssel-BE', 'Brno-CZ', 'Swap Body')
# ('Brüssel-BE', 'Brno-CZ', 'Trailer')
# ('Brüssel-BE', 'Brno-CZ', 'Van')
# ('Brüssel-BE', 'Ostrava-CZ', '2 Swap Bodies')
# ('Brüssel-BE', 'Ostrava-CZ', 'Swap Body')
# ('Brüssel-BE', 'Ostrava-CZ', 'Trailer')
# ('Brüssel-BE', 'Ostrava-CZ', 'Van')
# ('Brüssel-BE', 'Krupka 1-CZ', '2 Swap Bodies')
# ('Brüssel-BE', 'Krupka 1-CZ', 'Swap Body')
# ('Brüssel-BE', 'Krupka 1-CZ', 'Trailer')
# ('Brüssel-BE', 'Krupka 1-CZ', 'Van')
# ('Brüssel-BE', 'Plzen 1-CZ', '2 Swap Bodies')
# ('Brüssel-BE', 'Plzen 1-CZ', 'Swap Body')
# ('Brüssel-BE', 'Plzen 1-CZ', 'Trailer')
# ('Brüssel-BE', 'Plzen 1-CZ', 'Van')
# ('Brüssel-BE', 'Hradec Kralove - Brezhrad-CZ', '2 Swap Bodies')
# ('Brüssel-BE', 'Hradec Kralove - Brezhrad-CZ', 'Swap Body')
# ('Brüssel-BE', 'Hradec Kralove - Brezhrad-CZ', 'Trailer')
# ('Brüssel-BE', 'Hradec Kralove - Brezhrad-CZ', 'Van')
# ('Brüssel-BE', 'PZ 67 (Speyer)-DE', '2 Swap Bodies')
# ('Brüssel-BE', 'PZ 67 (Speyer)-DE', 'Swap Body')
# ('Brüssel-BE', 'PZ 67 (Speyer)-DE', 'Trailer')
# ('Brüssel-BE', 'PZ 67 (Speyer)-DE', 'Van')
# ('Brüssel-BE', 'PZ 50 (Köln)-DE', '2 Swap Bodies')
# ('Brüssel-BE', 'PZ 50 (Köln)-DE', 'Swap Body')
# ('Brüssel-BE', 'PZ 50 (Köln)-DE', 'Trailer')
# ('Brüssel-BE', 'PZ 50 (Köln)-DE', 'Van')
# ('Brüssel-BE', 'PZ 04 (Radefeld/Leipzig)-DE', '2 Swap Bodies')
# ('Brüssel-BE', 'PZ 04 (Radefeld/Leipzig)-DE', 'Swap Body')
# ('Brüssel-BE', 'PZ 04 (Radefeld/Leipzig)-DE', 'Trailer')
# ('Brüssel-BE', 'PZ 04 (Radefeld/Leipzig)-DE', 'Van')
# ('Brüssel-BE', 'PZ 90 (Feucht/Nürnberg)-DE', '2 Swap Bodies')
# ('Brüssel-BE', 'PZ 90 (Feucht/Nürnberg)-DE', 'Swap Body')
# ('Brüssel-BE', 'PZ 90 (Feucht/Nürnberg)-DE', 'Trailer')
# ('Brüssel-BE', 'PZ 90 (Feucht/Nürnberg)-DE', 'Van')
# ('Brüssel-BE', 'PZ 77 (Lahr)-DE', '2 Swap Bodies')
# ('Brüssel-BE', 'PZ 77 (Lahr)-DE', 'Swap Body')
# ('Brüssel-BE', 'PZ 77 (Lahr)-DE', 'Trailer')
# ('Brüssel-BE', 'PZ 77 (Lahr)-DE', 'Van')
# ('Brüssel-BE', 'PZ 93 (Regensburg)-DE', '2 Swap Bodies')
# ('Brüssel-BE', 'PZ 93 (Regensburg)-DE', 'Swap Body')
# ('Brüssel-BE', 'PZ 93 (Regensburg)-DE', 'Trailer')
# ('Brüssel-BE', 'PZ 93 (Regensburg)-DE', 'Van')
# ('Brüssel-BE', 'PZ 21 (Hamburg)-DE', '2 Swap Bodies')
# ('Brüssel-BE', 'PZ 21 (Hamburg)-DE', 'Swap Body')
# ('Brüssel-BE', 'PZ 21 (Hamburg)-DE', 'Trailer')
# ('Brüssel-BE', 'PZ 21 (Hamburg)-DE', 'Van')
# ('Brüssel-BE', 'PZ 46 (Dorsten)-DE', '2 Swap Bodies')
# ('Brüssel-BE', 'PZ 46 (Dorsten)-DE', 'Swap Body')
# ('Brüssel-BE', 'PZ 46 (Dorsten)-DE', 'Trailer')
# ('Brüssel-BE', 'PZ 46 (Dorsten)-DE', 'Van')
# ('Brüssel-BE', 'PZ 58 (Hagen)-DE', '2 Swap Bodies')
# ('Brüssel-BE', 'PZ 58 (Hagen)-DE', 'Swap Body')
# ('Brüssel-BE', 'PZ 58 (Hagen)-DE', 'Trailer')
# ('Brüssel-BE', 'PZ 58 (Hagen)-DE', 'Van')
# ('Brüssel-BE', 'PZ 08 (Neumark)-DE', '2 Swap Bodies')
# ('Brüssel-BE', 'PZ 08 (Neumark)-DE', 'Swap Body')
# ('Brüssel-BE', 'PZ 08 (Neumark)-DE', 'Trailer')
# ('Brüssel-BE', 'PZ 08 (Neumark)-DE', 'Van')
# ('Brüssel-BE', 'PZ 47 (Krefeld)-DE', '2 Swap Bodies')
# ('Brüssel-BE', 'PZ 47 (Krefeld)-DE', 'Swap Body')
# ('Brüssel-BE', 'PZ 47 (Krefeld)-DE', 'Trailer')
# ('Brüssel-BE', 'PZ 47 (Krefeld)-DE', 'Van')
# ('Brüssel-BE', 'PZ 15 (Rüdersdorf)-DE', '2 Swap Bodies')
# ('Brüssel-BE', 'PZ 15 (Rüdersdorf)-DE', 'Swap Body')
# ('Brüssel-BE', 'PZ 15 (Rüdersdorf)-DE', 'Trailer')
# ('Brüssel-BE', 'PZ 15 (Rüdersdorf)-DE', 'Van')
# ('Brüssel-BE', 'Kolding-DK', '2 Swap Bodies')
# ('Brüssel-BE', 'Kolding-DK', 'Swap Body')
# ('Brüssel-BE', 'Kolding-DK', 'Trailer')
# ('Brüssel-BE', 'Kolding-DK', 'Van')
# ('Brüssel-BE', 'Barcelona-ES', '2 Swap Bodies')
# ('Brüssel-BE', 'Barcelona-ES', 'Swap Body')
# ('Brüssel-BE', 'Barcelona-ES', 'Trailer')
# ('Brüssel-BE', 'Barcelona-ES', 'Van')
# ('Brüssel-BE', 'Madrid-ES', '2 Swap Bodies')
# ('Brüssel-BE', 'Madrid-ES', 'Swap Body')
# ('Brüssel-BE', 'Madrid-ES', 'Trailer')
# ('Brüssel-BE', 'Madrid-ES', 'Van')
# ('Brüssel-BE', 'Araba (Vitoria)-ES', '2 Swap Bodies')
# ('Brüssel-BE', 'Araba (Vitoria)-ES', 'Swap Body')
# ('Brüssel-BE', 'Araba (Vitoria)-ES', 'Trailer')
# ('Brüssel-BE', 'Araba (Vitoria)-ES', 'Van')
# ('Brüssel-BE', 'Combs la ville-FR', '2 Swap Bodies')
# ('Brüssel-BE', 'Combs la ville-FR', 'Swap Body')
# ('Brüssel-BE', 'Combs la ville-FR', 'Trailer')
# ('Brüssel-BE', 'Combs la ville-FR', 'Van')
# ('Brüssel-BE', 'Slough-GB', '2 Swap Bodies')
# ('Brüssel-BE', 'Slough-GB', 'Swap Body')
# ('Brüssel-BE', 'Slough-GB', 'Trailer')
# ('Brüssel-BE', 'Slough-GB', 'Van')
# ('Brüssel-BE', 'Ryton Gateway-GB', '2 Swap Bodies')
# ('Brüssel-BE', 'Ryton Gateway-GB', 'Swap Body')
# ('Brüssel-BE', 'Ryton Gateway-GB', 'Trailer')
# ('Brüssel-BE', 'Ryton Gateway-GB', 'Van')
# ('Brüssel-BE', 'Spata-GR', '2 Swap Bodies')
# ('Brüssel-BE', 'Spata-GR', 'Swap Body')
# ('Brüssel-BE', 'Spata-GR', 'Trailer')
# ('Brüssel-BE', 'Spata-GR', 'Van')
# ('Brüssel-BE', 'Zagreb-HR', '2 Swap Bodies')
# ('Brüssel-BE', 'Zagreb-HR', 'Swap Body')
# ('Brüssel-BE', 'Zagreb-HR', 'Trailer')
# ('Brüssel-BE', 'Zagreb-HR', 'Van')
# ('Brüssel-BE', 'Budapest OLK-HU', '2 Swap Bodies')
# ('Brüssel-BE', 'Budapest OLK-HU', 'Swap Body')
# ('Brüssel-BE', 'Budapest OLK-HU', 'Trailer')
# ('Brüssel-BE', 'Budapest OLK-HU', 'Van')
# ('Brüssel-BE', 'Budapest NPKK (OE)-HU', '2 Swap Bodies')
# ('Brüssel-BE', 'Budapest NPKK (OE)-HU', 'Swap Body')
# ('Brüssel-BE', 'Budapest NPKK (OE)-HU', 'Trailer')
# ('Brüssel-BE', 'Budapest NPKK (OE)-HU', 'Van')
# ('Brüssel-BE', 'Portlaoise-IE', '2 Swap Bodies')
# ('Brüssel-BE', 'Portlaoise-IE', 'Swap Body')
# ('Brüssel-BE', 'Portlaoise-IE', 'Trailer')
# ('Brüssel-BE', 'Portlaoise-IE', 'Van')
# ('Brüssel-BE', 'Kaunas-LT', '2 Swap Bodies')
# ('Brüssel-BE', 'Kaunas-LT', 'Swap Body')
# ('Brüssel-BE', 'Kaunas-LT', 'Trailer')
# ('Brüssel-BE', 'Kaunas-LT', 'Van')
# ('Brüssel-BE', 'Bettembourg-LU', '2 Swap Bodies')
# ('Brüssel-BE', 'Bettembourg-LU', 'Swap Body')
# ('Brüssel-BE', 'Bettembourg-LU', 'Trailer')
# ('Brüssel-BE', 'Bettembourg-LU', 'Van')
# ('Brüssel-BE', 'Eindhoven-Noord-NL', '2 Swap Bodies')
# ('Brüssel-BE', 'Eindhoven-Noord-NL', 'Swap Body')
# ('Brüssel-BE', 'Eindhoven-Noord-NL', 'Trailer')
# ('Brüssel-BE', 'Eindhoven-Noord-NL', 'Van')
# ('Brüssel-BE', 'Utrecht-West + Centrum-NL', '2 Swap Bodies')
# ('Brüssel-BE', 'Utrecht-West + Centrum-NL', 'Swap Body')
# ('Brüssel-BE', 'Utrecht-West + Centrum-NL', 'Trailer')
# ('Brüssel-BE', 'Utrecht-West + Centrum-NL', 'Van')
# ('Brüssel-BE', 'Zaltbommel-NL', '2 Swap Bodies')
# ('Brüssel-BE', 'Zaltbommel-NL', 'Swap Body')
# ('Brüssel-BE', 'Zaltbommel-NL', 'Trailer')
# ('Brüssel-BE', 'Zaltbommel-NL', 'Van')
# ('Brüssel-BE', 'Oslo-NO', '2 Swap Bodies')
# ('Brüssel-BE', 'Oslo-NO', 'Swap Body')
# ('Brüssel-BE', 'Oslo-NO', 'Trailer')
# ('Brüssel-BE', 'Oslo-NO', 'Van')
# ('Brüssel-BE', 'Suwałki (Ełk)-PL', '2 Swap Bodies')
# ('Brüssel-BE', 'Suwałki (Ełk)-PL', 'Swap Body')
# ('Brüssel-BE', 'Suwałki (Ełk)-PL', 'Trailer')
# ('Brüssel-BE', 'Suwałki (Ełk)-PL', 'Van')
# ('Brüssel-BE', 'Poznań-PL', '2 Swap Bodies')
# ('Brüssel-BE', 'Poznań-PL', 'Swap Body')
# ('Brüssel-BE', 'Poznań-PL', 'Trailer')
# ('Brüssel-BE', 'Poznań-PL', 'Van')
# ('Brüssel-BE', 'Zabrze-PL', '2 Swap Bodies')
# ('Brüssel-BE', 'Zabrze-PL', 'Swap Body')
# ('Brüssel-BE', 'Zabrze-PL', 'Trailer')
# ('Brüssel-BE', 'Zabrze-PL', 'Van')
# ('Brüssel-BE', 'Koninko-PL', '2 Swap Bodies')
# ('Brüssel-BE', 'Koninko-PL', 'Swap Body')
# ('Brüssel-BE', 'Koninko-PL', 'Trailer')
# ('Brüssel-BE', 'Koninko-PL', 'Van')
# ('Brüssel-BE', 'Wrocław-PL', '2 Swap Bodies')
# ('Brüssel-BE', 'Wrocław-PL', 'Swap Body')
# ('Brüssel-BE', 'Wrocław-PL', 'Trailer')
# ('Brüssel-BE', 'Wrocław-PL', 'Van')
# ('Brüssel-BE', 'Bydgoszcz (Solec Kujawski)-PL', '2 Swap Bodies')
# ('Brüssel-BE', 'Bydgoszcz (Solec Kujawski)-PL', 'Swap Body')
# ('Brüssel-BE', 'Bydgoszcz (Solec Kujawski)-PL', 'Trailer')
# ('Brüssel-BE', 'Bydgoszcz (Solec Kujawski)-PL', 'Van')
# ('Brüssel-BE', 'Lisboa-PT', '2 Swap Bodies')
# ('Brüssel-BE', 'Lisboa-PT', 'Swap Body')
# ('Brüssel-BE', 'Lisboa-PT', 'Trailer')
# ('Brüssel-BE', 'Lisboa-PT', 'Van')
# ('Brüssel-BE', 'Oradea-RO', '2 Swap Bodies')
# ('Brüssel-BE', 'Oradea-RO', 'Swap Body')
# ('Brüssel-BE', 'Oradea-RO', 'Trailer')
# ('Brüssel-BE', 'Oradea-RO', 'Van')
# ('Brüssel-BE', 'Stockholm - Västberga-SE', '2 Swap Bodies')
# ('Brüssel-BE', 'Stockholm - Västberga-SE', 'Swap Body')
# ('Brüssel-BE', 'Stockholm - Västberga-SE', 'Trailer')
# ('Brüssel-BE', 'Stockholm - Västberga-SE', 'Van')
# ('Brüssel-BE', 'Helsingborg-SE', '2 Swap Bodies')
# ('Brüssel-BE', 'Helsingborg-SE', 'Swap Body')
# ('Brüssel-BE', 'Helsingborg-SE', 'Trailer')
# ('Brüssel-BE', 'Helsingborg-SE', 'Van')
# ('Brüssel-BE', 'Arlöv-SE', '2 Swap Bodies')
# ('Brüssel-BE', 'Arlöv-SE', 'Swap Body')
# ('Brüssel-BE', 'Arlöv-SE', 'Trailer')
# ('Brüssel-BE', 'Arlöv-SE', 'Van')
# ('Brüssel-BE', 'Malmö-SE', '2 Swap Bodies')
# ('Brüssel-BE', 'Malmö-SE', 'Swap Body')
# ('Brüssel-BE', 'Malmö-SE', 'Trailer')
# ('Brüssel-BE', 'Malmö-SE', 'Van')
# ('Brüssel-BE', 'Ljubljana-SI', '2 Swap Bodies')
# ('Brüssel-BE', 'Ljubljana-SI', 'Swap Body')
# ('Brüssel-BE', 'Ljubljana-SI', 'Trailer')
# ('Brüssel-BE', 'Ljubljana-SI', 'Van')
# ('Brüssel-BE', 'Bratislava - Raca-SK', '2 Swap Bodies')
# ('Brüssel-BE', 'Bratislava - Raca-SK', 'Swap Body')
# ('Brüssel-BE', 'Bratislava - Raca-SK', 'Trailer')
# ('Brüssel-BE', 'Bratislava - Raca-SK', 'Van')
# ('Brüssel-BE', 'Bratislava - Petrzalka-SK', '2 Swap Bodies')
# ('Brüssel-BE', 'Bratislava - Petrzalka-SK', 'Swap Body')
# ('Brüssel-BE', 'Bratislava - Petrzalka-SK', 'Trailer')
# ('Brüssel-BE', 'Bratislava - Petrzalka-SK', 'Van')
# ('Brüssel-BE', 'Zilina- Strecno-SK', '2 Swap Bodies')
# ('Brüssel-BE', 'Zilina- Strecno-SK', 'Swap Body')
# ('Brüssel-BE', 'Zilina- Strecno-SK', 'Trailer')
# ('Brüssel-BE', 'Zilina- Strecno-SK', 'Van')
# ('Sofia-BG', 'Hub Wien I-AT', '2 Swap Bodies')
# ('Sofia-BG', 'Hub Wien I-AT', 'Swap Body')
# ('Sofia-BG', 'Hub Wien I-AT', 'Trailer')
# ('Sofia-BG', 'Hub Wien I-AT', 'Van')
# ('Sofia-BG', 'Hub Graz-AT', '2 Swap Bodies')
# ('Sofia-BG', 'Hub Graz-AT', 'Swap Body')
# ('Sofia-BG', 'Hub Graz-AT', 'Trailer')
# ('Sofia-BG', 'Hub Graz-AT', 'Van')
# ('Sofia-BG', 'Brüssel-BE', '2 Swap Bodies')
# ('Sofia-BG', 'Brüssel-BE', 'Swap Body')
# ('Sofia-BG', 'Brüssel-BE', 'Trailer')
# ('Sofia-BG', 'Brüssel-BE', 'Van')
# ('Sofia-BG', 'Brno-CZ', '2 Swap Bodies')
# ('Sofia-BG', 'Brno-CZ', 'Swap Body')
# ('Sofia-BG', 'Brno-CZ', 'Trailer')
# ('Sofia-BG', 'Brno-CZ', 'Van')
# ('Sofia-BG', 'Ostrava-CZ', '2 Swap Bodies')
# ('Sofia-BG', 'Ostrava-CZ', 'Swap Body')
# ('Sofia-BG', 'Ostrava-CZ', 'Trailer')
# ('Sofia-BG', 'Ostrava-CZ', 'Van')
# ('Sofia-BG', 'Krupka 1-CZ', '2 Swap Bodies')
# ('Sofia-BG', 'Krupka 1-CZ', 'Swap Body')
# ('Sofia-BG', 'Krupka 1-CZ', 'Trailer')
# ('Sofia-BG', 'Krupka 1-CZ', 'Van')
# ('Sofia-BG', 'Plzen 1-CZ', '2 Swap Bodies')
# ('Sofia-BG', 'Plzen 1-CZ', 'Swap Body')
# ('Sofia-BG', 'Plzen 1-CZ', 'Trailer')
# ('Sofia-BG', 'Plzen 1-CZ', 'Van')
# ('Sofia-BG', 'Hradec Kralove - Brezhrad-CZ', '2 Swap Bodies')
# ('Sofia-BG', 'Hradec Kralove - Brezhrad-CZ', 'Swap Body')
# ('Sofia-BG', 'Hradec Kralove - Brezhrad-CZ', 'Trailer')
# ('Sofia-BG', 'Hradec Kralove - Brezhrad-CZ', 'Van')
# ('Sofia-BG', 'PZ 67 (Speyer)-DE', '2 Swap Bodies')
# ('Sofia-BG', 'PZ 67 (Speyer)-DE', 'Swap Body')
# ('Sofia-BG', 'PZ 67 (Speyer)-DE', 'Trailer')
# ('Sofia-BG', 'PZ 67 (Speyer)-DE', 'Van')
# ('Sofia-BG', 'PZ 50 (Köln)-DE', '2 Swap Bodies')
# ('Sofia-BG', 'PZ 50 (Köln)-DE', 'Swap Body')
# ('Sofia-BG', 'PZ 50 (Köln)-DE', 'Trailer')
# ('Sofia-BG', 'PZ 50 (Köln)-DE', 'Van')
# ('Sofia-BG', 'PZ 04 (Radefeld/Leipzig)-DE', '2 Swap Bodies')
# ('Sofia-BG', 'PZ 04 (Radefeld/Leipzig)-DE', 'Swap Body')
# ('Sofia-BG', 'PZ 04 (Radefeld/Leipzig)-DE', 'Trailer')
# ('Sofia-BG', 'PZ 04 (Radefeld/Leipzig)-DE', 'Van')
# ('Sofia-BG', 'PZ 90 (Feucht/Nürnberg)-DE', '2 Swap Bodies')
# ('Sofia-BG', 'PZ 90 (Feucht/Nürnberg)-DE', 'Swap Body')
# ('Sofia-BG', 'PZ 90 (Feucht/Nürnberg)-DE', 'Trailer')
# ('Sofia-BG', 'PZ 90 (Feucht/Nürnberg)-DE', 'Van')
# ('Sofia-BG', 'PZ 77 (Lahr)-DE', '2 Swap Bodies')
# ('Sofia-BG', 'PZ 77 (Lahr)-DE', 'Swap Body')
# ('Sofia-BG', 'PZ 77 (Lahr)-DE', 'Trailer')
# ('Sofia-BG', 'PZ 77 (Lahr)-DE', 'Van')
# ('Sofia-BG', 'PZ 93 (Regensburg)-DE', '2 Swap Bodies')
# ('Sofia-BG', 'PZ 93 (Regensburg)-DE', 'Swap Body')
# ('Sofia-BG', 'PZ 93 (Regensburg)-DE', 'Trailer')
# ('Sofia-BG', 'PZ 93 (Regensburg)-DE', 'Van')
# ('Sofia-BG', 'PZ 21 (Hamburg)-DE', '2 Swap Bodies')
# ('Sofia-BG', 'PZ 21 (Hamburg)-DE', 'Swap Body')
# ('Sofia-BG', 'PZ 21 (Hamburg)-DE', 'Trailer')
# ('Sofia-BG', 'PZ 21 (Hamburg)-DE', 'Van')
# ('Sofia-BG', 'PZ 46 (Dorsten)-DE', '2 Swap Bodies')
# ('Sofia-BG', 'PZ 46 (Dorsten)-DE', 'Swap Body')
# ('Sofia-BG', 'PZ 46 (Dorsten)-DE', 'Trailer')
# ('Sofia-BG', 'PZ 46 (Dorsten)-DE', 'Van')
# ('Sofia-BG', 'PZ 58 (Hagen)-DE', '2 Swap Bodies')
# ('Sofia-BG', 'PZ 58 (Hagen)-DE', 'Swap Body')
# ('Sofia-BG', 'PZ 58 (Hagen)-DE', 'Trailer')
# ('Sofia-BG', 'PZ 58 (Hagen)-DE', 'Van')
# ('Sofia-BG', 'PZ 08 (Neumark)-DE', '2 Swap Bodies')
# ('Sofia-BG', 'PZ 08 (Neumark)-DE', 'Swap Body')
# ('Sofia-BG', 'PZ 08 (Neumark)-DE', 'Trailer')
# ('Sofia-BG', 'PZ 08 (Neumark)-DE', 'Van')
# ('Sofia-BG', 'PZ 47 (Krefeld)-DE', '2 Swap Bodies')
# ('Sofia-BG', 'PZ 47 (Krefeld)-DE', 'Swap Body')
# ('Sofia-BG', 'PZ 47 (Krefeld)-DE', 'Trailer')
# ('Sofia-BG', 'PZ 47 (Krefeld)-DE', 'Van')
# ('Sofia-BG', 'PZ 15 (Rüdersdorf)-DE', '2 Swap Bodies')
# ('Sofia-BG', 'PZ 15 (Rüdersdorf)-DE', 'Swap Body')
# ('Sofia-BG', 'PZ 15 (Rüdersdorf)-DE', 'Trailer')
# ('Sofia-BG', 'PZ 15 (Rüdersdorf)-DE', 'Van')
# ('Sofia-BG', 'Kolding-DK', '2 Swap Bodies')
# ('Sofia-BG', 'Kolding-DK', 'Swap Body')
# ('Sofia-BG', 'Kolding-DK', 'Trailer')
# ('Sofia-BG', 'Kolding-DK', 'Van')
# ('Sofia-BG', 'Barcelona-ES', '2 Swap Bodies')
# ('Sofia-BG', 'Barcelona-ES', 'Swap Body')
# ('Sofia-BG', 'Barcelona-ES', 'Trailer')
# ('Sofia-BG', 'Barcelona-ES', 'Van')
# ('Sofia-BG', 'Madrid-ES', '2 Swap Bodies')
# ('Sofia-BG', 'Madrid-ES', 'Swap Body')
# ('Sofia-BG', 'Madrid-ES', 'Trailer')
# ('Sofia-BG', 'Madrid-ES', 'Van')
# ('Sofia-BG', 'Araba (Vitoria)-ES', '2 Swap Bodies')
# ('Sofia-BG', 'Araba (Vitoria)-ES', 'Swap Body')
# ('Sofia-BG', 'Araba (Vitoria)-ES', 'Trailer')
# ('Sofia-BG', 'Araba (Vitoria)-ES', 'Van')
# ('Sofia-BG', 'Combs la ville-FR', '2 Swap Bodies')
# ('Sofia-BG', 'Combs la ville-FR', 'Swap Body')
# ('Sofia-BG', 'Combs la ville-FR', 'Trailer')
# ('Sofia-BG', 'Combs la ville-FR', 'Van')
# ('Sofia-BG', 'Slough-GB', '2 Swap Bodies')
# ('Sofia-BG', 'Slough-GB', 'Swap Body')
# ('Sofia-BG', 'Slough-GB', 'Trailer')
# ('Sofia-BG', 'Slough-GB', 'Van')
# ('Sofia-BG', 'Ryton Gateway-GB', '2 Swap Bodies')
# ('Sofia-BG', 'Ryton Gateway-GB', 'Swap Body')
# ('Sofia-BG', 'Ryton Gateway-GB', 'Trailer')
# ('Sofia-BG', 'Ryton Gateway-GB', 'Van')
# ('Sofia-BG', 'Spata-GR', '2 Swap Bodies')
# ('Sofia-BG', 'Spata-GR', 'Swap Body')
# ('Sofia-BG', 'Spata-GR', 'Trailer')
# ('Sofia-BG', 'Spata-GR', 'Van')
# ('Sofia-BG', 'Zagreb-HR', '2 Swap Bodies')
# ('Sofia-BG', 'Zagreb-HR', 'Swap Body')
# ('Sofia-BG', 'Zagreb-HR', 'Trailer')
# ('Sofia-BG', 'Zagreb-HR', 'Van')
# ('Sofia-BG', 'Budapest OLK-HU', '2 Swap Bodies')
# ('Sofia-BG', 'Budapest OLK-HU', 'Swap Body')
# ('Sofia-BG', 'Budapest OLK-HU', 'Trailer')
# ('Sofia-BG', 'Budapest OLK-HU', 'Van')
# ('Sofia-BG', 'Budapest NPKK (OE)-HU', '2 Swap Bodies')
# ('Sofia-BG', 'Budapest NPKK (OE)-HU', 'Swap Body')
# ('Sofia-BG', 'Budapest NPKK (OE)-HU', 'Trailer')
# ('Sofia-BG', 'Budapest NPKK (OE)-HU', 'Van')
# ('Sofia-BG', 'Portlaoise-IE', '2 Swap Bodies')
# ('Sofia-BG', 'Portlaoise-IE', 'Swap Body')
# ('Sofia-BG', 'Portlaoise-IE', 'Trailer')
# ('Sofia-BG', 'Portlaoise-IE', 'Van')
# ('Sofia-BG', 'Kaunas-LT', '2 Swap Bodies')
# ('Sofia-BG', 'Kaunas-LT', 'Swap Body')
# ('Sofia-BG', 'Kaunas-LT', 'Trailer')
# ('Sofia-BG', 'Kaunas-LT', 'Van')
# ('Sofia-BG', 'Bettembourg-LU', '2 Swap Bodies')
# ('Sofia-BG', 'Bettembourg-LU', 'Swap Body')
# ('Sofia-BG', 'Bettembourg-LU', 'Trailer')
# ('Sofia-BG', 'Bettembourg-LU', 'Van')
# ('Sofia-BG', 'Eindhoven-Noord-NL', '2 Swap Bodies')
# ('Sofia-BG', 'Eindhoven-Noord-NL', 'Swap Body')
# ('Sofia-BG', 'Eindhoven-Noord-NL', 'Trailer')
# ('Sofia-BG', 'Eindhoven-Noord-NL', 'Van')
# ('Sofia-BG', 'Utrecht-West + Centrum-NL', '2 Swap Bodies')
# ('Sofia-BG', 'Utrecht-West + Centrum-NL', 'Swap Body')
# ('Sofia-BG', 'Utrecht-West + Centrum-NL', 'Trailer')
# ('Sofia-BG', 'Utrecht-West + Centrum-NL', 'Van')
# ('Sofia-BG', 'Zaltbommel-NL', '2 Swap Bodies')
# ('Sofia-BG', 'Zaltbommel-NL', 'Swap Body')
# ('Sofia-BG', 'Zaltbommel-NL', 'Trailer')
# ('Sofia-BG', 'Zaltbommel-NL', 'Van')
# ('Sofia-BG', 'Oslo-NO', '2 Swap Bodies')
# ('Sofia-BG', 'Oslo-NO', 'Swap Body')
# ('Sofia-BG', 'Oslo-NO', 'Trailer')
# ('Sofia-BG', 'Oslo-NO', 'Van')
# ('Sofia-BG', 'Suwałki (Ełk)-PL', '2 Swap Bodies')
# ('Sofia-BG', 'Suwałki (Ełk)-PL', 'Swap Body')
# ('Sofia-BG', 'Suwałki (Ełk)-PL', 'Trailer')
# ('Sofia-BG', 'Suwałki (Ełk)-PL', 'Van')
# ('Sofia-BG', 'Poznań-PL', '2 Swap Bodies')
# ('Sofia-BG', 'Poznań-PL', 'Swap Body')
# ('Sofia-BG', 'Poznań-PL', 'Trailer')
# ('Sofia-BG', 'Poznań-PL', 'Van')
# ('Sofia-BG', 'Zabrze-PL', '2 Swap Bodies')
# ('Sofia-BG', 'Zabrze-PL', 'Swap Body')
# ('Sofia-BG', 'Zabrze-PL', 'Trailer')
# ('Sofia-BG', 'Zabrze-PL', 'Van')
# ('Sofia-BG', 'Koninko-PL', '2 Swap Bodies')
# ('Sofia-BG', 'Koninko-PL', 'Swap Body')
# ('Sofia-BG', 'Koninko-PL', 'Trailer')
# ('Sofia-BG', 'Koninko-PL', 'Van')
# ('Sofia-BG', 'Wrocław-PL', '2 Swap Bodies')
# ('Sofia-BG', 'Wrocław-PL', 'Swap Body')
# ('Sofia-BG', 'Wrocław-PL', 'Trailer')
# ('Sofia-BG', 'Wrocław-PL', 'Van')
# ('Sofia-BG', 'Bydgoszcz (Solec Kujawski)-PL', '2 Swap Bodies')
# ('Sofia-BG', 'Bydgoszcz (Solec Kujawski)-PL', 'Swap Body')
# ('Sofia-BG', 'Bydgoszcz (Solec Kujawski)-PL', 'Trailer')
# ('Sofia-BG', 'Bydgoszcz (Solec Kujawski)-PL', 'Van')
# ('Sofia-BG', 'Lisboa-PT', '2 Swap Bodies')
# ('Sofia-BG', 'Lisboa-PT', 'Swap Body')
# ('Sofia-BG', 'Lisboa-PT', 'Trailer')
# ('Sofia-BG', 'Lisboa-PT', 'Van')
# ('Sofia-BG', 'Oradea-RO', '2 Swap Bodies')
# ('Sofia-BG', 'Oradea-RO', 'Swap Body')
# ('Sofia-BG', 'Oradea-RO', 'Trailer')
# ('Sofia-BG', 'Oradea-RO', 'Van')
# ('Sofia-BG', 'Stockholm - Västberga-SE', '2 Swap Bodies')
# ('Sofia-BG', 'Stockholm - Västberga-SE', 'Swap Body')
# ('Sofia-BG', 'Stockholm - Västberga-SE', 'Trailer')
# ('Sofia-BG', 'Stockholm - Västberga-SE', 'Van')
# ('Sofia-BG', 'Helsingborg-SE', '2 Swap Bodies')
# ('Sofia-BG', 'Helsingborg-SE', 'Swap Body')
# ('Sofia-BG', 'Helsingborg-SE', 'Trailer')
# ('Sofia-BG', 'Helsingborg-SE', 'Van')
# ('Sofia-BG', 'Arlöv-SE', '2 Swap Bodies')
# ('Sofia-BG', 'Arlöv-SE', 'Swap Body')
# ('Sofia-BG', 'Arlöv-SE', 'Trailer')
# ('Sofia-BG', 'Arlöv-SE', 'Van')
# ('Sofia-BG', 'Malmö-SE', '2 Swap Bodies')
# ('Sofia-BG', 'Malmö-SE', 'Swap Body')
# ('Sofia-BG', 'Malmö-SE', 'Trailer')
# ('Sofia-BG', 'Malmö-SE', 'Van')
# ('Sofia-BG', 'Ljubljana-SI', '2 Swap Bodies')
# ('Sofia-BG', 'Ljubljana-SI', 'Swap Body')
# ('Sofia-BG', 'Ljubljana-SI', 'Trailer')
# ('Sofia-BG', 'Ljubljana-SI', 'Van')
# ('Sofia-BG', 'Bratislava - Raca-SK', '2 Swap Bodies')
# ('Sofia-BG', 'Bratislava - Raca-SK', 'Swap Body')
# ('Sofia-BG', 'Bratislava - Raca-SK', 'Trailer')
# ('Sofia-BG', 'Bratislava - Raca-SK', 'Van')
# ('Sofia-BG', 'Bratislava - Petrzalka-SK', '2 Swap Bodies')
# ('Sofia-BG', 'Bratislava - Petrzalka-SK', 'Swap Body')
# ('Sofia-BG', 'Bratislava - Petrzalka-SK', 'Trailer')
# ('Sofia-BG', 'Bratislava - Petrzalka-SK', 'Van')
# ('Sofia-BG', 'Zilina- Strecno-SK', '2 Swap Bodies')
# ('Sofia-BG', 'Zilina- Strecno-SK', 'Swap Body')
# ('Sofia-BG', 'Zilina- Strecno-SK', 'Trailer')
# ('Sofia-BG', 'Zilina- Strecno-SK', 'Van')
# ('Brno-CZ', 'Hub Wien I-AT', '2 Swap Bodies')
# ('Brno-CZ', 'Hub Wien I-AT', 'Swap Body')
# ('Brno-CZ', 'Hub Wien I-AT', 'Trailer')
# ('Brno-CZ', 'Hub Wien I-AT', 'Van')
# ('Brno-CZ', 'Hub Graz-AT', '2 Swap Bodies')
# ('Brno-CZ', 'Hub Graz-AT', 'Swap Body')
# ('Brno-CZ', 'Hub Graz-AT', 'Trailer')
# ('Brno-CZ', 'Hub Graz-AT', 'Van')
# ('Ostrava-CZ', 'Hub Wien I-AT', '2 Swap Bodies')
# ('Ostrava-CZ', 'Hub Wien I-AT', 'Swap Body')
# ('Ostrava-CZ', 'Hub Wien I-AT', 'Trailer')
# ('Ostrava-CZ', 'Hub Wien I-AT', 'Van')
# ('Ostrava-CZ', 'Hub Graz-AT', '2 Swap Bodies')
# ('Ostrava-CZ', 'Hub Graz-AT', 'Swap Body')
# ('Ostrava-CZ', 'Hub Graz-AT', 'Trailer')
# ('Ostrava-CZ', 'Hub Graz-AT', 'Van')
# ('Krupka 1-CZ', 'Hub Wien I-AT', '2 Swap Bodies')
# ('Krupka 1-CZ', 'Hub Wien I-AT', 'Swap Body')
# ('Krupka 1-CZ', 'Hub Wien I-AT', 'Trailer')
# ('Krupka 1-CZ', 'Hub Wien I-AT', 'Van')
# ('Krupka 1-CZ', 'Hub Graz-AT', '2 Swap Bodies')
# ('Krupka 1-CZ', 'Hub Graz-AT', 'Swap Body')
# ('Krupka 1-CZ', 'Hub Graz-AT', 'Trailer')
# ('Krupka 1-CZ', 'Hub Graz-AT', 'Van')
# ('Plzen 1-CZ', 'Hub Wien I-AT', '2 Swap Bodies')
# ('Plzen 1-CZ', 'Hub Wien I-AT', 'Swap Body')
# ('Plzen 1-CZ', 'Hub Wien I-AT', 'Trailer')
# ('Plzen 1-CZ', 'Hub Wien I-AT', 'Van')
# ('Plzen 1-CZ', 'Hub Graz-AT', '2 Swap Bodies')
# ('Plzen 1-CZ', 'Hub Graz-AT', 'Swap Body')
# ('Plzen 1-CZ', 'Hub Graz-AT', 'Trailer')
# ('Plzen 1-CZ', 'Hub Graz-AT', 'Van')
# ('Hradec Kralove - Brezhrad-CZ', 'Hub Wien I-AT', '2 Swap Bodies')
# ('Hradec Kralove - Brezhrad-CZ', 'Hub Wien I-AT', 'Swap Body')
# ('Hradec Kralove - Brezhrad-CZ', 'Hub Wien I-AT', 'Trailer')
# ('Hradec Kralove - Brezhrad-CZ', 'Hub Wien I-AT', 'Van')
# ('Hradec Kralove - Brezhrad-CZ', 'Hub Graz-AT', '2 Swap Bodies')
# ('Hradec Kralove - Brezhrad-CZ', 'Hub Graz-AT', 'Swap Body')
# ('Hradec Kralove - Brezhrad-CZ', 'Hub Graz-AT', 'Trailer')
# ('Hradec Kralove - Brezhrad-CZ', 'Hub Graz-AT', 'Van')
# ('Brno-CZ', 'Brüssel-BE', '2 Swap Bodies')
# ('Brno-CZ', 'Brüssel-BE', 'Swap Body')
# ('Brno-CZ', 'Brüssel-BE', 'Trailer')
# ('Brno-CZ', 'Brüssel-BE', 'Van')
# ('Ostrava-CZ', 'Brüssel-BE', '2 Swap Bodies')
# ('Ostrava-CZ', 'Brüssel-BE', 'Swap Body')
# ('Ostrava-CZ', 'Brüssel-BE', 'Trailer')
# ('Ostrava-CZ', 'Brüssel-BE', 'Van')
# ('Krupka 1-CZ', 'Brüssel-BE', '2 Swap Bodies')
# ('Krupka 1-CZ', 'Brüssel-BE', 'Swap Body')
# ('Krupka 1-CZ', 'Brüssel-BE', 'Trailer')
# ('Krupka 1-CZ', 'Brüssel-BE', 'Van')
# ('Plzen 1-CZ', 'Brüssel-BE', '2 Swap Bodies')
# ('Plzen 1-CZ', 'Brüssel-BE', 'Swap Body')
# ('Plzen 1-CZ', 'Brüssel-BE', 'Trailer')
# ('Plzen 1-CZ', 'Brüssel-BE', 'Van')
# ('Hradec Kralove - Brezhrad-CZ', 'Brüssel-BE', '2 Swap Bodies')
# ('Hradec Kralove - Brezhrad-CZ', 'Brüssel-BE', 'Swap Body')
# ('Hradec Kralove - Brezhrad-CZ', 'Brüssel-BE', 'Trailer')
# ('Hradec Kralove - Brezhrad-CZ', 'Brüssel-BE', 'Van')
# ('Brno-CZ', 'Sofia-BG', '2 Swap Bodies')
# ('Brno-CZ', 'Sofia-BG', 'Swap Body')
# ('Brno-CZ', 'Sofia-BG', 'Trailer')
# ('Brno-CZ', 'Sofia-BG', 'Van')
# ('Ostrava-CZ', 'Sofia-BG', '2 Swap Bodies')
# ('Ostrava-CZ', 'Sofia-BG', 'Swap Body')
# ('Ostrava-CZ', 'Sofia-BG', 'Trailer')
# ('Ostrava-CZ', 'Sofia-BG', 'Van')
# ('Krupka 1-CZ', 'Sofia-BG', '2 Swap Bodies')
# ('Krupka 1-CZ', 'Sofia-BG', 'Swap Body')
# ('Krupka 1-CZ', 'Sofia-BG', 'Trailer')
# ('Krupka 1-CZ', 'Sofia-BG', 'Van')
# ('Plzen 1-CZ', 'Sofia-BG', '2 Swap Bodies')
# ('Plzen 1-CZ', 'Sofia-BG', 'Swap Body')
# ('Plzen 1-CZ', 'Sofia-BG', 'Trailer')
# ('Plzen 1-CZ', 'Sofia-BG', 'Van')
# ('Hradec Kralove - Brezhrad-CZ', 'Sofia-BG', '2 Swap Bodies')
# ('Hradec Kralove - Brezhrad-CZ', 'Sofia-BG', 'Swap Body')
# ('Hradec Kralove - Brezhrad-CZ', 'Sofia-BG', 'Trailer')
# ('Hradec Kralove - Brezhrad-CZ', 'Sofia-BG', 'Van')
# ('Brno-CZ', 'PZ 67 (Speyer)-DE', '2 Swap Bodies')
# ('Brno-CZ', 'PZ 67 (Speyer)-DE', 'Swap Body')
# ('Brno-CZ', 'PZ 67 (Speyer)-DE', 'Trailer')
# ('Brno-CZ', 'PZ 67 (Speyer)-DE', 'Van')
# ('Brno-CZ', 'PZ 50 (Köln)-DE', '2 Swap Bodies')
# ('Brno-CZ', 'PZ 50 (Köln)-DE', 'Swap Body')
# ('Brno-CZ', 'PZ 50 (Köln)-DE', 'Trailer')
# ('Brno-CZ', 'PZ 50 (Köln)-DE', 'Van')
# ('Brno-CZ', 'PZ 04 (Radefeld/Leipzig)-DE', '2 Swap Bodies')
# ('Brno-CZ', 'PZ 04 (Radefeld/Leipzig)-DE', 'Swap Body')
# ('Brno-CZ', 'PZ 04 (Radefeld/Leipzig)-DE', 'Trailer')
# ('Brno-CZ', 'PZ 04 (Radefeld/Leipzig)-DE', 'Van')
# ('Brno-CZ', 'PZ 90 (Feucht/Nürnberg)-DE', '2 Swap Bodies')
# ('Brno-CZ', 'PZ 90 (Feucht/Nürnberg)-DE', 'Swap Body')
# ('Brno-CZ', 'PZ 90 (Feucht/Nürnberg)-DE', 'Trailer')
# ('Brno-CZ', 'PZ 90 (Feucht/Nürnberg)-DE', 'Van')
# ('Brno-CZ', 'PZ 77 (Lahr)-DE', '2 Swap Bodies')
# ('Brno-CZ', 'PZ 77 (Lahr)-DE', 'Swap Body')
# ('Brno-CZ', 'PZ 77 (Lahr)-DE', 'Trailer')
# ('Brno-CZ', 'PZ 77 (Lahr)-DE', 'Van')
# ('Brno-CZ', 'PZ 93 (Regensburg)-DE', '2 Swap Bodies')
# ('Brno-CZ', 'PZ 93 (Regensburg)-DE', 'Swap Body')
# ('Brno-CZ', 'PZ 93 (Regensburg)-DE', 'Trailer')
# ('Brno-CZ', 'PZ 93 (Regensburg)-DE', 'Van')
# ('Brno-CZ', 'PZ 21 (Hamburg)-DE', '2 Swap Bodies')
# ('Brno-CZ', 'PZ 21 (Hamburg)-DE', 'Swap Body')
# ('Brno-CZ', 'PZ 21 (Hamburg)-DE', 'Trailer')
# ('Brno-CZ', 'PZ 21 (Hamburg)-DE', 'Van')
# ('Brno-CZ', 'PZ 46 (Dorsten)-DE', '2 Swap Bodies')
# ('Brno-CZ', 'PZ 46 (Dorsten)-DE', 'Swap Body')
# ('Brno-CZ', 'PZ 46 (Dorsten)-DE', 'Trailer')
# ('Brno-CZ', 'PZ 46 (Dorsten)-DE', 'Van')
# ('Brno-CZ', 'PZ 58 (Hagen)-DE', '2 Swap Bodies')
# ('Brno-CZ', 'PZ 58 (Hagen)-DE', 'Swap Body')
# ('Brno-CZ', 'PZ 58 (Hagen)-DE', 'Trailer')
# ('Brno-CZ', 'PZ 58 (Hagen)-DE', 'Van')
# ('Brno-CZ', 'PZ 08 (Neumark)-DE', '2 Swap Bodies')
# ('Brno-CZ', 'PZ 08 (Neumark)-DE', 'Swap Body')
# ('Brno-CZ', 'PZ 08 (Neumark)-DE', 'Trailer')
# ('Brno-CZ', 'PZ 08 (Neumark)-DE', 'Van')
# ('Brno-CZ', 'PZ 47 (Krefeld)-DE', '2 Swap Bodies')
# ('Brno-CZ', 'PZ 47 (Krefeld)-DE', 'Swap Body')
# ('Brno-CZ', 'PZ 47 (Krefeld)-DE', 'Trailer')
# ('Brno-CZ', 'PZ 47 (Krefeld)-DE', 'Van')
# ('Brno-CZ', 'PZ 15 (Rüdersdorf)-DE', '2 Swap Bodies')
# ('Brno-CZ', 'PZ 15 (Rüdersdorf)-DE', 'Swap Body')
# ('Brno-CZ', 'PZ 15 (Rüdersdorf)-DE', 'Trailer')
# ('Brno-CZ', 'PZ 15 (Rüdersdorf)-DE', 'Van')
# ('Ostrava-CZ', 'PZ 67 (Speyer)-DE', '2 Swap Bodies')
# ('Ostrava-CZ', 'PZ 67 (Speyer)-DE', 'Swap Body')
# ('Ostrava-CZ', 'PZ 67 (Speyer)-DE', 'Trailer')
# ('Ostrava-CZ', 'PZ 67 (Speyer)-DE', 'Van')
# ('Ostrava-CZ', 'PZ 50 (Köln)-DE', '2 Swap Bodies')
# ('Ostrava-CZ', 'PZ 50 (Köln)-DE', 'Swap Body')
# ('Ostrava-CZ', 'PZ 50 (Köln)-DE', 'Trailer')
# ('Ostrava-CZ', 'PZ 50 (Köln)-DE', 'Van')
# ('Ostrava-CZ', 'PZ 04 (Radefeld/Leipzig)-DE', '2 Swap Bodies')
# ('Ostrava-CZ', 'PZ 04 (Radefeld/Leipzig)-DE', 'Swap Body')
# ('Ostrava-CZ', 'PZ 04 (Radefeld/Leipzig)-DE', 'Trailer')
# ('Ostrava-CZ', 'PZ 04 (Radefeld/Leipzig)-DE', 'Van')
# ('Ostrava-CZ', 'PZ 90 (Feucht/Nürnberg)-DE', '2 Swap Bodies')
# ('Ostrava-CZ', 'PZ 90 (Feucht/Nürnberg)-DE', 'Swap Body')
# ('Ostrava-CZ', 'PZ 90 (Feucht/Nürnberg)-DE', 'Trailer')
# ('Ostrava-CZ', 'PZ 90 (Feucht/Nürnberg)-DE', 'Van')
# ('Ostrava-CZ', 'PZ 77 (Lahr)-DE', '2 Swap Bodies')
# ('Ostrava-CZ', 'PZ 77 (Lahr)-DE', 'Swap Body')
# ('Ostrava-CZ', 'PZ 77 (Lahr)-DE', 'Trailer')
# ('Ostrava-CZ', 'PZ 77 (Lahr)-DE', 'Van')
# ('Ostrava-CZ', 'PZ 93 (Regensburg)-DE', '2 Swap Bodies')
# ('Ostrava-CZ', 'PZ 93 (Regensburg)-DE', 'Swap Body')
# ('Ostrava-CZ', 'PZ 93 (Regensburg)-DE', 'Trailer')
# ('Ostrava-CZ', 'PZ 93 (Regensburg)-DE', 'Van')
# ('Ostrava-CZ', 'PZ 21 (Hamburg)-DE', '2 Swap Bodies')
# ('Ostrava-CZ', 'PZ 21 (Hamburg)-DE', 'Swap Body')
# ('Ostrava-CZ', 'PZ 21 (Hamburg)-DE', 'Trailer')
# ('Ostrava-CZ', 'PZ 21 (Hamburg)-DE', 'Van')
# ('Ostrava-CZ', 'PZ 46 (Dorsten)-DE', '2 Swap Bodies')
# ('Ostrava-CZ', 'PZ 46 (Dorsten)-DE', 'Swap Body')
# ('Ostrava-CZ', 'PZ 46 (Dorsten)-DE', 'Trailer')
# ('Ostrava-CZ', 'PZ 46 (Dorsten)-DE', 'Van')
# ('Ostrava-CZ', 'PZ 58 (Hagen)-DE', '2 Swap Bodies')
# ('Ostrava-CZ', 'PZ 58 (Hagen)-DE', 'Swap Body')
# ('Ostrava-CZ', 'PZ 58 (Hagen)-DE', 'Trailer')
# ('Ostrava-CZ', 'PZ 58 (Hagen)-DE', 'Van')
# ('Ostrava-CZ', 'PZ 08 (Neumark)-DE', '2 Swap Bodies')
# ('Ostrava-CZ', 'PZ 08 (Neumark)-DE', 'Swap Body')
# ('Ostrava-CZ', 'PZ 08 (Neumark)-DE', 'Trailer')
# ('Ostrava-CZ', 'PZ 08 (Neumark)-DE', 'Van')
# ('Ostrava-CZ', 'PZ 47 (Krefeld)-DE', '2 Swap Bodies')
# ('Ostrava-CZ', 'PZ 47 (Krefeld)-DE', 'Swap Body')
# ('Ostrava-CZ', 'PZ 47 (Krefeld)-DE', 'Trailer')
# ('Ostrava-CZ', 'PZ 47 (Krefeld)-DE', 'Van')
# ('Ostrava-CZ', 'PZ 15 (Rüdersdorf)-DE', '2 Swap Bodies')
# ('Ostrava-CZ', 'PZ 15 (Rüdersdorf)-DE', 'Swap Body')
# ('Ostrava-CZ', 'PZ 15 (Rüdersdorf)-DE', 'Trailer')
# ('Ostrava-CZ', 'PZ 15 (Rüdersdorf)-DE', 'Van')
# ('Krupka 1-CZ', 'PZ 67 (Speyer)-DE', '2 Swap Bodies')
# ('Krupka 1-CZ', 'PZ 67 (Speyer)-DE', 'Swap Body')
# ...
# ('Zilina- Strecno-SK', 'Ryton Gateway-GB', 'Van')
# ('Bratislava - Raca-SK', 'Spata-GR', '2 Swap Bodies')
# ('Bratislava - Raca-SK', 'Spata-GR', 'Swap Body')
# ('Bratislava - Raca-SK', 'Spata-GR', 'Trailer')
# ('Bratislava - Raca-SK', 'Spata-GR', 'Van')
# ('Bratislava - Petrzalka-SK', 'Spata-GR', '2 Swap Bodies')
# ('Bratislava - Petrzalka-SK', 'Spata-GR', 'Swap Body')
# ('Bratislava - Petrzalka-SK', 'Spata-GR', 'Trailer')
# ('Bratislava - Petrzalka-SK', 'Spata-GR', 'Van')
# ('Zilina- Strecno-SK', 'Spata-GR', '2 Swap Bodies')
# ('Zilina- Strecno-SK', 'Spata-GR', 'Swap Body')
# ('Zilina- Strecno-SK', 'Spata-GR', 'Trailer')
# ('Zilina- Strecno-SK', 'Spata-GR', 'Van')
# ('Bratislava - Raca-SK', 'Zagreb-HR', '2 Swap Bodies')
# ('Bratislava - Raca-SK', 'Zagreb-HR', 'Swap Body')
# ('Bratislava - Raca-SK', 'Zagreb-HR', 'Trailer')
# ('Bratislava - Raca-SK', 'Zagreb-HR', 'Van')
# ('Bratislava - Petrzalka-SK', 'Zagreb-HR', '2 Swap Bodies')
# ('Bratislava - Petrzalka-SK', 'Zagreb-HR', 'Swap Body')
# ('Bratislava - Petrzalka-SK', 'Zagreb-HR', 'Trailer')
# ('Bratislava - Petrzalka-SK', 'Zagreb-HR', 'Van')
# ('Zilina- Strecno-SK', 'Zagreb-HR', '2 Swap Bodies')
# ('Zilina- Strecno-SK', 'Zagreb-HR', 'Swap Body')
# ('Zilina- Strecno-SK', 'Zagreb-HR', 'Trailer')
# ('Zilina- Strecno-SK', 'Zagreb-HR', 'Van')
# ('Bratislava - Raca-SK', 'Budapest OLK-HU', '2 Swap Bodies')
# ('Bratislava - Raca-SK', 'Budapest OLK-HU', 'Swap Body')
# ('Bratislava - Raca-SK', 'Budapest OLK-HU', 'Trailer')
# ('Bratislava - Raca-SK', 'Budapest OLK-HU', 'Van')
# ('Bratislava - Raca-SK', 'Budapest NPKK (OE)-HU', '2 Swap Bodies')
# ('Bratislava - Raca-SK', 'Budapest NPKK (OE)-HU', 'Swap Body')
# ('Bratislava - Raca-SK', 'Budapest NPKK (OE)-HU', 'Trailer')
# ('Bratislava - Raca-SK', 'Budapest NPKK (OE)-HU', 'Van')
# ('Bratislava - Petrzalka-SK', 'Budapest OLK-HU', '2 Swap Bodies')
# ('Bratislava - Petrzalka-SK', 'Budapest OLK-HU', 'Swap Body')
# ('Bratislava - Petrzalka-SK', 'Budapest OLK-HU', 'Trailer')
# ('Bratislava - Petrzalka-SK', 'Budapest OLK-HU', 'Van')
# ('Bratislava - Petrzalka-SK', 'Budapest NPKK (OE)-HU', '2 Swap Bodies')
# ('Bratislava - Petrzalka-SK', 'Budapest NPKK (OE)-HU', 'Swap Body')
# ('Bratislava - Petrzalka-SK', 'Budapest NPKK (OE)-HU', 'Trailer')
# ('Bratislava - Petrzalka-SK', 'Budapest NPKK (OE)-HU', 'Van')
# ('Zilina- Strecno-SK', 'Budapest OLK-HU', '2 Swap Bodies')
# ('Zilina- Strecno-SK', 'Budapest OLK-HU', 'Swap Body')
# ('Zilina- Strecno-SK', 'Budapest OLK-HU', 'Trailer')
# ('Zilina- Strecno-SK', 'Budapest OLK-HU', 'Van')
# ('Zilina- Strecno-SK', 'Budapest NPKK (OE)-HU', '2 Swap Bodies')
# ('Zilina- Strecno-SK', 'Budapest NPKK (OE)-HU', 'Swap Body')
# ('Zilina- Strecno-SK', 'Budapest NPKK (OE)-HU', 'Trailer')
# ('Zilina- Strecno-SK', 'Budapest NPKK (OE)-HU', 'Van')
# ('Bratislava - Raca-SK', 'Portlaoise-IE', '2 Swap Bodies')
# ('Bratislava - Raca-SK', 'Portlaoise-IE', 'Swap Body')
# ('Bratislava - Raca-SK', 'Portlaoise-IE', 'Trailer')
# ('Bratislava - Raca-SK', 'Portlaoise-IE', 'Van')
# ('Bratislava - Petrzalka-SK', 'Portlaoise-IE', '2 Swap Bodies')
# ('Bratislava - Petrzalka-SK', 'Portlaoise-IE', 'Swap Body')
# ('Bratislava - Petrzalka-SK', 'Portlaoise-IE', 'Trailer')
# ('Bratislava - Petrzalka-SK', 'Portlaoise-IE', 'Van')
# ('Zilina- Strecno-SK', 'Portlaoise-IE', '2 Swap Bodies')
# ('Zilina- Strecno-SK', 'Portlaoise-IE', 'Swap Body')
# ('Zilina- Strecno-SK', 'Portlaoise-IE', 'Trailer')
# ('Zilina- Strecno-SK', 'Portlaoise-IE', 'Van')
# ('Bratislava - Raca-SK', 'Kaunas-LT', '2 Swap Bodies')
# ('Bratislava - Raca-SK', 'Kaunas-LT', 'Swap Body')
# ('Bratislava - Raca-SK', 'Kaunas-LT', 'Trailer')
# ('Bratislava - Raca-SK', 'Kaunas-LT', 'Van')
# ('Bratislava - Petrzalka-SK', 'Kaunas-LT', '2 Swap Bodies')
# ('Bratislava - Petrzalka-SK', 'Kaunas-LT', 'Swap Body')
# ('Bratislava - Petrzalka-SK', 'Kaunas-LT', 'Trailer')
# ('Bratislava - Petrzalka-SK', 'Kaunas-LT', 'Van')
# ('Zilina- Strecno-SK', 'Kaunas-LT', '2 Swap Bodies')
# ('Zilina- Strecno-SK', 'Kaunas-LT', 'Swap Body')
# ('Zilina- Strecno-SK', 'Kaunas-LT', 'Trailer')
# ('Zilina- Strecno-SK', 'Kaunas-LT', 'Van')
# ('Bratislava - Raca-SK', 'Bettembourg-LU', '2 Swap Bodies')
# ('Bratislava - Raca-SK', 'Bettembourg-LU', 'Swap Body')
# ('Bratislava - Raca-SK', 'Bettembourg-LU', 'Trailer')
# ('Bratislava - Raca-SK', 'Bettembourg-LU', 'Van')
# ('Bratislava - Petrzalka-SK', 'Bettembourg-LU', '2 Swap Bodies')
# ('Bratislava - Petrzalka-SK', 'Bettembourg-LU', 'Swap Body')
# ('Bratislava - Petrzalka-SK', 'Bettembourg-LU', 'Trailer')
# ('Bratislava - Petrzalka-SK', 'Bettembourg-LU', 'Van')
# ('Zilina- Strecno-SK', 'Bettembourg-LU', '2 Swap Bodies')
# ('Zilina- Strecno-SK', 'Bettembourg-LU', 'Swap Body')
# ('Zilina- Strecno-SK', 'Bettembourg-LU', 'Trailer')
# ('Zilina- Strecno-SK', 'Bettembourg-LU', 'Van')
# ('Bratislava - Raca-SK', 'Eindhoven-Noord-NL', '2 Swap Bodies')
# ('Bratislava - Raca-SK', 'Eindhoven-Noord-NL', 'Swap Body')
# ('Bratislava - Raca-SK', 'Eindhoven-Noord-NL', 'Trailer')
# ('Bratislava - Raca-SK', 'Eindhoven-Noord-NL', 'Van')
# ('Bratislava - Raca-SK', 'Utrecht-West + Centrum-NL', '2 Swap Bodies')
# ('Bratislava - Raca-SK', 'Utrecht-West + Centrum-NL', 'Swap Body')
# ('Bratislava - Raca-SK', 'Utrecht-West + Centrum-NL', 'Trailer')
# ('Bratislava - Raca-SK', 'Utrecht-West + Centrum-NL', 'Van')
# ('Bratislava - Raca-SK', 'Zaltbommel-NL', '2 Swap Bodies')
# ('Bratislava - Raca-SK', 'Zaltbommel-NL', 'Swap Body')
# ('Bratislava - Raca-SK', 'Zaltbommel-NL', 'Trailer')
# ('Bratislava - Raca-SK', 'Zaltbommel-NL', 'Van')
# ('Bratislava - Petrzalka-SK', 'Eindhoven-Noord-NL', '2 Swap Bodies')
# ('Bratislava - Petrzalka-SK', 'Eindhoven-Noord-NL', 'Swap Body')
# ('Bratislava - Petrzalka-SK', 'Eindhoven-Noord-NL', 'Trailer')
# ('Bratislava - Petrzalka-SK', 'Eindhoven-Noord-NL', 'Van')
# ('Bratislava - Petrzalka-SK', 'Utrecht-West + Centrum-NL', '2 Swap Bodies')
# ('Bratislava - Petrzalka-SK', 'Utrecht-West + Centrum-NL', 'Swap Body')
# ('Bratislava - Petrzalka-SK', 'Utrecht-West + Centrum-NL', 'Trailer')
# ('Bratislava - Petrzalka-SK', 'Utrecht-West + Centrum-NL', 'Van')
# ('Bratislava - Petrzalka-SK', 'Zaltbommel-NL', '2 Swap Bodies')
# ('Bratislava - Petrzalka-SK', 'Zaltbommel-NL', 'Swap Body')
# ('Bratislava - Petrzalka-SK', 'Zaltbommel-NL', 'Trailer')
# ('Bratislava - Petrzalka-SK', 'Zaltbommel-NL', 'Van')
# ('Zilina- Strecno-SK', 'Eindhoven-Noord-NL', '2 Swap Bodies')
# ('Zilina- Strecno-SK', 'Eindhoven-Noord-NL', 'Swap Body')
# ('Zilina- Strecno-SK', 'Eindhoven-Noord-NL', 'Trailer')
# ('Zilina- Strecno-SK', 'Eindhoven-Noord-NL', 'Van')
# ('Zilina- Strecno-SK', 'Utrecht-West + Centrum-NL', '2 Swap Bodies')
# ('Zilina- Strecno-SK', 'Utrecht-West + Centrum-NL', 'Swap Body')
# ('Zilina- Strecno-SK', 'Utrecht-West + Centrum-NL', 'Trailer')
# ('Zilina- Strecno-SK', 'Utrecht-West + Centrum-NL', 'Van')
# ('Zilina- Strecno-SK', 'Zaltbommel-NL', '2 Swap Bodies')
# ('Zilina- Strecno-SK', 'Zaltbommel-NL', 'Swap Body')
# ('Zilina- Strecno-SK', 'Zaltbommel-NL', 'Trailer')
# ('Zilina- Strecno-SK', 'Zaltbommel-NL', 'Van')
# ('Bratislava - Raca-SK', 'Oslo-NO', '2 Swap Bodies')
# ('Bratislava - Raca-SK', 'Oslo-NO', 'Swap Body')
# ('Bratislava - Raca-SK', 'Oslo-NO', 'Trailer')
# ('Bratislava - Raca-SK', 'Oslo-NO', 'Van')
# ('Bratislava - Petrzalka-SK', 'Oslo-NO', '2 Swap Bodies')
# ('Bratislava - Petrzalka-SK', 'Oslo-NO', 'Swap Body')
# ('Bratislava - Petrzalka-SK', 'Oslo-NO', 'Trailer')
# ('Bratislava - Petrzalka-SK', 'Oslo-NO', 'Van')
# ('Zilina- Strecno-SK', 'Oslo-NO', '2 Swap Bodies')
# ('Zilina- Strecno-SK', 'Oslo-NO', 'Swap Body')
# ('Zilina- Strecno-SK', 'Oslo-NO', 'Trailer')
# ('Zilina- Strecno-SK', 'Oslo-NO', 'Van')
# ('Bratislava - Raca-SK', 'Suwałki (Ełk)-PL', '2 Swap Bodies')
# ('Bratislava - Raca-SK', 'Suwałki (Ełk)-PL', 'Swap Body')
# ('Bratislava - Raca-SK', 'Suwałki (Ełk)-PL', 'Trailer')
# ('Bratislava - Raca-SK', 'Suwałki (Ełk)-PL', 'Van')
# ('Bratislava - Raca-SK', 'Poznań-PL', '2 Swap Bodies')
# ('Bratislava - Raca-SK', 'Poznań-PL', 'Swap Body')
# ('Bratislava - Raca-SK', 'Poznań-PL', 'Trailer')
# ('Bratislava - Raca-SK', 'Poznań-PL', 'Van')
# ('Bratislava - Raca-SK', 'Zabrze-PL', '2 Swap Bodies')
# ('Bratislava - Raca-SK', 'Zabrze-PL', 'Swap Body')
# ('Bratislava - Raca-SK', 'Zabrze-PL', 'Trailer')
# ('Bratislava - Raca-SK', 'Zabrze-PL', 'Van')
# ('Bratislava - Raca-SK', 'Koninko-PL', '2 Swap Bodies')
# ('Bratislava - Raca-SK', 'Koninko-PL', 'Swap Body')
# ('Bratislava - Raca-SK', 'Koninko-PL', 'Trailer')
# ('Bratislava - Raca-SK', 'Koninko-PL', 'Van')
# ('Bratislava - Raca-SK', 'Wrocław-PL', '2 Swap Bodies')
# ('Bratislava - Raca-SK', 'Wrocław-PL', 'Swap Body')
# ('Bratislava - Raca-SK', 'Wrocław-PL', 'Trailer')
# ('Bratislava - Raca-SK', 'Wrocław-PL', 'Van')
# ('Bratislava - Raca-SK', 'Bydgoszcz (Solec Kujawski)-PL', '2 Swap Bodies')
# ('Bratislava - Raca-SK', 'Bydgoszcz (Solec Kujawski)-PL', 'Swap Body')
# ('Bratislava - Raca-SK', 'Bydgoszcz (Solec Kujawski)-PL', 'Trailer')
# ('Bratislava - Raca-SK', 'Bydgoszcz (Solec Kujawski)-PL', 'Van')
# ('Bratislava - Petrzalka-SK', 'Suwałki (Ełk)-PL', '2 Swap Bodies')
# ('Bratislava - Petrzalka-SK', 'Suwałki (Ełk)-PL', 'Swap Body')
# ('Bratislava - Petrzalka-SK', 'Suwałki (Ełk)-PL', 'Trailer')
# ('Bratislava - Petrzalka-SK', 'Suwałki (Ełk)-PL', 'Van')
# ('Bratislava - Petrzalka-SK', 'Poznań-PL', '2 Swap Bodies')
# ('Bratislava - Petrzalka-SK', 'Poznań-PL', 'Swap Body')
# ('Bratislava - Petrzalka-SK', 'Poznań-PL', 'Trailer')
# ('Bratislava - Petrzalka-SK', 'Poznań-PL', 'Van')
# ('Bratislava - Petrzalka-SK', 'Zabrze-PL', '2 Swap Bodies')
# ('Bratislava - Petrzalka-SK', 'Zabrze-PL', 'Swap Body')
# ('Bratislava - Petrzalka-SK', 'Zabrze-PL', 'Trailer')
# ('Bratislava - Petrzalka-SK', 'Zabrze-PL', 'Van')
# ('Bratislava - Petrzalka-SK', 'Koninko-PL', '2 Swap Bodies')
# ('Bratislava - Petrzalka-SK', 'Koninko-PL', 'Swap Body')
# ('Bratislava - Petrzalka-SK', 'Koninko-PL', 'Trailer')
# ('Bratislava - Petrzalka-SK', 'Koninko-PL', 'Van')
# ('Bratislava - Petrzalka-SK', 'Wrocław-PL', '2 Swap Bodies')
# ('Bratislava - Petrzalka-SK', 'Wrocław-PL', 'Swap Body')
# ('Bratislava - Petrzalka-SK', 'Wrocław-PL', 'Trailer')
# ('Bratislava - Petrzalka-SK', 'Wrocław-PL', 'Van')
# ('Bratislava - Petrzalka-SK', 'Bydgoszcz (Solec Kujawski)-PL', '2 Swap Bodies')
# ('Bratislava - Petrzalka-SK', 'Bydgoszcz (Solec Kujawski)-PL', 'Swap Body')
# ('Bratislava - Petrzalka-SK', 'Bydgoszcz (Solec Kujawski)-PL', 'Trailer')
# ('Bratislava - Petrzalka-SK', 'Bydgoszcz (Solec Kujawski)-PL', 'Van')
# ('Zilina- Strecno-SK', 'Suwałki (Ełk)-PL', '2 Swap Bodies')
# ('Zilina- Strecno-SK', 'Suwałki (Ełk)-PL', 'Swap Body')
# ('Zilina- Strecno-SK', 'Suwałki (Ełk)-PL', 'Trailer')
# ('Zilina- Strecno-SK', 'Suwałki (Ełk)-PL', 'Van')
# ('Zilina- Strecno-SK', 'Poznań-PL', '2 Swap Bodies')
# ('Zilina- Strecno-SK', 'Poznań-PL', 'Swap Body')
# ('Zilina- Strecno-SK', 'Poznań-PL', 'Trailer')
# ('Zilina- Strecno-SK', 'Poznań-PL', 'Van')
# ('Zilina- Strecno-SK', 'Zabrze-PL', '2 Swap Bodies')
# ('Zilina- Strecno-SK', 'Zabrze-PL', 'Swap Body')
# ('Zilina- Strecno-SK', 'Zabrze-PL', 'Trailer')
# ('Zilina- Strecno-SK', 'Zabrze-PL', 'Van')
# ('Zilina- Strecno-SK', 'Koninko-PL', '2 Swap Bodies')
# ('Zilina- Strecno-SK', 'Koninko-PL', 'Swap Body')
# ('Zilina- Strecno-SK', 'Koninko-PL', 'Trailer')
# ('Zilina- Strecno-SK', 'Koninko-PL', 'Van')
# ('Zilina- Strecno-SK', 'Wrocław-PL', '2 Swap Bodies')
# ('Zilina- Strecno-SK', 'Wrocław-PL', 'Swap Body')
# ('Zilina- Strecno-SK', 'Wrocław-PL', 'Trailer')
# ('Zilina- Strecno-SK', 'Wrocław-PL', 'Van')
# ('Zilina- Strecno-SK', 'Bydgoszcz (Solec Kujawski)-PL', '2 Swap Bodies')
# ('Zilina- Strecno-SK', 'Bydgoszcz (Solec Kujawski)-PL', 'Swap Body')
# ('Zilina- Strecno-SK', 'Bydgoszcz (Solec Kujawski)-PL', 'Trailer')
# ('Zilina- Strecno-SK', 'Bydgoszcz (Solec Kujawski)-PL', 'Van')
# ('Bratislava - Raca-SK', 'Lisboa-PT', '2 Swap Bodies')
# ('Bratislava - Raca-SK', 'Lisboa-PT', 'Swap Body')
# ('Bratislava - Raca-SK', 'Lisboa-PT', 'Trailer')
# ('Bratislava - Raca-SK', 'Lisboa-PT', 'Van')
# ('Bratislava - Petrzalka-SK', 'Lisboa-PT', '2 Swap Bodies')
# ('Bratislava - Petrzalka-SK', 'Lisboa-PT', 'Swap Body')
# ('Bratislava - Petrzalka-SK', 'Lisboa-PT', 'Trailer')
# ('Bratislava - Petrzalka-SK', 'Lisboa-PT', 'Van')
# ('Zilina- Strecno-SK', 'Lisboa-PT', '2 Swap Bodies')
# ('Zilina- Strecno-SK', 'Lisboa-PT', 'Swap Body')
# ('Zilina- Strecno-SK', 'Lisboa-PT', 'Trailer')
# ('Zilina- Strecno-SK', 'Lisboa-PT', 'Van')
# ('Bratislava - Raca-SK', 'Oradea-RO', '2 Swap Bodies')
# ('Bratislava - Raca-SK', 'Oradea-RO', 'Swap Body')
# ('Bratislava - Raca-SK', 'Oradea-RO', 'Trailer')
# ('Bratislava - Raca-SK', 'Oradea-RO', 'Van')
# ('Bratislava - Petrzalka-SK', 'Oradea-RO', '2 Swap Bodies')
# ('Bratislava - Petrzalka-SK', 'Oradea-RO', 'Swap Body')
# ('Bratislava - Petrzalka-SK', 'Oradea-RO', 'Trailer')
# ('Bratislava - Petrzalka-SK', 'Oradea-RO', 'Van')
# ('Zilina- Strecno-SK', 'Oradea-RO', '2 Swap Bodies')
# ('Zilina- Strecno-SK', 'Oradea-RO', 'Swap Body')
# ('Zilina- Strecno-SK', 'Oradea-RO', 'Trailer')
# ('Zilina- Strecno-SK', 'Oradea-RO', 'Van')
# ('Bratislava - Raca-SK', 'Stockholm - Västberga-SE', '2 Swap Bodies')
# ('Bratislava - Raca-SK', 'Stockholm - Västberga-SE', 'Swap Body')
# ('Bratislava - Raca-SK', 'Stockholm - Västberga-SE', 'Trailer')
# ('Bratislava - Raca-SK', 'Stockholm - Västberga-SE', 'Van')
# ('Bratislava - Raca-SK', 'Helsingborg-SE', '2 Swap Bodies')
# ('Bratislava - Raca-SK', 'Helsingborg-SE', 'Swap Body')
# ('Bratislava - Raca-SK', 'Helsingborg-SE', 'Trailer')
# ('Bratislava - Raca-SK', 'Helsingborg-SE', 'Van')
# ('Bratislava - Raca-SK', 'Arlöv-SE', '2 Swap Bodies')
# ('Bratislava - Raca-SK', 'Arlöv-SE', 'Swap Body')
# ('Bratislava - Raca-SK', 'Arlöv-SE', 'Trailer')
# ('Bratislava - Raca-SK', 'Arlöv-SE', 'Van')
# ('Bratislava - Raca-SK', 'Malmö-SE', '2 Swap Bodies')
# ('Bratislava - Raca-SK', 'Malmö-SE', 'Swap Body')
# ('Bratislava - Raca-SK', 'Malmö-SE', 'Trailer')
# ('Bratislava - Raca-SK', 'Malmö-SE', 'Van')
# ('Bratislava - Petrzalka-SK', 'Stockholm - Västberga-SE', '2 Swap Bodies')
# ('Bratislava - Petrzalka-SK', 'Stockholm - Västberga-SE', 'Swap Body')
# ('Bratislava - Petrzalka-SK', 'Stockholm - Västberga-SE', 'Trailer')
# ('Bratislava - Petrzalka-SK', 'Stockholm - Västberga-SE', 'Van')
# ('Bratislava - Petrzalka-SK', 'Helsingborg-SE', '2 Swap Bodies')
# ('Bratislava - Petrzalka-SK', 'Helsingborg-SE', 'Swap Body')
# ('Bratislava - Petrzalka-SK', 'Helsingborg-SE', 'Trailer')
# ('Bratislava - Petrzalka-SK', 'Helsingborg-SE', 'Van')
# ('Bratislava - Petrzalka-SK', 'Arlöv-SE', '2 Swap Bodies')
# ('Bratislava - Petrzalka-SK', 'Arlöv-SE', 'Swap Body')
# ('Bratislava - Petrzalka-SK', 'Arlöv-SE', 'Trailer')
# ('Bratislava - Petrzalka-SK', 'Arlöv-SE', 'Van')
# ('Bratislava - Petrzalka-SK', 'Malmö-SE', '2 Swap Bodies')
# ('Bratislava - Petrzalka-SK', 'Malmö-SE', 'Swap Body')
# ('Bratislava - Petrzalka-SK', 'Malmö-SE', 'Trailer')
# ('Bratislava - Petrzalka-SK', 'Malmö-SE', 'Van')
# ('Zilina- Strecno-SK', 'Stockholm - Västberga-SE', '2 Swap Bodies')
# ('Zilina- Strecno-SK', 'Stockholm - Västberga-SE', 'Swap Body')
# ('Zilina- Strecno-SK', 'Stockholm - Västberga-SE', 'Trailer')
# ('Zilina- Strecno-SK', 'Stockholm - Västberga-SE', 'Van')
# ('Zilina- Strecno-SK', 'Helsingborg-SE', '2 Swap Bodies')
# ('Zilina- Strecno-SK', 'Helsingborg-SE', 'Swap Body')
# ('Zilina- Strecno-SK', 'Helsingborg-SE', 'Trailer')
# ('Zilina- Strecno-SK', 'Helsingborg-SE', 'Van')
# ('Zilina- Strecno-SK', 'Arlöv-SE', '2 Swap Bodies')
# ('Zilina- Strecno-SK', 'Arlöv-SE', 'Swap Body')
# ('Zilina- Strecno-SK', 'Arlöv-SE', 'Trailer')
# ('Zilina- Strecno-SK', 'Arlöv-SE', 'Van')
# ('Zilina- Strecno-SK', 'Malmö-SE', '2 Swap Bodies')
# ('Zilina- Strecno-SK', 'Malmö-SE', 'Swap Body')
# ('Zilina- Strecno-SK', 'Malmö-SE', 'Trailer')
# ('Zilina- Strecno-SK', 'Malmö-SE', 'Van')
# ('Bratislava - Raca-SK', 'Ljubljana-SI', '2 Swap Bodies')
# ('Bratislava - Raca-SK', 'Ljubljana-SI', 'Swap Body')
# ('Bratislava - Raca-SK', 'Ljubljana-SI', 'Trailer')
# ('Bratislava - Raca-SK', 'Ljubljana-SI', 'Van')
# ('Bratislava - Petrzalka-SK', 'Ljubljana-SI', '2 Swap Bodies')
# ('Bratislava - Petrzalka-SK', 'Ljubljana-SI', 'Swap Body')
# ('Bratislava - Petrzalka-SK', 'Ljubljana-SI', 'Trailer')
# ('Bratislava - Petrzalka-SK', 'Ljubljana-SI', 'Van')
# ('Zilina- Strecno-SK', 'Ljubljana-SI', '2 Swap Bodies')
# ('Zilina- Strecno-SK', 'Ljubljana-SI', 'Swap Body')
# ('Zilina- Strecno-SK', 'Ljubljana-SI', 'Trailer')
# ('Zilina- Strecno-SK', 'Ljubljana-SI', 'Van')

# %% [markdown]
# ## 4. Travel time (TT)
# Total transportation time from hub p ∈ H to q ∈ H

# %%
tt_file = pd.read_csv("Database/travel time.csv")
TT = {}
for row in tt_file.index:
    key = (tt_file.loc[row, "From"], tt_file.loc[row, "To"])
    value = tt_file.loc[row, "est_tt"]
    
    TT[key] = value

# %% [markdown]
# ## 5. Hub Open & Cut-off time
# - Op = Hub opened time for hub p ∈ H
# - COp  = Hub cut off time for hub p ∈ H

# %%
def transform_time(target):
    try: 
        return int(target.split(":")[0]) + int(target.split(":")[1])/60 
    except:
        return 0

# %%
'''
hub_info = pd.read_csv("Database/Hub Cutoff and Open Time.csv")
hub_info["Hub"] = hub_info.apply(lambda row: name_transform(row["Gateways"]), axis = 1)
hub_info["Cut-off"] = hub_info.apply(lambda row: transform_time(row["Cut-Off"]), axis = 1)
hub_info["Open"] = hub_info.apply(lambda row: transform_time(row["Hub-Opening-Time"]), axis = 1)
hub_info.to_csv("Database/hub_info.csv")
'''
# Out:
# '\nhub_info = pd.read_csv("Database/Hub Cutoff and Open Time.csv")\nhub_info["Hub"] = hub_info.apply(lambda row: name_transform(row["Gateways"]), axis = 1)\nhub_info["Cut-off"] = hub_info.apply(lambda row: transform_time(row["Cut-Off"]), axis = 1)\nhub_info["Open"] = hub_info.apply(lambda row: transform_time(row["Hub-Opening-Time"]), axis = 1)\nhub_info.to_csv("Database/hub_info.csv")\n'

# %%
hub_info = pd.read_csv("Database/hub_info.csv")
merged_hub_info = hub_list_used.merge(hub_info[["Hub", "Open", "Cut-off"]], left_on = "Ref_City", right_on = "Hub", how = "left")

merged_hub_info["Open"].fillna(merged_hub_info["Open"].mode().values[0], inplace = True)
merged_hub_info["Cut-off"].fillna(merged_hub_info["Cut-off"].mode().values[0], inplace = True)

O = {} # Open time
for row in merged_hub_info.index:
    key = merged_hub_info.loc[row, "Ref_City"]
    value = merged_hub_info.loc[row, "Open"]
    O[key] = value

CO = {} # Cut-off time
for row in merged_hub_info.index:
    key = merged_hub_info.loc[row, "Ref_City"]
    value = merged_hub_info.loc[row, "Cut-off"]
    CO[key] =  value

# %% [markdown]
# ## 6. Truck Capacity

# %%
C = {}
for row in truck_cap.index:
    C[truck_cap.loc[row, "Truck Type"]] = truck_cap.loc[row, "Capacity"]

# %% [markdown]
# # Define the variables
# Decision variables:
# - xpq = 1 if the transportation from hub p ∈ H to hub q ∈ H is direct, else 0
# - x’piq = 1 if the transportation from hub p ∈ H to hub q ∈ H has to go through i ∈ H, else 0
# - Xmk = 1 if the transportation from country m ∈ E to county k ∈ E is direct, else 0
# - X’mjk = 1 if the transportation from country m ∈ E  to county k ∈ E  has to go through country j ∈ E , else 0
# - Vpq = route capacity from hub p ∈ H to hub q ∈ H
# - Fpqt = recommended frequency of truck t ∈ T from hub p ∈ H to hub q ∈ H
# - Spq = start time of truck from hub p ∈ H to hub q ∈ H,
# - Npq = Night needed from hub p ∈ H to hub q ∈ H

# %%
x = model.addVars(pq , vtype=GRB.BINARY, name='xpq')  # Direct from hub to hub

x_ = model.addVars(piq, vtype = GRB.BINARY, name = 'x_piq')  # Indirect from hub to hub

# %%
X = model.addVars(mk , vtype=GRB.BINARY, name='Xmk')       # Direct from country to country

X_ = model.addVars(mjk,  vtype = GRB.BINARY, name = 'X_mjk') # Indirect from country to country

# %%
V=model.addVars(pq , vtype=GRB.INTEGER, lb=0 ,name='Vpq')   # Route capacity

pqt = [(p,q,t) for p,q in pq for t in T]
F=model.addVars(pqt , vtype=GRB.INTEGER, lb=0, name='Fpqt') # Recommended Frequency

S=model.addVars(pq , vtype=GRB.CONTINUOUS, name='Spq')         # Start time from hub p

N=model.addVars(pq , vtype=GRB.INTEGER, name='Npq')         # Night Needed from hub p to hub q

# %%
attri_dict = {"hub_direct": x, "hub_indirect" : x_, "country_direct" : X, "country_indirect" : X_,
              "route_cap": V, "freq" : F, "start" : S, "night" : N}

# %% [markdown]
# # Constraints
# ## Direct or Indirect Transportation

# %%
## Please note that addConstrs is different from addConstr, we need addConstrs in here, because we are adding mroe than one constraints
model.addConstrs(((quicksum(X_[m,j,k] for j in E if (j != m) & (j != k)) == 
                   (1 - X[m,k])) for m in E for k in E if m != k),
                 "Transportation can be direct or Indirect")
# Out:
# {('AT', 'BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'FR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'GB'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'FR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'GB'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'FR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'GB'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'FR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'GB'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'FR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'GB'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK', 'AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK', 'BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK', 'DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK', 'FR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK', 'GB'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK', 'NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'FR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'GB'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FR', 'AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FR', 'BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FR', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FR', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FR', 'DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FR', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FR', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FR', 'GB'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FR', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FR', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FR', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FR', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FR', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FR', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FR', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FR', 'NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FR', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FR', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FR', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FR', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FR', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FR', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GB', 'AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GB', 'BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GB', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GB', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GB', 'DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GB', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GB', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GB', 'FR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GB', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GB', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GB', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GB', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GB', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GB', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GB', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GB', 'NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GB', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GB', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GB', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GB', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GB', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GB', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GR', 'AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GR', 'BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GR', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GR', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GR', 'DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GR', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GR', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GR', 'FR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GR', 'GB'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GR', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GR', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GR', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GR', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GR', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GR', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GR', 'NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GR', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GR', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GR', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GR', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GR', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GR', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HR', 'AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HR', 'BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HR', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HR', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HR', 'DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HR', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HR', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HR', 'FR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HR', 'GB'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HR', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HR', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HR', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HR', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HR', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HR', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HR', 'NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HR', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HR', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HR', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HR', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HR', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HR', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HU', 'AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HU', 'BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HU', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HU', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HU', 'DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HU', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HU', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HU', 'FR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HU', 'GB'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HU', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HU', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HU', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HU', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HU', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HU', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HU', 'NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HU', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HU', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HU', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HU', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HU', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HU', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('IE', 'AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('IE', 'BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('IE', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('IE', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('IE', 'DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('IE', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('IE', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('IE', 'FR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('IE', 'GB'): <gurobi.Constr *Awaiting Model Update*>,
#  ('IE', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('IE', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('IE', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('IE', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('IE', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('IE', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('IE', 'NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('IE', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('IE', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('IE', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('IE', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('IE', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('IE', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LT', 'AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LT', 'BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LT', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LT', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LT', 'DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LT', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LT', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LT', 'FR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LT', 'GB'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LT', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LT', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LT', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LT', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LT', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LT', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LT', 'NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LT', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LT', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LT', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LT', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LT', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LT', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LU', 'AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LU', 'BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LU', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LU', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LU', 'DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LU', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LU', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LU', 'FR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LU', 'GB'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LU', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LU', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LU', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LU', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LU', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LU', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LU', 'NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LU', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LU', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LU', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LU', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LU', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LU', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NL', 'AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NL', 'BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NL', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NL', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NL', 'DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NL', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NL', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NL', 'FR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NL', 'GB'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NL', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NL', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NL', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NL', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NL', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NL', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NL', 'NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NL', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NL', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NL', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NL', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NL', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NL', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NO', 'AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NO', 'BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NO', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NO', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NO', 'DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NO', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NO', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NO', 'FR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NO', 'GB'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NO', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NO', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NO', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NO', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NO', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NO', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NO', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NO', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NO', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NO', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NO', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NO', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NO', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PL', 'AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PL', 'BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PL', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PL', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PL', 'DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PL', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PL', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PL', 'FR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PL', 'GB'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PL', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PL', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PL', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PL', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PL', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PL', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PL', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PL', 'NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PL', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PL', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PL', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PL', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PL', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'FR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'GB'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('RO', 'AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('RO', 'BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('RO', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('RO', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('RO', 'DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('RO', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('RO', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('RO', 'FR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('RO', 'GB'): <gurobi.Constr *Awaiting Model Update*>,
#  ('RO', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('RO', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('RO', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('RO', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('RO', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('RO', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('RO', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('RO', 'NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('RO', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('RO', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('RO', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('RO', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('RO', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SE', 'AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SE', 'BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SE', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SE', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SE', 'DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SE', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SE', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SE', 'FR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SE', 'GB'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SE', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SE', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SE', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SE', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SE', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SE', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SE', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SE', 'NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SE', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SE', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SE', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SE', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SE', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI', 'AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI', 'BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI', 'DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI', 'FR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI', 'GB'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI', 'NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SK', 'AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SK', 'BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SK', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SK', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SK', 'DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SK', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SK', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SK', 'FR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SK', 'GB'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SK', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SK', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SK', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SK', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SK', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SK', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SK', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SK', 'NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SK', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SK', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SK', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SK', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SK', 'SI'): <gurobi.Constr *Awaiting Model Update*>}

# %% [markdown]
# ## Linking Countries and Hubs

# %%
model.addConstrs(((quicksum(x[p,q] for p in L[m] for q in L[k]) == 
                  X[m,k]) for m in E for k in E if m != k), "Linking")  ## We can't use E_mjk here
model.addConstrs(((quicksum(x_[p,i,q] for p in L[m] for i in L[j] for q in L[k]) ==
                 X_[m,j,k]) for m,j,k in mjk), "Linking")
# Out:
# {('AT', 'BE', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'BE', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'BE', 'DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'BE', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'BE', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'BE', 'FR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'BE', 'GB'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'BE', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'BE', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'BE', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'BE', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'BE', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'BE', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'BE', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'BE', 'NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'BE', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'BE', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'BE', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'BE', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'BE', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'BE', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'BG', 'BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'BG', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'BG', 'DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'BG', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'BG', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'BG', 'FR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'BG', 'GB'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'BG', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'BG', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'BG', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'BG', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'BG', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'BG', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'BG', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'BG', 'NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'BG', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'BG', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'BG', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'BG', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'BG', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'BG', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'CZ', 'BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'CZ', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'CZ', 'DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'CZ', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'CZ', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'CZ', 'FR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'CZ', 'GB'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'CZ', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'CZ', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'CZ', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'CZ', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'CZ', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'CZ', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'CZ', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'CZ', 'NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'CZ', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'CZ', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'CZ', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'CZ', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'CZ', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'CZ', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'DE', 'BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'DE', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'DE', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'DE', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'DE', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'DE', 'FR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'DE', 'GB'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'DE', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'DE', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'DE', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'DE', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'DE', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'DE', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'DE', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'DE', 'NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'DE', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'DE', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'DE', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'DE', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'DE', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'DE', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'DK', 'BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'DK', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'DK', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'DK', 'DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'DK', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'DK', 'FR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'DK', 'GB'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'DK', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'DK', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'DK', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'DK', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'DK', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'DK', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'DK', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'DK', 'NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'DK', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'DK', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'DK', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'DK', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'DK', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'DK', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'ES', 'BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'ES', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'ES', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'ES', 'DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'ES', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'ES', 'FR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'ES', 'GB'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'ES', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'ES', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'ES', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'ES', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'ES', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'ES', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'ES', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'ES', 'NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'ES', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'ES', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'ES', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'ES', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'ES', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'ES', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'FR', 'BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'FR', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'FR', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'FR', 'DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'FR', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'FR', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'FR', 'GB'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'FR', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'FR', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'FR', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'FR', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'FR', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'FR', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'FR', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'FR', 'NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'FR', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'FR', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'FR', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'FR', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'FR', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'FR', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'GB', 'BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'GB', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'GB', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'GB', 'DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'GB', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'GB', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'GB', 'FR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'GB', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'GB', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'GB', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'GB', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'GB', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'GB', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'GB', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'GB', 'NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'GB', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'GB', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'GB', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'GB', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'GB', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'GB', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'GR', 'BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'GR', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'GR', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'GR', 'DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'GR', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'GR', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'GR', 'FR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'GR', 'GB'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'GR', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'GR', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'GR', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'GR', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'GR', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'GR', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'GR', 'NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'GR', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'GR', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'GR', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'GR', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'GR', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'GR', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'HR', 'BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'HR', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'HR', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'HR', 'DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'HR', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'HR', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'HR', 'FR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'HR', 'GB'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'HR', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'HR', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'HR', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'HR', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'HR', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'HR', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'HR', 'NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'HR', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'HR', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'HR', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'HR', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'HR', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'HR', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'HU', 'BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'HU', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'HU', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'HU', 'DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'HU', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'HU', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'HU', 'FR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'HU', 'GB'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'HU', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'HU', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'HU', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'HU', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'HU', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'HU', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'HU', 'NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'HU', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'HU', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'HU', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'HU', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'HU', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'HU', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'IE', 'BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'IE', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'IE', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'IE', 'DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'IE', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'IE', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'IE', 'FR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'IE', 'GB'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'IE', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'IE', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'IE', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'IE', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'IE', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'IE', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'IE', 'NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'IE', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'IE', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'IE', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'IE', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'IE', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'IE', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'LT', 'BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'LT', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'LT', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'LT', 'DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'LT', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'LT', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'LT', 'FR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'LT', 'GB'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'LT', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'LT', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'LT', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'LT', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'LT', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'LT', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'LT', 'NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'LT', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'LT', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'LT', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'LT', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'LT', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'LT', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'LU', 'BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'LU', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'LU', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'LU', 'DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'LU', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'LU', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'LU', 'FR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'LU', 'GB'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'LU', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'LU', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'LU', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'LU', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'LU', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'LU', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'LU', 'NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'LU', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'LU', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'LU', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'LU', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'LU', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'LU', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'NL', 'BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'NL', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'NL', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'NL', 'DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'NL', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'NL', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'NL', 'FR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'NL', 'GB'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'NL', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'NL', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'NL', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'NL', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'NL', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'NL', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'NL', 'NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'NL', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'NL', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'NL', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'NL', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'NL', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'NL', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'NO', 'BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'NO', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'NO', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'NO', 'DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'NO', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'NO', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'NO', 'FR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'NO', 'GB'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'NO', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'NO', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'NO', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'NO', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'NO', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'NO', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'NO', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'NO', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'NO', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'NO', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'NO', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'NO', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'NO', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'PL', 'BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'PL', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'PL', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'PL', 'DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'PL', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'PL', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'PL', 'FR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'PL', 'GB'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'PL', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'PL', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'PL', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'PL', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'PL', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'PL', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'PL', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'PL', 'NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'PL', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'PL', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'PL', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'PL', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'PL', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'PT', 'BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'PT', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'PT', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'PT', 'DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'PT', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'PT', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'PT', 'FR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'PT', 'GB'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'PT', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'PT', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'PT', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'PT', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'PT', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'PT', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'PT', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'PT', 'NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'PT', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'PT', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'PT', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'PT', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'PT', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'RO', 'BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'RO', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'RO', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'RO', 'DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'RO', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'RO', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'RO', 'FR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'RO', 'GB'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'RO', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'RO', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'RO', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'RO', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'RO', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'RO', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'RO', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'RO', 'NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'RO', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'RO', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'RO', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'RO', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'RO', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'SE', 'BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'SE', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'SE', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'SE', 'DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'SE', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'SE', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'SE', 'FR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'SE', 'GB'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'SE', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'SE', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'SE', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'SE', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'SE', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'SE', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'SE', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'SE', 'NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'SE', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'SE', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'SE', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'SE', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'SE', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'SI', 'BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'SI', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'SI', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'SI', 'DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'SI', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'SI', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'SI', 'FR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'SI', 'GB'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'SI', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'SI', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'SI', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'SI', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'SI', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'SI', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'SI', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'SI', 'NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'SI', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'SI', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'SI', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'SI', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'SI', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'SK', 'BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'SK', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'SK', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'SK', 'DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'SK', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'SK', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'SK', 'FR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'SK', 'GB'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'SK', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'SK', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'SK', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'SK', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'SK', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'SK', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'SK', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'SK', 'NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'SK', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'SK', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'SK', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'SK', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'SK', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'AT', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'AT', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'AT', 'DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'AT', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'AT', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'AT', 'FR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'AT', 'GB'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'AT', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'AT', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'AT', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'AT', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'AT', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'AT', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'AT', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'AT', 'NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'AT', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'AT', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'AT', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'AT', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'AT', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'AT', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'BG', 'AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'BG', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'BG', 'DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'BG', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'BG', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'BG', 'FR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'BG', 'GB'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'BG', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'BG', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'BG', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'BG', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'BG', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'BG', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'BG', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'BG', 'NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'BG', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'BG', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'BG', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'BG', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'BG', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'BG', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'CZ', 'AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'CZ', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'CZ', 'DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'CZ', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'CZ', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'CZ', 'FR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'CZ', 'GB'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'CZ', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'CZ', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'CZ', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'CZ', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'CZ', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'CZ', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'CZ', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'CZ', 'NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'CZ', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'CZ', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'CZ', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'CZ', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'CZ', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'CZ', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'DE', 'AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'DE', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'DE', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'DE', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'DE', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'DE', 'FR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'DE', 'GB'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'DE', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'DE', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'DE', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'DE', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'DE', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'DE', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'DE', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'DE', 'NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'DE', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'DE', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'DE', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'DE', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'DE', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'DE', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'DK', 'AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'DK', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'DK', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'DK', 'DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'DK', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'DK', 'FR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'DK', 'GB'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'DK', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'DK', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'DK', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'DK', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'DK', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'DK', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'DK', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'DK', 'NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'DK', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'DK', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'DK', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'DK', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'DK', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'DK', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'ES', 'AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'ES', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'ES', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'ES', 'DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'ES', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'ES', 'FR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'ES', 'GB'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'ES', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'ES', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'ES', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'ES', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'ES', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'ES', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'ES', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'ES', 'NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'ES', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'ES', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'ES', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'ES', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'ES', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'ES', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'FR', 'AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'FR', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'FR', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'FR', 'DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'FR', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'FR', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'FR', 'GB'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'FR', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'FR', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'FR', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'FR', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'FR', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'FR', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'FR', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'FR', 'NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'FR', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'FR', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'FR', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'FR', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'FR', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'FR', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'GB', 'AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'GB', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'GB', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'GB', 'DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'GB', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'GB', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'GB', 'FR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'GB', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'GB', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'GB', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'GB', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'GB', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'GB', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'GB', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'GB', 'NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'GB', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'GB', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'GB', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'GB', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'GB', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'GB', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'GR', 'AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'GR', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'GR', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'GR', 'DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'GR', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'GR', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'GR', 'FR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'GR', 'GB'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'GR', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'GR', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'GR', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'GR', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'GR', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'GR', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'GR', 'NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'GR', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'GR', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'GR', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'GR', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'GR', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'GR', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'HR', 'AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'HR', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'HR', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'HR', 'DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'HR', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'HR', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'HR', 'FR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'HR', 'GB'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'HR', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'HR', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'HR', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'HR', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'HR', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'HR', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'HR', 'NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'HR', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'HR', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'HR', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'HR', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'HR', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'HR', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'HU', 'AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'HU', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'HU', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'HU', 'DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'HU', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'HU', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'HU', 'FR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'HU', 'GB'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'HU', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'HU', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'HU', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'HU', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'HU', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'HU', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'HU', 'NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'HU', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'HU', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'HU', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'HU', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'HU', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'HU', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'IE', 'AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'IE', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'IE', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'IE', 'DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'IE', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'IE', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'IE', 'FR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'IE', 'GB'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'IE', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'IE', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'IE', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'IE', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'IE', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'IE', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'IE', 'NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'IE', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'IE', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'IE', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'IE', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'IE', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'IE', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'LT', 'AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'LT', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'LT', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'LT', 'DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'LT', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'LT', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'LT', 'FR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'LT', 'GB'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'LT', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'LT', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'LT', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'LT', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'LT', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'LT', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'LT', 'NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'LT', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'LT', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'LT', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'LT', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'LT', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'LT', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'LU', 'AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'LU', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'LU', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'LU', 'DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'LU', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'LU', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'LU', 'FR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'LU', 'GB'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'LU', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'LU', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'LU', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'LU', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'LU', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'LU', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'LU', 'NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'LU', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'LU', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'LU', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'LU', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'LU', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'LU', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'NL', 'AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'NL', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'NL', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'NL', 'DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'NL', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'NL', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'NL', 'FR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'NL', 'GB'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'NL', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'NL', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'NL', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'NL', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'NL', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'NL', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'NL', 'NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'NL', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'NL', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'NL', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'NL', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'NL', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'NL', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'NO', 'AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'NO', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'NO', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'NO', 'DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'NO', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'NO', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'NO', 'FR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'NO', 'GB'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'NO', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'NO', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'NO', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'NO', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'NO', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'NO', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'NO', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'NO', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'NO', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'NO', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'NO', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'NO', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'NO', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'PL', 'AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'PL', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'PL', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'PL', 'DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'PL', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'PL', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'PL', 'FR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'PL', 'GB'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'PL', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'PL', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'PL', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'PL', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'PL', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'PL', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'PL', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'PL', 'NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'PL', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'PL', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'PL', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'PL', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'PL', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'PT', 'AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'PT', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'PT', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'PT', 'DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'PT', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'PT', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'PT', 'FR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'PT', 'GB'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'PT', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'PT', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'PT', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'PT', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'PT', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'PT', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'PT', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'PT', 'NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'PT', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'PT', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'PT', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'PT', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'PT', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'RO', 'AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'RO', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'RO', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'RO', 'DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'RO', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'RO', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'RO', 'FR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'RO', 'GB'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'RO', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'RO', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'RO', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'RO', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'RO', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'RO', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'RO', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'RO', 'NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'RO', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'RO', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'RO', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'RO', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'RO', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'SE', 'AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'SE', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'SE', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'SE', 'DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'SE', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'SE', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'SE', 'FR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'SE', 'GB'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'SE', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'SE', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'SE', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'SE', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'SE', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'SE', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'SE', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'SE', 'NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'SE', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'SE', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'SE', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'SE', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'SE', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'SI', 'AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'SI', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'SI', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'SI', 'DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'SI', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'SI', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'SI', 'FR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'SI', 'GB'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'SI', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'SI', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'SI', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'SI', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'SI', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'SI', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'SI', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'SI', 'NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'SI', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'SI', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'SI', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'SI', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'SI', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'SK', 'AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'SK', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'SK', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'SK', 'DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'SK', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'SK', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'SK', 'FR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'SK', 'GB'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'SK', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'SK', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'SK', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'SK', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'SK', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'SK', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'SK', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'SK', 'NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'SK', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'SK', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'SK', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'SK', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'SK', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'AT', 'BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'AT', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'AT', 'DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'AT', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'AT', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'AT', 'FR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'AT', 'GB'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'AT', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'AT', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'AT', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'AT', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'AT', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'AT', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'AT', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'AT', 'NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'AT', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'AT', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'AT', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'AT', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'AT', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'AT', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'BE', 'AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'BE', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'BE', 'DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'BE', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'BE', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'BE', 'FR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'BE', 'GB'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'BE', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'BE', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'BE', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'BE', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'BE', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'BE', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'BE', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'BE', 'NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'BE', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'BE', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'BE', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'BE', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'BE', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'BE', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'CZ', 'AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'CZ', 'BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'CZ', 'DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'CZ', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'CZ', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'CZ', 'FR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'CZ', 'GB'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'CZ', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'CZ', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'CZ', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'CZ', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'CZ', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'CZ', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'CZ', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'CZ', 'NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'CZ', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'CZ', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'CZ', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'CZ', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'CZ', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'CZ', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'DE', 'AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'DE', 'BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'DE', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'DE', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'DE', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'DE', 'FR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'DE', 'GB'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'DE', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'DE', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'DE', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'DE', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'DE', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'DE', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ...}

# %% [markdown]
# ## Truck Capacity

# %%
model.addConstrs(((V[p,q] ==  
                 quicksum(x_[p,q,i] * Z[m,k] for k in E if (k != m) & (k != j) for i in L[k]) +
                 quicksum(x_[i,p,q] * Z[k,j] for k in E if (k != m) & (k != j) for i in L[k]) + 
                 x[p,q] * Z[m,j])
                 for m in E for j in E if m != j
                 for p in L[m] for q in L[j]), "Truck Capacity") ## We can't use E_mjk here
# Out:
# {('AT',
#   'BE',
#   'Hub Wien I-AT',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'BE',
#   'Hub Graz-AT',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'BG',
#   'Hub Wien I-AT',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'BG',
#   'Hub Graz-AT',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'CZ',
#   'Hub Wien I-AT',
#   'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'CZ',
#   'Hub Wien I-AT',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'CZ',
#   'Hub Wien I-AT',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'CZ',
#   'Hub Wien I-AT',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'CZ',
#   'Hub Wien I-AT',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'CZ',
#   'Hub Graz-AT',
#   'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'CZ',
#   'Hub Graz-AT',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'CZ',
#   'Hub Graz-AT',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'CZ',
#   'Hub Graz-AT',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'CZ',
#   'Hub Graz-AT',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'DE',
#   'Hub Wien I-AT',
#   'PZ 67 (Speyer)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'DE',
#   'Hub Wien I-AT',
#   'PZ 50 (Köln)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'DE',
#   'Hub Wien I-AT',
#   'PZ 04 (Radefeld/Leipzig)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'DE',
#   'Hub Wien I-AT',
#   'PZ 90 (Feucht/Nürnberg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'DE',
#   'Hub Wien I-AT',
#   'PZ 77 (Lahr)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'DE',
#   'Hub Wien I-AT',
#   'PZ 93 (Regensburg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'DE',
#   'Hub Wien I-AT',
#   'PZ 21 (Hamburg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'DE',
#   'Hub Wien I-AT',
#   'PZ 46 (Dorsten)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'DE',
#   'Hub Wien I-AT',
#   'PZ 58 (Hagen)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'DE',
#   'Hub Wien I-AT',
#   'PZ 08 (Neumark)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'DE',
#   'Hub Wien I-AT',
#   'PZ 47 (Krefeld)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'DE',
#   'Hub Wien I-AT',
#   'PZ 15 (Rüdersdorf)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'DE',
#   'Hub Graz-AT',
#   'PZ 67 (Speyer)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'DE',
#   'Hub Graz-AT',
#   'PZ 50 (Köln)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'DE',
#   'Hub Graz-AT',
#   'PZ 04 (Radefeld/Leipzig)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'DE',
#   'Hub Graz-AT',
#   'PZ 90 (Feucht/Nürnberg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'DE',
#   'Hub Graz-AT',
#   'PZ 77 (Lahr)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'DE',
#   'Hub Graz-AT',
#   'PZ 93 (Regensburg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'DE',
#   'Hub Graz-AT',
#   'PZ 21 (Hamburg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'DE',
#   'Hub Graz-AT',
#   'PZ 46 (Dorsten)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'DE',
#   'Hub Graz-AT',
#   'PZ 58 (Hagen)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'DE',
#   'Hub Graz-AT',
#   'PZ 08 (Neumark)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'DE',
#   'Hub Graz-AT',
#   'PZ 47 (Krefeld)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'DE',
#   'Hub Graz-AT',
#   'PZ 15 (Rüdersdorf)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'DK',
#   'Hub Wien I-AT',
#   'Kolding-DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'DK',
#   'Hub Graz-AT',
#   'Kolding-DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'ES',
#   'Hub Wien I-AT',
#   'Barcelona-ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'ES',
#   'Hub Wien I-AT',
#   'Madrid-ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'ES',
#   'Hub Wien I-AT',
#   'Araba (Vitoria)-ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'ES',
#   'Hub Graz-AT',
#   'Barcelona-ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'ES',
#   'Hub Graz-AT',
#   'Madrid-ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'ES',
#   'Hub Graz-AT',
#   'Araba (Vitoria)-ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'FR',
#   'Hub Wien I-AT',
#   'Combs la ville-FR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'FR',
#   'Hub Graz-AT',
#   'Combs la ville-FR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'GB',
#   'Hub Wien I-AT',
#   'Slough-GB'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'GB',
#   'Hub Wien I-AT',
#   'Ryton Gateway-GB'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'GB',
#   'Hub Graz-AT',
#   'Slough-GB'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'GB',
#   'Hub Graz-AT',
#   'Ryton Gateway-GB'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'GR',
#   'Hub Wien I-AT',
#   'Spata-GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'GR',
#   'Hub Graz-AT',
#   'Spata-GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'HR',
#   'Hub Wien I-AT',
#   'Zagreb-HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'HR',
#   'Hub Graz-AT',
#   'Zagreb-HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'HU',
#   'Hub Wien I-AT',
#   'Budapest OLK-HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'HU',
#   'Hub Wien I-AT',
#   'Budapest NPKK (OE)-HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'HU',
#   'Hub Graz-AT',
#   'Budapest OLK-HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'HU',
#   'Hub Graz-AT',
#   'Budapest NPKK (OE)-HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'IE',
#   'Hub Wien I-AT',
#   'Portlaoise-IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'IE',
#   'Hub Graz-AT',
#   'Portlaoise-IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'LT',
#   'Hub Wien I-AT',
#   'Kaunas-LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'LT',
#   'Hub Graz-AT',
#   'Kaunas-LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'LU',
#   'Hub Wien I-AT',
#   'Bettembourg-LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'LU',
#   'Hub Graz-AT',
#   'Bettembourg-LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'NL',
#   'Hub Wien I-AT',
#   'Eindhoven-Noord-NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'NL',
#   'Hub Wien I-AT',
#   'Utrecht-West + Centrum-NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'NL',
#   'Hub Wien I-AT',
#   'Zaltbommel-NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'NL',
#   'Hub Graz-AT',
#   'Eindhoven-Noord-NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'NL',
#   'Hub Graz-AT',
#   'Utrecht-West + Centrum-NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'NL',
#   'Hub Graz-AT',
#   'Zaltbommel-NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'NO',
#   'Hub Wien I-AT',
#   'Oslo-NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'NO',
#   'Hub Graz-AT',
#   'Oslo-NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'PL',
#   'Hub Wien I-AT',
#   'Suwałki (Ełk)-PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'PL',
#   'Hub Wien I-AT',
#   'Poznań-PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'PL',
#   'Hub Wien I-AT',
#   'Zabrze-PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'PL',
#   'Hub Wien I-AT',
#   'Koninko-PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'PL',
#   'Hub Wien I-AT',
#   'Wrocław-PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'PL',
#   'Hub Wien I-AT',
#   'Bydgoszcz (Solec Kujawski)-PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'PL',
#   'Hub Graz-AT',
#   'Suwałki (Ełk)-PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'PL',
#   'Hub Graz-AT',
#   'Poznań-PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'PL',
#   'Hub Graz-AT',
#   'Zabrze-PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'PL',
#   'Hub Graz-AT',
#   'Koninko-PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'PL',
#   'Hub Graz-AT',
#   'Wrocław-PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'PL',
#   'Hub Graz-AT',
#   'Bydgoszcz (Solec Kujawski)-PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'PT',
#   'Hub Wien I-AT',
#   'Lisboa-PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'PT',
#   'Hub Graz-AT',
#   'Lisboa-PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'RO',
#   'Hub Wien I-AT',
#   'Oradea-RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'RO',
#   'Hub Graz-AT',
#   'Oradea-RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SE',
#   'Hub Wien I-AT',
#   'Stockholm - Västberga-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SE',
#   'Hub Wien I-AT',
#   'Helsingborg-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SE',
#   'Hub Wien I-AT',
#   'Arlöv-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SE',
#   'Hub Wien I-AT',
#   'Malmö-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SE',
#   'Hub Graz-AT',
#   'Stockholm - Västberga-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SE',
#   'Hub Graz-AT',
#   'Helsingborg-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SE',
#   'Hub Graz-AT',
#   'Arlöv-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SE',
#   'Hub Graz-AT',
#   'Malmö-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SI',
#   'Hub Wien I-AT',
#   'Ljubljana-SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SI',
#   'Hub Graz-AT',
#   'Ljubljana-SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SK',
#   'Hub Wien I-AT',
#   'Bratislava - Raca-SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SK',
#   'Hub Wien I-AT',
#   'Bratislava - Petrzalka-SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SK',
#   'Hub Wien I-AT',
#   'Zilina- Strecno-SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SK',
#   'Hub Graz-AT',
#   'Bratislava - Raca-SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SK',
#   'Hub Graz-AT',
#   'Bratislava - Petrzalka-SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SK',
#   'Hub Graz-AT',
#   'Zilina- Strecno-SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'AT',
#   'Brüssel-BE',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'AT',
#   'Brüssel-BE',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'BG',
#   'Brüssel-BE',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'CZ',
#   'Brüssel-BE',
#   'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'CZ',
#   'Brüssel-BE',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'CZ',
#   'Brüssel-BE',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'CZ',
#   'Brüssel-BE',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'CZ',
#   'Brüssel-BE',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'DE',
#   'Brüssel-BE',
#   'PZ 67 (Speyer)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'DE',
#   'Brüssel-BE',
#   'PZ 50 (Köln)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'DE',
#   'Brüssel-BE',
#   'PZ 04 (Radefeld/Leipzig)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'DE',
#   'Brüssel-BE',
#   'PZ 90 (Feucht/Nürnberg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'DE',
#   'Brüssel-BE',
#   'PZ 77 (Lahr)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'DE',
#   'Brüssel-BE',
#   'PZ 93 (Regensburg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'DE',
#   'Brüssel-BE',
#   'PZ 21 (Hamburg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'DE',
#   'Brüssel-BE',
#   'PZ 46 (Dorsten)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'DE',
#   'Brüssel-BE',
#   'PZ 58 (Hagen)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'DE',
#   'Brüssel-BE',
#   'PZ 08 (Neumark)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'DE',
#   'Brüssel-BE',
#   'PZ 47 (Krefeld)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'DE',
#   'Brüssel-BE',
#   'PZ 15 (Rüdersdorf)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'DK',
#   'Brüssel-BE',
#   'Kolding-DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'ES',
#   'Brüssel-BE',
#   'Barcelona-ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'ES',
#   'Brüssel-BE',
#   'Madrid-ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'ES',
#   'Brüssel-BE',
#   'Araba (Vitoria)-ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'FR',
#   'Brüssel-BE',
#   'Combs la ville-FR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'GB',
#   'Brüssel-BE',
#   'Slough-GB'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'GB',
#   'Brüssel-BE',
#   'Ryton Gateway-GB'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'GR',
#   'Brüssel-BE',
#   'Spata-GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'HR',
#   'Brüssel-BE',
#   'Zagreb-HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'HU',
#   'Brüssel-BE',
#   'Budapest OLK-HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'HU',
#   'Brüssel-BE',
#   'Budapest NPKK (OE)-HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'IE',
#   'Brüssel-BE',
#   'Portlaoise-IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'LT',
#   'Brüssel-BE',
#   'Kaunas-LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'LU',
#   'Brüssel-BE',
#   'Bettembourg-LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'NL',
#   'Brüssel-BE',
#   'Eindhoven-Noord-NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'NL',
#   'Brüssel-BE',
#   'Utrecht-West + Centrum-NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'NL',
#   'Brüssel-BE',
#   'Zaltbommel-NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'NO',
#   'Brüssel-BE',
#   'Oslo-NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'PL',
#   'Brüssel-BE',
#   'Suwałki (Ełk)-PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'PL',
#   'Brüssel-BE',
#   'Poznań-PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'PL',
#   'Brüssel-BE',
#   'Zabrze-PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'PL',
#   'Brüssel-BE',
#   'Koninko-PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'PL',
#   'Brüssel-BE',
#   'Wrocław-PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'PL',
#   'Brüssel-BE',
#   'Bydgoszcz (Solec Kujawski)-PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'PT',
#   'Brüssel-BE',
#   'Lisboa-PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'RO',
#   'Brüssel-BE',
#   'Oradea-RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'SE',
#   'Brüssel-BE',
#   'Stockholm - Västberga-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'SE',
#   'Brüssel-BE',
#   'Helsingborg-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'SE',
#   'Brüssel-BE',
#   'Arlöv-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'SE',
#   'Brüssel-BE',
#   'Malmö-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'SI',
#   'Brüssel-BE',
#   'Ljubljana-SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'SK',
#   'Brüssel-BE',
#   'Bratislava - Raca-SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'SK',
#   'Brüssel-BE',
#   'Bratislava - Petrzalka-SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'SK',
#   'Brüssel-BE',
#   'Zilina- Strecno-SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'AT',
#   'Sofia-BG',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'AT',
#   'Sofia-BG',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'BE',
#   'Sofia-BG',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'CZ', 'Sofia-BG', 'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'CZ',
#   'Sofia-BG',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'CZ',
#   'Sofia-BG',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'CZ',
#   'Sofia-BG',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'CZ',
#   'Sofia-BG',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'DE',
#   'Sofia-BG',
#   'PZ 67 (Speyer)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'DE',
#   'Sofia-BG',
#   'PZ 50 (Köln)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'DE',
#   'Sofia-BG',
#   'PZ 04 (Radefeld/Leipzig)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'DE',
#   'Sofia-BG',
#   'PZ 90 (Feucht/Nürnberg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'DE',
#   'Sofia-BG',
#   'PZ 77 (Lahr)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'DE',
#   'Sofia-BG',
#   'PZ 93 (Regensburg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'DE',
#   'Sofia-BG',
#   'PZ 21 (Hamburg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'DE',
#   'Sofia-BG',
#   'PZ 46 (Dorsten)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'DE',
#   'Sofia-BG',
#   'PZ 58 (Hagen)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'DE',
#   'Sofia-BG',
#   'PZ 08 (Neumark)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'DE',
#   'Sofia-BG',
#   'PZ 47 (Krefeld)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'DE',
#   'Sofia-BG',
#   'PZ 15 (Rüdersdorf)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'DK',
#   'Sofia-BG',
#   'Kolding-DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'ES',
#   'Sofia-BG',
#   'Barcelona-ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'ES',
#   'Sofia-BG',
#   'Madrid-ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'ES',
#   'Sofia-BG',
#   'Araba (Vitoria)-ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'FR',
#   'Sofia-BG',
#   'Combs la ville-FR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'GB',
#   'Sofia-BG',
#   'Slough-GB'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'GB',
#   'Sofia-BG',
#   'Ryton Gateway-GB'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'GR', 'Sofia-BG', 'Spata-GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'HR',
#   'Sofia-BG',
#   'Zagreb-HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'HU',
#   'Sofia-BG',
#   'Budapest OLK-HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'HU',
#   'Sofia-BG',
#   'Budapest NPKK (OE)-HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'IE',
#   'Sofia-BG',
#   'Portlaoise-IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'LT',
#   'Sofia-BG',
#   'Kaunas-LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'LU',
#   'Sofia-BG',
#   'Bettembourg-LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'NL',
#   'Sofia-BG',
#   'Eindhoven-Noord-NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'NL',
#   'Sofia-BG',
#   'Utrecht-West + Centrum-NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'NL',
#   'Sofia-BG',
#   'Zaltbommel-NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'NO', 'Sofia-BG', 'Oslo-NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'PL',
#   'Sofia-BG',
#   'Suwałki (Ełk)-PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'PL',
#   'Sofia-BG',
#   'Poznań-PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'PL',
#   'Sofia-BG',
#   'Zabrze-PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'PL',
#   'Sofia-BG',
#   'Koninko-PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'PL',
#   'Sofia-BG',
#   'Wrocław-PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'PL',
#   'Sofia-BG',
#   'Bydgoszcz (Solec Kujawski)-PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'PT',
#   'Sofia-BG',
#   'Lisboa-PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'RO',
#   'Sofia-BG',
#   'Oradea-RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'SE',
#   'Sofia-BG',
#   'Stockholm - Västberga-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'SE',
#   'Sofia-BG',
#   'Helsingborg-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'SE', 'Sofia-BG', 'Arlöv-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'SE', 'Sofia-BG', 'Malmö-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'SI',
#   'Sofia-BG',
#   'Ljubljana-SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'SK',
#   'Sofia-BG',
#   'Bratislava - Raca-SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'SK',
#   'Sofia-BG',
#   'Bratislava - Petrzalka-SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'SK',
#   'Sofia-BG',
#   'Zilina- Strecno-SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'AT',
#   'Brno-CZ',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'AT',
#   'Brno-CZ',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'AT',
#   'Ostrava-CZ',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'AT',
#   'Ostrava-CZ',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'AT',
#   'Krupka 1-CZ',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'AT',
#   'Krupka 1-CZ',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'AT',
#   'Plzen 1-CZ',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'AT',
#   'Plzen 1-CZ',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'AT',
#   'Hradec Kralove - Brezhrad-CZ',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'AT',
#   'Hradec Kralove - Brezhrad-CZ',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'BE',
#   'Brno-CZ',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'BE',
#   'Ostrava-CZ',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'BE',
#   'Krupka 1-CZ',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'BE',
#   'Plzen 1-CZ',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'BE',
#   'Hradec Kralove - Brezhrad-CZ',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'BG', 'Brno-CZ', 'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'BG',
#   'Ostrava-CZ',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'BG',
#   'Krupka 1-CZ',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'BG',
#   'Plzen 1-CZ',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'BG',
#   'Hradec Kralove - Brezhrad-CZ',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'Brno-CZ',
#   'PZ 67 (Speyer)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'Brno-CZ',
#   'PZ 50 (Köln)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'Brno-CZ',
#   'PZ 04 (Radefeld/Leipzig)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'Brno-CZ',
#   'PZ 90 (Feucht/Nürnberg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'Brno-CZ',
#   'PZ 77 (Lahr)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'Brno-CZ',
#   'PZ 93 (Regensburg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'Brno-CZ',
#   'PZ 21 (Hamburg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'Brno-CZ',
#   'PZ 46 (Dorsten)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'Brno-CZ',
#   'PZ 58 (Hagen)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'Brno-CZ',
#   'PZ 08 (Neumark)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'Brno-CZ',
#   'PZ 47 (Krefeld)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'Brno-CZ',
#   'PZ 15 (Rüdersdorf)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'Ostrava-CZ',
#   'PZ 67 (Speyer)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'Ostrava-CZ',
#   'PZ 50 (Köln)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'Ostrava-CZ',
#   'PZ 04 (Radefeld/Leipzig)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'Ostrava-CZ',
#   'PZ 90 (Feucht/Nürnberg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'Ostrava-CZ',
#   'PZ 77 (Lahr)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'Ostrava-CZ',
#   'PZ 93 (Regensburg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'Ostrava-CZ',
#   'PZ 21 (Hamburg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'Ostrava-CZ',
#   'PZ 46 (Dorsten)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'Ostrava-CZ',
#   'PZ 58 (Hagen)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'Ostrava-CZ',
#   'PZ 08 (Neumark)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'Ostrava-CZ',
#   'PZ 47 (Krefeld)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'Ostrava-CZ',
#   'PZ 15 (Rüdersdorf)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'Krupka 1-CZ',
#   'PZ 67 (Speyer)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'Krupka 1-CZ',
#   'PZ 50 (Köln)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'Krupka 1-CZ',
#   'PZ 04 (Radefeld/Leipzig)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'Krupka 1-CZ',
#   'PZ 90 (Feucht/Nürnberg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'Krupka 1-CZ',
#   'PZ 77 (Lahr)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'Krupka 1-CZ',
#   'PZ 93 (Regensburg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'Krupka 1-CZ',
#   'PZ 21 (Hamburg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'Krupka 1-CZ',
#   'PZ 46 (Dorsten)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'Krupka 1-CZ',
#   'PZ 58 (Hagen)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'Krupka 1-CZ',
#   'PZ 08 (Neumark)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'Krupka 1-CZ',
#   'PZ 47 (Krefeld)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'Krupka 1-CZ',
#   'PZ 15 (Rüdersdorf)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'Plzen 1-CZ',
#   'PZ 67 (Speyer)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'Plzen 1-CZ',
#   'PZ 50 (Köln)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'Plzen 1-CZ',
#   'PZ 04 (Radefeld/Leipzig)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'Plzen 1-CZ',
#   'PZ 90 (Feucht/Nürnberg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'Plzen 1-CZ',
#   'PZ 77 (Lahr)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'Plzen 1-CZ',
#   'PZ 93 (Regensburg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'Plzen 1-CZ',
#   'PZ 21 (Hamburg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'Plzen 1-CZ',
#   'PZ 46 (Dorsten)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'Plzen 1-CZ',
#   'PZ 58 (Hagen)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'Plzen 1-CZ',
#   'PZ 08 (Neumark)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'Plzen 1-CZ',
#   'PZ 47 (Krefeld)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'Plzen 1-CZ',
#   'PZ 15 (Rüdersdorf)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'Hradec Kralove - Brezhrad-CZ',
#   'PZ 67 (Speyer)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'Hradec Kralove - Brezhrad-CZ',
#   'PZ 50 (Köln)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'Hradec Kralove - Brezhrad-CZ',
#   'PZ 04 (Radefeld/Leipzig)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'Hradec Kralove - Brezhrad-CZ',
#   'PZ 90 (Feucht/Nürnberg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'Hradec Kralove - Brezhrad-CZ',
#   'PZ 77 (Lahr)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'Hradec Kralove - Brezhrad-CZ',
#   'PZ 93 (Regensburg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'Hradec Kralove - Brezhrad-CZ',
#   'PZ 21 (Hamburg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'Hradec Kralove - Brezhrad-CZ',
#   'PZ 46 (Dorsten)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'Hradec Kralove - Brezhrad-CZ',
#   'PZ 58 (Hagen)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'Hradec Kralove - Brezhrad-CZ',
#   'PZ 08 (Neumark)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'Hradec Kralove - Brezhrad-CZ',
#   'PZ 47 (Krefeld)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'Hradec Kralove - Brezhrad-CZ',
#   'PZ 15 (Rüdersdorf)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DK',
#   'Brno-CZ',
#   'Kolding-DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DK',
#   'Ostrava-CZ',
#   'Kolding-DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DK',
#   'Krupka 1-CZ',
#   'Kolding-DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DK',
#   'Plzen 1-CZ',
#   'Kolding-DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DK',
#   'Hradec Kralove - Brezhrad-CZ',
#   'Kolding-DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'ES',
#   'Brno-CZ',
#   'Barcelona-ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'ES', 'Brno-CZ', 'Madrid-ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'ES',
#   'Brno-CZ',
#   'Araba (Vitoria)-ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'ES',
#   'Ostrava-CZ',
#   'Barcelona-ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'ES',
#   'Ostrava-CZ',
#   'Madrid-ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'ES',
#   'Ostrava-CZ',
#   'Araba (Vitoria)-ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'ES',
#   'Krupka 1-CZ',
#   'Barcelona-ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'ES',
#   'Krupka 1-CZ',
#   'Madrid-ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'ES',
#   'Krupka 1-CZ',
#   'Araba (Vitoria)-ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'ES',
#   'Plzen 1-CZ',
#   'Barcelona-ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'ES',
#   'Plzen 1-CZ',
#   'Madrid-ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'ES',
#   'Plzen 1-CZ',
#   'Araba (Vitoria)-ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'ES',
#   'Hradec Kralove - Brezhrad-CZ',
#   'Barcelona-ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'ES',
#   'Hradec Kralove - Brezhrad-CZ',
#   'Madrid-ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'ES',
#   'Hradec Kralove - Brezhrad-CZ',
#   'Araba (Vitoria)-ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'FR',
#   'Brno-CZ',
#   'Combs la ville-FR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'FR',
#   'Ostrava-CZ',
#   'Combs la ville-FR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'FR',
#   'Krupka 1-CZ',
#   'Combs la ville-FR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'FR',
#   'Plzen 1-CZ',
#   'Combs la ville-FR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'FR',
#   'Hradec Kralove - Brezhrad-CZ',
#   'Combs la ville-FR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'GB', 'Brno-CZ', 'Slough-GB'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'GB',
#   'Brno-CZ',
#   'Ryton Gateway-GB'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'GB',
#   'Ostrava-CZ',
#   'Slough-GB'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'GB',
#   'Ostrava-CZ',
#   'Ryton Gateway-GB'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'GB',
#   'Krupka 1-CZ',
#   'Slough-GB'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'GB',
#   'Krupka 1-CZ',
#   'Ryton Gateway-GB'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'GB',
#   'Plzen 1-CZ',
#   'Slough-GB'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'GB',
#   'Plzen 1-CZ',
#   'Ryton Gateway-GB'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'GB',
#   'Hradec Kralove - Brezhrad-CZ',
#   'Slough-GB'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'GB',
#   'Hradec Kralove - Brezhrad-CZ',
#   'Ryton Gateway-GB'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'GR', 'Brno-CZ', 'Spata-GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'GR',
#   'Ostrava-CZ',
#   'Spata-GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'GR',
#   'Krupka 1-CZ',
#   'Spata-GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'GR',
#   'Plzen 1-CZ',
#   'Spata-GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'GR',
#   'Hradec Kralove - Brezhrad-CZ',
#   'Spata-GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'HR', 'Brno-CZ', 'Zagreb-HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'HR',
#   'Ostrava-CZ',
#   'Zagreb-HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'HR',
#   'Krupka 1-CZ',
#   'Zagreb-HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'HR',
#   'Plzen 1-CZ',
#   'Zagreb-HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'HR',
#   'Hradec Kralove - Brezhrad-CZ',
#   'Zagreb-HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'HU',
#   'Brno-CZ',
#   'Budapest OLK-HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'HU',
#   'Brno-CZ',
#   'Budapest NPKK (OE)-HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'HU',
#   'Ostrava-CZ',
#   'Budapest OLK-HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'HU',
#   'Ostrava-CZ',
#   'Budapest NPKK (OE)-HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'HU',
#   'Krupka 1-CZ',
#   'Budapest OLK-HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'HU',
#   'Krupka 1-CZ',
#   'Budapest NPKK (OE)-HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'HU',
#   'Plzen 1-CZ',
#   'Budapest OLK-HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'HU',
#   'Plzen 1-CZ',
#   'Budapest NPKK (OE)-HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'HU',
#   'Hradec Kralove - Brezhrad-CZ',
#   'Budapest OLK-HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'HU',
#   'Hradec Kralove - Brezhrad-CZ',
#   'Budapest NPKK (OE)-HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'IE',
#   'Brno-CZ',
#   'Portlaoise-IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'IE',
#   'Ostrava-CZ',
#   'Portlaoise-IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'IE',
#   'Krupka 1-CZ',
#   'Portlaoise-IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'IE',
#   'Plzen 1-CZ',
#   'Portlaoise-IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'IE',
#   'Hradec Kralove - Brezhrad-CZ',
#   'Portlaoise-IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'LT', 'Brno-CZ', 'Kaunas-LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'LT',
#   'Ostrava-CZ',
#   'Kaunas-LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'LT',
#   'Krupka 1-CZ',
#   'Kaunas-LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'LT',
#   'Plzen 1-CZ',
#   'Kaunas-LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'LT',
#   'Hradec Kralove - Brezhrad-CZ',
#   'Kaunas-LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'LU',
#   'Brno-CZ',
#   'Bettembourg-LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'LU',
#   'Ostrava-CZ',
#   'Bettembourg-LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'LU',
#   'Krupka 1-CZ',
#   'Bettembourg-LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'LU',
#   'Plzen 1-CZ',
#   'Bettembourg-LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'LU',
#   'Hradec Kralove - Brezhrad-CZ',
#   'Bettembourg-LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'NL',
#   'Brno-CZ',
#   'Eindhoven-Noord-NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'NL',
#   'Brno-CZ',
#   'Utrecht-West + Centrum-NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'NL',
#   'Brno-CZ',
#   'Zaltbommel-NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'NL',
#   'Ostrava-CZ',
#   'Eindhoven-Noord-NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'NL',
#   'Ostrava-CZ',
#   'Utrecht-West + Centrum-NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'NL',
#   'Ostrava-CZ',
#   'Zaltbommel-NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'NL',
#   'Krupka 1-CZ',
#   'Eindhoven-Noord-NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'NL',
#   'Krupka 1-CZ',
#   'Utrecht-West + Centrum-NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'NL',
#   'Krupka 1-CZ',
#   'Zaltbommel-NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'NL',
#   'Plzen 1-CZ',
#   'Eindhoven-Noord-NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'NL',
#   'Plzen 1-CZ',
#   'Utrecht-West + Centrum-NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'NL',
#   'Plzen 1-CZ',
#   'Zaltbommel-NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'NL',
#   'Hradec Kralove - Brezhrad-CZ',
#   'Eindhoven-Noord-NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'NL',
#   'Hradec Kralove - Brezhrad-CZ',
#   'Utrecht-West + Centrum-NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'NL',
#   'Hradec Kralove - Brezhrad-CZ',
#   'Zaltbommel-NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'NO', 'Brno-CZ', 'Oslo-NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'NO',
#   'Ostrava-CZ',
#   'Oslo-NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'NO',
#   'Krupka 1-CZ',
#   'Oslo-NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'NO',
#   'Plzen 1-CZ',
#   'Oslo-NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'NO',
#   'Hradec Kralove - Brezhrad-CZ',
#   'Oslo-NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PL',
#   'Brno-CZ',
#   'Suwałki (Ełk)-PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'PL', 'Brno-CZ', 'Poznań-PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'PL', 'Brno-CZ', 'Zabrze-PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PL',
#   'Brno-CZ',
#   'Koninko-PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PL',
#   'Brno-CZ',
#   'Wrocław-PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PL',
#   'Brno-CZ',
#   'Bydgoszcz (Solec Kujawski)-PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PL',
#   'Ostrava-CZ',
#   'Suwałki (Ełk)-PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PL',
#   'Ostrava-CZ',
#   'Poznań-PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PL',
#   'Ostrava-CZ',
#   'Zabrze-PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PL',
#   'Ostrava-CZ',
#   'Koninko-PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PL',
#   'Ostrava-CZ',
#   'Wrocław-PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PL',
#   'Ostrava-CZ',
#   'Bydgoszcz (Solec Kujawski)-PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PL',
#   'Krupka 1-CZ',
#   'Suwałki (Ełk)-PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PL',
#   'Krupka 1-CZ',
#   'Poznań-PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PL',
#   'Krupka 1-CZ',
#   'Zabrze-PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PL',
#   'Krupka 1-CZ',
#   'Koninko-PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PL',
#   'Krupka 1-CZ',
#   'Wrocław-PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PL',
#   'Krupka 1-CZ',
#   'Bydgoszcz (Solec Kujawski)-PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PL',
#   'Plzen 1-CZ',
#   'Suwałki (Ełk)-PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PL',
#   'Plzen 1-CZ',
#   'Poznań-PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PL',
#   'Plzen 1-CZ',
#   'Zabrze-PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PL',
#   'Plzen 1-CZ',
#   'Koninko-PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PL',
#   'Plzen 1-CZ',
#   'Wrocław-PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PL',
#   'Plzen 1-CZ',
#   'Bydgoszcz (Solec Kujawski)-PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PL',
#   'Hradec Kralove - Brezhrad-CZ',
#   'Suwałki (Ełk)-PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PL',
#   'Hradec Kralove - Brezhrad-CZ',
#   'Poznań-PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PL',
#   'Hradec Kralove - Brezhrad-CZ',
#   'Zabrze-PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PL',
#   'Hradec Kralove - Brezhrad-CZ',
#   'Koninko-PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PL',
#   'Hradec Kralove - Brezhrad-CZ',
#   'Wrocław-PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PL',
#   'Hradec Kralove - Brezhrad-CZ',
#   'Bydgoszcz (Solec Kujawski)-PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'PT', 'Brno-CZ', 'Lisboa-PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PT',
#   'Ostrava-CZ',
#   'Lisboa-PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PT',
#   'Krupka 1-CZ',
#   'Lisboa-PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PT',
#   'Plzen 1-CZ',
#   'Lisboa-PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PT',
#   'Hradec Kralove - Brezhrad-CZ',
#   'Lisboa-PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'RO', 'Brno-CZ', 'Oradea-RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'RO',
#   'Ostrava-CZ',
#   'Oradea-RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'RO',
#   'Krupka 1-CZ',
#   'Oradea-RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'RO',
#   'Plzen 1-CZ',
#   'Oradea-RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'RO',
#   'Hradec Kralove - Brezhrad-CZ',
#   'Oradea-RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SE',
#   'Brno-CZ',
#   'Stockholm - Västberga-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SE',
#   'Brno-CZ',
#   'Helsingborg-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'SE', 'Brno-CZ', 'Arlöv-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'SE', 'Brno-CZ', 'Malmö-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SE',
#   'Ostrava-CZ',
#   'Stockholm - Västberga-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SE',
#   'Ostrava-CZ',
#   'Helsingborg-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SE',
#   'Ostrava-CZ',
#   'Arlöv-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SE',
#   'Ostrava-CZ',
#   'Malmö-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SE',
#   'Krupka 1-CZ',
#   'Stockholm - Västberga-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SE',
#   'Krupka 1-CZ',
#   'Helsingborg-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SE',
#   'Krupka 1-CZ',
#   'Arlöv-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SE',
#   'Krupka 1-CZ',
#   'Malmö-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SE',
#   'Plzen 1-CZ',
#   'Stockholm - Västberga-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SE',
#   'Plzen 1-CZ',
#   'Helsingborg-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SE',
#   'Plzen 1-CZ',
#   'Arlöv-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SE',
#   'Plzen 1-CZ',
#   'Malmö-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SE',
#   'Hradec Kralove - Brezhrad-CZ',
#   'Stockholm - Västberga-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SE',
#   'Hradec Kralove - Brezhrad-CZ',
#   'Helsingborg-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SE',
#   'Hradec Kralove - Brezhrad-CZ',
#   'Arlöv-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SE',
#   'Hradec Kralove - Brezhrad-CZ',
#   'Malmö-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SI',
#   'Brno-CZ',
#   'Ljubljana-SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SI',
#   'Ostrava-CZ',
#   'Ljubljana-SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SI',
#   'Krupka 1-CZ',
#   'Ljubljana-SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SI',
#   'Plzen 1-CZ',
#   'Ljubljana-SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SI',
#   'Hradec Kralove - Brezhrad-CZ',
#   'Ljubljana-SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SK',
#   'Brno-CZ',
#   'Bratislava - Raca-SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SK',
#   'Brno-CZ',
#   'Bratislava - Petrzalka-SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SK',
#   'Brno-CZ',
#   'Zilina- Strecno-SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SK',
#   'Ostrava-CZ',
#   'Bratislava - Raca-SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SK',
#   'Ostrava-CZ',
#   'Bratislava - Petrzalka-SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SK',
#   'Ostrava-CZ',
#   'Zilina- Strecno-SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SK',
#   'Krupka 1-CZ',
#   'Bratislava - Raca-SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SK',
#   'Krupka 1-CZ',
#   'Bratislava - Petrzalka-SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SK',
#   'Krupka 1-CZ',
#   'Zilina- Strecno-SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SK',
#   'Plzen 1-CZ',
#   'Bratislava - Raca-SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SK',
#   'Plzen 1-CZ',
#   'Bratislava - Petrzalka-SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SK',
#   'Plzen 1-CZ',
#   'Zilina- Strecno-SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SK',
#   'Hradec Kralove - Brezhrad-CZ',
#   'Bratislava - Raca-SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SK',
#   'Hradec Kralove - Brezhrad-CZ',
#   'Bratislava - Petrzalka-SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SK',
#   'Hradec Kralove - Brezhrad-CZ',
#   'Zilina- Strecno-SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'AT',
#   'PZ 67 (Speyer)-DE',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'AT',
#   'PZ 67 (Speyer)-DE',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'AT',
#   'PZ 50 (Köln)-DE',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'AT',
#   'PZ 50 (Köln)-DE',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'AT',
#   'PZ 04 (Radefeld/Leipzig)-DE',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'AT',
#   'PZ 04 (Radefeld/Leipzig)-DE',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'AT',
#   'PZ 90 (Feucht/Nürnberg)-DE',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'AT',
#   'PZ 90 (Feucht/Nürnberg)-DE',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'AT',
#   'PZ 77 (Lahr)-DE',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'AT',
#   'PZ 77 (Lahr)-DE',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'AT',
#   'PZ 93 (Regensburg)-DE',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'AT',
#   'PZ 93 (Regensburg)-DE',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'AT',
#   'PZ 21 (Hamburg)-DE',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'AT',
#   'PZ 21 (Hamburg)-DE',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'AT',
#   'PZ 46 (Dorsten)-DE',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'AT',
#   'PZ 46 (Dorsten)-DE',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'AT',
#   'PZ 58 (Hagen)-DE',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'AT',
#   'PZ 58 (Hagen)-DE',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'AT',
#   'PZ 08 (Neumark)-DE',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'AT',
#   'PZ 08 (Neumark)-DE',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'AT',
#   'PZ 47 (Krefeld)-DE',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'AT',
#   'PZ 47 (Krefeld)-DE',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'AT',
#   'PZ 15 (Rüdersdorf)-DE',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'AT',
#   'PZ 15 (Rüdersdorf)-DE',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'BE',
#   'PZ 67 (Speyer)-DE',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'BE',
#   'PZ 50 (Köln)-DE',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'BE',
#   'PZ 04 (Radefeld/Leipzig)-DE',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'BE',
#   'PZ 90 (Feucht/Nürnberg)-DE',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'BE',
#   'PZ 77 (Lahr)-DE',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'BE',
#   'PZ 93 (Regensburg)-DE',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'BE',
#   'PZ 21 (Hamburg)-DE',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'BE',
#   'PZ 46 (Dorsten)-DE',
# ...
#   'Zabrze-PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'PL',
#   'PZ 08 (Neumark)-DE',
#   'Koninko-PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'PL',
#   'PZ 08 (Neumark)-DE',
#   'Wrocław-PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'PL',
#   'PZ 08 (Neumark)-DE',
#   'Bydgoszcz (Solec Kujawski)-PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'PL',
#   'PZ 47 (Krefeld)-DE',
#   'Suwałki (Ełk)-PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'PL',
#   'PZ 47 (Krefeld)-DE',
#   'Poznań-PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'PL',
#   'PZ 47 (Krefeld)-DE',
#   'Zabrze-PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'PL',
#   'PZ 47 (Krefeld)-DE',
#   'Koninko-PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'PL',
#   'PZ 47 (Krefeld)-DE',
#   'Wrocław-PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'PL',
#   'PZ 47 (Krefeld)-DE',
#   'Bydgoszcz (Solec Kujawski)-PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'PL',
#   'PZ 15 (Rüdersdorf)-DE',
#   'Suwałki (Ełk)-PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'PL',
#   'PZ 15 (Rüdersdorf)-DE',
#   'Poznań-PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'PL',
#   'PZ 15 (Rüdersdorf)-DE',
#   'Zabrze-PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'PL',
#   'PZ 15 (Rüdersdorf)-DE',
#   'Koninko-PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'PL',
#   'PZ 15 (Rüdersdorf)-DE',
#   'Wrocław-PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'PL',
#   'PZ 15 (Rüdersdorf)-DE',
#   'Bydgoszcz (Solec Kujawski)-PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'PT',
#   'PZ 67 (Speyer)-DE',
#   'Lisboa-PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'PT',
#   'PZ 50 (Köln)-DE',
#   'Lisboa-PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'PT',
#   'PZ 04 (Radefeld/Leipzig)-DE',
#   'Lisboa-PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'PT',
#   'PZ 90 (Feucht/Nürnberg)-DE',
#   'Lisboa-PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'PT',
#   'PZ 77 (Lahr)-DE',
#   'Lisboa-PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'PT',
#   'PZ 93 (Regensburg)-DE',
#   'Lisboa-PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'PT',
#   'PZ 21 (Hamburg)-DE',
#   'Lisboa-PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'PT',
#   'PZ 46 (Dorsten)-DE',
#   'Lisboa-PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'PT',
#   'PZ 58 (Hagen)-DE',
#   'Lisboa-PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'PT',
#   'PZ 08 (Neumark)-DE',
#   'Lisboa-PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'PT',
#   'PZ 47 (Krefeld)-DE',
#   'Lisboa-PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'PT',
#   'PZ 15 (Rüdersdorf)-DE',
#   'Lisboa-PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'RO',
#   'PZ 67 (Speyer)-DE',
#   'Oradea-RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'RO',
#   'PZ 50 (Köln)-DE',
#   'Oradea-RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'RO',
#   'PZ 04 (Radefeld/Leipzig)-DE',
#   'Oradea-RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'RO',
#   'PZ 90 (Feucht/Nürnberg)-DE',
#   'Oradea-RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'RO',
#   'PZ 77 (Lahr)-DE',
#   'Oradea-RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'RO',
#   'PZ 93 (Regensburg)-DE',
#   'Oradea-RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'RO',
#   'PZ 21 (Hamburg)-DE',
#   'Oradea-RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'RO',
#   'PZ 46 (Dorsten)-DE',
#   'Oradea-RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'RO',
#   'PZ 58 (Hagen)-DE',
#   'Oradea-RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'RO',
#   'PZ 08 (Neumark)-DE',
#   'Oradea-RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'RO',
#   'PZ 47 (Krefeld)-DE',
#   'Oradea-RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'RO',
#   'PZ 15 (Rüdersdorf)-DE',
#   'Oradea-RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'PZ 67 (Speyer)-DE',
#   'Stockholm - Västberga-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'PZ 67 (Speyer)-DE',
#   'Helsingborg-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'PZ 67 (Speyer)-DE',
#   'Arlöv-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'PZ 67 (Speyer)-DE',
#   'Malmö-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'PZ 50 (Köln)-DE',
#   'Stockholm - Västberga-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'PZ 50 (Köln)-DE',
#   'Helsingborg-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'PZ 50 (Köln)-DE',
#   'Arlöv-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'PZ 50 (Köln)-DE',
#   'Malmö-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'PZ 04 (Radefeld/Leipzig)-DE',
#   'Stockholm - Västberga-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'PZ 04 (Radefeld/Leipzig)-DE',
#   'Helsingborg-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'PZ 04 (Radefeld/Leipzig)-DE',
#   'Arlöv-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'PZ 04 (Radefeld/Leipzig)-DE',
#   'Malmö-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'PZ 90 (Feucht/Nürnberg)-DE',
#   'Stockholm - Västberga-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'PZ 90 (Feucht/Nürnberg)-DE',
#   'Helsingborg-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'PZ 90 (Feucht/Nürnberg)-DE',
#   'Arlöv-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'PZ 90 (Feucht/Nürnberg)-DE',
#   'Malmö-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'PZ 77 (Lahr)-DE',
#   'Stockholm - Västberga-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'PZ 77 (Lahr)-DE',
#   'Helsingborg-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'PZ 77 (Lahr)-DE',
#   'Arlöv-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'PZ 77 (Lahr)-DE',
#   'Malmö-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'PZ 93 (Regensburg)-DE',
#   'Stockholm - Västberga-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'PZ 93 (Regensburg)-DE',
#   'Helsingborg-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'PZ 93 (Regensburg)-DE',
#   'Arlöv-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'PZ 93 (Regensburg)-DE',
#   'Malmö-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'PZ 21 (Hamburg)-DE',
#   'Stockholm - Västberga-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'PZ 21 (Hamburg)-DE',
#   'Helsingborg-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'PZ 21 (Hamburg)-DE',
#   'Arlöv-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'PZ 21 (Hamburg)-DE',
#   'Malmö-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'PZ 46 (Dorsten)-DE',
#   'Stockholm - Västberga-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'PZ 46 (Dorsten)-DE',
#   'Helsingborg-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'PZ 46 (Dorsten)-DE',
#   'Arlöv-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'PZ 46 (Dorsten)-DE',
#   'Malmö-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'PZ 58 (Hagen)-DE',
#   'Stockholm - Västberga-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'PZ 58 (Hagen)-DE',
#   'Helsingborg-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'PZ 58 (Hagen)-DE',
#   'Arlöv-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'PZ 58 (Hagen)-DE',
#   'Malmö-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'PZ 08 (Neumark)-DE',
#   'Stockholm - Västberga-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'PZ 08 (Neumark)-DE',
#   'Helsingborg-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'PZ 08 (Neumark)-DE',
#   'Arlöv-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'PZ 08 (Neumark)-DE',
#   'Malmö-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'PZ 47 (Krefeld)-DE',
#   'Stockholm - Västberga-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'PZ 47 (Krefeld)-DE',
#   'Helsingborg-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'PZ 47 (Krefeld)-DE',
#   'Arlöv-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'PZ 47 (Krefeld)-DE',
#   'Malmö-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'PZ 15 (Rüdersdorf)-DE',
#   'Stockholm - Västberga-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'PZ 15 (Rüdersdorf)-DE',
#   'Helsingborg-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'PZ 15 (Rüdersdorf)-DE',
#   'Arlöv-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'PZ 15 (Rüdersdorf)-DE',
#   'Malmö-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SI',
#   'PZ 67 (Speyer)-DE',
#   'Ljubljana-SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SI',
#   'PZ 50 (Köln)-DE',
#   'Ljubljana-SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SI',
#   'PZ 04 (Radefeld/Leipzig)-DE',
#   'Ljubljana-SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SI',
#   'PZ 90 (Feucht/Nürnberg)-DE',
#   'Ljubljana-SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SI',
#   'PZ 77 (Lahr)-DE',
#   'Ljubljana-SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SI',
#   'PZ 93 (Regensburg)-DE',
#   'Ljubljana-SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SI',
#   'PZ 21 (Hamburg)-DE',
#   'Ljubljana-SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SI',
#   'PZ 46 (Dorsten)-DE',
#   'Ljubljana-SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SI',
#   'PZ 58 (Hagen)-DE',
#   'Ljubljana-SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SI',
#   'PZ 08 (Neumark)-DE',
#   'Ljubljana-SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SI',
#   'PZ 47 (Krefeld)-DE',
#   'Ljubljana-SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SI',
#   'PZ 15 (Rüdersdorf)-DE',
#   'Ljubljana-SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'PZ 67 (Speyer)-DE',
#   'Bratislava - Raca-SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'PZ 67 (Speyer)-DE',
#   'Bratislava - Petrzalka-SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'PZ 67 (Speyer)-DE',
#   'Zilina- Strecno-SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'PZ 50 (Köln)-DE',
#   'Bratislava - Raca-SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'PZ 50 (Köln)-DE',
#   'Bratislava - Petrzalka-SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'PZ 50 (Köln)-DE',
#   'Zilina- Strecno-SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'PZ 04 (Radefeld/Leipzig)-DE',
#   'Bratislava - Raca-SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'PZ 04 (Radefeld/Leipzig)-DE',
#   'Bratislava - Petrzalka-SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'PZ 04 (Radefeld/Leipzig)-DE',
#   'Zilina- Strecno-SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'PZ 90 (Feucht/Nürnberg)-DE',
#   'Bratislava - Raca-SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'PZ 90 (Feucht/Nürnberg)-DE',
#   'Bratislava - Petrzalka-SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'PZ 90 (Feucht/Nürnberg)-DE',
#   'Zilina- Strecno-SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'PZ 77 (Lahr)-DE',
#   'Bratislava - Raca-SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'PZ 77 (Lahr)-DE',
#   'Bratislava - Petrzalka-SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'PZ 77 (Lahr)-DE',
#   'Zilina- Strecno-SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'PZ 93 (Regensburg)-DE',
#   'Bratislava - Raca-SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'PZ 93 (Regensburg)-DE',
#   'Bratislava - Petrzalka-SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'PZ 93 (Regensburg)-DE',
#   'Zilina- Strecno-SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'PZ 21 (Hamburg)-DE',
#   'Bratislava - Raca-SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'PZ 21 (Hamburg)-DE',
#   'Bratislava - Petrzalka-SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'PZ 21 (Hamburg)-DE',
#   'Zilina- Strecno-SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'PZ 46 (Dorsten)-DE',
#   'Bratislava - Raca-SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'PZ 46 (Dorsten)-DE',
#   'Bratislava - Petrzalka-SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'PZ 46 (Dorsten)-DE',
#   'Zilina- Strecno-SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'PZ 58 (Hagen)-DE',
#   'Bratislava - Raca-SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'PZ 58 (Hagen)-DE',
#   'Bratislava - Petrzalka-SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'PZ 58 (Hagen)-DE',
#   'Zilina- Strecno-SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'PZ 08 (Neumark)-DE',
#   'Bratislava - Raca-SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'PZ 08 (Neumark)-DE',
#   'Bratislava - Petrzalka-SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'PZ 08 (Neumark)-DE',
#   'Zilina- Strecno-SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'PZ 47 (Krefeld)-DE',
#   'Bratislava - Raca-SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'PZ 47 (Krefeld)-DE',
#   'Bratislava - Petrzalka-SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'PZ 47 (Krefeld)-DE',
#   'Zilina- Strecno-SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'PZ 15 (Rüdersdorf)-DE',
#   'Bratislava - Raca-SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'PZ 15 (Rüdersdorf)-DE',
#   'Bratislava - Petrzalka-SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'PZ 15 (Rüdersdorf)-DE',
#   'Zilina- Strecno-SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK',
#   'AT',
#   'Kolding-DK',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK',
#   'AT',
#   'Kolding-DK',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK',
#   'BE',
#   'Kolding-DK',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK',
#   'BG',
#   'Kolding-DK',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK',
#   'CZ',
#   'Kolding-DK',
#   'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK',
#   'CZ',
#   'Kolding-DK',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK',
#   'CZ',
#   'Kolding-DK',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK',
#   'CZ',
#   'Kolding-DK',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK',
#   'CZ',
#   'Kolding-DK',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK',
#   'DE',
#   'Kolding-DK',
#   'PZ 67 (Speyer)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK',
#   'DE',
#   'Kolding-DK',
#   'PZ 50 (Köln)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK',
#   'DE',
#   'Kolding-DK',
#   'PZ 04 (Radefeld/Leipzig)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK',
#   'DE',
#   'Kolding-DK',
#   'PZ 90 (Feucht/Nürnberg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK',
#   'DE',
#   'Kolding-DK',
#   'PZ 77 (Lahr)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK',
#   'DE',
#   'Kolding-DK',
#   'PZ 93 (Regensburg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK',
#   'DE',
#   'Kolding-DK',
#   'PZ 21 (Hamburg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK',
#   'DE',
#   'Kolding-DK',
#   'PZ 46 (Dorsten)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK',
#   'DE',
#   'Kolding-DK',
#   'PZ 58 (Hagen)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK',
#   'DE',
#   'Kolding-DK',
#   'PZ 08 (Neumark)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK',
#   'DE',
#   'Kolding-DK',
#   'PZ 47 (Krefeld)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ...}

# %% [markdown]
# ## Truck type and Frequency of trucks

# %%
model.addConstrs(((V[p,q] <= 
                 quicksum(F[p,q,t] * C[t]*4 for t in T) )
                 for m in E for j in E if m != j for q in L[j] for p in L[m]), "Truck Type and Frequency")


# But the capacity can't be too much
model.addConstrs((V[p,q]*10000 >= 
                 quicksum(F[p,q,t] * C[t]*4 for t in T) 
                 for m in E for j in E if m != j for q in L[j] for p in L[m]), "Truck Type and Frequency")
# Out:
# {('AT',
#   'BE',
#   'Brüssel-BE',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'BE',
#   'Brüssel-BE',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'BG',
#   'Sofia-BG',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'BG',
#   'Sofia-BG',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'CZ',
#   'Brno-CZ',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'CZ',
#   'Brno-CZ',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'CZ',
#   'Ostrava-CZ',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'CZ',
#   'Ostrava-CZ',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'CZ',
#   'Krupka 1-CZ',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'CZ',
#   'Krupka 1-CZ',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'CZ',
#   'Plzen 1-CZ',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'CZ',
#   'Plzen 1-CZ',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'CZ',
#   'Hradec Kralove - Brezhrad-CZ',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'CZ',
#   'Hradec Kralove - Brezhrad-CZ',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'DE',
#   'PZ 67 (Speyer)-DE',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'DE',
#   'PZ 67 (Speyer)-DE',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'DE',
#   'PZ 50 (Köln)-DE',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'DE',
#   'PZ 50 (Köln)-DE',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'DE',
#   'PZ 04 (Radefeld/Leipzig)-DE',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'DE',
#   'PZ 04 (Radefeld/Leipzig)-DE',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'DE',
#   'PZ 90 (Feucht/Nürnberg)-DE',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'DE',
#   'PZ 90 (Feucht/Nürnberg)-DE',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'DE',
#   'PZ 77 (Lahr)-DE',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'DE',
#   'PZ 77 (Lahr)-DE',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'DE',
#   'PZ 93 (Regensburg)-DE',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'DE',
#   'PZ 93 (Regensburg)-DE',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'DE',
#   'PZ 21 (Hamburg)-DE',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'DE',
#   'PZ 21 (Hamburg)-DE',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'DE',
#   'PZ 46 (Dorsten)-DE',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'DE',
#   'PZ 46 (Dorsten)-DE',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'DE',
#   'PZ 58 (Hagen)-DE',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'DE',
#   'PZ 58 (Hagen)-DE',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'DE',
#   'PZ 08 (Neumark)-DE',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'DE',
#   'PZ 08 (Neumark)-DE',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'DE',
#   'PZ 47 (Krefeld)-DE',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'DE',
#   'PZ 47 (Krefeld)-DE',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'DE',
#   'PZ 15 (Rüdersdorf)-DE',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'DE',
#   'PZ 15 (Rüdersdorf)-DE',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'DK',
#   'Kolding-DK',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'DK',
#   'Kolding-DK',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'ES',
#   'Barcelona-ES',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'ES',
#   'Barcelona-ES',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'ES',
#   'Madrid-ES',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'ES',
#   'Madrid-ES',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'ES',
#   'Araba (Vitoria)-ES',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'ES',
#   'Araba (Vitoria)-ES',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'FR',
#   'Combs la ville-FR',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'FR',
#   'Combs la ville-FR',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'GB',
#   'Slough-GB',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'GB',
#   'Slough-GB',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'GB',
#   'Ryton Gateway-GB',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'GB',
#   'Ryton Gateway-GB',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'GR',
#   'Spata-GR',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'GR',
#   'Spata-GR',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'HR',
#   'Zagreb-HR',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'HR',
#   'Zagreb-HR',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'HU',
#   'Budapest OLK-HU',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'HU',
#   'Budapest OLK-HU',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'HU',
#   'Budapest NPKK (OE)-HU',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'HU',
#   'Budapest NPKK (OE)-HU',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'IE',
#   'Portlaoise-IE',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'IE',
#   'Portlaoise-IE',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'LT',
#   'Kaunas-LT',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'LT',
#   'Kaunas-LT',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'LU',
#   'Bettembourg-LU',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'LU',
#   'Bettembourg-LU',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'NL',
#   'Eindhoven-Noord-NL',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'NL',
#   'Eindhoven-Noord-NL',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'NL',
#   'Utrecht-West + Centrum-NL',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'NL',
#   'Utrecht-West + Centrum-NL',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'NL',
#   'Zaltbommel-NL',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'NL',
#   'Zaltbommel-NL',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'NO',
#   'Oslo-NO',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'NO',
#   'Oslo-NO',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'PL',
#   'Suwałki (Ełk)-PL',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'PL',
#   'Suwałki (Ełk)-PL',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'PL',
#   'Poznań-PL',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'PL',
#   'Poznań-PL',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'PL',
#   'Zabrze-PL',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'PL',
#   'Zabrze-PL',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'PL',
#   'Koninko-PL',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'PL',
#   'Koninko-PL',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'PL',
#   'Wrocław-PL',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'PL',
#   'Wrocław-PL',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'PL',
#   'Bydgoszcz (Solec Kujawski)-PL',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'PL',
#   'Bydgoszcz (Solec Kujawski)-PL',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'PT',
#   'Lisboa-PT',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'PT',
#   'Lisboa-PT',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'RO',
#   'Oradea-RO',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'RO',
#   'Oradea-RO',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SE',
#   'Stockholm - Västberga-SE',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SE',
#   'Stockholm - Västberga-SE',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SE',
#   'Helsingborg-SE',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SE',
#   'Helsingborg-SE',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SE',
#   'Arlöv-SE',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SE',
#   'Arlöv-SE',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SE',
#   'Malmö-SE',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SE',
#   'Malmö-SE',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SI',
#   'Ljubljana-SI',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SI',
#   'Ljubljana-SI',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SK',
#   'Bratislava - Raca-SK',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SK',
#   'Bratislava - Raca-SK',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SK',
#   'Bratislava - Petrzalka-SK',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SK',
#   'Bratislava - Petrzalka-SK',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SK',
#   'Zilina- Strecno-SK',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SK',
#   'Zilina- Strecno-SK',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'AT',
#   'Hub Wien I-AT',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'AT',
#   'Hub Graz-AT',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'BG',
#   'Sofia-BG',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'CZ',
#   'Brno-CZ',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'CZ',
#   'Ostrava-CZ',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'CZ',
#   'Krupka 1-CZ',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'CZ',
#   'Plzen 1-CZ',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'CZ',
#   'Hradec Kralove - Brezhrad-CZ',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'DE',
#   'PZ 67 (Speyer)-DE',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'DE',
#   'PZ 50 (Köln)-DE',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'DE',
#   'PZ 04 (Radefeld/Leipzig)-DE',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'DE',
#   'PZ 90 (Feucht/Nürnberg)-DE',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'DE',
#   'PZ 77 (Lahr)-DE',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'DE',
#   'PZ 93 (Regensburg)-DE',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'DE',
#   'PZ 21 (Hamburg)-DE',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'DE',
#   'PZ 46 (Dorsten)-DE',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'DE',
#   'PZ 58 (Hagen)-DE',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'DE',
#   'PZ 08 (Neumark)-DE',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'DE',
#   'PZ 47 (Krefeld)-DE',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'DE',
#   'PZ 15 (Rüdersdorf)-DE',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'DK',
#   'Kolding-DK',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'ES',
#   'Barcelona-ES',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'ES',
#   'Madrid-ES',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'ES',
#   'Araba (Vitoria)-ES',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'FR',
#   'Combs la ville-FR',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'GB',
#   'Slough-GB',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'GB',
#   'Ryton Gateway-GB',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'GR',
#   'Spata-GR',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'HR',
#   'Zagreb-HR',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'HU',
#   'Budapest OLK-HU',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'HU',
#   'Budapest NPKK (OE)-HU',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'IE',
#   'Portlaoise-IE',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'LT',
#   'Kaunas-LT',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'LU',
#   'Bettembourg-LU',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'NL',
#   'Eindhoven-Noord-NL',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'NL',
#   'Utrecht-West + Centrum-NL',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'NL',
#   'Zaltbommel-NL',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'NO',
#   'Oslo-NO',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'PL',
#   'Suwałki (Ełk)-PL',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'PL',
#   'Poznań-PL',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'PL',
#   'Zabrze-PL',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'PL',
#   'Koninko-PL',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'PL',
#   'Wrocław-PL',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'PL',
#   'Bydgoszcz (Solec Kujawski)-PL',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'PT',
#   'Lisboa-PT',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'RO',
#   'Oradea-RO',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'SE',
#   'Stockholm - Västberga-SE',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'SE',
#   'Helsingborg-SE',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'SE',
#   'Arlöv-SE',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'SE',
#   'Malmö-SE',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'SI',
#   'Ljubljana-SI',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'SK',
#   'Bratislava - Raca-SK',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'SK',
#   'Bratislava - Petrzalka-SK',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'SK',
#   'Zilina- Strecno-SK',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'AT',
#   'Hub Wien I-AT',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'AT',
#   'Hub Graz-AT',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'BE',
#   'Brüssel-BE',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'CZ', 'Brno-CZ', 'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'CZ',
#   'Ostrava-CZ',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'CZ',
#   'Krupka 1-CZ',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'CZ',
#   'Plzen 1-CZ',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'CZ',
#   'Hradec Kralove - Brezhrad-CZ',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'DE',
#   'PZ 67 (Speyer)-DE',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'DE',
#   'PZ 50 (Köln)-DE',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'DE',
#   'PZ 04 (Radefeld/Leipzig)-DE',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'DE',
#   'PZ 90 (Feucht/Nürnberg)-DE',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'DE',
#   'PZ 77 (Lahr)-DE',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'DE',
#   'PZ 93 (Regensburg)-DE',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'DE',
#   'PZ 21 (Hamburg)-DE',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'DE',
#   'PZ 46 (Dorsten)-DE',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'DE',
#   'PZ 58 (Hagen)-DE',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'DE',
#   'PZ 08 (Neumark)-DE',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'DE',
#   'PZ 47 (Krefeld)-DE',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'DE',
#   'PZ 15 (Rüdersdorf)-DE',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'DK',
#   'Kolding-DK',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'ES',
#   'Barcelona-ES',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'ES',
#   'Madrid-ES',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'ES',
#   'Araba (Vitoria)-ES',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'FR',
#   'Combs la ville-FR',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'GB',
#   'Slough-GB',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'GB',
#   'Ryton Gateway-GB',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'GR', 'Spata-GR', 'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'HR',
#   'Zagreb-HR',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'HU',
#   'Budapest OLK-HU',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'HU',
#   'Budapest NPKK (OE)-HU',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'IE',
#   'Portlaoise-IE',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'LT',
#   'Kaunas-LT',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'LU',
#   'Bettembourg-LU',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'NL',
#   'Eindhoven-Noord-NL',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'NL',
#   'Utrecht-West + Centrum-NL',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'NL',
#   'Zaltbommel-NL',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'NO', 'Oslo-NO', 'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'PL',
#   'Suwałki (Ełk)-PL',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'PL',
#   'Poznań-PL',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'PL',
#   'Zabrze-PL',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'PL',
#   'Koninko-PL',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'PL',
#   'Wrocław-PL',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'PL',
#   'Bydgoszcz (Solec Kujawski)-PL',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'PT',
#   'Lisboa-PT',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'RO',
#   'Oradea-RO',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'SE',
#   'Stockholm - Västberga-SE',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'SE',
#   'Helsingborg-SE',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'SE', 'Arlöv-SE', 'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'SE', 'Malmö-SE', 'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'SI',
#   'Ljubljana-SI',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'SK',
#   'Bratislava - Raca-SK',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'SK',
#   'Bratislava - Petrzalka-SK',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'SK',
#   'Zilina- Strecno-SK',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'AT',
#   'Hub Wien I-AT',
#   'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'AT',
#   'Hub Wien I-AT',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'AT',
#   'Hub Wien I-AT',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'AT',
#   'Hub Wien I-AT',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'AT',
#   'Hub Wien I-AT',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'AT',
#   'Hub Graz-AT',
#   'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'AT',
#   'Hub Graz-AT',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'AT',
#   'Hub Graz-AT',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'AT',
#   'Hub Graz-AT',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'AT',
#   'Hub Graz-AT',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'BE',
#   'Brüssel-BE',
#   'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'BE',
#   'Brüssel-BE',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'BE',
#   'Brüssel-BE',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'BE',
#   'Brüssel-BE',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'BE',
#   'Brüssel-BE',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'BG', 'Sofia-BG', 'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'BG',
#   'Sofia-BG',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'BG',
#   'Sofia-BG',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'BG',
#   'Sofia-BG',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'BG',
#   'Sofia-BG',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 67 (Speyer)-DE',
#   'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 67 (Speyer)-DE',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 67 (Speyer)-DE',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 67 (Speyer)-DE',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 67 (Speyer)-DE',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 50 (Köln)-DE',
#   'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 50 (Köln)-DE',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 50 (Köln)-DE',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 50 (Köln)-DE',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 50 (Köln)-DE',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 04 (Radefeld/Leipzig)-DE',
#   'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 04 (Radefeld/Leipzig)-DE',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 04 (Radefeld/Leipzig)-DE',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 04 (Radefeld/Leipzig)-DE',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 04 (Radefeld/Leipzig)-DE',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 90 (Feucht/Nürnberg)-DE',
#   'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 90 (Feucht/Nürnberg)-DE',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 90 (Feucht/Nürnberg)-DE',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 90 (Feucht/Nürnberg)-DE',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 90 (Feucht/Nürnberg)-DE',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 77 (Lahr)-DE',
#   'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 77 (Lahr)-DE',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 77 (Lahr)-DE',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 77 (Lahr)-DE',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 77 (Lahr)-DE',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 93 (Regensburg)-DE',
#   'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 93 (Regensburg)-DE',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 93 (Regensburg)-DE',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 93 (Regensburg)-DE',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 93 (Regensburg)-DE',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 21 (Hamburg)-DE',
#   'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 21 (Hamburg)-DE',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 21 (Hamburg)-DE',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 21 (Hamburg)-DE',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 21 (Hamburg)-DE',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 46 (Dorsten)-DE',
#   'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 46 (Dorsten)-DE',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 46 (Dorsten)-DE',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 46 (Dorsten)-DE',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 46 (Dorsten)-DE',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 58 (Hagen)-DE',
#   'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 58 (Hagen)-DE',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 58 (Hagen)-DE',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 58 (Hagen)-DE',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 58 (Hagen)-DE',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 08 (Neumark)-DE',
#   'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 08 (Neumark)-DE',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 08 (Neumark)-DE',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 08 (Neumark)-DE',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 08 (Neumark)-DE',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 47 (Krefeld)-DE',
#   'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 47 (Krefeld)-DE',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 47 (Krefeld)-DE',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 47 (Krefeld)-DE',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 47 (Krefeld)-DE',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 15 (Rüdersdorf)-DE',
#   'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 15 (Rüdersdorf)-DE',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 15 (Rüdersdorf)-DE',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 15 (Rüdersdorf)-DE',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 15 (Rüdersdorf)-DE',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DK',
#   'Kolding-DK',
#   'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DK',
#   'Kolding-DK',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DK',
#   'Kolding-DK',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DK',
#   'Kolding-DK',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DK',
#   'Kolding-DK',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'ES',
#   'Barcelona-ES',
#   'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'ES',
#   'Barcelona-ES',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'ES',
#   'Barcelona-ES',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'ES',
#   'Barcelona-ES',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'ES',
#   'Barcelona-ES',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'ES', 'Madrid-ES', 'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'ES',
#   'Madrid-ES',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'ES',
#   'Madrid-ES',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'ES',
#   'Madrid-ES',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'ES',
#   'Madrid-ES',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'ES',
#   'Araba (Vitoria)-ES',
#   'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'ES',
#   'Araba (Vitoria)-ES',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'ES',
#   'Araba (Vitoria)-ES',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'ES',
#   'Araba (Vitoria)-ES',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'ES',
#   'Araba (Vitoria)-ES',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'FR',
#   'Combs la ville-FR',
#   'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'FR',
#   'Combs la ville-FR',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'FR',
#   'Combs la ville-FR',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'FR',
#   'Combs la ville-FR',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'FR',
#   'Combs la ville-FR',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'GB', 'Slough-GB', 'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'GB',
#   'Slough-GB',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'GB',
#   'Slough-GB',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'GB',
#   'Slough-GB',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'GB',
#   'Slough-GB',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'GB',
#   'Ryton Gateway-GB',
#   'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'GB',
#   'Ryton Gateway-GB',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'GB',
#   'Ryton Gateway-GB',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'GB',
#   'Ryton Gateway-GB',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'GB',
#   'Ryton Gateway-GB',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'GR', 'Spata-GR', 'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'GR',
#   'Spata-GR',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'GR',
#   'Spata-GR',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'GR',
#   'Spata-GR',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'GR',
#   'Spata-GR',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'HR', 'Zagreb-HR', 'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'HR',
#   'Zagreb-HR',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'HR',
#   'Zagreb-HR',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'HR',
#   'Zagreb-HR',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'HR',
#   'Zagreb-HR',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'HU',
#   'Budapest OLK-HU',
#   'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'HU',
#   'Budapest OLK-HU',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'HU',
#   'Budapest OLK-HU',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'HU',
#   'Budapest OLK-HU',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'HU',
#   'Budapest OLK-HU',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'HU',
#   'Budapest NPKK (OE)-HU',
#   'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'HU',
#   'Budapest NPKK (OE)-HU',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'HU',
#   'Budapest NPKK (OE)-HU',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'HU',
#   'Budapest NPKK (OE)-HU',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'HU',
#   'Budapest NPKK (OE)-HU',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'IE',
#   'Portlaoise-IE',
#   'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'IE',
#   'Portlaoise-IE',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'IE',
#   'Portlaoise-IE',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'IE',
#   'Portlaoise-IE',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'IE',
#   'Portlaoise-IE',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'LT', 'Kaunas-LT', 'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'LT',
#   'Kaunas-LT',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'LT',
#   'Kaunas-LT',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'LT',
#   'Kaunas-LT',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'LT',
#   'Kaunas-LT',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'LU',
#   'Bettembourg-LU',
#   'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'LU',
#   'Bettembourg-LU',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'LU',
#   'Bettembourg-LU',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'LU',
#   'Bettembourg-LU',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'LU',
#   'Bettembourg-LU',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'NL',
#   'Eindhoven-Noord-NL',
#   'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'NL',
#   'Eindhoven-Noord-NL',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'NL',
#   'Eindhoven-Noord-NL',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'NL',
#   'Eindhoven-Noord-NL',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'NL',
#   'Eindhoven-Noord-NL',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'NL',
#   'Utrecht-West + Centrum-NL',
#   'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'NL',
#   'Utrecht-West + Centrum-NL',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'NL',
#   'Utrecht-West + Centrum-NL',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'NL',
#   'Utrecht-West + Centrum-NL',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'NL',
#   'Utrecht-West + Centrum-NL',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'NL',
#   'Zaltbommel-NL',
#   'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'NL',
#   'Zaltbommel-NL',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'NL',
#   'Zaltbommel-NL',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'NL',
#   'Zaltbommel-NL',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'NL',
#   'Zaltbommel-NL',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'NO', 'Oslo-NO', 'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'NO',
#   'Oslo-NO',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'NO',
#   'Oslo-NO',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'NO',
#   'Oslo-NO',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'NO',
#   'Oslo-NO',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PL',
#   'Suwałki (Ełk)-PL',
#   'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PL',
#   'Suwałki (Ełk)-PL',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PL',
#   'Suwałki (Ełk)-PL',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PL',
#   'Suwałki (Ełk)-PL',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PL',
#   'Suwałki (Ełk)-PL',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'PL', 'Poznań-PL', 'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PL',
#   'Poznań-PL',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PL',
#   'Poznań-PL',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PL',
#   'Poznań-PL',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PL',
#   'Poznań-PL',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'PL', 'Zabrze-PL', 'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PL',
#   'Zabrze-PL',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PL',
#   'Zabrze-PL',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PL',
#   'Zabrze-PL',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PL',
#   'Zabrze-PL',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PL',
#   'Koninko-PL',
#   'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PL',
#   'Koninko-PL',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PL',
#   'Koninko-PL',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PL',
#   'Koninko-PL',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PL',
#   'Koninko-PL',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PL',
#   'Wrocław-PL',
#   'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PL',
#   'Wrocław-PL',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PL',
#   'Wrocław-PL',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PL',
#   'Wrocław-PL',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PL',
#   'Wrocław-PL',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PL',
#   'Bydgoszcz (Solec Kujawski)-PL',
#   'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PL',
#   'Bydgoszcz (Solec Kujawski)-PL',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PL',
#   'Bydgoszcz (Solec Kujawski)-PL',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PL',
#   'Bydgoszcz (Solec Kujawski)-PL',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PL',
#   'Bydgoszcz (Solec Kujawski)-PL',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'PT', 'Lisboa-PT', 'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PT',
#   'Lisboa-PT',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PT',
#   'Lisboa-PT',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PT',
#   'Lisboa-PT',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PT',
#   'Lisboa-PT',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'RO', 'Oradea-RO', 'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'RO',
#   'Oradea-RO',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'RO',
#   'Oradea-RO',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'RO',
#   'Oradea-RO',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'RO',
#   'Oradea-RO',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SE',
#   'Stockholm - Västberga-SE',
#   'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SE',
#   'Stockholm - Västberga-SE',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SE',
#   'Stockholm - Västberga-SE',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SE',
#   'Stockholm - Västberga-SE',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SE',
#   'Stockholm - Västberga-SE',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SE',
#   'Helsingborg-SE',
#   'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SE',
#   'Helsingborg-SE',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SE',
#   'Helsingborg-SE',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SE',
#   'Helsingborg-SE',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SE',
#   'Helsingborg-SE',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'SE', 'Arlöv-SE', 'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SE',
#   'Arlöv-SE',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SE',
#   'Arlöv-SE',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SE',
#   'Arlöv-SE',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SE',
#   'Arlöv-SE',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'SE', 'Malmö-SE', 'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SE',
#   'Malmö-SE',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SE',
#   'Malmö-SE',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SE',
#   'Malmö-SE',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SE',
#   'Malmö-SE',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SI',
#   'Ljubljana-SI',
#   'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SI',
#   'Ljubljana-SI',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SI',
#   'Ljubljana-SI',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SI',
#   'Ljubljana-SI',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SI',
#   'Ljubljana-SI',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SK',
#   'Bratislava - Raca-SK',
#   'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SK',
#   'Bratislava - Raca-SK',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SK',
#   'Bratislava - Raca-SK',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SK',
#   'Bratislava - Raca-SK',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SK',
#   'Bratislava - Raca-SK',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SK',
#   'Bratislava - Petrzalka-SK',
#   'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SK',
#   'Bratislava - Petrzalka-SK',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SK',
#   'Bratislava - Petrzalka-SK',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SK',
#   'Bratislava - Petrzalka-SK',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SK',
#   'Bratislava - Petrzalka-SK',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SK',
#   'Zilina- Strecno-SK',
#   'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SK',
#   'Zilina- Strecno-SK',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SK',
#   'Zilina- Strecno-SK',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SK',
#   'Zilina- Strecno-SK',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SK',
#   'Zilina- Strecno-SK',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'AT',
#   'Hub Wien I-AT',
#   'PZ 67 (Speyer)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'AT',
#   'Hub Wien I-AT',
#   'PZ 50 (Köln)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'AT',
#   'Hub Wien I-AT',
#   'PZ 04 (Radefeld/Leipzig)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'AT',
#   'Hub Wien I-AT',
#   'PZ 90 (Feucht/Nürnberg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'AT',
#   'Hub Wien I-AT',
#   'PZ 77 (Lahr)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'AT',
#   'Hub Wien I-AT',
#   'PZ 93 (Regensburg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'AT',
#   'Hub Wien I-AT',
#   'PZ 21 (Hamburg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'AT',
#   'Hub Wien I-AT',
#   'PZ 46 (Dorsten)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'AT',
#   'Hub Wien I-AT',
#   'PZ 58 (Hagen)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'AT',
#   'Hub Wien I-AT',
#   'PZ 08 (Neumark)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'AT',
#   'Hub Wien I-AT',
#   'PZ 47 (Krefeld)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'AT',
#   'Hub Wien I-AT',
#   'PZ 15 (Rüdersdorf)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'AT',
#   'Hub Graz-AT',
#   'PZ 67 (Speyer)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'AT',
#   'Hub Graz-AT',
#   'PZ 50 (Köln)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'AT',
#   'Hub Graz-AT',
#   'PZ 04 (Radefeld/Leipzig)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'AT',
#   'Hub Graz-AT',
#   'PZ 90 (Feucht/Nürnberg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'AT',
#   'Hub Graz-AT',
#   'PZ 77 (Lahr)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'AT',
#   'Hub Graz-AT',
#   'PZ 93 (Regensburg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'AT',
#   'Hub Graz-AT',
#   'PZ 21 (Hamburg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'AT',
#   'Hub Graz-AT',
#   'PZ 46 (Dorsten)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'AT',
#   'Hub Graz-AT',
#   'PZ 58 (Hagen)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'AT',
#   'Hub Graz-AT',
#   'PZ 08 (Neumark)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'AT',
#   'Hub Graz-AT',
#   'PZ 47 (Krefeld)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'AT',
#   'Hub Graz-AT',
#   'PZ 15 (Rüdersdorf)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'BE',
#   'Brüssel-BE',
#   'PZ 67 (Speyer)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'BE',
#   'Brüssel-BE',
#   'PZ 50 (Köln)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'BE',
#   'Brüssel-BE',
#   'PZ 04 (Radefeld/Leipzig)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'BE',
#   'Brüssel-BE',
#   'PZ 90 (Feucht/Nürnberg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'BE',
#   'Brüssel-BE',
#   'PZ 77 (Lahr)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'BE',
#   'Brüssel-BE',
#   'PZ 93 (Regensburg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'BE',
#   'Brüssel-BE',
#   'PZ 21 (Hamburg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'BE',
#   'Brüssel-BE',
# ...
#   'PL',
#   'Wrocław-PL',
#   'PZ 47 (Krefeld)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'PL',
#   'Wrocław-PL',
#   'PZ 15 (Rüdersdorf)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'PL',
#   'Bydgoszcz (Solec Kujawski)-PL',
#   'PZ 67 (Speyer)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'PL',
#   'Bydgoszcz (Solec Kujawski)-PL',
#   'PZ 50 (Köln)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'PL',
#   'Bydgoszcz (Solec Kujawski)-PL',
#   'PZ 04 (Radefeld/Leipzig)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'PL',
#   'Bydgoszcz (Solec Kujawski)-PL',
#   'PZ 90 (Feucht/Nürnberg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'PL',
#   'Bydgoszcz (Solec Kujawski)-PL',
#   'PZ 77 (Lahr)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'PL',
#   'Bydgoszcz (Solec Kujawski)-PL',
#   'PZ 93 (Regensburg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'PL',
#   'Bydgoszcz (Solec Kujawski)-PL',
#   'PZ 21 (Hamburg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'PL',
#   'Bydgoszcz (Solec Kujawski)-PL',
#   'PZ 46 (Dorsten)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'PL',
#   'Bydgoszcz (Solec Kujawski)-PL',
#   'PZ 58 (Hagen)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'PL',
#   'Bydgoszcz (Solec Kujawski)-PL',
#   'PZ 08 (Neumark)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'PL',
#   'Bydgoszcz (Solec Kujawski)-PL',
#   'PZ 47 (Krefeld)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'PL',
#   'Bydgoszcz (Solec Kujawski)-PL',
#   'PZ 15 (Rüdersdorf)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'PT',
#   'Lisboa-PT',
#   'PZ 67 (Speyer)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'PT',
#   'Lisboa-PT',
#   'PZ 50 (Köln)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'PT',
#   'Lisboa-PT',
#   'PZ 04 (Radefeld/Leipzig)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'PT',
#   'Lisboa-PT',
#   'PZ 90 (Feucht/Nürnberg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'PT',
#   'Lisboa-PT',
#   'PZ 77 (Lahr)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'PT',
#   'Lisboa-PT',
#   'PZ 93 (Regensburg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'PT',
#   'Lisboa-PT',
#   'PZ 21 (Hamburg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'PT',
#   'Lisboa-PT',
#   'PZ 46 (Dorsten)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'PT',
#   'Lisboa-PT',
#   'PZ 58 (Hagen)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'PT',
#   'Lisboa-PT',
#   'PZ 08 (Neumark)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'PT',
#   'Lisboa-PT',
#   'PZ 47 (Krefeld)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'PT',
#   'Lisboa-PT',
#   'PZ 15 (Rüdersdorf)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'RO',
#   'Oradea-RO',
#   'PZ 67 (Speyer)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'RO',
#   'Oradea-RO',
#   'PZ 50 (Köln)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'RO',
#   'Oradea-RO',
#   'PZ 04 (Radefeld/Leipzig)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'RO',
#   'Oradea-RO',
#   'PZ 90 (Feucht/Nürnberg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'RO',
#   'Oradea-RO',
#   'PZ 77 (Lahr)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'RO',
#   'Oradea-RO',
#   'PZ 93 (Regensburg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'RO',
#   'Oradea-RO',
#   'PZ 21 (Hamburg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'RO',
#   'Oradea-RO',
#   'PZ 46 (Dorsten)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'RO',
#   'Oradea-RO',
#   'PZ 58 (Hagen)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'RO',
#   'Oradea-RO',
#   'PZ 08 (Neumark)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'RO',
#   'Oradea-RO',
#   'PZ 47 (Krefeld)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'RO',
#   'Oradea-RO',
#   'PZ 15 (Rüdersdorf)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Stockholm - Västberga-SE',
#   'PZ 67 (Speyer)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Stockholm - Västberga-SE',
#   'PZ 50 (Köln)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Stockholm - Västberga-SE',
#   'PZ 04 (Radefeld/Leipzig)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Stockholm - Västberga-SE',
#   'PZ 90 (Feucht/Nürnberg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Stockholm - Västberga-SE',
#   'PZ 77 (Lahr)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Stockholm - Västberga-SE',
#   'PZ 93 (Regensburg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Stockholm - Västberga-SE',
#   'PZ 21 (Hamburg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Stockholm - Västberga-SE',
#   'PZ 46 (Dorsten)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Stockholm - Västberga-SE',
#   'PZ 58 (Hagen)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Stockholm - Västberga-SE',
#   'PZ 08 (Neumark)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Stockholm - Västberga-SE',
#   'PZ 47 (Krefeld)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Stockholm - Västberga-SE',
#   'PZ 15 (Rüdersdorf)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Helsingborg-SE',
#   'PZ 67 (Speyer)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Helsingborg-SE',
#   'PZ 50 (Köln)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Helsingborg-SE',
#   'PZ 04 (Radefeld/Leipzig)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Helsingborg-SE',
#   'PZ 90 (Feucht/Nürnberg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Helsingborg-SE',
#   'PZ 77 (Lahr)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Helsingborg-SE',
#   'PZ 93 (Regensburg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Helsingborg-SE',
#   'PZ 21 (Hamburg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Helsingborg-SE',
#   'PZ 46 (Dorsten)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Helsingborg-SE',
#   'PZ 58 (Hagen)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Helsingborg-SE',
#   'PZ 08 (Neumark)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Helsingborg-SE',
#   'PZ 47 (Krefeld)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Helsingborg-SE',
#   'PZ 15 (Rüdersdorf)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Arlöv-SE',
#   'PZ 67 (Speyer)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Arlöv-SE',
#   'PZ 50 (Köln)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Arlöv-SE',
#   'PZ 04 (Radefeld/Leipzig)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Arlöv-SE',
#   'PZ 90 (Feucht/Nürnberg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Arlöv-SE',
#   'PZ 77 (Lahr)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Arlöv-SE',
#   'PZ 93 (Regensburg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Arlöv-SE',
#   'PZ 21 (Hamburg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Arlöv-SE',
#   'PZ 46 (Dorsten)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Arlöv-SE',
#   'PZ 58 (Hagen)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Arlöv-SE',
#   'PZ 08 (Neumark)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Arlöv-SE',
#   'PZ 47 (Krefeld)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Arlöv-SE',
#   'PZ 15 (Rüdersdorf)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Malmö-SE',
#   'PZ 67 (Speyer)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Malmö-SE',
#   'PZ 50 (Köln)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Malmö-SE',
#   'PZ 04 (Radefeld/Leipzig)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Malmö-SE',
#   'PZ 90 (Feucht/Nürnberg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Malmö-SE',
#   'PZ 77 (Lahr)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Malmö-SE',
#   'PZ 93 (Regensburg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Malmö-SE',
#   'PZ 21 (Hamburg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Malmö-SE',
#   'PZ 46 (Dorsten)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Malmö-SE',
#   'PZ 58 (Hagen)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Malmö-SE',
#   'PZ 08 (Neumark)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Malmö-SE',
#   'PZ 47 (Krefeld)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Malmö-SE',
#   'PZ 15 (Rüdersdorf)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SI',
#   'Ljubljana-SI',
#   'PZ 67 (Speyer)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SI',
#   'Ljubljana-SI',
#   'PZ 50 (Köln)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SI',
#   'Ljubljana-SI',
#   'PZ 04 (Radefeld/Leipzig)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SI',
#   'Ljubljana-SI',
#   'PZ 90 (Feucht/Nürnberg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SI',
#   'Ljubljana-SI',
#   'PZ 77 (Lahr)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SI',
#   'Ljubljana-SI',
#   'PZ 93 (Regensburg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SI',
#   'Ljubljana-SI',
#   'PZ 21 (Hamburg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SI',
#   'Ljubljana-SI',
#   'PZ 46 (Dorsten)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SI',
#   'Ljubljana-SI',
#   'PZ 58 (Hagen)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SI',
#   'Ljubljana-SI',
#   'PZ 08 (Neumark)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SI',
#   'Ljubljana-SI',
#   'PZ 47 (Krefeld)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SI',
#   'Ljubljana-SI',
#   'PZ 15 (Rüdersdorf)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'Bratislava - Raca-SK',
#   'PZ 67 (Speyer)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'Bratislava - Raca-SK',
#   'PZ 50 (Köln)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'Bratislava - Raca-SK',
#   'PZ 04 (Radefeld/Leipzig)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'Bratislava - Raca-SK',
#   'PZ 90 (Feucht/Nürnberg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'Bratislava - Raca-SK',
#   'PZ 77 (Lahr)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'Bratislava - Raca-SK',
#   'PZ 93 (Regensburg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'Bratislava - Raca-SK',
#   'PZ 21 (Hamburg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'Bratislava - Raca-SK',
#   'PZ 46 (Dorsten)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'Bratislava - Raca-SK',
#   'PZ 58 (Hagen)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'Bratislava - Raca-SK',
#   'PZ 08 (Neumark)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'Bratislava - Raca-SK',
#   'PZ 47 (Krefeld)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'Bratislava - Raca-SK',
#   'PZ 15 (Rüdersdorf)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'Bratislava - Petrzalka-SK',
#   'PZ 67 (Speyer)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'Bratislava - Petrzalka-SK',
#   'PZ 50 (Köln)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'Bratislava - Petrzalka-SK',
#   'PZ 04 (Radefeld/Leipzig)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'Bratislava - Petrzalka-SK',
#   'PZ 90 (Feucht/Nürnberg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'Bratislava - Petrzalka-SK',
#   'PZ 77 (Lahr)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'Bratislava - Petrzalka-SK',
#   'PZ 93 (Regensburg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'Bratislava - Petrzalka-SK',
#   'PZ 21 (Hamburg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'Bratislava - Petrzalka-SK',
#   'PZ 46 (Dorsten)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'Bratislava - Petrzalka-SK',
#   'PZ 58 (Hagen)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'Bratislava - Petrzalka-SK',
#   'PZ 08 (Neumark)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'Bratislava - Petrzalka-SK',
#   'PZ 47 (Krefeld)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'Bratislava - Petrzalka-SK',
#   'PZ 15 (Rüdersdorf)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'Zilina- Strecno-SK',
#   'PZ 67 (Speyer)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'Zilina- Strecno-SK',
#   'PZ 50 (Köln)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'Zilina- Strecno-SK',
#   'PZ 04 (Radefeld/Leipzig)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'Zilina- Strecno-SK',
#   'PZ 90 (Feucht/Nürnberg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'Zilina- Strecno-SK',
#   'PZ 77 (Lahr)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'Zilina- Strecno-SK',
#   'PZ 93 (Regensburg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'Zilina- Strecno-SK',
#   'PZ 21 (Hamburg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'Zilina- Strecno-SK',
#   'PZ 46 (Dorsten)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'Zilina- Strecno-SK',
#   'PZ 58 (Hagen)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'Zilina- Strecno-SK',
#   'PZ 08 (Neumark)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'Zilina- Strecno-SK',
#   'PZ 47 (Krefeld)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'Zilina- Strecno-SK',
#   'PZ 15 (Rüdersdorf)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK',
#   'AT',
#   'Hub Wien I-AT',
#   'Kolding-DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK',
#   'AT',
#   'Hub Graz-AT',
#   'Kolding-DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK',
#   'BE',
#   'Brüssel-BE',
#   'Kolding-DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK',
#   'BG',
#   'Sofia-BG',
#   'Kolding-DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK',
#   'CZ',
#   'Brno-CZ',
#   'Kolding-DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK',
#   'CZ',
#   'Ostrava-CZ',
#   'Kolding-DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK',
#   'CZ',
#   'Krupka 1-CZ',
#   'Kolding-DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK',
#   'CZ',
#   'Plzen 1-CZ',
#   'Kolding-DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK',
#   'CZ',
#   'Hradec Kralove - Brezhrad-CZ',
#   'Kolding-DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK',
#   'DE',
#   'PZ 67 (Speyer)-DE',
#   'Kolding-DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK',
#   'DE',
#   'PZ 50 (Köln)-DE',
#   'Kolding-DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK',
#   'DE',
#   'PZ 04 (Radefeld/Leipzig)-DE',
#   'Kolding-DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK',
#   'DE',
#   'PZ 90 (Feucht/Nürnberg)-DE',
#   'Kolding-DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK',
#   'DE',
#   'PZ 77 (Lahr)-DE',
#   'Kolding-DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK',
#   'DE',
#   'PZ 93 (Regensburg)-DE',
#   'Kolding-DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK',
#   'DE',
#   'PZ 21 (Hamburg)-DE',
#   'Kolding-DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK',
#   'DE',
#   'PZ 46 (Dorsten)-DE',
#   'Kolding-DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK',
#   'DE',
#   'PZ 58 (Hagen)-DE',
#   'Kolding-DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK',
#   'DE',
#   'PZ 08 (Neumark)-DE',
#   'Kolding-DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK',
#   'DE',
#   'PZ 47 (Krefeld)-DE',
#   'Kolding-DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ...}

# %% [markdown]
# ## Hub Cut Off Time and Hub Open Time

# %%
BigM = 9999
model.addConstrs((S[p,q] + TT[p,q] - N[p,q] * 24  <=  
                 CO[q] - 
                 BigM *(
                     1 - (x[p, q] + 
                          quicksum(x_[p, q, i] for j in E for i in L[j] if (j != k) & (j != m)) + 
                          quicksum(x_[i, p, q] for j in E for i in L[j] if (j != k) & (j != m)))
                 ) for m,k in mk for q in L[k] for p in L[m]), "Hub Cut Off Time")
# Out:
# {('AT',
#   'BE',
#   'Brüssel-BE',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'BE',
#   'Brüssel-BE',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'BG',
#   'Sofia-BG',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'BG',
#   'Sofia-BG',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'CZ',
#   'Brno-CZ',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'CZ',
#   'Brno-CZ',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'CZ',
#   'Ostrava-CZ',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'CZ',
#   'Ostrava-CZ',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'CZ',
#   'Krupka 1-CZ',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'CZ',
#   'Krupka 1-CZ',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'CZ',
#   'Plzen 1-CZ',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'CZ',
#   'Plzen 1-CZ',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'CZ',
#   'Hradec Kralove - Brezhrad-CZ',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'CZ',
#   'Hradec Kralove - Brezhrad-CZ',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'DE',
#   'PZ 67 (Speyer)-DE',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'DE',
#   'PZ 67 (Speyer)-DE',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'DE',
#   'PZ 50 (Köln)-DE',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'DE',
#   'PZ 50 (Köln)-DE',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'DE',
#   'PZ 04 (Radefeld/Leipzig)-DE',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'DE',
#   'PZ 04 (Radefeld/Leipzig)-DE',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'DE',
#   'PZ 90 (Feucht/Nürnberg)-DE',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'DE',
#   'PZ 90 (Feucht/Nürnberg)-DE',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'DE',
#   'PZ 77 (Lahr)-DE',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'DE',
#   'PZ 77 (Lahr)-DE',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'DE',
#   'PZ 93 (Regensburg)-DE',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'DE',
#   'PZ 93 (Regensburg)-DE',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'DE',
#   'PZ 21 (Hamburg)-DE',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'DE',
#   'PZ 21 (Hamburg)-DE',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'DE',
#   'PZ 46 (Dorsten)-DE',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'DE',
#   'PZ 46 (Dorsten)-DE',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'DE',
#   'PZ 58 (Hagen)-DE',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'DE',
#   'PZ 58 (Hagen)-DE',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'DE',
#   'PZ 08 (Neumark)-DE',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'DE',
#   'PZ 08 (Neumark)-DE',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'DE',
#   'PZ 47 (Krefeld)-DE',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'DE',
#   'PZ 47 (Krefeld)-DE',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'DE',
#   'PZ 15 (Rüdersdorf)-DE',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'DE',
#   'PZ 15 (Rüdersdorf)-DE',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'DK',
#   'Kolding-DK',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'DK',
#   'Kolding-DK',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'ES',
#   'Barcelona-ES',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'ES',
#   'Barcelona-ES',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'ES',
#   'Madrid-ES',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'ES',
#   'Madrid-ES',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'ES',
#   'Araba (Vitoria)-ES',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'ES',
#   'Araba (Vitoria)-ES',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'FR',
#   'Combs la ville-FR',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'FR',
#   'Combs la ville-FR',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'GB',
#   'Slough-GB',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'GB',
#   'Slough-GB',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'GB',
#   'Ryton Gateway-GB',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'GB',
#   'Ryton Gateway-GB',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'GR',
#   'Spata-GR',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'GR',
#   'Spata-GR',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'HR',
#   'Zagreb-HR',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'HR',
#   'Zagreb-HR',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'HU',
#   'Budapest OLK-HU',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'HU',
#   'Budapest OLK-HU',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'HU',
#   'Budapest NPKK (OE)-HU',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'HU',
#   'Budapest NPKK (OE)-HU',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'IE',
#   'Portlaoise-IE',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'IE',
#   'Portlaoise-IE',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'LT',
#   'Kaunas-LT',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'LT',
#   'Kaunas-LT',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'LU',
#   'Bettembourg-LU',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'LU',
#   'Bettembourg-LU',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'NL',
#   'Eindhoven-Noord-NL',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'NL',
#   'Eindhoven-Noord-NL',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'NL',
#   'Utrecht-West + Centrum-NL',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'NL',
#   'Utrecht-West + Centrum-NL',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'NL',
#   'Zaltbommel-NL',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'NL',
#   'Zaltbommel-NL',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'NO',
#   'Oslo-NO',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'NO',
#   'Oslo-NO',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'PL',
#   'Suwałki (Ełk)-PL',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'PL',
#   'Suwałki (Ełk)-PL',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'PL',
#   'Poznań-PL',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'PL',
#   'Poznań-PL',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'PL',
#   'Zabrze-PL',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'PL',
#   'Zabrze-PL',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'PL',
#   'Koninko-PL',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'PL',
#   'Koninko-PL',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'PL',
#   'Wrocław-PL',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'PL',
#   'Wrocław-PL',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'PL',
#   'Bydgoszcz (Solec Kujawski)-PL',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'PL',
#   'Bydgoszcz (Solec Kujawski)-PL',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'PT',
#   'Lisboa-PT',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'PT',
#   'Lisboa-PT',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'RO',
#   'Oradea-RO',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'RO',
#   'Oradea-RO',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SE',
#   'Stockholm - Västberga-SE',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SE',
#   'Stockholm - Västberga-SE',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SE',
#   'Helsingborg-SE',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SE',
#   'Helsingborg-SE',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SE',
#   'Arlöv-SE',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SE',
#   'Arlöv-SE',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SE',
#   'Malmö-SE',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SE',
#   'Malmö-SE',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SI',
#   'Ljubljana-SI',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SI',
#   'Ljubljana-SI',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SK',
#   'Bratislava - Raca-SK',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SK',
#   'Bratislava - Raca-SK',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SK',
#   'Bratislava - Petrzalka-SK',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SK',
#   'Bratislava - Petrzalka-SK',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SK',
#   'Zilina- Strecno-SK',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SK',
#   'Zilina- Strecno-SK',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'AT',
#   'Hub Wien I-AT',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'AT',
#   'Hub Graz-AT',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'BG',
#   'Sofia-BG',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'CZ',
#   'Brno-CZ',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'CZ',
#   'Ostrava-CZ',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'CZ',
#   'Krupka 1-CZ',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'CZ',
#   'Plzen 1-CZ',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'CZ',
#   'Hradec Kralove - Brezhrad-CZ',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'DE',
#   'PZ 67 (Speyer)-DE',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'DE',
#   'PZ 50 (Köln)-DE',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'DE',
#   'PZ 04 (Radefeld/Leipzig)-DE',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'DE',
#   'PZ 90 (Feucht/Nürnberg)-DE',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'DE',
#   'PZ 77 (Lahr)-DE',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'DE',
#   'PZ 93 (Regensburg)-DE',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'DE',
#   'PZ 21 (Hamburg)-DE',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'DE',
#   'PZ 46 (Dorsten)-DE',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'DE',
#   'PZ 58 (Hagen)-DE',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'DE',
#   'PZ 08 (Neumark)-DE',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'DE',
#   'PZ 47 (Krefeld)-DE',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'DE',
#   'PZ 15 (Rüdersdorf)-DE',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'DK',
#   'Kolding-DK',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'ES',
#   'Barcelona-ES',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'ES',
#   'Madrid-ES',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'ES',
#   'Araba (Vitoria)-ES',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'FR',
#   'Combs la ville-FR',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'GB',
#   'Slough-GB',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'GB',
#   'Ryton Gateway-GB',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'GR',
#   'Spata-GR',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'HR',
#   'Zagreb-HR',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'HU',
#   'Budapest OLK-HU',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'HU',
#   'Budapest NPKK (OE)-HU',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'IE',
#   'Portlaoise-IE',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'LT',
#   'Kaunas-LT',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'LU',
#   'Bettembourg-LU',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'NL',
#   'Eindhoven-Noord-NL',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'NL',
#   'Utrecht-West + Centrum-NL',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'NL',
#   'Zaltbommel-NL',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'NO',
#   'Oslo-NO',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'PL',
#   'Suwałki (Ełk)-PL',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'PL',
#   'Poznań-PL',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'PL',
#   'Zabrze-PL',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'PL',
#   'Koninko-PL',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'PL',
#   'Wrocław-PL',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'PL',
#   'Bydgoszcz (Solec Kujawski)-PL',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'PT',
#   'Lisboa-PT',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'RO',
#   'Oradea-RO',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'SE',
#   'Stockholm - Västberga-SE',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'SE',
#   'Helsingborg-SE',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'SE',
#   'Arlöv-SE',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'SE',
#   'Malmö-SE',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'SI',
#   'Ljubljana-SI',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'SK',
#   'Bratislava - Raca-SK',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'SK',
#   'Bratislava - Petrzalka-SK',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'SK',
#   'Zilina- Strecno-SK',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'AT',
#   'Hub Wien I-AT',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'AT',
#   'Hub Graz-AT',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'BE',
#   'Brüssel-BE',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'CZ', 'Brno-CZ', 'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'CZ',
#   'Ostrava-CZ',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'CZ',
#   'Krupka 1-CZ',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'CZ',
#   'Plzen 1-CZ',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'CZ',
#   'Hradec Kralove - Brezhrad-CZ',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'DE',
#   'PZ 67 (Speyer)-DE',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'DE',
#   'PZ 50 (Köln)-DE',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'DE',
#   'PZ 04 (Radefeld/Leipzig)-DE',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'DE',
#   'PZ 90 (Feucht/Nürnberg)-DE',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'DE',
#   'PZ 77 (Lahr)-DE',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'DE',
#   'PZ 93 (Regensburg)-DE',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'DE',
#   'PZ 21 (Hamburg)-DE',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'DE',
#   'PZ 46 (Dorsten)-DE',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'DE',
#   'PZ 58 (Hagen)-DE',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'DE',
#   'PZ 08 (Neumark)-DE',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'DE',
#   'PZ 47 (Krefeld)-DE',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'DE',
#   'PZ 15 (Rüdersdorf)-DE',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'DK',
#   'Kolding-DK',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'ES',
#   'Barcelona-ES',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'ES',
#   'Madrid-ES',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'ES',
#   'Araba (Vitoria)-ES',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'FR',
#   'Combs la ville-FR',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'GB',
#   'Slough-GB',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'GB',
#   'Ryton Gateway-GB',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'GR', 'Spata-GR', 'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'HR',
#   'Zagreb-HR',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'HU',
#   'Budapest OLK-HU',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'HU',
#   'Budapest NPKK (OE)-HU',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'IE',
#   'Portlaoise-IE',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'LT',
#   'Kaunas-LT',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'LU',
#   'Bettembourg-LU',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'NL',
#   'Eindhoven-Noord-NL',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'NL',
#   'Utrecht-West + Centrum-NL',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'NL',
#   'Zaltbommel-NL',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'NO', 'Oslo-NO', 'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'PL',
#   'Suwałki (Ełk)-PL',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'PL',
#   'Poznań-PL',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'PL',
#   'Zabrze-PL',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'PL',
#   'Koninko-PL',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'PL',
#   'Wrocław-PL',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'PL',
#   'Bydgoszcz (Solec Kujawski)-PL',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'PT',
#   'Lisboa-PT',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'RO',
#   'Oradea-RO',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'SE',
#   'Stockholm - Västberga-SE',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'SE',
#   'Helsingborg-SE',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'SE', 'Arlöv-SE', 'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'SE', 'Malmö-SE', 'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'SI',
#   'Ljubljana-SI',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'SK',
#   'Bratislava - Raca-SK',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'SK',
#   'Bratislava - Petrzalka-SK',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'SK',
#   'Zilina- Strecno-SK',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'AT',
#   'Hub Wien I-AT',
#   'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'AT',
#   'Hub Wien I-AT',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'AT',
#   'Hub Wien I-AT',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'AT',
#   'Hub Wien I-AT',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'AT',
#   'Hub Wien I-AT',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'AT',
#   'Hub Graz-AT',
#   'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'AT',
#   'Hub Graz-AT',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'AT',
#   'Hub Graz-AT',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'AT',
#   'Hub Graz-AT',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'AT',
#   'Hub Graz-AT',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'BE',
#   'Brüssel-BE',
#   'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'BE',
#   'Brüssel-BE',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'BE',
#   'Brüssel-BE',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'BE',
#   'Brüssel-BE',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'BE',
#   'Brüssel-BE',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'BG', 'Sofia-BG', 'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'BG',
#   'Sofia-BG',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'BG',
#   'Sofia-BG',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'BG',
#   'Sofia-BG',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'BG',
#   'Sofia-BG',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 67 (Speyer)-DE',
#   'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 67 (Speyer)-DE',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 67 (Speyer)-DE',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 67 (Speyer)-DE',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 67 (Speyer)-DE',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 50 (Köln)-DE',
#   'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 50 (Köln)-DE',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 50 (Köln)-DE',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 50 (Köln)-DE',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 50 (Köln)-DE',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 04 (Radefeld/Leipzig)-DE',
#   'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 04 (Radefeld/Leipzig)-DE',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 04 (Radefeld/Leipzig)-DE',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 04 (Radefeld/Leipzig)-DE',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 04 (Radefeld/Leipzig)-DE',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 90 (Feucht/Nürnberg)-DE',
#   'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 90 (Feucht/Nürnberg)-DE',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 90 (Feucht/Nürnberg)-DE',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 90 (Feucht/Nürnberg)-DE',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 90 (Feucht/Nürnberg)-DE',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 77 (Lahr)-DE',
#   'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 77 (Lahr)-DE',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 77 (Lahr)-DE',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 77 (Lahr)-DE',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 77 (Lahr)-DE',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 93 (Regensburg)-DE',
#   'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 93 (Regensburg)-DE',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 93 (Regensburg)-DE',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 93 (Regensburg)-DE',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 93 (Regensburg)-DE',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 21 (Hamburg)-DE',
#   'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 21 (Hamburg)-DE',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 21 (Hamburg)-DE',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 21 (Hamburg)-DE',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 21 (Hamburg)-DE',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 46 (Dorsten)-DE',
#   'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 46 (Dorsten)-DE',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 46 (Dorsten)-DE',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 46 (Dorsten)-DE',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 46 (Dorsten)-DE',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 58 (Hagen)-DE',
#   'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 58 (Hagen)-DE',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 58 (Hagen)-DE',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 58 (Hagen)-DE',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 58 (Hagen)-DE',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 08 (Neumark)-DE',
#   'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 08 (Neumark)-DE',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 08 (Neumark)-DE',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 08 (Neumark)-DE',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 08 (Neumark)-DE',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 47 (Krefeld)-DE',
#   'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 47 (Krefeld)-DE',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 47 (Krefeld)-DE',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 47 (Krefeld)-DE',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 47 (Krefeld)-DE',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 15 (Rüdersdorf)-DE',
#   'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 15 (Rüdersdorf)-DE',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 15 (Rüdersdorf)-DE',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 15 (Rüdersdorf)-DE',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 15 (Rüdersdorf)-DE',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DK',
#   'Kolding-DK',
#   'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DK',
#   'Kolding-DK',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DK',
#   'Kolding-DK',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DK',
#   'Kolding-DK',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DK',
#   'Kolding-DK',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'ES',
#   'Barcelona-ES',
#   'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'ES',
#   'Barcelona-ES',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'ES',
#   'Barcelona-ES',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'ES',
#   'Barcelona-ES',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'ES',
#   'Barcelona-ES',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'ES', 'Madrid-ES', 'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'ES',
#   'Madrid-ES',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'ES',
#   'Madrid-ES',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'ES',
#   'Madrid-ES',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'ES',
#   'Madrid-ES',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'ES',
#   'Araba (Vitoria)-ES',
#   'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'ES',
#   'Araba (Vitoria)-ES',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'ES',
#   'Araba (Vitoria)-ES',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'ES',
#   'Araba (Vitoria)-ES',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'ES',
#   'Araba (Vitoria)-ES',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'FR',
#   'Combs la ville-FR',
#   'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'FR',
#   'Combs la ville-FR',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'FR',
#   'Combs la ville-FR',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'FR',
#   'Combs la ville-FR',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'FR',
#   'Combs la ville-FR',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'GB', 'Slough-GB', 'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'GB',
#   'Slough-GB',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'GB',
#   'Slough-GB',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'GB',
#   'Slough-GB',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'GB',
#   'Slough-GB',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'GB',
#   'Ryton Gateway-GB',
#   'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'GB',
#   'Ryton Gateway-GB',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'GB',
#   'Ryton Gateway-GB',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'GB',
#   'Ryton Gateway-GB',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'GB',
#   'Ryton Gateway-GB',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'GR', 'Spata-GR', 'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'GR',
#   'Spata-GR',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'GR',
#   'Spata-GR',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'GR',
#   'Spata-GR',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'GR',
#   'Spata-GR',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'HR', 'Zagreb-HR', 'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'HR',
#   'Zagreb-HR',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'HR',
#   'Zagreb-HR',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'HR',
#   'Zagreb-HR',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'HR',
#   'Zagreb-HR',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'HU',
#   'Budapest OLK-HU',
#   'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'HU',
#   'Budapest OLK-HU',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'HU',
#   'Budapest OLK-HU',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'HU',
#   'Budapest OLK-HU',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'HU',
#   'Budapest OLK-HU',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'HU',
#   'Budapest NPKK (OE)-HU',
#   'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'HU',
#   'Budapest NPKK (OE)-HU',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'HU',
#   'Budapest NPKK (OE)-HU',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'HU',
#   'Budapest NPKK (OE)-HU',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'HU',
#   'Budapest NPKK (OE)-HU',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'IE',
#   'Portlaoise-IE',
#   'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'IE',
#   'Portlaoise-IE',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'IE',
#   'Portlaoise-IE',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'IE',
#   'Portlaoise-IE',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'IE',
#   'Portlaoise-IE',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'LT', 'Kaunas-LT', 'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'LT',
#   'Kaunas-LT',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'LT',
#   'Kaunas-LT',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'LT',
#   'Kaunas-LT',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'LT',
#   'Kaunas-LT',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'LU',
#   'Bettembourg-LU',
#   'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'LU',
#   'Bettembourg-LU',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'LU',
#   'Bettembourg-LU',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'LU',
#   'Bettembourg-LU',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'LU',
#   'Bettembourg-LU',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'NL',
#   'Eindhoven-Noord-NL',
#   'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'NL',
#   'Eindhoven-Noord-NL',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'NL',
#   'Eindhoven-Noord-NL',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'NL',
#   'Eindhoven-Noord-NL',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'NL',
#   'Eindhoven-Noord-NL',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'NL',
#   'Utrecht-West + Centrum-NL',
#   'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'NL',
#   'Utrecht-West + Centrum-NL',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'NL',
#   'Utrecht-West + Centrum-NL',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'NL',
#   'Utrecht-West + Centrum-NL',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'NL',
#   'Utrecht-West + Centrum-NL',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'NL',
#   'Zaltbommel-NL',
#   'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'NL',
#   'Zaltbommel-NL',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'NL',
#   'Zaltbommel-NL',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'NL',
#   'Zaltbommel-NL',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'NL',
#   'Zaltbommel-NL',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'NO', 'Oslo-NO', 'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'NO',
#   'Oslo-NO',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'NO',
#   'Oslo-NO',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'NO',
#   'Oslo-NO',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'NO',
#   'Oslo-NO',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PL',
#   'Suwałki (Ełk)-PL',
#   'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PL',
#   'Suwałki (Ełk)-PL',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PL',
#   'Suwałki (Ełk)-PL',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PL',
#   'Suwałki (Ełk)-PL',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PL',
#   'Suwałki (Ełk)-PL',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'PL', 'Poznań-PL', 'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PL',
#   'Poznań-PL',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PL',
#   'Poznań-PL',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PL',
#   'Poznań-PL',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PL',
#   'Poznań-PL',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'PL', 'Zabrze-PL', 'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PL',
#   'Zabrze-PL',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PL',
#   'Zabrze-PL',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PL',
#   'Zabrze-PL',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PL',
#   'Zabrze-PL',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PL',
#   'Koninko-PL',
#   'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PL',
#   'Koninko-PL',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PL',
#   'Koninko-PL',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PL',
#   'Koninko-PL',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PL',
#   'Koninko-PL',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PL',
#   'Wrocław-PL',
#   'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PL',
#   'Wrocław-PL',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PL',
#   'Wrocław-PL',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PL',
#   'Wrocław-PL',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PL',
#   'Wrocław-PL',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PL',
#   'Bydgoszcz (Solec Kujawski)-PL',
#   'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PL',
#   'Bydgoszcz (Solec Kujawski)-PL',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PL',
#   'Bydgoszcz (Solec Kujawski)-PL',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PL',
#   'Bydgoszcz (Solec Kujawski)-PL',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PL',
#   'Bydgoszcz (Solec Kujawski)-PL',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'PT', 'Lisboa-PT', 'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PT',
#   'Lisboa-PT',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PT',
#   'Lisboa-PT',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PT',
#   'Lisboa-PT',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PT',
#   'Lisboa-PT',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'RO', 'Oradea-RO', 'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'RO',
#   'Oradea-RO',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'RO',
#   'Oradea-RO',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'RO',
#   'Oradea-RO',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'RO',
#   'Oradea-RO',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SE',
#   'Stockholm - Västberga-SE',
#   'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SE',
#   'Stockholm - Västberga-SE',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SE',
#   'Stockholm - Västberga-SE',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SE',
#   'Stockholm - Västberga-SE',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SE',
#   'Stockholm - Västberga-SE',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SE',
#   'Helsingborg-SE',
#   'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SE',
#   'Helsingborg-SE',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SE',
#   'Helsingborg-SE',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SE',
#   'Helsingborg-SE',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SE',
#   'Helsingborg-SE',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'SE', 'Arlöv-SE', 'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SE',
#   'Arlöv-SE',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SE',
#   'Arlöv-SE',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SE',
#   'Arlöv-SE',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SE',
#   'Arlöv-SE',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'SE', 'Malmö-SE', 'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SE',
#   'Malmö-SE',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SE',
#   'Malmö-SE',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SE',
#   'Malmö-SE',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SE',
#   'Malmö-SE',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SI',
#   'Ljubljana-SI',
#   'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SI',
#   'Ljubljana-SI',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SI',
#   'Ljubljana-SI',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SI',
#   'Ljubljana-SI',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SI',
#   'Ljubljana-SI',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SK',
#   'Bratislava - Raca-SK',
#   'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SK',
#   'Bratislava - Raca-SK',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SK',
#   'Bratislava - Raca-SK',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SK',
#   'Bratislava - Raca-SK',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SK',
#   'Bratislava - Raca-SK',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SK',
#   'Bratislava - Petrzalka-SK',
#   'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SK',
#   'Bratislava - Petrzalka-SK',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SK',
#   'Bratislava - Petrzalka-SK',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SK',
#   'Bratislava - Petrzalka-SK',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SK',
#   'Bratislava - Petrzalka-SK',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SK',
#   'Zilina- Strecno-SK',
#   'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SK',
#   'Zilina- Strecno-SK',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SK',
#   'Zilina- Strecno-SK',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SK',
#   'Zilina- Strecno-SK',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SK',
#   'Zilina- Strecno-SK',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'AT',
#   'Hub Wien I-AT',
#   'PZ 67 (Speyer)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'AT',
#   'Hub Wien I-AT',
#   'PZ 50 (Köln)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'AT',
#   'Hub Wien I-AT',
#   'PZ 04 (Radefeld/Leipzig)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'AT',
#   'Hub Wien I-AT',
#   'PZ 90 (Feucht/Nürnberg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'AT',
#   'Hub Wien I-AT',
#   'PZ 77 (Lahr)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'AT',
#   'Hub Wien I-AT',
#   'PZ 93 (Regensburg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'AT',
#   'Hub Wien I-AT',
#   'PZ 21 (Hamburg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'AT',
#   'Hub Wien I-AT',
#   'PZ 46 (Dorsten)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'AT',
#   'Hub Wien I-AT',
#   'PZ 58 (Hagen)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'AT',
#   'Hub Wien I-AT',
#   'PZ 08 (Neumark)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'AT',
#   'Hub Wien I-AT',
#   'PZ 47 (Krefeld)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'AT',
#   'Hub Wien I-AT',
#   'PZ 15 (Rüdersdorf)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'AT',
#   'Hub Graz-AT',
#   'PZ 67 (Speyer)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'AT',
#   'Hub Graz-AT',
#   'PZ 50 (Köln)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'AT',
#   'Hub Graz-AT',
#   'PZ 04 (Radefeld/Leipzig)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'AT',
#   'Hub Graz-AT',
#   'PZ 90 (Feucht/Nürnberg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'AT',
#   'Hub Graz-AT',
#   'PZ 77 (Lahr)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'AT',
#   'Hub Graz-AT',
#   'PZ 93 (Regensburg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'AT',
#   'Hub Graz-AT',
#   'PZ 21 (Hamburg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'AT',
#   'Hub Graz-AT',
#   'PZ 46 (Dorsten)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'AT',
#   'Hub Graz-AT',
#   'PZ 58 (Hagen)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'AT',
#   'Hub Graz-AT',
#   'PZ 08 (Neumark)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'AT',
#   'Hub Graz-AT',
#   'PZ 47 (Krefeld)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'AT',
#   'Hub Graz-AT',
#   'PZ 15 (Rüdersdorf)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'BE',
#   'Brüssel-BE',
#   'PZ 67 (Speyer)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'BE',
#   'Brüssel-BE',
#   'PZ 50 (Köln)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'BE',
#   'Brüssel-BE',
#   'PZ 04 (Radefeld/Leipzig)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'BE',
#   'Brüssel-BE',
#   'PZ 90 (Feucht/Nürnberg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'BE',
#   'Brüssel-BE',
#   'PZ 77 (Lahr)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'BE',
#   'Brüssel-BE',
#   'PZ 93 (Regensburg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'BE',
#   'Brüssel-BE',
#   'PZ 21 (Hamburg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'BE',
#   'Brüssel-BE',
# ...
#   'PL',
#   'Wrocław-PL',
#   'PZ 47 (Krefeld)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'PL',
#   'Wrocław-PL',
#   'PZ 15 (Rüdersdorf)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'PL',
#   'Bydgoszcz (Solec Kujawski)-PL',
#   'PZ 67 (Speyer)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'PL',
#   'Bydgoszcz (Solec Kujawski)-PL',
#   'PZ 50 (Köln)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'PL',
#   'Bydgoszcz (Solec Kujawski)-PL',
#   'PZ 04 (Radefeld/Leipzig)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'PL',
#   'Bydgoszcz (Solec Kujawski)-PL',
#   'PZ 90 (Feucht/Nürnberg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'PL',
#   'Bydgoszcz (Solec Kujawski)-PL',
#   'PZ 77 (Lahr)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'PL',
#   'Bydgoszcz (Solec Kujawski)-PL',
#   'PZ 93 (Regensburg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'PL',
#   'Bydgoszcz (Solec Kujawski)-PL',
#   'PZ 21 (Hamburg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'PL',
#   'Bydgoszcz (Solec Kujawski)-PL',
#   'PZ 46 (Dorsten)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'PL',
#   'Bydgoszcz (Solec Kujawski)-PL',
#   'PZ 58 (Hagen)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'PL',
#   'Bydgoszcz (Solec Kujawski)-PL',
#   'PZ 08 (Neumark)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'PL',
#   'Bydgoszcz (Solec Kujawski)-PL',
#   'PZ 47 (Krefeld)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'PL',
#   'Bydgoszcz (Solec Kujawski)-PL',
#   'PZ 15 (Rüdersdorf)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'PT',
#   'Lisboa-PT',
#   'PZ 67 (Speyer)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'PT',
#   'Lisboa-PT',
#   'PZ 50 (Köln)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'PT',
#   'Lisboa-PT',
#   'PZ 04 (Radefeld/Leipzig)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'PT',
#   'Lisboa-PT',
#   'PZ 90 (Feucht/Nürnberg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'PT',
#   'Lisboa-PT',
#   'PZ 77 (Lahr)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'PT',
#   'Lisboa-PT',
#   'PZ 93 (Regensburg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'PT',
#   'Lisboa-PT',
#   'PZ 21 (Hamburg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'PT',
#   'Lisboa-PT',
#   'PZ 46 (Dorsten)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'PT',
#   'Lisboa-PT',
#   'PZ 58 (Hagen)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'PT',
#   'Lisboa-PT',
#   'PZ 08 (Neumark)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'PT',
#   'Lisboa-PT',
#   'PZ 47 (Krefeld)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'PT',
#   'Lisboa-PT',
#   'PZ 15 (Rüdersdorf)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'RO',
#   'Oradea-RO',
#   'PZ 67 (Speyer)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'RO',
#   'Oradea-RO',
#   'PZ 50 (Köln)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'RO',
#   'Oradea-RO',
#   'PZ 04 (Radefeld/Leipzig)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'RO',
#   'Oradea-RO',
#   'PZ 90 (Feucht/Nürnberg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'RO',
#   'Oradea-RO',
#   'PZ 77 (Lahr)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'RO',
#   'Oradea-RO',
#   'PZ 93 (Regensburg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'RO',
#   'Oradea-RO',
#   'PZ 21 (Hamburg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'RO',
#   'Oradea-RO',
#   'PZ 46 (Dorsten)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'RO',
#   'Oradea-RO',
#   'PZ 58 (Hagen)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'RO',
#   'Oradea-RO',
#   'PZ 08 (Neumark)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'RO',
#   'Oradea-RO',
#   'PZ 47 (Krefeld)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'RO',
#   'Oradea-RO',
#   'PZ 15 (Rüdersdorf)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Stockholm - Västberga-SE',
#   'PZ 67 (Speyer)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Stockholm - Västberga-SE',
#   'PZ 50 (Köln)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Stockholm - Västberga-SE',
#   'PZ 04 (Radefeld/Leipzig)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Stockholm - Västberga-SE',
#   'PZ 90 (Feucht/Nürnberg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Stockholm - Västberga-SE',
#   'PZ 77 (Lahr)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Stockholm - Västberga-SE',
#   'PZ 93 (Regensburg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Stockholm - Västberga-SE',
#   'PZ 21 (Hamburg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Stockholm - Västberga-SE',
#   'PZ 46 (Dorsten)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Stockholm - Västberga-SE',
#   'PZ 58 (Hagen)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Stockholm - Västberga-SE',
#   'PZ 08 (Neumark)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Stockholm - Västberga-SE',
#   'PZ 47 (Krefeld)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Stockholm - Västberga-SE',
#   'PZ 15 (Rüdersdorf)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Helsingborg-SE',
#   'PZ 67 (Speyer)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Helsingborg-SE',
#   'PZ 50 (Köln)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Helsingborg-SE',
#   'PZ 04 (Radefeld/Leipzig)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Helsingborg-SE',
#   'PZ 90 (Feucht/Nürnberg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Helsingborg-SE',
#   'PZ 77 (Lahr)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Helsingborg-SE',
#   'PZ 93 (Regensburg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Helsingborg-SE',
#   'PZ 21 (Hamburg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Helsingborg-SE',
#   'PZ 46 (Dorsten)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Helsingborg-SE',
#   'PZ 58 (Hagen)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Helsingborg-SE',
#   'PZ 08 (Neumark)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Helsingborg-SE',
#   'PZ 47 (Krefeld)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Helsingborg-SE',
#   'PZ 15 (Rüdersdorf)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Arlöv-SE',
#   'PZ 67 (Speyer)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Arlöv-SE',
#   'PZ 50 (Köln)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Arlöv-SE',
#   'PZ 04 (Radefeld/Leipzig)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Arlöv-SE',
#   'PZ 90 (Feucht/Nürnberg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Arlöv-SE',
#   'PZ 77 (Lahr)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Arlöv-SE',
#   'PZ 93 (Regensburg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Arlöv-SE',
#   'PZ 21 (Hamburg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Arlöv-SE',
#   'PZ 46 (Dorsten)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Arlöv-SE',
#   'PZ 58 (Hagen)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Arlöv-SE',
#   'PZ 08 (Neumark)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Arlöv-SE',
#   'PZ 47 (Krefeld)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Arlöv-SE',
#   'PZ 15 (Rüdersdorf)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Malmö-SE',
#   'PZ 67 (Speyer)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Malmö-SE',
#   'PZ 50 (Köln)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Malmö-SE',
#   'PZ 04 (Radefeld/Leipzig)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Malmö-SE',
#   'PZ 90 (Feucht/Nürnberg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Malmö-SE',
#   'PZ 77 (Lahr)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Malmö-SE',
#   'PZ 93 (Regensburg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Malmö-SE',
#   'PZ 21 (Hamburg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Malmö-SE',
#   'PZ 46 (Dorsten)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Malmö-SE',
#   'PZ 58 (Hagen)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Malmö-SE',
#   'PZ 08 (Neumark)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Malmö-SE',
#   'PZ 47 (Krefeld)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Malmö-SE',
#   'PZ 15 (Rüdersdorf)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SI',
#   'Ljubljana-SI',
#   'PZ 67 (Speyer)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SI',
#   'Ljubljana-SI',
#   'PZ 50 (Köln)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SI',
#   'Ljubljana-SI',
#   'PZ 04 (Radefeld/Leipzig)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SI',
#   'Ljubljana-SI',
#   'PZ 90 (Feucht/Nürnberg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SI',
#   'Ljubljana-SI',
#   'PZ 77 (Lahr)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SI',
#   'Ljubljana-SI',
#   'PZ 93 (Regensburg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SI',
#   'Ljubljana-SI',
#   'PZ 21 (Hamburg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SI',
#   'Ljubljana-SI',
#   'PZ 46 (Dorsten)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SI',
#   'Ljubljana-SI',
#   'PZ 58 (Hagen)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SI',
#   'Ljubljana-SI',
#   'PZ 08 (Neumark)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SI',
#   'Ljubljana-SI',
#   'PZ 47 (Krefeld)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SI',
#   'Ljubljana-SI',
#   'PZ 15 (Rüdersdorf)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'Bratislava - Raca-SK',
#   'PZ 67 (Speyer)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'Bratislava - Raca-SK',
#   'PZ 50 (Köln)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'Bratislava - Raca-SK',
#   'PZ 04 (Radefeld/Leipzig)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'Bratislava - Raca-SK',
#   'PZ 90 (Feucht/Nürnberg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'Bratislava - Raca-SK',
#   'PZ 77 (Lahr)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'Bratislava - Raca-SK',
#   'PZ 93 (Regensburg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'Bratislava - Raca-SK',
#   'PZ 21 (Hamburg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'Bratislava - Raca-SK',
#   'PZ 46 (Dorsten)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'Bratislava - Raca-SK',
#   'PZ 58 (Hagen)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'Bratislava - Raca-SK',
#   'PZ 08 (Neumark)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'Bratislava - Raca-SK',
#   'PZ 47 (Krefeld)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'Bratislava - Raca-SK',
#   'PZ 15 (Rüdersdorf)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'Bratislava - Petrzalka-SK',
#   'PZ 67 (Speyer)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'Bratislava - Petrzalka-SK',
#   'PZ 50 (Köln)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'Bratislava - Petrzalka-SK',
#   'PZ 04 (Radefeld/Leipzig)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'Bratislava - Petrzalka-SK',
#   'PZ 90 (Feucht/Nürnberg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'Bratislava - Petrzalka-SK',
#   'PZ 77 (Lahr)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'Bratislava - Petrzalka-SK',
#   'PZ 93 (Regensburg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'Bratislava - Petrzalka-SK',
#   'PZ 21 (Hamburg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'Bratislava - Petrzalka-SK',
#   'PZ 46 (Dorsten)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'Bratislava - Petrzalka-SK',
#   'PZ 58 (Hagen)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'Bratislava - Petrzalka-SK',
#   'PZ 08 (Neumark)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'Bratislava - Petrzalka-SK',
#   'PZ 47 (Krefeld)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'Bratislava - Petrzalka-SK',
#   'PZ 15 (Rüdersdorf)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'Zilina- Strecno-SK',
#   'PZ 67 (Speyer)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'Zilina- Strecno-SK',
#   'PZ 50 (Köln)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'Zilina- Strecno-SK',
#   'PZ 04 (Radefeld/Leipzig)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'Zilina- Strecno-SK',
#   'PZ 90 (Feucht/Nürnberg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'Zilina- Strecno-SK',
#   'PZ 77 (Lahr)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'Zilina- Strecno-SK',
#   'PZ 93 (Regensburg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'Zilina- Strecno-SK',
#   'PZ 21 (Hamburg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'Zilina- Strecno-SK',
#   'PZ 46 (Dorsten)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'Zilina- Strecno-SK',
#   'PZ 58 (Hagen)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'Zilina- Strecno-SK',
#   'PZ 08 (Neumark)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'Zilina- Strecno-SK',
#   'PZ 47 (Krefeld)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'Zilina- Strecno-SK',
#   'PZ 15 (Rüdersdorf)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK',
#   'AT',
#   'Hub Wien I-AT',
#   'Kolding-DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK',
#   'AT',
#   'Hub Graz-AT',
#   'Kolding-DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK',
#   'BE',
#   'Brüssel-BE',
#   'Kolding-DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK',
#   'BG',
#   'Sofia-BG',
#   'Kolding-DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK',
#   'CZ',
#   'Brno-CZ',
#   'Kolding-DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK',
#   'CZ',
#   'Ostrava-CZ',
#   'Kolding-DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK',
#   'CZ',
#   'Krupka 1-CZ',
#   'Kolding-DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK',
#   'CZ',
#   'Plzen 1-CZ',
#   'Kolding-DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK',
#   'CZ',
#   'Hradec Kralove - Brezhrad-CZ',
#   'Kolding-DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK',
#   'DE',
#   'PZ 67 (Speyer)-DE',
#   'Kolding-DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK',
#   'DE',
#   'PZ 50 (Köln)-DE',
#   'Kolding-DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK',
#   'DE',
#   'PZ 04 (Radefeld/Leipzig)-DE',
#   'Kolding-DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK',
#   'DE',
#   'PZ 90 (Feucht/Nürnberg)-DE',
#   'Kolding-DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK',
#   'DE',
#   'PZ 77 (Lahr)-DE',
#   'Kolding-DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK',
#   'DE',
#   'PZ 93 (Regensburg)-DE',
#   'Kolding-DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK',
#   'DE',
#   'PZ 21 (Hamburg)-DE',
#   'Kolding-DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK',
#   'DE',
#   'PZ 46 (Dorsten)-DE',
#   'Kolding-DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK',
#   'DE',
#   'PZ 58 (Hagen)-DE',
#   'Kolding-DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK',
#   'DE',
#   'PZ 08 (Neumark)-DE',
#   'Kolding-DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK',
#   'DE',
#   'PZ 47 (Krefeld)-DE',
#   'Kolding-DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ...}

# %%
BigMM = 12000

model.addConstrs((S[p,q] + TT[p,q] - N[p,q] * 24  >=  
                 O[q] - 
                 BigMM *(
                     1 - (x[p, q] + 
                          quicksum(x_[p, q, i] for j in E for i in L[j] if (j != k) & (j != m)) + 
                          quicksum(x_[i, p, q] for j in E for i in L[j] if (j != k) & (j != m)))
                 ) for m,k in mk for q in L[k] for p in L[m]), "Hub Open Time")
# Out:
# {('AT',
#   'BE',
#   'Brüssel-BE',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'BE',
#   'Brüssel-BE',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'BG',
#   'Sofia-BG',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'BG',
#   'Sofia-BG',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'CZ',
#   'Brno-CZ',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'CZ',
#   'Brno-CZ',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'CZ',
#   'Ostrava-CZ',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'CZ',
#   'Ostrava-CZ',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'CZ',
#   'Krupka 1-CZ',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'CZ',
#   'Krupka 1-CZ',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'CZ',
#   'Plzen 1-CZ',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'CZ',
#   'Plzen 1-CZ',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'CZ',
#   'Hradec Kralove - Brezhrad-CZ',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'CZ',
#   'Hradec Kralove - Brezhrad-CZ',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'DE',
#   'PZ 67 (Speyer)-DE',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'DE',
#   'PZ 67 (Speyer)-DE',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'DE',
#   'PZ 50 (Köln)-DE',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'DE',
#   'PZ 50 (Köln)-DE',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'DE',
#   'PZ 04 (Radefeld/Leipzig)-DE',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'DE',
#   'PZ 04 (Radefeld/Leipzig)-DE',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'DE',
#   'PZ 90 (Feucht/Nürnberg)-DE',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'DE',
#   'PZ 90 (Feucht/Nürnberg)-DE',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'DE',
#   'PZ 77 (Lahr)-DE',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'DE',
#   'PZ 77 (Lahr)-DE',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'DE',
#   'PZ 93 (Regensburg)-DE',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'DE',
#   'PZ 93 (Regensburg)-DE',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'DE',
#   'PZ 21 (Hamburg)-DE',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'DE',
#   'PZ 21 (Hamburg)-DE',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'DE',
#   'PZ 46 (Dorsten)-DE',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'DE',
#   'PZ 46 (Dorsten)-DE',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'DE',
#   'PZ 58 (Hagen)-DE',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'DE',
#   'PZ 58 (Hagen)-DE',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'DE',
#   'PZ 08 (Neumark)-DE',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'DE',
#   'PZ 08 (Neumark)-DE',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'DE',
#   'PZ 47 (Krefeld)-DE',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'DE',
#   'PZ 47 (Krefeld)-DE',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'DE',
#   'PZ 15 (Rüdersdorf)-DE',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'DE',
#   'PZ 15 (Rüdersdorf)-DE',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'DK',
#   'Kolding-DK',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'DK',
#   'Kolding-DK',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'ES',
#   'Barcelona-ES',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'ES',
#   'Barcelona-ES',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'ES',
#   'Madrid-ES',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'ES',
#   'Madrid-ES',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'ES',
#   'Araba (Vitoria)-ES',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'ES',
#   'Araba (Vitoria)-ES',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'FR',
#   'Combs la ville-FR',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'FR',
#   'Combs la ville-FR',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'GB',
#   'Slough-GB',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'GB',
#   'Slough-GB',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'GB',
#   'Ryton Gateway-GB',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'GB',
#   'Ryton Gateway-GB',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'GR',
#   'Spata-GR',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'GR',
#   'Spata-GR',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'HR',
#   'Zagreb-HR',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'HR',
#   'Zagreb-HR',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'HU',
#   'Budapest OLK-HU',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'HU',
#   'Budapest OLK-HU',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'HU',
#   'Budapest NPKK (OE)-HU',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'HU',
#   'Budapest NPKK (OE)-HU',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'IE',
#   'Portlaoise-IE',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'IE',
#   'Portlaoise-IE',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'LT',
#   'Kaunas-LT',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'LT',
#   'Kaunas-LT',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'LU',
#   'Bettembourg-LU',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'LU',
#   'Bettembourg-LU',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'NL',
#   'Eindhoven-Noord-NL',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'NL',
#   'Eindhoven-Noord-NL',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'NL',
#   'Utrecht-West + Centrum-NL',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'NL',
#   'Utrecht-West + Centrum-NL',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'NL',
#   'Zaltbommel-NL',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'NL',
#   'Zaltbommel-NL',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'NO',
#   'Oslo-NO',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'NO',
#   'Oslo-NO',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'PL',
#   'Suwałki (Ełk)-PL',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'PL',
#   'Suwałki (Ełk)-PL',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'PL',
#   'Poznań-PL',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'PL',
#   'Poznań-PL',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'PL',
#   'Zabrze-PL',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'PL',
#   'Zabrze-PL',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'PL',
#   'Koninko-PL',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'PL',
#   'Koninko-PL',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'PL',
#   'Wrocław-PL',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'PL',
#   'Wrocław-PL',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'PL',
#   'Bydgoszcz (Solec Kujawski)-PL',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'PL',
#   'Bydgoszcz (Solec Kujawski)-PL',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'PT',
#   'Lisboa-PT',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'PT',
#   'Lisboa-PT',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'RO',
#   'Oradea-RO',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'RO',
#   'Oradea-RO',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SE',
#   'Stockholm - Västberga-SE',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SE',
#   'Stockholm - Västberga-SE',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SE',
#   'Helsingborg-SE',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SE',
#   'Helsingborg-SE',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SE',
#   'Arlöv-SE',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SE',
#   'Arlöv-SE',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SE',
#   'Malmö-SE',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SE',
#   'Malmö-SE',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SI',
#   'Ljubljana-SI',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SI',
#   'Ljubljana-SI',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SK',
#   'Bratislava - Raca-SK',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SK',
#   'Bratislava - Raca-SK',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SK',
#   'Bratislava - Petrzalka-SK',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SK',
#   'Bratislava - Petrzalka-SK',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SK',
#   'Zilina- Strecno-SK',
#   'Hub Wien I-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SK',
#   'Zilina- Strecno-SK',
#   'Hub Graz-AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'AT',
#   'Hub Wien I-AT',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'AT',
#   'Hub Graz-AT',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'BG',
#   'Sofia-BG',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'CZ',
#   'Brno-CZ',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'CZ',
#   'Ostrava-CZ',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'CZ',
#   'Krupka 1-CZ',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'CZ',
#   'Plzen 1-CZ',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'CZ',
#   'Hradec Kralove - Brezhrad-CZ',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'DE',
#   'PZ 67 (Speyer)-DE',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'DE',
#   'PZ 50 (Köln)-DE',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'DE',
#   'PZ 04 (Radefeld/Leipzig)-DE',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'DE',
#   'PZ 90 (Feucht/Nürnberg)-DE',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'DE',
#   'PZ 77 (Lahr)-DE',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'DE',
#   'PZ 93 (Regensburg)-DE',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'DE',
#   'PZ 21 (Hamburg)-DE',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'DE',
#   'PZ 46 (Dorsten)-DE',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'DE',
#   'PZ 58 (Hagen)-DE',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'DE',
#   'PZ 08 (Neumark)-DE',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'DE',
#   'PZ 47 (Krefeld)-DE',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'DE',
#   'PZ 15 (Rüdersdorf)-DE',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'DK',
#   'Kolding-DK',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'ES',
#   'Barcelona-ES',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'ES',
#   'Madrid-ES',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'ES',
#   'Araba (Vitoria)-ES',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'FR',
#   'Combs la ville-FR',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'GB',
#   'Slough-GB',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'GB',
#   'Ryton Gateway-GB',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'GR',
#   'Spata-GR',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'HR',
#   'Zagreb-HR',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'HU',
#   'Budapest OLK-HU',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'HU',
#   'Budapest NPKK (OE)-HU',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'IE',
#   'Portlaoise-IE',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'LT',
#   'Kaunas-LT',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'LU',
#   'Bettembourg-LU',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'NL',
#   'Eindhoven-Noord-NL',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'NL',
#   'Utrecht-West + Centrum-NL',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'NL',
#   'Zaltbommel-NL',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'NO',
#   'Oslo-NO',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'PL',
#   'Suwałki (Ełk)-PL',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'PL',
#   'Poznań-PL',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'PL',
#   'Zabrze-PL',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'PL',
#   'Koninko-PL',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'PL',
#   'Wrocław-PL',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'PL',
#   'Bydgoszcz (Solec Kujawski)-PL',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'PT',
#   'Lisboa-PT',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'RO',
#   'Oradea-RO',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'SE',
#   'Stockholm - Västberga-SE',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'SE',
#   'Helsingborg-SE',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'SE',
#   'Arlöv-SE',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'SE',
#   'Malmö-SE',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'SI',
#   'Ljubljana-SI',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'SK',
#   'Bratislava - Raca-SK',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'SK',
#   'Bratislava - Petrzalka-SK',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'SK',
#   'Zilina- Strecno-SK',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'AT',
#   'Hub Wien I-AT',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'AT',
#   'Hub Graz-AT',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'BE',
#   'Brüssel-BE',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'CZ', 'Brno-CZ', 'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'CZ',
#   'Ostrava-CZ',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'CZ',
#   'Krupka 1-CZ',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'CZ',
#   'Plzen 1-CZ',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'CZ',
#   'Hradec Kralove - Brezhrad-CZ',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'DE',
#   'PZ 67 (Speyer)-DE',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'DE',
#   'PZ 50 (Köln)-DE',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'DE',
#   'PZ 04 (Radefeld/Leipzig)-DE',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'DE',
#   'PZ 90 (Feucht/Nürnberg)-DE',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'DE',
#   'PZ 77 (Lahr)-DE',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'DE',
#   'PZ 93 (Regensburg)-DE',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'DE',
#   'PZ 21 (Hamburg)-DE',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'DE',
#   'PZ 46 (Dorsten)-DE',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'DE',
#   'PZ 58 (Hagen)-DE',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'DE',
#   'PZ 08 (Neumark)-DE',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'DE',
#   'PZ 47 (Krefeld)-DE',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'DE',
#   'PZ 15 (Rüdersdorf)-DE',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'DK',
#   'Kolding-DK',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'ES',
#   'Barcelona-ES',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'ES',
#   'Madrid-ES',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'ES',
#   'Araba (Vitoria)-ES',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'FR',
#   'Combs la ville-FR',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'GB',
#   'Slough-GB',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'GB',
#   'Ryton Gateway-GB',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'GR', 'Spata-GR', 'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'HR',
#   'Zagreb-HR',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'HU',
#   'Budapest OLK-HU',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'HU',
#   'Budapest NPKK (OE)-HU',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'IE',
#   'Portlaoise-IE',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'LT',
#   'Kaunas-LT',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'LU',
#   'Bettembourg-LU',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'NL',
#   'Eindhoven-Noord-NL',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'NL',
#   'Utrecht-West + Centrum-NL',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'NL',
#   'Zaltbommel-NL',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'NO', 'Oslo-NO', 'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'PL',
#   'Suwałki (Ełk)-PL',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'PL',
#   'Poznań-PL',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'PL',
#   'Zabrze-PL',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'PL',
#   'Koninko-PL',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'PL',
#   'Wrocław-PL',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'PL',
#   'Bydgoszcz (Solec Kujawski)-PL',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'PT',
#   'Lisboa-PT',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'RO',
#   'Oradea-RO',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'SE',
#   'Stockholm - Västberga-SE',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'SE',
#   'Helsingborg-SE',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'SE', 'Arlöv-SE', 'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'SE', 'Malmö-SE', 'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'SI',
#   'Ljubljana-SI',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'SK',
#   'Bratislava - Raca-SK',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'SK',
#   'Bratislava - Petrzalka-SK',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'SK',
#   'Zilina- Strecno-SK',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'AT',
#   'Hub Wien I-AT',
#   'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'AT',
#   'Hub Wien I-AT',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'AT',
#   'Hub Wien I-AT',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'AT',
#   'Hub Wien I-AT',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'AT',
#   'Hub Wien I-AT',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'AT',
#   'Hub Graz-AT',
#   'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'AT',
#   'Hub Graz-AT',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'AT',
#   'Hub Graz-AT',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'AT',
#   'Hub Graz-AT',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'AT',
#   'Hub Graz-AT',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'BE',
#   'Brüssel-BE',
#   'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'BE',
#   'Brüssel-BE',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'BE',
#   'Brüssel-BE',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'BE',
#   'Brüssel-BE',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'BE',
#   'Brüssel-BE',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'BG', 'Sofia-BG', 'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'BG',
#   'Sofia-BG',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'BG',
#   'Sofia-BG',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'BG',
#   'Sofia-BG',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'BG',
#   'Sofia-BG',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 67 (Speyer)-DE',
#   'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 67 (Speyer)-DE',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 67 (Speyer)-DE',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 67 (Speyer)-DE',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 67 (Speyer)-DE',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 50 (Köln)-DE',
#   'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 50 (Köln)-DE',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 50 (Köln)-DE',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 50 (Köln)-DE',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 50 (Köln)-DE',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 04 (Radefeld/Leipzig)-DE',
#   'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 04 (Radefeld/Leipzig)-DE',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 04 (Radefeld/Leipzig)-DE',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 04 (Radefeld/Leipzig)-DE',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 04 (Radefeld/Leipzig)-DE',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 90 (Feucht/Nürnberg)-DE',
#   'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 90 (Feucht/Nürnberg)-DE',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 90 (Feucht/Nürnberg)-DE',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 90 (Feucht/Nürnberg)-DE',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 90 (Feucht/Nürnberg)-DE',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 77 (Lahr)-DE',
#   'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 77 (Lahr)-DE',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 77 (Lahr)-DE',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 77 (Lahr)-DE',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 77 (Lahr)-DE',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 93 (Regensburg)-DE',
#   'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 93 (Regensburg)-DE',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 93 (Regensburg)-DE',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 93 (Regensburg)-DE',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 93 (Regensburg)-DE',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 21 (Hamburg)-DE',
#   'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 21 (Hamburg)-DE',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 21 (Hamburg)-DE',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 21 (Hamburg)-DE',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 21 (Hamburg)-DE',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 46 (Dorsten)-DE',
#   'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 46 (Dorsten)-DE',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 46 (Dorsten)-DE',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 46 (Dorsten)-DE',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 46 (Dorsten)-DE',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 58 (Hagen)-DE',
#   'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 58 (Hagen)-DE',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 58 (Hagen)-DE',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 58 (Hagen)-DE',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 58 (Hagen)-DE',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 08 (Neumark)-DE',
#   'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 08 (Neumark)-DE',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 08 (Neumark)-DE',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 08 (Neumark)-DE',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 08 (Neumark)-DE',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 47 (Krefeld)-DE',
#   'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 47 (Krefeld)-DE',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 47 (Krefeld)-DE',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 47 (Krefeld)-DE',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 47 (Krefeld)-DE',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 15 (Rüdersdorf)-DE',
#   'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 15 (Rüdersdorf)-DE',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 15 (Rüdersdorf)-DE',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 15 (Rüdersdorf)-DE',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DE',
#   'PZ 15 (Rüdersdorf)-DE',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DK',
#   'Kolding-DK',
#   'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DK',
#   'Kolding-DK',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DK',
#   'Kolding-DK',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DK',
#   'Kolding-DK',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DK',
#   'Kolding-DK',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'ES',
#   'Barcelona-ES',
#   'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'ES',
#   'Barcelona-ES',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'ES',
#   'Barcelona-ES',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'ES',
#   'Barcelona-ES',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'ES',
#   'Barcelona-ES',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'ES', 'Madrid-ES', 'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'ES',
#   'Madrid-ES',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'ES',
#   'Madrid-ES',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'ES',
#   'Madrid-ES',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'ES',
#   'Madrid-ES',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'ES',
#   'Araba (Vitoria)-ES',
#   'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'ES',
#   'Araba (Vitoria)-ES',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'ES',
#   'Araba (Vitoria)-ES',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'ES',
#   'Araba (Vitoria)-ES',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'ES',
#   'Araba (Vitoria)-ES',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'FR',
#   'Combs la ville-FR',
#   'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'FR',
#   'Combs la ville-FR',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'FR',
#   'Combs la ville-FR',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'FR',
#   'Combs la ville-FR',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'FR',
#   'Combs la ville-FR',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'GB', 'Slough-GB', 'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'GB',
#   'Slough-GB',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'GB',
#   'Slough-GB',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'GB',
#   'Slough-GB',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'GB',
#   'Slough-GB',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'GB',
#   'Ryton Gateway-GB',
#   'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'GB',
#   'Ryton Gateway-GB',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'GB',
#   'Ryton Gateway-GB',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'GB',
#   'Ryton Gateway-GB',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'GB',
#   'Ryton Gateway-GB',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'GR', 'Spata-GR', 'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'GR',
#   'Spata-GR',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'GR',
#   'Spata-GR',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'GR',
#   'Spata-GR',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'GR',
#   'Spata-GR',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'HR', 'Zagreb-HR', 'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'HR',
#   'Zagreb-HR',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'HR',
#   'Zagreb-HR',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'HR',
#   'Zagreb-HR',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'HR',
#   'Zagreb-HR',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'HU',
#   'Budapest OLK-HU',
#   'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'HU',
#   'Budapest OLK-HU',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'HU',
#   'Budapest OLK-HU',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'HU',
#   'Budapest OLK-HU',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'HU',
#   'Budapest OLK-HU',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'HU',
#   'Budapest NPKK (OE)-HU',
#   'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'HU',
#   'Budapest NPKK (OE)-HU',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'HU',
#   'Budapest NPKK (OE)-HU',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'HU',
#   'Budapest NPKK (OE)-HU',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'HU',
#   'Budapest NPKK (OE)-HU',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'IE',
#   'Portlaoise-IE',
#   'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'IE',
#   'Portlaoise-IE',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'IE',
#   'Portlaoise-IE',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'IE',
#   'Portlaoise-IE',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'IE',
#   'Portlaoise-IE',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'LT', 'Kaunas-LT', 'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'LT',
#   'Kaunas-LT',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'LT',
#   'Kaunas-LT',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'LT',
#   'Kaunas-LT',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'LT',
#   'Kaunas-LT',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'LU',
#   'Bettembourg-LU',
#   'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'LU',
#   'Bettembourg-LU',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'LU',
#   'Bettembourg-LU',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'LU',
#   'Bettembourg-LU',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'LU',
#   'Bettembourg-LU',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'NL',
#   'Eindhoven-Noord-NL',
#   'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'NL',
#   'Eindhoven-Noord-NL',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'NL',
#   'Eindhoven-Noord-NL',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'NL',
#   'Eindhoven-Noord-NL',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'NL',
#   'Eindhoven-Noord-NL',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'NL',
#   'Utrecht-West + Centrum-NL',
#   'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'NL',
#   'Utrecht-West + Centrum-NL',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'NL',
#   'Utrecht-West + Centrum-NL',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'NL',
#   'Utrecht-West + Centrum-NL',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'NL',
#   'Utrecht-West + Centrum-NL',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'NL',
#   'Zaltbommel-NL',
#   'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'NL',
#   'Zaltbommel-NL',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'NL',
#   'Zaltbommel-NL',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'NL',
#   'Zaltbommel-NL',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'NL',
#   'Zaltbommel-NL',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'NO', 'Oslo-NO', 'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'NO',
#   'Oslo-NO',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'NO',
#   'Oslo-NO',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'NO',
#   'Oslo-NO',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'NO',
#   'Oslo-NO',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PL',
#   'Suwałki (Ełk)-PL',
#   'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PL',
#   'Suwałki (Ełk)-PL',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PL',
#   'Suwałki (Ełk)-PL',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PL',
#   'Suwałki (Ełk)-PL',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PL',
#   'Suwałki (Ełk)-PL',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'PL', 'Poznań-PL', 'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PL',
#   'Poznań-PL',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PL',
#   'Poznań-PL',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PL',
#   'Poznań-PL',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PL',
#   'Poznań-PL',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'PL', 'Zabrze-PL', 'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PL',
#   'Zabrze-PL',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PL',
#   'Zabrze-PL',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PL',
#   'Zabrze-PL',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PL',
#   'Zabrze-PL',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PL',
#   'Koninko-PL',
#   'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PL',
#   'Koninko-PL',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PL',
#   'Koninko-PL',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PL',
#   'Koninko-PL',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PL',
#   'Koninko-PL',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PL',
#   'Wrocław-PL',
#   'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PL',
#   'Wrocław-PL',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PL',
#   'Wrocław-PL',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PL',
#   'Wrocław-PL',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PL',
#   'Wrocław-PL',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PL',
#   'Bydgoszcz (Solec Kujawski)-PL',
#   'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PL',
#   'Bydgoszcz (Solec Kujawski)-PL',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PL',
#   'Bydgoszcz (Solec Kujawski)-PL',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PL',
#   'Bydgoszcz (Solec Kujawski)-PL',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PL',
#   'Bydgoszcz (Solec Kujawski)-PL',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'PT', 'Lisboa-PT', 'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PT',
#   'Lisboa-PT',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PT',
#   'Lisboa-PT',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PT',
#   'Lisboa-PT',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'PT',
#   'Lisboa-PT',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'RO', 'Oradea-RO', 'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'RO',
#   'Oradea-RO',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'RO',
#   'Oradea-RO',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'RO',
#   'Oradea-RO',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'RO',
#   'Oradea-RO',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SE',
#   'Stockholm - Västberga-SE',
#   'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SE',
#   'Stockholm - Västberga-SE',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SE',
#   'Stockholm - Västberga-SE',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SE',
#   'Stockholm - Västberga-SE',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SE',
#   'Stockholm - Västberga-SE',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SE',
#   'Helsingborg-SE',
#   'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SE',
#   'Helsingborg-SE',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SE',
#   'Helsingborg-SE',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SE',
#   'Helsingborg-SE',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SE',
#   'Helsingborg-SE',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'SE', 'Arlöv-SE', 'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SE',
#   'Arlöv-SE',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SE',
#   'Arlöv-SE',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SE',
#   'Arlöv-SE',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SE',
#   'Arlöv-SE',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'SE', 'Malmö-SE', 'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SE',
#   'Malmö-SE',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SE',
#   'Malmö-SE',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SE',
#   'Malmö-SE',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SE',
#   'Malmö-SE',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SI',
#   'Ljubljana-SI',
#   'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SI',
#   'Ljubljana-SI',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SI',
#   'Ljubljana-SI',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SI',
#   'Ljubljana-SI',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SI',
#   'Ljubljana-SI',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SK',
#   'Bratislava - Raca-SK',
#   'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SK',
#   'Bratislava - Raca-SK',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SK',
#   'Bratislava - Raca-SK',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SK',
#   'Bratislava - Raca-SK',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SK',
#   'Bratislava - Raca-SK',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SK',
#   'Bratislava - Petrzalka-SK',
#   'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SK',
#   'Bratislava - Petrzalka-SK',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SK',
#   'Bratislava - Petrzalka-SK',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SK',
#   'Bratislava - Petrzalka-SK',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SK',
#   'Bratislava - Petrzalka-SK',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SK',
#   'Zilina- Strecno-SK',
#   'Brno-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SK',
#   'Zilina- Strecno-SK',
#   'Ostrava-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SK',
#   'Zilina- Strecno-SK',
#   'Krupka 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SK',
#   'Zilina- Strecno-SK',
#   'Plzen 1-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SK',
#   'Zilina- Strecno-SK',
#   'Hradec Kralove - Brezhrad-CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'AT',
#   'Hub Wien I-AT',
#   'PZ 67 (Speyer)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'AT',
#   'Hub Wien I-AT',
#   'PZ 50 (Köln)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'AT',
#   'Hub Wien I-AT',
#   'PZ 04 (Radefeld/Leipzig)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'AT',
#   'Hub Wien I-AT',
#   'PZ 90 (Feucht/Nürnberg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'AT',
#   'Hub Wien I-AT',
#   'PZ 77 (Lahr)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'AT',
#   'Hub Wien I-AT',
#   'PZ 93 (Regensburg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'AT',
#   'Hub Wien I-AT',
#   'PZ 21 (Hamburg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'AT',
#   'Hub Wien I-AT',
#   'PZ 46 (Dorsten)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'AT',
#   'Hub Wien I-AT',
#   'PZ 58 (Hagen)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'AT',
#   'Hub Wien I-AT',
#   'PZ 08 (Neumark)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'AT',
#   'Hub Wien I-AT',
#   'PZ 47 (Krefeld)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'AT',
#   'Hub Wien I-AT',
#   'PZ 15 (Rüdersdorf)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'AT',
#   'Hub Graz-AT',
#   'PZ 67 (Speyer)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'AT',
#   'Hub Graz-AT',
#   'PZ 50 (Köln)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'AT',
#   'Hub Graz-AT',
#   'PZ 04 (Radefeld/Leipzig)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'AT',
#   'Hub Graz-AT',
#   'PZ 90 (Feucht/Nürnberg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'AT',
#   'Hub Graz-AT',
#   'PZ 77 (Lahr)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'AT',
#   'Hub Graz-AT',
#   'PZ 93 (Regensburg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'AT',
#   'Hub Graz-AT',
#   'PZ 21 (Hamburg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'AT',
#   'Hub Graz-AT',
#   'PZ 46 (Dorsten)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'AT',
#   'Hub Graz-AT',
#   'PZ 58 (Hagen)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'AT',
#   'Hub Graz-AT',
#   'PZ 08 (Neumark)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'AT',
#   'Hub Graz-AT',
#   'PZ 47 (Krefeld)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'AT',
#   'Hub Graz-AT',
#   'PZ 15 (Rüdersdorf)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'BE',
#   'Brüssel-BE',
#   'PZ 67 (Speyer)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'BE',
#   'Brüssel-BE',
#   'PZ 50 (Köln)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'BE',
#   'Brüssel-BE',
#   'PZ 04 (Radefeld/Leipzig)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'BE',
#   'Brüssel-BE',
#   'PZ 90 (Feucht/Nürnberg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'BE',
#   'Brüssel-BE',
#   'PZ 77 (Lahr)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'BE',
#   'Brüssel-BE',
#   'PZ 93 (Regensburg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'BE',
#   'Brüssel-BE',
#   'PZ 21 (Hamburg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'BE',
#   'Brüssel-BE',
# ...
#   'PL',
#   'Wrocław-PL',
#   'PZ 47 (Krefeld)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'PL',
#   'Wrocław-PL',
#   'PZ 15 (Rüdersdorf)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'PL',
#   'Bydgoszcz (Solec Kujawski)-PL',
#   'PZ 67 (Speyer)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'PL',
#   'Bydgoszcz (Solec Kujawski)-PL',
#   'PZ 50 (Köln)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'PL',
#   'Bydgoszcz (Solec Kujawski)-PL',
#   'PZ 04 (Radefeld/Leipzig)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'PL',
#   'Bydgoszcz (Solec Kujawski)-PL',
#   'PZ 90 (Feucht/Nürnberg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'PL',
#   'Bydgoszcz (Solec Kujawski)-PL',
#   'PZ 77 (Lahr)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'PL',
#   'Bydgoszcz (Solec Kujawski)-PL',
#   'PZ 93 (Regensburg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'PL',
#   'Bydgoszcz (Solec Kujawski)-PL',
#   'PZ 21 (Hamburg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'PL',
#   'Bydgoszcz (Solec Kujawski)-PL',
#   'PZ 46 (Dorsten)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'PL',
#   'Bydgoszcz (Solec Kujawski)-PL',
#   'PZ 58 (Hagen)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'PL',
#   'Bydgoszcz (Solec Kujawski)-PL',
#   'PZ 08 (Neumark)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'PL',
#   'Bydgoszcz (Solec Kujawski)-PL',
#   'PZ 47 (Krefeld)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'PL',
#   'Bydgoszcz (Solec Kujawski)-PL',
#   'PZ 15 (Rüdersdorf)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'PT',
#   'Lisboa-PT',
#   'PZ 67 (Speyer)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'PT',
#   'Lisboa-PT',
#   'PZ 50 (Köln)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'PT',
#   'Lisboa-PT',
#   'PZ 04 (Radefeld/Leipzig)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'PT',
#   'Lisboa-PT',
#   'PZ 90 (Feucht/Nürnberg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'PT',
#   'Lisboa-PT',
#   'PZ 77 (Lahr)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'PT',
#   'Lisboa-PT',
#   'PZ 93 (Regensburg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'PT',
#   'Lisboa-PT',
#   'PZ 21 (Hamburg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'PT',
#   'Lisboa-PT',
#   'PZ 46 (Dorsten)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'PT',
#   'Lisboa-PT',
#   'PZ 58 (Hagen)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'PT',
#   'Lisboa-PT',
#   'PZ 08 (Neumark)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'PT',
#   'Lisboa-PT',
#   'PZ 47 (Krefeld)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'PT',
#   'Lisboa-PT',
#   'PZ 15 (Rüdersdorf)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'RO',
#   'Oradea-RO',
#   'PZ 67 (Speyer)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'RO',
#   'Oradea-RO',
#   'PZ 50 (Köln)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'RO',
#   'Oradea-RO',
#   'PZ 04 (Radefeld/Leipzig)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'RO',
#   'Oradea-RO',
#   'PZ 90 (Feucht/Nürnberg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'RO',
#   'Oradea-RO',
#   'PZ 77 (Lahr)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'RO',
#   'Oradea-RO',
#   'PZ 93 (Regensburg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'RO',
#   'Oradea-RO',
#   'PZ 21 (Hamburg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'RO',
#   'Oradea-RO',
#   'PZ 46 (Dorsten)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'RO',
#   'Oradea-RO',
#   'PZ 58 (Hagen)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'RO',
#   'Oradea-RO',
#   'PZ 08 (Neumark)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'RO',
#   'Oradea-RO',
#   'PZ 47 (Krefeld)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'RO',
#   'Oradea-RO',
#   'PZ 15 (Rüdersdorf)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Stockholm - Västberga-SE',
#   'PZ 67 (Speyer)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Stockholm - Västberga-SE',
#   'PZ 50 (Köln)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Stockholm - Västberga-SE',
#   'PZ 04 (Radefeld/Leipzig)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Stockholm - Västberga-SE',
#   'PZ 90 (Feucht/Nürnberg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Stockholm - Västberga-SE',
#   'PZ 77 (Lahr)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Stockholm - Västberga-SE',
#   'PZ 93 (Regensburg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Stockholm - Västberga-SE',
#   'PZ 21 (Hamburg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Stockholm - Västberga-SE',
#   'PZ 46 (Dorsten)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Stockholm - Västberga-SE',
#   'PZ 58 (Hagen)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Stockholm - Västberga-SE',
#   'PZ 08 (Neumark)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Stockholm - Västberga-SE',
#   'PZ 47 (Krefeld)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Stockholm - Västberga-SE',
#   'PZ 15 (Rüdersdorf)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Helsingborg-SE',
#   'PZ 67 (Speyer)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Helsingborg-SE',
#   'PZ 50 (Köln)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Helsingborg-SE',
#   'PZ 04 (Radefeld/Leipzig)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Helsingborg-SE',
#   'PZ 90 (Feucht/Nürnberg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Helsingborg-SE',
#   'PZ 77 (Lahr)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Helsingborg-SE',
#   'PZ 93 (Regensburg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Helsingborg-SE',
#   'PZ 21 (Hamburg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Helsingborg-SE',
#   'PZ 46 (Dorsten)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Helsingborg-SE',
#   'PZ 58 (Hagen)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Helsingborg-SE',
#   'PZ 08 (Neumark)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Helsingborg-SE',
#   'PZ 47 (Krefeld)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Helsingborg-SE',
#   'PZ 15 (Rüdersdorf)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Arlöv-SE',
#   'PZ 67 (Speyer)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Arlöv-SE',
#   'PZ 50 (Köln)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Arlöv-SE',
#   'PZ 04 (Radefeld/Leipzig)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Arlöv-SE',
#   'PZ 90 (Feucht/Nürnberg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Arlöv-SE',
#   'PZ 77 (Lahr)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Arlöv-SE',
#   'PZ 93 (Regensburg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Arlöv-SE',
#   'PZ 21 (Hamburg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Arlöv-SE',
#   'PZ 46 (Dorsten)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Arlöv-SE',
#   'PZ 58 (Hagen)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Arlöv-SE',
#   'PZ 08 (Neumark)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Arlöv-SE',
#   'PZ 47 (Krefeld)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Arlöv-SE',
#   'PZ 15 (Rüdersdorf)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Malmö-SE',
#   'PZ 67 (Speyer)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Malmö-SE',
#   'PZ 50 (Köln)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Malmö-SE',
#   'PZ 04 (Radefeld/Leipzig)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Malmö-SE',
#   'PZ 90 (Feucht/Nürnberg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Malmö-SE',
#   'PZ 77 (Lahr)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Malmö-SE',
#   'PZ 93 (Regensburg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Malmö-SE',
#   'PZ 21 (Hamburg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Malmö-SE',
#   'PZ 46 (Dorsten)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Malmö-SE',
#   'PZ 58 (Hagen)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Malmö-SE',
#   'PZ 08 (Neumark)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Malmö-SE',
#   'PZ 47 (Krefeld)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SE',
#   'Malmö-SE',
#   'PZ 15 (Rüdersdorf)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SI',
#   'Ljubljana-SI',
#   'PZ 67 (Speyer)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SI',
#   'Ljubljana-SI',
#   'PZ 50 (Köln)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SI',
#   'Ljubljana-SI',
#   'PZ 04 (Radefeld/Leipzig)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SI',
#   'Ljubljana-SI',
#   'PZ 90 (Feucht/Nürnberg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SI',
#   'Ljubljana-SI',
#   'PZ 77 (Lahr)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SI',
#   'Ljubljana-SI',
#   'PZ 93 (Regensburg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SI',
#   'Ljubljana-SI',
#   'PZ 21 (Hamburg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SI',
#   'Ljubljana-SI',
#   'PZ 46 (Dorsten)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SI',
#   'Ljubljana-SI',
#   'PZ 58 (Hagen)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SI',
#   'Ljubljana-SI',
#   'PZ 08 (Neumark)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SI',
#   'Ljubljana-SI',
#   'PZ 47 (Krefeld)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SI',
#   'Ljubljana-SI',
#   'PZ 15 (Rüdersdorf)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'Bratislava - Raca-SK',
#   'PZ 67 (Speyer)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'Bratislava - Raca-SK',
#   'PZ 50 (Köln)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'Bratislava - Raca-SK',
#   'PZ 04 (Radefeld/Leipzig)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'Bratislava - Raca-SK',
#   'PZ 90 (Feucht/Nürnberg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'Bratislava - Raca-SK',
#   'PZ 77 (Lahr)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'Bratislava - Raca-SK',
#   'PZ 93 (Regensburg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'Bratislava - Raca-SK',
#   'PZ 21 (Hamburg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'Bratislava - Raca-SK',
#   'PZ 46 (Dorsten)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'Bratislava - Raca-SK',
#   'PZ 58 (Hagen)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'Bratislava - Raca-SK',
#   'PZ 08 (Neumark)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'Bratislava - Raca-SK',
#   'PZ 47 (Krefeld)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'Bratislava - Raca-SK',
#   'PZ 15 (Rüdersdorf)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'Bratislava - Petrzalka-SK',
#   'PZ 67 (Speyer)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'Bratislava - Petrzalka-SK',
#   'PZ 50 (Köln)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'Bratislava - Petrzalka-SK',
#   'PZ 04 (Radefeld/Leipzig)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'Bratislava - Petrzalka-SK',
#   'PZ 90 (Feucht/Nürnberg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'Bratislava - Petrzalka-SK',
#   'PZ 77 (Lahr)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'Bratislava - Petrzalka-SK',
#   'PZ 93 (Regensburg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'Bratislava - Petrzalka-SK',
#   'PZ 21 (Hamburg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'Bratislava - Petrzalka-SK',
#   'PZ 46 (Dorsten)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'Bratislava - Petrzalka-SK',
#   'PZ 58 (Hagen)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'Bratislava - Petrzalka-SK',
#   'PZ 08 (Neumark)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'Bratislava - Petrzalka-SK',
#   'PZ 47 (Krefeld)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'Bratislava - Petrzalka-SK',
#   'PZ 15 (Rüdersdorf)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'Zilina- Strecno-SK',
#   'PZ 67 (Speyer)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'Zilina- Strecno-SK',
#   'PZ 50 (Köln)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'Zilina- Strecno-SK',
#   'PZ 04 (Radefeld/Leipzig)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'Zilina- Strecno-SK',
#   'PZ 90 (Feucht/Nürnberg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'Zilina- Strecno-SK',
#   'PZ 77 (Lahr)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'Zilina- Strecno-SK',
#   'PZ 93 (Regensburg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'Zilina- Strecno-SK',
#   'PZ 21 (Hamburg)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'Zilina- Strecno-SK',
#   'PZ 46 (Dorsten)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'Zilina- Strecno-SK',
#   'PZ 58 (Hagen)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'Zilina- Strecno-SK',
#   'PZ 08 (Neumark)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'Zilina- Strecno-SK',
#   'PZ 47 (Krefeld)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'SK',
#   'Zilina- Strecno-SK',
#   'PZ 15 (Rüdersdorf)-DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK',
#   'AT',
#   'Hub Wien I-AT',
#   'Kolding-DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK',
#   'AT',
#   'Hub Graz-AT',
#   'Kolding-DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK',
#   'BE',
#   'Brüssel-BE',
#   'Kolding-DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK',
#   'BG',
#   'Sofia-BG',
#   'Kolding-DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK',
#   'CZ',
#   'Brno-CZ',
#   'Kolding-DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK',
#   'CZ',
#   'Ostrava-CZ',
#   'Kolding-DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK',
#   'CZ',
#   'Krupka 1-CZ',
#   'Kolding-DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK',
#   'CZ',
#   'Plzen 1-CZ',
#   'Kolding-DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK',
#   'CZ',
#   'Hradec Kralove - Brezhrad-CZ',
#   'Kolding-DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK',
#   'DE',
#   'PZ 67 (Speyer)-DE',
#   'Kolding-DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK',
#   'DE',
#   'PZ 50 (Köln)-DE',
#   'Kolding-DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK',
#   'DE',
#   'PZ 04 (Radefeld/Leipzig)-DE',
#   'Kolding-DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK',
#   'DE',
#   'PZ 90 (Feucht/Nürnberg)-DE',
#   'Kolding-DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK',
#   'DE',
#   'PZ 77 (Lahr)-DE',
#   'Kolding-DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK',
#   'DE',
#   'PZ 93 (Regensburg)-DE',
#   'Kolding-DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK',
#   'DE',
#   'PZ 21 (Hamburg)-DE',
#   'Kolding-DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK',
#   'DE',
#   'PZ 46 (Dorsten)-DE',
#   'Kolding-DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK',
#   'DE',
#   'PZ 58 (Hagen)-DE',
#   'Kolding-DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK',
#   'DE',
#   'PZ 08 (Neumark)-DE',
#   'Kolding-DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK',
#   'DE',
#   'PZ 47 (Krefeld)-DE',
#   'Kolding-DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ...}

# %% [markdown]
# ## Cost Constraint

# %%
# Assumption: all the excessive spaces could be loaded with co-loading opportunities in the current network
# Assumption: In the new network, all the co-loading oppottunities doesn't exist
'''
model.addConstrs(((quicksum(F[p,q,t] * cost[p,q,t] for p in L[m] for q in L[k] for t in T) *
                 quicksum(F_[p,q,t] * C[t] for p in L[m] for q in L[k] for t in T) <= 
                 (quicksum(F_[p,q,t] * cost[p,q,t] for p in L[m] for q in L[k] for t in T) *
                 quicksum(F[p,q,t] * C[t] for p in L[m] for q in L[k] for t in T)) * 1.05) for m, k in mk), "Cost Constraint")

'''

model.addConstrs(((quicksum(F[p,q,t] * cost[p,q,t] for p in L[m] for q in L[k] for t in T) *
                 quicksum(F_[p,q,t] * C[t] for p in L[m] for q in L[k] for t in T) <= 
                 (quicksum(F_[p,q,t] * cost[p,q,t] for p in L[m] for q in L[k] for t in T) *
                 quicksum(V[p,q] for p in L[m] for q in L[k])) * 1.05) for m, k in mk
                 ),"Cost Constraint")
# Out:
# {('AT', 'BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'FR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'GB'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'FR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'GB'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'FR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'GB'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'FR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'GB'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'FR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'GB'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK', 'AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK', 'BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK', 'DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK', 'FR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK', 'GB'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK', 'NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'FR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'GB'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FR', 'AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FR', 'BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FR', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FR', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FR', 'DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FR', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FR', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FR', 'GB'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FR', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FR', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FR', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FR', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FR', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FR', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FR', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FR', 'NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FR', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FR', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FR', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FR', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FR', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FR', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GB', 'AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GB', 'BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GB', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GB', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GB', 'DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GB', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GB', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GB', 'FR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GB', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GB', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GB', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GB', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GB', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GB', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GB', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GB', 'NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GB', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GB', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GB', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GB', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GB', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GB', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GR', 'AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GR', 'BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GR', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GR', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GR', 'DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GR', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GR', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GR', 'FR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GR', 'GB'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GR', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GR', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GR', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GR', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GR', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GR', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GR', 'NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GR', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GR', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GR', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GR', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GR', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GR', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HR', 'AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HR', 'BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HR', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HR', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HR', 'DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HR', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HR', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HR', 'FR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HR', 'GB'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HR', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HR', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HR', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HR', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HR', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HR', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HR', 'NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HR', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HR', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HR', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HR', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HR', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HR', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HU', 'AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HU', 'BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HU', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HU', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HU', 'DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HU', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HU', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HU', 'FR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HU', 'GB'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HU', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HU', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HU', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HU', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HU', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HU', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HU', 'NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HU', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HU', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HU', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HU', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HU', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HU', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('IE', 'AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('IE', 'BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('IE', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('IE', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('IE', 'DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('IE', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('IE', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('IE', 'FR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('IE', 'GB'): <gurobi.Constr *Awaiting Model Update*>,
#  ('IE', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('IE', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('IE', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('IE', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('IE', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('IE', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('IE', 'NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('IE', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('IE', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('IE', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('IE', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('IE', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('IE', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LT', 'AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LT', 'BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LT', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LT', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LT', 'DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LT', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LT', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LT', 'FR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LT', 'GB'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LT', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LT', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LT', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LT', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LT', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LT', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LT', 'NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LT', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LT', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LT', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LT', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LT', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LT', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LU', 'AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LU', 'BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LU', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LU', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LU', 'DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LU', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LU', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LU', 'FR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LU', 'GB'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LU', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LU', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LU', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LU', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LU', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LU', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LU', 'NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LU', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LU', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LU', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LU', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LU', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LU', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NL', 'AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NL', 'BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NL', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NL', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NL', 'DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NL', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NL', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NL', 'FR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NL', 'GB'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NL', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NL', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NL', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NL', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NL', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NL', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NL', 'NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NL', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NL', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NL', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NL', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NL', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NL', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NO', 'AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NO', 'BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NO', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NO', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NO', 'DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NO', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NO', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NO', 'FR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NO', 'GB'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NO', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NO', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NO', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NO', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NO', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NO', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NO', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NO', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NO', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NO', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NO', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NO', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NO', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PL', 'AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PL', 'BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PL', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PL', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PL', 'DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PL', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PL', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PL', 'FR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PL', 'GB'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PL', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PL', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PL', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PL', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PL', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PL', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PL', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PL', 'NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PL', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PL', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PL', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PL', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PL', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'FR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'GB'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('RO', 'AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('RO', 'BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('RO', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('RO', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('RO', 'DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('RO', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('RO', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('RO', 'FR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('RO', 'GB'): <gurobi.Constr *Awaiting Model Update*>,
#  ('RO', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('RO', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('RO', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('RO', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('RO', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('RO', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('RO', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('RO', 'NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('RO', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('RO', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('RO', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('RO', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('RO', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SE', 'AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SE', 'BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SE', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SE', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SE', 'DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SE', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SE', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SE', 'FR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SE', 'GB'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SE', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SE', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SE', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SE', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SE', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SE', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SE', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SE', 'NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SE', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SE', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SE', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SE', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SE', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI', 'AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI', 'BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI', 'DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI', 'FR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI', 'GB'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI', 'NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SK', 'AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SK', 'BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SK', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SK', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SK', 'DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SK', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SK', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SK', 'FR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SK', 'GB'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SK', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SK', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SK', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SK', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SK', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SK', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SK', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SK', 'NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SK', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SK', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SK', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SK', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SK', 'SI'): <gurobi.Constr *Awaiting Model Update*>}

# %% [markdown]
# ## Obj

# %%
model.setObjective(quicksum(x_[p,q,i] * TT[p, i] for p, q, i in piq) + 
                  quicksum(x_[i,p,q] * TT[i, q] for p, q, i in piq) +
                  quicksum(x[p,q] * TT[p, q] for p, q in pq)
                  ,  GRB.MINIMIZE)

# %%
model.update()

# %%
timeLimit = 2000 # In second
model.Params.SolutionLimit = 10
oldSolutionLimit = model.Params.SolutionLimit
model.Params.TimeLimit = timeLimit - model.getAttr(GRB.Attr.Runtime)
#model.Params.SolutionLimit = oldSolutionLimit - model.Params.SolutionLimit
model.optimize()
# Out:
# Changed value of parameter SolutionLimit to 10
#    Prev: 2000000000  Min: 1  Max: 2000000000  Default: 2000000000
# Changed value of parameter TimeLimit to 2000.0
#    Prev: 1e+100  Min: 0.0  Max: 1e+100  Default: 1e+100
# Optimize a model with 25904 rows, 158980 columns and 865577 nonzeros
# Variable types: 2752 continuous, 156228 integer (139716 binary)
# Coefficient statistics:
#   Matrix range     [8e-02, 1e+06]
#   Objective range  [2e+00, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Presolve removed 8953 rows and 10820 columns (presolve time = 5s) ...
# Presolve removed 13659 rows and 14830 columns
# Presolve time: 8.90s
# Presolved: 12245 rows, 144150 columns, 580109 nonzeros
# Variable types: 0 continuous, 144150 integer (129421 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0167313e+04   1.786531e+03   2.613840e+09     10s
# Concurrent spin time: 0.00s
#
# Solved with dual simplex
#
# Root relaxation: objective 9.955590e+03, 87 iterations, 0.77 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 9955.59000    0  657          - 9955.59000      -     -   10s
#      0     0 9955.67531    0  496          - 9955.67531      -     -   12s
#      0     0 9955.67531    0  139          - 9955.67531      -     -   13s
#      0     0 9955.90308    0  123          - 9955.90308      -     -   14s
#      0     0 9955.90308    0  124          - 9955.90308      -     -   14s
#      0     0 9955.92431    0  146          - 9955.92431      -     -   15s
#      0     0 9955.92431    0  141          - 9955.92431      -     -   16s
#      0     0 9955.96982    0  150          - 9955.96982      -     -   16s
#      0     0 9955.98172    0  152          - 9955.98172      -     -   17s
#      0     0 9955.98260    0  152          - 9955.98260      -     -   17s
#      0     0 9955.98687    0  155          - 9955.98687      -     -   18s
#      0     0 9955.98800    0  158          - 9955.98800      -     -   18s
#      0     0 9955.99767    0  155          - 9955.99767      -     -   19s
#      0     0 9955.99767    0  128          - 9955.99767      -     -   19s
#      0     2 9955.99767    0  128          - 9955.99767      -     -   30s
#     53    55 9957.94755   19  105          - 9956.02858      -  25.9   36s
#    109   109 9958.61898   44  184          - 9956.02858      -  16.6   40s
#    187   188 9959.07750   77  258          - 9956.02858      -  13.0   45s
#    330   331 9961.80613  148  261          - 9956.02858      -   9.2   50s
#    459   460 9964.22517  216  259          - 9956.02858      -   7.5   55s
#    610   610 9976.46638  295  273          - 9956.02858      -   6.5   61s
#    781   782 10003.1185  410  251          - 9956.02858      -   6.5   66s
#    992   993 10005.5845  554  307          - 9956.02858      -   5.9   72s
#   1049  1050 10017.2734  584  274          - 9956.02858      -   6.0   76s
#   1165  1165 10020.7223  649  295          - 9956.02858      -   6.5   82s
#   1222  1222 10027.0854  683  281          - 9956.02858      -   7.1   85s
#   1516  1517 10034.9401  885  273          - 9956.02858      -   6.7   93s
#   1616  1617 10035.4198  948  284          - 9956.02858      -   6.6   96s
#   1747  1748 10036.2059  997  317          - 9956.02858      -   6.5  102s
#   1822  1822 10036.5239 1030  320          - 9956.02858      -   6.5  105s
#   2031  2030 10044.3033 1103  367          - 9956.02858      -   6.5  113s
#   2146  2146 10047.5011 1174  372          - 9956.02858      -   6.4  117s
#   2279  2271 10053.9773 1241  386          - 9956.02858      -   6.5  122s
#   2398  2389 10078.4112 1285  311          - 9956.02858      -   6.5  127s
#   2564  2556 10078.4986 1328  322          - 9956.02858      -   6.3  131s
#   2744  2734 10110.7913 1372  350          - 9956.02858      -   6.1  136s
#   2913  2904 10090.2470 1407  406          - 9956.02858      -   6.3  141s
#   3084  3075 10096.0683 1438  425          - 9956.02858      -   6.5  145s
#   3311  3300 10098.5314 1455  407          - 9956.02858      -   7.1  151s
#   3470  3460 10098.3985 1498  221          - 9956.02858      -   7.1  157s
#   3627  3615 10012.4660  723  128          - 9956.02858      -   7.2  166s
#   3630  3617 10016.1708  394   78          - 9956.02858      -   7.2  170s
#   3636  3621 10014.0642  308   96          - 9956.02858      -   7.1  175s
#   3641  3624 9989.80600  324  103          - 9956.02858      -   7.1  180s
#   3650  3630 9991.36053  316  105          - 9956.02858      -   7.1  185s
#   3656  3634 10036.2086  883  112          - 9956.02858      -   7.1  190s
#   3658  3636 9985.39434  169  112          - 9956.02858      -   7.1  207s
#   3667  3645 9957.54241   13   62          - 9956.02858      -   9.1  210s
#   3724  3681 9964.75486   27   61          - 9956.02858      -   9.3  215s
#   3817  3744 9969.66328   50   56          - 9956.02858      -   9.6  220s
#   3892  3793 9956.02858   68   93          - 9956.02858      -   9.7  225s
#   4013  3873 9968.37005  101   71          - 9956.02858      -   9.9  230s
#   4102  3932 9970.07544  123   72          - 9956.02858      -  10.0  235s
#   4238  4025 9964.93719  160   92          - 9956.02858      -  10.0  240s
#   4381  4119 9967.71591  198   73          - 9956.02858      -  10.1  245s
#   4501  4200 9973.59591  229   73          - 9956.02858      -  10.2  250s
#   4650  4298 9968.71338  269   97          - 9956.02858      -  10.2  255s
#   4822  4414 9961.87572  319  113          - 9956.02858      -  10.2  261s
#   4947  4497 9963.33539  353   92          - 9956.02858      -  10.2  265s
#   5151  4623 9964.13318  406  101          - 9956.02858      -  10.2  272s
#   5222  4669 9977.08782  421   84          - 9956.02858      -  10.1  275s
#   5359  4734 9965.69824  454   72          - 9956.02858      -  10.2  281s
#   5485  4818 9966.07243  494   94          - 9956.02858      -  10.6  286s
#   5620  4908 9988.09670  539   57          - 9956.02858      -  10.9  292s
#   5699  4958 9966.39827  565   66          - 9956.02858      -  11.1  295s
#   5868  5073 9966.94251  618   86          - 9956.02858      -  11.4  302s
#   5957  5132 9968.69545  646   48          - 9956.02858      -  11.6  306s
#   6052  5195 10000.9137  677   41          - 9956.02858      -  11.9  310s
#   6254  5328 9974.45684  742   31          - 9956.02858      -  12.3  318s
#   6359  5398 9988.30746  777   17          - 9956.02858      -  12.6  322s
#   6470  5473 9990.43337  817   19          - 9956.02858      -  12.8  327s
#   6588  5552 10020.0134  857   19          - 9956.02858      -  13.1  332s
#   6716  5637 10027.5433  900    9          - 9956.02858      -  13.3  337s
#   6840  5723 10034.9867  944    9          - 9956.02858      -  13.6  344s
#   6981  5813 10031.0078  993   30          - 9956.02858      -  13.8  351s
#   7122  5910 10056.6800 1041    9          - 9956.02858      -  14.0  357s
#   7268  6003 10061.2320 1091   30          - 9956.02858      -  14.3  376s
#   7424  6109 10096.4833 1144   11          - 9956.02858      -  14.6  382s
#   7584  6216 10104.8600 1200   11          - 9956.02858      -  14.9  393s
#   7754  6333 10102.3146 1256   18          - 9956.02858      -  15.2  400s
#   7946  6439 10085.3787 1322   18          - 9956.02858      -  15.5  408s
#   8108  6534 10103.6700 1375   14          - 9956.02858      -  15.9  413s
#   8259  6625 9958.50688   41   70          - 9956.02858      -  16.5  419s
#   8440  6748 9957.42501   75  144          - 9956.02858      -  16.8  428s
#   8677  6904 9959.58136  111   85          - 9956.02858      -  17.0  436s
#   8878  7040 9957.72166  151  197          - 9956.02858      -  17.2  444s
#   8962  7094 9987.87763  739  126          - 9956.02858      -  17.7  445s
#   9091  7177 9957.91873  193  212          - 9956.02858      -  17.5  453s
#   9303  7320 9960.33522  231  111          - 9956.02858      -  17.7  461s
#   9521  7466 9960.39481  270  143          - 9956.02858      -  18.1  470s
#   9746  7617 9958.25539  298  278          - 9956.02858      -  18.5  481s
#   9952  7754 9958.49014  332  325          - 9956.02858      -  18.9  491s
#  10167  7895 9958.80870  374  329          - 9956.02858      -  19.2  504s
#  10386  8044 9959.04082  417  335          - 9956.02858      -  19.5  515s
#  10648  8218 9959.18603  466  367          - 9956.02858      -  20.0  525s
#  10901  8384 9959.73225  509  377          - 9956.02858      -  20.3  536s
#  11224  8603 9976.84782  578  119          - 9956.02858      -  20.2  547s
#  11604  8853 9965.70227  679  161          - 9956.02858      -  20.0  556s
#  11965  9097 9973.96288  773  150          - 9956.02858      -  19.7  566s
#  12255  9274 9970.72006  860  124          - 9956.02858      -  19.4  576s
#  12524  9420 9975.59407  912  137          - 9956.02858      -  19.2  584s
#  12814  9606 9970.80890  956  145          - 9956.02858      -  18.9  595s
#  13102  9804 9975.01590  998  143          - 9956.02858      -  18.6  604s
#  13409 10018 9984.15940 1050  147          - 9956.02858      -  18.4  613s
#  13727 10196 9970.95771 1114  169          - 9956.02858      -  18.1  621s
#  14097 10398 10006.0710 1197  143          - 9956.02858      -  17.8  628s
#  14414 10612 9993.44689 1270  117          - 9956.02858      -  17.6  636s
#  14777 10921 9976.57170 1352   97          - 9956.02858      -  17.4  730s
#  15046 11191 9978.71243 1432   30          - 9956.02858      -  17.2  738s
#  15396 11527 10046.2929 1524   29          - 9956.02858      -  16.9  745s
#  15749 11883 9957.81951  138  239          - 9956.02858      -  16.6  753s
#  16155 12239 9962.55333  331  150          - 9956.02858      -  16.3  760s
#  16561 12620 9965.99129  529  193          - 9956.02858      -  16.0  767s
#  16967 13024 9969.62156  732  183          - 9956.02858      -  15.7  773s
#  17373 13431 9979.23243  935  169          - 9956.02858      -  15.4  779s
#  17779 13841 9990.09127 1131  128          - 9956.02858      -  15.2  785s
#  18128 14169 9991.30649 1334  122          - 9956.02858      -  14.9  838s
#  18422 14451 9994.81861 1508   54          - 9956.02858      -  14.8  845s
#  18828 14777 infeasible 1627               - 9956.19941      -  14.5  853s
# H18946 10604                    9997.3566667 9956.19941  0.41%  14.5  854s
# H19129  9502                    9989.6566667 9956.19941  0.33%  14.4  860s
# H19209  8754                    9984.1500000 9956.19941  0.28%  14.4  866s
#  19335  8871 9961.65746   83   90 9984.15000 9956.19941  0.28%  14.3  872s
#  19432  8955 9963.96012  127   73 9984.15000 9956.19941  0.28%  14.2  878s
#  19593  9089 9980.40580  206   79 9984.15000 9956.24235  0.28%  14.2  887s
# H19669  8865                    9982.8200000 9956.25434  0.27%  14.1  887s
#  19747  8982 9965.56920   96  140 9982.82000 9956.25434  0.27%  14.1  894s
#  19960  9149 9973.98005  212  111 9982.82000 9956.25434  0.27%  14.0  899s
#  20218  9381 9963.94194  164  123 9982.82000 9956.27621  0.27%  13.8  906s
#  20516  9652 9962.84101   87  114 9982.82000 9956.33941  0.27%  13.7  912s
#  20813  9923 9969.40825  241   87 9982.82000 9956.37101  0.26%  13.5  919s
#  21025 10123 9972.21250   70   87 9982.82000 9956.37101  0.26%  13.5  926s
#  21212 10299 9967.37529  116   73 9982.82000 9956.37101  0.26%  13.5  931s
#  21393 10445     cutoff  160      9982.82000 9956.37101  0.26%  13.4  936s
#  21629 10605 9968.58485  151   92 9982.82000 9956.37101  0.26%  13.4  943s
#  21891 10790 9967.59097  148   75 9982.82000 9956.37498  0.26%  13.3  949s
#  22188 11050 9958.63153   89  128 9982.82000 9956.38601  0.26%  13.1 1026s
#  22195 11055 9962.44008   70  113 9982.82000 9956.38601  0.26%  13.1 1030s
#  22200 11058 9963.29000  100  109 9982.82000 9956.38601  0.26%  13.1 1035s
# H22205 10507                    9982.1666667 9956.38601  0.26%  13.1 1039s
#  22207 10509 9959.24222   91  116 9982.16667 9956.38601  0.26%  13.1 1040s
#  22215 10514 9978.46344  316  119 9982.16667 9956.38601  0.26%  13.1 1045s
#  22222 10519 9959.45406   66  118 9982.16667 9956.38601  0.26%  13.1 1051s
#  22225 10524 9956.38601   24  112 9982.16667 9956.38601  0.26%  13.4 1056s
#  22289 10565 9956.38601   40  111 9982.16667 9956.38601  0.26%  13.4 1060s
#  22415 10647 9956.38601   68   95 9982.16667 9956.38601  0.26%  13.5 1065s
#  22527 10724 9956.38601   96   82 9982.16667 9956.38601  0.26%  13.5 1070s
#  22650 10803 9958.20640  123   68 9982.16667 9956.38601  0.26%  13.5 1075s
#  22813 10903 9956.38601  168   93 9982.16667 9956.38601  0.26%  13.4 1080s
#  22947 10986 9956.89797  201   93 9982.16667 9956.38601  0.26%  13.4 1085s
#  23083 11074 9963.30506  234   77 9982.16667 9956.38601  0.26%  13.3 1090s
#  23249 11161 9959.94268  280   79 9982.16667 9956.38601  0.26%  13.3 1095s
#  23442 11277 9980.43955  327   47 9982.16667 9956.38601  0.26%  13.3 1101s
#  23560 11353 9956.38601  107   87 9982.16667 9956.38601  0.26%  13.3 1106s
#  23671 11426 9956.38601  135   80 9982.16667 9956.38601  0.26%  13.3 1110s
#  23844 11540 9967.52335  172   71 9982.16667 9956.38601  0.26%  13.2 1115s
#  24137 11663 infeasible  261      9982.16667 9956.38601  0.26%  13.1 1121s
#  24450 11827 9956.38601  149  133 9982.16667 9956.38601  0.26%  13.0 1125s
#  24762 12008 9977.75053  322   59 9982.16667 9956.38601  0.26%  12.9 1130s
#  25070 12171 9956.38601  145  128 9982.16667 9956.38601  0.26%  12.8 1135s
#  25477 12343 9963.94291  355   83 9982.16667 9956.38601  0.26%  12.6 1142s
#  25646 12421 9956.38601  149   84 9982.16667 9956.38601  0.26%  12.5 1145s
#  26216 12736 9956.55559  145  103 9982.16667 9956.38601  0.26%  12.3 1152s
#  26578 12947 9961.69999  367   85 9982.16667 9956.38601  0.26%  12.2 1155s
#  27265 13312 9958.41360  220   76 9982.16667 9956.38601  0.26%  12.0 1162s
#  27644 13524 9956.38601  142   80 9982.16667 9956.38601  0.26%  11.8 1165s
#  27973 13705 9976.06524  362   41 9982.16667 9956.38601  0.26%  11.8 1170s
#  28459 13962 9957.73235  241  116 9982.16667 9956.38601  0.26%  11.7 1179s
#  28575 14024 9958.45329  270  108 9982.16667 9956.38601  0.26%  11.7 1183s
#  28849 14166 9965.56409  316   82 9982.16667 9956.38601  0.26%  11.6 1187s
#  29182 14329 9979.50695  370   74 9982.16667 9956.38601  0.26%  11.6 1192s
#  29420 14444 infeasible  433      9982.16667 9956.38601  0.26%  11.5 1202s
#  29847 14678 9960.64242  275   53 9982.16667 9956.38601  0.26%  11.4 1206s
#  30421 15001 9957.86175  224  128 9982.16667 9956.38601  0.26%  11.2 1210s
#  30877 15213 9976.72770  394   77 9982.16667 9956.38601  0.26%  11.1 1216s
#  31239 15402 9956.41827  151   74 9982.16667 9956.38601  0.26%  11.0 1220s
#  32124 15945 9978.68413  405   48 9982.16667 9956.40689  0.26%  10.8 1226s
#  32532 16160 9975.84511  355   44 9982.16667 9956.46828  0.26%  10.7 1230s
#  32856 16344 9962.86146  234   58 9982.16667 9956.51365  0.26%  10.6 1237s
#  33208 16562 9972.41242  376   32 9982.16667 9956.51996  0.26%  10.6 1241s
#  33766 16839 9956.57144  201   85 9982.16667 9956.53297  0.26%  10.5 1248s
#  33994 16920 9976.09705  231   34 9982.16667 9956.54974  0.26%  10.5 1251s
#  34274 17047 9962.84599  318   74 9982.16667 9956.55778  0.26%  10.4 1255s
#  35028 17438 9966.69795  438   88 9982.16667 9956.60434  0.26%  10.3 1263s
# H35031 16899                    9982.0733333 9956.60434  0.26%  10.3 1263s
# H35034 16285                    9981.3733333 9956.60434  0.25%  10.3 1263s
# H35114 15767                    9981.0466667 9956.63138  0.24%  10.3 1263s
# H35116 15169                    9980.3700000 9956.63138  0.24%  10.3 1263s
# H35125 14677                    9980.0666667 9956.63138  0.23%  10.3 1263s
#
# Cutting planes:
#   Gomory: 16
#   Implied bound: 9
#   MIR: 40
#   StrongCG: 4
#   Flow cover: 22
#   Zero half: 1
#
# Explored 35187 nodes (365505 simplex iterations) in 1263.87 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 10: 9980.07 9980.37 9981.05 ... 9989.66
#
# Solution limit reached
# Best objective 9.980066666667e+03, best bound 9.956633333333e+03, gap 0.2348%

# %%
model.solCount
# Out:
# 10

# %%
def turn_to_df(Var, col_name = None):  # Here you could input the variable
    solution = model.getAttr('x', Var)
    num_col = len(solution.keys()[0])
    collect = []
    for row in range(0, len(solution)):
        new_row = []
        for col in range(0, num_col):
            new_row.append(solution.keys()[row][col])
        new_row.append(solution[solution.keys()[row]])
    
        collect.append(new_row)
    return pd.DataFrame(collect, columns = col_name)

# %%
Country_Direct = turn_to_df(X, ["Ori_Country", "Dest_Country", "Taken"])
Country_Indirect = turn_to_df(X_, ["Ori_Country", "Transit_Country","Dest_Country", "Taken"])

Hub_Direct = turn_to_df(x, ["Ori_Hub", "Dest_Hub", "Taken"])
Hub_Indirect = turn_to_df(x_, ["Ori_Hub", "Transit_Hub","Dest_Hub", "Taken"])

Route_Cap = turn_to_df(V, ["Ori_Hub", "Dest_Hub", "Taken"])
Freq = turn_to_df(F, ["Ori_Hub", "Dest_Hub","Truck Type", "Taken"])
Start = turn_to_df(S, ["Ori_Hub", "Dest_Hub", "Time"])
Night = turn_to_df(N, ["Ori_Hub", "Dest_Hub", "Nights"])

# %%
for key in attri_dict.keys():
    df_output = turn_to_df(attri_dict[key])
    df_output.to_csv(f"Output/{key}_output.csv")

# %%
# Out:
# 10439.0
