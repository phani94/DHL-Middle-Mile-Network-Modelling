# %%
from gurobipy import Model, GRB, quicksum, tuplelist
import numpy as np
import pandas as pd

# %%
# The following file works as a reference table to match the names of 2 sheets
hub_list = pd.read_csv('Database/Hub list.csv')
hub_list.Ref_City = hub_list.Ref_City + "-" + hub_list.Country

# drop duplicates
hub_list.drop_duplicates(subset = "Ref_City", keep='first', inplace=True)


hub_ref = {}
for row in hub_list.index:
    hub_ref[hub_list.loc[row, "City"]] = hub_list.loc[row, "Ref_City"]

    
    
def name_transform(city_name):
    if city_name in hub_ref.keys():
        return hub_ref[city_name]
    else:
        return city_name

# %%
# Simple Version
masterfile = pd.read_excel("Database/Simple/Simple Routes.xlsx", sheet_name = 0)

# Complete Version
#masterfile = pd.read_csv("Database/inter_distances.csv")

# %%
# Import forecast for creating the country set
forecast = pd.read_csv("Database/Average_Forecast.csv")
forecast.fillna(0, inplace = True)

# Only satisfied those the current network can reach
# Otherwise the solution would be infeasible

used_c = masterfile["Origin Country"].unique().tolist() +  masterfile["Destination Country"].unique().tolist() # Not every hubs in the hub list is used
used_c = list( dict.fromkeys(used_c) )  # Remove duplicate

all_c = forecast.Origin.unique().tolist() +  forecast.Destination.unique().tolist() # Not every hubs in the hub list is used
all_c = list( dict.fromkeys(all_c) )  # Remove duplicate

for x in used_c:
    try:
        all_c.remove(x)
    except:
        continue
        
for c in all_c:
    forecast["Origin"].replace(c, np.nan, inplace = True)
    forecast["Destination"].replace(c, np.nan, inplace = True)
    
forecast.dropna(how = "any", inplace = True)
forecast = forecast[forecast["Average"] > 0]

country_set = list(zip(forecast["Origin"].to_list(), forecast["Destination"].to_list()))

# %% [markdown]
# # Define the Set
# ## 1. Hubs in each Country (L) & All Hubs (H)

# %%
used_hubs = masterfile.From.unique().tolist() +  masterfile.To.unique().tolist() # Not every hubs in the hub list is used
used_hubs = list( dict.fromkeys(used_hubs) )  # Remove duplicate

hub_list_used = hub_list.set_index("Ref_City")
hub_list_used = hub_list_used.loc[hub_list_used.index.isin(used_hubs), :]
hub_list_used.reset_index(inplace = True)

#hub_list_used["Country"] = hub_list_used.apply(lambda row: row["Ref_City"].split("-")[-1], axis = 1) # To fill NA in country

L = {}
for country in used_c:  # hub_list_used.Country.unique():
    hub_collect = hub_list_used[hub_list_used.loc[:, "Country"] == country]["Ref_City"].tolist()
    L[country] = hub_collect

    #for row in hub_list_used.index:

    #L[hub_list_used.loc[row, "Country"]].append(hub_list_used.loc[row, "Ref_City"])
H = hub_list_used.Ref_City.unique().tolist() # All hubs

# %% [markdown]
# ## 2. European Countries (E)

# %%
E = used_c # from the "forecast" file

# %% [markdown]
# ## 3. Truck Types (T)

# %%
truck_cap = pd.read_csv("Database/TruckVSCap.csv")
T = truck_cap["Truck Type"].tolist()

# %%
T
# Out:
# ['2 Swap Bodies', 'Swap Body', 'Trailer', 'Van', 'Co-loading']

# %% [markdown]
# ## Define subset for the later use

# %%
# Define tuplelist for the assign of variables

mjk = tuplelist([(m,j,k) for m, k in country_set for j in E if (m != j) & (j != k)])
mk = tuplelist([(m,k) for m, k in country_set])
pq = tuplelist([(p,q) for m,k in mk for p in L[m] for q in L[k]])
piq = tuplelist([(p,i,q) for (m,j,k) in mjk for p in L[m] for i in L[j] for q in L[k]])
pq_all = tuplelist((p, q) for m in E for k in E if m != k for p in L[m] for q in L[k])
pqt = [(p,q,t) for p,q in pq_all for t in T]

# %% [markdown]
# # Define all the parameters
#
# ## 1. Cost:
# Transportation Cost between hub p ∈ H and hub q ∈ H using truck t ∈ T (Euro/ kg)

# %%
cost_file = pd.read_csv("Database/Costs.csv")

# %%
cost = {}
for row in cost_file.index:
    cost_key = (cost_file["From"][row], cost_file["To"][row], cost_file["Truck type"][row])
    cost[cost_key] = cost_file["Cost/kg"][row]
    
cl_distance = 800

if "Co-loading" in T:
    for p, q in pq_all:
        cost[(p, q, "Co-loading")] = cost[(p, q, "Van")]*0.7 if cost[(p, q, "Van")] < ((0.6*cl_distance+5)/2250) else 99
        # (0.6*500+5)/2250 use distance as a filter, over 500 km, the Co-loading opportunities are less
'''
for p, q in pq:
    cost[(p, q, "Co-loading-Extra")] = cost[(p, q, "Van")]*10
'''
# Out:
# '\nfor p, q in pq:\n    cost[(p, q, "Co-loading-Extra")] = cost[(p, q, "Van")]*10\n'

# %% [markdown]
# # 2. Forecast volume: Z
# Average forecasted parcel volume from country m ∈ E to country j ∈ E

# %%
Z = {}

minimum_demands = 0
forecast["Target"] = forecast.apply(lambda row: row.Average if row.Average >= minimum_demands else 0, axis = 1)

for row in forecast.index:
    key = (forecast["Origin"][row], forecast["Destination"][row])
    Z[key] = int(round(forecast["Target"][row])) # Can only be interger

# Some missing connection in the forecast
for conn in mk:
    if conn not in Z.keys():
        Z[conn] = 0
        print(conn)

# %% [markdown]
# ## 3. Current Freqency (F_)
# the frequency of truck t from hub to hub q in the current network.

# %%
# The following code transform the excel files to csv file in specific format
'''
freq_truck = pd.read_excel("Database/Result_Freq.xlsx", sheet_name = 0)
freq_truck.replace("Ryton Gateway", "Ryton", inplace = True)
freq_truck["From"] = freq_truck.apply(lambda row: name_transform(row["Org. GTW"]), axis = 1)
freq_truck["To"] = freq_truck.apply(lambda row: name_transform(row["Dst. GTW"]), axis = 1)
freq_truck.loc[:, :].to_csv("Database/current_network.csv")

'''
# Out:
# '\nfreq_truck = pd.read_excel("Database/Result_Freq.xlsx", sheet_name = 0)\nfreq_truck.replace("Ryton Gateway", "Ryton", inplace = True)\nfreq_truck["From"] = freq_truck.apply(lambda row: name_transform(row["Org. GTW"]), axis = 1)\nfreq_truck["To"] = freq_truck.apply(lambda row: name_transform(row["Dst. GTW"]), axis = 1)\nfreq_truck.loc[:, :].to_csv("Database/current_network.csv")\n\n'

# %%
freq_current = pd.read_csv("Database/current_network.csv")
# The following section work as a formatting part. To avoid different naming issues
freq_current.replace("trailer", "Trailer", inplace = True)
freq_current.replace("2 swap bodies", "2 Swap Bodies", inplace = True)
freq_current.replace("van", "Van", inplace = True)
freq_current.replace("1 swap body", "Swap Body", inplace = True)
freq_current.replace("SEMI TRAILER", "Swap Body", inplace = True)
freq_current.replace("Cargo 50 m3", "Swap Body", inplace = True)
freq_current.replace("Sea Container", "2 Swap Bodies", inplace = True)
freq_current.replace("Van 15 m3", "Van", inplace = True)
freq_current.replace("Van 22m3", "Van", inplace = True)
freq_current.replace("4 swap bodies", "2 Swap Bodies", inplace = True)

# %%
F_ = {}
for row in freq_current.index:
    key = (freq_current.loc[row, "From"], freq_current.loc[row, "To"], freq_current.loc[row, "Truck type"])
    value = freq_current.loc[row, "Frequency"]
    
    F_[key] = value
    
for target in pqt:
    if target not in F_.keys():
        F_[target] = 0

# %% [markdown]
# ## 4. Travel time (TT)
# Total transportation time from hub p ∈ H to q ∈ H

# %%
tt_file = pd.read_csv("Database/travel time.csv")
TT = {}
for row in tt_file.index:
    key = (tt_file.loc[row, "From"], tt_file.loc[row, "To"])
    value = tt_file.loc[row, "est_tt"]
    
    TT[key] = value

# %% [markdown]
# ## 5. Hub Open & Cut-off time
# - Op = Hub opened time for hub p ∈ H
# - COp  = Hub cut off time for hub p ∈ H

# %%
def transform_time(target):
    try: 
        return int(target.split(":")[0]) + int(target.split(":")[1])/60 
    except:
        return 0

# %%
'''
hub_info = pd.read_csv("Database/Hub Cutoff and Open Time.csv")
hub_info["Hub"] = hub_info.apply(lambda row: name_transform(row["Gateways"]), axis = 1)
hub_info["Cut-off"] = hub_info.apply(lambda row: transform_time(row["Cut-Off"]), axis = 1)
hub_info["Open"] = hub_info.apply(lambda row: transform_time(row["Hub-Opening-Time"]), axis = 1)
hub_info.to_csv("Database/hub_info.csv")
'''
# Out:
# '\nhub_info = pd.read_csv("Database/Hub Cutoff and Open Time.csv")\nhub_info["Hub"] = hub_info.apply(lambda row: name_transform(row["Gateways"]), axis = 1)\nhub_info["Cut-off"] = hub_info.apply(lambda row: transform_time(row["Cut-Off"]), axis = 1)\nhub_info["Open"] = hub_info.apply(lambda row: transform_time(row["Hub-Opening-Time"]), axis = 1)\nhub_info.to_csv("Database/hub_info.csv")\n'

# %%
hub_info = pd.read_csv("Database/hub_info.csv")
merged_hub_info = hub_list_used.merge(hub_info[["Hub", "Open", "Cut-off"]], left_on = "Ref_City", right_on = "Hub", how = "left")

merged_hub_info["Open"].fillna(merged_hub_info["Open"].mode().values[0], inplace = True)
merged_hub_info["Cut-off"].fillna(merged_hub_info["Cut-off"].mode().values[0], inplace = True)

O = {} # Open time
for row in merged_hub_info.index:
    key = merged_hub_info.loc[row, "Ref_City"]
    value = merged_hub_info.loc[row, "Open"]
    O[key] = value

CO = {} # Cut-off time
for row in merged_hub_info.index:
    key = merged_hub_info.loc[row, "Ref_City"]
    value = merged_hub_info.loc[row, "Cut-off"]
    CO[key] =  value

# %% [markdown]
# ## 6. Truck Capacity

# %%
C = {}
for row in truck_cap.index:
    C[truck_cap.loc[row, "Truck Type"]] = truck_cap.loc[row, "Capacity"]

# %% [markdown]
# # Start the model

# %%
model = Model("DHL")

# %% [markdown]
# # Define the variables
# Decision variables:
# - xpq = 1 if the transportation from hub p ∈ H to hub q ∈ H is direct, else 0
# - x’piq = 1 if the transportation from hub p ∈ H to hub q ∈ H has to go through i ∈ H, else 0
# - Xmk = 1 if the transportation from country m ∈ E to county k ∈ E is direct, else 0
# - X’mjk = 1 if the transportation from country m ∈ E  to county k ∈ E  has to go through country j ∈ E , else 0
# - Vpq = route capacity from hub p ∈ H to hub q ∈ H
# - Fpqt = recommended frequency of truck t ∈ T from hub p ∈ H to hub q ∈ H
# - Spq = start time of truck from hub p ∈ H to hub q ∈ H,
# - Npq = Night needed from hub p ∈ H to hub q ∈ H

# %%
x = model.addVars(pq , vtype=GRB.BINARY, name='xpq')  # Direct from hub to hub
x_ = model.addVars(piq, vtype = GRB.BINARY, name = 'x_piq')  # Indirect from hub to hub

# %%
X = model.addVars(mk , vtype=GRB.BINARY, name='Xmk')       # Direct from country to country

X_ = model.addVars(mjk,  vtype = GRB.BINARY, name = 'X_mjk') # Indirect from country to country

# %%
V=model.addVars(pq_all , vtype=GRB.INTEGER, lb=0 ,name='Vpq')   # Route capacity

F=model.addVars(pqt , vtype=GRB.INTEGER, lb=0, name='Fpqt') # Recommended Frequency

S=model.addVars(pq_all , vtype=GRB.CONTINUOUS, lb=0, name='Spq')         # Start time from hub p

N=model.addVars(pq_all , vtype=GRB.INTEGER, lb=0, name='Npq')         # Night Needed from hub p to hub q

CL = model.addVars(pq_all, vtype = GRB.INTEGER, lb = 0, name = "CLpq") # Co-loading (in) between p and q

# %%
attri_dict = {"hub_direct": x, "hub_indirect" : x_, "country_direct" : X, "country_indirect" : X_,
              "route_cap": V, "freq" : F, "start" : S, "night" : N, "Co-loading":CL}

# %% [markdown]
# # Constraints
# ## Direct or Indirect Transportation

# %%
## Please note that addConstrs is different from addConstr, we need addConstrs in here, because we are adding mroe than one constraints
model.addConstrs(((quicksum(X_[m,j,k] for j in E if (j != m) & (j != k)) == 
                   (1 - X[m,k])) for m, k in mk),
                 "Transportation can be direct or Indirect")
# Out:
# {('LT', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI', 'BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SE', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HU', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FL', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FL', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SE', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FL', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SE', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SE', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SE', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HU', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI', 'AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SE', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SE', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FL', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NL', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HU', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HU', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GB', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FL', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SE', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FL', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GB', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NL', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NL', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NL', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NL', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SE', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SE', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SE', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FL', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GB', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HU', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GB', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NL', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GB', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GB', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HU', 'BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NL', 'FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SE', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FL', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GB', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HU', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SE', 'FR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PL', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FL', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PL', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FL', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FL', 'AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FL', 'BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SE', 'BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NL', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NL', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GB', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI', 'DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GB', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'FR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GB', 'FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GB', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NL', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PL', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GB', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PL', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GB', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FL', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HU', 'AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NL', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SE', 'GB'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GB', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PL', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'GB'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PL', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NL', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SE', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PL', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NL', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PL', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HU', 'DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NL', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PL', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GB', 'BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PL', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'GB'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PL', 'FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PL', 'BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GB', 'AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PL', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FL', 'DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NL', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PL', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PL', 'AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GB', 'FR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SE', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NL', 'GB'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PL', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NL', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'GB'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GB', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SE', 'DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SE', 'FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NL', 'FR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GB', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NL', 'AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SE', 'AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PL', 'GB'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SE', 'NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'FR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PL', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'GB'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FL', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PL', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SK', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GB', 'DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PL', 'DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'DE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NL', 'DE'): <gurobi.Constr *Awaiting Model Update*>}

# %% [markdown]
# ## Linking Countries and Hubs

# %%
model.addConstrs(((quicksum(x[p,q] for p in L[m] for q in L[k]) == 
                  X[m,k]) for m, k in mk), "Linking_pq")  ## We can't use E_mjk here
model.addConstrs(((quicksum(x_[p,i,q] for p in L[m] for i in L[j] for q in L[k]) ==
                 X_[m,j,k]) for m,j,k in mjk), "Linking_piq")
# Out:
# {('LT', 'AT', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LT', 'BE', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LT', 'BG', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LT', 'CZ', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LT', 'DE', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LT', 'DK', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LT', 'ES', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LT', 'FL', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LT', 'FR', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LT', 'GB', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LT', 'GR', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LT', 'HR', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LT', 'HU', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LT', 'IE', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LT', 'LU', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LT', 'NL', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LT', 'NO', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LT', 'PL', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LT', 'PT', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LT', 'RO', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LT', 'SI', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LT', 'SK', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'AT', 'FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'BE', 'FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'CZ', 'FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'DE', 'FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'DK', 'FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'ES', 'FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'FR', 'FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'GB', 'FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'GR', 'FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'HR', 'FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'HU', 'FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'IE', 'FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'LT', 'FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'LU', 'FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'NL', 'FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'NO', 'FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'PL', 'FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'PT', 'FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'RO', 'FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'SE', 'FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'SI', 'FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'SK', 'FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'AT', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'BE', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'CZ', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'DE', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'DK', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'ES', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'FL', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'FR', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'GB', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'GR', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'HR', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'HU', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'IE', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'LT', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'LU', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'NL', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'NO', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'PL', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'RO', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'SE', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'SI', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'SK', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'AT', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'CZ', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'DE', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'DK', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'ES', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'FL', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'FR', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'GB', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'GR', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'HR', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'HU', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'IE', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'LT', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'LU', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'NL', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'NO', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'PL', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'PT', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'RO', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'SE', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'SI', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'SK', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'AT', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'BE', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'CZ', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'DE', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'DK', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'ES', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'FL', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'FR', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'GB', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'GR', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'HR', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'HU', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'IE', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'LT', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'LU', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'NL', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'NO', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'PL', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'RO', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'SE', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'SI', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'SK', 'PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'AT', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'BE', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'BG', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'CZ', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'DE', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'DK', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'ES', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'FL', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'FR', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'GB', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'GR', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'HR', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'HU', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'IE', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'LT', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'LU', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'NL', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'NO', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'PL', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'RO', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'SE', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'SK', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI', 'AT', 'BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI', 'BG', 'BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI', 'CZ', 'BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI', 'DE', 'BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI', 'DK', 'BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI', 'ES', 'BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI', 'FL', 'BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI', 'FR', 'BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI', 'GB', 'BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI', 'GR', 'BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI', 'HR', 'BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI', 'HU', 'BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI', 'IE', 'BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI', 'LT', 'BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI', 'LU', 'BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI', 'NL', 'BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI', 'NO', 'BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI', 'PL', 'BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI', 'PT', 'BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI', 'RO', 'BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI', 'SE', 'BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI', 'SK', 'BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI', 'AT', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI', 'BE', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI', 'BG', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI', 'CZ', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI', 'DE', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI', 'DK', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI', 'ES', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI', 'FL', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI', 'FR', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI', 'GB', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI', 'GR', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI', 'HR', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI', 'HU', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI', 'IE', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI', 'LT', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI', 'LU', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI', 'NL', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI', 'NO', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI', 'PT', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI', 'RO', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI', 'SE', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI', 'SK', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'AT', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'BE', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'CZ', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'DE', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'DK', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'ES', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'FL', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'FR', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'GB', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'GR', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'HR', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'HU', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'IE', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'LU', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'NL', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'NO', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'PL', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'PT', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'RO', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'SE', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'SI', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'SK', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'AT', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'BE', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'BG', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'CZ', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'DE', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'DK', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'ES', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'FL', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'FR', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'GB', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'HR', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'HU', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'IE', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'LT', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'LU', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'NL', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'NO', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'PL', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'RO', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'SE', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'SI', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'SK', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'AT', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'BE', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'BG', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'CZ', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'DE', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'DK', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'ES', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'FL', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'FR', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'GB', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'GR', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'HR', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'HU', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'IE', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'LT', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'LU', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'NL', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'NO', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'PL', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'RO', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'SE', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'SI', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'AT', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'BE', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'BG', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'CZ', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'DE', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'DK', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'ES', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'FL', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'FR', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'GB', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'GR', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'HR', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'HU', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'IE', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'LT', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'LU', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'NL', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'NO', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'PL', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'RO', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'SI', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'SK', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'AT', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'BE', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'BG', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'CZ', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'DE', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'DK', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'FL', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'FR', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'GB', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'HR', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'HU', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'IE', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'LT', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'LU', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'NL', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'NO', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'PL', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'PT', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'RO', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'SE', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'SI', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'SK', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'AT', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'BE', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'BG', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'CZ', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'DE', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'DK', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'ES', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'FL', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'FR', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'GB', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'GR', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'HR', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'HU', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'IE', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'LT', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'LU', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'NL', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'NO', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'PL', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'SE', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'SI', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'SK', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'AT', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'BG', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'CZ', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'DE', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'DK', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'ES', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'FL', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'FR', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'GB', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'GR', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'HR', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'HU', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'IE', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'LU', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'NL', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'NO', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'PL', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'PT', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'RO', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'SE', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'SI', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'SK', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'AT', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'BG', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'CZ', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'DE', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'DK', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'ES', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'FL', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'FR', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'GB', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'GR', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'HR', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'HU', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'IE', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'LT', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'LU', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'NL', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'NO', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'PL', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'PT', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'RO', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'SE', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'SK', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'BE', 'AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'CZ', 'AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'DE', 'AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'DK', 'AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'ES', 'AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'FL', 'AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'FR', 'AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'GB', 'AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'GR', 'AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'HR', 'AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'HU', 'AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'IE', 'AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'LT', 'AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'LU', 'AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'NL', 'AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'NO', 'AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'PL', 'AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'PT', 'AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'RO', 'AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'SE', 'AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'SI', 'AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'SK', 'AT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'AT', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'BE', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'BG', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'DE', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'DK', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'ES', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'FL', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'FR', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'GB', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'GR', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'HR', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'HU', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'IE', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'LU', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'NL', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'NO', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'PL', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'PT', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'RO', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'SE', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'SI', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'SK', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'AT', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'BG', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'CZ', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'DE', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'DK', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'ES', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'FL', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'FR', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'GB', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'HR', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'HU', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'IE', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'LT', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'LU', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'NL', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'NO', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'PL', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'PT', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'RO', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'SE', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'SI', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'SK', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'AT', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'BE', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'BG', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'CZ', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'DE', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'FL', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'FR', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'GB', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'GR', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'HR', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'HU', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'IE', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'LT', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'LU', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'NL', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'NO', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'PL', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'PT', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'RO', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'SE', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'SI', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'SK', 'DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'AT', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'BE', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'BG', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'CZ', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'DE', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'DK', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'FL', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'FR', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'GB', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'GR', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'HR', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'HU', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'IE', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'LU', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'NL', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'NO', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'PL', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'PT', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'RO', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'SE', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'SI', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'SK', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'AT', 'FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'BE', 'FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'BG', 'FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'DE', 'FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'DK', 'FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'ES', 'FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'FR', 'FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'GB', 'FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'GR', 'FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'HR', 'FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'HU', 'FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'IE', 'FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'LT', 'FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'LU', 'FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'NL', 'FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'NO', 'FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'PL', 'FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'PT', 'FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'RO', 'FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'SE', 'FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'SI', 'FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'SK', 'FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'AT', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'BG', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'CZ', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'DE', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'DK', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'ES', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'FL', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'FR', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'GB', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'GR', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'HU', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'IE', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'LT', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'LU', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'NL', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'NO', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'PL', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'PT', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'RO', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'SE', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'SI', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'SK', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SE', 'AT', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SE', 'BE', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SE', 'CZ', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SE', 'DE', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SE', 'DK', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SE', 'ES', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SE', 'FL', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SE', 'FR', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SE', 'GB', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SE', 'GR', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SE', 'HR', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SE', 'HU', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SE', 'IE', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SE', 'LT', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SE', 'LU', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SE', 'NL', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SE', 'NO', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SE', 'PL', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SE', 'PT', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SE', 'RO', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SE', 'SI', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SE', 'SK', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'AT', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'BE', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'BG', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'CZ', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'DE', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'DK', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'ES', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'FL', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'FR', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'GB', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'GR', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'HR', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'IE', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'LT', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'LU', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'NL', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'NO', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'PL', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'RO', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'SE', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'SI', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'SK', 'HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'AT', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'BE', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'BG', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'CZ', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'DK', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'ES', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'FL', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'FR', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'GB', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'GR', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'HR', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'HU', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'IE', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'LU', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'NL', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'NO', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'PL', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'PT', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'RO', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'SE', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'SI', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'SK', 'LT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'AT', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'BE', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'BG', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'CZ', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'DE', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'DK', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'ES', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'FL', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'FR', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'GB', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'GR', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'HR', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'HU', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'IE', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'LT', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'NL', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'NO', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'PL', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'RO', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'SE', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'SI', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'SK', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'AT', 'NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'BE', 'NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'BG', 'NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'CZ', 'NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'DK', 'NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'ES', 'NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'FL', 'NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'FR', 'NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'GB', 'NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'GR', 'NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'HR', 'NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'HU', 'NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'IE', 'NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'LT', 'NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'LU', 'NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'NL', 'NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'PL', 'NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'PT', 'NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'RO', 'NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'SE', 'NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'SI', 'NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'SK', 'NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'AT', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'BE', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'BG', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'CZ', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'DK', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'ES', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'FL', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'FR', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'GB', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'GR', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'HR', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'HU', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'LT', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'LU', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'NL', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'NO', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'PL', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'PT', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'RO', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'SE', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'SI', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'SK', 'IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'AT', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'BE', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'BG', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'CZ', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'DE', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'DK', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'ES', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'FL', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'FR', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'GB', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'GR', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'HU', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'IE', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'LT', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'LU', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'NL', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'NO', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'PL', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'RO', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'SE', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'SI', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'SK', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'AT', 'FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'BE', 'FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'BG', 'FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'CZ', 'FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'DE', 'FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'DK', 'FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'FR', 'FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'GB', 'FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'GR', 'FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'HR', 'FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'HU', 'FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'IE', 'FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'LT', 'FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'LU', 'FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'NL', 'FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'NO', 'FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'PL', 'FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'PT', 'FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'RO', 'FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'SE', 'FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'SI', 'FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'SK', 'FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'AT', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'BG', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'CZ', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'DE', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'DK', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'ES', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'FL', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'FR', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'GB', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'GR', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'HR', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'HU', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'IE', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'LT', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'LU', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'NL', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'NO', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'PL', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'PT', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'RO', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'SE', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'SI', 'SK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HU', 'AT', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HU', 'BE', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HU', 'BG', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HU', 'CZ', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HU', 'DE', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HU', 'DK', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HU', 'ES', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HU', 'FL', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HU', 'FR', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HU', 'GB', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HU', 'GR', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HU', 'HR', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HU', 'IE', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HU', 'LT', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HU', 'NL', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HU', 'NO', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HU', 'PL', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HU', 'PT', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HU', 'RO', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HU', 'SE', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HU', 'SI', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HU', 'SK', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FL', 'AT', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FL', 'BE', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FL', 'CZ', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FL', 'DE', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FL', 'DK', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FL', 'ES', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FL', 'FR', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FL', 'GB', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FL', 'GR', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FL', 'HR', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FL', 'HU', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FL', 'IE', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FL', 'LT', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FL', 'LU', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FL', 'NL', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FL', 'NO', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FL', 'PL', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FL', 'PT', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FL', 'RO', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FL', 'SE', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FL', 'SI', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FL', 'SK', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'AT', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'BE', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'CZ', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'DE', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'DK', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'FL', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'FR', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'GB', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'GR', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'HR', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'HU', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'IE', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'LT', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'LU', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'NL', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'NO', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'PL', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'PT', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'RO', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'SE', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'SI', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'SK', 'ES'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'AT', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'BE', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'BG', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'DE', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'DK', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'ES', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'FL', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'FR', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'GB', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'GR', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'HR', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'HU', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'IE', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'LT', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'LU', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'NL', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'NO', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'PL', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'RO', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'SE', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'SI', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'SK', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'AT', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'BE', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'BG', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'CZ', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'DK', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'ES', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'FL', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'FR', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'GB', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'HR', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'HU', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'IE', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'LT', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'LU', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'NL', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'NO', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'PL', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'PT', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'RO', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'SE', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'SI', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'SK', 'GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'AT', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'BE', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'CZ', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'DE', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'DK', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'FL', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'FR', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'GB', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'GR', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'HR', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'HU', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'IE', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'LT', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'LU', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'NL', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'NO', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'PL', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'PT', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'RO', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'SE', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'SI', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'SK', 'BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'AT', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'BE', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'BG', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'CZ', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'DE', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'DK', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'ES', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'FL', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'FR', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'GB', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'GR', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'HR', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'HU', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'IE', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'LT', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'LU', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'NL', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'NO', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'RO', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'SE', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'SI', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'SK', 'PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FL', 'AT', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FL', 'BE', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FL', 'BG', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FL', 'CZ', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FL', 'DE', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FL', 'DK', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FL', 'ES', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FL', 'FR', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FL', 'GB', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FL', 'GR', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FL', 'HR', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FL', 'HU', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FL', 'IE', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FL', 'LT', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FL', 'LU', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FL', 'NL', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FL', 'NO', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FL', 'PL', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FL', 'PT', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FL', 'RO', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FL', 'SE', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FL', 'SK', 'SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'AT', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'BG', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'DE', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'DK', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'ES', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'FL', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'FR', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'GB', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'GR', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'HR', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'HU', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'IE', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'LT', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'LU', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'NL', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'NO', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'PL', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'PT', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'RO', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'SE', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'SI', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE', 'SK', 'CZ'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'AT', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'BE', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'BG', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'CZ', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'DK', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'ES', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'FL', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'FR', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'GB', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'GR', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'HU', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'IE', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'LT', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'LU', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'NL', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'NO', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'PL', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'PT', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'RO', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'SE', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'SI', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE', 'SK', 'HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'AT', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'BE', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'BG', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'DE', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'DK', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'ES', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'FL', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'FR', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'GB', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'GR', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'HR', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'HU', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'IE', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'LT', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'LU', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'NL', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'NO', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'PL', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'PT', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'RO', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'SI', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'SK', 'SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'AT', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'BE', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'BG', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'CZ', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'DE', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'DK', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'FL', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'FR', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'GB', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'GR', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'HR', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'HU', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'IE', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'LT', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'NL', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'NO', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'PL', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'PT', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'RO', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'SE', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'SI', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'SK', 'LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI', 'AT', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI', 'BE', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI', 'BG', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI', 'CZ', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI', 'DE', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI', 'DK', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI', 'ES', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI', 'FL', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI', 'FR', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI', 'GB', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI', 'GR', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI', 'HR', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI', 'HU', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI', 'IE', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI', 'LT', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI', 'LU', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI', 'NO', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI', 'PL', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI', 'PT', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI', 'RO', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI', 'SE', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI', 'SK', 'NL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SE', 'AT', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SE', 'BE', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SE', 'BG', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SE', 'CZ', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SE', 'DE', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SE', 'DK', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SE', 'ES', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SE', 'FL', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SE', 'FR', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SE', 'GB', 'RO'): <gurobi.Constr *Awaiting Model Update*>,
#  ...}

# %% [markdown]
# ## Truck Capacity

# %%
mj_k = [(m, j) for m, j, k in mjk if (m,j) not in mk]   # m connects to j exlcudes k (transit countries)
j_mk = [(j, k) for m, j, k in mjk if (j,k) not in mk]   # j excludes m (transit countries), connects to k

#len(j_mk) + len(mj_k) + len(mk) #- len(mjk)

# %%
# V = monthly demand of the route
# For the countries of p, q are in mk
model.addConstrs(((V[p,q] ==  
                 quicksum(x_[p,q,i] * Z[m,j] for m, k, j in mjk.select(m, k, "*") for i in L[j]) +
                 quicksum(x_[i,p,q] * Z[j,k] for j, m, k in mjk.select("*", m, k) for i in L[j]) + 
                 x[p,q] * Z[m,k])
                 for m, k in mk for p in L[m] for q in L[k]), "Truck Capacity")

# For the countries of p are in the origin, q are not in the destination:
model.addConstrs((V[p,q] ==  
                 quicksum(x_[p,q,i] * Z[m,j] for m, k, j in mjk.select(m, k, "*") for i in L[j])
                 for m, k in mj_k for p in L[m] for q in L[k]), "Truck Capacity")
                 
# For the countries of p are not in the origin, q are in the destination:           
model.addConstrs((V[p,q] ==  
                 quicksum(x_[i,p,q] * Z[j,k] for j, m, k in mjk.select("*", m, k) for i in L[j]) 
                 for m, k in j_mk for p in L[m] for q in L[k]), "Truck Capacity")
# Out:
# {('AT',
#   'GR',
#   'Hub Wien I-AT',
#   'Spata-GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'GR',
#   'Hub Wien II-AT',
#   'Spata-GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'GR',
#   'Hub Graz-AT',
#   'Spata-GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'GR',
#   'Hagenbrunn-AT',
#   'Spata-GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'GR',
#   'Allhaming-AT',
#   'Spata-GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'GR', 'Enns-AT', 'Spata-GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'GR',
#   'Wernberg-AT',
#   'Spata-GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'GR', 'Wals-AT', 'Spata-GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'GR',
#   'Hall in Tirol-AT',
#   'Spata-GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'GR',
#   'Liesing-AT',
#   'Spata-GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'GR',
#   'Wundschuh-AT',
#   'Spata-GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'GR', 'Sofia-BG', 'Spata-GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'GR', 'Brno-CZ', 'Spata-GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'GR',
#   'Ostrava-CZ',
#   'Spata-GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'GR',
#   'Krupka 1-CZ',
#   'Spata-GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'GR',
#   'Plzen 1-CZ',
#   'Spata-GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'GR',
#   'Hradec Kralove - Brezhrad-CZ',
#   'Spata-GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'GR',
#   'Ricany -CZ',
#   'Spata-GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'GR', 'Zlin-CZ', 'Spata-GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'GR',
#   'Olomouc-CZ',
#   'Spata-GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK',
#   'GR',
#   'Kolding-DK',
#   'Spata-GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FL',
#   'GR',
#   'Lieto (Turku)-FL',
#   'Spata-GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FL',
#   'GR',
#   'Vantaa (Helsinki)-FL',
#   'Spata-GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FR',
#   'GR',
#   'Combs la ville-FR',
#   'Spata-GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HR',
#   'GR',
#   'Zagreb-HR',
#   'Spata-GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HU',
#   'GR',
#   'Budapest OLK-HU',
#   'Spata-GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HU',
#   'GR',
#   'Budapest NPKK (OE)-HU',
#   'Spata-GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('IE',
#   'GR',
#   'Portlaoise-IE',
#   'Spata-GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('IE',
#   'GR',
#   'Dublin-IE',
#   'Spata-GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LT',
#   'GR',
#   'Kaunas-LT',
#   'Spata-GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LU',
#   'GR',
#   'Bettembourg-LU',
#   'Spata-GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NO', 'GR', 'Oslo-NO', 'Spata-GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PL',
#   'GR',
#   'Suwałki (Ełk)-PL',
#   'Spata-GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PL',
#   'GR',
#   'Poznań-PL',
#   'Spata-GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PL',
#   'GR',
#   'Zabrze-PL',
#   'Spata-GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PL',
#   'GR',
#   'Koninko-PL',
#   'Spata-GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PL',
#   'GR',
#   'Wrocław-PL',
#   'Spata-GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PL',
#   'GR',
#   'Bydgoszcz (Solec Kujawski)-PL',
#   'Spata-GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('RO',
#   'GR',
#   'Oradea-RO',
#   'Spata-GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SE',
#   'GR',
#   'Göteborg-SE',
#   'Spata-GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SE',
#   'GR',
#   'Stockholm - Västberga-SE',
#   'Spata-GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SE',
#   'GR',
#   'Helsingborg-SE',
#   'Spata-GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SE', 'GR', 'Arlöv-SE', 'Spata-GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SE', 'GR', 'Malmö-SE', 'Spata-GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI',
#   'GR',
#   'Ljubljana-SI',
#   'Spata-GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SK',
#   'GR',
#   'Zilina- Strecno-SK',
#   'Spata-GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SK',
#   'GR',
#   'Ivanka pri Dunaji-SK',
#   'Spata-GR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'HR',
#   'Hub Wien I-AT',
#   'Zagreb-HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'HR',
#   'Hub Wien II-AT',
#   'Zagreb-HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'HR',
#   'Hub Graz-AT',
#   'Zagreb-HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'HR',
#   'Hagenbrunn-AT',
#   'Zagreb-HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'HR',
#   'Allhaming-AT',
#   'Zagreb-HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'HR', 'Enns-AT', 'Zagreb-HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'HR',
#   'Wernberg-AT',
#   'Zagreb-HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'HR', 'Wals-AT', 'Zagreb-HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'HR',
#   'Hall in Tirol-AT',
#   'Zagreb-HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'HR',
#   'Liesing-AT',
#   'Zagreb-HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'HR',
#   'Wundschuh-AT',
#   'Zagreb-HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'HR',
#   'Sofia-BG',
#   'Zagreb-HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'HR', 'Brno-CZ', 'Zagreb-HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'HR',
#   'Ostrava-CZ',
#   'Zagreb-HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'HR',
#   'Krupka 1-CZ',
#   'Zagreb-HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'HR',
#   'Plzen 1-CZ',
#   'Zagreb-HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'HR',
#   'Hradec Kralove - Brezhrad-CZ',
#   'Zagreb-HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'HR',
#   'Ricany -CZ',
#   'Zagreb-HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'HR', 'Zlin-CZ', 'Zagreb-HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'HR',
#   'Olomouc-CZ',
#   'Zagreb-HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK',
#   'HR',
#   'Kolding-DK',
#   'Zagreb-HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FL',
#   'HR',
#   'Lieto (Turku)-FL',
#   'Zagreb-HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FL',
#   'HR',
#   'Vantaa (Helsinki)-FL',
#   'Zagreb-HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FR',
#   'HR',
#   'Combs la ville-FR',
#   'Zagreb-HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GR',
#   'HR',
#   'Spata-GR',
#   'Zagreb-HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HU',
#   'HR',
#   'Budapest OLK-HU',
#   'Zagreb-HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HU',
#   'HR',
#   'Budapest NPKK (OE)-HU',
#   'Zagreb-HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('IE',
#   'HR',
#   'Portlaoise-IE',
#   'Zagreb-HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('IE',
#   'HR',
#   'Dublin-IE',
#   'Zagreb-HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LT',
#   'HR',
#   'Kaunas-LT',
#   'Zagreb-HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LU',
#   'HR',
#   'Bettembourg-LU',
#   'Zagreb-HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NO', 'HR', 'Oslo-NO', 'Zagreb-HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('RO',
#   'HR',
#   'Oradea-RO',
#   'Zagreb-HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI',
#   'HR',
#   'Ljubljana-SI',
#   'Zagreb-HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SK',
#   'HR',
#   'Zilina- Strecno-SK',
#   'Zagreb-HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SK',
#   'HR',
#   'Ivanka pri Dunaji-SK',
#   'Zagreb-HR'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'LU',
#   'Hub Wien I-AT',
#   'Bettembourg-LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'LU',
#   'Hub Wien II-AT',
#   'Bettembourg-LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'LU',
#   'Hub Graz-AT',
#   'Bettembourg-LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'LU',
#   'Hagenbrunn-AT',
#   'Bettembourg-LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'LU',
#   'Allhaming-AT',
#   'Bettembourg-LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'LU',
#   'Enns-AT',
#   'Bettembourg-LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'LU',
#   'Wernberg-AT',
#   'Bettembourg-LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'LU',
#   'Wals-AT',
#   'Bettembourg-LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'LU',
#   'Hall in Tirol-AT',
#   'Bettembourg-LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'LU',
#   'Liesing-AT',
#   'Bettembourg-LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'LU',
#   'Wundschuh-AT',
#   'Bettembourg-LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'LU',
#   'Brüssel-BE',
#   'Bettembourg-LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'LU',
#   'Sofia-BG',
#   'Bettembourg-LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'LU',
#   'Brno-CZ',
#   'Bettembourg-LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'LU',
#   'Ostrava-CZ',
#   'Bettembourg-LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'LU',
#   'Krupka 1-CZ',
#   'Bettembourg-LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'LU',
#   'Plzen 1-CZ',
#   'Bettembourg-LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'LU',
#   'Hradec Kralove - Brezhrad-CZ',
#   'Bettembourg-LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'LU',
#   'Ricany -CZ',
#   'Bettembourg-LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'LU',
#   'Zlin-CZ',
#   'Bettembourg-LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'LU',
#   'Olomouc-CZ',
#   'Bettembourg-LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK',
#   'LU',
#   'Kolding-DK',
#   'Bettembourg-LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FR',
#   'LU',
#   'Combs la ville-FR',
#   'Bettembourg-LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GR',
#   'LU',
#   'Spata-GR',
#   'Bettembourg-LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HR',
#   'LU',
#   'Zagreb-HR',
#   'Bettembourg-LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('IE',
#   'LU',
#   'Portlaoise-IE',
#   'Bettembourg-LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('IE',
#   'LU',
#   'Dublin-IE',
#   'Bettembourg-LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LT',
#   'LU',
#   'Kaunas-LT',
#   'Bettembourg-LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NL',
#   'LU',
#   'Eindhoven-Noord-NL',
#   'Bettembourg-LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NL',
#   'LU',
#   'Zaltbommel-NL',
#   'Bettembourg-LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NO',
#   'LU',
#   'Oslo-NO',
#   'Bettembourg-LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('RO',
#   'LU',
#   'Oradea-RO',
#   'Bettembourg-LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI',
#   'LU',
#   'Ljubljana-SI',
#   'Bettembourg-LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SK',
#   'LU',
#   'Zilina- Strecno-SK',
#   'Bettembourg-LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SK',
#   'LU',
#   'Ivanka pri Dunaji-SK',
#   'Bettembourg-LU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SE',
#   'Hub Wien I-AT',
#   'Göteborg-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SE',
#   'Hub Wien I-AT',
#   'Stockholm - Västberga-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SE',
#   'Hub Wien I-AT',
#   'Helsingborg-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SE',
#   'Hub Wien I-AT',
#   'Arlöv-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SE',
#   'Hub Wien I-AT',
#   'Malmö-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SE',
#   'Hub Wien II-AT',
#   'Göteborg-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SE',
#   'Hub Wien II-AT',
#   'Stockholm - Västberga-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SE',
#   'Hub Wien II-AT',
#   'Helsingborg-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SE',
#   'Hub Wien II-AT',
#   'Arlöv-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SE',
#   'Hub Wien II-AT',
#   'Malmö-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SE',
#   'Hub Graz-AT',
#   'Göteborg-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SE',
#   'Hub Graz-AT',
#   'Stockholm - Västberga-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SE',
#   'Hub Graz-AT',
#   'Helsingborg-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SE',
#   'Hub Graz-AT',
#   'Arlöv-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SE',
#   'Hub Graz-AT',
#   'Malmö-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SE',
#   'Hagenbrunn-AT',
#   'Göteborg-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SE',
#   'Hagenbrunn-AT',
#   'Stockholm - Västberga-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SE',
#   'Hagenbrunn-AT',
#   'Helsingborg-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SE',
#   'Hagenbrunn-AT',
#   'Arlöv-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SE',
#   'Hagenbrunn-AT',
#   'Malmö-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SE',
#   'Allhaming-AT',
#   'Göteborg-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SE',
#   'Allhaming-AT',
#   'Stockholm - Västberga-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SE',
#   'Allhaming-AT',
#   'Helsingborg-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SE',
#   'Allhaming-AT',
#   'Arlöv-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SE',
#   'Allhaming-AT',
#   'Malmö-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SE',
#   'Enns-AT',
#   'Göteborg-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SE',
#   'Enns-AT',
#   'Stockholm - Västberga-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SE',
#   'Enns-AT',
#   'Helsingborg-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'SE', 'Enns-AT', 'Arlöv-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'SE', 'Enns-AT', 'Malmö-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SE',
#   'Wernberg-AT',
#   'Göteborg-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SE',
#   'Wernberg-AT',
#   'Stockholm - Västberga-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SE',
#   'Wernberg-AT',
#   'Helsingborg-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SE',
#   'Wernberg-AT',
#   'Arlöv-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SE',
#   'Wernberg-AT',
#   'Malmö-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SE',
#   'Wals-AT',
#   'Göteborg-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SE',
#   'Wals-AT',
#   'Stockholm - Västberga-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SE',
#   'Wals-AT',
#   'Helsingborg-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'SE', 'Wals-AT', 'Arlöv-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'SE', 'Wals-AT', 'Malmö-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SE',
#   'Hall in Tirol-AT',
#   'Göteborg-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SE',
#   'Hall in Tirol-AT',
#   'Stockholm - Västberga-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SE',
#   'Hall in Tirol-AT',
#   'Helsingborg-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SE',
#   'Hall in Tirol-AT',
#   'Arlöv-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SE',
#   'Hall in Tirol-AT',
#   'Malmö-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SE',
#   'Liesing-AT',
#   'Göteborg-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SE',
#   'Liesing-AT',
#   'Stockholm - Västberga-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SE',
#   'Liesing-AT',
#   'Helsingborg-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SE',
#   'Liesing-AT',
#   'Arlöv-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SE',
#   'Liesing-AT',
#   'Malmö-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SE',
#   'Wundschuh-AT',
#   'Göteborg-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SE',
#   'Wundschuh-AT',
#   'Stockholm - Västberga-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SE',
#   'Wundschuh-AT',
#   'Helsingborg-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SE',
#   'Wundschuh-AT',
#   'Arlöv-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SE',
#   'Wundschuh-AT',
#   'Malmö-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'SE',
#   'Sofia-BG',
#   'Göteborg-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'SE',
#   'Sofia-BG',
#   'Stockholm - Västberga-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'SE',
#   'Sofia-BG',
#   'Helsingborg-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'SE', 'Sofia-BG', 'Arlöv-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'SE', 'Sofia-BG', 'Malmö-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK',
#   'SE',
#   'Kolding-DK',
#   'Göteborg-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK',
#   'SE',
#   'Kolding-DK',
#   'Stockholm - Västberga-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK',
#   'SE',
#   'Kolding-DK',
#   'Helsingborg-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK',
#   'SE',
#   'Kolding-DK',
#   'Arlöv-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK',
#   'SE',
#   'Kolding-DK',
#   'Malmö-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FR',
#   'SE',
#   'Combs la ville-FR',
#   'Göteborg-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FR',
#   'SE',
#   'Combs la ville-FR',
#   'Stockholm - Västberga-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FR',
#   'SE',
#   'Combs la ville-FR',
#   'Helsingborg-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FR',
#   'SE',
#   'Combs la ville-FR',
#   'Arlöv-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FR',
#   'SE',
#   'Combs la ville-FR',
#   'Malmö-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GB',
#   'SE',
#   'Slough-GB',
#   'Göteborg-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GB',
#   'SE',
#   'Slough-GB',
#   'Stockholm - Västberga-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GB',
#   'SE',
#   'Slough-GB',
#   'Helsingborg-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GB',
#   'SE',
#   'Slough-GB',
#   'Arlöv-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GB',
#   'SE',
#   'Slough-GB',
#   'Malmö-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GB',
#   'SE',
#   'Ryton Gateway-GB',
#   'Göteborg-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GB',
#   'SE',
#   'Ryton Gateway-GB',
#   'Stockholm - Västberga-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GB',
#   'SE',
#   'Ryton Gateway-GB',
#   'Helsingborg-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GB',
#   'SE',
#   'Ryton Gateway-GB',
#   'Arlöv-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GB',
#   'SE',
#   'Ryton Gateway-GB',
#   'Malmö-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GR',
#   'SE',
#   'Spata-GR',
#   'Göteborg-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GR',
#   'SE',
#   'Spata-GR',
#   'Stockholm - Västberga-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GR',
#   'SE',
#   'Spata-GR',
#   'Helsingborg-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GR', 'SE', 'Spata-GR', 'Arlöv-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GR', 'SE', 'Spata-GR', 'Malmö-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HR',
#   'SE',
#   'Zagreb-HR',
#   'Göteborg-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HR',
#   'SE',
#   'Zagreb-HR',
#   'Stockholm - Västberga-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HR',
#   'SE',
#   'Zagreb-HR',
#   'Helsingborg-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HR',
#   'SE',
#   'Zagreb-HR',
#   'Arlöv-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HR',
#   'SE',
#   'Zagreb-HR',
#   'Malmö-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HU',
#   'SE',
#   'Budapest OLK-HU',
#   'Göteborg-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HU',
#   'SE',
#   'Budapest OLK-HU',
#   'Stockholm - Västberga-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HU',
#   'SE',
#   'Budapest OLK-HU',
#   'Helsingborg-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HU',
#   'SE',
#   'Budapest OLK-HU',
#   'Arlöv-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HU',
#   'SE',
#   'Budapest OLK-HU',
#   'Malmö-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HU',
#   'SE',
#   'Budapest NPKK (OE)-HU',
#   'Göteborg-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HU',
#   'SE',
#   'Budapest NPKK (OE)-HU',
#   'Stockholm - Västberga-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HU',
#   'SE',
#   'Budapest NPKK (OE)-HU',
#   'Helsingborg-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HU',
#   'SE',
#   'Budapest NPKK (OE)-HU',
#   'Arlöv-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HU',
#   'SE',
#   'Budapest NPKK (OE)-HU',
#   'Malmö-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('IE',
#   'SE',
#   'Portlaoise-IE',
#   'Göteborg-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('IE',
#   'SE',
#   'Portlaoise-IE',
#   'Stockholm - Västberga-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('IE',
#   'SE',
#   'Portlaoise-IE',
#   'Helsingborg-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('IE',
#   'SE',
#   'Portlaoise-IE',
#   'Arlöv-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('IE',
#   'SE',
#   'Portlaoise-IE',
#   'Malmö-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('IE',
#   'SE',
#   'Dublin-IE',
#   'Göteborg-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('IE',
#   'SE',
#   'Dublin-IE',
#   'Stockholm - Västberga-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('IE',
#   'SE',
#   'Dublin-IE',
#   'Helsingborg-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('IE',
#   'SE',
#   'Dublin-IE',
#   'Arlöv-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('IE',
#   'SE',
#   'Dublin-IE',
#   'Malmö-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LU',
#   'SE',
#   'Bettembourg-LU',
#   'Göteborg-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LU',
#   'SE',
#   'Bettembourg-LU',
#   'Stockholm - Västberga-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LU',
#   'SE',
#   'Bettembourg-LU',
#   'Helsingborg-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LU',
#   'SE',
#   'Bettembourg-LU',
#   'Arlöv-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LU',
#   'SE',
#   'Bettembourg-LU',
#   'Malmö-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NO',
#   'SE',
#   'Oslo-NO',
#   'Göteborg-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NO',
#   'SE',
#   'Oslo-NO',
#   'Stockholm - Västberga-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NO',
#   'SE',
#   'Oslo-NO',
#   'Helsingborg-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NO', 'SE', 'Oslo-NO', 'Arlöv-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NO', 'SE', 'Oslo-NO', 'Malmö-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('RO',
#   'SE',
#   'Oradea-RO',
#   'Göteborg-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('RO',
#   'SE',
#   'Oradea-RO',
#   'Stockholm - Västberga-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('RO',
#   'SE',
#   'Oradea-RO',
#   'Helsingborg-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('RO',
#   'SE',
#   'Oradea-RO',
#   'Arlöv-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('RO',
#   'SE',
#   'Oradea-RO',
#   'Malmö-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI',
#   'SE',
#   'Ljubljana-SI',
#   'Göteborg-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI',
#   'SE',
#   'Ljubljana-SI',
#   'Stockholm - Västberga-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI',
#   'SE',
#   'Ljubljana-SI',
#   'Helsingborg-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI',
#   'SE',
#   'Ljubljana-SI',
#   'Arlöv-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI',
#   'SE',
#   'Ljubljana-SI',
#   'Malmö-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SK',
#   'SE',
#   'Zilina- Strecno-SK',
#   'Göteborg-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SK',
#   'SE',
#   'Zilina- Strecno-SK',
#   'Stockholm - Västberga-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SK',
#   'SE',
#   'Zilina- Strecno-SK',
#   'Helsingborg-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SK',
#   'SE',
#   'Zilina- Strecno-SK',
#   'Arlöv-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SK',
#   'SE',
#   'Zilina- Strecno-SK',
#   'Malmö-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SK',
#   'SE',
#   'Ivanka pri Dunaji-SK',
#   'Göteborg-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SK',
#   'SE',
#   'Ivanka pri Dunaji-SK',
#   'Stockholm - Västberga-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SK',
#   'SE',
#   'Ivanka pri Dunaji-SK',
#   'Helsingborg-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SK',
#   'SE',
#   'Ivanka pri Dunaji-SK',
#   'Arlöv-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SK',
#   'SE',
#   'Ivanka pri Dunaji-SK',
#   'Malmö-SE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'FL',
#   'Hub Wien I-AT',
#   'Lieto (Turku)-FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'FL',
#   'Hub Wien I-AT',
#   'Vantaa (Helsinki)-FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'FL',
#   'Hub Wien II-AT',
#   'Lieto (Turku)-FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'FL',
#   'Hub Wien II-AT',
#   'Vantaa (Helsinki)-FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'FL',
#   'Hub Graz-AT',
#   'Lieto (Turku)-FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'FL',
#   'Hub Graz-AT',
#   'Vantaa (Helsinki)-FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'FL',
#   'Hagenbrunn-AT',
#   'Lieto (Turku)-FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'FL',
#   'Hagenbrunn-AT',
#   'Vantaa (Helsinki)-FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'FL',
#   'Allhaming-AT',
#   'Lieto (Turku)-FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'FL',
#   'Allhaming-AT',
#   'Vantaa (Helsinki)-FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'FL',
#   'Enns-AT',
#   'Lieto (Turku)-FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'FL',
#   'Enns-AT',
#   'Vantaa (Helsinki)-FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'FL',
#   'Wernberg-AT',
#   'Lieto (Turku)-FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'FL',
#   'Wernberg-AT',
#   'Vantaa (Helsinki)-FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'FL',
#   'Wals-AT',
#   'Lieto (Turku)-FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'FL',
#   'Wals-AT',
#   'Vantaa (Helsinki)-FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'FL',
#   'Hall in Tirol-AT',
#   'Lieto (Turku)-FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'FL',
#   'Hall in Tirol-AT',
#   'Vantaa (Helsinki)-FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'FL',
#   'Liesing-AT',
#   'Lieto (Turku)-FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'FL',
#   'Liesing-AT',
#   'Vantaa (Helsinki)-FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'FL',
#   'Wundschuh-AT',
#   'Lieto (Turku)-FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'FL',
#   'Wundschuh-AT',
#   'Vantaa (Helsinki)-FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'FL',
#   'PZ 67 (Speyer)-DE',
#   'Lieto (Turku)-FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'FL',
#   'PZ 67 (Speyer)-DE',
#   'Vantaa (Helsinki)-FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'FL',
#   'PZ 50 (Köln)-DE',
#   'Lieto (Turku)-FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'FL',
#   'PZ 50 (Köln)-DE',
#   'Vantaa (Helsinki)-FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'FL',
#   'PZ 04 (Radefeld/Leipzig)-DE',
#   'Lieto (Turku)-FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'FL',
#   'PZ 04 (Radefeld/Leipzig)-DE',
#   'Vantaa (Helsinki)-FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'FL',
#   'PZ 90 (Feucht/Nürnberg)-DE',
#   'Lieto (Turku)-FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'FL',
#   'PZ 90 (Feucht/Nürnberg)-DE',
#   'Vantaa (Helsinki)-FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'FL',
#   'PZ 77 (Lahr)-DE',
#   'Lieto (Turku)-FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'FL',
#   'PZ 77 (Lahr)-DE',
#   'Vantaa (Helsinki)-FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'FL',
#   'PZ 93 (Regensburg)-DE',
#   'Lieto (Turku)-FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'FL',
#   'PZ 93 (Regensburg)-DE',
#   'Vantaa (Helsinki)-FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'FL',
#   'PZ 21 (Hamburg)-DE',
#   'Lieto (Turku)-FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'FL',
#   'PZ 21 (Hamburg)-DE',
#   'Vantaa (Helsinki)-FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'FL',
#   'PZ 46 (Dorsten)-DE',
#   'Lieto (Turku)-FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'FL',
#   'PZ 46 (Dorsten)-DE',
#   'Vantaa (Helsinki)-FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'FL',
#   'PZ 58 (Hagen)-DE',
#   'Lieto (Turku)-FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'FL',
#   'PZ 58 (Hagen)-DE',
#   'Vantaa (Helsinki)-FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'FL',
#   'PZ 08 (Neumark)-DE',
#   'Lieto (Turku)-FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'FL',
#   'PZ 08 (Neumark)-DE',
#   'Vantaa (Helsinki)-FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'FL',
#   'PZ 47 (Krefeld)-DE',
#   'Lieto (Turku)-FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'FL',
#   'PZ 47 (Krefeld)-DE',
#   'Vantaa (Helsinki)-FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'FL',
#   'PZ 15 (Rüdersdorf)-DE',
#   'Lieto (Turku)-FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'FL',
#   'PZ 15 (Rüdersdorf)-DE',
#   'Vantaa (Helsinki)-FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'FL',
#   'PZ 24 (Neumünster)-DE',
#   'Lieto (Turku)-FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'FL',
#   'PZ 24 (Neumünster)-DE',
#   'Vantaa (Helsinki)-FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'FL',
#   'PZ 44 (Bochum) [im Bau]-DE',
#   'Lieto (Turku)-FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DE',
#   'FL',
#   'PZ 44 (Bochum) [im Bau]-DE',
#   'Vantaa (Helsinki)-FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK',
#   'FL',
#   'Kolding-DK',
#   'Lieto (Turku)-FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK',
#   'FL',
#   'Kolding-DK',
#   'Vantaa (Helsinki)-FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FR',
#   'FL',
#   'Combs la ville-FR',
#   'Lieto (Turku)-FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FR',
#   'FL',
#   'Combs la ville-FR',
#   'Vantaa (Helsinki)-FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GR',
#   'FL',
#   'Spata-GR',
#   'Lieto (Turku)-FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GR',
#   'FL',
#   'Spata-GR',
#   'Vantaa (Helsinki)-FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HR',
#   'FL',
#   'Zagreb-HR',
#   'Lieto (Turku)-FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HR',
#   'FL',
#   'Zagreb-HR',
#   'Vantaa (Helsinki)-FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HU',
#   'FL',
#   'Budapest OLK-HU',
#   'Lieto (Turku)-FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HU',
#   'FL',
#   'Budapest OLK-HU',
#   'Vantaa (Helsinki)-FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HU',
#   'FL',
#   'Budapest NPKK (OE)-HU',
#   'Lieto (Turku)-FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HU',
#   'FL',
#   'Budapest NPKK (OE)-HU',
#   'Vantaa (Helsinki)-FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('IE',
#   'FL',
#   'Portlaoise-IE',
#   'Lieto (Turku)-FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('IE',
#   'FL',
#   'Portlaoise-IE',
#   'Vantaa (Helsinki)-FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('IE',
#   'FL',
#   'Dublin-IE',
#   'Lieto (Turku)-FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('IE',
#   'FL',
#   'Dublin-IE',
#   'Vantaa (Helsinki)-FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LT',
#   'FL',
#   'Kaunas-LT',
#   'Lieto (Turku)-FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LT',
#   'FL',
#   'Kaunas-LT',
#   'Vantaa (Helsinki)-FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LU',
#   'FL',
#   'Bettembourg-LU',
#   'Lieto (Turku)-FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LU',
#   'FL',
#   'Bettembourg-LU',
#   'Vantaa (Helsinki)-FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NO',
#   'FL',
#   'Oslo-NO',
#   'Lieto (Turku)-FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NO',
#   'FL',
#   'Oslo-NO',
#   'Vantaa (Helsinki)-FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('RO',
#   'FL',
#   'Oradea-RO',
#   'Lieto (Turku)-FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('RO',
#   'FL',
#   'Oradea-RO',
#   'Vantaa (Helsinki)-FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI',
#   'FL',
#   'Ljubljana-SI',
#   'Lieto (Turku)-FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI',
#   'FL',
#   'Ljubljana-SI',
#   'Vantaa (Helsinki)-FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SK',
#   'FL',
#   'Zilina- Strecno-SK',
#   'Lieto (Turku)-FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SK',
#   'FL',
#   'Zilina- Strecno-SK',
#   'Vantaa (Helsinki)-FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SK',
#   'FL',
#   'Ivanka pri Dunaji-SK',
#   'Lieto (Turku)-FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SK',
#   'FL',
#   'Ivanka pri Dunaji-SK',
#   'Vantaa (Helsinki)-FL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'BG',
#   'Hub Wien I-AT',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'BG',
#   'Hub Wien II-AT',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'BG',
#   'Hub Graz-AT',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'BG',
#   'Hagenbrunn-AT',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'BG',
#   'Allhaming-AT',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'BG', 'Enns-AT', 'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'BG',
#   'Wernberg-AT',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'BG', 'Wals-AT', 'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'BG',
#   'Hall in Tirol-AT',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'BG',
#   'Liesing-AT',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'BG',
#   'Wundschuh-AT',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'BG', 'Brno-CZ', 'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'BG',
#   'Ostrava-CZ',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'BG',
#   'Krupka 1-CZ',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'BG',
#   'Plzen 1-CZ',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'BG',
#   'Hradec Kralove - Brezhrad-CZ',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'BG',
#   'Ricany -CZ',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'BG', 'Zlin-CZ', 'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'BG',
#   'Olomouc-CZ',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK',
#   'BG',
#   'Kolding-DK',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FR',
#   'BG',
#   'Combs la ville-FR',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GR', 'BG', 'Spata-GR', 'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HR',
#   'BG',
#   'Zagreb-HR',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HU',
#   'BG',
#   'Budapest OLK-HU',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HU',
#   'BG',
#   'Budapest NPKK (OE)-HU',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('IE',
#   'BG',
#   'Portlaoise-IE',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('IE',
#   'BG',
#   'Dublin-IE',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LT',
#   'BG',
#   'Kaunas-LT',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LU',
#   'BG',
#   'Bettembourg-LU',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NO', 'BG', 'Oslo-NO', 'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('RO',
#   'BG',
#   'Oradea-RO',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI',
#   'BG',
#   'Ljubljana-SI',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SK',
#   'BG',
#   'Zilina- Strecno-SK',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SK',
#   'BG',
#   'Ivanka pri Dunaji-SK',
#   'Sofia-BG'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'PT',
#   'Hub Wien I-AT',
#   'Lisboa-PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'PT',
#   'Hub Wien II-AT',
#   'Lisboa-PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'PT',
#   'Hub Graz-AT',
#   'Lisboa-PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'PT',
#   'Hagenbrunn-AT',
#   'Lisboa-PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'PT',
#   'Allhaming-AT',
#   'Lisboa-PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'PT', 'Enns-AT', 'Lisboa-PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'PT',
#   'Wernberg-AT',
#   'Lisboa-PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'PT', 'Wals-AT', 'Lisboa-PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'PT',
#   'Hall in Tirol-AT',
#   'Lisboa-PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'PT',
#   'Liesing-AT',
#   'Lisboa-PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'PT',
#   'Wundschuh-AT',
#   'Lisboa-PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK',
#   'PT',
#   'Kolding-DK',
#   'Lisboa-PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES',
#   'PT',
#   'Barcelona-ES',
#   'Lisboa-PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES',
#   'PT',
#   'Madrid-ES',
#   'Lisboa-PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES',
#   'PT',
#   'Araba (Vitoria)-ES',
#   'Lisboa-PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FR',
#   'PT',
#   'Combs la ville-FR',
#   'Lisboa-PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GR',
#   'PT',
#   'Spata-GR',
#   'Lisboa-PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HR',
#   'PT',
#   'Zagreb-HR',
#   'Lisboa-PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HU',
#   'PT',
#   'Budapest OLK-HU',
#   'Lisboa-PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HU',
#   'PT',
#   'Budapest NPKK (OE)-HU',
#   'Lisboa-PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('IE',
#   'PT',
#   'Portlaoise-IE',
#   'Lisboa-PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('IE',
#   'PT',
#   'Dublin-IE',
#   'Lisboa-PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LT',
#   'PT',
#   'Kaunas-LT',
#   'Lisboa-PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LU',
#   'PT',
#   'Bettembourg-LU',
#   'Lisboa-PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NO', 'PT', 'Oslo-NO', 'Lisboa-PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('RO',
#   'PT',
#   'Oradea-RO',
#   'Lisboa-PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI',
#   'PT',
#   'Ljubljana-SI',
#   'Lisboa-PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SK',
#   'PT',
#   'Zilina- Strecno-SK',
#   'Lisboa-PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SK',
#   'PT',
#   'Ivanka pri Dunaji-SK',
#   'Lisboa-PT'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SI',
#   'Hub Wien I-AT',
#   'Ljubljana-SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SI',
#   'Hub Wien II-AT',
#   'Ljubljana-SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SI',
#   'Hub Graz-AT',
#   'Ljubljana-SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SI',
#   'Hagenbrunn-AT',
#   'Ljubljana-SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SI',
#   'Allhaming-AT',
#   'Ljubljana-SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SI',
#   'Enns-AT',
#   'Ljubljana-SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SI',
#   'Wernberg-AT',
#   'Ljubljana-SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SI',
#   'Wals-AT',
#   'Ljubljana-SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SI',
#   'Hall in Tirol-AT',
#   'Ljubljana-SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SI',
#   'Liesing-AT',
#   'Ljubljana-SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'SI',
#   'Wundschuh-AT',
#   'Ljubljana-SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'SI',
#   'Sofia-BG',
#   'Ljubljana-SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SI',
#   'Brno-CZ',
#   'Ljubljana-SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SI',
#   'Ostrava-CZ',
#   'Ljubljana-SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SI',
#   'Krupka 1-CZ',
#   'Ljubljana-SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SI',
#   'Plzen 1-CZ',
#   'Ljubljana-SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SI',
#   'Hradec Kralove - Brezhrad-CZ',
#   'Ljubljana-SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SI',
#   'Ricany -CZ',
#   'Ljubljana-SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SI',
#   'Zlin-CZ',
#   'Ljubljana-SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'SI',
#   'Olomouc-CZ',
#   'Ljubljana-SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK',
#   'SI',
#   'Kolding-DK',
#   'Ljubljana-SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FR',
#   'SI',
#   'Combs la ville-FR',
#   'Ljubljana-SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GR',
#   'SI',
#   'Spata-GR',
#   'Ljubljana-SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HR',
#   'SI',
#   'Zagreb-HR',
#   'Ljubljana-SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('IE',
#   'SI',
#   'Portlaoise-IE',
#   'Ljubljana-SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('IE',
#   'SI',
#   'Dublin-IE',
#   'Ljubljana-SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LT',
#   'SI',
#   'Kaunas-LT',
#   'Ljubljana-SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LU',
#   'SI',
#   'Bettembourg-LU',
#   'Ljubljana-SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NO',
#   'SI',
#   'Oslo-NO',
#   'Ljubljana-SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('RO',
#   'SI',
#   'Oradea-RO',
#   'Ljubljana-SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SK',
#   'SI',
#   'Zilina- Strecno-SK',
#   'Ljubljana-SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SK',
#   'SI',
#   'Ivanka pri Dunaji-SK',
#   'Ljubljana-SI'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'BE',
#   'Hub Wien I-AT',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'BE',
#   'Hub Wien II-AT',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'BE',
#   'Hub Graz-AT',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'BE',
#   'Hagenbrunn-AT',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'BE',
#   'Allhaming-AT',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'BE',
#   'Enns-AT',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'BE',
#   'Wernberg-AT',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'BE',
#   'Wals-AT',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'BE',
#   'Hall in Tirol-AT',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'BE',
#   'Liesing-AT',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'BE',
#   'Wundschuh-AT',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'BE',
#   'Sofia-BG',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'BE',
#   'Brno-CZ',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'BE',
#   'Ostrava-CZ',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'BE',
#   'Krupka 1-CZ',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'BE',
#   'Plzen 1-CZ',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'BE',
#   'Hradec Kralove - Brezhrad-CZ',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'BE',
#   'Ricany -CZ',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'BE',
#   'Zlin-CZ',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'BE',
#   'Olomouc-CZ',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK',
#   'BE',
#   'Kolding-DK',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FR',
#   'BE',
#   'Combs la ville-FR',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GR',
#   'BE',
#   'Spata-GR',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HR',
#   'BE',
#   'Zagreb-HR',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('IE',
#   'BE',
#   'Portlaoise-IE',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('IE',
#   'BE',
#   'Dublin-IE',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LT',
#   'BE',
#   'Kaunas-LT',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LU',
#   'BE',
#   'Bettembourg-LU',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NL',
#   'BE',
#   'Eindhoven-Noord-NL',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NL',
#   'BE',
#   'Zaltbommel-NL',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NO',
#   'BE',
#   'Oslo-NO',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('RO',
#   'BE',
#   'Oradea-RO',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SK',
#   'BE',
#   'Zilina- Strecno-SK',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SK',
#   'BE',
#   'Ivanka pri Dunaji-SK',
#   'Brüssel-BE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'PL',
#   'Sofia-BG',
#   'Suwałki (Ełk)-PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'PL',
#   'Sofia-BG',
#   'Poznań-PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'PL',
#   'Sofia-BG',
#   'Zabrze-PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'PL',
#   'Sofia-BG',
#   'Koninko-PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'PL',
#   'Sofia-BG',
#   'Wrocław-PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'PL',
#   'Sofia-BG',
#   'Bydgoszcz (Solec Kujawski)-PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK',
#   'PL',
#   'Kolding-DK',
#   'Suwałki (Ełk)-PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK',
#   'PL',
#   'Kolding-DK',
#   'Poznań-PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK',
#   'PL',
#   'Kolding-DK',
#   'Zabrze-PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK',
#   'PL',
#   'Kolding-DK',
#   'Koninko-PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK',
#   'PL',
#   'Kolding-DK',
#   'Wrocław-PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK',
#   'PL',
#   'Kolding-DK',
#   'Bydgoszcz (Solec Kujawski)-PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FR',
#   'PL',
#   'Combs la ville-FR',
#   'Suwałki (Ełk)-PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FR',
#   'PL',
#   'Combs la ville-FR',
#   'Poznań-PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FR',
#   'PL',
#   'Combs la ville-FR',
#   'Zabrze-PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FR',
#   'PL',
#   'Combs la ville-FR',
#   'Koninko-PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FR',
#   'PL',
#   'Combs la ville-FR',
#   'Wrocław-PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FR',
#   'PL',
#   'Combs la ville-FR',
#   'Bydgoszcz (Solec Kujawski)-PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GR',
#   'PL',
#   'Spata-GR',
#   'Suwałki (Ełk)-PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GR',
#   'PL',
#   'Spata-GR',
#   'Poznań-PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GR',
#   'PL',
#   'Spata-GR',
#   'Zabrze-PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GR',
#   'PL',
#   'Spata-GR',
#   'Koninko-PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GR',
#   'PL',
#   'Spata-GR',
#   'Wrocław-PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GR',
#   'PL',
#   'Spata-GR',
#   'Bydgoszcz (Solec Kujawski)-PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HR',
#   'PL',
#   'Zagreb-HR',
#   'Suwałki (Ełk)-PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HR',
#   'PL',
#   'Zagreb-HR',
#   'Poznań-PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HR',
#   'PL',
#   'Zagreb-HR',
#   'Zabrze-PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HR',
#   'PL',
#   'Zagreb-HR',
#   'Koninko-PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HR',
#   'PL',
#   'Zagreb-HR',
#   'Wrocław-PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HR',
#   'PL',
#   'Zagreb-HR',
#   'Bydgoszcz (Solec Kujawski)-PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('IE',
#   'PL',
#   'Portlaoise-IE',
#   'Suwałki (Ełk)-PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('IE',
#   'PL',
#   'Portlaoise-IE',
#   'Poznań-PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('IE',
#   'PL',
#   'Portlaoise-IE',
#   'Zabrze-PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('IE',
#   'PL',
#   'Portlaoise-IE',
#   'Koninko-PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('IE',
#   'PL',
#   'Portlaoise-IE',
#   'Wrocław-PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('IE',
#   'PL',
#   'Portlaoise-IE',
#   'Bydgoszcz (Solec Kujawski)-PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('IE',
#   'PL',
#   'Dublin-IE',
#   'Suwałki (Ełk)-PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('IE',
#   'PL',
#   'Dublin-IE',
#   'Poznań-PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('IE',
#   'PL',
#   'Dublin-IE',
#   'Zabrze-PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('IE',
#   'PL',
#   'Dublin-IE',
#   'Koninko-PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('IE',
#   'PL',
#   'Dublin-IE',
#   'Wrocław-PL'): <gurobi.Constr *Awaiting Model Update*>,
#  ('IE',
#   'PL',
#   'Dublin-IE',
# ...
#  ('AT',
#   'DK',
#   'Wals-AT',
#   'Kolding-DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'DK',
#   'Hall in Tirol-AT',
#   'Kolding-DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'DK',
#   'Liesing-AT',
#   'Kolding-DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'DK',
#   'Wundschuh-AT',
#   'Kolding-DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'DK',
#   'Sofia-BG',
#   'Kolding-DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DK',
#   'Brno-CZ',
#   'Kolding-DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DK',
#   'Ostrava-CZ',
#   'Kolding-DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DK',
#   'Krupka 1-CZ',
#   'Kolding-DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DK',
#   'Plzen 1-CZ',
#   'Kolding-DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DK',
#   'Hradec Kralove - Brezhrad-CZ',
#   'Kolding-DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DK',
#   'Ricany -CZ',
#   'Kolding-DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DK',
#   'Zlin-CZ',
#   'Kolding-DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'DK',
#   'Olomouc-CZ',
#   'Kolding-DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FR',
#   'DK',
#   'Combs la ville-FR',
#   'Kolding-DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GR',
#   'DK',
#   'Spata-GR',
#   'Kolding-DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HR',
#   'DK',
#   'Zagreb-HR',
#   'Kolding-DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HU',
#   'DK',
#   'Budapest OLK-HU',
#   'Kolding-DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HU',
#   'DK',
#   'Budapest NPKK (OE)-HU',
#   'Kolding-DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('IE',
#   'DK',
#   'Portlaoise-IE',
#   'Kolding-DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('IE',
#   'DK',
#   'Dublin-IE',
#   'Kolding-DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LT',
#   'DK',
#   'Kaunas-LT',
#   'Kolding-DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LU',
#   'DK',
#   'Bettembourg-LU',
#   'Kolding-DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NO',
#   'DK',
#   'Oslo-NO',
#   'Kolding-DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('RO',
#   'DK',
#   'Oradea-RO',
#   'Kolding-DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI',
#   'DK',
#   'Ljubljana-SI',
#   'Kolding-DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SK',
#   'DK',
#   'Zilina- Strecno-SK',
#   'Kolding-DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SK',
#   'DK',
#   'Ivanka pri Dunaji-SK',
#   'Kolding-DK'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'HU',
#   'Hub Wien I-AT',
#   'Budapest OLK-HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'HU',
#   'Hub Wien I-AT',
#   'Budapest NPKK (OE)-HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'HU',
#   'Hub Wien II-AT',
#   'Budapest OLK-HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'HU',
#   'Hub Wien II-AT',
#   'Budapest NPKK (OE)-HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'HU',
#   'Hub Graz-AT',
#   'Budapest OLK-HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'HU',
#   'Hub Graz-AT',
#   'Budapest NPKK (OE)-HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'HU',
#   'Hagenbrunn-AT',
#   'Budapest OLK-HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'HU',
#   'Hagenbrunn-AT',
#   'Budapest NPKK (OE)-HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'HU',
#   'Allhaming-AT',
#   'Budapest OLK-HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'HU',
#   'Allhaming-AT',
#   'Budapest NPKK (OE)-HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'HU',
#   'Enns-AT',
#   'Budapest OLK-HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'HU',
#   'Enns-AT',
#   'Budapest NPKK (OE)-HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'HU',
#   'Wernberg-AT',
#   'Budapest OLK-HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'HU',
#   'Wernberg-AT',
#   'Budapest NPKK (OE)-HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'HU',
#   'Wals-AT',
#   'Budapest OLK-HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'HU',
#   'Wals-AT',
#   'Budapest NPKK (OE)-HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'HU',
#   'Hall in Tirol-AT',
#   'Budapest OLK-HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'HU',
#   'Hall in Tirol-AT',
#   'Budapest NPKK (OE)-HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'HU',
#   'Liesing-AT',
#   'Budapest OLK-HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'HU',
#   'Liesing-AT',
#   'Budapest NPKK (OE)-HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'HU',
#   'Wundschuh-AT',
#   'Budapest OLK-HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'HU',
#   'Wundschuh-AT',
#   'Budapest NPKK (OE)-HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'HU',
#   'Sofia-BG',
#   'Budapest OLK-HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'HU',
#   'Sofia-BG',
#   'Budapest NPKK (OE)-HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK',
#   'HU',
#   'Kolding-DK',
#   'Budapest OLK-HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK',
#   'HU',
#   'Kolding-DK',
#   'Budapest NPKK (OE)-HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FR',
#   'HU',
#   'Combs la ville-FR',
#   'Budapest OLK-HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FR',
#   'HU',
#   'Combs la ville-FR',
#   'Budapest NPKK (OE)-HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GR',
#   'HU',
#   'Spata-GR',
#   'Budapest OLK-HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GR',
#   'HU',
#   'Spata-GR',
#   'Budapest NPKK (OE)-HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HR',
#   'HU',
#   'Zagreb-HR',
#   'Budapest OLK-HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HR',
#   'HU',
#   'Zagreb-HR',
#   'Budapest NPKK (OE)-HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('IE',
#   'HU',
#   'Portlaoise-IE',
#   'Budapest OLK-HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('IE',
#   'HU',
#   'Portlaoise-IE',
#   'Budapest NPKK (OE)-HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('IE',
#   'HU',
#   'Dublin-IE',
#   'Budapest OLK-HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('IE',
#   'HU',
#   'Dublin-IE',
#   'Budapest NPKK (OE)-HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LT',
#   'HU',
#   'Kaunas-LT',
#   'Budapest OLK-HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LT',
#   'HU',
#   'Kaunas-LT',
#   'Budapest NPKK (OE)-HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LU',
#   'HU',
#   'Bettembourg-LU',
#   'Budapest OLK-HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LU',
#   'HU',
#   'Bettembourg-LU',
#   'Budapest NPKK (OE)-HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NO',
#   'HU',
#   'Oslo-NO',
#   'Budapest OLK-HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NO',
#   'HU',
#   'Oslo-NO',
#   'Budapest NPKK (OE)-HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('RO',
#   'HU',
#   'Oradea-RO',
#   'Budapest OLK-HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('RO',
#   'HU',
#   'Oradea-RO',
#   'Budapest NPKK (OE)-HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI',
#   'HU',
#   'Ljubljana-SI',
#   'Budapest OLK-HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI',
#   'HU',
#   'Ljubljana-SI',
#   'Budapest NPKK (OE)-HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SK',
#   'HU',
#   'Zilina- Strecno-SK',
#   'Budapest OLK-HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SK',
#   'HU',
#   'Zilina- Strecno-SK',
#   'Budapest NPKK (OE)-HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SK',
#   'HU',
#   'Ivanka pri Dunaji-SK',
#   'Budapest OLK-HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SK',
#   'HU',
#   'Ivanka pri Dunaji-SK',
#   'Budapest NPKK (OE)-HU'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'NO',
#   'Hub Wien I-AT',
#   'Oslo-NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'NO',
#   'Hub Wien II-AT',
#   'Oslo-NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'NO',
#   'Hub Graz-AT',
#   'Oslo-NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'NO',
#   'Hagenbrunn-AT',
#   'Oslo-NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'NO',
#   'Allhaming-AT',
#   'Oslo-NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'NO', 'Enns-AT', 'Oslo-NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'NO',
#   'Wernberg-AT',
#   'Oslo-NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'NO', 'Wals-AT', 'Oslo-NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'NO',
#   'Hall in Tirol-AT',
#   'Oslo-NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'NO',
#   'Liesing-AT',
#   'Oslo-NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'NO',
#   'Wundschuh-AT',
#   'Oslo-NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BE',
#   'NO',
#   'Brüssel-BE',
#   'Oslo-NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG', 'NO', 'Sofia-BG', 'Oslo-NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'NO', 'Brno-CZ', 'Oslo-NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'NO',
#   'Ostrava-CZ',
#   'Oslo-NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'NO',
#   'Krupka 1-CZ',
#   'Oslo-NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'NO',
#   'Plzen 1-CZ',
#   'Oslo-NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'NO',
#   'Hradec Kralove - Brezhrad-CZ',
#   'Oslo-NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'NO',
#   'Ricany -CZ',
#   'Oslo-NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ', 'NO', 'Zlin-CZ', 'Oslo-NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('CZ',
#   'NO',
#   'Olomouc-CZ',
#   'Oslo-NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK',
#   'NO',
#   'Kolding-DK',
#   'Oslo-NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES',
#   'NO',
#   'Barcelona-ES',
#   'Oslo-NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES', 'NO', 'Madrid-ES', 'Oslo-NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('ES',
#   'NO',
#   'Araba (Vitoria)-ES',
#   'Oslo-NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FL',
#   'NO',
#   'Lieto (Turku)-FL',
#   'Oslo-NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FL',
#   'NO',
#   'Vantaa (Helsinki)-FL',
#   'Oslo-NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FR',
#   'NO',
#   'Combs la ville-FR',
#   'Oslo-NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GB', 'NO', 'Slough-GB', 'Oslo-NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GB',
#   'NO',
#   'Ryton Gateway-GB',
#   'Oslo-NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GR', 'NO', 'Spata-GR', 'Oslo-NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HR', 'NO', 'Zagreb-HR', 'Oslo-NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HU',
#   'NO',
#   'Budapest OLK-HU',
#   'Oslo-NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HU',
#   'NO',
#   'Budapest NPKK (OE)-HU',
#   'Oslo-NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('IE',
#   'NO',
#   'Portlaoise-IE',
#   'Oslo-NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('IE', 'NO', 'Dublin-IE', 'Oslo-NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LT', 'NO', 'Kaunas-LT', 'Oslo-NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('LU',
#   'NO',
#   'Bettembourg-LU',
#   'Oslo-NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NL',
#   'NO',
#   'Eindhoven-Noord-NL',
#   'Oslo-NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('NL',
#   'NO',
#   'Zaltbommel-NL',
#   'Oslo-NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PL',
#   'NO',
#   'Suwałki (Ełk)-PL',
#   'Oslo-NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PL', 'NO', 'Poznań-PL', 'Oslo-NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PL', 'NO', 'Zabrze-PL', 'Oslo-NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PL',
#   'NO',
#   'Koninko-PL',
#   'Oslo-NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PL',
#   'NO',
#   'Wrocław-PL',
#   'Oslo-NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PL',
#   'NO',
#   'Bydgoszcz (Solec Kujawski)-PL',
#   'Oslo-NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('PT', 'NO', 'Lisboa-PT', 'Oslo-NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('RO', 'NO', 'Oradea-RO', 'Oslo-NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SI',
#   'NO',
#   'Ljubljana-SI',
#   'Oslo-NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SK',
#   'NO',
#   'Zilina- Strecno-SK',
#   'Oslo-NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('SK',
#   'NO',
#   'Ivanka pri Dunaji-SK',
#   'Oslo-NO'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'IE',
#   'Hub Wien I-AT',
#   'Portlaoise-IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'IE',
#   'Hub Wien I-AT',
#   'Dublin-IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'IE',
#   'Hub Wien II-AT',
#   'Portlaoise-IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'IE',
#   'Hub Wien II-AT',
#   'Dublin-IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'IE',
#   'Hub Graz-AT',
#   'Portlaoise-IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'IE',
#   'Hub Graz-AT',
#   'Dublin-IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'IE',
#   'Hagenbrunn-AT',
#   'Portlaoise-IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'IE',
#   'Hagenbrunn-AT',
#   'Dublin-IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'IE',
#   'Allhaming-AT',
#   'Portlaoise-IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'IE',
#   'Allhaming-AT',
#   'Dublin-IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'IE',
#   'Enns-AT',
#   'Portlaoise-IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'IE', 'Enns-AT', 'Dublin-IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'IE',
#   'Wernberg-AT',
#   'Portlaoise-IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'IE',
#   'Wernberg-AT',
#   'Dublin-IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'IE',
#   'Wals-AT',
#   'Portlaoise-IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT', 'IE', 'Wals-AT', 'Dublin-IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'IE',
#   'Hall in Tirol-AT',
#   'Portlaoise-IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'IE',
#   'Hall in Tirol-AT',
#   'Dublin-IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'IE',
#   'Liesing-AT',
#   'Portlaoise-IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'IE',
#   'Liesing-AT',
#   'Dublin-IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'IE',
#   'Wundschuh-AT',
#   'Portlaoise-IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('AT',
#   'IE',
#   'Wundschuh-AT',
#   'Dublin-IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'IE',
#   'Sofia-BG',
#   'Portlaoise-IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('BG',
#   'IE',
#   'Sofia-BG',
#   'Dublin-IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK',
#   'IE',
#   'Kolding-DK',
#   'Portlaoise-IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('DK',
#   'IE',
#   'Kolding-DK',
#   'Dublin-IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FL',
#   'IE',
#   'Lieto (Turku)-FL',
#   'Portlaoise-IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FL',
#   'IE',
#   'Lieto (Turku)-FL',
#   'Dublin-IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FL',
#   'IE',
#   'Vantaa (Helsinki)-FL',
#   'Portlaoise-IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FL',
#   'IE',
#   'Vantaa (Helsinki)-FL',
#   'Dublin-IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FR',
#   'IE',
#   'Combs la ville-FR',
#   'Portlaoise-IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('FR',
#   'IE',
#   'Combs la ville-FR',
#   'Dublin-IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GB',
#   'IE',
#   'Slough-GB',
#   'Portlaoise-IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GB',
#   'IE',
#   'Slough-GB',
#   'Dublin-IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GB',
#   'IE',
#   'Ryton Gateway-GB',
#   'Portlaoise-IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GB',
#   'IE',
#   'Ryton Gateway-GB',
#   'Dublin-IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GR',
#   'IE',
#   'Spata-GR',
#   'Portlaoise-IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('GR',
#   'IE',
#   'Spata-GR',
#   'Dublin-IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HR',
#   'IE',
#   'Zagreb-HR',
#   'Portlaoise-IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HR',
#   'IE',
#   'Zagreb-HR',
#   'Dublin-IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HU',
#   'IE',
#   'Budapest OLK-HU',
#   'Portlaoise-IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HU',
#   'IE',
#   'Budapest OLK-HU',
#   'Dublin-IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ('HU',
#   'IE',
#   'Budapest NPKK (OE)-HU',
#   'Portlaoise-IE'): <gurobi.Constr *Awaiting Model Update*>,
#  ...}

# %% [markdown]
# ## Truck type and Frequency of trucks

# %%
# transforming the weekly frequency to monthly by multiplying 4
model.addConstrs(((V[p,q] + CL[p, q]*4 <=   # Updated
                 quicksum(F[p,q,t] * C[t] * 4 for t in T) )
                 for m, k in mk for q in L[k] for p in L[m]),
                 "Truck Type and Frequency"
                )


'''
model.addConstrs(((V[p,q]*1.2 >= 
                 quicksum(F[p,q,t] * C[t] * 4 for t in T) )
                 for m in E for j in E if m != j for q in L[j] for p in L[m]),
                 "Truck Type and Frequency"
                )
'''

# Co-loading out constraints
model.addConstrs((F[p,q,"Co-loading"] <= 2000 for p,q in pq), "Coloading out constraints")
#model.addConstrs(F[p,q,"Co-loading-Extra"] <=1500 for p,q in pq)

# Co-loading in constraints
model.addConstrs((CL[p,q] <= 2000 for p,q in pq), "Coloading in constraints")
model.addConstrs((CL[p,q] <= quicksum(F[p,q,t]*C[t] for t in T)*0.3 for p, q in pq), "Coloading in constraints 2")

BigM = 9999
model.addConstrs((S[p,q] + TT[p,q] - N[p,q] * 24  <=  
                 CO[q] - 
                 BigM * (
                     1 - (x[p, q] + 
                          quicksum(x_[p, q, i] for m, k, j in mjk.select(m, k, "*") for i in L[j]) + 
                          quicksum(x_[i, p, q] for j, m, k in mjk.select("*", m, k) for i in L[j])
                 ) ) for m,k in mk for q in L[k] for p in L[m]), "Hub Cut Off Time")


BigMM = 9000

model.addConstrs((S[p,q] + TT[p,q] - N[p,q] * 24  >=  
                 O[q] -
                 BigMM * (
                     1 - (x[p, q] + 
                          quicksum(x_[p, q, i] for m, k, j in mjk.select(m, k, "*") for i in L[j]) + 
                          quicksum(x_[i, p, q] for j, m, k in mjk.select("*", m, k) for i in L[j])
                 ) ) for m,k in mk for q in L[k] for p in L[m]), "Hub Open Time")

BigMMM = 9000
model.addConstrs((S[p,q] >=  
                 O[p] - 
                 BigMMM *(
                     1 - (x[p, q] + 
                          quicksum(x_[p, q, i] for m, k, j in mjk.select(m, k, "*") for i in L[j]) + 
                          quicksum(x_[i, p, q] for j, m, k in mjk.select("*", m, k) for i in L[j])
                 ) ) for m,k in mk for q in L[k] for p in L[m]), "Hub Open Time for Departure")

# Assumption: all the excessive spaces could be loaded with co-loading opportunities in the current network
# Assumption: In the new network, all the co-loading oppottunities doesn't exist

Cost_bound = 1.05
# The tighten model (loose a bit)
model.addConstr((quicksum(F[p,q,t] * cost[p,q,t] * C[t] for p, q, t in pqt) *
                 quicksum(F_[p,q,t] * C[t] for p, q, t in pqt) <= 
                 (quicksum(F_[p,q,t] * cost[p,q,t] * C[t] for p, q, t in pqt) *
                 (quicksum(Z[m,k] for m, k in mk)/4 + quicksum(CL[p,q] for p,q in pq)) * Cost_bound))
                 , "Cost Constraint")



# Minimize the travel time for each route
model.setObjective(quicksum(x[p, q] * TT[p, q] for p, q in pq) +
                   quicksum(x_[p, i ,q] * (TT[p, i] + 9 + TT[i, q])for p, i, q in piq) # Consider the transit time in the hubs
                                                                                       # Taking 9 as an example
                   ,  GRB.MINIMIZE)


timeLimit = 8000 # In second
model.Params.TimeLimit = timeLimit - model.getAttr(GRB.Attr.Runtime)

#model.feasRelaxS(2, False, False, True)
model.optimize()
# Out:
# Changed value of parameter TimeLimit to 7891.325605392456
#    Prev: 6000.0  Min: 0.0  Max: 1e+100  Default: 1e+100
# Optimize a model with 150057 rows, 376494 columns and 3276947 nonzeros
# Variable types: 83381 continuous, 293113 integer (256681 binary)
# Coefficient statistics:
#   Matrix range     [3e-01, 8e+09]
#   Objective range  [1e+00, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+11]
# Warning: Model contains large matrix coefficients
# Warning: Model contains large rhs
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 36927 rows and 45470 columns (presolve time = 6s) ...
# Presolve removed 36925 rows and 45468 columns
# Presolve time: 7.18s
# Presolved: 113132 rows, 331026 columns, 3145544 nonzeros
# Variable types: 58347 continuous, 272679 integer (247025 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.179116e+06   0.000000e+00     13s
#    23064    6.8475477e+04   0.000000e+00   0.000000e+00     15s
#
# Root relaxation: objective 6.847548e+04, 23064 iterations, 2.27 seconds
# Total elapsed time = 15.66s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 68475.4766    0 9220          - 68475.4766      -     -   19s
#      0     0 70128.4262    0 11866          - 70128.4262      -     -   30s
#      0     0 70243.3922    0 10830          - 70243.3922      -     -   33s
#      0     0 70422.2214    0 8146          - 70422.2214      -     -   35s
#      0     0 70429.8401    0 8091          - 70429.8401      -     -   36s
#      0     0 70451.0983    0 11326          - 70451.0983      -     -   44s
#      0     0 70452.4358    0 11257          - 70452.4358      -     -   45s
#      0     0 70452.4845    0 11260          - 70452.4845      -     -   46s
#      0     0 70795.0960    0 9679          - 70795.0960      -     -   54s
#      0     0 70796.0588    0 9842          - 70796.0588      -     -   56s
#      0     0 70796.1117    0 9848          - 70796.1117      -     -   57s
#      0     0 71161.7818    0 8660          - 71161.7818      -     -   67s
#  26673 21037 71750.8660 2041  406          - 71660.1407      -  50.3 6627s
#  26885 21251 71750.8663 2052  407          - 71660.1407      -  50.9 6714s
#  27100 21480 71751.7332 2072  407          - 71660.1407      -  51.6 6817s
#  27362 21730 71751.7346 2085  406          - 71660.1407      -  52.1 6896s
#  27623 21993 71751.7358 2097  405          - 71660.1407      -  52.4 6975s
#  27884 22237 71751.7363 2110  406          - 71660.1407      -  52.6 7059s
#  28143 22511 71751.7370 2122  406          - 71660.1407      -  52.9 7141s
#  28406 22774 71751.7384 2135  405          - 71660.1407      -  53.2 7219s
#  28661 23031 71751.7387 2146  409          - 71660.1407      -  53.5 7299s
#  28920 23274 71752.7662 2158  413          - 71660.1407      -  53.8 7374s
#  29178 23544 71751.7401 2170  406          - 71660.1407      -  54.0 7444s
#  29437 23807 71751.7500 2183  413          - 71660.1407      -  54.2 7516s
#  29696 24064 71751.7417 2195  409          - 71660.1407      -  54.4 7592s
#  29953 24307 71751.7424 2207  410          - 71660.1407      -  54.6 7672s
#  30211 24579 71751.7429 2219  410          - 71660.1407      -  54.9 7746s
#  30470 24826 71751.7437 2231  412          - 71660.1407      -  55.1 7893s
#
# Cutting planes:
#   Learned: 782
#   Gomory: 496
#   Cover: 174
#   Implied bound: 8
#   MIR: 4349
#   StrongCG: 17
#   Flow cover: 5306
#   Zero half: 60
#
# Explored 30518 nodes (1737856 simplex iterations) in 7895.28 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 0
#
# Time limit reached
# Best objective -, best bound 7.166014073073e+04, gap -

# %%
def turn_to_df(Var, col_name = None):  # Here you could input the variable
    solution = model.getAttr('x_', Var)
    num_col = len(solution.keys()[0])
    collect = []
    for row in range(0, len(solution)):
        new_row = []
        for col in range(0, num_col):
            new_row.append(solution.keys()[row][col])
        new_row.append(solution[solution.keys()[row]])
    
        collect.append(new_row)
    return pd.DataFrame(collect, columns = col_name)

# %%
Hub_Indirect = turn_to_df(x_, ["Ori_Hub", "Transit_Hub","Dest_Hub", "Taken"])
Hub_Indirect[Hub_Indirect.Taken > 0 ]
# Out:
# ---------------------------------------------------------------------------
# GurobiError                               Traceback (most recent call last)
# <ipython-input-81-7736fa2f02c5> in <module>
# ----> 1 Hub_Indirect = turn_to_df(x_, ["Ori_Hub", "Transit_Hub","Dest_Hub", "Taken"])
#       2 Hub_Indirect[Hub_Indirect.Taken > 0 ]
#
# <ipython-input-80-8ffee54ee5a3> in turn_to_df(Var, col_name)
#       1 def turn_to_df(Var, col_name = None):  # Here you could input the variable
# ----> 2     solution = model.getAttr('x_', Var)
#       3     num_col = len(solution.keys()[0])
#       4     collect = []
#       5     for row in range(0, len(solution)):
#
# model.pxi in gurobipy.Model.getAttr()
#
# model.pxi in gurobipy.Model.__gettypedattrlist()
#
# GurobiError: Unable to retrieve attribute 'x_'

# %%
Country_Direct = turn_to_df(X, ["Ori_Country", "Dest_Country", "Taken"])
Country_Indirect = turn_to_df(X_, ["Ori_Country", "Transit_Country","Dest_Country", "Taken"])

Hub_Direct = turn_to_df(x, ["Ori_Hub", "Dest_Hub", "Taken"])
Hub_Indirect = turn_to_df(x_, ["Ori_Hub", "Transit_Hub","Dest_Hub", "Taken"])

Route_Cap = turn_to_df(V, ["Ori_Hub", "Dest_Hub", "Taken"])
Freq = turn_to_df(F, ["Ori_Hub", "Dest_Hub","Truck Type", "Taken"])
Start = turn_to_df(S, ["Ori_Hub", "Dest_Hub", "Time"])
Night = turn_to_df(N, ["Ori_Hub", "Dest_Hub", "Nights"])
Co_load = turn_to_df(CL, ["Ori_Hub", "Dest_Hub", "Amount"])

# %%
for key in attri_dict.keys():
    df_output = turn_to_df(attri_dict[key])
    df_output.to_csv(f"Output/{key}_output.csv")

# %%
ind = Country_Indirect.Taken.sum()
d = Country_Direct.Taken.sum()

print(f"{ind} indriect routes and {d} direct route" )

# %%
freq_result = model.getAttr('x', F)
demand_filled = model.getAttr('x', V)
print(sum(freq_result[p,q,t] * C[t] * cost[p,q,t] for p, q,t in pqt) / (sum(demand_filled[p,q] for p, q in pq)/4))
print(sum(freq_result[p,q,t] * C[t] * cost[p,q,t] for p, q,t in pqt) / (sum(freq_result[p,q,t] * C[t] for p, q,t in pqt)))
print(sum(freq_result[p,q,t] * C[t] * cost[p,q,t] for p, q,t in pqt) / (sum(Z[m, k] for m, k in mk)/4))

# %%
sum(F_[p,q,t] * C[t] * cost[p,q,t] for p, q, t in pqt) / sum(F_[p,q,t] * C[t] for p,q,t in pqt)

# %%
Freq_result = Freq[Freq.Taken > 0]
Freq_result.groupby("Truck Type").count()

# %%
Freq_result = Freq[Freq.Taken > 0]
Freq_result["agg"] = Freq_result["Ori_Hub"] + Freq_result["Dest_Hub"]
print(Freq_result.groupby("Truck Type").count()) # Truck type count per routes

Freq_result["Capacity"] = Freq_result.apply(lambda row: C[row["Truck Type"]] * row["Taken"] * 4, axis = 1)
capacity_from_freq = Freq_result.groupby(["agg"]).sum()
capacity_from_freq

# Indirect Route Overview

Hub_Indirect_T = Hub_Indirect[Hub_Indirect.Taken > 0]
Hub_Indirect_T["First"] = Hub_Indirect_T["Ori_Hub"] + Hub_Indirect_T["Transit_Hub"]
Hub_Indirect_T["Second"] = Hub_Indirect_T["Transit_Hub"] + Hub_Indirect_T["Dest_Hub"]

Hub_merge = Hub_Indirect_T.merge(capacity_from_freq.loc[:, "Capacity"], left_on = "First", right_on = "agg", how = "right")
#Hub_merge = Hub_merge.merge(capacity_from_freq.loc[:, "Capacity"], left_on = "Second", right_on = "agg", how = "right")

pd.options.display.max_rows = 100
Hub_merge.dropna()

# %%
Co_load[Co_load["Amount"] > 0]

# %% [markdown]
# ## Checking if some routes exist

# %%
solution = model.getAttr('x_', X_)
solution[("GB", "DE","FL")]

solution_dir = model.getAttr('x_', X)
solution_dir[("GB","FL")]

# %%
Z[("GB", "FL")]

# %%
Freq["Ori_C"] = Freq.apply(lambda row: row.Ori_Hub.rsplit("-")[-1], axis = 1)
Freq["Dest_C"] = Freq.apply(lambda row: row.Dest_Hub.rsplit("-")[-1], axis = 1)

# %%
Freq.loc[(Freq["Ori_C"] == "GB") & (Freq["Dest_C"] == "FL"), :]

# %%
Route_Cap["Ori_C"] = Route_Cap.apply(lambda row: row.Ori_Hub.rsplit("-")[-1], axis = 1)
Route_Cap["Dest_C"] = Route_Cap.apply(lambda row: row.Dest_Hub.rsplit("-")[-1], axis = 1)

# %%
Route_Cap.loc[(Route_Cap["Ori_C"] == "DE") & (Route_Cap["Dest_C"] == "FL"), :]
