# %%
from gurobipy import Model, GRB, quicksum, tuplelist
import numpy as np
import pandas as pd

# %%
# The following file works as a reference table to match the names of 2 sheets
hub_list = pd.read_csv('Database/Hub list.csv')
hub_list.Ref_City = hub_list.Ref_City + "-" + hub_list.Country

# drop duplicates
hub_list.drop_duplicates(subset = "Ref_City", keep='first', inplace=True)


hub_ref = {}
for row in hub_list.index:
    hub_ref[hub_list.loc[row, "City"]] = hub_list.loc[row, "Ref_City"]

    
    
def name_transform(city_name):
    if city_name in hub_ref.keys():
        return hub_ref[city_name]
    else:
        return city_name

# %%
# Simple Version
masterfile = pd.read_excel("Database/Simple/Simple Routes.xlsx", sheet_name = 0)

# Complete Version
#masterfile = pd.read_csv("Database/inter_distances.csv")

# %% [markdown]
# # Load Truck Type

# %%
truck_cap = pd.read_csv("Database/TruckVSCap.csv")
C = {}
for row in truck_cap.index:
    C[truck_cap.loc[row, "Truck Type"]] = truck_cap.loc[row, "Capacity"]

# %% [markdown]
# # Load the current network

# %%
freq_current = pd.read_csv("Database/current_network.csv")
# The following section work as a formatting part. To avoid different naming issues
freq_current.replace("trailer", "Trailer", inplace = True)
freq_current.replace("2 swap bodies", "2 Swap Bodies", inplace = True)
freq_current.replace("van", "Van", inplace = True)
freq_current.replace("1 swap body", "Swap Body", inplace = True)
freq_current.replace("SEMI TRAILER", "Swap Body", inplace = True)
freq_current.replace("Cargo 50 m3", "Swap Body", inplace = True)
freq_current.replace("Sea Container", "2 Swap Bodies", inplace = True)
freq_current.replace("Van 15 m3", "Van", inplace = True)
freq_current.replace("Van 22m3", "Van", inplace = True)
freq_current.replace("4 swap bodies", "2 Swap Bodies", inplace = True)

# %%
freq_current["Cap"] = freq_current.apply(lambda row: C[row["Truck type"]] * row.Frequency, axis = 1)
fixed_demands = freq_current.groupby(["From", "To"]).sum().reset_index()
fixed_demands["Ori_C"] = fixed_demands.apply(lambda row: row.From.rsplit("-")[-1], axis = 1)
fixed_demands["Dest_C"] = fixed_demands.apply(lambda row: row.To.rsplit("-")[-1], axis = 1)
fixed_demands = fixed_demands[fixed_demands.Cap > 75000 ]
high_demands_filled = list(zip(fixed_demands["Ori_C"],fixed_demands["Dest_C"] ))

# %%
high_demands_routes = list(zip(fixed_demands.From, fixed_demands.To))

# %% [markdown]
# # Import the forecast data

# %%
# Import forecast for creating the country set
forecast = pd.read_csv("Database/Average_Forecast.csv")
forecast.fillna(0, inplace = True)

# Only satisfied those the current network can reach
# Otherwise the solution would be infeasible

used_c = masterfile["Origin Country"].unique().tolist() +  masterfile["Destination Country"].unique().tolist() # Not every hubs in the hub list is used
used_c = list( dict.fromkeys(used_c) )  # Remove duplicate

all_c = forecast.Origin.unique().tolist() +  forecast.Destination.unique().tolist() # Not every hubs in the hub list is used
all_c = list( dict.fromkeys(all_c) )  # Remove duplicate

for x in used_c:
    try:
        all_c.remove(x)
    except:
        continue
        
for c in all_c:
    forecast["Origin"].replace(c, np.nan, inplace = True)
    forecast["Destination"].replace(c, np.nan, inplace = True)
forecast.dropna(how = "any", inplace = True)

# Remove high demands routes that is existing in the current network:
forecast["agg_tuple"] = forecast.apply(lambda row: (row["Origin"], row["Destination"]), axis = 1) 
forecast = forecast[~forecast["agg_tuple"].isin(high_demands_filled)]


# Set up the threshold for the demands
minimum_demands = 0
maximum_demands = forecast.Average.max()
forecast["Target"] = forecast.apply(lambda row: row.Average if (row.Average >= minimum_demands) and (row.Average <= maximum_demands) else 0, axis = 1)
#forecast["Target"] = forecast.apply(lambda row: row.Target if row.Target <= maximum_demands else 0, axis = 1)


forecast = forecast[forecast["Target"] > 0]
country_set = list(zip(forecast["Origin"].to_list(), forecast["Destination"].to_list()))

origin_list = list(forecast["Origin"].unique())
dst_list =  list(forecast["Destination"].unique())

country_with_forecast = forecast.Origin.unique().tolist() +  forecast.Destination.unique().tolist()
country_with_forecast = list( dict.fromkeys(country_with_forecast))  # Remove Dup
len(forecast)
# Out:
# 197

# %% [markdown]
# # Define the Set
# ## 1. Hubs in each Country (L) & All Hubs (H)

# %%
used_hubs = masterfile.From.unique().tolist() +  masterfile.To.unique().tolist() # Not every hubs in the hub list is used
used_hubs = list( dict.fromkeys(used_hubs) )  # Remove duplicate

hub_list_used = hub_list.set_index("Ref_City")
hub_list_used = hub_list_used.loc[hub_list_used.index.isin(used_hubs), :]
hub_list_used.reset_index(inplace = True)

#hub_list_used["Country"] = hub_list_used.apply(lambda row: row["Ref_City"].split("-")[-1], axis = 1) # To fill NA in country

L = {}
for country in country_with_forecast:  # hub_list_used.Country.unique():
    hub_collect = hub_list_used[hub_list_used.loc[:, "Country"] == country]["Ref_City"].tolist()
    L[country] = hub_collect

    #for row in hub_list_used.index:

    #L[hub_list_used.loc[row, "Country"]].append(hub_list_used.loc[row, "Ref_City"])
H = hub_list_used.Ref_City.unique().tolist() # All hubs

# %% [markdown]
# ## 2. European Countries (E)

# %%
E = country_with_forecast # from the "forecast" file
len(E)
# Out:
# 24

# %% [markdown]
# ## 3. Truck Types (T)

# %%
T = truck_cap["Truck Type"].tolist()

# %% [markdown]
# ## Define subset for the later use

# %%
# Define tuplelist for the assign of variables

mjk = tuplelist([(m,j,k) for m, k in country_set for j in country_with_forecast if (m != j) & (j != k)])
mk = tuplelist([(m,k) for m, k in country_set])

mj_k = [(m, j) for m in origin_list for j in country_with_forecast if (m, j) not in mk if m != j]   # m connects to j exlcudes k (transit countries)
mj_k = list( dict.fromkeys(mj_k) )

#j_mk = [(m, k) for m in country_with_forecast for k in dst_list if (m not in origin_list) & (m != k)]   # m connects to j exlcudes k (transit countries)
j_mk = [(j, k)  for j in country_with_forecast for k in dst_list if (j,k) not in mk if k != j]  
#j_mk = [(j, k) for m, j, k in mjk if (j,k) not in mk]   # j excludes m (transit countries), connects to k
j_mk = list( dict.fromkeys(j_mk) )

mk_all = j_mk + mj_k + mk
mk_all = list( dict.fromkeys(mk_all) )

pq = tuplelist([(p,q) for m,k in mk for p in L[m] for q in L[k]])
piq = tuplelist([(p,i,q) for (m,j,k) in mjk for p in L[m] for i in L[j] for q in L[k]])
pq_all = tuplelist((p, q) for m,k in mk_all for p in L[m] for q in L[k])
pqt = tuplelist([(p,q,t) for p,q in pq_all for t in T])

# %% [markdown]
# # Define all the parameters
#
# ## 1. Cost:
# Transportation Cost between hub p ∈ H and hub q ∈ H using truck t ∈ T (Euro/ kg)

# %%
cost_file = pd.read_csv("Database/Costs.csv")

# %%
cost = {}
for row in cost_file.index:
    cost_key = (cost_file["From"][row], cost_file["To"][row], cost_file["Truck type"][row])
    cost[cost_key] = cost_file["Cost/kg"][row]
    
cl_file = pd.read_csv("Database/Co Loading Hubs.csv")
cl_od = tuple(zip(cl_file["Origin Hub-Country"].to_list(), cl_file["Destination Hub-Country"].to_list()))
    
    
coeff_cl = 0.7
if "Co-loading" in T:
    for p, q in pq_all:
        
        if (p,q) in high_demands_routes:
            print(p,q, " is a high demand route")
            cost[p, q, "Co-loading"] = min([cost[p_s, q_s, t] for p_s, q_s, t in pqt.select(p, q, "*") if t != "Co-loading"])
            
        elif (p,q) in cl_od:
            print(p,q)
            cost[(p, q, "Co-loading")] = max([cost[p_s, q_s, t] for p_s, q_s, t in pqt.select(p, q, "*") if t != "Co-loading"])*coeff_cl
        else:
            cost[(p, q, "Co-loading")] = 99
# Out:
# Madrid-ES Lisboa-PT
# Stockholm - Västberga-SE Lieto (Turku)-FL  is a high demand route
# Göteborg-SE Oslo-NO  is a high demand route
# Helsingborg-SE Oslo-NO
# PZ 50 (Köln)-DE Brüssel-BE  is a high demand route
# PZ 90 (Feucht/Nürnberg)-DE Oradea-RO
# PZ 90 (Feucht/Nürnberg)-DE Hub Wien I-AT
# PZ 93 (Regensburg)-DE Hub Wien I-AT  is a high demand route
# PZ 93 (Regensburg)-DE Hub Wien II-AT  is a high demand route
# PZ 93 (Regensburg)-DE Hub Graz-AT  is a high demand route
# PZ 93 (Regensburg)-DE Hagenbrunn-AT  is a high demand route
# PZ 93 (Regensburg)-DE Allhaming-AT  is a high demand route
# PZ 93 (Regensburg)-DE Enns-AT  is a high demand route
# PZ 93 (Regensburg)-DE Wernberg-AT  is a high demand route
# PZ 93 (Regensburg)-DE Wals-AT  is a high demand route
# PZ 93 (Regensburg)-DE Liesing-AT  is a high demand route
# PZ 93 (Regensburg)-DE Wundschuh-AT  is a high demand route
# PZ 21 (Hamburg)-DE Hub Wien I-AT
# PZ 50 (Köln)-DE Bettembourg-LU  is a high demand route
# PZ 67 (Speyer)-DE Barcelona-ES  is a high demand route
# PZ 67 (Speyer)-DE Madrid-ES  is a high demand route
# PZ 50 (Köln)-DE Barcelona-ES
# PZ 46 (Dorsten)-DE Zaltbommel-NL  is a high demand route
# PZ 47 (Krefeld)-DE Zaltbommel-NL
# PZ 50 (Köln)-DE Dublin-IE  is a high demand route
# PZ 46 (Dorsten)-DE Ryton Gateway-GB  is a high demand route
# Hub Wien I-AT Sofia-BG
# Hub Graz-AT Ljubljana-SI
# Hub Wien I-AT Oradea-RO
# Hub Wien I-AT Zagreb-HR
# Hub Wien I-AT Budapest OLK-HU
# Hub Wien I-AT PZ 90 (Feucht/Nürnberg)-DE
# Hub Wien I-AT PZ 93 (Regensburg)-DE  is a high demand route
# Hub Graz-AT PZ 93 (Regensburg)-DE
# Allhaming-AT PZ 93 (Regensburg)-DE  is a high demand route
# Eindhoven-Noord-NL Arlöv-SE  is a high demand route
# Zaltbommel-NL Malmö-SE
# Eindhoven-Noord-NL Araba (Vitoria)-ES  is a high demand route
# Zaltbommel-NL PZ 46 (Dorsten)-DE  is a high demand route
# Zaltbommel-NL PZ 47 (Krefeld)-DE
# Zaltbommel-NL PZ 44 (Bochum) [im Bau]-DE
# Eindhoven-Noord-NL Ryton Gateway-GB  is a high demand route
# Zaltbommel-NL Ryton Gateway-GB
# Poznań-PL PZ 15 (Rüdersdorf)-DE  is a high demand route
# Zagreb-HR Ljubljana-SI
# Zagreb-HR Hub Wien I-AT
# Zagreb-HR PZ 90 (Feucht/Nürnberg)-DE
# Oslo-NO Göteborg-SE
# Oslo-NO PZ 21 (Hamburg)-DE
# Dublin-IE Göteborg-SE
# Dublin-IE Barcelona-ES
# Dublin-IE Madrid-ES
# Sofia-BG Hub Wien I-AT
# PZ 21 (Hamburg)-DE Oslo-NO
# PZ 90 (Feucht/Nürnberg)-DE Zagreb-HR
# Brno-CZ Helsingborg-SE
# Barcelona-ES Helsingborg-SE
# Ljubljana-SI Hub Wien I-AT
# Helsingborg-SE Brno-CZ
# Helsingborg-SE Poznań-PL
# Göteborg-SE Dublin-IE
# Helsingborg-SE Barcelona-ES
# Helsingborg-SE Madrid-ES
# PZ 50 (Köln)-DE Lisboa-PT
# Zaltbommel-NL Poznań-PL
# Ljubljana-SI PZ 90 (Feucht/Nürnberg)-DE
# Budapest OLK-HU Hub Wien I-AT
# Poznań-PL Helsingborg-SE
# Budapest OLK-HU PZ 90 (Feucht/Nürnberg)-DE
# PZ 90 (Feucht/Nürnberg)-DE Sofia-BG
# Lisboa-PT PZ 50 (Köln)-DE
# PZ 90 (Feucht/Nürnberg)-DE Budapest OLK-HU
# Brno-CZ Hub Wien I-AT
# PZ 50 (Köln)-DE Helsingborg-SE
# PZ 90 (Feucht/Nürnberg)-DE Helsingborg-SE
# PZ 21 (Hamburg)-DE Helsingborg-SE
# PZ 21 (Hamburg)-DE Malmö-SE
# Helsingborg-SE PZ 21 (Hamburg)-DE
# Malmö-SE PZ 21 (Hamburg)-DE
# PZ 90 (Feucht/Nürnberg)-DE Poznań-PL
# PZ 21 (Hamburg)-DE Poznań-PL
# Barcelona-ES PZ 50 (Köln)-DE
# Hub Wien I-AT Brno-CZ

# %% [markdown]
# # 2. Forecast volume: Z
# Average forecasted parcel volume from country m ∈ E to country j ∈ E

# %%
Z = {}


for row in forecast.index:
    key = (forecast["Origin"][row], forecast["Destination"][row])
    Z[key] = int(round(forecast["Target"][row])) # Can only be interger

# Some missing connection in the forecast
for conn in mk:
    if conn not in Z.keys():
        Z[conn] = 0
        print(conn)

# %% [markdown]
# ## 3. Current Freqency (F_)
# the frequency of truck t from hub to hub q in the current network.

# %%
# The following code transform the excel files to csv file in specific format
'''
freq_truck = pd.read_excel("Database/Result_Freq.xlsx", sheet_name = 0)
freq_truck.replace("Ryton Gateway", "Ryton", inplace = True)
freq_truck["From"] = freq_truck.apply(lambda row: name_transform(row["Org. GTW"]), axis = 1)
freq_truck["To"] = freq_truck.apply(lambda row: name_transform(row["Dst. GTW"]), axis = 1)
freq_truck.loc[:, :].to_csv("Database/current_network.csv")

'''
# Out:
# '\nfreq_truck = pd.read_excel("Database/Result_Freq.xlsx", sheet_name = 0)\nfreq_truck.replace("Ryton Gateway", "Ryton", inplace = True)\nfreq_truck["From"] = freq_truck.apply(lambda row: name_transform(row["Org. GTW"]), axis = 1)\nfreq_truck["To"] = freq_truck.apply(lambda row: name_transform(row["Dst. GTW"]), axis = 1)\nfreq_truck.loc[:, :].to_csv("Database/current_network.csv")\n\n'

# %%
F_ = {}
for row in freq_current.index:
    key = (freq_current.loc[row, "From"], freq_current.loc[row, "To"], freq_current.loc[row, "Truck type"])
    value = freq_current.loc[row, "Frequency"]
    
    F_[key] = value
    
for target in pqt:
    if target not in F_.keys():
        F_[target] = 0

# %% [markdown]
# ## 4. Travel time (TT)
# Total transportation time from hub p ∈ H to q ∈ H

# %%
tt_file = pd.read_csv("Database/travel time.csv")
TT = {}
for row in tt_file.index:
    key = (tt_file.loc[row, "From"], tt_file.loc[row, "To"])
    value = tt_file.loc[row, "est_tt"]
    
    TT[key] = value

# %% [markdown]
# ## 5. Hub Open & Cut-off time
# - Op = Hub opened time for hub p ∈ H
# - COp  = Hub cut off time for hub p ∈ H

# %%
def transform_time(target):
    try: 
        return int(target.split(":")[0]) + int(target.split(":")[1])/60 
    except:
        return 0

# %%
'''
hub_info = pd.read_csv("Database/Hub Cutoff and Open Time.csv")
hub_info["Hub"] = hub_info.apply(lambda row: name_transform(row["Gateways"]), axis = 1)
hub_info["Cut-off"] = hub_info.apply(lambda row: transform_time(row["Cut-Off"]), axis = 1)
hub_info["Open"] = hub_info.apply(lambda row: transform_time(row["Hub-Opening-Time"]), axis = 1)
hub_info.to_csv("Database/hub_info.csv")
'''
# Out:
# '\nhub_info = pd.read_csv("Database/Hub Cutoff and Open Time.csv")\nhub_info["Hub"] = hub_info.apply(lambda row: name_transform(row["Gateways"]), axis = 1)\nhub_info["Cut-off"] = hub_info.apply(lambda row: transform_time(row["Cut-Off"]), axis = 1)\nhub_info["Open"] = hub_info.apply(lambda row: transform_time(row["Hub-Opening-Time"]), axis = 1)\nhub_info.to_csv("Database/hub_info.csv")\n'

# %%
hub_info = pd.read_csv("Database/hub_info.csv")
merged_hub_info = hub_list_used.merge(hub_info[["Hub", "Open", "Cut-off"]], left_on = "Ref_City", right_on = "Hub", how = "left")

merged_hub_info["Open"].fillna(merged_hub_info["Open"].mode().values[0], inplace = True)
merged_hub_info["Cut-off"].fillna(merged_hub_info["Cut-off"].mode().values[0], inplace = True)

O = {} # Open time
for row in merged_hub_info.index:
    key = merged_hub_info.loc[row, "Ref_City"]
    value = merged_hub_info.loc[row, "Open"]
    O[key] = value

CO = {} # Cut-off time
for row in merged_hub_info.index:
    key = merged_hub_info.loc[row, "Ref_City"]
    value = merged_hub_info.loc[row, "Cut-off"]
    CO[key] =  value

# %% [markdown]
# ## 6. Truck Capacity

# %%
C = {}
for row in truck_cap.index:
    C[truck_cap.loc[row, "Truck Type"]] = truck_cap.loc[row, "Capacity"]

# %% [markdown]
# # Start the model

# %%
model = Model("DHL")
# Out:
# Academic license - for non-commercial use only

# %% [markdown]
# # Define the variables
# Decision variables:
# - xpq = 1 if the transportation from hub p ∈ H to hub q ∈ H is direct, else 0
# - x’piq = 1 if the transportation from hub p ∈ H to hub q ∈ H has to go through i ∈ H, else 0
# - Xmk = 1 if the transportation from country m ∈ E to county k ∈ E is direct, else 0
# - X’mjk = 1 if the transportation from country m ∈ E  to county k ∈ E  has to go through country j ∈ E , else 0
# - Vpq = route capacity from hub p ∈ H to hub q ∈ H
# - Fpqt = recommended frequency of truck t ∈ T from hub p ∈ H to hub q ∈ H
# - Spq = start time of truck from hub p ∈ H to hub q ∈ H,
# - Npq = Night needed from hub p ∈ H to hub q ∈ H

# %%
x = model.addVars(pq , vtype=GRB.BINARY, name='xpq')  # Direct from hub to hub

x_ = model.addVars(piq, vtype = GRB.BINARY, name = 'x_piq')  # Indirect from hub to hub

X = model.addVars(mk , vtype=GRB.BINARY, name='Xmk')       # Direct from country to country

X_ = model.addVars(mjk,  vtype = GRB.BINARY, name = 'X_mjk') # Indirect from country to country

V = model.addVars(pq_all , vtype=GRB.INTEGER, lb=0 ,name='Vpq')   # Route capacity

F=model.addVars(pqt , vtype=GRB.INTEGER, lb=0, name='Fpqt') # Recommended Frequency

# S=model.addVars(pq_all , vtype=GRB.CONTINUOUS, name='Spq')         # Start time from hub p

# N=model.addVars(pq_all , vtype=GRB.INTEGER, name='Npq')         # Night Needed from hub p to hub q

CL = model.addVars(pq_all, vtype = GRB.INTEGER, lb = 0, name = "CLpq") # Co-loading (in) between p and q

# %%
attri_dict = {"hub_direct": x, "hub_indirect" : x_, "country_direct" : X, "country_indirect" : X_,
              "route_cap": V, "freq" : F, "Co-loading":CL}

# %% [markdown]
# ## Objective

# %%
model.update()

# Minimize the travel time for each route
model.setObjective(quicksum(x[p, q] * TT[p, q] for p, q in pq) +
                   quicksum(x_[p, i ,q] * (TT[p, i] + 9 + TT[i, q])for p, i, q in piq) # Consider the transit time in the hubs
                                                                                       # Taking 9 as an example
                   ,  GRB.MINIMIZE)

# %% [markdown]
# ## Constraints

# %%
### Constraints
## Direct or Indirect Transportation

model.addConstrs(((quicksum(X_[m,j,k] for j in E if (j != m) & (j != k)) == 
                   (1 - X[m,k])) for m, k in mk),
                 "Transportation can be direct or Indirect")


## Linking Countries and Hubs

model.addConstrs(((quicksum(x[p,q] for p in L[m] for q in L[k]) == 
                  X[m,k]) for m, k in mk), "Linking_pq")  ## We can't use E_mjk here
model.addConstrs(((quicksum(x_[p,i,q] for p in L[m] for i in L[j] for q in L[k]) ==
                 X_[m,j,k]) for m,j,k in mjk), "Linking_piq")

## Truck Capacity:

# V = monthly demand of the route
# For the countries of p, q are in mk
model.addConstrs((V[p,q] ==  
                 quicksum(x_[p,q,i] * Z[m,j] for m, k, j in mjk.select(m, k, "*") for i in L[j]) +
                 quicksum(x_[i,p,q] * Z[j,k] for j, m, k in mjk.select("*", m, k) for i in L[j]) + 
                 x[p,q] * Z[m,k]
                 for m, k in mk for p in L[m] for q in L[k]), "Truck Capacity")

# For the countries of p are in the origin, q are not in the destination:
model.addConstrs((V[p,q] ==  
                 quicksum(x_[p,q,i] * Z[m,j] for m, k, j in mjk.select(m, k, "*") for i in L[j])
                 for m, k in mj_k for p in L[m] for q in L[k] if (m,k) not in j_mk), "Truck Capacity")
                 
# For the countries of p are not in the origin, q are in the destination:           
model.addConstrs((V[p,q] ==  
                 quicksum(x_[i,p,q] * Z[j,k] for j, m, k in mjk.select("*", m, k) for i in L[j]) 
                 for m, k in j_mk for p in L[m] for q in L[k] if (m,k) not in mj_k), "Truck Capacity")

# For the countries of p and q are not in mk, but in j_mk and mj_k in the same time
model.addConstrs((V[p,q] ==  
                 quicksum(x_[p,q,i] * Z[m,j] for m, k, j in mjk.select(m, k, "*") for i in L[j]) +
                 quicksum(x_[i,p,q] * Z[j,k] for j, m, k in mjk.select("*", m, k) for i in L[j])
                 for m, k in j_mk for p in L[m] for q in L[k] if (m,k) in mj_k), "Truck Capacity 4")


## Truck type and Frequency of trucks
# transforming the weekly frequency to monthly by multiplying 4
model.addConstrs(((V[p,q] + CL[p, q]*4 <=   # Updated
                 quicksum(F[p,q,t] * C[t] * 4 for t in T) )
                 for m, k in mk_all for q in L[k] for p in L[m]),
                 "Truck Type and Frequency"
                )

# Co-loading in constraints
model.addConstrs((CL[p,q] <= 2000 for p,q in pq_all), "Coloading in constraints")
model.addConstrs((CL[p,q] <= V[p, q]*0.3 for p, q in pq_all), "Coloading in constraints 2")


'''
BigM = 9999
model.addConstrs((S[p,q] + TT[p,q] - N[p,q] * 24  <=  
                 CO[q] + 
                 BigM * (
                     1 - (x[p, q] + 
                          quicksum(x_[p, q, i] for m, k, j in mjk.select(m, k, "*") for i in L[j]) + 
                          quicksum(x_[i, p, q] for j, m, k in mjk.select("*", m, k) for i in L[j])
                 ) ) for m,k in mk for q in L[k] for p in L[m]), "Hub Cut Off Time")


BigMM = 9000

model.addConstrs((S[p,q] + TT[p,q] - N[p,q] * 24  >=  
                 O[q] + 
                 BigMM * (
                     1 - (x[p, q] + 
                          quicksum(x_[p, q, i] for m, k, j in mjk.select(m, k, "*") for i in L[j]) + 
                          quicksum(x_[i, p, q] for j, m, k in mjk.select("*", m, k) for i in L[j])
                 ) ) for m,k in mk for q in L[k] for p in L[m]), "Hub Open Time")

'''

# Assumption: all the excessive spaces could be loaded with co-loading opportunities in the current network
# Assumption: In the new network, all the co-loading oppottunities doesn't exist


Cost_bound = 1.05
Current_full = 1


current_cost = sum(F_[p,q,t] * C[t] * cost[p,q,t] for p, q, t in pqt) / sum(F_[p,q,t] * C[t] for p,q,t in pqt)
'''
model.addConstr((quicksum(F[p,q,t] * cost[p,q,t] * C[t] for p, q, t in pqt) <= 
                 (current_cost * (quicksum(V[p,q] for p, q in pq_all) / 4 + quicksum(CL[p,q] for p,q in pq_all))) * Cost_bound / Current_full), "Cost Constraint")
'''
model.addConstr((quicksum(F[p,q,t] * cost[p,q,t] * C[t] for p, q, t in pqt) <= 
                 (current_cost * (quicksum(V[p,q] for p, q in pq_all) / 4 + quicksum(CL[p,q] for p,q in pq_all))) * Cost_bound / Current_full), "Cost Constraint")
# Out:
# <gurobi.Constr *Awaiting Model Update*>

# %% [markdown]
# ## Solver

# %%
model.update()
model.printStats()
# Out:
# Statistics for model DHL :
#   Linear constraint matrix    : 22945 Constrs, 178061 Vars, 513569 NZs
#   Variable types              : 0 Continuous, 178061 Integer (146183 Binary)
#   Matrix coefficient range    : [ 0.0196094, 471880 ]
#   Objective coefficient range : [ 2.1, 197.2 ]
#   Variable bound range        : [ 1, 1 ]
#   RHS coefficient range       : [ 1, 2000 ]

# %%
# model.reset()

timeLimit = 3600*6 # In second

model.Params.TimeLimit = timeLimit - model.getAttr(GRB.Attr.Runtime)

model.Params.Heuristics = 0.2

model.Params.MIPFocus=3

model.Params.TuneCriterion = 2

model.Params.TuneTrials = 3

model.Params.SolutionLimit = 1

oldSolutionLimit = model.Params.SolutionLimit

model.Params.Seed = 3

model.Params.TuneTimeLimit = timeLimit/3

model.tune()

# model.feasRelaxS(1, False, False, True)

model.optimize()


'''
if model.tuneResultCount > 0:

    # Load the best tuned parameters into the model
    model.getTuneResult(0)

    # Write tuned parameters to a file
    model.write('tune.prm')

    # Solve the model using the tuned parameters
    model.optimize()
    
'''
# Out:
# Changed value of parameter TimeLimit to 21600.0
#    Prev: 1e+100  Min: 0.0  Max: 1e+100  Default: 1e+100
# Changed value of parameter Heuristics to 0.2
#    Prev: 0.05  Min: 0.0  Max: 1.0  Default: 0.05
# Changed value of parameter MIPFocus to 3
#    Prev: 0  Min: 0  Max: 3  Default: 0
# Changed value of parameter TuneCriterion to 2
#    Prev: -1  Min: -1  Max: 3  Default: -1
# Parameter TuneTrials unchanged
#    Value: 3  Min: 1  Max: 2000000000  Default: 3
# Changed value of parameter SolutionLimit to 1
#    Prev: 2000000000  Min: 1  Max: 2000000000  Default: 2000000000
# Changed value of parameter Seed to 3
#    Prev: 0  Min: 0  Max: 2000000000  Default: 0
# Changed value of parameter TuneTimeLimit to 7200.0
#    Prev: -1.0  Min: -1.0  Max: 1e+100  Default: -1.0
#
# Solving model using baseline parameter set with TimeLimit=21600s
#
# Solving with random seed #1 ...
# Optimize a model with 22945 rows, 178061 columns and 513569 nonzeros
# Variable types: 0 continuous, 178061 integer (146183 binary)
# Coefficient statistics:
#   Matrix range     [2e-02, 5e+05]
#   Objective range  [2e+00, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Presolve removed 7675 rows and 12217 columns
# Presolve time: 4.26s
# Presolved: 15270 rows, 165844 columns, 484503 nonzeros
# Variable types: 0 continuous, 165844 integer (143177 binary)
# Presolve removed 922 rows and 948 columns
# Presolved: 14348 rows, 164896 columns, 482547 nonzeros
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    9.2886333e+02   2.343007e+02   0.000000e+00      7s
#      791    6.0728900e+03   0.000000e+00   0.000000e+00      7s
#      791    6.0728900e+03   0.000000e+00   0.000000e+00      7s
#
# Root relaxation: objective 6.072890e+03, 791 iterations, 0.92 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 
+00, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Presolve removed 7675 rows and 12217 columns
# Presolve time: 4.09s
# Presolved: 15270 rows, 165844 columns, 484503 nonzeros
# Variable types: 0 continuous, 165844 integer (143177 binary)
# Presolve removed 922 rows and 948 columns
# Presolved: 14348 rows, 164896 columns, 482547 nonzeros
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    9.2886333e+02   2.343007e+02   0.000000e+00      7s
#      769    6.0728900e+03   0.000000e+00   0.000000e+00      7s
#      769    6.0728900e+03   0.000000e+00   0.000000e+00      7s
#
# Root relaxation: objective 6.072890e+03, 769 iterations, 0.98 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 6072.89000    0  197          - 6072.89000      -     -    8s
#      0     0 6182.07493    0  561          - 6182.07493      -     -   31s
#      0     0 6199.90344    0  551          - 6199.90344      -     -   37s
#      0     0 6200.02390    0  548          - 6200.02390      -     -   37s
#      0     0 6312.33133    0  666          - 6312.33133      -     -   68s
#      0     0 6315.93621    0  643          - 6315.93621      -     -   74s
#      0     0 6315.94136    0  643          - 6315.94136      -     -   74s
#      0     0 6372.45290    0  736          - 6372.45290      -     -   96s
#      0     0 6375.46025    0  729          - 6375.46025      -     -  101s
#      0     0 6375.52050    0  728          - 6375.52050      -     -  102s
#      0     0 6402.12525    0  728          - 6402.12525      -     -  122s
#      0     0 6404.57402    0  791          - 6404.57402      -     -  127s
#      0     0 6404.89828    0  776          - 6404.89828      -     -  127s
#      0     0 6404.93796    0  777          - 6404.93796      -     -  127s
#      0     0 6424.93449    0  773          - 6424.93449      -     -  150s
#      0     0 6426.94513    0  754          - 6426.94513      -     -  155s
#      0     0 6427.07657    0  773          - 6427.07657      -     -  155s
#      0     0 6450.74787    0  825          - 6450.74787      -     -  178s
#      0     0 6452.37672    0  780          - 6452.37672      -     -  183s
#      0     0 6452.60312    0  786          - 6452.60312      -     -  183s
#      0     0 6452.67385    0  788          - 6452.67385      -     -  184s
#      0     0 6464.83259    0  800          - 6464.83259      -     -  208s
#      0     0 6465.95118    0  801          - 6465.95118      -     -  213s
#      0     0 6466.07285    0  780          - 6466.07285      -     -  214s
#      0     0 6476.35917    0  861          - 6476.35917      -     -  240s
#      0     0 6478.35127    0  823          - 6478.35127      -     -  245s
#      0     0 6478.89345    0  819          - 6478.89345      -     -  246s
#      0     0 6479.02563    0  833          - 6479.02563      -     -  246s
#      0     0 6488.17654    0 1086          - 6488.17654      -     -  275s
#      0     0 6489.93269    0 1043          - 6489.93269      -     -  281s
#      0     0 6490.57230    0 1055          - 6490.57230      -     -  281s
#      0     0 6490.79966    0 1060          - 6490.79966      -     -  282s
#      0     0 6490.84599    0 1057          - 6490.84599      -     -  282s
#      0     0 6496.13201    0 1044          - 6496.13201      -     -  313s
#      0     0 6499.09824    0 1103          - 6499.09824      -     -  320s
#      0     0 6499.49038    0 1089          - 6499.49038      -     -  321s
#      0     0 6499.51934    0 1100          - 6499.51934      -     -  321s
#      0     0 6504.31280    0 1126          - 6504.31280      -     -  352s
#      0     0 6505.62713    0 1065          - 6505.62713      -     -  357s
#      0     0 6506.12239    0 1109          - 6506.12239      -     -  357s
#      0     0 6506.36397    0 1047          - 6506.36397      -     -  358s
#      0     0 6510.35827    0 1066          - 6510.35827      -     -  387s
#      0     0 6511.28932    0 1144          - 6511.28932      -     -  391s
#   5851  5658 6634.32266 1387 1625          - 6634.32266      -  97.0 10885s
#   5854  5660 6634.32266  630 1703          - 6634.32266      -  97.0 10891s
#   5857  5662 6634.32266  401 1799          - 6634.32266      -  96.9 10895s
#   5859  5664 6634.32266  681 1767          - 6634.32266      -  96.9 10900s
#   5864  5667 6646.00729 1054 1812          - 6634.32266      -  96.8 10905s
#   5870  5671 6634.32266  724 1961          - 6634.32266      -  96.7 10910s
#   5878  5676 6634.32266  730 1916          - 6634.32266      -  96.6 10915s
#   5881  5678 6634.32266   33 1908          - 6634.32266      -  96.5 10950s
#   5882  5679 6634.33789  111 1965          - 6634.33789      -  96.5 11011s
#   5885  5681 6634.35300  104 2059          - 6634.35300      -  96.4 11071s
#   5886  5682 6634.35702  743 2008          - 6634.35702      -  96.4 11134s
#   5887  5682 6634.36280  346 2009          - 6634.36280      -  96.4 11135s
#   5888  5683 6645.20897  572 2000          - 6634.36307      -  96.4 11187s
#   5889  5684 6634.36313  483 1997          - 6634.36313      -  96.4 11489s
#   5890  5684 6634.36313  374 1997          - 6634.36313      -  96.4 11532s
# H 5890  5398                    6672.2000000 6634.36313  0.57%  96.4 11821s
#
# Cutting planes:
#   Gomory: 313
#   Cover: 1
#   Implied bound: 10
#   MIR: 2320
#   StrongCG: 21
#   Flow cover: 426
#   Zero half: 97
#
# Explored 5890 nodes (663815 simplex iterations) in 11823.15 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 6672.2
#
# Solution limit reached
# Best objective 6.672200000000e+03, best bound 6.634363333333e+03, gap 0.5671%
# "\nif model.tuneResultCount > 0:\n\n    # Load the best tuned parameters into the model\n    model.getTuneResult(0)\n\n    # Write tuned parameters to a file\n    model.write('tune.prm')\n\n    # Solve the model using the tuned parameters\n    model.optimize()\n    \n"

# %%
def turn_to_df(Var, col_name = None):  # Here you could input the variable
    solution = model.getAttr('x_', Var)
    num_col = len(solution.keys()[0])
    collect = []
    for row in range(0, len(solution)):
        new_row = []
        for col in range(0, num_col):
            new_row.append(solution.keys()[row][col])
        new_row.append(solution[solution.keys()[row]])
    
        collect.append(new_row)
    return pd.DataFrame(collect, columns = col_name)

def cost_ref(A, B):
    for p, q, t in pqt.select(A, B, "*"):
        print(t, ": ", cost[p, q, t])

# %%
Country_Direct = turn_to_df(X, ["Ori_Country", "Dest_Country", "Taken"])
X_sol = model.getAttr('x_', X)

Country_Indirect = turn_to_df(X_, ["Ori_Country", "Transit_Country","Dest_Country", "Taken"])
Hub_Direct = turn_to_df(x, ["Ori_Hub", "Dest_Hub", "Taken"])
Hub_Indirect = turn_to_df(x_, ["Ori_Hub", "Transit_Hub","Dest_Hub", "Taken"])
Route_Cap = turn_to_df(V, ["Ori_Hub", "Dest_Hub", "Taken"])
v_sol = model.getAttr('x_', V)
Freq = turn_to_df(F, ["Ori_Hub", "Dest_Hub","Truck Type", "Taken"])
#Start = turn_to_df(S, ["Ori_Hub", "Dest_Hub", "Time"])
#Night = turn_to_df(N, ["Ori_Hub", "Dest_Hub", "Nights"])
Co_load = turn_to_df(CL, ["Ori_Hub", "Dest_Hub", "Amount"])
CL_sol =  model.getAttr('x_', CL)

# %%
for key in attri_dict.keys():
    df_output = turn_to_df(attri_dict[key])
    df_output.to_csv(f"Output/{key}_output.csv")

# %%
ind = Country_Indirect.Taken.sum()
d = Country_Direct.Taken.sum()

print(f"{ind} indriect routes and {d} direct route, total: {len(Z)}" )
# Out:
# 120.0 indriect routes and 77.0 direct route, total: 197

# %%
freq_result = model.getAttr('x', F)
demand_filled = model.getAttr('x', V)
print("Current Cost:", sum(F_[p,q,t] * C[t] * cost[p,q,t] for p, q, t in pqt) / sum(F_[p,q,t] * C[t] for p,q,t in pqt))
print("Cost by Route Cap.:", round(sum(freq_result[p,q,t] * C[t] * cost[p,q,t] for p, q, t in pqt) / (sum(demand_filled[p,q] for p, q in pq_all)/4), 2))
print("Cost by Capacity.:", sum(freq_result[p,q,t] * C[t] * cost[p,q,t] for p, q,t in pqt) / (sum(freq_result[p,q,t] * C[t] for p, q,t in pqt)))
print("Cost by Demands.:", sum(freq_result[p,q,t] * C[t] * cost[p,q,t] for p, q,t in pqt) / (sum(Z[m, k] for m, k in mk)/4))
print("Cost by Demands + Co-load:", sum(freq_result[p,q,t] * C[t] * cost[p,q,t] for p, q, t in pqt) / (sum(Z[m, k] for m, k in mk)/4 + sum(CL_sol[p, q] for p, q in pq_all)))
print("Cost by Demands + Co-load:", sum(freq_result[p,q,t] * C[t] * cost[p,q,t] for p, q, t in pqt) / (sum(v_sol[p, q] for p, q in pq_all)/4 + sum(CL_sol[p, q] for p, q in pq_all)))
# Out:
# Current Cost: 0.07470231825180565
# Cost by Route Cap.: 0.09
# Cost by Capacity.: 0.07231905244030393
# Cost by Demands.: 0.15268161303544966
# Cost by Demands + Co-load: 0.12685723596362364
# Cost by Demands + Co-load: 0.0784321472106471

# %%
Freq_result = Freq[Freq.Taken > 0]
Freq_result.groupby("Truck Type").count()
# Out:
#                Ori_Hub  Dest_Hub  Taken
# Truck Type
# 2 Swap Bodies       33        33     33
# Co-loading          18        18     18
# Swap Body           46        46     46
# Van                 72        72     72

# %%
Freq_result = Freq[Freq.Taken > 0]
Freq_result["agg"] = Freq_result["Ori_Hub"] + Freq_result["Dest_Hub"]

Freq_result["Capacity"] = Freq_result.apply(lambda row: C[row["Truck Type"]] * row["Taken"] * 4, axis = 1)
capacity_from_freq = Freq_result.groupby(["agg"]).sum()


# Indirect Route Overview

Hub_Indirect_T = Hub_Indirect[Hub_Indirect.Taken > 0]
Hub_Indirect_T["First"] = Hub_Indirect_T["Ori_Hub"] + Hub_Indirect_T["Transit_Hub"]
Hub_Indirect_T["Second"] = Hub_Indirect_T["Transit_Hub"] + Hub_Indirect_T["Dest_Hub"]

Hub_merge = Hub_Indirect_T.merge(capacity_from_freq.loc[:, "Capacity"], left_on = "First", right_on = "agg", how = "right")
Hub_merge = Hub_merge.merge(capacity_from_freq.loc[:, "Capacity"], left_on = "Second", right_on = "agg", how = "right")

pd.options.display.max_rows = 100
Hub_merge.dropna(inplace = True)

for row in Hub_merge.index:
    ori = Hub_merge.loc[row, "Ori_Hub"]
    transit = Hub_merge.loc[row, "Transit_Hub"]
    dest = Hub_merge.loc[row, "Dest_Hub"]
    Hub_merge.loc[row, "Route_Cap_1"] = v_sol[ori, transit]
    Hub_merge.loc[row, "Route_Cap_2"] = v_sol[transit, dest]
# Out:
# C:\Users\MAHITA\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\MAHITA\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# C:\Users\MAHITA\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()
# C:\Users\MAHITA\Anaconda3\lib\site-packages\ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':

# %%
cost_ref("Enns-AT","PZ 93 (Regensburg)-DE")
# Out:
# 2 Swap Bodies :  0.04274614007874955
# Swap Body :  0.0401468384633739
# Trailer :  0.04683077124183006
# Van :  0.06441475555555555
# Co-loading :  99

# %%
cost_ref("Plzen 1-CZ", "PZ 93 (Regensburg)-DE")
# Out:
# 2 Swap Bodies :  0.037596241498627836
# Swap Body :  0.029848270102600806
# Trailer :  0.04118877124183006
# Van :  0.04797235555555555
# Co-loading :  99

# %%
cost_ref("Enns-AT", "Plzen 1-CZ")
# Out:
# 2 Swap Bodies :  0.044499522729984496
# Swap Body :  0.04365318539727989
# Trailer :  0.04875169934640523
# Van :  0.07001288888888889
# Co-loading :  99

# %%
v_sol["Enns-AT", "Plzen 1-CZ"]
# Out:
# -0.0

# %%
pd.set_option("display.max_rows", 120)
Hub_merge
# Out:
#                    Ori_Hub                 Transit_Hub               Dest_Hub  \
# 0                Kaunas-LT                   Poznań-PL               Malmö-SE
# 1                 Sofia-BG             Budapest OLK-HU   Vantaa (Helsinki)-FL
# 2                 Sofia-BG             Budapest OLK-HU              Kaunas-LT
# 3                 Sofia-BG             Budapest OLK-HU  PZ 93 (Regensburg)-DE
# 4                Lisboa-PT                   Zagreb-HR               Sofia-BG
# 5               Brüssel-BE                   Zagreb-HR               Sofia-BG
# 6             Barcelona-ES                   Zagreb-HR               Sofia-BG
# 7    PZ 93 (Regensburg)-DE                   Zagreb-HR               Sofia-BG
# 8       Eindhoven-Noord-NL                   Zagreb-HR               Sofia-BG
# 9                Slough-GB                   Zagreb-HR               Sofia-BG
# 10               Lisboa-PT                   Zagreb-HR               Spata-GR
# 11              Brüssel-BE                   Zagreb-HR               Spata-GR
# 12            Barcelona-ES                   Zagreb-HR               Spata-GR
# 13   PZ 93 (Regensburg)-DE                   Zagreb-HR               Spata-GR
# 14      Eindhoven-Noord-NL                   Zagreb-HR               Spata-GR
# 15               Slough-GB                   Zagreb-HR               Spata-GR
# 16               Lisboa-PT                   Zagreb-HR              Oradea-RO
# 17            Barcelona-ES                   Zagreb-HR              Oradea-RO
# 18               Lisboa-PT                   Zagreb-HR        Budapest OLK-HU
# 19            Barcelona-ES                   Zagreb-HR        Budapest OLK-HU
# 20                Sofia-BG          Araba (Vitoria)-ES              Lisboa-PT
# 21        Lieto (Turku)-FL          Araba (Vitoria)-ES              Lisboa-PT
# 22      Eindhoven-Noord-NL          Araba (Vitoria)-ES              Lisboa-PT
# 23               Lisboa-PT          Araba (Vitoria)-ES           Ljubljana-SI
# 24            Ljubljana-SI  PZ 90 (Feucht/Nürnberg)-DE             Brüssel-BE
# 25         Budapest OLK-HU  PZ 90 (Feucht/Nürnberg)-DE             Brüssel-BE
# 26            Ljubljana-SI  PZ 90 (Feucht/Nürnberg)-DE     Eindhoven-Noord-NL
# 27         Budapest OLK-HU  PZ 90 (Feucht/Nürnberg)-DE     Eindhoven-Noord-NL
# 28               Lisboa-PT             PZ 50 (Köln)-DE   Ivanka pri Dunaji-SK
# 29              Brüssel-BE             PZ 50 (Köln)-DE   Ivanka pri Dunaji-SK
# 30               Slough-GB             PZ 50 (Köln)-DE   Ivanka pri Dunaji-SK
# 31      Eindhoven-Noord-NL             PZ 50 (Köln)-DE   Ivanka pri Dunaji-SK
# 32               Lisboa-PT             PZ 50 (Köln)-DE         Helsingborg-SE
# 33              Brüssel-BE             PZ 50 (Köln)-DE           Ljubljana-SI
# 34                Malmö-SE             PZ 50 (Köln)-DE           Ljubljana-SI
# 35               Slough-GB             PZ 50 (Köln)-DE           Ljubljana-SI
# 36      Eindhoven-Noord-NL             PZ 50 (Köln)-DE           Ljubljana-SI
# 37              Ostrava-CZ            Suwałki (Ełk)-PL              Kaunas-LT
# 38              Ostrava-CZ            Suwałki (Ełk)-PL   Vantaa (Helsinki)-FL
# 39      Araba (Vitoria)-ES                  Brüssel-BE             Kolding-DK
# 40               Lisboa-PT                  Brüssel-BE             Kolding-DK
# 41      Araba (Vitoria)-ES                  Brüssel-BE              Kaunas-LT
# 42               Lisboa-PT                  Brüssel-BE              Kaunas-LT
# 43               Slough-GB                  Brüssel-BE              Kaunas-LT
# 44      Araba (Vitoria)-ES                  Brüssel-BE       Lieto (Turku)-FL
# 45               Lisboa-PT                  Brüssel-BE       Lieto (Turku)-FL
# 46               Slough-GB                  Brüssel-BE       Lieto (Turku)-FL
# 47      Araba (Vitoria)-ES                  Brüssel-BE              Poznań-PL
# 48               Lisboa-PT                  Brüssel-BE              Poznań-PL
# 49               Slough-GB                  Brüssel-BE              Poznań-PL
# 50      Araba (Vitoria)-ES                  Brüssel-BE        PZ 50 (Köln)-DE
# 51                Malmö-SE             Budapest OLK-HU               Sofia-BG
# 52    Vantaa (Helsinki)-FL             Budapest OLK-HU               Sofia-BG
# 53               Zabrze-PL             Budapest OLK-HU               Sofia-BG
# 54                Malmö-SE             Budapest OLK-HU              Oradea-RO
# 55               Slough-GB             Budapest OLK-HU              Oradea-RO
# 56   PZ 15 (Rüdersdorf)-DE                   Poznań-PL              Kaunas-LT
# 57           Zaltbommel-NL                   Poznań-PL              Kaunas-LT
# 58               Lisboa-PT           Combs la ville-FR         Bettembourg-LU
# 59      Araba (Vitoria)-ES           Combs la ville-FR         Bettembourg-LU
# 60               Lisboa-PT           Combs la ville-FR             Plzen 1-CZ
# 61      Araba (Vitoria)-ES           Combs la ville-FR             Plzen 1-CZ
# 62               Lisboa-PT           Combs la ville-FR     Eindhoven-Noord-NL
# 63      Araba (Vitoria)-ES           Combs la ville-FR     Eindhoven-Noord-NL
# 64               Lisboa-PT           Combs la ville-FR       Hall in Tirol-AT
# 65      Araba (Vitoria)-ES           Combs la ville-FR       Hall in Tirol-AT
# 66               Lisboa-PT           Combs la ville-FR              Dublin-IE
# 67      Araba (Vitoria)-ES           Combs la ville-FR              Dublin-IE
# 68              Plzen 1-CZ           Combs la ville-FR              Dublin-IE
# 69               Lisboa-PT           Combs la ville-FR        PZ 50 (Köln)-DE
# 70               Lisboa-PT           Combs la ville-FR              Slough-GB
# 71      Araba (Vitoria)-ES           Combs la ville-FR              Slough-GB
# 72         Budapest OLK-HU  PZ 90 (Feucht/Nürnberg)-DE         Bettembourg-LU
# 73    Vantaa (Helsinki)-FL             Budapest OLK-HU           Ljubljana-SI
# 74              Brüssel-BE                     Wals-AT        Budapest OLK-HU
# 75      Eindhoven-Noord-NL                     Wals-AT        Budapest OLK-HU
# 76        Lieto (Turku)-FL                  Brüssel-BE         Bettembourg-LU
# 77                Malmö-SE             PZ 50 (Köln)-DE         Bettembourg-LU
# 78                Malmö-SE             PZ 50 (Köln)-DE              Lisboa-PT
# 79                Malmö-SE             PZ 50 (Köln)-DE              Dublin-IE
# 80                Malmö-SE             PZ 50 (Köln)-DE             Brüssel-BE
# 81                Malmö-SE                 Krupka 1-CZ   Ivanka pri Dunaji-SK
# 82                Malmö-SE                 Krupka 1-CZ              Zagreb-HR
# 83                Malmö-SE                 Krupka 1-CZ           Allhaming-AT
# 84              Brüssel-BE                  Kolding-DK               Malmö-SE
# 85      PZ 21 (Hamburg)-DE                  Kolding-DK               Malmö-SE
# 86              Brüssel-BE           Combs la ville-FR              Lisboa-PT
# 87              Plzen 1-CZ           Combs la ville-FR              Lisboa-PT
# 88               Slough-GB           Combs la ville-FR              Lisboa-PT
# 89               Poznań-PL           Combs la ville-FR              Lisboa-PT
# 90              Brüssel-BE           Combs la ville-FR     Araba (Vitoria)-ES
# 91              Plzen 1-CZ           Combs la ville-FR     Araba (Vitoria)-ES
# 92               Slough-GB           Combs la ville-FR     Araba (Vitoria)-ES
# 93               Poznań-PL           Combs la ville-FR     Araba (Vitoria)-ES
# 94    Vantaa (Helsinki)-FL            Suwałki (Ełk)-PL     Zilina- Strecno-SK
# 95               Slough-GB                  Brüssel-BE             Plzen 1-CZ
# 96               Slough-GB                  Brüssel-BE                Wals-AT
# 97               Slough-GB                  Brüssel-BE     Eindhoven-Noord-NL
# 98        Lieto (Turku)-FL                    Malmö-SE            Krupka 1-CZ
# 99        Lieto (Turku)-FL                    Malmö-SE     Eindhoven-Noord-NL
# 100     Eindhoven-Noord-NL                     Wals-AT              Oradea-RO
# 101     Eindhoven-Noord-NL                  Kolding-DK       Lieto (Turku)-FL
# 102               Malmö-SE          Eindhoven-Noord-NL      Combs la ville-FR
# 103     PZ 47 (Krefeld)-DE          Eindhoven-Noord-NL      Combs la ville-FR
# 104               Malmö-SE          Eindhoven-Noord-NL              Slough-GB
# 105              Poznań-PL          Eindhoven-Noord-NL              Slough-GB
# 106              Slough-GB          Eindhoven-Noord-NL             Kolding-DK
# 107              Slough-GB          Eindhoven-Noord-NL     PZ 47 (Krefeld)-DE
# 108             Brüssel-BE          Eindhoven-Noord-NL     PZ 47 (Krefeld)-DE
# 109              Poznań-PL                  Brüssel-BE              Dublin-IE
# 110       Lieto (Turku)-FL                  Kolding-DK     PZ 21 (Hamburg)-DE
# 111     Eindhoven-Noord-NL                   Slough-GB              Dublin-IE
# 112               Malmö-SE                  Kolding-DK  PZ 24 (Neumünster)-DE
# 113     Eindhoven-Noord-NL                  Brüssel-BE      Combs la ville-FR
# 114     Eindhoven-Noord-NL       PZ 93 (Regensburg)-DE                Wals-AT
# 115              Zabrze-PL                  Ostrava-CZ     Zilina- Strecno-SK
# 116              Zabrze-PL          Zilina- Strecno-SK             Ostrava-CZ
# 117             Liesing-AT        Ivanka pri Dunaji-SK                Brno-CZ
# 118             Ricany -CZ                Allhaming-AT  PZ 93 (Regensburg)-DE
# 119   Ivanka pri Dunaji-SK               Hagenbrunn-AT                Brno-CZ
#
#      Taken                                      First  \
# 0      1.0                         Kaunas-LTPoznań-PL
# 1      1.0                    Sofia-BGBudapest OLK-HU
# 2      1.0                    Sofia-BGBudapest OLK-HU
# 3      1.0                    Sofia-BGBudapest OLK-HU
# 4      1.0                         Lisboa-PTZagreb-HR
# 5      1.0                        Brüssel-BEZagreb-HR
# 6      1.0                      Barcelona-ESZagreb-HR
# 7      1.0             PZ 93 (Regensburg)-DEZagreb-HR
# 8      1.0                Eindhoven-Noord-NLZagreb-HR
# 9      1.0                         Slough-GBZagreb-HR
# 10     1.0                         Lisboa-PTZagreb-HR
# 11     1.0                        Brüssel-BEZagreb-HR
# 12     1.0                      Barcelona-ESZagreb-HR
# 13     1.0             PZ 93 (Regensburg)-DEZagreb-HR
# 14     1.0                Eindhoven-Noord-NLZagreb-HR
# 15     1.0                         Slough-GBZagreb-HR
# 16     1.0                         Lisboa-PTZagreb-HR
# 17     1.0                      Barcelona-ESZagreb-HR
# 18     1.0                         Lisboa-PTZagreb-HR
# 19     1.0                      Barcelona-ESZagreb-HR
# 20     1.0                 Sofia-BGAraba (Vitoria)-ES
# 21     1.0         Lieto (Turku)-FLAraba (Vitoria)-ES
# 22     1.0       Eindhoven-Noord-NLAraba (Vitoria)-ES
# 23     1.0                Lisboa-PTAraba (Vitoria)-ES
# 24     1.0     Ljubljana-SIPZ 90 (Feucht/Nürnberg)-DE
# 25     1.0  Budapest OLK-HUPZ 90 (Feucht/Nürnberg)-DE
# 26     1.0     Ljubljana-SIPZ 90 (Feucht/Nürnberg)-DE
# 27     1.0  Budapest OLK-HUPZ 90 (Feucht/Nürnberg)-DE
# 28     1.0                   Lisboa-PTPZ 50 (Köln)-DE
# 29     1.0                  Brüssel-BEPZ 50 (Köln)-DE
# 30     1.0                   Slough-GBPZ 50 (Köln)-DE
# 31     1.0          Eindhoven-Noord-NLPZ 50 (Köln)-DE
# 32     1.0                   Lisboa-PTPZ 50 (Köln)-DE
# 33     1.0                  Brüssel-BEPZ 50 (Köln)-DE
# 34     1.0                    Malmö-SEPZ 50 (Köln)-DE
# 35     1.0                   Slough-GBPZ 50 (Köln)-DE
# 36     1.0          Eindhoven-Noord-NLPZ 50 (Köln)-DE
# 37     1.0                 Ostrava-CZSuwałki (Ełk)-PL
# 38     1.0                 Ostrava-CZSuwałki (Ełk)-PL
# 39     1.0               Araba (Vitoria)-ESBrüssel-BE
# 40     1.0                        Lisboa-PTBrüssel-BE
# 41     1.0               Araba (Vitoria)-ESBrüssel-BE
# 42     1.0                        Lisboa-PTBrüssel-BE
# 43     1.0                        Slough-GBBrüssel-BE
# 44     1.0               Araba (Vitoria)-ESBrüssel-BE
# 45     1.0                        Lisboa-PTBrüssel-BE
# 46     1.0                        Slough-GBBrüssel-BE
# 47     1.0               Araba (Vitoria)-ESBrüssel-BE
# 48     1.0                        Lisboa-PTBrüssel-BE
# 49     1.0                        Slough-GBBrüssel-BE
# 50     1.0               Araba (Vitoria)-ESBrüssel-BE
# 51     1.0                    Malmö-SEBudapest OLK-HU
# 52     1.0        Vantaa (Helsinki)-FLBudapest OLK-HU
# 53     1.0                   Zabrze-PLBudapest OLK-HU
# 54     1.0                    Malmö-SEBudapest OLK-HU
# 55     1.0                   Slough-GBBudapest OLK-HU
# 56     1.0             PZ 15 (Rüdersdorf)-DEPoznań-PL
# 57     1.0                     Zaltbommel-NLPoznań-PL
# 58     1.0                 Lisboa-PTCombs la ville-FR
# 59     1.0        Araba (Vitoria)-ESCombs la ville-FR
# 60     1.0                 Lisboa-PTCombs la ville-FR
# 61     1.0        Araba (Vitoria)-ESCombs la ville-FR
# 62     1.0                 Lisboa-PTCombs la ville-FR
# 63     1.0        Araba (Vitoria)-ESCombs la ville-FR
# 64     1.0                 Lisboa-PTCombs la ville-FR
# 65     1.0        Araba (Vitoria)-ESCombs la ville-FR
# 66     1.0                 Lisboa-PTCombs la ville-FR
# 67     1.0        Araba (Vitoria)-ESCombs la ville-FR
# 68     1.0                Plzen 1-CZCombs la ville-FR
# 69     1.0                 Lisboa-PTCombs la ville-FR
# 70     1.0                 Lisboa-PTCombs la ville-FR
# 71     1.0        Araba (Vitoria)-ESCombs la ville-FR
# 72     1.0  Budapest OLK-HUPZ 90 (Feucht/Nürnberg)-DE
# 73     1.0        Vantaa (Helsinki)-FLBudapest OLK-HU
# 74     1.0                          Brüssel-BEWals-AT
# 75     1.0                  Eindhoven-Noord-NLWals-AT
# 76     1.0                 Lieto (Turku)-FLBrüssel-BE
# 77     1.0                    Malmö-SEPZ 50 (Köln)-DE
# 78     1.0                    Malmö-SEPZ 50 (Köln)-DE
# 79     1.0                    Malmö-SEPZ 50 (Köln)-DE
# 80     1.0                    Malmö-SEPZ 50 (Köln)-DE
# 81     1.0                        Malmö-SEKrupka 1-CZ
# 82     1.0                        Malmö-SEKrupka 1-CZ
# 83     1.0                        Malmö-SEKrupka 1-CZ
# 84     1.0                       Brüssel-BEKolding-DK
# 85     1.0               PZ 21 (Hamburg)-DEKolding-DK
# 86     1.0                Brüssel-BECombs la ville-FR
# 87     1.0                Plzen 1-CZCombs la ville-FR
# 88     1.0                 Slough-GBCombs la ville-FR
# 89     1.0                 Poznań-PLCombs la ville-FR
# 90     1.0                Brüssel-BECombs la ville-FR
# 91     1.0                Plzen 1-CZCombs la ville-FR
# 92     1.0                 Slough-GBCombs la ville-FR
# 93     1.0                 Poznań-PLCombs la ville-FR
# 94     1.0       Vantaa (Helsinki)-FLSuwałki (Ełk)-PL
# 95     1.0                        Slough-GBBrüssel-BE
# 96     1.0                        Slough-GBBrüssel-BE
# 97     1.0                        Slough-GBBrüssel-BE
# 98     1.0                   Lieto (Turku)-FLMalmö-SE
# 99     1.0                   Lieto (Turku)-FLMalmö-SE
# 100    1.0                  Eindhoven-Noord-NLWals-AT
# 101    1.0               Eindhoven-Noord-NLKolding-DK
# 102    1.0                 Malmö-SEEindhoven-Noord-NL
# 103    1.0       PZ 47 (Krefeld)-DEEindhoven-Noord-NL
# 104    1.0                 Malmö-SEEindhoven-Noord-NL
# 105    1.0                Poznań-PLEindhoven-Noord-NL
# 106    1.0                Slough-GBEindhoven-Noord-NL
# 107    1.0                Slough-GBEindhoven-Noord-NL
# 108    1.0               Brüssel-BEEindhoven-Noord-NL
# 109    1.0                        Poznań-PLBrüssel-BE
# 110    1.0                 Lieto (Turku)-FLKolding-DK
# 111    1.0                Eindhoven-Noord-NLSlough-GB
# 112    1.0                         Malmö-SEKolding-DK
# 113    1.0               Eindhoven-Noord-NLBrüssel-BE
# 114    1.0    Eindhoven-Noord-NLPZ 93 (Regensburg)-DE
# 115    1.0                        Zabrze-PLOstrava-CZ
# 116    1.0                Zabrze-PLZilina- Strecno-SK
# 117    1.0             Liesing-ATIvanka pri Dunaji-SK
# 118    1.0                     Ricany -CZAllhaming-AT
# 119    1.0          Ivanka pri Dunaji-SKHagenbrunn-AT
#
#                                            Second  Capacity_x  Capacity_y  \
# 0                               Poznań-PLMalmö-SE      9000.0     16764.0
# 1             Budapest OLK-HUVantaa (Helsinki)-FL      9000.0      9000.0
# 2                        Budapest OLK-HUKaunas-LT      9000.0      9000.0
# 3            Budapest OLK-HUPZ 93 (Regensburg)-DE      9000.0     16764.0
# 4                               Zagreb-HRSofia-BG      9000.0     16764.0
# 5                               Zagreb-HRSofia-BG      9000.0     16764.0
# 6                               Zagreb-HRSofia-BG      9000.0     16764.0
# 7                               Zagreb-HRSofia-BG     16764.0     16764.0
# 8                               Zagreb-HRSofia-BG      9000.0     16764.0
# 9                               Zagreb-HRSofia-BG      9000.0     16764.0
# 10                              Zagreb-HRSpata-GR      9000.0      9000.0
# 11                              Zagreb-HRSpata-GR      9000.0      9000.0
# 12                              Zagreb-HRSpata-GR      9000.0      9000.0
# 13                              Zagreb-HRSpata-GR     16764.0      9000.0
# 14                              Zagreb-HRSpata-GR      9000.0      9000.0
# 15                              Zagreb-HRSpata-GR      9000.0      9000.0
# 16                             Zagreb-HROradea-RO      9000.0      9000.0
# 17                             Zagreb-HROradea-RO      9000.0      9000.0
# 18                       Zagreb-HRBudapest OLK-HU      9000.0      9000.0
# 19                       Zagreb-HRBudapest OLK-HU      9000.0      9000.0
# 20                    Araba (Vitoria)-ESLisboa-PT      9000.0     16764.0
# 21                    Araba (Vitoria)-ESLisboa-PT      9000.0     16764.0
# 22                    Araba (Vitoria)-ESLisboa-PT     10608.0     16764.0
# 23                 Araba (Vitoria)-ESLjubljana-SI      9000.0      9000.0
# 24           PZ 90 (Feucht/Nürnberg)-DEBrüssel-BE      4080.0      9000.0
# 25           PZ 90 (Feucht/Nürnberg)-DEBrüssel-BE      3264.0      9000.0
# 26   PZ 90 (Feucht/Nürnberg)-DEEindhoven-Noord-NL      4080.0      9000.0
# 27   PZ 90 (Feucht/Nürnberg)-DEEindhoven-Noord-NL      3264.0      9000.0
# 28            PZ 50 (Köln)-DEIvanka pri Dunaji-SK       816.0     16764.0
# 29            PZ 50 (Köln)-DEIvanka pri Dunaji-SK    100584.0     16764.0
# 30            PZ 50 (Köln)-DEIvanka pri Dunaji-SK     16764.0     16764.0
# 31            PZ 50 (Köln)-DEIvanka pri Dunaji-SK     16764.0     16764.0
# 32                  PZ 50 (Köln)-DEHelsingborg-SE       816.0       816.0
# 33                    PZ 50 (Köln)-DELjubljana-SI    100584.0      9000.0
# 34                    PZ 50 (Köln)-DELjubljana-SI      9000.0      9000.0
# 35                    PZ 50 (Köln)-DELjubljana-SI     16764.0      9000.0
# 36                    PZ 50 (Köln)-DELjubljana-SI     16764.0      9000.0
# 37                      Suwałki (Ełk)-PLKaunas-LT      9000.0     16764.0
# 38           Suwałki (Ełk)-PLVantaa (Helsinki)-FL      9000.0     16764.0
# 39                           Brüssel-BEKolding-DK    100572.0      9000.0
# 40                           Brüssel-BEKolding-DK      9000.0      9000.0
# 41                            Brüssel-BEKaunas-LT    100572.0      9000.0
# 42                            Brüssel-BEKaunas-LT      9000.0      9000.0
# 43                            Brüssel-BEKaunas-LT    100572.0      9000.0
# 44                     Brüssel-BELieto (Turku)-FL    100572.0      9000.0
# 45                     Brüssel-BELieto (Turku)-FL      9000.0      9000.0
# 46                     Brüssel-BELieto (Turku)-FL    100572.0      9000.0
# 47                            Brüssel-BEPoznań-PL    100572.0      9000.0
# 48                            Brüssel-BEPoznań-PL      9000.0      9000.0
# 49                            Brüssel-BEPoznań-PL    100572.0      9000.0
# 50                      Brüssel-BEPZ 50 (Köln)-DE    100572.0    100584.0
# 51                        Budapest OLK-HUSofia-BG      9000.0     16764.0
# 52                        Budapest OLK-HUSofia-BG      9000.0     16764.0
# 53                        Budapest OLK-HUSofia-BG     33524.0     16764.0
# 54                       Budapest OLK-HUOradea-RO      9000.0      9000.0
# 55                       Budapest OLK-HUOradea-RO      9000.0      9000.0
# 56                             Poznań-PLKaunas-LT     83820.0      9000.0
# 57                             Poznań-PLKaunas-LT      4080.0      9000.0
# 58                Combs la ville-FRBettembourg-LU     33524.0      9000.0
# 59                Combs la ville-FRBettembourg-LU     16764.0      9000.0
# 60                    Combs la ville-FRPlzen 1-CZ     33524.0      9000.0
# 61                    Combs la ville-FRPlzen 1-CZ     16764.0      9000.0
# 62            Combs la ville-FREindhoven-Noord-NL     33524.0      9000.0
# 63            Combs la ville-FREindhoven-Noord-NL     16764.0      9000.0
# 64              Combs la ville-FRHall in Tirol-AT     33524.0      9000.0
# 65              Combs la ville-FRHall in Tirol-AT     16764.0      9000.0
# 66                     Combs la ville-FRDublin-IE     33524.0      9000.0
# 67                     Combs la ville-FRDublin-IE     16764.0      9000.0
# 68                     Combs la ville-FRDublin-IE     16764.0      9000.0
# 69               Combs la ville-FRPZ 50 (Köln)-DE     33524.0     16764.0
# 70                     Combs la ville-FRSlough-GB     33524.0     33524.0
# 71                     Combs la ville-FRSlough-GB     16764.0     33524.0
# 72       PZ 90 (Feucht/Nürnberg)-DEBettembourg-LU      3264.0      9000.0
# 73                    Budapest OLK-HULjubljana-SI      9000.0      9000.0
# 74                         Wals-ATBudapest OLK-HU     33524.0     16764.0
# 75                         Wals-ATBudapest OLK-HU     16764.0     16764.0
# 76                       Brüssel-BEBettembourg-LU      9000.0      9000.0
# 77                  PZ 50 (Köln)-DEBettembourg-LU      9000.0       816.0
# 78                       PZ 50 (Köln)-DELisboa-PT      9000.0      3264.0
# 79                       PZ 50 (Köln)-DEDublin-IE      9000.0      1632.0
# 80                      PZ 50 (Köln)-DEBrüssel-BE      9000.0      5712.0
# 81                Krupka 1-CZIvanka pri Dunaji-SK     67048.0      9000.0
# 82                           Krupka 1-CZZagreb-HR     67048.0      9000.0
# 83                        Krupka 1-CZAllhaming-AT     67048.0     67048.0
# 84                             Kolding-DKMalmö-SE      9000.0     50292.0
# 85                             Kolding-DKMalmö-SE     50288.0     50292.0
# 86                     Combs la ville-FRLisboa-PT     67048.0     33524.0
# 87                     Combs la ville-FRLisboa-PT     16764.0     33524.0
# 88                     Combs la ville-FRLisboa-PT     83812.0     33524.0
# 89                     Combs la ville-FRLisboa-PT     67048.0     33524.0
# 90            Combs la ville-FRAraba (Vitoria)-ES     67048.0    100572.0
# 91            Combs la ville-FRAraba (Vitoria)-ES     16764.0    100572.0
# 92            Combs la ville-FRAraba (Vitoria)-ES     83812.0    100572.0
# 93            Combs la ville-FRAraba (Vitoria)-ES     67048.0    100572.0
# 94             Suwałki (Ełk)-PLZilina- Strecno-SK      9000.0      9000.0
# 95                           Brüssel-BEPlzen 1-CZ    100572.0      9000.0
# 96                              Brüssel-BEWals-AT    100572.0     33524.0
# 97                   Brüssel-BEEindhoven-Noord-NL    100572.0    150876.0
# 98                            Malmö-SEKrupka 1-CZ      9000.0     67048.0
# 99                     Malmö-SEEindhoven-Noord-NL      9000.0     33524.0
# 100                              Wals-ATOradea-RO     16764.0      9000.0
# 101                    Kolding-DKLieto (Turku)-FL      9000.0      9000.0
# 102           Eindhoven-Noord-NLCombs la ville-FR     33524.0    100572.0
# 103           Eindhoven-Noord-NLCombs la ville-FR    109584.0    100572.0
# 104                   Eindhoven-Noord-NLSlough-GB     33524.0    100572.0
# 105                   Eindhoven-Noord-NLSlough-GB    100572.0    100572.0
# 106                  Eindhoven-Noord-NLKolding-DK    502860.0      9000.0
# 107          Eindhoven-Noord-NLPZ 47 (Krefeld)-DE    502860.0    569976.0
# 108          Eindhoven-Noord-NLPZ 47 (Krefeld)-DE    150876.0    569976.0
# 109                           Brüssel-BEDublin-IE     33524.0     16764.0
# 85       37311.0      35953.0
# 86       56316.0      21583.0
# 87        7649.0      21583.0
# 88       79757.0      21583.0
# 89       54125.0      21583.0
# 90       56316.0      87323.0
# 91        7649.0      87323.0
# 92       79757.0      87323.0
# 93       54125.0      87323.0
# 94        2726.0        482.0
# 95       97217.0       3435.0
# 96       97217.0      22423.0
# 97       97217.0     145562.0
# 98        5368.0      65733.0
# 99        5368.0      18792.0
# 100       8587.0       1351.0
# 101       6654.0       1813.0
# 102      18792.0      98782.0
# 103      96813.0      98782.0
# 104      18792.0      97873.0
# 105      93526.0      97873.0
# 106     475848.0       6654.0
# 107     475848.0     557200.0
# 108     145562.0     557200.0
# 109      23501.0      11413.0
# 110      27477.0      25037.0
# 111      97873.0      25330.0
# 112      83318.0      48234.0
# 113      50960.0      56316.0
# 114      61227.0      61227.0
# 115      98453.0      98453.0
# 116     128337.0     128337.0
# 117     146713.0     146713.0
# 118     199103.0     199103.0
# 119     201434.0     201434.0

# %%
#Freq_result[Freq_result["Truck Type"] == "Co-loading"]
co_loading_taken = Freq_result[Freq_result["Truck Type"] == "Co-loading"]

for row in co_loading_taken.index:
    ori = co_loading_taken.loc[row, "Ori_Hub"]
    dest = co_loading_taken.loc[row, "Dest_Hub"]
    print(ori, dest, cost[ori, dest, "Co-loading"])
# Out:
# PZ 50 (Köln)-DE Brüssel-BE 0.0362531615366261
# PZ 93 (Regensburg)-DE Wals-AT 0.03443058935814841
# PZ 50 (Köln)-DE Bettembourg-LU 0.03569145788594608
# PZ 50 (Köln)-DE Dublin-IE 0.11729058584894406
# Allhaming-AT PZ 93 (Regensburg)-DE 0.03619236459078979
# Eindhoven-Noord-NL Araba (Vitoria)-ES 0.13500523803842024
# Sofia-BG Hub Wien I-AT 0.1906274222222222
# PZ 21 (Hamburg)-DE Oslo-NO 0.17604950222222218
# Barcelona-ES Helsingborg-SE 0.41527795555555547
# Helsingborg-SE Poznań-PL 0.1480198222222222
# Helsingborg-SE Barcelona-ES 0.41578718222222216
# PZ 50 (Köln)-DE Lisboa-PT 0.41415590222222215
# Zaltbommel-NL Poznań-PL 0.16716248888888888
# Ljubljana-SI PZ 90 (Feucht/Nürnberg)-DE 0.10776888888888887
# Budapest OLK-HU Hub Wien I-AT 0.045990248888888884
# Budapest OLK-HU PZ 90 (Feucht/Nürnberg)-DE 0.13672779555555553
# Lisboa-PT PZ 50 (Köln)-DE 0.4134816622222222
# PZ 50 (Köln)-DE Helsingborg-SE 0.16044547555555552

# %% [markdown]
# ## Checking if some routes exist

# %%
Freq["Ori_C"] = Freq.apply(lambda row: row.Ori_Hub.rsplit("-")[-1], axis = 1)
Freq["Dest_C"] = Freq.apply(lambda row: row.Dest_Hub.rsplit("-")[-1], axis = 1)
Freq[Freq.Taken > 0]
# Out:
#                            Ori_Hub                    Dest_Hub     Truck Type  \
# 38                       Kaunas-LT                   Poznań-PL            Van
# 423                       Sofia-BG             Budapest OLK-HU            Van
# 533                      Lisboa-PT          Araba (Vitoria)-ES            Van
# 535                      Lisboa-PT           Combs la ville-FR  2 Swap Bodies
# 548                     Brüssel-BE              Bettembourg-LU            Van
# 556                     Brüssel-BE          Eindhoven-Noord-NL      Swap Body
# 756             Araba (Vitoria)-ES                   Lisboa-PT      Swap Body
# 786             Araba (Vitoria)-ES           Combs la ville-FR      Swap Body
# 961                     Ostrava-CZ          Zilina- Strecno-SK      Swap Body
# 963                     Ostrava-CZ          Zilina- Strecno-SK            Van
# 978                    Krupka 1-CZ        Ivanka pri Dunaji-SK            Van
# 1123                   Krupka 1-CZ                   Zagreb-HR            Van
# 1326                    Plzen 1-CZ           Combs la ville-FR      Swap Body
# 1704               PZ 50 (Köln)-DE                  Brüssel-BE     Co-loading
# 1713    PZ 90 (Feucht/Nürnberg)-DE                  Brüssel-BE            Van
# 2149         PZ 93 (Regensburg)-DE                     Wals-AT     Co-loading
# 2614               PZ 50 (Köln)-DE              Bettembourg-LU     Co-loading
# 2623    PZ 90 (Feucht/Nürnberg)-DE              Bettembourg-LU            Van
# 2918    PZ 90 (Feucht/Nürnberg)-DE          Eindhoven-Noord-NL            Van
# 2986            PZ 47 (Krefeld)-DE          Eindhoven-Noord-NL      Swap Body
# 2988            PZ 47 (Krefeld)-DE          Eindhoven-Noord-NL            Van
# 3044               PZ 50 (Köln)-DE                   Dublin-IE     Co-loading
# 3363               Budapest OLK-HU        Vantaa (Helsinki)-FL            Van
# 3376               Budapest OLK-HU                    Sofia-BG      Swap Body
# 3398               Budapest OLK-HU                   Kaunas-LT            Van
# 3418               Budapest OLK-HU                   Oradea-RO            Van
# 4446                    Liesing-AT        Ivanka pri Dunaji-SK      Swap Body
# 4448                    Liesing-AT        Ivanka pri Dunaji-SK            Van
# 4498                       Wals-AT                   Oradea-RO            Van
# 4696                       Wals-AT             Budapest OLK-HU      Swap Body
# 5426                  Allhaming-AT       PZ 93 (Regensburg)-DE      Swap Body
# 5429                  Allhaming-AT       PZ 93 (Regensburg)-DE     Co-loading
# 6106            Eindhoven-Noord-NL                  Brüssel-BE      Swap Body
# 6108            Eindhoven-Noord-NL                  Brüssel-BE            Van
# 6149            Eindhoven-Noord-NL          Araba (Vitoria)-ES     Co-loading
# 6171            Eindhoven-Noord-NL             PZ 50 (Köln)-DE      Swap Body
# 6190            Eindhoven-Noord-NL       PZ 93 (Regensburg)-DE  2 Swap Bodies
# 6216            Eindhoven-Noord-NL          PZ 47 (Krefeld)-DE      Swap Body
# 6305            Eindhoven-Noord-NL                   Slough-GB  2 Swap Bodies
# 6390                     Slough-GB                   Dublin-IE  2 Swap Bodies
# 6890                     Poznań-PL           Combs la ville-FR  2 Swap Bodies
# 7186          Ivanka pri Dunaji-SK               Hagenbrunn-AT      Swap Body
# 7188          Ivanka pri Dunaji-SK               Hagenbrunn-AT            Van
# 8246                    Kolding-DK                    Malmö-SE      Swap Body
# 8253                    Kolding-DK            Lieto (Turku)-FL            Van
# 8520                    Kolding-DK          PZ 21 (Hamburg)-DE  2 Swap Bodies
# 8550                    Kolding-DK       PZ 24 (Neumünster)-DE  2 Swap Bodies
# 8551                    Kolding-DK       PZ 24 (Neumünster)-DE      Swap Body
# 8611                     Zagreb-HR                    Sofia-BG      Swap Body
# 8668                     Zagreb-HR                    Spata-GR            Van
# ...                            ...                         ...            ...
# 15776                    Poznań-PL                    Malmö-SE      Swap Body
# 15899              Budapest OLK-HU  PZ 90 (Feucht/Nürnberg)-DE     Co-loading
# 15906              Budapest OLK-HU       PZ 93 (Regensburg)-DE      Swap Body
# 16120                    Zabrze-PL             Budapest OLK-HU  2 Swap Bodies
# 16160                    Slough-GB                  Brüssel-BE  2 Swap Bodies
# 16239                    Lisboa-PT             PZ 50 (Köln)-DE     Co-loading
# 16316             Suwałki (Ełk)-PL        Vantaa (Helsinki)-FL      Swap Body
# 16375                    Poznań-PL                  Brüssel-BE  2 Swap Bodies
# 16548              PZ 50 (Köln)-DE                Ljubljana-SI            Van
# 16565        PZ 93 (Regensburg)-DE                Ljubljana-SI  2 Swap Bodies
# 16660        PZ 93 (Regensburg)-DE             Budapest OLK-HU  2 Swap Bodies
# 16766                      Brno-CZ               Hagenbrunn-AT      Swap Body
# 16880                  Krupka 1-CZ                Allhaming-AT  2 Swap Bodies
# 17046                   Ricany -CZ                Allhaming-AT      Swap Body
# 17206              PZ 50 (Köln)-DE        Ivanka pri Dunaji-SK      Swap Body
# 17245        PZ 93 (Regensburg)-DE        Ivanka pri Dunaji-SK  2 Swap Bodies
# 17500                    Poznań-PL          Eindhoven-Noord-NL  2 Swap Bodies
# 17550                      Brno-CZ             Budapest OLK-HU  2 Swap Bodies
# 17755                    Zabrze-PL               Hagenbrunn-AT  2 Swap Bodies
# 17960                    Slough-GB           Combs la ville-FR  2 Swap Bodies
# 17961                    Slough-GB           Combs la ville-FR      Swap Body
# 18061  PZ 04 (Radefeld/Leipzig)-DE                 Krupka 1-CZ      Swap Body
# 18063  PZ 04 (Radefeld/Leipzig)-DE                 Krupka 1-CZ            Van
# 18551                     Malmö-SE                  Kolding-DK      Swap Body
# 18594              PZ 50 (Köln)-DE              Helsingborg-SE     Co-loading
# 19005                Hagenbrunn-AT                   Zabrze-PL  2 Swap Bodies
# 19006                Hagenbrunn-AT                   Zabrze-PL      Swap Body
# 19325                   Brüssel-BE                   Slough-GB  2 Swap Bodies
# 19326                   Brüssel-BE                   Slough-GB      Swap Body
# 19653                     Malmö-SE             PZ 50 (Köln)-DE            Van
# 19715           Eindhoven-Noord-NL           Combs la ville-FR  2 Swap Bodies
# 19725                    Slough-GB          Eindhoven-Noord-NL  2 Swap Bodies
# 19781           Eindhoven-Noord-NL                     Wals-AT      Swap Body
# 19888                   Ostrava-CZ            Suwałki (Ełk)-PL            Van
# 19896                   Ostrava-CZ                   Zabrze-PL      Swap Body
# 19898                   Ostrava-CZ                   Zabrze-PL            Van
# 20766        PZ 15 (Rüdersdorf)-DE                   Poznań-PL      Swap Body
# 20856                   Brüssel-BE             PZ 50 (Köln)-DE      Swap Body
# 21203             Suwałki (Ełk)-PL          Zilina- Strecno-SK            Van
# 21221                    Zabrze-PL          Zilina- Strecno-SK      Swap Body
# 21265             Lieto (Turku)-FL    Stockholm - Västberga-SE  2 Swap Bodies
# 21266             Lieto (Turku)-FL    Stockholm - Västberga-SE      Swap Body
# 21283             Lieto (Turku)-FL                    Malmö-SE            Van
# 21396                    Zabrze-PL                  Ostrava-CZ      Swap Body
# 21398                    Zabrze-PL                  Ostrava-CZ            Van
# 21671                Hagenbrunn-AT                     Brno-CZ      Swap Body
# 21673                Hagenbrunn-AT                     Brno-CZ            Van
# 22556           Zilina- Strecno-SK                  Ostrava-CZ      Swap Body
# 22591         Ivanka pri Dunaji-SK                     Brno-CZ      Swap Body
# 22636                    Slough-GB             PZ 50 (Köln)-DE      Swap Body
#
#        Taken Ori_C Dest_C
# 38       1.0    LT     PL
# 423      1.0    BG     HU
# 533      1.0    PT     ES
# 535      1.0    PT     FR
# 548      1.0    BE     LU
# 556      9.0    BE     NL
# 756      1.0    ES     PT
# 786      1.0    ES     FR
# 961      6.0    CZ     SK
# 963      1.0    CZ     SK
# 978      1.0    CZ     SK
# 1123     1.0    CZ     HR
# 1326     1.0    CZ     FR
# 1704     7.0    DE     BE
# 1713     1.0    DE     BE
# 2149    85.0    DE     AT
# 2614     1.0    DE     LU
# 2623     1.0    DE     LU
# 2918     1.0    DE     NL
# 2986     6.0    DE     NL
# 2988     1.0    DE     NL
# 3044     2.0    DE     IE
# 3363     1.0    HU     FL
# 3376     1.0    HU     BG
# 3398     1.0    HU     LT
# 3418     1.0    HU     RO
# 4446     9.0    AT     SK
# 4448     1.0    AT     SK
# 4498     1.0    AT     RO
# 4696     1.0    AT     HU
# 5426     7.0    AT     DE
# 5429   110.0    AT     DE
# 6106     3.0    NL     BE
# 6108     1.0    NL     BE
# 6149    13.0    NL     ES
# 6171     1.0    NL     DE
# 6190     2.0    NL     DE
# 6216    34.0    NL     DE
# 6305     3.0    NL     GB
# 6390     1.0    GB     IE
# 6890     2.0    PL     FR
# 7186    12.0    SK     AT
# 7188     1.0    SK     AT
# 8246     3.0    DK     SE
# 8253     1.0    DK     FL
# 8520     1.0    DK     DE
# 8550     1.0    DK     DE
# 8551     1.0    DK     DE
# 8611     1.0    HR     BG
# 8668     1.0    HR     GR
# ...      ...   ...    ...
# 15776    1.0    PL     SE
# 15899    4.0    HU     DE
# 15906    1.0    HU     DE
# 16120    1.0    PL     HU
# 16160    3.0    GB     BE
# 16239    1.0    PT     DE
# 16316    1.0    PL     FL
# 16375    1.0    PL     BE
# 16548    1.0    DE     SI
# 16565    1.0    DE     SI
# 16660    1.0    DE     HU
# 16766    2.0    CZ     AT
# 16880    2.0    CZ     AT
# 17046   12.0    CZ     AT
# 17206    1.0    DE     SK
# 17245    1.0    DE     SK
# 17500    3.0    PL     NL
# 17550    1.0    CZ     HU
# 17755    1.0    PL     AT
# 17960    2.0    GB     FR
# 17961    1.0    GB     FR
# 18061    2.0    DE     CZ
# 18063    1.0    DE     CZ
# 18551    6.0    SE     DK
# 18594    1.0    DE     SE
# 19005    1.0    AT     PL
# 19006    1.0    AT     PL
# 19325    1.0    BE     GB
# 19326    1.0    BE     GB
# 19653    1.0    SE     DE
# 19715    3.0    NL     FR
# 19725   15.0    GB     NL
# 19781    1.0    NL     AT
# 19888    1.0    CZ     PL
# 19896    4.0    CZ     PL
# 19898    1.0    CZ     PL
# 20766    5.0    DE     PL
# 20856    6.0    BE     DE
# 21203    1.0    PL     SK
# 21221    8.0    PL     SK
# 21265    3.0    FL     SE
# 21266    1.0    FL     SE
# 21283    1.0    FL     SE
# 21396    6.0    PL     CZ
# 21398    1.0    PL     CZ
# 21671   12.0    AT     CZ
# 21673    1.0    AT     CZ
# 22556    8.0    SK     CZ
# 22591    9.0    SK     CZ
# 22636    1.0    GB     DE
#
# [169 rows x 6 columns]

# %%
check = Freq.loc[(Freq["Ori_C"] == "AT") & (Freq["Dest_C"] == "CZ"), :]
check[check.Taken> 0]
# Out:
#              Ori_Hub Dest_Hub Truck Type  Taken Ori_C Dest_C
# 21671  Hagenbrunn-AT  Brno-CZ  Swap Body   12.0    AT     CZ
# 21673  Hagenbrunn-AT  Brno-CZ        Van    1.0    AT     CZ

# %% [markdown]
# # Check the relationship between Route Capacity and Demands

# %%
Route_Cap["Ori_C"] = Route_Cap.apply(lambda row: row.Ori_Hub.rsplit("-")[-1], axis = 1)
Route_Cap["Dest_C"] = Route_Cap.apply(lambda row: row.Dest_Hub.rsplit("-")[-1], axis = 1)
Route_Cap["Demands"] = Route_Cap.apply(lambda row: Z[row.Ori_C, row.Dest_C] if (row.Ori_C, row.Dest_C) in Z.keys() else 0, axis = 1)

# %%
# Route_Cap.loc[(Route_Cap["Ori_C"] == "DE") & (Route_Cap["Dest_C"] == "FL"), :]
Route_Cap[Route_Cap.Taken > 0]
# Out:
#                           Ori_Hub                    Dest_Hub     Taken Ori_C  \
# 7                       Kaunas-LT                   Poznań-PL      14.0    LT
# 84                       Sofia-BG             Budapest OLK-HU    1753.0    BG
# 106                     Lisboa-PT          Araba (Vitoria)-ES      26.0    PT
# 107                     Lisboa-PT           Combs la ville-FR   24967.0    PT
# 109                    Brüssel-BE              Bettembourg-LU     276.0    BE
# 111                    Brüssel-BE          Eindhoven-Noord-NL  145562.0    BE
# 151            Araba (Vitoria)-ES                   Lisboa-PT   10727.0    ES
# 157            Araba (Vitoria)-ES           Combs la ville-FR   10993.0    ES
# 192                    Ostrava-CZ          Zilina- Strecno-SK   98453.0    CZ
# 195                   Krupka 1-CZ        Ivanka pri Dunaji-SK     324.0    CZ
# 224                   Krupka 1-CZ                   Zagreb-HR     326.0    CZ
# 265                    Plzen 1-CZ           Combs la ville-FR    7649.0    CZ
# 340               PZ 50 (Köln)-DE                  Brüssel-BE    2564.0    DE
# 342    PZ 90 (Feucht/Nürnberg)-DE                  Brüssel-BE    1428.0    DE
# 429         PZ 93 (Regensburg)-DE                     Wals-AT   61227.0    DE
# 522               PZ 50 (Köln)-DE              Bettembourg-LU     402.0    DE
# 524    PZ 90 (Feucht/Nürnberg)-DE              Bettembourg-LU     157.0    DE
# 583    PZ 90 (Feucht/Nürnberg)-DE          Eindhoven-Noord-NL    1454.0    DE
# 597            PZ 47 (Krefeld)-DE          Eindhoven-Noord-NL   96813.0    DE
# 608               PZ 50 (Köln)-DE                   Dublin-IE    1115.0    DE
# 672               Budapest OLK-HU        Vantaa (Helsinki)-FL      17.0    HU
# 675               Budapest OLK-HU                    Sofia-BG    8580.0    HU
# 679               Budapest OLK-HU                   Kaunas-LT      31.0    HU
# 683               Budapest OLK-HU                   Oradea-RO    1429.0    HU
# 889                    Liesing-AT        Ivanka pri Dunaji-SK  146713.0    AT
# 899                       Wals-AT                   Oradea-RO    1351.0    AT
# 939                       Wals-AT             Budapest OLK-HU    7506.0    AT
# 1085                 Allhaming-AT       PZ 93 (Regensburg)-DE  199103.0    AT
# 1221           Eindhoven-Noord-NL                  Brüssel-BE   50960.0    NL
# 1229           Eindhoven-Noord-NL          Araba (Vitoria)-ES   10143.0    NL
# 1234           Eindhoven-Noord-NL             PZ 50 (Köln)-DE    8615.0    NL
# 1238           Eindhoven-Noord-NL       PZ 93 (Regensburg)-DE   61227.0    NL
# 1243           Eindhoven-Noord-NL          PZ 47 (Krefeld)-DE  557200.0    NL
# 1261           Eindhoven-Noord-NL                   Slough-GB   97873.0    NL
# 1278                    Slough-GB                   Dublin-IE   25330.0    GB
# 1378                    Poznań-PL           Combs la ville-FR   54125.0    PL
# 1437         Ivanka pri Dunaji-SK               Hagenbrunn-AT  201434.0    SK
# 1649                   Kolding-DK                    Malmö-SE   35953.0    DK
# 1650                   Kolding-DK            Lieto (Turku)-FL    1813.0    DK
# 1704                   Kolding-DK          PZ 21 (Hamburg)-DE   25037.0    DK
# 1710                   Kolding-DK       PZ 24 (Neumünster)-DE   48234.0    DK
# 1722                    Zagreb-HR                    Sofia-BG   10437.0    HR
# 1733                    Zagreb-HR                    Spata-GR    3219.0    HR
# 1736                    Zagreb-HR                   Oradea-RO     340.0    HR
# 1749                    Zagreb-HR             Budapest OLK-HU     395.0    HR
# 2071            Combs la ville-FR                   Lisboa-PT   21583.0    FR
# 2093            Combs la ville-FR            Hall in Tirol-AT    1784.0    FR
# 2100            Combs la ville-FR              Bettembourg-LU     326.0    FR
# 2104            Combs la ville-FR          Araba (Vitoria)-ES   87323.0    FR
# 2108            Combs la ville-FR                  Plzen 1-CZ     511.0    FR
# ...                           ...                         ...       ...   ...
# 3017              Budapest OLK-HU               Hub Wien I-AT    4238.0    HU
# 3053                    Slough-GB             Budapest OLK-HU    6228.0    GB
# 3059                    Zabrze-PL                   Oradea-RO    5630.0    PL
# 3070                   Brüssel-BE                     Wals-AT   22423.0    BE
# 3104             Suwałki (Ełk)-PL                   Kaunas-LT    7117.0    PL
# 3105                    Poznań-PL                   Kaunas-LT     856.0    PL
# 3122                     Malmö-SE          Eindhoven-Noord-NL   18792.0    SE
# 3132           Eindhoven-Noord-NL                 Krupka 1-CZ    8354.0    NL
# 3155                    Poznań-PL                    Malmö-SE    8508.0    PL
# 3179              Budapest OLK-HU  PZ 90 (Feucht/Nürnberg)-DE    2792.0    HU
# 3181              Budapest OLK-HU       PZ 93 (Regensburg)-DE   10730.0    HU
# 3224                    Zabrze-PL             Budapest OLK-HU   18538.0    PL
# 3232                    Slough-GB                  Brüssel-BE   97217.0    GB
# 3247                    Lisboa-PT             PZ 50 (Köln)-DE      91.0    PT
# 3263             Suwałki (Ełk)-PL        Vantaa (Helsinki)-FL   11256.0    PL
# 3275                    Poznań-PL                  Brüssel-BE   23501.0    PL
# 3309              PZ 50 (Köln)-DE                Ljubljana-SI    5663.0    DE
# 3313        PZ 93 (Regensburg)-DE                Ljubljana-SI   22360.0    DE
# 3332        PZ 93 (Regensburg)-DE             Budapest OLK-HU   22426.0    DE
# 3353                      Brno-CZ               Hagenbrunn-AT   22601.0    CZ
# 3376                  Krupka 1-CZ                Allhaming-AT   63353.0    CZ
# 3409                   Ricany -CZ                Allhaming-AT  199103.0    CZ
# 3441              PZ 50 (Köln)-DE        Ivanka pri Dunaji-SK    9002.0    DE
# 3449        PZ 93 (Regensburg)-DE        Ivanka pri Dunaji-SK   22870.0    DE
# 3500                    Poznań-PL          Eindhoven-Noord-NL   93526.0    PL
# 3510                      Brno-CZ             Budapest OLK-HU   28440.0    CZ
# 3551                    Zabrze-PL               Hagenbrunn-AT   28959.0    PL
# 3592                    Slough-GB           Combs la ville-FR   79757.0    GB
# 3612  PZ 04 (Radefeld/Leipzig)-DE                 Krupka 1-CZ   34848.0    DE
# 3710                     Malmö-SE                  Kolding-DK   83318.0    SE
# 3718              PZ 50 (Köln)-DE              Helsingborg-SE      54.0    DE
# 3801                Hagenbrunn-AT                   Zabrze-PL   37699.0    AT
# 3865                   Brüssel-BE                   Slough-GB   39911.0    BE
# 3930                     Malmö-SE             PZ 50 (Köln)-DE    5367.0    SE
# 3943           Eindhoven-Noord-NL           Combs la ville-FR   98782.0    NL
# 3945                    Slough-GB          Eindhoven-Noord-NL  475848.0    GB
# 3956           Eindhoven-Noord-NL                     Wals-AT    8587.0    NL
# 3977                   Ostrava-CZ            Suwałki (Ełk)-PL     147.0    CZ
# 3979                   Ostrava-CZ                   Zabrze-PL   61940.0    CZ
# 4153        PZ 15 (Rüdersdorf)-DE                   Poznań-PL   75953.0    DE
# 4171                   Brüssel-BE             PZ 50 (Köln)-DE   94607.0    BE
# 4240             Suwałki (Ełk)-PL          Zilina- Strecno-SK     482.0    PL
# 4244                    Zabrze-PL          Zilina- Strecno-SK  128337.0    PL
# 4253             Lieto (Turku)-FL    Stockholm - Västberga-SE  116234.0    FL
# 4256             Lieto (Turku)-FL                    Malmö-SE    5368.0    FL
# 4279                    Zabrze-PL                  Ostrava-CZ   98453.0    PL
# 4334                Hagenbrunn-AT                     Brno-CZ  201434.0    AT
# 4511           Zilina- Strecno-SK                  Ostrava-CZ  128337.0    SK
# 4518         Ivanka pri Dunaji-SK                     Brno-CZ  146713.0    SK
# 4527                    Slough-GB             PZ 50 (Köln)-DE    5510.0    GB
#
#      Dest_C  Demands
# 7        PL        0
# 84       HU        0
# 106      ES        0
# 107      FR        0
# 109      LU        0
# 111      NL        0
# 151      PT        0
# 157      FR        0
# 192      SK        0
# 195      SK        0
# 224      HR        0
# 265      FR        0
# 340      BE        0
# 342      BE        0
# 429      AT        0
# 522      LU        0
# 524      LU        0
# 583      NL        0
# 597      NL        0
# 608      IE        0
# 672      FL        0
# 675      BG        0
# 679      LT        0
# 683      RO        0
# 889      SK        0
# 899      RO        0
# 939      HU        0
# 1085     DE        0
# 1221     BE        0
# 1229     ES        0
# 1234     DE        0
# 1238     DE        0
# 1243     DE        0
# 1261     GB        0
# 1278     IE        0
# 1378     FR        0
# 1437     AT        0
# 1649     SE        0
# 1650     FL        0
# 1704     DE        0
# 1710     DE        0
# 1722     BG        0
# 1733     GR        0
# 1736     RO        0
# 1749     HU        0
# 2071     PT        0
# 2093     AT        0
# 2100     LU        0
# 2104     ES        0
# 2108     CZ        0
# ...     ...      ...
# 3017     AT     4238
# 3053     HU     5055
# 3059     RO     5630
# 3070     AT     5943
# 3104     LT     7053
# 3105     LT     7053
# 3122     NL     7676
# 3132     CZ     8354
# 3155     SE     8494
# 3179     DE     9025
# 3181     DE     9025
# 3224     HU    10217
# 3232     BE    10401
# 3247     DE    10770
# 3263     FL    11173
# 3275     BE    12766
# 3309     SI    22360
# 3313     SI    22360
# 3332     HU    22426
# 3353     AT    22601
# 3376     AT    22601
# 3409     AT    22601
# 3441     SK    22870
# 3449     SK    22870
# 3500     NL    25913
# 3510     HU    28440
# 3551     AT    28959
# 3592     FR    33992
# 3612     CZ    34848
# 3710     DK    35084
# 3718     SE    35601
# 3801     PL    37699
# 3865     GB    39911
# 3930     DE    48234
# 3943     FR    50960
# 3945     NL    60242
# 3956     AT    61227
# 3977     PL    61940
# 3979     PL    61940
# 4153     PL    75854
# 4171     DE    85320
# 4240     SK    98453
# 4244     SK    98453
# 4253     SE   116234
# 4256     SE   116234
# 4279     CZ   128337
# 4334     CZ   146713
# 4511     CZ   201434
# 4518     CZ   201434
# 4527     DE   471880
#
# [153 rows x 6 columns]

# %%
ind_hubs = model.getAttr('x', x_)
d_hubs = model.getAttr('x', x)

capacity_from_freq_by_hub = Freq_result.groupby(["Ori_Hub", "Dest_Hub"]).sum()
capacity_from_freq_by_hub.reset_index(inplace = True)
capacity_from_freq_by_hub.loc[:, "Clustering"] = 0

for row in capacity_from_freq_by_hub.index:
    ori = capacity_from_freq_by_hub.loc[row, "Ori_Hub"]
    dest = capacity_from_freq_by_hub.loc[row, "Dest_Hub"]
    
    try:
        ind_1 = sum(ind_hubs[p, q, i] for p, q, i in piq.select(ori, dest, "*"))
    except:
        ind_1 = 0
        
    try:
        ind_2 = sum(ind_hubs[i, p, q] for i, p, q in piq.select("*", ori, dest))
    except:
        ind_2 = 0
        
    try:
        d_1 = d_hubs[ori, dest]
        
    except:
        d_1 = 0
    
        
    capacity_from_freq_by_hub.loc[row, "Clustering"] = ind_1 + ind_2 + d_1
    
capacity_from_freq_by_hub
# Out:
#                         Ori_Hub                    Dest_Hub  Taken  Capacity  \
# 0                  Allhaming-AT       PZ 93 (Regensburg)-DE  117.0  207108.0
# 1            Araba (Vitoria)-ES                  Brüssel-BE    3.0  100572.0
# 2            Araba (Vitoria)-ES           Combs la ville-FR    1.0   16764.0
# 3            Araba (Vitoria)-ES                   Lisboa-PT    1.0   16764.0
# 4            Araba (Vitoria)-ES                Ljubljana-SI    1.0    9000.0
# 5                  Barcelona-ES              Helsingborg-SE    1.0     816.0
# 6                  Barcelona-ES        Ivanka pri Dunaji-SK    1.0    9000.0
# 7                  Barcelona-ES                   Zagreb-HR    1.0    9000.0
# 8                       Brno-CZ             Budapest OLK-HU    1.0   33524.0
# 9                       Brno-CZ               Hagenbrunn-AT    2.0   33528.0
# 10                   Brüssel-BE              Bettembourg-LU    1.0    9000.0
# 11                   Brüssel-BE           Combs la ville-FR    2.0   67048.0
# 12                   Brüssel-BE                   Dublin-IE    1.0   16764.0
# 13                   Brüssel-BE          Eindhoven-Noord-NL    9.0  150876.0
# 14                   Brüssel-BE                   Kaunas-LT    1.0    9000.0
# 15                   Brüssel-BE                  Kolding-DK    1.0    9000.0
# 16                   Brüssel-BE            Lieto (Turku)-FL    1.0    9000.0
# 17                   Brüssel-BE             PZ 50 (Köln)-DE    6.0  100584.0
# 18                   Brüssel-BE                  Plzen 1-CZ    1.0    9000.0
# 19                   Brüssel-BE                   Poznań-PL    1.0    9000.0
# 20                   Brüssel-BE                   Slough-GB    2.0   50288.0
# 21                   Brüssel-BE                     Wals-AT    1.0   33524.0
# 22                   Brüssel-BE                   Zagreb-HR    1.0    9000.0
# 23              Budapest OLK-HU                     Brno-CZ    1.0    9000.0
# 24              Budapest OLK-HU               Hub Wien I-AT   11.0    8976.0
# 25              Budapest OLK-HU        Ivanka pri Dunaji-SK    1.0    9000.0
# 26              Budapest OLK-HU                   Kaunas-LT    1.0    9000.0
# 27              Budapest OLK-HU                Ljubljana-SI    1.0    9000.0
# 28              Budapest OLK-HU                   Oradea-RO    1.0    9000.0
# 29              Budapest OLK-HU  PZ 90 (Feucht/Nürnberg)-DE    4.0    3264.0
# 30              Budapest OLK-HU       PZ 93 (Regensburg)-DE    1.0   16764.0
# 31              Budapest OLK-HU                    Sofia-BG    1.0   16764.0
# 32              Budapest OLK-HU        Vantaa (Helsinki)-FL    1.0    9000.0
# 33              Budapest OLK-HU                   Zabrze-PL    1.0    9000.0
# 34            Combs la ville-FR          Araba (Vitoria)-ES    3.0  100572.0
# 35            Combs la ville-FR              Bettembourg-LU    1.0    9000.0
# 36            Combs la ville-FR                   Dublin-IE    1.0    9000.0
# 37            Combs la ville-FR          Eindhoven-Noord-NL    1.0    9000.0
# 38            Combs la ville-FR            Hall in Tirol-AT    1.0    9000.0
# 39            Combs la ville-FR                   Lisboa-PT    1.0   33524.0
# 40            Combs la ville-FR             PZ 50 (Köln)-DE    1.0   16764.0
# 41            Combs la ville-FR                  Plzen 1-CZ    1.0    9000.0
# 42            Combs la ville-FR                   Slough-GB    1.0   33524.0
# 43           Eindhoven-Noord-NL          Araba (Vitoria)-ES   13.0   10608.0
# 44           Eindhoven-Noord-NL                  Brüssel-BE    4.0   59292.0
# 45           Eindhoven-Noord-NL           Combs la ville-FR    3.0  100572.0
# 46           Eindhoven-Noord-NL                  Kolding-DK    1.0    9000.0
# 47           Eindhoven-Noord-NL                 Krupka 1-CZ    1.0   16764.0
# 48           Eindhoven-Noord-NL          PZ 47 (Krefeld)-DE   34.0  569976.0
# 49           Eindhoven-Noord-NL             PZ 50 (Köln)-DE    1.0   16764.0
# ..                          ...                         ...    ...       ...
# 103  PZ 90 (Feucht/Nürnberg)-DE              Bettembourg-LU    1.0    9000.0
# 104  PZ 90 (Feucht/Nürnberg)-DE                  Brüssel-BE    1.0    9000.0
# 105  PZ 90 (Feucht/Nürnberg)-DE          Eindhoven-Noord-NL    1.0    9000.0
# 106       PZ 93 (Regensburg)-DE             Budapest OLK-HU    1.0   33524.0
# 107       PZ 93 (Regensburg)-DE        Ivanka pri Dunaji-SK    1.0   33524.0
# 108       PZ 93 (Regensburg)-DE                Ljubljana-SI    1.0   33524.0
# 109       PZ 93 (Regensburg)-DE                     Wals-AT   85.0   69360.0
# 110       PZ 93 (Regensburg)-DE                   Zagreb-HR    1.0   16764.0
# 111                  Plzen 1-CZ           Combs la ville-FR    1.0   16764.0
# 112                   Poznań-PL                  Brüssel-BE    1.0   33524.0
# 113                   Poznań-PL           Combs la ville-FR    2.0   67048.0
# 114                   Poznań-PL          Eindhoven-Noord-NL    3.0  100572.0
# 115                   Poznań-PL                   Kaunas-LT    1.0    9000.0
# 116                   Poznań-PL                  Kolding-DK    1.0    9000.0
# 117                   Poznań-PL                    Malmö-SE    1.0   16764.0
# 118                  Ricany -CZ                Allhaming-AT   12.0  201168.0
# 119                   Slough-GB              Bettembourg-LU    1.0    9000.0
# 120                   Slough-GB                  Brüssel-BE    3.0  100572.0
# 121                   Slough-GB             Budapest OLK-HU    1.0    9000.0
# 122                   Slough-GB           Combs la ville-FR    3.0   83812.0
# 123                   Slough-GB                   Dublin-IE    1.0   33524.0
# 124                   Slough-GB          Eindhoven-Noord-NL   15.0  502860.0
# 125                   Slough-GB             PZ 50 (Köln)-DE    1.0   16764.0
# 126                   Slough-GB                   Zagreb-HR    1.0    9000.0
# 127                    Sofia-BG          Araba (Vitoria)-ES    1.0    9000.0
# 128                    Sofia-BG             Budapest OLK-HU    1.0    9000.0
# 129                    Sofia-BG               Hub Wien I-AT    1.0     816.0
# 130            Suwałki (Ełk)-PL                   Kaunas-LT    1.0   16764.0
# 131            Suwałki (Ełk)-PL        Vantaa (Helsinki)-FL    1.0   16764.0
# 132            Suwałki (Ełk)-PL          Zilina- Strecno-SK    1.0    9000.0
# 133        Vantaa (Helsinki)-FL             Budapest OLK-HU    1.0    9000.0
# 134        Vantaa (Helsinki)-FL               Hagenbrunn-AT    1.0    9000.0
# 135        Vantaa (Helsinki)-FL            Suwałki (Ełk)-PL    1.0    9000.0
# 136                     Wals-AT             Budapest OLK-HU    1.0   16764.0
# 137                     Wals-AT          Eindhoven-Noord-NL    1.0    9000.0
# 138                     Wals-AT                   Oradea-RO    1.0    9000.0
# 139                  Wrocław-PL              Bettembourg-LU    1.0    9000.0
# 140                   Zabrze-PL             Budapest OLK-HU    1.0   33524.0
# 141                   Zabrze-PL               Hagenbrunn-AT    1.0   33524.0
# 142                   Zabrze-PL                Ljubljana-SI    1.0    9000.0
# 143                   Zabrze-PL                   Oradea-RO    1.0   16764.0
# 144                   Zabrze-PL                  Ostrava-CZ    7.0  109584.0
# 145                   Zabrze-PL                   Zagreb-HR    1.0    9000.0
# 146                   Zabrze-PL          Zilina- Strecno-SK    8.0  134112.0
# 147                   Zagreb-HR             Budapest OLK-HU    1.0    9000.0
# 148                   Zagreb-HR                   Oradea-RO    1.0    9000.0
# 149                   Zagreb-HR                    Sofia-BG    1.0   16764.0
# 150                   Zagreb-HR                    Spata-GR    1.0    9000.0
# 151               Zaltbommel-NL                   Poznań-PL    5.0    4080.0
# 152          Zilina- Strecno-SK                  Ostrava-CZ    8.0  134112.0
#
#      Clustering
# 0           1.0
# 1           6.0
# 2           6.0
# 3           3.0
# 4           2.0
# 5           1.0
# 6           1.0
# 7           5.0
# 8           1.0
# 9           1.0
# 10          1.0
# 11          4.0
# 12          2.0
# 13          2.0
# 14          4.0
# 15          4.0
# 16          4.0
# 17          3.0
# 18          2.0
# 19          4.0
# 20          1.0
# 21          3.0
# 22          3.0
# 23          1.0
# 24          1.0
# 25          1.0
# 26          1.0
# 27          2.0
# 28          2.0
# 29          3.0
# 30          2.0
# 31          3.0
# 32          1.0
# 33          1.0
# 34          4.0
# 35          2.0
# 36          3.0
# 37          2.0
# 38          2.0
# 39          4.0
# 40          1.0
# 41          2.0
# 42          2.0
# 43          1.0
# 44          1.0
# 45          2.0
# 46          3.0
# 47          1.0
# 48          2.0
# 49          2.0
# ..          ...
# 103         1.0
# 104         2.0
# 105         2.0
# 106         1.0
# 107         1.0
# 108         1.0
# 109         1.0
# 110         3.0
# 111         3.0
# 112         2.0
# 113         2.0
# 114         2.0
# 115         2.0
# 116         1.0
# 117         2.0
# 118         1.0
# 119         1.0
# 120         7.0
# 121         2.0
# 122         3.0
# 123         1.0
# 124         2.0
# 125         2.0
# 126         3.0
# 127         2.0
# 128         3.0
# 129         1.0
# 130         2.0
# 131         2.0
# 132         1.0
# 133         3.0
# 134         1.0
# 135         2.0
# 136         2.0
# 137         1.0
# 138         1.0
# 139         1.0
# 140         2.0
# 141         1.0
# 142         1.0
# 143         1.0
# 144         1.0
# 145         1.0
# 146         1.0
# 147         2.0
# 148         2.0
# 149         6.0
# 150         6.0
# 151         2.0
# 152         1.0
#
# [153 rows x 5 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
cap_gb_count = capacity_from_freq_by_hub.groupby("Clustering").count().reset_index()
sns.barplot(data = cap_gb_count, x = "Clustering", y = "Taken")

# %%
capacity_from_freq_by_hub
# Out:
#                         Ori_Hub                    Dest_Hub  Taken  Capacity  \
# 0                  Allhaming-AT       PZ 93 (Regensburg)-DE  117.0  207108.0
# 1            Araba (Vitoria)-ES                  Brüssel-BE    3.0  100572.0
# 2            Araba (Vitoria)-ES           Combs la ville-FR    1.0   16764.0
# 3            Araba (Vitoria)-ES                   Lisboa-PT    1.0   16764.0
# 4            Araba (Vitoria)-ES                Ljubljana-SI    1.0    9000.0
# 5                  Barcelona-ES              Helsingborg-SE    1.0     816.0
# 6                  Barcelona-ES        Ivanka pri Dunaji-SK    1.0    9000.0
# 7                  Barcelona-ES                   Zagreb-HR    1.0    9000.0
# 8                       Brno-CZ             Budapest OLK-HU    1.0   33524.0
# 9                       Brno-CZ               Hagenbrunn-AT    2.0   33528.0
# 10                   Brüssel-BE              Bettembourg-LU    1.0    9000.0
# 11                   Brüssel-BE           Combs la ville-FR    2.0   67048.0
# 12                   Brüssel-BE                   Dublin-IE    1.0   16764.0
# 13                   Brüssel-BE          Eindhoven-Noord-NL    9.0  150876.0
# 14                   Brüssel-BE                   Kaunas-LT    1.0    9000.0
# 15                   Brüssel-BE                  Kolding-DK    1.0    9000.0
# 16                   Brüssel-BE            Lieto (Turku)-FL    1.0    9000.0
# 17                   Brüssel-BE             PZ 50 (Köln)-DE    6.0  100584.0
# 18                   Brüssel-BE                  Plzen 1-CZ    1.0    9000.0
# 19                   Brüssel-BE                   Poznań-PL    1.0    9000.0
# 20                   Brüssel-BE                   Slough-GB    2.0   50288.0
# 21                   Brüssel-BE                     Wals-AT    1.0   33524.0
# 22                   Brüssel-BE                   Zagreb-HR    1.0    9000.0
# 23              Budapest OLK-HU                     Brno-CZ    1.0    9000.0
# 24              Budapest OLK-HU               Hub Wien I-AT   11.0    8976.0
# 25              Budapest OLK-HU        Ivanka pri Dunaji-SK    1.0    9000.0
# 26              Budapest OLK-HU                   Kaunas-LT    1.0    9000.0
# 27              Budapest OLK-HU                Ljubljana-SI    1.0    9000.0
# 28              Budapest OLK-HU                   Oradea-RO    1.0    9000.0
# 29              Budapest OLK-HU  PZ 90 (Feucht/Nürnberg)-DE    4.0    3264.0
# 30              Budapest OLK-HU       PZ 93 (Regensburg)-DE    1.0   16764.0
# 31              Budapest OLK-HU                    Sofia-BG    1.0   16764.0
# 32              Budapest OLK-HU        Vantaa (Helsinki)-FL    1.0    9000.0
# 33              Budapest OLK-HU                   Zabrze-PL    1.0    9000.0
# 34            Combs la ville-FR          Araba (Vitoria)-ES    3.0  100572.0
# 35            Combs la ville-FR              Bettembourg-LU    1.0    9000.0
# 36            Combs la ville-FR                   Dublin-IE    1.0    9000.0
# 37            Combs la ville-FR          Eindhoven-Noord-NL    1.0    9000.0
# 38            Combs la ville-FR            Hall in Tirol-AT    1.0    9000.0
# 39            Combs la ville-FR                   Lisboa-PT    1.0   33524.0
# 40            Combs la ville-FR             PZ 50 (Köln)-DE    1.0   16764.0
# 41            Combs la ville-FR                  Plzen 1-CZ    1.0    9000.0
# 42            Combs la ville-FR                   Slough-GB    1.0   33524.0
# 43           Eindhoven-Noord-NL          Araba (Vitoria)-ES   13.0   10608.0
# 44           Eindhoven-Noord-NL                  Brüssel-BE    4.0   59292.0
# 45           Eindhoven-Noord-NL           Combs la ville-FR    3.0  100572.0
# 46           Eindhoven-Noord-NL                  Kolding-DK    1.0    9000.0
# 47           Eindhoven-Noord-NL                 Krupka 1-CZ    1.0   16764.0
# 48           Eindhoven-Noord-NL          PZ 47 (Krefeld)-DE   34.0  569976.0
# 49           Eindhoven-Noord-NL             PZ 50 (Köln)-DE    1.0   16764.0
# ..                          ...                         ...    ...       ...
# 103  PZ 90 (Feucht/Nürnberg)-DE              Bettembourg-LU    1.0    9000.0
# 104  PZ 90 (Feucht/Nürnberg)-DE                  Brüssel-BE    1.0    9000.0
# 105  PZ 90 (Feucht/Nürnberg)-DE          Eindhoven-Noord-NL    1.0    9000.0
# 106       PZ 93 (Regensburg)-DE             Budapest OLK-HU    1.0   33524.0
# 107       PZ 93 (Regensburg)-DE        Ivanka pri Dunaji-SK    1.0   33524.0
# 108       PZ 93 (Regensburg)-DE                Ljubljana-SI    1.0   33524.0
# 109       PZ 93 (Regensburg)-DE                     Wals-AT   85.0   69360.0
# 110       PZ 93 (Regensburg)-DE                   Zagreb-HR    1.0   16764.0
# 111                  Plzen 1-CZ           Combs la ville-FR    1.0   16764.0
# 112                   Poznań-PL                  Brüssel-BE    1.0   33524.0
# 113                   Poznań-PL           Combs la ville-FR    2.0   67048.0
# 114                   Poznań-PL          Eindhoven-Noord-NL    3.0  100572.0
# 115                   Poznań-PL                   Kaunas-LT    1.0    9000.0
# 116                   Poznań-PL                  Kolding-DK    1.0    9000.0
# 117                   Poznań-PL                    Malmö-SE    1.0   16764.0
# 118                  Ricany -CZ                Allhaming-AT   12.0  201168.0
# 119                   Slough-GB              Bettembourg-LU    1.0    9000.0
# 120                   Slough-GB                  Brüssel-BE    3.0  100572.0
# 121                   Slough-GB             Budapest OLK-HU    1.0    9000.0
# 122                   Slough-GB           Combs la ville-FR    3.0   83812.0
# 123                   Slough-GB                   Dublin-IE    1.0   33524.0
# 124                   Slough-GB          Eindhoven-Noord-NL   15.0  502860.0
# 125                   Slough-GB             PZ 50 (Köln)-DE    1.0   16764.0
# 126                   Slough-GB                   Zagreb-HR    1.0    9000.0
# 127                    Sofia-BG          Araba (Vitoria)-ES    1.0    9000.0
# 128                    Sofia-BG             Budapest OLK-HU    1.0    9000.0
# 129                    Sofia-BG               Hub Wien I-AT    1.0     816.0
# 130            Suwałki (Ełk)-PL                   Kaunas-LT    1.0   16764.0
# 131            Suwałki (Ełk)-PL        Vantaa (Helsinki)-FL    1.0   16764.0
# 132            Suwałki (Ełk)-PL          Zilina- Strecno-SK    1.0    9000.0
# 133        Vantaa (Helsinki)-FL             Budapest OLK-HU    1.0    9000.0
# 134        Vantaa (Helsinki)-FL               Hagenbrunn-AT    1.0    9000.0
# 135        Vantaa (Helsinki)-FL            Suwałki (Ełk)-PL    1.0    9000.0
# 136                     Wals-AT             Budapest OLK-HU    1.0   16764.0
# 137                     Wals-AT          Eindhoven-Noord-NL    1.0    9000.0
# 138                     Wals-AT                   Oradea-RO    1.0    9000.0
# 139                  Wrocław-PL              Bettembourg-LU    1.0    9000.0
# 140                   Zabrze-PL             Budapest OLK-HU    1.0   33524.0
# 141                   Zabrze-PL               Hagenbrunn-AT    1.0   33524.0
# 142                   Zabrze-PL                Ljubljana-SI    1.0    9000.0
# 143                   Zabrze-PL                   Oradea-RO    1.0   16764.0
# 144                   Zabrze-PL                  Ostrava-CZ    7.0  109584.0
# 145                   Zabrze-PL                   Zagreb-HR    1.0    9000.0
# 146                   Zabrze-PL          Zilina- Strecno-SK    8.0  134112.0
# 147                   Zagreb-HR             Budapest OLK-HU    1.0    9000.0
# 148                   Zagreb-HR                   Oradea-RO    1.0    9000.0
# 149                   Zagreb-HR                    Sofia-BG    1.0   16764.0
# 150                   Zagreb-HR                    Spata-GR    1.0    9000.0
# 151               Zaltbommel-NL                   Poznań-PL    5.0    4080.0
# 152          Zilina- Strecno-SK                  Ostrava-CZ    8.0  134112.0
#
#      Clustering
# 0           1.0
# 1           6.0
# 2           6.0
# 3           3.0
# 4           2.0
# 5           1.0
# 6           1.0
# 7           5.0
# 8           1.0
# 9           1.0
# 10          1.0
# 11          4.0
# 12          2.0
# 13          2.0
# 14          4.0
# 15          4.0
# 16          4.0
# 17          3.0
# 18          2.0
# 19          4.0
# 20          1.0
# 21          3.0
# 22          3.0
# 23          1.0
# 24          1.0
# 25          1.0
# 26          1.0
# 27          2.0
# 28          2.0
# 29          3.0
# 30          2.0
# 31          3.0
# 32          1.0
# 33          1.0
# 34          4.0
# 35          2.0
# 36          3.0
# 37          2.0
# 38          2.0
# 39          4.0
# 40          1.0
# 41          2.0
# 42          2.0
# 43          1.0
# 44          1.0
# 45          2.0
# 46          3.0
# 47          1.0
# 48          2.0
# 49          2.0
# ..          ...
# 103         1.0
# 104         2.0
# 105         2.0
# 106         1.0
# 107         1.0
# 108         1.0
# 109         1.0
# 110         3.0
# 111         3.0
# 112         2.0
# 113         2.0
# 114         2.0
# 115         2.0
# 116         1.0
# 117         2.0
# 118         1.0
# 119         1.0
# 120         7.0
# 121         2.0
# 122         3.0
# 123         1.0
# 124         2.0
# 125         2.0
# 126         3.0
# 127         2.0
# 128         3.0
# 129         1.0
# 130         2.0
# 131         2.0
# 132         1.0
# 133         3.0
# 134         1.0
# 135         2.0
# 136         2.0
# 137         1.0
# 138         1.0
# 139         1.0
# 140         2.0
# 141         1.0
# 142         1.0
# 143         1.0
# 144         1.0
# 145         1.0
# 146         1.0
# 147         2.0
# 148         2.0
# 149         6.0
# 150         6.0
# 151         2.0
# 152         1.0
#
# [153 rows x 5 columns]

# %%
Co_load[Co_load.Amount > 0]
# Out:
#                           Ori_Hub                    Dest_Hub  Amount
# 7                       Kaunas-LT                   Poznań-PL     4.0
# 84                       Sofia-BG             Budapest OLK-HU   525.0
# 106                     Lisboa-PT          Araba (Vitoria)-ES     7.0
# 107                     Lisboa-PT           Combs la ville-FR  2000.0
# 109                    Brüssel-BE              Bettembourg-LU    82.0
# 111                    Brüssel-BE          Eindhoven-Noord-NL  1328.0
# 151            Araba (Vitoria)-ES                   Lisboa-PT  1509.0
# 157            Araba (Vitoria)-ES           Combs la ville-FR  1442.0
# 192                    Ostrava-CZ          Zilina- Strecno-SK  2000.0
# 195                   Krupka 1-CZ        Ivanka pri Dunaji-SK    97.0
# 224                   Krupka 1-CZ                   Zagreb-HR    97.0
# 265                    Plzen 1-CZ           Combs la ville-FR  2000.0
# 340               PZ 50 (Köln)-DE                  Brüssel-BE   769.0
# 342    PZ 90 (Feucht/Nürnberg)-DE                  Brüssel-BE   428.0
# 429         PZ 93 (Regensburg)-DE                     Wals-AT  2000.0
# 522               PZ 50 (Köln)-DE              Bettembourg-LU   103.0
# 524    PZ 90 (Feucht/Nürnberg)-DE              Bettembourg-LU    47.0
# 583    PZ 90 (Feucht/Nürnberg)-DE          Eindhoven-Noord-NL   436.0
# 597            PZ 47 (Krefeld)-DE          Eindhoven-Noord-NL  2000.0
# 608               PZ 50 (Köln)-DE                   Dublin-IE   129.0
# 672               Budapest OLK-HU        Vantaa (Helsinki)-FL     5.0
# 675               Budapest OLK-HU                    Sofia-BG  2000.0
# 679               Budapest OLK-HU                   Kaunas-LT     9.0
# 683               Budapest OLK-HU                   Oradea-RO   428.0
# 889                    Liesing-AT        Ivanka pri Dunaji-SK  2000.0
# 899                       Wals-AT                   Oradea-RO   405.0
# 939                       Wals-AT             Budapest OLK-HU  2000.0
# 1085                 Allhaming-AT       PZ 93 (Regensburg)-DE  2000.0
# 1221           Eindhoven-Noord-NL                  Brüssel-BE  2000.0
# 1229           Eindhoven-Noord-NL          Araba (Vitoria)-ES   116.0
# 1234           Eindhoven-Noord-NL             PZ 50 (Köln)-DE  2000.0
# 1238           Eindhoven-Noord-NL       PZ 93 (Regensburg)-DE  1455.0
# 1243           Eindhoven-Noord-NL          PZ 47 (Krefeld)-DE  2000.0
# 1261           Eindhoven-Noord-NL                   Slough-GB   674.0
# 1278                    Slough-GB                   Dublin-IE  2000.0
# 1378                    Poznań-PL           Combs la ville-FR  2000.0
# 1437         Ivanka pri Dunaji-SK               Hagenbrunn-AT  2000.0
# 1649                   Kolding-DK                    Malmö-SE  2000.0
# 1650                   Kolding-DK            Lieto (Turku)-FL   543.0
# 1704                   Kolding-DK          PZ 21 (Hamburg)-DE  2000.0
# 1710                   Kolding-DK       PZ 24 (Neumünster)-DE   513.0
# 1722                    Zagreb-HR                    Sofia-BG  1581.0
# 1733                    Zagreb-HR                    Spata-GR   965.0
# 1736                    Zagreb-HR                   Oradea-RO   102.0
# 1749                    Zagreb-HR             Budapest OLK-HU   118.0
# 2071            Combs la ville-FR                   Lisboa-PT  2000.0
# 2093            Combs la ville-FR            Hall in Tirol-AT   535.0
# 2100            Combs la ville-FR              Bettembourg-LU    97.0
# 2104            Combs la ville-FR          Araba (Vitoria)-ES  2000.0
# 2108            Combs la ville-FR                  Plzen 1-CZ   153.0
# ...                           ...                         ...     ...
# 3017              Budapest OLK-HU               Hub Wien I-AT  1184.0
# 3053                    Slough-GB             Budapest OLK-HU   693.0
# 3059                    Zabrze-PL                   Oradea-RO  1689.0
# 3070                   Brüssel-BE                     Wals-AT  2000.0
# 3104             Suwałki (Ełk)-PL                   Kaunas-LT  2000.0
# 3105                    Poznań-PL                   Kaunas-LT   256.0
# 3122                     Malmö-SE          Eindhoven-Noord-NL  2000.0
# 3132           Eindhoven-Noord-NL                 Krupka 1-CZ  2000.0
# 3155                    Poznań-PL                    Malmö-SE  2000.0
# 3179              Budapest OLK-HU  PZ 90 (Feucht/Nürnberg)-DE   118.0
# 3181              Budapest OLK-HU       PZ 93 (Regensburg)-DE  1508.0
# 3224                    Zabrze-PL             Budapest OLK-HU  2000.0
# 3232                    Slough-GB                  Brüssel-BE   838.0
# 3247                    Lisboa-PT             PZ 50 (Köln)-DE    27.0
# 3263             Suwałki (Ełk)-PL        Vantaa (Helsinki)-FL  1377.0
# 3275                    Poznań-PL                  Brüssel-BE  2000.0
# 3309              PZ 50 (Köln)-DE                Ljubljana-SI   834.0
# 3313        PZ 93 (Regensburg)-DE                Ljubljana-SI  2000.0
# 3332        PZ 93 (Regensburg)-DE             Budapest OLK-HU  2000.0
# 3353                      Brno-CZ               Hagenbrunn-AT  2000.0
# 3376                  Krupka 1-CZ                Allhaming-AT   923.0
# 3409                   Ricany -CZ                Allhaming-AT   516.0
# 3441              PZ 50 (Köln)-DE        Ivanka pri Dunaji-SK  1940.0
# 3449        PZ 93 (Regensburg)-DE        Ivanka pri Dunaji-SK  2000.0
# 3500                    Poznań-PL          Eindhoven-Noord-NL  1761.0
# 3510                      Brno-CZ             Budapest OLK-HU  1271.0
# 3551                    Zabrze-PL               Hagenbrunn-AT  1141.0
# 3592                    Slough-GB           Combs la ville-FR  1013.0
# 3612  PZ 04 (Radefeld/Leipzig)-DE                 Krupka 1-CZ  1920.0
# 3710                     Malmö-SE                  Kolding-DK  2000.0
# 3718              PZ 50 (Köln)-DE              Helsingborg-SE    16.0
# 3801                Hagenbrunn-AT                   Zabrze-PL  2000.0
# 3865                   Brüssel-BE                   Slough-GB  2000.0
# 3930                     Malmö-SE             PZ 50 (Köln)-DE   908.0
# 3943           Eindhoven-Noord-NL           Combs la ville-FR   447.0
# 3945                    Slough-GB          Eindhoven-Noord-NL  2000.0
# 3956           Eindhoven-Noord-NL                     Wals-AT  2000.0
# 3977                   Ostrava-CZ            Suwałki (Ełk)-PL    44.0
# 3979                   Ostrava-CZ                   Zabrze-PL  2000.0
# 4153        PZ 15 (Rüdersdorf)-DE                   Poznań-PL  1966.0
# 4171                   Brüssel-BE             PZ 50 (Köln)-DE  1494.0
# 4240             Suwałki (Ełk)-PL          Zilina- Strecno-SK   144.0
# 4244                    Zabrze-PL          Zilina- Strecno-SK  1443.0
# 4253             Lieto (Turku)-FL    Stockholm - Västberga-SE   275.0
# 4256             Lieto (Turku)-FL                    Malmö-SE   908.0
# 4279                    Zabrze-PL                  Ostrava-CZ  2000.0
# 4334                Hagenbrunn-AT                     Brno-CZ  2000.0
# 4511           Zilina- Strecno-SK                  Ostrava-CZ  1443.0
# 4518         Ivanka pri Dunaji-SK                     Brno-CZ  1040.0
# 4527                    Slough-GB             PZ 50 (Köln)-DE  1653.0
#
# [153 rows x 3 columns]
