# %%
from gurobipy import Model, GRB, quicksum, tuplelist
import numpy as np
import pandas as pd

# %%
# The following file works as a reference table to match the names of 2 sheets
hub_list = pd.read_csv('Database/Hub list.csv')
hub_list.Ref_City = hub_list.Ref_City + "-" + hub_list.Country

# drop duplicates
hub_list.drop_duplicates(subset = "Ref_City", keep='first', inplace=True)


hub_ref = {}
for row in hub_list.index:
    hub_ref[hub_list.loc[row, "City"]] = hub_list.loc[row, "Ref_City"]

    
    
def name_transform(city_name):
    if city_name in hub_ref.keys():
        return hub_ref[city_name]
    else:
        return city_name

# %%
# Simple Version
masterfile = pd.read_excel("Database/Simple/Simple Routes.xlsx", sheet_name = 0)

# Complete Version
#masterfile = pd.read_csv("Database/inter_distances.csv")

# %%
# Import forecast for creating the country set
forecast = pd.read_csv("Database/Average_Forecast.csv")
forecast.fillna(0, inplace = True)

# Only satisfied those the current network can reach
# Otherwise the solution would be infeasible

used_c = masterfile["Origin Country"].unique().tolist() +  masterfile["Destination Country"].unique().tolist() # Not every hubs in the hub list is used
used_c = list( dict.fromkeys(used_c) )  # Remove duplicate

all_c = forecast.Origin.unique().tolist() +  forecast.Destination.unique().tolist() # Not every hubs in the hub list is used
all_c = list( dict.fromkeys(all_c) )  # Remove duplicate

for x in used_c:
    try:
        all_c.remove(x)
    except:
        continue
        
for c in all_c:
    forecast["Origin"].replace(c, np.nan, inplace = True)
    forecast["Destination"].replace(c, np.nan, inplace = True)
forecast.dropna(how = "any", inplace = True)


# Set up the threshold for the demands
minimum_demands = 0
maximum_demands = 10000000000
forecast["Target"] = forecast.apply(lambda row: row.Average if row.Average >= minimum_demands else 0, axis = 1)

forecast["Target"] = forecast.apply(lambda row: row.Target if row.Target <= maximum_demands else 0, axis = 1)


forecast = forecast[forecast["Target"] > 0]
country_set = list(zip(forecast["Origin"].to_list(), forecast["Destination"].to_list()))

origin_list = list(forecast["Origin"].unique())
dst_list =  list(forecast["Destination"].unique())

country_with_forecast = forecast.Origin.unique().tolist() +  forecast.Destination.unique().tolist()
country_with_forecast = list( dict.fromkeys(country_with_forecast))  # Remove Dup

# %%
len(forecast)
# Out:
# 212

# %% [markdown]
# # Define the Set
# ## 1. Hubs in each Country (L) & All Hubs (H)

# %%
used_hubs = masterfile.From.unique().tolist() +  masterfile.To.unique().tolist() # Not every hubs in the hub list is used
used_hubs = list( dict.fromkeys(used_hubs) )  # Remove duplicate

hub_list_used = hub_list.set_index("Ref_City")
hub_list_used = hub_list_used.loc[hub_list_used.index.isin(used_hubs), :]
hub_list_used.reset_index(inplace = True)

#hub_list_used["Country"] = hub_list_used.apply(lambda row: row["Ref_City"].split("-")[-1], axis = 1) # To fill NA in country

L = {}
for country in country_with_forecast:  # hub_list_used.Country.unique():
    hub_collect = hub_list_used[hub_list_used.loc[:, "Country"] == country]["Ref_City"].tolist()
    L[country] = hub_collect

    #for row in hub_list_used.index:

    #L[hub_list_used.loc[row, "Country"]].append(hub_list_used.loc[row, "Ref_City"])
H = hub_list_used.Ref_City.unique().tolist() # All hubs

# %% [markdown]
# ## 2. European Countries (E)

# %%
E = country_with_forecast # from the "forecast" file

# %% [markdown]
# ## 3. Truck Types (T)

# %%
truck_cap = pd.read_csv("Database/TruckVSCap.csv")
T = truck_cap["Truck Type"].tolist()
#T.remove("Swap Body") # To simplify the model

# %% [markdown]
# ## Define subset for the later use

# %%
# Define tuplelist for the assign of variables

mjk = tuplelist([(m,j,k) for m, k in country_set for j in country_with_forecast if (m != j) & (j != k)])
mk = tuplelist([(m,k) for m, k in country_set])

mj_k = [(m, j) for m in origin_list for j in country_with_forecast if (m, j) not in mk if m != j]   # m connects to j exlcudes k (transit countries)
mj_k = list( dict.fromkeys(mj_k) )

#j_mk = [(m, k) for m in country_with_forecast for k in dst_list if (m not in origin_list) & (m != k)]   # m connects to j exlcudes k (transit countries)
j_mk = [(j, k)  for j in country_with_forecast for k in dst_list if (j,k) not in mk if k != j]  
#j_mk = [(j, k) for m, j, k in mjk if (j,k) not in mk]   # j excludes m (transit countries), connects to k
j_mk = list( dict.fromkeys(j_mk) )

mk_all = j_mk + mj_k + mk
mk_all = list( dict.fromkeys(mk_all) )

pq = tuplelist([(p,q) for m,k in mk for p in L[m] for q in L[k]])
piq = tuplelist([(p,i,q) for (m,j,k) in mjk for p in L[m] for i in L[j] for q in L[k]])
pq_all = tuplelist((p, q) for m,k in mk_all for p in L[m] for q in L[k])
pqt = tuplelist([(p,q,t) for p,q in pq_all for t in T])

# %% [markdown]
# # Define all the parameters
#
# ## 1. Cost:
# Transportation Cost between hub p ∈ H and hub q ∈ H using truck t ∈ T (Euro/ kg)

# %%
cost_file = pd.read_csv("Database/Costs.csv")

# %%
cost = {}
for row in cost_file.index:
    cost_key = (cost_file["From"][row], cost_file["To"][row], cost_file["Truck type"][row])
    cost[cost_key] = cost_file["Cost/kg"][row]
'''    
cl_distance = 500

if "Co-loading" in T:
    for p, q in pq_all:
        cost[(p, q, "Co-loading")] = max([cost[p_s, q_s, t] for p_s, q_s, t in pqt.select(p, q, "*") if t != "Co-loading"])*1.5 if cost[(p, q, "Van")] < ((0.6*cl_distance+5)/2250) else 99
        # (0.6*500+5)/2250 use distance as a filter, over 500 km, the Co-loading opportunities are less

for p, q in pq:
    cost[(p, q, "Co-loading-Extra")] = cost[(p, q, "Van")]*10
'''
# Out:
# '    \ncl_distance = 500\n\nif "Co-loading" in T:\n    for p, q in pq_all:\n        cost[(p, q, "Co-loading")] = max([cost[p_s, q_s, t] for p_s, q_s, t in pqt.select(p, q, "*") if t != "Co-loading"])*1.5 if cost[(p, q, "Van")] < ((0.6*cl_distance+5)/2250) else 99\n        # (0.6*500+5)/2250 use distance as a filter, over 500 km, the Co-loading opportunities are less\n\nfor p, q in pq:\n    cost[(p, q, "Co-loading-Extra")] = cost[(p, q, "Van")]*10\n'

# %%
cl_file = pd.read_excel("Database/Co Loading Hubs.xlsx", sheet_name = "List hub")

cl_od = tuple(zip(cl_file["Origin"].to_list(), cl_file["Destination"].to_list()))


#cl={}

#cl=tuple(zip(cl_od))

    
if "Co-loading" in T:
    for p, q in pq_all:
        #for cl_od in cl:
        cost[(p, q, "Co-loading")] = max([cost[p_s, q_s, t] for p_s, q_s, t in pqt.select(p, q, "*") if t != "Co-loading"])*3 if (p,q) in cl_od else 99
        #print(cost[(p, q, "Co-loading")])

# %% [markdown]
# # 2. Forecast volume: Z
# Average forecasted parcel volume from country m ∈ E to country j ∈ E

# %%
Z = {}


for row in forecast.index:
    key = (forecast["Origin"][row], forecast["Destination"][row])
    Z[key] = int(round(forecast["Target"][row])) # Can only be interger

# Some missing connection in the forecast
for conn in mk:
    if conn not in Z.keys():
        Z[conn] = 0
        print(conn)

# %% [markdown]
# ## 3. Current Freqency (F_)
# the frequency of truck t from hub to hub q in the current network.

# %%
# The following code transform the excel files to csv file in specific format
'''
freq_truck = pd.read_excel("Database/Result_Freq.xlsx", sheet_name = 0)
freq_truck.replace("Ryton Gateway", "Ryton", inplace = True)
freq_truck["From"] = freq_truck.apply(lambda row: name_transform(row["Org. GTW"]), axis = 1)
freq_truck["To"] = freq_truck.apply(lambda row: name_transform(row["Dst. GTW"]), axis = 1)
freq_truck.loc[:, :].to_csv("Database/current_network.csv")

'''
# Out:
# '\nfreq_truck = pd.read_excel("Database/Result_Freq.xlsx", sheet_name = 0)\nfreq_truck.replace("Ryton Gateway", "Ryton", inplace = True)\nfreq_truck["From"] = freq_truck.apply(lambda row: name_transform(row["Org. GTW"]), axis = 1)\nfreq_truck["To"] = freq_truck.apply(lambda row: name_transform(row["Dst. GTW"]), axis = 1)\nfreq_truck.loc[:, :].to_csv("Database/current_network.csv")\n\n'

# %%
freq_current = pd.read_csv("Database/current_network.csv")
# The following section work as a formatting part. To avoid different naming issues
freq_current.replace("trailer", "Trailer", inplace = True)
freq_current.replace("2 swap bodies", "2 Swap Bodies", inplace = True)
freq_current.replace("van", "Van", inplace = True)
freq_current.replace("1 swap body", "Swap Body", inplace = True)
freq_current.replace("SEMI TRAILER", "Swap Body", inplace = True)
freq_current.replace("Cargo 50 m3", "Swap Body", inplace = True)
freq_current.replace("Sea Container", "2 Swap Bodies", inplace = True)
freq_current.replace("Van 15 m3", "Van", inplace = True)
freq_current.replace("Van 22m3", "Van", inplace = True)
freq_current.replace("4 swap bodies", "2 Swap Bodies", inplace = True)

# %%
F_ = {}
for row in freq_current.index:
    key = (freq_current.loc[row, "From"], freq_current.loc[row, "To"], freq_current.loc[row, "Truck type"])
    value = freq_current.loc[row, "Frequency"]
    
    F_[key] = value
    
for target in pqt:
    if target not in F_.keys():
        F_[target] = 0

# %% [markdown]
# ## 4. Travel time (TT)
# Total transportation time from hub p ∈ H to q ∈ H

# %%
tt_file = pd.read_csv("Database/travel time.csv")
TT = {}
for row in tt_file.index:
    key = (tt_file.loc[row, "From"], tt_file.loc[row, "To"])
    value = tt_file.loc[row, "est_tt"]
    
    TT[key] = value

# %% [markdown]
# ## 5. Hub Open & Cut-off time
# - Op = Hub opened time for hub p ∈ H
# - COp  = Hub cut off time for hub p ∈ H

# %%
def transform_time(target):
    try: 
        return int(target.split(":")[0]) + int(target.split(":")[1])/60 
    except:
        return 0

# %%
'''
hub_info = pd.read_csv("Database/Hub Cutoff and Open Time.csv")
hub_info["Hub"] = hub_info.apply(lambda row: name_transform(row["Gateways"]), axis = 1)
hub_info["Cut-off"] = hub_info.apply(lambda row: transform_time(row["Cut-Off"]), axis = 1)
hub_info["Open"] = hub_info.apply(lambda row: transform_time(row["Hub-Opening-Time"]), axis = 1)
hub_info.to_csv("Database/hub_info.csv")
'''
# Out:
# '\nhub_info = pd.read_csv("Database/Hub Cutoff and Open Time.csv")\nhub_info["Hub"] = hub_info.apply(lambda row: name_transform(row["Gateways"]), axis = 1)\nhub_info["Cut-off"] = hub_info.apply(lambda row: transform_time(row["Cut-Off"]), axis = 1)\nhub_info["Open"] = hub_info.apply(lambda row: transform_time(row["Hub-Opening-Time"]), axis = 1)\nhub_info.to_csv("Database/hub_info.csv")\n'

# %%
hub_info = pd.read_csv("Database/hub_info.csv")
merged_hub_info = hub_list_used.merge(hub_info[["Hub", "Open", "Cut-off"]], left_on = "Ref_City", right_on = "Hub", how = "left")

merged_hub_info["Open"].fillna(merged_hub_info["Open"].mode().values[0], inplace = True)
merged_hub_info["Cut-off"].fillna(merged_hub_info["Cut-off"].mode().values[0], inplace = True)

O = {} # Open time
for row in merged_hub_info.index:
    key = merged_hub_info.loc[row, "Ref_City"]
    value = merged_hub_info.loc[row, "Open"]
    O[key] = value

CO = {} # Cut-off time
for row in merged_hub_info.index:
    key = merged_hub_info.loc[row, "Ref_City"]
    value = merged_hub_info.loc[row, "Cut-off"]
    CO[key] =  value

# %% [markdown]
# ## 6. Truck Capacity

# %%
C = {}
for row in truck_cap.index:
    C[truck_cap.loc[row, "Truck Type"]] = truck_cap.loc[row, "Capacity"]

# %% [markdown]
# # Start the model

# %%
model = Model("DHL")
# Out:
# Academic license - for non-commercial use only

# %% [markdown]
# # Define the variables
# Decision variables:
# - xpq = 1 if the transportation from hub p ∈ H to hub q ∈ H is direct, else 0
# - x’piq = 1 if the transportation from hub p ∈ H to hub q ∈ H has to go through i ∈ H, else 0
# - Xmk = 1 if the transportation from country m ∈ E to county k ∈ E is direct, else 0
# - X’mjk = 1 if the transportation from country m ∈ E  to county k ∈ E  has to go through country j ∈ E , else 0
# - Vpq = route capacity from hub p ∈ H to hub q ∈ H
# - Fpqt = recommended frequency of truck t ∈ T from hub p ∈ H to hub q ∈ H
# - Spq = start time of truck from hub p ∈ H to hub q ∈ H,
# - Npq = Night needed from hub p ∈ H to hub q ∈ H

# %%
x = model.addVars(pq , vtype=GRB.BINARY, name='xpq')  # Direct from hub to hub

x_ = model.addVars(piq, vtype = GRB.BINARY, name = 'x_piq')  # Indirect from hub to hub

X = model.addVars(mk , vtype=GRB.BINARY, name='Xmk')       # Direct from country to country

X_ = model.addVars(mjk,  vtype = GRB.BINARY, name = 'X_mjk') # Indirect from country to country

V = model.addVars(pq_all , vtype=GRB.INTEGER, lb=0 ,name='Vpq')   # Route capacity

F=model.addVars(pqt , vtype=GRB.INTEGER, lb=0, name='Fpqt') # Recommended Frequency

# S=model.addVars(pq_all , vtype=GRB.CONTINUOUS, name='Spq')         # Start time from hub p

# N=model.addVars(pq_all , vtype=GRB.INTEGER, name='Npq')         # Night Needed from hub p to hub q

CL = model.addVars(pq_all, vtype = GRB.INTEGER, lb = 0, name = "CLpq") # Co-loading (in) between p and q

# %%
attri_dict = {"hub_direct": x, "hub_indirect" : x_, "country_direct" : X, "country_indirect" : X_,
              "route_cap": V, "freq" : F, "Co-loading":CL}

# %% [markdown]
# ## Objective

# %%
("NL", "AT") in mj_k
# Out:
# False

# %%
model.update()

# Minimize the travel time for each route
model.setObjective(quicksum(x[p, q] * TT[p, q] for p, q in pq) +
                   quicksum(x_[p, i ,q] * (TT[p, i] + 9 + TT[i, q])for p, i, q in piq) # Consider the transit time in the hubs
                                                                                       # Taking 9 as an example
                   ,  GRB.MINIMIZE)

# %% [markdown]
# ## Constraints

# %%
### Constraints
## Direct or Indirect Transportation

model.addConstrs(((quicksum(X_[m,j,k] for j in E if (j != m) & (j != k)) == 
                   (1 - X[m,k])) for m, k in mk),
                 "Transportation can be direct or Indirect")


## Linking Countries and Hubs

model.addConstrs(((quicksum(x[p,q] for p in L[m] for q in L[k]) == 
                  X[m,k]) for m, k in mk), "Linking_pq")  ## We can't use E_mjk here
model.addConstrs(((quicksum(x_[p,i,q] for p in L[m] for i in L[j] for q in L[k]) ==
                 X_[m,j,k]) for m,j,k in mjk), "Linking_piq")

## Truck Capacity:

# V = monthly demand of the route
# For the countries of p, q are in mk
model.addConstrs(((V[p,q] ==  
                 quicksum(x_[p,q,i] * Z[m,j] for m, k, j in mjk.select(m, k, "*") for i in L[j]) +
                 quicksum(x_[i,p,q] * Z[j,k] for j, m, k in mjk.select("*", m, k) for i in L[j]) + 
                 x[p,q] * Z[m,k])
                 for m, k in mk for p in L[m] for q in L[k]), "Truck Capacity")

# For the countries of p are in the origin, q are not in the destination:
model.addConstrs((V[p,q] ==  
                 quicksum(x_[p,q,i] * Z[m,j] for m, k, j in mjk.select(m, k, "*") for i in L[j])
                 for m, k in mj_k for p in L[m] for q in L[k] if (m,k) not in j_mk), "Truck Capacity")
                 
# For the countries of p are not in the origin, q are in the destination:           
model.addConstrs((V[p,q] ==  
                 quicksum(x_[i,p,q] * Z[j,k] for j, m, k in mjk.select("*", m, k) for i in L[j]) 
                 for m, k in j_mk for p in L[m] for q in L[k] if (m,k) not in mj_k), "Truck Capacity")

# For the countries of p and q are not in mk, but in j_mk and mj_k in the same time
model.addConstrs((V[p,q] ==  
                 quicksum(x_[p,q,i] * Z[m,j] for m, k, j in mjk.select(m, k, "*") for i in L[j]) +
                 quicksum(x_[i,p,q] * Z[j,k] for j, m, k in mjk.select("*", m, k) for i in L[j])
                 for m, k in j_mk for p in L[m] for q in L[k] if (m,k) in mj_k), "Truck Capacity 4")


## Truck type and Frequency of trucks
# transforming the weekly frequency to monthly by multiplying 4
model.addConstrs(((V[p,q] + CL[p, q]*4 <=   # Updated
                 quicksum(F[p,q,t] * C[t] * 4 for t in T) )
                 for m, k in mk_all for q in L[k] for p in L[m]),
                 "Truck Type and Frequency"
                )

# Co-loading out constraints
# model.addConstrs((F[p,q,"Co-loading"] <= 2000 for p,q in pq_all), "Coloading out constraints") ## Removed after discussion on 6/22

# Co-loading in constraints
model.addConstrs((CL[p,q] <= 2000 for p,q in pq_all), "Coloading in constraints")
model.addConstrs((CL[p,q] <= quicksum(F[p,q,t]*C[t] for t in T)*0.3 for p, q in pq_all), "Coloading in constraints 2")


'''
BigM = 9999
model.addConstrs((S[p,q] + TT[p,q] - N[p,q] * 24  <=  
                 CO[q] + 
                 BigM * (
                     1 - (x[p, q] + 
                          quicksum(x_[p, q, i] for m, k, j in mjk.select(m, k, "*") for i in L[j]) + 
                          quicksum(x_[i, p, q] for j, m, k in mjk.select("*", m, k) for i in L[j])
                 ) ) for m,k in mk for q in L[k] for p in L[m]), "Hub Cut Off Time")


BigMM = 9000

model.addConstrs((S[p,q] + TT[p,q] - N[p,q] * 24  >=  
                 O[q] + 
                 BigMM * (
                     1 - (x[p, q] + 
                          quicksum(x_[p, q, i] for m, k, j in mjk.select(m, k, "*") for i in L[j]) + 
                          quicksum(x_[i, p, q] for j, m, k in mjk.select("*", m, k) for i in L[j])
                 ) ) for m,k in mk for q in L[k] for p in L[m]), "Hub Open Time")

'''

# Assumption: all the excessive spaces could be loaded with co-loading opportunities in the current network
# Assumption: In the new network, all the co-loading oppottunities doesn't exist


Cost_bound = 1.05
Current_full = 1


'''
# The tighten model (loose a bit)
model.addConstr((quicksum(F[p,q,t] * cost[p,q,t] * C[t] for p, q, t in pqt) *
                 quicksum(F_[p,q,t] * C[t] for p, q, t in pqt) <= 
                 (quicksum(F_[p,q,t] * cost[p,q,t] * C[t] for p, q, t in pqt) *
                 (quicksum(Z[m,k] for m, k in mk)/4 + quicksum(CL[p,q] for p,q in pq)) * Cost_bound))
                 , "Cost Constraint")
'''

current_cost = sum(F_[p,q,t] * C[t] * cost[p,q,t] for p, q, t in pqt) / sum(F_[p,q,t] * C[t] for p,q,t in pqt)

model.addConstr((quicksum(F[p,q,t] * cost[p,q,t] * C[t] for p, q, t in pqt) <= 
                 (current_cost * (quicksum(V[p,q] for p, q in pq_all) / 4 + quicksum(CL[p,q] for p,q in pq))) * Cost_bound / Current_full), "Cost Constraint")

#V[p,q] for p, q in pq_all
# Out:
# <gurobi.Constr *Awaiting Model Update*>

# %% [markdown]
# ## Solver

# %%
model.update()
model.printStats()
# Out:
# Statistics for model DHL :
#   Linear constraint matrix    : 23305 Constrs, 209732 Vars, 624320 NZs
#   Variable types              : 0 Continuous, 209732 Integer (177854 Binary)
#   Matrix coefficient range    : [ 0.0196094, 1.43338e+06 ]
#   Objective coefficient range : [ 2.1, 197.2 ]
#   Variable bound range        : [ 1, 1 ]
#   RHS coefficient range       : [ 1, 2000 ]

# %%
# model.reset()

timeLimit = 3600*8 # In second

model.Params.TimeLimit = timeLimit - model.getAttr(GRB.Attr.Runtime)

model.Params.Heuristics = 0.5

model.Params.MIPFocus=3

model.Params.TuneCriterion = 2

model.Params.TuneTrials = 3

model.Params.SolutionLimit = 10

oldSolutionLimit = model.Params.SolutionLimit

model.Params.Seed = 3

model.Params.TuneTimeLimit = timeLimit/3

model.tune()

# model.feasRelaxS(1, False, False, True)

model.optimize()


'''
if model.tuneResultCount > 0:

    # Load the best tuned parameters into the model
    model.getTuneResult(0)

    # Write tuned parameters to a file
    model.write('tune.prm')

    # Solve the model using the tuned parameters
    model.optimize()
    
'''
# Out:
# Changed value of parameter TimeLimit to 28800.0
#    Prev: 1e+100  Min: 0.0  Max: 1e+100  Default: 1e+100
# Changed value of parameter Heuristics to 0.5
#    Prev: 0.05  Min: 0.0  Max: 1.0  Default: 0.05
# Changed value of parameter MIPFocus to 3
#    Prev: 0  Min: 0  Max: 3  Default: 0
# Changed value of parameter TuneCriterion to 2
#    Prev: -1  Min: -1  Max: 3  Default: -1
# Parameter TuneTrials unchanged
#    Value: 3  Min: 1  Max: 2000000000  Default: 3
# Changed value of parameter SolutionLimit to 10
#    Prev: 2000000000  Min: 1  Max: 2000000000  Default: 2000000000
# Changed value of parameter Seed to 3
#    Prev: 0  Min: 0  Max: 2000000000  Default: 0
# Changed value of parameter TuneTimeLimit to 9600.0
#    Prev: -1.0  Min: -1.0  Max: 1e+100  Default: -1.0
#
# Solving model using baseline parameter set with TimeLimit=28800s
#
# Solving with random seed #1 ...
# Optimize a model with 23305 rows, 209732 columns and 624320 nonzeros
# Variable types: 0 continuous, 209732 integer (177854 binary)
# Coefficient statistics:
#   Matrix range     [2e-02, 1e+06]
#   Objective range  [2e+00, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Presolve removed 8206 rows and 12795 columns (presolve time = 5s) ...
# Presolve removed 9610 rows and 14199 columns (presolve time = 10s) ...
# Presolve removed 9994 rows and 14583 columns
# Presolve time: 12.73s
# Presolved: 13311 rows, 195149 columns, 576963 nonzeros
# Variable types: 0 continuous, 195149 integer (174022 binary)
# Presolve removed 999 rows and 999 columns
# Presolved: 12312 rows, 194150 columns, 574926 nonzeros
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    6.2375167e+03   4.967388e+03   0.000000e+00     16s
#      672    6.2375167e+03   0.000000e+00   0.000000e+00     17s
#      672    6.2375167e+03   0.000000e+00   0.000000e+00     17s
#
# Root relaxation: objective 6.237517e+03, 672 iterations, 2.02 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 6237.51667    0  213          - 6237.51667      -     -   19s
#      0     0 6266.28687    0  330          - 6266.28687      -     -   57s
#      0     0 6268.24758    0  333          - 6268.24758      -     -   69s
#      0     0 6312.82543    0  377          - 6312.82543      -     -  105s
#      0     0 6315.43911    0  346          - 6315.43911      -     -  124s
#      0     0 6315.46626    0  350          - 6315.46626      -     -  125s
#      0     0 6315.46628    0  351          - 6315.46628      -     -  125s
#      0     0 6341.95775    0  403          - 6341.95775      -     -  168s
#      0     0 6343.36230    0  359          - 6343.36230      -     -  185s
#      0     0 6343.37094    0  362          - 6343.37094      -     -  185s
#      0     0 6358.18477    0  332          - 6358.18477      -     -  227s
#      0     0 6359.49846    0  315          - 6359.49846      -     -  297s
#      0     0 6359.51305    0  316          - 6359.51305      -     -  297s
#      0     0 6367.74004    0  305          - 6367.74004      -     -  341s
#      0     0 6367.95036    0  303          - 6367.95036      -     -  410s
#      0     0 6367.97142    0  310          - 6367.97142      -     -  410s
#      0     0 6371.07859    0  309          - 6371.07859      -     -  454s
# H    0     0                    6500.8433333 6371.07859  2.00%     -  498s
# H    0     0                    6400.6300000 6371.07859  0.46%     -  542s
#      0     0 6371.47657    0  286 6400.63000 6371.47657  0.46%     -  542s
#      0     0 6371.47906    0  288 6400.63000 6371.47906  0.46%     -  542s
#      0     0 6375.97911    0  322 6400.63000 6375.97911  0.39%     -  583s
#      0     0 6375.97911    0  204 6400.63000 6375.97911  0.39%     -  603s
#      0     0 6375.97911    0  340 6400.63000 6375.97911  0.39%     -  622s
# H    0     0                    6399.7200000 6375.97911  0.37%     -  640s
#      0     0 6375.97911    0  386 6399.72000 6375.97911  0.37%     -  642s
#      0     0 6375.97911    0  334 6399.72000 6375.97911  0.37%     -  644s
#      0     0 6378.09710    0  302 6399.72000 6378.09710  0.34%     -  644s
#      0     0 6382.17242    0  316 6399.72000 6382.17242  0.27%     -  645s
#      0     0 6382.71932    0  318 6399.72000 6382.71932  0.27%     -  645s
#      0     0 6382.77358    0  336 6399.72000 6382.77358  0.26%     -  646s
#      0     0 6382.78365    0  336 6399.72000 6382.78365  0.26%     -  646s
#      0     0 6387.26315    0  245 6399.72000 6387.26315  0.19%     -  691s
#      0     0 6387.26315    0  212 6399.72000 6387.26315  0.19%     -  699s
#      0     0 6387.26315    0  310 6399.72000 6387.26315  0.19%     -  714s
#      0     0 6387.26315    0  335 6399.72000 6387.26315  0.19%     -  719s
#      0     0 6387.26315    0  248 6399.72000 6387.26315  0.19%     -  720s
#      0     0 6387.26315    0  237 6399.72000 6387.26315  0.19%     -  720s
#      0     0 6387.76237    0  251 6399.72000 6387.76237  0.19%     -  720s
#      0     0 6387.96547    0  248 6399.72000 6387.96547  0.18%     -  720s
#      0     0 6388.16811    0  246 6399.72000 6388.16811  0.18%     -  720s
#      0     0 6388.17231    0  244 6399.72000 6388.17231  0.18%     -  720s
#      0     0 6390.65888    0  280 6399.72000 6390.65888  0.14%     -  784s
#      0     0 6390.77197    0  278 6399.72000 6390.77197  0.14%     -  786s
#      0     0 6390.81420    0  272 6399.72000 6390.81420  0.14%     -  786s
#      0     0 6392.48469    0  198 6399.72000 6392.48469  0.11%     -  839s
#      0     0 6392.48469    0  212 6399.72000 6392.48469  0.11%     -  843s
#      0     0 6392.48469    0  317 6399.72000 6392.48469  0.11%     -  856s
#      0     0 6392.48469    0  292 6399.72000 6392.48469  0.11%     -  859s
#      0     0 6392.48469    0  252 6399.72000 6392.48469  0.11%     -  860s
#      0     0 6392.48469    0  206 6399.72000 6392.48469  0.11%     -  860s
#      0     0 6392.48469    0  203 6399.72000 6392.48469  0.11%     -  860s
#      0     0 6392.48766    0  203 6399.72000 6392.48766  0.11%     -  860s
#      0     0 6392.78317    0  217 6399.72000 6392.78317  0.11%     -  860s
#      0     0 6392.81737    0  205 6399.72000 6392.81737  0.11%     -  860s
#      0     0 6393.16686    0  225 6399.72000 6393.16686  0.10%     -  913s
#      0     0 6393.16857    0  236 6399.72000 6393.16857  0.10%     -  915s
# H    0     0                    6399.3933333 6393.16857  0.10%     -  940s
# H    0     0                    6399.3700000 6393.16857  0.10%     -  964s
#      0     0 6394.07349    0  242 6399.37000 6394.07349  0.08%     -  989s
#      0     0 6394.18719    0  230 6399.37000 6394.18719  0.08%     -  991s
#      0     0 6394.77854    0  157 6399.37000 6394.77854  0.07%     - 1036s
#      0     0 6394.78303    0  150 6399.37000 6394.78303  0.07%     - 1037s
# H    0     0                    6399.2766667 6394.78303  0.07%     - 1059s
#      0     0 6395.06350    0  195 6399.27667 6395.06350  0.07%     - 1114s
#      0     0 6395.06350    0  195 6399.27667 6395.06350  0.07%     - 1140s
#      0     0 6395.06350    0  208 6399.27667 6395.06350  0.07%     - 1145s
#      0     0 6395.06350    0  307 6399.27667 6395.06350  0.07%     - 1155s
#      0     0 6395.06350    0  290 6399.27667 6395.06350  0.07%     - 1158s
#      0     0 6395.06350    0  193 6399.27667 6395.06350  0.07%     - 1159s
#      0     0 6395.06350    0  185 6399.27667 6395.06350  0.07%     - 1159s
#      0     0 6395.06350    0  175 6399.27667 6395.06350  0.07%     - 1159s
#      0     0 6395.06350    0  174 6399.27667 6395.06350  0.07%     - 1159s
#      0     0 6395.06350    0  193 6399.27667 6395.06350  0.07%     - 1159s
#      0     0 6395.06350    0  224 6399.27667 6395.06350  0.07%     - 1159s
#      0     0 6395.07293    0  172 6399.27667 6395.07293  0.07%     - 1159s
#      0     0 6395.10547    0  170 6399.27667 6395.10547  0.07%     - 1159s
#      0     0 6395.87695    0  189 6399.27667 6395.87695  0.05%     - 1207s
#      0     0 6395.88836    0  183 6399.27667 6395.88836  0.05%     - 1208s
#      0     0 6396.58513    0  150 6399.27667 6396.58513  0.04%     - 1282s
#      0     0 6396.60448    0  150 6399.27667 6396.60448  0.04%     - 1283s
#      0     0 6396.80400    0  167 6399.27667 6396.80400  0.04%     - 1376s
#      0     0 6396.81686    0  172 6399.27667 6396.81686  0.04%     - 1405s
#      0     0 6396.82352    0  160 6399.27667 6396.82352  0.04%     - 1434s
#      0     0 6396.82352    0  160 6399.27667 6396.82352  0.04%     - 1455s
#      0     0 6396.82352    0  206 6399.27667 6396.82352  0.04%     - 1458s
#      0     0 6396.82352    0  267 6399.27667 6396.82352  0.04%     - 1464s
#      0     0 6396.82352    0  268 6399.27667 6396.82352  0.04%     - 1466s
#      0     0 6396.82352    0  210 6399.27667 6396.82352  0.04%     - 1466s
#      0     0 6396.82352    0  166 6399.27667 6396.82352  0.04%     - 1466s
#      0     0 6396.82352    0  145 6399.27667 6396.82352  0.04%     - 1466s
#      0     0 6396.82352    0  169 6399.27667 6396.82352  0.04%     - 1466s
#      0     0 6396.82352    0  183 6399.27667 6396.82352  0.04%     - 1466s
#      0     0 6396.82352    0  141 6399.27667 6396.82352  0.04%     - 1467s
#      0     0 6396.82352    0  143 6399.27667 6396.82352  0.04%     - 1467s
#      0     0 6396.82352    0  156 6399.27667 6396.82352  0.04%     - 1467s
#      0     0 6396.83534    0  157 6399.27667 6396.83534  0.04%     - 1467s
#      0     0 6397.09355    0  111 6399.27667 6397.09355  0.03%     - 1517s
#      0     0 6397.14974    0   93 6399.27667 6397.14974  0.03%     - 1518s
#      0     0 6397.93615    0  204 6399.27667 6397.93615  0.02%     - 1579s
#      0     0 6398.08833    0  197 6399.27667 6398.08833  0.02%     - 1579s
#      0     0 6398.22718    0  166 6399.27667 6398.22718  0.02%     - 1614s
#      0     0 6398.22718    0  178 6399.27667 6398.22718  0.02%     - 1615s
#      0     0 6398.22718    0  179 6399.27667 6398.22718  0.02%     - 1618s
#      0     0 6398.22718    0  259 6399.27667 6398.22718  0.02%     - 1618s
#      0     0 6398.22718    0  199 6399.27667 6398.22718  0.02%     - 1618s
#      0     0 6398.22718    0  144 6399.27667 6398.22718  0.02%     - 1618s
#      0     0 6398.22718    0  149 6399.27667 6398.22718  0.02%     - 1618s
#      0     0 6398.22718    0  157 6399.27667 6398.22718  0.02%     - 1618s
#      0     0 6398.22718    0  138 6399.27667 6398.22718  0.02%     - 1618s
#      0     0 6398.22718    0  156 6399.27667 6398.22718  0.02%     - 1618s
#      0     0 6398.22718    0  165 6399.27667 6398.22718  0.02%     - 1618s
#      0     0 6398.23437    0  165 6399.27667 6398.23437  0.02%     - 1618s
#      0     0 6398.49029    0  173 6399.27667 6398.49029  0.01%     - 1633s
#      0     0 6398.50423    0  138 6399.27667 6398.50423  0.01%     - 1633s
#      0     0 6398.62263    0  137 6399.27667 6398.62263  0.01%     - 1642s
#      0     0 6398.62263    0  151 6399.27667 6398.62263  0.01%     - 1643s
#      0     0 6398.62263    0  139 6399.27667 6398.62263  0.01%     - 1644s
#      0     0 6398.62263    0  190 6399.27667 6398.62263  0.01%     - 1644s
#      0     0 6398.62263    0  196 6399.27667 6398.62263  0.01%     - 1644s
#      0     0 6398.62263    0  177 6399.27667 6398.62263  0.01%     - 1644s
#      0     0 6398.62263    0  185 6399.27667 6398.62263  0.01%     - 1644s
#      0     0 6398.62263    0  197 6399.27667 6398.62263  0.01%     - 1644s
#      0     0 6398.64193    0  181 6399.27667 6398.64193  0.01%     - 1644s
#
# Cutting planes:
#   Gomory: 159
#   Cover: 6
#   Implied bound: 1
#   MIR: 405
#   StrongCG: 17
#   Flow cover: 24
#   GUB cover: 2
#   Zero half: 3
#
# Explored 1 nodes (81878 simplex iterations) in 1644.38 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 6: 6399.28 6399.37 6399.39 ... 6500.84
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.399276666667e+03, best bound 6.398643333333e+03, gap 0.0099%
#
# -------------------------------------------------------------------------------
#
# Solving with random seed #2 ...
# Optimize a model with 23305 rows, 209732 columns and 624320 nonzeros
# Variable types: 0 continuous, 209732 integer (177854 binary)
# Coefficient statistics:
#   Matrix range     [2e-02, 1e+06]
#   Objective range  [2e+00, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Presolve removed 8630 rows and 13219 columns (presolve time = 5s) ...
# Presolve removed 9994 rows and 14583 columns
# Presolve time: 9.76s
# Presolved: 13311 rows, 195149 columns, 576963 nonzeros
# Variable types: 0 continuous, 195149 integer (174022 binary)
# Presolve removed 999 rows and 999 columns
# Presolved: 12312 rows, 194150 columns, 574926 nonzeros
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    6.2375167e+03   4.967388e+03   0.000000e+00     13s
#      596    6.2375167e+03   0.000000e+00   0.000000e+00     13s
#      596    6.2375167e+03   0.000000e+00   0.000000e+00     14s
#
# Root relaxation: objective 6.237517e+03, 596 iterations, 1.53 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 6237.51667    0  213          - 6237.51667      -     -   15s
#      0     0 6261.78269    0  315          - 6261.78269      -     -   42s
#      0     0 6263.97766    0  314          - 6263.97766      -     -   56s
#      0     0 6307.37020    0  374          - 6307.37020      -     -   96s
#      0     0 6309.97034    0  354          - 6309.97034      -     -  114s
#      0     0 6310.07266    0  356          - 6310.07266      -     -  115s
#      0     0 6310.07309    0  357          - 6310.07309      -     -  115s
#      0     0 6338.06774    0  383          - 6338.06774      -     -  161s
#      0     0 6339.23832    0  352          - 6339.23832      -     -  182s
#      0     0 6339.27021    0  356          - 6339.27021      -     -  182s
#      0     0 6339.27076    0  356          - 6339.27076      -     -  183s
#      0     0 6353.89929    0  365          - 6353.89929      -     -  223s
#      0     0 6355.09731    0  341          - 6355.09731      -     -  304s
#      0     0 6355.12891    0  336          - 6355.12891      -     -  304s
#      0     0 6365.40282    0  316          - 6365.40282      -     -  370s
#      0     0 6366.00574    0  296          - 6366.00574      -     -  455s
#      0     0 6366.03089    0  291          - 6366.03089      -     -  455s
#      0     0 6369.21548    0  287          - 6369.21548      -     -  533s
#      0     0 6369.56311    0  286          - 6369.56311      -     -  640s
#      0     0 6369.57649    0  286          - 6369.57649      -     -  641s
#      0     0 6371.90680    0  337          - 6371.90680      -     -  703s
#      0     0 6371.93192    0  335          - 6371.93192      -     -  771s
#      0     0 6373.39307    0  293          - 6373.39307      -     -  820s
# H    0     0                    6498.6733333 6373.39307  1.93%     -  876s
# H    0     0                    6400.7666667 6373.39307  0.43%     -  939s
#      0     0 6373.43915    0  286 6400.76667 6373.43915  0.43%     -  939s
#      0     0 6381.08446    0  315 6400.76667 6381.08446  0.31%     -  985s
#      0     0 6381.08446    0  170 6400.76667 6381.08446  0.31%     - 1004s
#      0     0 6381.08446    0  330 6400.76667 6381.08446  0.31%     - 1017s
# H    0     0                    6400.5800000 6381.08446  0.30%     - 1030s
#      0     0 6381.08446    0  369 6400.58000 6381.08446  0.30%     - 1032s
#      0     0 6381.08446    0  378 6400.58000 6381.08446  0.30%     - 1033s
#      0     0 6381.08446    0  363 6400.58000 6381.08446  0.30%     - 1034s
#      0     0 6381.89687    0  301 6400.58000 6381.89687  0.29%     - 1034s
#      0     0 6383.37537    0  332 6400.58000 6383.37537  0.27%     - 1035s
#      0     0 6383.62300    0  331 6400.58000 6383.62300  0.26%     - 1035s
#      0     0 6383.69190    0  331 6400.58000 6383.69190  0.26%     - 1035s
# H    0     0                    6400.4866667 6383.69190  0.26%     - 1075s
#      0     0 6387.19264    0  304 6400.48667 6387.19264  0.21%     - 1104s
# H    0     0                    6400.4633333 6387.19264  0.21%     - 1116s
#      0     0 6387.21900    0  275 6400.46333 6387.21900  0.21%     - 1116s
#      0     0 6391.14876    0  293 6400.46333 6391.14876  0.15%     - 1202s
#      0     0 6391.14876    0  212 6400.46333 6391.14876  0.15%     - 1207s
#      0     0 6391.14876    0  348 6400.46333 6391.14876  0.15%     - 1218s
#      0     0 6391.14876    0  302 6400.46333 6391.14876  0.15%     - 1221s
#      0     0 6391.14876    0  268 6400.46333 6391.14876  0.15%     - 1222s
#      0     0 6391.14876    0  251 6400.46333 6391.14876  0.15%     - 1222s
#      0     0 6391.14876    0  287 6400.46333 6391.14876  0.15%     - 1222s
#      0     0 6391.62590    0  280 6400.46333 6391.62590  0.14%     - 1222s
#      0     0 6391.74407    0  261 6400.46333 6391.74407  0.14%     - 1222s
#      0     0 6391.89229    0  258 6400.46333 6391.89229  0.13%     - 1222s
#      0     0 6391.96922    0  271 6400.46333 6391.96922  0.13%     - 1222s
#      0     0 6392.07524    0  273 6400.46333 6392.07524  0.13%     - 1222s
#      0     0 6393.44078    0  248 6400.46333 6393.44078  0.11%     - 1299s
# H    0     0                    6399.8600000 6393.44078  0.10%     - 1301s
#      0     0 6393.45006    0  221 6399.86000 6393.45006  0.10%     - 1301s
#      0     0 6394.08318    0  190 6399.86000 6394.08318  0.09%     - 1369s
#      0     0 6394.09000    0  211 6399.86000 6394.09000  0.09%     - 1371s
#      0     0 6394.60657    0  178 6399.86000 6394.60657  0.08%     - 1472s
#      0     0 6394.60657    0  178 6399.86000 6394.60657  0.08%     - 1503s
#      0     0 6394.60657    0  209 6399.86000 6394.60657  0.08%     - 1511s
#      0     0 6394.60657    0  361 6399.86000 6394.60657  0.08%     - 1522s
#      0     0 6394.60657    0  252 6399.86000 6394.60657  0.08%     - 1525s
#      0     0 6394.60657    0  218 6399.86000 6394.60657  0.08%     - 1525s
#      0     0 6394.60657    0  185 6399.86000 6394.60657  0.08%     - 1526s
#      0     0 6394.60657    0  200 6399.86000 6394.60657  0.08%     - 1526s
#      0     0 6394.60657    0  212 6399.86000 6394.60657  0.08%     - 1526s
#      0     0 6394.60657    0  176 6399.86000 6394.60657  0.08%     - 1526s
#      0     0 6394.60657    0  180 6399.86000 6394.60657  0.08%     - 1526s
#      0     0 6394.60657    0  176 6399.86000 6394.60657  0.08%     - 1526s
#      0     0 6394.85229    0  171 6399.86000 6394.85229  0.08%     - 1526s
#      0     0 6394.85825    0  173 6399.86000 6394.85825  0.08%     - 1526s
#      0     0 6395.30010    0  209 6399.86000 6395.30010  0.07%     - 1577s
#      0     0 6395.30409    0  199 6399.86000 6395.30409  0.07%     - 1579s
#      0     0 6395.78270    0  237 6399.86000 6395.78270  0.06%     - 1641s
#      0     0 6395.79434    0  209 6399.86000 6395.79434  0.06%     - 1671s
#      0     0 6395.79434    0  209 6399.86000 6395.79434  0.06%     - 1700s
#      0     0 6395.79434    0  208 6399.86000 6395.79434  0.06%     - 1705s
#      0     0 6395.79434    0  342 6399.86000 6395.79434  0.06%     - 1715s
#      0     0 6395.79434    0  252 6399.86000 6395.79434  0.06%     - 1719s
#      0     0 6395.79434    0  207 6399.86000 6395.79434  0.06%     - 1719s
#      0     0 6395.79434    0  193 6399.86000 6395.79434  0.06%     - 1719s
#      0     0 6395.79434    0  204 6399.86000 6395.79434  0.06%     - 1720s
#      0     0 6395.79434    0  196 6399.86000 6395.79434  0.06%     - 1720s
#      0     0 6395.79434    0  214 6399.86000 6395.79434  0.06%     - 1720s
#      0     0 6395.79434    0  211 6399.86000 6395.79434  0.06%     - 1720s
#      0     0 6395.79434    0  183 6399.86000 6395.79434  0.06%     - 1720s
#      0     0 6395.83206    0  188 6399.86000 6395.83206  0.06%     - 1720s
#      0     0 6395.84447    0  189 6399.86000 6395.84447  0.06%     - 1720s
#      0     0 6396.31715    0  206 6399.86000 6396.31715  0.06%     - 1769s
#      0     0 6396.34466    0  222 6399.86000 6396.34466  0.05%     - 1771s
#      0     0 6396.48613    0  194 6399.86000 6396.48613  0.05%     - 1824s
#      0     0 6396.48613    0  194 6399.86000 6396.48613  0.05%     - 1846s
#      0     0 6396.48613    0  207 6399.86000 6396.48613  0.05%     - 1849s
#      0     0 6396.48613    0  328 6399.86000 6396.48613  0.05%     - 1858s
#      0     0 6396.48613    0  243 6399.86000 6396.48613  0.05%     - 1860s
#      0     0 6396.48613    0  199 6399.86000 6396.48613  0.05%     - 1860s
#      0     0 6396.48613    0  175 6399.86000 6396.48613  0.05%     - 1860s
#      0     0 6396.48613    0  201 6399.86000 6396.48613  0.05%     - 1860s
#      0     0 6396.48613    0  209 6399.86000 6396.48613  0.05%     - 1860s
#      0     0 6396.48613    0  187 6399.86000 6396.48613  0.05%     - 1860s
#      0     0 6396.48613    0  215 6399.86000 6396.48613  0.05%     - 1860s
#      0     0 6396.48613    0  208 6399.86000 6396.48613  0.05%     - 1860s
#      0     0 6396.48613    0  175 6399.86000 6396.48613  0.05%     - 1860s
#      0     0 6396.50097    0  192 6399.86000 6396.50097  0.05%     - 1860s
#      0     0 6396.52822    0  192 6399.86000 6396.52822  0.05%     - 1861s
#      0     0 6396.57040    0  192 6399.86000 6396.57040  0.05%     - 1861s
#      0     0 6396.89103    0  210 6399.86000 6396.89103  0.05%     - 1897s
#      0     0 6396.92342    0  217 6399.86000 6396.92342  0.05%     - 1898s
#      0     0 6397.13322    0  229 6399.86000 6397.13322  0.04%     - 1954s
#      0     0 6397.13569    0  236 6399.86000 6397.13569  0.04%     - 1979s
#      0     0 6397.14528    0  228 6399.86000 6397.14528  0.04%     - 2003s
#      0     0 6397.15029    0  216 6399.86000 6397.15029  0.04%     - 2026s
#      0     0 6397.15029    0  216 6399.86000 6397.15029  0.04%     - 2049s
#      0     0 6397.15029    0  201 6399.86000 6397.15029  0.04%     - 2051s
#      0     0 6397.15029    0  265 6399.86000 6397.15029  0.04%     - 2059s
#      0     0 6397.15029    0  269 6399.86000 6397.15029  0.04%     - 2061s
#      0     0 6397.15029    0  198 6399.86000 6397.15029  0.04%     - 2061s
#      0     0 6397.15029    0  164 6399.86000 6397.15029  0.04%     - 2061s
#      0     0 6397.15029    0  183 6399.86000 6397.15029  0.04%     - 2061s
#      0     0 6397.15029    0  208 6399.86000 6397.15029  0.04%     - 2061s
#      0     0 6397.15029    0  181 6399.86000 6397.15029  0.04%     - 2061s
#      0     0 6397.15029    0  195 6399.86000 6397.15029  0.04%     - 2062s
#      0     0 6397.15029    0  194 6399.86000 6397.15029  0.04%     - 2062s
#      0     0 6397.15029    0  184 6399.86000 6397.15029  0.04%     - 2062s
#      0     0 6397.15029    0  201 6399.86000 6397.15029  0.04%     - 2062s
#      0     0 6397.15029    0  182 6399.86000 6397.15029  0.04%     - 2062s
#      0     0 6397.15029    0  187 6399.86000 6397.15029  0.04%     - 2062s
#      0     0 6397.15029    0  188 6399.86000 6397.15029  0.04%     - 2062s
#      0     0 6397.15036    0  216 6399.86000 6397.15036  0.04%     - 2062s
#      0     0 6397.46596    0  200 6399.86000 6397.46596  0.04%     - 2091s
#      0     0 6397.46600    0  201 6399.86000 6397.46600  0.04%     - 2092s
#      0     0 6398.15344    0  192 6399.86000 6398.15344  0.03%     - 2156s
#      0     0 6398.15827    0  189 6399.86000 6398.15827  0.03%     - 2187s
#      0     0 6398.15827    0  189 6399.86000 6398.15827  0.03%     - 2201s
# H    0     0                    6399.4633333 6398.15827  0.02%     - 2202s
#      0     0 6398.15827    0  188 6399.46333 6398.15827  0.02%     - 2203s
#      0     0 6398.15827    0  209 6399.46333 6398.15827  0.02%     - 2208s
#      0     0 6398.15827    0  241 6399.46333 6398.15827  0.02%     - 2208s
#      0     0 6398.15827    0  205 6399.46333 6398.15827  0.02%     - 2209s
#      0     0 6398.15827    0  166 6399.46333 6398.15827  0.02%     - 2209s
#      0     0 6398.15827    0  150 6399.46333 6398.15827  0.02%     - 2209s
#      0     0 6398.15827    0  173 6399.46333 6398.15827  0.02%     - 2209s
#      0     0 6398.15827    0  126 6399.46333 6398.15827  0.02%     - 2209s
#      0     0 6398.15827    0  183 6399.46333 6398.15827  0.02%     - 2209s
#      0     0 6398.15827    0  167 6399.46333 6398.15827  0.02%     - 2209s
#      0     0 6398.15827    0  185 6399.46333 6398.15827  0.02%     - 2209s
#      0     0 6398.15827    0  165 6399.46333 6398.15827  0.02%     - 2209s
#      0     0 6398.15827    0  198 6399.46333 6398.15827  0.02%     - 2209s
#      0     0 6398.28935    0  189 6399.46333 6398.28935  0.02%     - 2209s
#      0     0 6398.29328    0  191 6399.46333 6398.29328  0.02%     - 2209s
#      0     0 6398.43591    0  226 6399.46333 6398.43591  0.02%     - 2227s
#      0     0 6398.43605    0  194 6399.46333 6398.43605  0.02%     - 2227s
#      0     0 6398.60169    0  160 6399.46333 6398.60169  0.01%     - 2256s
#      0     0 6398.60169    0  167 6399.46333 6398.60169  0.01%     - 2257s
#      0     0 6398.60169    0  150 6399.46333 6398.60169  0.01%     - 2260s
#      0     0 6398.60169    0  233 6399.46333 6398.60169  0.01%     - 2260s
#      0     0 6398.60169    0  195 6399.46333 6398.60169  0.01%     - 2260s
#      0     0 6398.60169    0  197 6399.46333 6398.60169  0.01%     - 2260s
#      0     0 6398.60169    0  167 6399.46333 6398.60169  0.01%     - 2260s
#      0     0 6398.60169    0  172 6399.46333 6398.60169  0.01%     - 2260s
#      0     0 6398.60169    0  182 6399.46333 6398.60169  0.01%     - 2260s
#      0     0 6398.60169    0  155 6399.46333 6398.60169  0.01%     - 2260s
#      0     0 6398.61626    0  142 6399.46333 6398.61626  0.01%     - 2260s
#      0     0 6398.61992    0  142 6399.46333 6398.61992  0.01%     - 2260s
#      0     0 6398.67400    0  107 6399.46333 6398.67400  0.01%     - 2268s
#      0     0 6398.67400    0  104 6399.46333 6398.67400  0.01%     - 2268s
#      0     0 6398.71857    0  109 6399.46333 6398.71857  0.01%     - 2280s
#      0     0 6398.71857    0  109 6399.46333 6398.71857  0.01%     - 2285s
#      0     0 6398.71857    0  153 6399.46333 6398.71857  0.01%     - 2286s
#      0     0 6398.71857    0  113 6399.46333 6398.71857  0.01%     - 2287s
#      0     0 6398.71857    0  213 6399.46333 6398.71857  0.01%     - 2287s
#      0     0 6398.71857    0  190 6399.46333 6398.71857  0.01%     - 2287s
#      0     0 6398.71857    0  180 6399.46333 6398.71857  0.01%     - 2288s
#      0     0 6398.71857    0  137 6399.46333 6398.71857  0.01%     - 2288s
#      0     0 6398.71857    0  144 6399.46333 6398.71857  0.01%     - 2288s
#      0     0 6398.71857    0  201 6399.46333 6398.71857  0.01%     - 2288s
#      0     0 6398.71857    0  108 6399.46333 6398.71857  0.01%     - 2288s
#      0     0 6398.71857    0  108 6399.46333 6398.71857  0.01%     - 2288s
#      0     0 6398.75483    0  119 6399.46333 6398.75483  0.01%     - 2293s
#      0     0 6398.76666    0  107 6399.46333 6398.76666  0.01%     - 2294s
#      0     0 6398.78590    0  103 6399.46333 6398.78590  0.01%     - 2301s
#      0     0 6398.80046    0  142 6399.46333 6398.80046  0.01%     - 2310s
#      0     0 6398.80046    0  142 6399.46333 6398.80046  0.01%     - 2314s
#      0     0 6398.80046    0  149 6399.46333 6398.80046  0.01%     - 2314s
#      0     0 6398.80046    0  121 6399.46333 6398.80046  0.01%     - 2315s
#      0     0 6398.80046    0  214 6399.46333 6398.80046  0.01%     - 2315s
#      0     0 6398.80046    0  203 6399.46333 6398.80046  0.01%     - 2315s
#      0     0 6398.80046    0  138 6399.46333 6398.80046  0.01%     - 2315s
#      0     0 6398.80046    0  164 6399.46333 6398.80046  0.01%     - 2315s
#      0     0 6398.80046    0  228 6399.46333 6398.80046  0.01%     - 2316s
#      0     0 6398.80046    0  100 6399.46333 6398.80046  0.01%     - 2316s
#      0     0 6398.80046    0  114 6399.46333 6398.80046  0.01%     - 2316s
#      0     0 6398.80966    0  115 6399.46333 6398.80966  0.01%     - 2316s
#      0     0 6398.81864    0   94 6399.46333 6398.81864  0.01%     - 2316s
#      0     0 6398.83946    0   93 6399.46333 6398.83946  0.01%     - 2321s
#
# Cutting planes:
#   Gomory: 153
#   Cover: 8
#   Implied bound: 4
#   MIR: 383
#   StrongCG: 14
#   Flow cover: 54
#   GUB cover: 1
#   Zero half: 7
#
# Explored 1 nodes (103183 simplex iterations) in 2321.87 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 7: 6399.46 6399.86 6400.46 ... 6498.67
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.399463333333e+03, best bound 6.398840000000e+03, gap 0.0097%
#
# -------------------------------------------------------------------------------
#
# Solving with random seed #3 ...
# Optimize a model with 23305 rows, 209732 columns and 624320 nonzeros
# Variable types: 0 continuous, 209732 integer (177854 binary)
# Coefficient statistics:
#   Matrix range     [2e-02, 1e+06]
#   Objective range  [2e+00, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Presolve removed 7994 rows and 12583 columns (presolve time = 5s) ...
# Presolve removed 9226 rows and 13815 columns (presolve time = 10s) ...
# Presolve removed 9994 rows and 14583 columns (presolve time = 15s) ...
# Presolve removed 9994 rows and 14583 columns
# Presolve time: 15.30s
# Presolved: 13311 rows, 195149 columns, 576963 nonzeros
# Variable types: 0 continuous, 195149 integer (174022 binary)
# Presolve removed 999 rows and 999 columns
# Presolved: 12312 rows, 194150 columns, 574926 nonzeros
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    6.2375167e+03   4.967388e+03   0.000000e+00     20s
#      633    6.2375167e+03   0.000000e+00   0.000000e+00     22s
#      633    6.2375167e+03   0.000000e+00   0.000000e+00     22s
#
# Root relaxation: objective 6.237517e+03, 633 iterations, 2.61 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 6237.51667    0  213          - 6237.51667      -     -   24s
#      0     0 6260.87107    0  320          - 6260.87107      -     -   65s
#      0     0 6262.63687    0  318          - 6262.63687      -     -   81s
#      0     0 6309.57118    0  376          - 6309.57118      -     -  122s
#      0     0 6312.30399    0  363          - 6312.30399      -     -  142s
#      0     0 6312.84150    0  353          - 6312.84150      -     -  142s
#      0     0 6312.84194    0  354          - 6312.84194      -     -  143s
#      0     0 6339.59129    0  385          - 6339.59129      -     -  195s
#      0     0 6340.46627    0  351          - 6340.46627      -     -  219s
#      0     0 6340.50959    0  355          - 6340.50959      -     -  219s
#      0     0 6340.51011    0  355          - 6340.51011      -     -  219s
#      0     0 6353.16798    0  339          - 6353.16798      -     -  279s
#      0     0 6354.68235    0  321          - 6354.68235      -     -  352s
#      0     0 6354.71354    0  312          - 6354.71354      -     -  353s
#      0     0 6364.60032    0  294          - 6364.60032      -     -  394s
#      0     0 6365.08209    0  272          - 6365.08209      -     -  462s
#      0     0 6365.08747    0  235          - 6365.08747      -     -  462s
#      0     0 6369.12332    0  258          - 6369.12332      -     -  503s
# H    0     0                    6477.8400000 6369.12332  1.68%     -  566s
# H    0     0                    6401.0733333 6369.12332  0.50%     -  639s
#      0     0 6369.53348    0  269 6401.07333 6369.53348  0.49%     -  640s
#      0     0 6369.53973    0  271 6401.07333 6369.53973  0.49%     -  641s
#      0     0 6373.81116    0  267 6401.07333 6373.81116  0.43%     -  687s
#      0     0 6373.81116    0  190 6401.07333 6373.81116  0.43%     -  721s
# H    0     0                    6400.5833333 6373.81116  0.42%     -  727s
#      0     0 6373.81116    0  345 6400.58333 6373.81116  0.42%     -  743s
# H    0     0                    6399.8133333 6373.81116  0.41%     -  759s
#      0     0 6373.81116    0  343 6399.81333 6373.81116  0.41%     -  763s
#      0     0 6373.81116    0  333 6399.81333 6373.81116  0.41%     -  767s
#      0     0 6375.56330    0  285 6399.81333 6375.56330  0.38%     -  767s
#      0     0 6380.15656    0  263 6399.81333 6380.15656  0.31%     -  768s
#      0     0 6381.53136    0  266 6399.81333 6381.53136  0.29%     -  768s
#      0     0 6382.39858    0  261 6399.81333 6382.39858  0.27%     -  769s
#      0     0 6382.47096    0  259 6399.81333 6382.47096  0.27%     -  769s
#      0     0 6386.28424    0  262 6399.81333 6386.28424  0.21%     -  811s
#      0     0 6386.28424    0  177 6399.81333 6386.28424  0.21%     -  824s
#      0     0 6386.28424    0  338 6399.81333 6386.28424  0.21%     -  839s
#      0     0 6386.28424    0  365 6399.81333 6386.28424  0.21%     -  846s
#      0     0 6386.28424    0  252 6399.81333 6386.28424  0.21%     -  846s
#      0     0 6386.28424    0  246 6399.81333 6386.28424  0.21%     -  847s
#      0     0 6386.28424    0  241 6399.81333 6386.28424  0.21%     -  847s
#      0     0 6386.93551    0  241 6399.81333 6386.93551  0.20%     -  847s
#      0     0 6387.49499    0  251 6399.81333 6387.49499  0.19%     -  847s
#      0     0 6387.51605    0  252 6399.81333 6387.51605  0.19%     -  848s
#      0     0 6387.51715    0  251 6399.81333 6387.51715  0.19%     -  848s
#      0     0 6391.09333    0  227 6399.81333 6391.09333  0.14%     -  912s
#      0     0 6391.18948    0  234 6399.81333 6391.18948  0.13%     -  916s
#      0     0 6391.22981    0  234 6399.81333 6391.22981  0.13%     -  917s
#      0     0 6392.15177    0  238 6399.81333 6392.15177  0.12%     -  970s
#      0     0 6392.15177    0  211 6399.81333 6392.15177  0.12%     -  975s
#      0     0 6392.15177    0  352 6399.81333 6392.15177  0.12%     -  986s
#      0     0 6392.15177    0  247 6399.81333 6392.15177  0.12%     -  989s
#      0     0 6392.15177    0  212 6399.81333 6392.15177  0.12%     -  989s
#      0     0 6392.15177    0  196 6399.81333 6392.15177  0.12%     -  989s
#      0     0 6392.15177    0  191 6399.81333 6392.15177  0.12%     -  989s
#      0     0 6392.19804    0  194 6399.81333 6392.19804  0.12%     -  989s
#      0     0 6392.55494    0  194 6399.81333 6392.55494  0.11%     -  989s
#      0     0 6392.59542    0  195 6399.81333 6392.59542  0.11%     -  989s
#      0     0 6393.14422    0  200 6399.81333 6393.14422  0.10%     - 1046s
# H    0     0                    6399.6033333 6393.14422  0.10%     - 1047s
# H    0     0                    6399.5333333 6393.14422  0.10%     - 1047s
# H    0     0                    6399.3700000 6393.14422  0.10%     - 1047s
#      0     0 6393.15632    0  203 6399.37000 6393.15632  0.10%     - 1047s
#      0     0 6394.06801    0  238 6399.37000 6394.06801  0.08%     - 1083s
#      0     0 6394.08345    0  222 6399.37000 6394.08345  0.08%     - 1084s
#      0     0 6394.74085    0  183 6399.37000 6394.74085  0.07%     - 1151s
#      0     0 6394.86073    0  184 6399.37000 6394.86073  0.07%     - 1153s
#      0     0 6394.86542    0  180 6399.37000 6394.86542  0.07%     - 1153s
#      0     0 6395.47860    0  170 6399.37000 6395.47860  0.06%     - 1203s
#      0     0 6395.48799    0  161 6399.37000 6395.48799  0.06%     - 1223s
#      0     0 6395.48799    0  161 6399.37000 6395.48799  0.06%     - 1242s
#      0     0 6395.48799    0  207 6399.37000 6395.48799  0.06%     - 1246s
#      0     0 6395.48799    0  320 6399.37000 6395.48799  0.06%     - 1261s
#      0     0 6395.48799    0  255 6399.37000 6395.48799  0.06%     - 1263s
#      0     0 6395.48799    0  181 6399.37000 6395.48799  0.06%     - 1263s
#      0     0 6395.48799    0  162 6399.37000 6395.48799  0.06%     - 1264s
#      0     0 6395.48799    0  189 6399.37000 6395.48799  0.06%     - 1264s
#      0     0 6395.48799    0  182 6399.37000 6395.48799  0.06%     - 1264s
#      0     0 6395.48799    0  193 6399.37000 6395.48799  0.06%     - 1264s
#      0     0 6395.48799    0  176 6399.37000 6395.48799  0.06%     - 1264s
#      0     0 6395.48799    0  186 6399.37000 6395.48799  0.06%     - 1264s
#      0     0 6395.53356    0  174 6399.37000 6395.53356  0.06%     - 1264s
#      0     0 6395.53851    0  166 6399.37000 6395.53851  0.06%     - 1264s
#      0     0 6396.09708    0  165 6399.37000 6396.09708  0.05%     - 1302s
#      0     0 6396.09746    0  165 6399.37000 6396.09746  0.05%     - 1303s
#      0     0 6396.29949    0  165 6399.37000 6396.29949  0.05%     - 1391s
#      0     0 6396.37746    0  165 6399.37000 6396.37746  0.05%     - 1418s
#      0     0 6396.37746    0  165 6399.37000 6396.37746  0.05%     - 1446s
#      0     0 6396.37746    0  205 6399.37000 6396.37746  0.05%     - 1449s
#      0     0 6396.37746    0  307 6399.37000 6396.37746  0.05%     - 1458s
#      0     0 6396.37746    0  241 6399.37000 6396.37746  0.05%     - 1461s
#      0     0 6396.37746    0  165 6399.37000 6396.37746  0.05%     - 1461s
#      0     0 6396.37746    0  143 6399.37000 6396.37746  0.05%     - 1461s
#      0     0 6396.37746    0  177 6399.37000 6396.37746  0.05%     - 1461s
#      0     0 6396.37746    0  175 6399.37000 6396.37746  0.05%     - 1461s
#      0     0 6396.37746    0  220 6399.37000 6396.37746  0.05%     - 1461s
#      0     0 6396.37746    0  173 6399.37000 6396.37746  0.05%     - 1461s
#      0     0 6396.37746    0  155 6399.37000 6396.37746  0.05%     - 1461s
#      0     0 6396.37746    0  123 6399.37000 6396.37746  0.05%     - 1461s
#      0     0 6396.37746    0  140 6399.37000 6396.37746  0.05%     - 1461s
#      0     0 6396.38191    0  160 6399.37000 6396.38191  0.05%     - 1461s
#      0     0 6396.62927    0  190 6399.37000 6396.62927  0.04%     - 1536s
#      0     0 6396.73209    0  218 6399.37000 6396.73209  0.04%     - 1537s
#      0     0 6396.74663    0  237 6399.37000 6396.74663  0.04%     - 1537s
#      0     0 6396.98798    0  191 6399.37000 6396.98798  0.04%     - 1597s
#      0     0 6397.10628    0  187 6399.37000 6397.10628  0.04%     - 1619s
#      0     0 6397.11310    0  178 6399.37000 6397.11310  0.04%     - 1659s
#      0     0 6397.11310    0  178 6399.37000 6397.11310  0.04%     - 1679s
#      0     0 6397.11310    0  196 6399.37000 6397.11310  0.04%     - 1681s
#      0     0 6397.11310    0  273 6399.37000 6397.11310  0.04%     - 1689s
#      0     0 6397.11310    0  242 6399.37000 6397.11310  0.04%     - 1690s
#      0     0 6397.11310    0  172 6399.37000 6397.11310  0.04%     - 1690s
#      0     0 6397.11310    0  140 6399.37000 6397.11310  0.04%     - 1690s
#      0     0 6397.11310    0  147 6399.37000 6397.11310  0.04%     - 1690s
#      0     0 6397.11310    0  150 6399.37000 6397.11310  0.04%     - 1690s
#      0     0 6397.11310    0  166 6399.37000 6397.11310  0.04%     - 1690s
#      0     0 6397.11310    0  148 6399.37000 6397.11310  0.04%     - 1690s
#      0     0 6397.11310    0  117 6399.37000 6397.11310  0.04%     - 1690s
#      0     0 6397.11310    0  149 6399.37000 6397.11310  0.04%     - 1690s
#      0     0 6397.11310    0  159 6399.37000 6397.11310  0.04%     - 1690s
#      0     0 6397.11310    0  185 6399.37000 6397.11310  0.04%     - 1690s
#      0     0 6397.11310    0  185 6399.37000 6397.11310  0.04%     - 1690s
#      0     0 6397.11649    0  173 6399.37000 6397.11649  0.04%     - 1691s
#      0     0 6397.13370    0  185 6399.37000 6397.13370  0.03%     - 1691s
#      0     0 6397.14726    0  179 6399.37000 6397.14726  0.03%     - 1691s
#      0     0 6397.82356    0  179 6399.37000 6397.82356  0.02%     - 1722s
#      0     0 6397.82928    0  180 6399.37000 6397.82928  0.02%     - 1723s
#      0     0 6398.15854    0  142 6399.37000 6398.15854  0.02%     - 1770s
#      0     0 6398.15854    0  181 6399.37000 6398.15854  0.02%     - 1770s
#      0     0 6398.15854    0  213 6399.37000 6398.15854  0.02%     - 1774s
#      0     0 6398.15854    0  212 6399.37000 6398.15854  0.02%     - 1775s
#      0     0 6398.15854    0  167 6399.37000 6398.15854  0.02%     - 1775s
#      0     0 6398.15854    0  151 6399.37000 6398.15854  0.02%     - 1775s
#      0     0 6398.15854    0  149 6399.37000 6398.15854  0.02%     - 1775s
#      0     0 6398.15854    0  133 6399.37000 6398.15854  0.02%     - 1775s
#      0     0 6398.15854    0  135 6399.37000 6398.15854  0.02%     - 1775s
#      0     0 6398.15854    0  159 6399.37000 6398.15854  0.02%     - 1775s
#      0     0 6398.15854    0  122 6399.37000 6398.15854  0.02%     - 1775s
#      0     0 6398.15854    0  159 6399.37000 6398.15854  0.02%     - 1775s
#      0     0 6398.19964    0  147 6399.37000 6398.19964  0.02%     - 1775s
#      0     0 6398.42269    0  197 6399.37000 6398.42269  0.01%     - 1800s
#      0     0 6398.42461    0  183 6399.37000 6398.42461  0.01%     - 1800s
#      0     0 6398.61491    0  111 6399.37000 6398.61491  0.01%     - 1829s
#      0     0 6398.61491    0  160 6399.37000 6398.61491  0.01%     - 1830s
#      0     0 6398.61491    0  151 6399.37000 6398.61491  0.01%     - 1832s
#      0     0 6398.61491    0  228 6399.37000 6398.61491  0.01%     - 1832s
#      0     0 6398.61491    0  182 6399.37000 6398.61491  0.01%     - 1832s
#      0     0 6398.61491    0  155 6399.37000 6398.61491  0.01%     - 1832s
#      0     0 6398.61491    0  124 6399.37000 6398.61491  0.01%     - 1832s
#      0     0 6398.61491    0  148 6399.37000 6398.61491  0.01%     - 1832s
#      0     0 6398.61491    0  123 6399.37000 6398.61491  0.01%     - 1832s
#      0     0 6398.61491    0  125 6399.37000 6398.61491  0.01%     - 1832s
#      0     0 6398.61491    0  125 6399.37000 6398.61491  0.01%     - 1832s
#      0     0 6398.61505    0  115 6399.37000 6398.61505  0.01%     - 1832s
#      0     0 6398.67490    0  118 6399.37000 6398.67490  0.01%     - 1842s
#      0     0 6398.68374    0  118 6399.37000 6398.68374  0.01%     - 1843s
#      0     0 6398.76108    0  144 6399.37000 6398.76108  0.01%     - 1854s
#
# Cutting planes:
#   Gomory: 192
#   Cover: 7
#   Implied bound: 5
#   Clique: 1
#   MIR: 442
#   StrongCG: 12
#   Flow cover: 39
#   Zero half: 5
#
# Explored 1 nodes (88946 simplex iterations) in 1854.85 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 7: 6399.37 6399.53 6399.6 ... 6477.84
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.399370000000e+03, best bound 6.398763333333e+03, gap 0.0095%
#
#
# -------------------------------------------------------------------------------
# Begin tuning (baseline mean runtime 1940.38s)...
# -------------------------------------------------------------------------------
#
# Testing candidate parameter set 2...
#
# 	SolutionLimit 10
# 	NormAdjust 0
# 	Heuristics 0.5
# 	MIPFocus 3
#
# Solving with random seed #1 ... runtime 2020.82s
# Solving with random seed #2 ...
#
# Tune time limit reached.
#
# -------------------------------------------------------------------------------
#
# Tested 1 parameter sets in 39160.21s
#
# Baseline parameter set: mean runtime 1940.38s
#
# -------------------------------------------------------------------------------
#
# Tested 1 parameter sets in 39160.21s
# Unable to improve on baseline parameter set.
#
# Optimize a model with 23305 rows, 209732 columns and 624320 nonzeros
# Variable types: 0 continuous, 209732 integer (177854 binary)
# Coefficient statistics:
#   Matrix range     [2e-02, 1e+06]
#   Objective range  [2e+00, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Presolve removed 9034 rows and 13623 columns (presolve time = 5s) ...
# Presolve removed 9994 rows and 14583 columns
# Presolve time: 9.28s
# Presolved: 13311 rows, 195149 columns, 576963 nonzeros
# Variable types: 0 continuous, 195149 integer (174022 binary)
# Presolve removed 999 rows and 999 columns
# Presolved: 12312 rows, 194150 columns, 574926 nonzeros
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    6.2375167e+03   4.967388e+03   0.000000e+00     13s
#      623    6.2375167e+03   0.000000e+00   0.000000e+00     14s
#      623    6.2375167e+03   0.000000e+00   0.000000e+00     15s
#
# Root relaxation: objective 6.237517e+03, 623 iterations, 1.91 seconds
# Total elapsed time = 15.32s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 6237.51667    0  213          - 6237.51667      -     -   16s
#      0     0 6264.37871    0  326          - 6264.37871      -     -   54s
#      0     0 6266.52091    0  325          - 6266.52091      -     -   69s
#      0     0 6310.41983    0  373          - 6310.41983      -     -  116s
#      0     0 6312.95787    0  363          - 6312.95787      -     -  138s
#      0     0 6313.46276    0  362          - 6313.46276      -     -  138s
#      0     0 6313.46319    0  362          - 6313.46319      -     -  139s
#      0     0 6340.43492    0  395          - 6340.43492      -     -  182s
#      0     0 6341.11566    0  363          - 6341.11566      -     -  199s
#      0     0 6341.14751    0  367          - 6341.14751      -     -  200s
#      0     0 6341.14786    0  367          - 6341.14786      -     -  200s
#      0     0 6354.45988    0  340          - 6354.45988      -     -  242s
#      0     0 6354.66918    0  327          - 6354.66918      -     -  301s
#      0     0 6354.68196    0  328          - 6354.68196      -     -  301s
#      0     0 6364.96090    0  320          - 6364.96090      -     -  342s
#      0     0 6365.50617    0  278          - 6365.50617      -     -  405s
#      0     0 6365.52423    0  280          - 6365.52423      -     -  406s
#      0     0 6368.88978    0  273          - 6368.88978      -     -  455s
#      0     0 6369.12330    0  243          - 6369.12330      -     -  521s
#      0     0 6369.12538    0  244          - 6369.12538      -     -  522s
#      0     0 6370.32421    0  246          - 6370.32421      -     -  567s
#      0     0 6370.34471    0  248          - 6370.34471      -     -  636s
#      0     0 6371.83367    0  246          - 6371.83367      -     -  683s
#      0     0 6371.88553    0  237          - 6371.88553      -     -  743s
#      0     0 6372.89397    0  279          - 6372.89397      -     -  789s
#      0     0 6372.90658    0  276          - 6372.90658      -     -  850s
#      0     0 6373.81660    0  265          - 6373.81660      -     -  903s
# H    0     0                    6480.0066667 6373.81660  1.64%     -  959s
# H    0     0                    6401.4466667 6373.81660  0.43%     - 1010s
#      0     0 6373.81976    0  272 6401.44667 6373.81976  0.43%     - 1010s
#      0     0 6382.89779    0  247 6401.44667 6382.89779  0.29%     - 1064s
#      0     0 6382.89779    0  197 6401.44667 6382.89779  0.29%     - 1080s
# H    0     0                    6400.7000000 6382.89779  0.28%     - 1083s
#      0     0 6382.89779    0  325 6400.70000 6382.89779  0.28%     - 1092s
#      0     0 6382.89779    0  369 6400.70000 6382.89779  0.28%     - 1102s
#      0     0 6382.89779    0  317 6400.70000 6382.89779  0.28%     - 1103s
#      0     0 6382.89779    0  230 6400.70000 6382.89779  0.28%     - 1103s
#      0     0 6382.89779    0  216 6400.70000 6382.89779  0.28%     - 1104s
#      0     0 6384.61114    0  293 6400.70000 6384.61114  0.25%     - 1104s
#      0     0 6385.17297    0  235 6400.70000 6385.17297  0.24%     - 1104s
#      0     0 6385.35843    0  239 6400.70000 6385.35843  0.24%     - 1104s
#      0     0 6385.48322    0  252 6400.70000 6385.48322  0.24%     - 1104s
#      0     0 6388.76924    0  282 6400.70000 6388.76924  0.19%     - 1162s
#      0     0 6388.76924    0  212 6400.70000 6388.76924  0.19%     - 1167s
#      0     0 6388.76924    0  309 6400.70000 6388.76924  0.19%     - 1178s
#      0     0 6388.76924    0  321 6400.70000 6388.76924  0.19%     - 1184s
#      0     0 6388.76924    0  196 6400.70000 6388.76924  0.19%     - 1185s
#      0     0 6388.76924    0  206 6400.70000 6388.76924  0.19%     - 1185s
#      0     0 6388.76924    0  263 6400.70000 6388.76924  0.19%     - 1185s
#      0     0 6388.92483    0  300 6400.70000 6388.92483  0.18%     - 1185s
#      0     0 6389.35428    0  268 6400.70000 6389.35428  0.18%     - 1186s
#      0     0 6389.45575    0  273 6400.70000 6389.45575  0.18%     - 1186s
#      0     0 6389.69937    0  286 6400.70000 6389.69937  0.17%     - 1186s
#      0     0 6389.82896    0  284 6400.70000 6389.82896  0.17%     - 1186s
# H    0     0                    6400.3033333 6389.82896  0.16%     - 1226s
#      0     0 6392.41864    0  229 6400.30333 6392.41864  0.12%     - 1252s
# H    0     0                    6400.2100000 6392.41864  0.12%     - 1254s
# H    0     0                    6400.0933333 6392.41864  0.12%     - 1254s
#      0     0 6392.48622    0  239 6400.09333 6392.48622  0.12%     - 1254s
#      0     0 6393.39838    0  233 6400.09333 6393.39838  0.10%     - 1330s
#      0     0 6393.39838    0  211 6400.09333 6393.39838  0.10%     - 1333s
#      0     0 6393.39838    0  313 6400.09333 6393.39838  0.10%     - 1341s
#      0     0 6393.39838    0  256 6400.09333 6393.39838  0.10%     - 1344s
#      0     0 6393.39838    0  206 6400.09333 6393.39838  0.10%     - 1344s
#      0     0 6393.39838    0  161 6400.09333 6393.39838  0.10%     - 1344s
#      0     0 6393.39838    0  186 6400.09333 6393.39838  0.10%     - 1344s
#      0     0 6393.39838    0  238 6400.09333 6393.39838  0.10%     - 1344s
#      0     0 6393.39838    0  231 6400.09333 6393.39838  0.10%     - 1344s
#      0     0 6393.39838    0  202 6400.09333 6393.39838  0.10%     - 1344s
#      0     0 6393.39838    0  221 6400.09333 6393.39838  0.10%     - 1344s
#      0     0 6393.63342    0  203 6400.09333 6393.63342  0.10%     - 1345s
#      0     0 6393.65333    0  211 6400.09333 6393.65333  0.10%     - 1345s
#      0     0 6393.65866    0  211 6400.09333 6393.65866  0.10%     - 1345s
# H    0     0                    6399.3933333 6393.65866  0.09%     - 1380s
#      0     0 6394.27230    0  204 6399.39333 6394.27230  0.08%     - 1407s
#      0     0 6394.41039    0  215 6399.39333 6394.41039  0.08%     - 1408s
#      0     0 6394.93184    0  205 6399.39333 6394.93184  0.07%     - 1491s
#      0     0 6394.93201    0  191 6399.39333 6394.93201  0.07%     - 1516s
#      0     0 6394.93201    0  191 6399.39333 6394.93201  0.07%     - 1539s
#      0     0 6394.93201    0  208 6399.39333 6394.93201  0.07%     - 1543s
#      0     0 6394.93201    0  311 6399.39333 6394.93201  0.07%     - 1551s
#      0     0 6394.93201    0  268 6399.39333 6394.93201  0.07%     - 1553s
#      0     0 6394.93201    0  190 6399.39333 6394.93201  0.07%     - 1553s
#      0     0 6394.93201    0  154 6399.39333 6394.93201  0.07%     - 1553s
#      0     0 6394.93201    0  169 6399.39333 6394.93201  0.07%     - 1553s
#      0     0 6394.93201    0  194 6399.39333 6394.93201  0.07%     - 1554s
#      0     0 6394.93201    0  146 6399.39333 6394.93201  0.07%     - 1554s
#      0     0 6394.93201    0  220 6399.39333 6394.93201  0.07%     - 1554s
#      0     0 6394.93201    0  189 6399.39333 6394.93201  0.07%     - 1554s
#      0     0 6394.93201    0  191 6399.39333 6394.93201  0.07%     - 1554s
#      0     0 6394.93201    0  184 6399.39333 6394.93201  0.07%     - 1554s
#      0     0 6394.94983    0  184 6399.39333 6394.94983  0.07%     - 1554s
#      0     0 6395.32094    0  258 6399.39333 6395.32094  0.06%     - 1588s
#      0     0 6395.37454    0  252 6399.39333 6395.37454  0.06%     - 1589s
#      0     0 6396.26472    0  152 6399.39333 6396.26472  0.05%     - 1667s
#      0     0 6396.35847    0  152 6399.39333 6396.35847  0.05%     - 1668s
#      0     0 6396.51889    0  173 6399.39333 6396.51889  0.04%     - 1710s
#      0     0 6396.51903    0  176 6399.39333 6396.51903  0.04%     - 1731s
#      0     0 6396.51903    0  176 6399.39333 6396.51903  0.04%     - 1751s
#      0     0 6396.51903    0  207 6399.39333 6396.51903  0.04%     - 1754s
#      0     0 6396.51903    0  297 6399.39333 6396.51903  0.04%     - 1762s
#      0     0 6396.51903    0  244 6399.39333 6396.51903  0.04%     - 1764s
#      0     0 6396.51903    0  151 6399.39333 6396.51903  0.04%     - 1764s
#      0     0 6396.51903    0  152 6399.39333 6396.51903  0.04%     - 1764s
#      0     0 6396.51903    0  189 6399.39333 6396.51903  0.04%     - 1764s
#      0     0 6396.51903    0  163 6399.39333 6396.51903  0.04%     - 1764s
#      0     0 6396.51903    0  121 6399.39333 6396.51903  0.04%     - 1764s
#      0     0 6396.51903    0  153 6399.39333 6396.51903  0.04%     - 1764s
#      0     0 6396.51903    0  161 6399.39333 6396.51903  0.04%     - 1764s
#      0     0 6396.51903    0  150 6399.39333 6396.51903  0.04%     - 1764s
#      0     0 6396.51903    0  173 6399.39333 6396.51903  0.04%     - 1764s
#      0     0 6396.51986    0  178 6399.39333 6396.51986  0.04%     - 1764s
#      0     0 6396.56560    0  176 6399.39333 6396.56560  0.04%     - 1764s
#      0     0 6396.59037    0  179 6399.39333 6396.59037  0.04%     - 1764s
#      0     0 6396.68767    0  192 6399.39333 6396.68767  0.04%     - 1764s
#      0     0 6396.69065    0  191 6399.39333 6396.69065  0.04%     - 1764s
#      0     0 6397.09818    0  138 6399.39333 6397.09818  0.04%     - 1800s
#      0     0 6397.12182    0  174 6399.39333 6397.12182  0.04%     - 1801s
# H    0     0                    6399.3700000 6397.12182  0.04%     - 1813s
#      0     0 6397.31494    0  138 6399.37000 6397.31494  0.03%     - 1838s
#      0     0 6397.41611    0  105 6399.37000 6397.41611  0.03%     - 1857s
#      0     0 6397.42439    0  105 6399.37000 6397.42439  0.03%     - 1866s
#      0     0 6397.43036    0  120 6399.37000 6397.43036  0.03%     - 1875s
#      0     0 6397.43036    0  120 6399.37000 6397.43036  0.03%     - 1885s
#      0     0 6397.43036    0  202 6399.37000 6397.43036  0.03%     - 1886s
#      0     0 6397.43036    0  272 6399.37000 6397.43036  0.03%     - 1889s
#      0     0 6397.43036    0  217 6399.37000 6397.43036  0.03%     - 1890s
#      0     0 6397.43036    0  159 6399.37000 6397.43036  0.03%     - 1890s
#      0     0 6397.43036    0  138 6399.37000 6397.43036  0.03%     - 1890s
#      0     0 6397.43036    0  163 6399.37000 6397.43036  0.03%     - 1890s
#      0     0 6397.43036    0  174 6399.37000 6397.43036  0.03%     - 1890s
#      0     0 6397.43036    0  123 6399.37000 6397.43036  0.03%     - 1890s
#      0     0 6397.43036    0  142 6399.37000 6397.43036  0.03%     - 1890s
#      0     0 6397.43036    0  147 6399.37000 6397.43036  0.03%     - 1890s
#      0     0 6397.43036    0  120 6399.37000 6397.43036  0.03%     - 1890s
#      0     0 6397.43036    0  100 6399.37000 6397.43036  0.03%     - 1890s
#      0     0 6397.43036    0   99 6399.37000 6397.43036  0.03%     - 1890s
#      0     0 6397.43036    0  130 6399.37000 6397.43036  0.03%     - 1910s
#      0     0 6397.52065    0  135 6399.37000 6397.52065  0.03%     - 1911s
#      0     0 6397.83093    0  148 6399.37000 6397.83093  0.02%     - 1911s
#      0     0 6398.39291    0  191 6399.37000 6398.39291  0.02%     - 1934s
#      0     0 6398.46792    0  169 6399.37000 6398.46792  0.01%     - 1934s
#      0     0 6398.56602    0  202 6399.37000 6398.56602  0.01%     - 1944s
#      0     0 6398.56602    0  169 6399.37000 6398.56602  0.01%     - 1944s
#      0     0 6398.56602    0  157 6399.37000 6398.56602  0.01%     - 1945s
#      0     0 6398.56602    0  234 6399.37000 6398.56602  0.01%     - 1945s
#      0     0 6398.56602    0  191 6399.37000 6398.56602  0.01%     - 1945s
#      0     0 6398.56602    0  188 6399.37000 6398.56602  0.01%     - 1946s
#      0     0 6398.56602    0  117 6399.37000 6398.56602  0.01%     - 1946s
#      0     0 6398.56602    0  135 6399.37000 6398.56602  0.01%     - 1946s
#      0     0 6398.56602    0  166 6399.37000 6398.56602  0.01%     - 1946s
#      0     0 6398.57942    0  134 6399.37000 6398.57942  0.01%     - 1946s
#      0     0 6398.65548    0  103 6399.37000 6398.65548  0.01%     - 1953s
#      0     0 6398.66579    0  129 6399.37000 6398.66579  0.01%     - 1953s
#      0     0 6398.69882    0  163 6399.37000 6398.69882  0.01%     - 1959s
#      0     0 6398.69882    0  151 6399.37000 6398.69882  0.01%     - 1959s
#      0     0 6398.69882    0  121 6399.37000 6398.69882  0.01%     - 1959s
#      0     0 6398.69882    0  207 6399.37000 6398.69882  0.01%     - 1959s
#      0     0 6398.69882    0  199 6399.37000 6398.69882  0.01%     - 1959s
#      0     0 6398.69882    0  181 6399.37000 6398.69882  0.01%     - 1959s
#      0     0 6398.69882    0  153 6399.37000 6398.69882  0.01%     - 1959s
#      0     0 6398.69882    0  136 6399.37000 6398.69882  0.01%     - 1959s
#      0     0 6398.69882    0  119 6399.37000 6398.69882  0.01%     - 1960s
#      0     0 6398.69882    0  114 6399.37000 6398.69882  0.01%     - 1960s
#      0     0 6398.69882    0  160 6399.37000 6398.69882  0.01%     - 1960s
#      0     0 6398.70258    0  160 6399.37000 6398.70258  0.01%     - 1960s
#      0     0 6398.76473    0  112 6399.37000 6398.76473  0.01%     - 1963s
#
# Cutting planes:
#   Gomory: 157
#   Cover: 9
#   Implied bound: 2
#   Clique: 2
#   MIR: 435
#   StrongCG: 20
#   Flow cover: 35
#   GUB cover: 1
#   Zero half: 7
#   Mod-K: 1
#
# Explored 1 nodes (91976 simplex iterations) in 1963.52 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 8: 6399.37 6399.39 6400.09 ... 6480.01
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.399370000000e+03, best bound 6.398766666667e+03, gap 0.0094%
# "\nif model.tuneResultCount > 0:\n\n    # Load the best tuned parameters into the model\n    model.getTuneResult(0)\n\n    # Write tuned parameters to a file\n    model.write('tune.prm')\n\n    # Solve the model using the tuned parameters\n    model.optimize()\n    \n"

# %%
def turn_to_df(Var, col_name = None):  # Here you could input the variable
    solution = model.getAttr('x_', Var)
    num_col = len(solution.keys()[0])
    collect = []
    for row in range(0, len(solution)):
        new_row = []
        for col in range(0, num_col):
            new_row.append(solution.keys()[row][col])
        new_row.append(solution[solution.keys()[row]])
    
        collect.append(new_row)
    return pd.DataFrame(collect, columns = col_name)

# %%
Hub_Indirect = turn_to_df(x_, ["Ori_Hub", "Transit_Hub","Dest_Hub", "Taken"])
Hub_Indirect[Hub_Indirect.Taken > 0 ]
# Out:
#                       Ori_Hub         Transit_Hub  \
# 249                 Kaunas-LT           Poznań-PL
# 524                 Lisboa-PT           Zagreb-HR
# 593                Brüssel-BE           Zagreb-HR
# 1322                Lisboa-PT           Zagreb-HR
# 1349                Lisboa-PT          Plzen 1-CZ
# 1688                Lisboa-PT  Eindhoven-Noord-NL
# 1972             Barcelona-ES           Zagreb-HR
# 1993                Lisboa-PT        Ljubljana-SI
# 5011                 Malmö-SE     Budapest OLK-HU
# 5189                Lisboa-PT        Ljubljana-SI
# 9303     Vantaa (Helsinki)-FL     Budapest OLK-HU
# 10771   PZ 93 (Regensburg)-DE           Zagreb-HR
# 11033            Barcelona-ES           Zagreb-HR
# 11346               Lisboa-PT  Eindhoven-Noord-NL
# 11521    Vantaa (Helsinki)-FL       Hagenbrunn-AT
# 18338            Barcelona-ES        Ljubljana-SI
# 22515              Brüssel-BE  Araba (Vitoria)-ES
# 22829               Lisboa-PT  Eindhoven-Noord-NL
# 22861               Lisboa-PT  Araba (Vitoria)-ES
# 25657               Lisboa-PT  Araba (Vitoria)-ES
# 25845      Eindhoven-Noord-NL           Zagreb-HR
# 27957               Slough-GB  Eindhoven-Noord-NL
# 28005        Lieto (Turku)-FL  Araba (Vitoria)-ES
# 31955               Slough-GB           Zagreb-HR
# 33461                Malmö-SE  Araba (Vitoria)-ES
# 36515                Malmö-SE  Eindhoven-Noord-NL
# 37734               Slough-GB     Budapest OLK-HU
# 45463               Slough-GB          Brüssel-BE
# 48123               Lisboa-PT  Araba (Vitoria)-ES
# 55792               Slough-GB  Eindhoven-Noord-NL
# 55878               Slough-GB  Araba (Vitoria)-ES
# 71955      Eindhoven-Noord-NL  Araba (Vitoria)-ES
# 73012               Poznań-PL          Brüssel-BE
# 74525               Lisboa-PT  Araba (Vitoria)-ES
# 75862               Slough-GB          Brüssel-BE
# 77245              Wrocław-PL     PZ 77 (Lahr)-DE
# 106918             Wrocław-PL     PZ 77 (Lahr)-DE
# 121567              Poznań-PL  Eindhoven-Noord-NL
# 156518              Slough-GB  Eindhoven-Noord-NL
# 158190             Wrocław-PL         Krupka 1-CZ
# 163163                Enns-AT          Plzen 1-CZ
# 168502     Eindhoven-Noord-NL          Brüssel-BE
#
#                            Dest_Hub  Taken
# 249                        Malmö-SE    1.0
# 524                        Sofia-BG    1.0
# 593                        Sofia-BG    1.0
# 1322                       Spata-GR    1.0
# 1349           Ivanka pri Dunaji-SK    1.0
# 1688                       Malmö-SE    1.0
# 1972                       Spata-GR    1.0
# 1993                      Oradea-RO    1.0
# 5011                       Sofia-BG    1.0
# 5189                Budapest OLK-HU    1.0
# 9303                       Sofia-BG    1.0
# 10771                      Spata-GR    1.0
# 11033                      Sofia-BG    1.0
# 11346                     Poznań-PL    1.0
# 11521                  Ljubljana-SI    1.0
# 18338                     Oradea-RO    1.0
# 22515                     Lisboa-PT    1.0
# 22829                    Kolding-DK    1.0
# 22861              Lieto (Turku)-FL    1.0
# 25657                    Brüssel-BE    1.0
# 25845                      Sofia-BG    1.0
# 27957                     Kaunas-LT    1.0
# 28005                     Lisboa-PT    1.0
# 31955                      Sofia-BG    1.0
# 33461                     Lisboa-PT    1.0
# 36515                     Dublin-IE    1.0
# 37734                     Oradea-RO    1.0
# 45463                      Spata-GR    1.0
# 48123                     Dublin-IE    1.0
# 55792              Lieto (Turku)-FL    1.0
# 55878                     Lisboa-PT    1.0
# 71955                     Lisboa-PT    1.0
# 73012                     Dublin-IE    1.0
# 74525                     Slough-GB    1.0
# 75862                       Wals-AT    1.0
# 77245                     Lisboa-PT    1.0
# 106918                 Barcelona-ES    1.0
# 121567                    Slough-GB    1.0
# 156518           PZ 47 (Krefeld)-DE    1.0
# 158190  PZ 04 (Radefeld/Leipzig)-DE    1.0
# 163163        PZ 93 (Regensburg)-DE    1.0
# 168502           PZ 47 (Krefeld)-DE    1.0

# %%
Country_Direct = turn_to_df(X, ["Ori_Country", "Dest_Country", "Taken"])
Country_Indirect = turn_to_df(X_, ["Ori_Country", "Transit_Country","Dest_Country", "Taken"])

Hub_Direct = turn_to_df(x, ["Ori_Hub", "Dest_Hub", "Taken"])
Hub_Indirect = turn_to_df(x_, ["Ori_Hub", "Transit_Hub","Dest_Hub", "Taken"])

Route_Cap = turn_to_df(V, ["Ori_Hub", "Dest_Hub", "Taken"])
Freq = turn_to_df(F, ["Ori_Hub", "Dest_Hub","Truck Type", "Taken"])
#Start = turn_to_df(S, ["Ori_Hub", "Dest_Hub", "Time"])
#Night = turn_to_df(N, ["Ori_Hub", "Dest_Hub", "Nights"])
Co_load = turn_to_df(CL, ["Ori_Hub", "Dest_Hub", "Amount"])
CL_sol =  model.getAttr('x_', CL)

# %%
for key in attri_dict.keys():
    df_output = turn_to_df(attri_dict[key])
    df_output.to_csv(f"Output/{key}_output.csv")

# %%
ind = Country_Indirect.Taken.sum()
d = Country_Direct.Taken.sum()

print(f"{ind} indriect routes and {d} direct route, total: {len(Z)}" )
# Out:
# 42.0 indriect routes and 170.0 direct route, total: 212

# %%
freq_result = model.getAttr('x', F)
demand_filled = model.getAttr('x', V)
print("Cost by Route Cap.:", round(sum(freq_result[p,q,t] * C[t] * cost[p,q,t] for p, q, t in pqt) / (sum(demand_filled[p,q] for p, q in pq_all)/4), 2))
print("Cost by Capacity.:", sum(freq_result[p,q,t] * C[t] * cost[p,q,t] for p, q,t in pqt) / (sum(freq_result[p,q,t] * C[t] for p, q,t in pqt)))
print("Cost by Demands.:", sum(freq_result[p,q,t] * C[t] * cost[p,q,t] for p, q,t in pqt) / (sum(Z[m, k] for m, k in mk)/4))
print("Cost by Demands + Co-load:", sum(freq_result[p,q,t] * C[t] * cost[p,q,t] for p, q, t in pqt) / (sum(Z[m, k] for m, k in mk)/4 + sum(CL_sol[p, q] for p, q in pq_all)))
# Out:
# Cost by Route Cap.: 0.08
# Cost by Capacity.: 0.07303555043783896
# Cost by Demands.: 0.12999281747966585
# Cost by Demands + Co-load: 0.1176304820765471

# %%
sum(F_[p,q,t] * C[t] * cost[p,q,t] for p, q, t in pqt) / sum(F_[p,q,t] * C[t] for p,q,t in pqt)
# Out:
# 0.07470231825180568

# %%
Freq_result = Freq[Freq.Taken > 0]
Freq_result.groupby("Truck Type").count()
# Out:
#                Ori_Hub  Dest_Hub  Taken
# Truck Type
# 2 Swap Bodies       33        33     33
# Co-loading           3         3      3
# Swap Body           51        51     51
# Van                122       122    122

# %%
Freq_result = Freq[Freq.Taken > 0]
Freq_result["agg"] = Freq_result["Ori_Hub"] + Freq_result["Dest_Hub"]
print(Freq_result.groupby("Truck Type").count()) # Truck type count per routes

Freq_result["Capacity"] = Freq_result.apply(lambda row: C[row["Truck Type"]] * row["Taken"] * 4, axis = 1)
capacity_from_freq = Freq_result.groupby(["agg"]).sum()


# Indirect Route Overview

Hub_Indirect_T = Hub_Indirect[Hub_Indirect.Taken > 0]
Hub_Indirect_T["First"] = Hub_Indirect_T["Ori_Hub"] + Hub_Indirect_T["Transit_Hub"]
Hub_Indirect_T["Second"] = Hub_Indirect_T["Transit_Hub"] + Hub_Indirect_T["Dest_Hub"]

Hub_merge = Hub_Indirect_T.merge(capacity_from_freq.loc[:, "Capacity"], left_on = "First", right_on = "agg", how = "right")
Hub_merge = Hub_merge.merge(capacity_from_freq.loc[:, "Capacity"], left_on = "Second", right_on = "agg", how = "right")

pd.options.display.max_rows = 100
Hub_merge.dropna()
# Out:
#                Ori_Hub  Dest_Hub  Taken  agg
# Truck Type
# 2 Swap Bodies       33        33     33   33
# Co-loading           3         3      3    3
# Swap Body           51        51     51   51
# Van                122       122    122  122
# C:\Users\MAHITA\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\MAHITA\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# C:\Users\MAHITA\Anaconda3\lib\site-packages\ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
# C:\Users\MAHITA\Anaconda3\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]
#                   Ori_Hub         Transit_Hub                     Dest_Hub  \
# 0               Kaunas-LT           Poznań-PL                     Malmö-SE
# 1               Lisboa-PT           Zagreb-HR                     Sofia-BG
# 2              Brüssel-BE           Zagreb-HR                     Sofia-BG
# 3            Barcelona-ES           Zagreb-HR                     Sofia-BG
# 4      Eindhoven-Noord-NL           Zagreb-HR                     Sofia-BG
# 5               Slough-GB           Zagreb-HR                     Sofia-BG
# 6               Lisboa-PT           Zagreb-HR                     Spata-GR
# 7            Barcelona-ES           Zagreb-HR                     Spata-GR
# 8   PZ 93 (Regensburg)-DE           Zagreb-HR                     Spata-GR
# 9               Lisboa-PT          Plzen 1-CZ         Ivanka pri Dunaji-SK
# 10              Lisboa-PT  Eindhoven-Noord-NL                     Malmö-SE
# 11              Lisboa-PT  Eindhoven-Noord-NL                    Poznań-PL
# 12              Lisboa-PT  Eindhoven-Noord-NL                   Kolding-DK
# 13              Lisboa-PT        Ljubljana-SI                    Oradea-RO
# 14           Barcelona-ES        Ljubljana-SI                    Oradea-RO
# 15              Lisboa-PT        Ljubljana-SI              Budapest OLK-HU
# 16               Malmö-SE     Budapest OLK-HU                     Sofia-BG
# 17   Vantaa (Helsinki)-FL     Budapest OLK-HU                     Sofia-BG
# 18   Vantaa (Helsinki)-FL       Hagenbrunn-AT                 Ljubljana-SI
# 19             Brüssel-BE  Araba (Vitoria)-ES                    Lisboa-PT
# 20       Lieto (Turku)-FL  Araba (Vitoria)-ES                    Lisboa-PT
# 21               Malmö-SE  Araba (Vitoria)-ES                    Lisboa-PT
# 22              Slough-GB  Araba (Vitoria)-ES                    Lisboa-PT
# 23     Eindhoven-Noord-NL  Araba (Vitoria)-ES                    Lisboa-PT
# 24              Lisboa-PT  Araba (Vitoria)-ES             Lieto (Turku)-FL
# 25              Lisboa-PT  Araba (Vitoria)-ES                   Brüssel-BE
# 26              Lisboa-PT  Araba (Vitoria)-ES                    Dublin-IE
# 27              Lisboa-PT  Araba (Vitoria)-ES                    Slough-GB
# 28              Slough-GB  Eindhoven-Noord-NL                    Kaunas-LT
# 29              Slough-GB  Eindhoven-Noord-NL             Lieto (Turku)-FL
# 30              Slough-GB  Eindhoven-Noord-NL           PZ 47 (Krefeld)-DE
# 31               Malmö-SE  Eindhoven-Noord-NL                    Dublin-IE
# 32              Slough-GB     Budapest OLK-HU                    Oradea-RO
# 33              Slough-GB          Brüssel-BE                     Spata-GR
# 34              Slough-GB          Brüssel-BE                      Wals-AT
# 35              Poznań-PL          Brüssel-BE                    Dublin-IE
# 36             Wrocław-PL     PZ 77 (Lahr)-DE                    Lisboa-PT
# 37             Wrocław-PL     PZ 77 (Lahr)-DE                 Barcelona-ES
# 38              Poznań-PL  Eindhoven-Noord-NL                    Slough-GB
# 39             Wrocław-PL         Krupka 1-CZ  PZ 04 (Radefeld/Leipzig)-DE
# 40                Enns-AT          Plzen 1-CZ        PZ 93 (Regensburg)-DE
# 41     Eindhoven-Noord-NL          Brüssel-BE           PZ 47 (Krefeld)-DE
#
#     Taken                                 First  \
# 0     1.0                    Kaunas-LTPoznań-PL
# 1     1.0                    Lisboa-PTZagreb-HR
# 2     1.0                   Brüssel-BEZagreb-HR
# 3     1.0                 Barcelona-ESZagreb-HR
# 4     1.0           Eindhoven-Noord-NLZagreb-HR
# 5     1.0                    Slough-GBZagreb-HR
# 6     1.0                    Lisboa-PTZagreb-HR
# 7     1.0                 Barcelona-ESZagreb-HR
# 8     1.0        PZ 93 (Regensburg)-DEZagreb-HR
# 9     1.0                   Lisboa-PTPlzen 1-CZ
# 10    1.0           Lisboa-PTEindhoven-Noord-NL
# 11    1.0           Lisboa-PTEindhoven-Noord-NL
# 12    1.0           Lisboa-PTEindhoven-Noord-NL
# 13    1.0                 Lisboa-PTLjubljana-SI
# 14    1.0              Barcelona-ESLjubljana-SI
# 15    1.0                 Lisboa-PTLjubljana-SI
# 16    1.0               Malmö-SEBudapest OLK-HU
# 17    1.0   Vantaa (Helsinki)-FLBudapest OLK-HU
# 18    1.0     Vantaa (Helsinki)-FLHagenbrunn-AT
# 19    1.0          Brüssel-BEAraba (Vitoria)-ES
# 20    1.0    Lieto (Turku)-FLAraba (Vitoria)-ES
# 21    1.0            Malmö-SEAraba (Vitoria)-ES
# 22    1.0           Slough-GBAraba (Vitoria)-ES
# 23    1.0  Eindhoven-Noord-NLAraba (Vitoria)-ES
# 24    1.0           Lisboa-PTAraba (Vitoria)-ES
# 25    1.0           Lisboa-PTAraba (Vitoria)-ES
# 26    1.0           Lisboa-PTAraba (Vitoria)-ES
# 27    1.0           Lisboa-PTAraba (Vitoria)-ES
# 28    1.0           Slough-GBEindhoven-Noord-NL
# 29    1.0           Slough-GBEindhoven-Noord-NL
# 30    1.0           Slough-GBEindhoven-Noord-NL
# 31    1.0            Malmö-SEEindhoven-Noord-NL
# 32    1.0              Slough-GBBudapest OLK-HU
# 33    1.0                   Slough-GBBrüssel-BE
# 34    1.0                   Slough-GBBrüssel-BE
# 35    1.0                   Poznań-PLBrüssel-BE
# 36    1.0             Wrocław-PLPZ 77 (Lahr)-DE
# 37    1.0             Wrocław-PLPZ 77 (Lahr)-DE
# 38    1.0           Poznań-PLEindhoven-Noord-NL
# 39    1.0                 Wrocław-PLKrupka 1-CZ
# 40    1.0                     Enns-ATPlzen 1-CZ
# 41    1.0          Eindhoven-Noord-NLBrüssel-BE
#
#                                     Second  Capacity_x  Capacity_y
# 0                        Poznań-PLMalmö-SE      9000.0     16764.0
# 1                        Zagreb-HRSofia-BG      9000.0      9000.0
# 2                        Zagreb-HRSofia-BG      9000.0      9000.0
# 3                        Zagreb-HRSofia-BG      9000.0      9000.0
# 4                        Zagreb-HRSofia-BG      9000.0      9000.0
# 5                        Zagreb-HRSofia-BG      9000.0      9000.0
# 6                        Zagreb-HRSpata-GR      9000.0      9000.0
# 7                        Zagreb-HRSpata-GR      9000.0      9000.0
# 8                        Zagreb-HRSpata-GR      9000.0      9000.0
# 9           Plzen 1-CZIvanka pri Dunaji-SK      9000.0      9000.0
# 10              Eindhoven-Noord-NLMalmö-SE      9000.0      9000.0
# 11             Eindhoven-Noord-NLPoznań-PL      9000.0      9000.0
# 12            Eindhoven-Noord-NLKolding-DK      9000.0      9000.0
# 13                   Ljubljana-SIOradea-RO      9000.0      9000.0
# 14                   Ljubljana-SIOradea-RO      9000.0      9000.0
# 15             Ljubljana-SIBudapest OLK-HU      9000.0      9000.0
# 16                 Budapest OLK-HUSofia-BG      9000.0      9000.0
# 17                 Budapest OLK-HUSofia-BG      9000.0      9000.0
# 18               Hagenbrunn-ATLjubljana-SI      9000.0      9000.0
# 19             Araba (Vitoria)-ESLisboa-PT      9000.0     16764.0
# 20             Araba (Vitoria)-ESLisboa-PT      9000.0     16764.0
# 21             Araba (Vitoria)-ESLisboa-PT      9000.0     16764.0
# 22             Araba (Vitoria)-ESLisboa-PT     50288.0     16764.0
# 23             Araba (Vitoria)-ESLisboa-PT     50288.0     16764.0
# 24      Araba (Vitoria)-ESLieto (Turku)-FL     16764.0      9000.0
# 25            Araba (Vitoria)-ESBrüssel-BE     16764.0      9000.0
# 26             Araba (Vitoria)-ESDublin-IE     16764.0      9000.0
# 27             Araba (Vitoria)-ESSlough-GB     16764.0     33524.0
# 28             Eindhoven-Noord-NLKaunas-LT    536384.0      9000.0
# 29      Eindhoven-Noord-NLLieto (Turku)-FL    536384.0      9000.0
# 30    Eindhoven-Noord-NLPZ 47 (Krefeld)-DE    536384.0    486156.0
# 31             Eindhoven-Noord-NLDublin-IE      9000.0     33524.0
# 32                Budapest OLK-HUOradea-RO      9000.0      9000.0
# 33                      Brüssel-BESpata-GR     33524.0      9000.0
# 34                       Brüssel-BEWals-AT     33524.0     33524.0
# 35                     Brüssel-BEDublin-IE     33524.0     16764.0
# 36                PZ 77 (Lahr)-DELisboa-PT     67048.0     33524.0
# 37             PZ 77 (Lahr)-DEBarcelona-ES     67048.0     50288.0
# 38             Eindhoven-Noord-NLSlough-GB    100572.0    109572.0
# 39  Krupka 1-CZPZ 04 (Radefeld/Leipzig)-DE    787816.0    787908.0
# 40         Plzen 1-CZPZ 93 (Regensburg)-DE    938784.0   1139952.0
# 41            Brüssel-BEPZ 47 (Krefeld)-DE   1433940.0   1525524.0

# %%
Z["NL", "GB"]
# Out:
# 35554

# %% [markdown]
# ## Checking if some routes exist

# %%
("FR","ES") in mk_all
# Out:
# True

# %%
'''
solution = model.getAttr('x_', X_)
print(solution[("HU", "AT","BE")])

solution_dir = model.getAttr('x_', X)
solution_dir[("AT","BE")]
'''
# Out:
# '\nsolution = model.getAttr(\'x_\', X_)\nprint(solution[("HU", "AT","BE")])\n\nsolution_dir = model.getAttr(\'x_\', X)\nsolution_dir[("AT","BE")]\n'

# %%
Freq["Ori_C"] = Freq.apply(lambda row: row.Ori_Hub.rsplit("-")[-1], axis = 1)
Freq["Dest_C"] = Freq.apply(lambda row: row.Dest_Hub.rsplit("-")[-1], axis = 1)
Freq[Freq.Taken > 0]
# Out:
#                         Ori_Hub                     Dest_Hub     Truck Type  \
# 38                    Kaunas-LT                    Poznań-PL            Van
# 531                   Lisboa-PT           Araba (Vitoria)-ES      Swap Body
# 633                Ljubljana-SI                    Oradea-RO            Van
# 648                Ljubljana-SI              Budapest OLK-HU            Van
# 756          Araba (Vitoria)-ES                    Lisboa-PT      Swap Body
# 988                  Plzen 1-CZ         Ivanka pri Dunaji-SK            Van
# 1763            Budapest OLK-HU                     Sofia-BG            Van
# 1803            Budapest OLK-HU                    Oradea-RO            Van
# 2533              Hagenbrunn-AT                 Ljubljana-SI            Van
# 3671         Eindhoven-Noord-NL                   Brüssel-BE      Swap Body
# 3673         Eindhoven-Noord-NL                   Brüssel-BE            Van
# 5568                  Zagreb-HR                     Sofia-BG            Van
# 5623                  Zagreb-HR                     Spata-GR            Van
# 7653                   Sofia-BG         Vantaa (Helsinki)-FL            Van
# 7668                   Sofia-BG                    Lisboa-PT            Van
# 7673                  Lisboa-PT                 Ljubljana-SI            Van
# 7678               Ljubljana-SI                   Brüssel-BE            Van
# 7693               Ljubljana-SI                    Zabrze-PL            Van
# 7713                   Sofia-BG                    Kaunas-LT            Van
# 7778                 Brüssel-BE                    Kaunas-LT            Van
# 7783                 Brüssel-BE                 Ljubljana-SI            Van
# 7789                   Sofia-BG                Hub Wien I-AT     Co-loading
# 7848                 Ostrava-CZ                    Kaunas-LT            Van
# 7883                 Brüssel-BE                     Spata-GR            Van
# 7888               Barcelona-ES                   Kolding-DK            Van
# 7903               Barcelona-ES                    Kaunas-LT            Van
# 7933                 Ostrava-CZ         Vantaa (Helsinki)-FL            Van
# 7998                 Brüssel-BE                    Zagreb-HR            Van
# 8093      PZ 15 (Rüdersdorf)-DE                    Kaunas-LT            Van
# 8108                  Lisboa-PT               Bettembourg-LU            Van
# 8144         PZ 21 (Hamburg)-DE                      Oslo-NO     Co-loading
# 8288         PZ 47 (Krefeld)-DE                    Dublin-IE            Van
# 8323                  Lisboa-PT                    Zagreb-HR            Van
# 8348         Araba (Vitoria)-ES             Lieto (Turku)-FL            Van
# 8363                 Brüssel-BE         Ivanka pri Dunaji-SK            Van
# 8368            Budapest OLK-HU               Bettembourg-LU            Van
# 8388                   Sofia-BG                 Barcelona-ES            Van
# 8418                  Lisboa-PT                   Plzen 1-CZ            Van
# 8583                 Brüssel-BE                   Plzen 1-CZ            Van
# 8633      PZ 93 (Regensburg)-DE                    Zagreb-HR            Van
# 8748                Krupka 1-CZ                     Malmö-SE            Van
# 8878               Barcelona-ES               Bettembourg-LU            Van
# 8893               Ljubljana-SI           Eindhoven-Noord-NL            Van
# 8923                   Malmö-SE                    Oradea-RO            Van
# 8998                    Wals-AT           Eindhoven-Noord-NL            Van
# 9038                 Brüssel-BE              Budapest OLK-HU            Van
# 9048           Lieto (Turku)-FL               Bettembourg-LU            Van
# 9069               Barcelona-ES               Helsingborg-SE     Co-loading
# 9168                   Malmö-SE                 Ljubljana-SI            Van
# 9173               Barcelona-ES              Budapest OLK-HU            Van
# ...                         ...                          ...            ...
# 15971                  Arlöv-SE                   Kolding-DK      Swap Body
# 15976                  Malmö-SE                   Kolding-DK      Swap Body
# 15980        Eindhoven-Noord-NL                    Slough-GB  2 Swap Bodies
# 15983        Eindhoven-Noord-NL                    Slough-GB            Van
# 16171        PZ 21 (Hamburg)-DE                     Malmö-SE      Swap Body
# 16173        PZ 21 (Hamburg)-DE                     Malmö-SE            Van
# 16450             Hagenbrunn-AT                    Zabrze-PL  2 Swap Bodies
# 16451             Hagenbrunn-AT                    Zabrze-PL      Swap Body
# 16780        Eindhoven-Noord-NL           Araba (Vitoria)-ES  2 Swap Bodies
# 16781        Eindhoven-Noord-NL           Araba (Vitoria)-ES      Swap Body
# 16851        PZ 47 (Krefeld)-DE                   Brüssel-BE      Swap Body
# 16870                Brüssel-BE                    Slough-GB  2 Swap Bodies
# 16871                Brüssel-BE                    Slough-GB      Swap Body
# 16890                 Slough-GB           Araba (Vitoria)-ES  2 Swap Bodies
# 16891                 Slough-GB           Araba (Vitoria)-ES      Swap Body
# 17220                  Malmö-SE           PZ 21 (Hamburg)-DE  2 Swap Bodies
# 17221                  Malmö-SE           PZ 21 (Hamburg)-DE      Swap Body
# 17270  Stockholm - Västberga-SE             Lieto (Turku)-FL  2 Swap Bodies
# 17310        Eindhoven-Noord-NL            Combs la ville-FR  2 Swap Bodies
# 17320                 Slough-GB           Eindhoven-Noord-NL  2 Swap Bodies
# 17375        Eindhoven-Noord-NL                      Wals-AT  2 Swap Bodies
# 17491                Ostrava-CZ                    Zabrze-PL      Swap Body
# 17493                Ostrava-CZ                    Zabrze-PL            Van
# 17945                  Malmö-SE                      Wals-AT  2 Swap Bodies
# 18361     PZ 15 (Rüdersdorf)-DE                    Poznań-PL      Swap Body
# 18496                Brüssel-BE           PZ 47 (Krefeld)-DE      Swap Body
# 18826     PZ 93 (Regensburg)-DE                      Wals-AT      Swap Body
# 19285               Göteborg-SE                      Oslo-NO  2 Swap Bodies
# 19330              Barcelona-ES              PZ 77 (Lahr)-DE  2 Swap Bodies
# 19525           PZ 50 (Köln)-DE            Combs la ville-FR  2 Swap Bodies
# 19611                 Zabrze-PL           Zilina- Strecno-SK      Swap Body
# 19750        PZ 47 (Krefeld)-DE                    Slough-GB  2 Swap Bodies
# 19753        PZ 47 (Krefeld)-DE                    Slough-GB            Van
# 19795          Lieto (Turku)-FL     Stockholm - Västberga-SE  2 Swap Bodies
# 19796          Lieto (Turku)-FL     Stockholm - Västberga-SE      Swap Body
# 19926                 Zabrze-PL                   Ostrava-CZ      Swap Body
# 20010                Wrocław-PL                  Krupka 1-CZ  2 Swap Bodies
# 20011                Wrocław-PL                  Krupka 1-CZ      Swap Body
# 20121            Hub Wien II-AT                      Brno-CZ      Swap Body
# 20201             Hagenbrunn-AT                      Brno-CZ      Swap Body
# 20296                   Enns-AT                   Plzen 1-CZ      Swap Body
# 20671               Krupka 1-CZ  PZ 04 (Radefeld/Leipzig)-DE      Swap Body
# 20756                Plzen 1-CZ        PZ 93 (Regensburg)-DE      Swap Body
# 21086        Zilina- Strecno-SK                   Ostrava-CZ      Swap Body
# 21088        Zilina- Strecno-SK                   Ostrava-CZ            Van
# 21111        Zilina- Strecno-SK                      Zlin-CZ      Swap Body
# 21261        PZ 47 (Krefeld)-DE           Eindhoven-Noord-NL      Swap Body
# 21263        PZ 47 (Krefeld)-DE           Eindhoven-Noord-NL            Van
# 21740                Wrocław-PL              PZ 77 (Lahr)-DE  2 Swap Bodies
# 22681        Eindhoven-Noord-NL           PZ 47 (Krefeld)-DE      Swap Body
#
#        Taken Ori_C Dest_C
# 38       1.0    LT     PL
# 531      1.0    PT     ES
# 633      1.0    SI     RO
# 648      1.0    SI     HU
# 756      1.0    ES     PT
# 988      1.0    CZ     SK
# 1763     1.0    HU     BG
# 1803     1.0    HU     RO
# 2533     1.0    AT     SI
# 3671    85.0    NL     BE
# 3673     1.0    NL     BE
# 5568     1.0    HR     BG
# 5623     1.0    HR     GR
# 7653     1.0    BG     FL
# 7668     1.0    BG     PT
# 7673     1.0    PT     SI
# 7678     1.0    SI     BE
# 7693     1.0    SI     PL
# 7713     1.0    BG     LT
# 7778     1.0    BE     LT
# 7783     1.0    BE     SI
# 7789     1.0    BG     AT
# 7848     1.0    CZ     LT
# 7883     1.0    BE     GR
# 7888     1.0    ES     DK
# 7903     1.0    ES     LT
# 7933     1.0    CZ     FL
# 7998     1.0    BE     HR
# 8093     1.0    DE     LT
# 8108     1.0    PT     LU
# 8144     1.0    DE     NO
# 8288     1.0    DE     IE
# 8323     1.0    PT     HR
# 8348     1.0    ES     FL
# 8363     1.0    BE     SK
# 8368     1.0    HU     LU
# 8388     1.0    BG     ES
# 8418     1.0    PT     CZ
# 8583     1.0    BE     CZ
# 8633     1.0    DE     HR
# 8748     1.0    CZ     SE
# 8878     1.0    ES     LU
# 8893     1.0    SI     NL
# 8923     1.0    SE     RO
# 8998     1.0    AT     NL
# 9038     1.0    BE     HU
# 9048     1.0    FL     LU
# 9069     2.0    ES     SE
# 9168     1.0    SE     SI
# 9173     1.0    ES     HU
# ...      ...   ...    ...
# 15971    2.0    SE     DK
# 15976    3.0    SE     DK
# 15980    3.0    NL     GB
# 15983    1.0    NL     GB
# 16171    2.0    DE     SE
# 16173    1.0    DE     SE
# 16450    1.0    AT     PL
# 16451    1.0    AT     PL
# 16780    1.0    NL     ES
# 16781    1.0    NL     ES
# 16851    3.0    DE     BE
# 16870    1.0    BE     GB
# 16871    1.0    BE     GB
# 16890    1.0    GB     ES
# 16891    1.0    GB     ES
# 17220    1.0    SE     DE
# 17221    1.0    SE     DE
# 17270    2.0    SE     FL
# 17310    2.0    NL     FR
# 17320   16.0    GB     NL
# 17375    2.0    NL     AT
# 17491    4.0    CZ     PL
# 17493    1.0    CZ     PL
# 17945    2.0    SE     AT
# 18361    5.0    DE     PL
# 18496   91.0    BE     DE
# 18826    6.0    DE     AT
# 19285    3.0    SE     NO
# 19330    3.0    ES     DE
# 19525    3.0    DE     FR
# 19611    6.0    PL     SK
# 19750    3.0    DE     GB
# 19753    1.0    DE     GB
# 19795    3.0    FL     SE
# 19796    1.0    FL     SE
# 19926    8.0    PL     CZ
# 20010   23.0    PL     CZ
# 20011    1.0    PL     CZ
# 20121    1.0    AT     CZ
# 20201    9.0    AT     CZ
# 20296   56.0    AT     CZ
# 20671   47.0    CZ     DE
# 20756   68.0    CZ     DE
# 21086   12.0    SK     CZ
# 21088    1.0    SK     CZ
# 21111    1.0    SK     CZ
# 21261   17.0    DE     NL
# 21263    1.0    DE     NL
# 21740    2.0    PL     DE
# 22681   29.0    NL     DE
#
# [209 rows x 6 columns]

# %%
Freq.loc[(Freq["Ori_C"] == "BE") & (Freq["Dest_C"] == "DE"), :]
# Out:
#           Ori_Hub                     Dest_Hub     Truck Type  Taken Ori_C  \
# 18445  Brüssel-BE            PZ 67 (Speyer)-DE  2 Swap Bodies   -0.0    BE
# 18446  Brüssel-BE            PZ 67 (Speyer)-DE      Swap Body   -0.0    BE
# 18447  Brüssel-BE            PZ 67 (Speyer)-DE        Trailer   -0.0    BE
# 18448  Brüssel-BE            PZ 67 (Speyer)-DE            Van   -0.0    BE
# 18449  Brüssel-BE            PZ 67 (Speyer)-DE     Co-loading   -0.0    BE
# 18450  Brüssel-BE              PZ 50 (Köln)-DE  2 Swap Bodies   -0.0    BE
# 18451  Brüssel-BE              PZ 50 (Köln)-DE      Swap Body    0.0    BE
# 18452  Brüssel-BE              PZ 50 (Köln)-DE        Trailer   -0.0    BE
# 18453  Brüssel-BE              PZ 50 (Köln)-DE            Van   -0.0    BE
# 18454  Brüssel-BE              PZ 50 (Köln)-DE     Co-loading   -0.0    BE
# 18455  Brüssel-BE  PZ 04 (Radefeld/Leipzig)-DE  2 Swap Bodies   -0.0    BE
# 18456  Brüssel-BE  PZ 04 (Radefeld/Leipzig)-DE      Swap Body   -0.0    BE
# 18457  Brüssel-BE  PZ 04 (Radefeld/Leipzig)-DE        Trailer   -0.0    BE
# 18458  Brüssel-BE  PZ 04 (Radefeld/Leipzig)-DE            Van   -0.0    BE
# 18459  Brüssel-BE  PZ 04 (Radefeld/Leipzig)-DE     Co-loading   -0.0    BE
# 18460  Brüssel-BE   PZ 90 (Feucht/Nürnberg)-DE  2 Swap Bodies   -0.0    BE
# 18461  Brüssel-BE   PZ 90 (Feucht/Nürnberg)-DE      Swap Body   -0.0    BE
# 18462  Brüssel-BE   PZ 90 (Feucht/Nürnberg)-DE        Trailer   -0.0    BE
# 18463  Brüssel-BE   PZ 90 (Feucht/Nürnberg)-DE            Van   -0.0    BE
# 18464  Brüssel-BE   PZ 90 (Feucht/Nürnberg)-DE     Co-loading   -0.0    BE
# 18465  Brüssel-BE              PZ 77 (Lahr)-DE  2 Swap Bodies   -0.0    BE
# 18466  Brüssel-BE              PZ 77 (Lahr)-DE      Swap Body   -0.0    BE
# 18467  Brüssel-BE              PZ 77 (Lahr)-DE        Trailer   -0.0    BE
# 18468  Brüssel-BE              PZ 77 (Lahr)-DE            Van   -0.0    BE
# 18469  Brüssel-BE              PZ 77 (Lahr)-DE     Co-loading   -0.0    BE
# 18470  Brüssel-BE        PZ 93 (Regensburg)-DE  2 Swap Bodies   -0.0    BE
# 18471  Brüssel-BE        PZ 93 (Regensburg)-DE      Swap Body   -0.0    BE
# 18472  Brüssel-BE        PZ 93 (Regensburg)-DE        Trailer   -0.0    BE
# 18473  Brüssel-BE        PZ 93 (Regensburg)-DE            Van   -0.0    BE
# 18474  Brüssel-BE        PZ 93 (Regensburg)-DE     Co-loading   -0.0    BE
# 18475  Brüssel-BE           PZ 21 (Hamburg)-DE  2 Swap Bodies   -0.0    BE
# 18476  Brüssel-BE           PZ 21 (Hamburg)-DE      Swap Body   -0.0    BE
# 18477  Brüssel-BE           PZ 21 (Hamburg)-DE        Trailer   -0.0    BE
# 18478  Brüssel-BE           PZ 21 (Hamburg)-DE            Van   -0.0    BE
# 18479  Brüssel-BE           PZ 21 (Hamburg)-DE     Co-loading   -0.0    BE
# 18480  Brüssel-BE           PZ 46 (Dorsten)-DE  2 Swap Bodies   -0.0    BE
# 18481  Brüssel-BE           PZ 46 (Dorsten)-DE      Swap Body   -0.0    BE
# 18482  Brüssel-BE           PZ 46 (Dorsten)-DE        Trailer   -0.0    BE
# 18483  Brüssel-BE           PZ 46 (Dorsten)-DE            Van   -0.0    BE
# 18484  Brüssel-BE           PZ 46 (Dorsten)-DE     Co-loading   -0.0    BE
# 18485  Brüssel-BE             PZ 58 (Hagen)-DE  2 Swap Bodies   -0.0    BE
# 18486  Brüssel-BE             PZ 58 (Hagen)-DE      Swap Body   -0.0    BE
# 18487  Brüssel-BE             PZ 58 (Hagen)-DE        Trailer   -0.0    BE
# 18488  Brüssel-BE             PZ 58 (Hagen)-DE            Van   -0.0    BE
# 18489  Brüssel-BE             PZ 58 (Hagen)-DE     Co-loading   -0.0    BE
# 18490  Brüssel-BE           PZ 08 (Neumark)-DE  2 Swap Bodies   -0.0    BE
# 18491  Brüssel-BE           PZ 08 (Neumark)-DE      Swap Body   -0.0    BE
# 18492  Brüssel-BE           PZ 08 (Neumark)-DE        Trailer   -0.0    BE
# 18493  Brüssel-BE           PZ 08 (Neumark)-DE            Van   -0.0    BE
# 18494  Brüssel-BE           PZ 08 (Neumark)-DE     Co-loading   -0.0    BE
# 18495  Brüssel-BE           PZ 47 (Krefeld)-DE  2 Swap Bodies   -0.0    BE
# 18496  Brüssel-BE           PZ 47 (Krefeld)-DE      Swap Body   91.0    BE
# 18497  Brüssel-BE           PZ 47 (Krefeld)-DE        Trailer   -0.0    BE
# 18498  Brüssel-BE           PZ 47 (Krefeld)-DE            Van   -0.0    BE
# 18499  Brüssel-BE           PZ 47 (Krefeld)-DE     Co-loading   -0.0    BE
# 18500  Brüssel-BE        PZ 15 (Rüdersdorf)-DE  2 Swap Bodies    0.0    BE
# 18501  Brüssel-BE        PZ 15 (Rüdersdorf)-DE      Swap Body   -0.0    BE
# 18502  Brüssel-BE        PZ 15 (Rüdersdorf)-DE        Trailer   -0.0    BE
# 18503  Brüssel-BE        PZ 15 (Rüdersdorf)-DE            Van   -0.0    BE
# 18504  Brüssel-BE        PZ 15 (Rüdersdorf)-DE     Co-loading   -0.0    BE
# 18505  Brüssel-BE        PZ 24 (Neumünster)-DE  2 Swap Bodies   -0.0    BE
# 18506  Brüssel-BE        PZ 24 (Neumünster)-DE      Swap Body   -0.0    BE
# 18507  Brüssel-BE        PZ 24 (Neumünster)-DE        Trailer   -0.0    BE
# 18508  Brüssel-BE        PZ 24 (Neumünster)-DE            Van   -0.0    BE
# 18509  Brüssel-BE        PZ 24 (Neumünster)-DE     Co-loading   -0.0    BE
# 18510  Brüssel-BE   PZ 44 (Bochum) [im Bau]-DE  2 Swap Bodies   -0.0    BE
# 18511  Brüssel-BE   PZ 44 (Bochum) [im Bau]-DE      Swap Body   -0.0    BE
# 18512  Brüssel-BE   PZ 44 (Bochum) [im Bau]-DE        Trailer   -0.0    BE
# 18513  Brüssel-BE   PZ 44 (Bochum) [im Bau]-DE            Van   -0.0    BE
# 18514  Brüssel-BE   PZ 44 (Bochum) [im Bau]-DE     Co-loading   -0.0    BE
#
#       Dest_C
# 18445     DE
# 18446     DE
# 18447     DE
# 18448     DE
# 18449     DE
# 18450     DE
# 18451     DE
# 18452     DE
# 18453     DE
# 18454     DE
# 18455     DE
# 18456     DE
# 18457     DE
# 18458     DE
# 18459     DE
# 18460     DE
# 18461     DE
# 18462     DE
# 18463     DE
# 18464     DE
# 18465     DE
# 18466     DE
# 18467     DE
# 18468     DE
# 18469     DE
# 18470     DE
# 18471     DE
# 18472     DE
# 18473     DE
# 18474     DE
# 18475     DE
# 18476     DE
# 18477     DE
# 18478     DE
# 18479     DE
# 18480     DE
# 18481     DE
# 18482     DE
# 18483     DE
# 18484     DE
# 18485     DE
# 18486     DE
# 18487     DE
# 18488     DE
# 18489     DE
# 18490     DE
# 18491     DE
# 18492     DE
# 18493     DE
# 18494     DE
# 18495     DE
# 18496     DE
# 18497     DE
# 18498     DE
# 18499     DE
# 18500     DE
# 18501     DE
# 18502     DE
# 18503     DE
# 18504     DE
# 18505     DE
# 18506     DE
# 18507     DE
# 18508     DE
# 18509     DE
# 18510     DE
# 18511     DE
# 18512     DE
# 18513     DE
# 18514     DE

# %% [markdown]
# # Check the relationship between Route Capacity and Demands

# %%
Route_Cap["Ori_C"] = Route_Cap.apply(lambda row: row.Ori_Hub.rsplit("-")[-1], axis = 1)
Route_Cap["Dest_C"] = Route_Cap.apply(lambda row: row.Dest_Hub.rsplit("-")[-1], axis = 1)
Route_Cap["Demands"] = Route_Cap.apply(lambda row: Z[row.Ori_C, row.Dest_C] if (row.Ori_C, row.Dest_C) in Z.keys() else 0, axis = 1)

# %%
# Route_Cap.loc[(Route_Cap["Ori_C"] == "DE") & (Route_Cap["Dest_C"] == "FL"), :]
Route_Cap[Route_Cap.Taken > 0]
# Out:
#                           Ori_Hub                     Dest_Hub      Taken  \
# 7                       Kaunas-LT                    Poznań-PL       14.0
# 106                     Lisboa-PT           Araba (Vitoria)-ES    13937.0
# 126                  Ljubljana-SI                    Oradea-RO      340.0
# 129                  Ljubljana-SI              Budapest OLK-HU       94.0
# 151            Araba (Vitoria)-ES                    Lisboa-PT    15843.0
# 197                    Plzen 1-CZ         Ivanka pri Dunaji-SK       37.0
# 352               Budapest OLK-HU                     Sofia-BG      259.0
# 360               Budapest OLK-HU                    Oradea-RO     1173.0
# 506                 Hagenbrunn-AT                 Ljubljana-SI      196.0
# 734            Eindhoven-Noord-NL                   Brüssel-BE  1433385.0
# 1113                    Zagreb-HR                     Sofia-BG     1381.0
# 1124                    Zagreb-HR                     Spata-GR      273.0
# 1530                     Sofia-BG         Vantaa (Helsinki)-FL       17.0
# 1533                     Sofia-BG                    Lisboa-PT       22.0
# 1534                    Lisboa-PT                 Ljubljana-SI      176.0
# 1535                 Ljubljana-SI                   Brüssel-BE       27.0
# 1538                 Ljubljana-SI                    Zabrze-PL       30.0
# 1542                     Sofia-BG                    Kaunas-LT       31.0
# 1555                   Brüssel-BE                    Kaunas-LT       58.0
# 1556                   Brüssel-BE                 Ljubljana-SI       61.0
# 1557                     Sofia-BG                Hub Wien I-AT       61.0
# 1569                   Ostrava-CZ                    Kaunas-LT       64.0
# 1576                   Brüssel-BE                     Spata-GR     2008.0
# 1577                 Barcelona-ES                   Kolding-DK       75.0
# 1580                 Barcelona-ES                    Kaunas-LT       76.0
# 1586                   Ostrava-CZ         Vantaa (Helsinki)-FL       83.0
# 1599                   Brüssel-BE                    Zagreb-HR      105.0
# 1618        PZ 15 (Rüdersdorf)-DE                    Kaunas-LT       99.0
# 1621                    Lisboa-PT               Bettembourg-LU      107.0
# 1628           PZ 21 (Hamburg)-DE                      Oslo-NO      124.0
# 1657           PZ 47 (Krefeld)-DE                    Dublin-IE      134.0
# 1664                    Lisboa-PT                    Zagreb-HR      191.0
# 1669           Araba (Vitoria)-ES             Lieto (Turku)-FL      522.0
# 1672                   Brüssel-BE         Ivanka pri Dunaji-SK      143.0
# 1673              Budapest OLK-HU               Bettembourg-LU      157.0
# 1677                     Sofia-BG                 Barcelona-ES      175.0
# 1683                    Lisboa-PT                   Plzen 1-CZ      215.0
# 1716                   Brüssel-BE                   Plzen 1-CZ      199.0
# 1726        PZ 93 (Regensburg)-DE                    Zagreb-HR      389.0
# 1749                  Krupka 1-CZ                     Malmö-SE      211.0
# 1775                 Barcelona-ES               Bettembourg-LU      219.0
# 1778                 Ljubljana-SI           Eindhoven-Noord-NL      220.0
# 1784                     Malmö-SE                    Oradea-RO      256.0
# 1799                      Wals-AT           Eindhoven-Noord-NL      268.0
# 1807                   Brüssel-BE              Budapest OLK-HU      270.0
# 1809             Lieto (Turku)-FL               Bettembourg-LU      276.0
# 1813                 Barcelona-ES               Helsingborg-SE      282.0
# 1833                     Malmö-SE                 Ljubljana-SI      299.0
# 1834                 Barcelona-ES              Budapest OLK-HU      301.0
# 1849                     Malmö-SE         Ivanka pri Dunaji-SK      324.0
# ...                           ...                          ...        ...
# 2709                    Zabrze-PL              Budapest OLK-HU    10217.0
# 2717                    Slough-GB                   Brüssel-BE    28548.0
# 2735                    Lisboa-PT              PZ 77 (Lahr)-DE    10770.0
# 2748             Suwałki (Ełk)-PL         Vantaa (Helsinki)-FL    11173.0
# 2760                    Poznań-PL                   Brüssel-BE    23501.0
# 2798        PZ 93 (Regensburg)-DE                 Ljubljana-SI    22360.0
# 2817        PZ 93 (Regensburg)-DE              Budapest OLK-HU    22426.0
# 2838                      Brno-CZ                Hagenbrunn-AT    22601.0
# 2934        PZ 93 (Regensburg)-DE         Ivanka pri Dunaji-SK    22870.0
# 2957             Lieto (Turku)-FL           PZ 21 (Hamburg)-DE    25037.0
# 2980           Eindhoven-Noord-NL                    Dublin-IE    26445.0
# 2985                    Poznań-PL           Eindhoven-Noord-NL    93526.0
# 2995                      Brno-CZ              Budapest OLK-HU    28440.0
# 3036                    Zabrze-PL                Hagenbrunn-AT    28959.0
# 3077                    Slough-GB            Combs la ville-FR    33992.0
# 3097  PZ 04 (Radefeld/Leipzig)-DE                  Krupka 1-CZ    34848.0
# 3195                     Malmö-SE                   Kolding-DK    35084.0
# 3196           Eindhoven-Noord-NL                    Slough-GB   103167.0
# 3234           PZ 21 (Hamburg)-DE                     Malmö-SE    35601.0
# 3290                Hagenbrunn-AT                    Zabrze-PL    37699.0
# 3356           Eindhoven-Noord-NL           Araba (Vitoria)-ES    48560.0
# 3370           PZ 47 (Krefeld)-DE                   Brüssel-BE    38721.0
# 3374                   Brüssel-BE                    Slough-GB    39911.0
# 3378                    Slough-GB           Araba (Vitoria)-ES    45765.0
# 3444                     Malmö-SE           PZ 21 (Hamburg)-DE    48234.0
# 3454     Stockholm - Västberga-SE             Lieto (Turku)-FL    50491.0
# 3462           Eindhoven-Noord-NL            Combs la ville-FR    50960.0
# 3464                    Slough-GB           Eindhoven-Noord-NL   536083.0
# 3475           Eindhoven-Noord-NL                      Wals-AT    61227.0
# 3498                   Ostrava-CZ                    Zabrze-PL    61940.0
# 3589                     Malmö-SE                      Wals-AT    63353.0
# 3672        PZ 15 (Rüdersdorf)-DE                    Poznań-PL    75854.0
# 3699                   Brüssel-BE           PZ 47 (Krefeld)-DE  1518705.0
# 3765        PZ 93 (Regensburg)-DE                      Wals-AT    89665.0
# 3857                  Göteborg-SE                      Oslo-NO    92346.0
# 3866                 Barcelona-ES              PZ 77 (Lahr)-DE    94403.0
# 3905              PZ 50 (Köln)-DE            Combs la ville-FR    96813.0
# 3922                    Zabrze-PL           Zilina- Strecno-SK    98453.0
# 3950           PZ 47 (Krefeld)-DE                    Slough-GB   100659.0
# 3959             Lieto (Turku)-FL     Stockholm - Västberga-SE   116234.0
# 3985                    Zabrze-PL                   Ostrava-CZ   128337.0
# 4002                   Wrocław-PL                  Krupka 1-CZ   777502.0
# 4040                Hagenbrunn-AT                      Brno-CZ   146713.0
# 4059                      Enns-AT                   Plzen 1-CZ   932495.0
# 4134                  Krupka 1-CZ  PZ 04 (Radefeld/Leipzig)-DE   777502.0
# 4151                   Plzen 1-CZ        PZ 93 (Regensburg)-DE  1131598.0
# 4217           Zilina- Strecno-SK                   Ostrava-CZ   201434.0
# 4252           PZ 47 (Krefeld)-DE           Eindhoven-Noord-NL   280731.0
# 4348                   Wrocław-PL              PZ 77 (Lahr)-DE    54125.0
# 4536           Eindhoven-Noord-NL           PZ 47 (Krefeld)-DE   471880.0
#
#      Ori_C Dest_C  Demands
# 7       LT     PL        0
# 106     PT     ES        0
# 126     SI     RO        0
# 129     SI     HU        0
# 151     ES     PT        0
# 197     CZ     SK        0
# 352     HU     BG        0
# 360     HU     RO        0
# 506     AT     SI        0
# 734     NL     BE        0
# 1113    HR     BG        0
# 1124    HR     GR        0
# 1530    BG     FL       17
# 1533    BG     PT       22
# 1534    PT     SI       26
# 1535    SI     BE       27
# 1538    SI     PL       30
# 1542    BG     LT       31
# 1555    BE     LT       58
# 1556    BE     SI       61
# 1557    BG     AT       61
# 1569    CZ     LT       64
# 1576    BE     GR       71
# 1577    ES     DK       75
# 1580    ES     LT       76
# 1586    CZ     FL       83
# 1599    BE     HR       83
# 1618    DE     LT       99
# 1621    PT     LU      107
# 1628    DE     NO      124
# 1657    DE     IE      134
# 1664    PT     HR      134
# 1669    ES     FL      138
# 1672    BE     SK      143
# 1673    HU     LU      157
# 1677    BG     ES      175
# 1683    PT     CZ      178
# 1716    BE     CZ      199
# 1726    DE     HR      209
# 1749    CZ     SE      211
# 1775    ES     LU      219
# 1778    SI     NL      220
# 1784    SE     RO      256
# 1799    AT     NL      268
# 1807    BE     HU      270
# 1809    FL     LU      276
# 1813    ES     SE      282
# 1833    SE     SI      299
# 1834    ES     HU      301
# 1849    SE     SK      324
# ...    ...    ...      ...
# 2709    PL     HU    10217
# 2717    GB     BE    10401
# 2735    PT     DE    10770
# 2748    PL     FL    11173
# 2760    PL     BE    12766
# 2798    DE     SI    22360
# 2817    DE     HU    22426
# 2838    CZ     AT    22601
# 2934    DE     SK    22870
# 2957    FL     DE    25037
# 2980    NL     IE    25330
# 2985    PL     NL    25913
# 2995    CZ     HU    28440
# 3036    PL     AT    28959
# 3077    GB     FR    33992
# 3097    DE     CZ    34848
# 3195    SE     DK    35084
# 3196    NL     GB    35554
# 3234    DE     SE    35601
# 3290    AT     PL    37699
# 3356    NL     ES    38417
# 3370    DE     BE    38721
# 3374    BE     GB    39911
# 3378    GB     ES    41968
# 3444    SE     DE    48234
# 3454    SE     FL    50491
# 3462    NL     FR    50960
# 3464    GB     NL    60242
# 3475    NL     AT    61227
# 3498    CZ     PL    61940
# 3589    SE     AT    63353
# 3672    DE     PL    75854
# 3699    BE     DE    85320
# 3765    DE     AT    89665
# 3857    SE     NO    92346
# 3866    ES     DE    94403
# 3905    DE     FR    96813
# 3922    PL     SK    98453
# 3950    DE     GB   100659
# 3959    FL     SE   116234
# 3985    PL     CZ   128337
# 4002    PL     CZ   128337
# 4040    AT     CZ   146713
# 4059    AT     CZ   146713
# 4134    CZ     DE   199103
# 4151    CZ     DE   199103
# 4217    SK     CZ   201434
# 4252    DE     NL   280731
# 4348    PL     DE   777502
# 4536    NL     DE  1433385
#
# [187 rows x 6 columns]

# %%
Route_Cap.loc[(Route_Cap["Ori_C"] == "BE") & (Route_Cap["Dest_C"] == "NL"), :]
# Out:
#         Ori_Hub            Dest_Hub  Taken Ori_C Dest_C  Demands
# 111  Brüssel-BE  Eindhoven-Noord-NL    0.0    BE     NL        0
# 112  Brüssel-BE       Zaltbommel-NL    0.0    BE     NL        0

# %%
Z["BE", "AT"]
# Out:
# 5943

# %%
("NL", "AT") in mk_all
# Out:
# True
